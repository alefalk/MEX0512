# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}

param_grid = {
    'lr': [0.01],
    'n_tree': [80],
    'tree_depth': [9],
    'tree_feature_rate': [0.5],
    'feat_dropout': [0.1],
    'out_size_nrf': [768]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 1)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.3450
# Epoch 050 | NRF Loss: 2.2653 | Val Acc: 0.8283
# Epoch 100 | NRF Loss: 1.4664 | Val Acc: 0.8589
# Epoch 150 | NRF Loss: 1.0058 | Val Acc: 0.8778
# Epoch 200 | NRF Loss: 0.7761 | Val Acc: 0.8839
# Epoch 250 | NRF Loss: 0.6507 | Val Acc: 0.8911
# Epoch 300 | NRF Loss: 0.5759 | Val Acc: 0.8939
# Epoch 350 | NRF Loss: 0.5257 | Val Acc: 0.9039
# Epoch 400 | NRF Loss: 0.4904 | Val Acc: 0.9022
# Epoch 450 | NRF Loss: 0.4627 | Val Acc: 0.9067
# Epoch 500 | NRF Loss: 0.4423 | Val Acc: 0.9111
# Epoch 550 | NRF Loss: 0.4262 | Val Acc: 0.9094
# Epoch 600 | NRF Loss: 0.4121 | Val Acc: 0.9133
# Epoch 650 | NRF Loss: 0.4016 | Val Acc: 0.9128
# Epoch 700 | NRF Loss: 0.3927 | Val Acc: 0.9161
# Epoch 750 | NRF Loss: 0.3852 | Val Acc: 0.9200
# Epoch 800 | NRF Loss: 0.3789 | Val Acc: 0.9189
# Epoch 850 | NRF Loss: 0.3737 | Val Acc: 0.9211
# Epoch 900 | NRF Loss: 0.3680 | Val Acc: 0.9206
# Epoch 950 | NRF Loss: 0.3627 | Val Acc: 0.9206
# Epoch 1000 | NRF Loss: 0.3576 | Val Acc: 0.9233
# Epoch 1050 | NRF Loss: 0.3546 | Val Acc: 0.9211
# Epoch 1100 | NRF Loss: 0.3509 | Val Acc: 0.9217
# Epoch 1150 | NRF Loss: 0.3478 | Val Acc: 0.9200
# Early stopping at epoch 1176
# Best validation acc: 0.9261 @ epoch 876
# Evaluating on test set using full graph...
# 0.917222261428833

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.917222261428833, 'epoch': 876, 'y_pred': ['Boko Haram', "Kurdistan Workers' Party (PKK)", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Muslim extremists', 'Al-Shabaab', 'Al-Shabaab', 'Palestinians', 'Liberation Tigers of Tamil Eelam (LTTE)', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Nicaraguan Democratic Force (FDN)', 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Houthi extremists (Ansar Allah)', 'Taliban', 'Palestinians', 'Houthi extremists (Ansar Allah)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Shining Path (SL)', "Donetsk People's Republic", 'Abu Sayyaf Group (ASG)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Houthi extremists (Ansar Allah)', 'Islamic State of Iraq and the Levant (ISIL)', 'Liberation Tigers of Tamil Eelam (LTTE)', "Donetsk People's Republic", 'Taliban', 'Houthi extremists (Ansar Allah)', 'Shining Path (SL)', 'Taliban', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Communist Party of India - Maoist (CPI-Maoist)', 'Farabundo Marti National Liberation Front (FMLN)', 'Farabundo Marti National Liberation Front (FMLN)', 'Islamic State of Iraq and the Levant (ISIL)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Sikh Extremists', 'African National Congress (South Africa)', 'Boko Haram', 'Farabundo Marti National Liberation Front (FMLN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Liberation Tigers of Tamil Eelam (LTTE)', "Donetsk People's Republic", 'Liberation Tigers of Tamil Eelam (LTTE)', 'Irish Republican Army (IRA)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Shabaab', 'Palestinians', 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Boko Haram', 'Irish Republican Army (IRA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Al-Qaida in Iraq', 'Farabundo Marti National Liberation Front (FMLN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Islamic State of Iraq and the Levant (ISIL)', "Kurdistan Workers' Party (PKK)", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Irish Republican Army (IRA)', 'Palestinians', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', "New People's Army (NPA)", 'Communist Party of India - Maoist (CPI-Maoist)', 'Irish Republican Army (IRA)', 'Tupac Amaru Revolutionary Movement (MRTA)', "Donetsk People's Republic", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Boko Haram', 'Boko Haram', 'Liberation Tigers of Tamil Eelam (LTTE)', "Kurdistan Workers' Party (PKK)", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Corsican National Liberation Front (FLNC)', 'Shining Path (SL)', "New People's Army (NPA)", "Kurdistan Workers' Party (PKK)", 'Fulani extremists', 'Taliban', 'Farabundo Marti National Liberation Front (FMLN)', 'Maoists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Corsican National Liberation Front (FLNC)', 'Sikh Extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Houthi extremists (Ansar Allah)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)', 'Fulani extremists', 'Muslim extremists', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Taliban', 'Al-Qaida in the Arabian Peninsula (AQAP)', "Kurdistan Workers' Party (PKK)", 'Liberation Tigers of Tamil Eelam (LTTE)', 'Boko Haram', "Kurdis ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
