# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
#Config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}

param_grid = {
    'lr': [0.01],
    'n_tree': [50],
    'tree_depth': [8],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.2],
    'out_size_nrf': [512]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.3200
# Epoch 050 | NRF Loss: 2.4672 | Val Acc: 0.6667
# Epoch 100 | NRF Loss: 1.6469 | Val Acc: 0.7758
# Epoch 150 | NRF Loss: 1.1618 | Val Acc: 0.8092
# Epoch 200 | NRF Loss: 0.9202 | Val Acc: 0.8325
# Epoch 250 | NRF Loss: 0.7867 | Val Acc: 0.8467
# Epoch 300 | NRF Loss: 0.7081 | Val Acc: 0.8500
# Epoch 350 | NRF Loss: 0.6540 | Val Acc: 0.8600
# Epoch 400 | NRF Loss: 0.6145 | Val Acc: 0.8642
# Epoch 450 | NRF Loss: 0.5845 | Val Acc: 0.8650
# Epoch 500 | NRF Loss: 0.5601 | Val Acc: 0.8700
# Epoch 550 | NRF Loss: 0.5408 | Val Acc: 0.8733
# Epoch 600 | NRF Loss: 0.5288 | Val Acc: 0.8742
# Epoch 650 | NRF Loss: 0.5171 | Val Acc: 0.8767
# Epoch 700 | NRF Loss: 0.5071 | Val Acc: 0.8758
# Epoch 750 | NRF Loss: 0.4952 | Val Acc: 0.8775
# Epoch 800 | NRF Loss: 0.4855 | Val Acc: 0.8742
# Epoch 850 | NRF Loss: 0.4765 | Val Acc: 0.8717
# Epoch 900 | NRF Loss: 0.4702 | Val Acc: 0.8767
# Epoch 950 | NRF Loss: 0.4645 | Val Acc: 0.8808
# Epoch 1000 | NRF Loss: 0.4595 | Val Acc: 0.8800
# Epoch 1050 | NRF Loss: 0.4541 | Val Acc: 0.8825
# Epoch 1100 | NRF Loss: 0.4500 | Val Acc: 0.8817
# Epoch 1150 | NRF Loss: 0.4436 | Val Acc: 0.8875
# Epoch 1200 | NRF Loss: 0.4402 | Val Acc: 0.8858
# Epoch 1250 | NRF Loss: 0.4353 | Val Acc: 0.8883
# Epoch 1300 | NRF Loss: 0.4318 | Val Acc: 0.8875
# Epoch 1350 | NRF Loss: 0.4302 | Val Acc: 0.8908
# Epoch 1400 | NRF Loss: 0.4275 | Val Acc: 0.8908
# Epoch 1450 | NRF Loss: 0.4239 | Val Acc: 0.8875
# Epoch 1500 | NRF Loss: 0.4220 | Val Acc: 0.8917
# Epoch 1550 | NRF Loss: 0.4168 | Val Acc: 0.8925
# Epoch 1600 | NRF Loss: 0.4134 | Val Acc: 0.8900
# Epoch 1650 | NRF Loss: 0.4104 | Val Acc: 0.8883
# Epoch 1700 | NRF Loss: 0.4095 | Val Acc: 0.8908
# Epoch 1750 | NRF Loss: 0.4082 | Val Acc: 0.8883
# Epoch 1800 | NRF Loss: 0.4045 | Val Acc: 0.8858
# Epoch 1850 | NRF Loss: 0.4006 | Val Acc: 0.8892
# Early stopping at epoch 1874
# Best validation acc: 0.8983 @ epoch 1574
# Evaluating on test set using full graph...
# 0.9133333563804626

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9133333563804626, 'epoch': 1574, 'y_pred': ['Muslim extremists', "New People's Army (NPA)", 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', 'African National Congress (South Africa)', 'Sikh Extremists', 'African National Congress (South Africa)', 'Taliban', 'Corsican National Liberation Front (FLNC)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Corsican National Liberation Front (FLNC)', "New People's Army (NPA)", 'Abu Sayyaf Group (ASG)', "Kurdistan Workers' Party (PKK)", 'Fulani extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Sikh Extremists', 'Al-Qaida in Iraq', 'Nicaraguan Democratic Force (FDN)', 'Al-Shabaab', 'African National Congress (South Africa)', 'Islamic State of Iraq and the Levant (ISIL)', 'Irish Republican Army (IRA)', 'Houthi extremists (Ansar Allah)', "New People's Army (NPA)", "New People's Army (NPA)", 'Houthi extremists (Ansar Allah)', 'Palestinians', 'Revolutionary Armed Forces of Colombia (FARC)', 'Maoists', 'Boko Haram', 'Maoists', 'Houthi extremists (Ansar Allah)', 'Irish Republican Army (IRA)', 'Maoists', 'African National Congress (South Africa)', 'Fulani extremists', "Donetsk People's Republic", 'Taliban', 'Taliban', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Taliban', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Basque Fatherland and Freedom (ETA)', 'Al-Qaida in Iraq', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', 'Palestinians', 'Shining Path (SL)', 'Houthi extremists (Ansar Allah)', "Kurdistan Workers' Party (PKK)", 'Palestinians', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Fulani extremists', 'National Liberation Army of Colombia (ELN)', 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Islamic State of Iraq and the Levant (ISIL)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'Boko Haram', 'African National Congress (South Africa)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Qaida in Iraq', 'Liberation Tigers of Tamil Eelam (LTTE)', "Kurdistan Workers' Party (PKK)", 'Tehrik-i-Taliban Pakistan (TTP)', 'Basque Fatherland and Freedom (ETA)', "Kurdistan Workers' Party (PKK)", 'Al-Qaida in the Arabian Peninsula (AQAP)', "Kurdistan Workers' Party (PKK)", 'Al-Qaida in the Arabian Peninsula (AQAP)', "Kurdistan Workers' Party (PKK)", 'Muslim extremists', 'Abu Sayyaf Group (ASG)', 'Irish Republican Army (IRA)', 'Basque Fatherland and Freedom (ETA)', 'Shining Path (SL)', 'Al-Shabaab', 'Manuel Rodriguez Patriotic Front (FPMR)', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', 'Irish Republican Army (IRA)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Al-Qaida in Iraq', 'Muslim extremists', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Palestinians', 'Farabundo Marti National Liberation Front (FMLN)', 'Palestinians', 'Houthi extremists (Ansar Allah)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Islamic State of Iraq and the Levant (ISIL)', 'Muslim extremists', "New People's Army (NPA)", 'Nicaraguan Democratic Force (FDN)', 'Al-Shabaab', 'Nicaraguan Democratic Force (FDN)', 'Taliban', 'Boko Haram', 'Fulani extremists', 'Al-Qaida in Iraq', 'National Liberation Army of Colombia (ELN)', 'Manuel Rodrigue ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
