# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid

param_grid = {
    'lr': [0.01],
    'n_tree': [40, 50, 60],
    'tree_depth': [7,8,9,10],
    'tree_feature_rate': [0.1, 0.3, 0.5],
    'feat_dropout': [0.0, 0.1,0.2],
    'out_size_nrf': [512]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

random.seed(42)  # for reproducibility
#if len(grid_combos) > 100:
 #   grid_combos = random.sample(grid_combos, 100)

partitions = [100]
print(len(grid_combos))
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")
print(df.shape)
for partition in partitions:
    df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")
    label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
    best_score = -1
    for col in continuous_cols:
        print(f"\nTraining model for {col} prediction...")
        best_run = None
        best_score = -1

        for combo in grid_combos:
            args = {
                **dict(zip(param_names, combo)),
                'partition': f"gtd{partition}",
                'n_class': len(label_index),
                'epochs': 1500,
                'final_evaluation': False
            }

            print(f"Running config: {args}")
            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)

            if acc > best_score:
                best_score = acc
                best_run = {
                    "args": args,
                    "acc": acc,
                    "epoch": epoch,
                    "y_pred": y_pred_decoded,
                    "y_true": y_true_decoded,
                    "precision": p,
                    "recall": r,
                    "f1": f1,
                    "micro": (p_micro, r_micro, f1_micro),
                    "macro": (p_macro, r_macro, f1_macro),
                    "auroc": (auc_w, auc_mi, auc_ma),
                    "epoch_logs": epoch_logs
                }


        # Save best results
        if best_run:
            print(f"\nRetraining best config for {col} on partition {partition} with 3000 epochs...")
            best_args_final = best_run["args"].copy()
            best_args_final["epochs"] = 3000
            best_args_final["final_evaluation"] = True

            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, \
            p_micro, r_micro, f1_micro, \
            p_macro, r_macro, f1_macro, \
            auc_w, auc_mi, auc_ma, epoch_logs = train_joint(df, best_args_final, label_index, verbose=True)

            # overwrite with retrained results
            best_run.update({
                "args": best_args_final,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            })

            # Save results
            os.makedirs(f"Results{partition}", exist_ok=True)
            results_path = f"Results{partition}/Results_{col}_prediction"
            with open(results_path, "w") as f:
                f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
                f.write(f"Config: {best_run['args']}\n")
                f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
                f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
                f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
                f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

            log_path = f"Results{partition}/epoch_logs_{col}_prediction"
            with open(log_path, "w") as f:
                f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

            y_preds.append(best_run['y_pred'])
            y_trues.append(best_run['y_true'])

    print(f"Best score for partition {partition}: {best_score:.4f}")
# Out:
# 108
# (3000, 14)
#
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 40, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'out_size_nrf': 512, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 49
#      40 args = {
#      41     **dict(zip(param_names, combo)),
#      42     'partition': f"gtd{partition}",
#    (...)
#      45     'final_evaluation': False
#      46 }
#      48 print(f"Running config: {args}")
# ---> 49 acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)
#      51 if acc > best_score:
#      52     best_score = acc
#
# File ~/MEX0512/GTD_2025/DNDF_layerTesting/DNDF_noGeographic/train.py:81, in train_joint(df, args, label_index, verbose)
#      73 input_size = len(df.columns) - 1
#      74 feat_layer_cls = {
#      75     "gtd100": GTD100FeatureLayer,
#      76     "gtd200": GTD200FeatureLayer,
#      77     "gtd300": GTD300FeatureLayer,
#      78     "gtd478": GTD478FeatureLayer,
#      79 }[args['partition']]
# ---> 81 feat_layer = feat_layer_cls(out_layer_size = args['out_size_nrf'], input_size = input_size, dropout_rate=args['feat_dropout'])
#      83 # Create neural decision forest
#      84 forest = Forest(
#      85     n_tree=args['n_tree'],
#      86     tree_depth=args['tree_depth'],
#    (...)
#      89     n_class=args['n_class']
#      90 )
#
# File ~/MEX0512/GTD_2025/DNDF_layerTesting/DNDF_noGeographic/ndf.py:51, in GTD100FeatureLayer.__init__(self, out_layer_size, input_size, dropout_rate, shallow)
#      50 def __init__(self, out_layer_size=1024, input_size=47, dropout_rate=0.0, shallow=True):
# ---> 51     super().__init__()
#      52     print(input_size)
#      53     self.shallow = shallow
#
# TypeError: Linear.__init__() missing 2 required positional arguments: 'in_features' and 'out_features'

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 60, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.24666666984558105, 'epoch': 874, 'y_pred': ['Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Qaida in Iraq', 'Fulani extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Abu Sayyaf Group (ASG)', 'Fulani extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', 'Sikh Extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'Houthi extremists (Ansar Allah)', 'Abu Sayyaf Group (ASG)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Sikh Extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Muslim extremists', 'Sikh Extremists', 'Houthi extremists (Ansar Allah)', 'Boko Haram', 'Houthi extremists (Ansar Allah)', 'Abu Sayyaf Group (ASG)', 'Palestinians', 'Sikh Extremists', 'Fulani extremists', 'Fulani extremists', 'African National Congress (South Africa)', 'Boko Haram', 'Palestinians', 'Al-Qaida in the Arabian Peninsula (AQAP)', "Donetsk People's Republic", 'Sikh Extremists', 'Houthi extremists (Ansar Allah)', 'Sikh Extremists', 'Sikh Extremists', 'Sikh Extremists', 'Sikh Extremists', 'Al-Shabaab', 'Fulani extremists', 'Palestinians', 'Al-Shabaab', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Sikh Extremists', 'Sikh Extremists', 'Abu Sayyaf Group (ASG)', 'Al-Shabaab', 'Sikh Extremists', 'Palestinians', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', 'Sikh Extremists', 'Palestinians', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in Iraq', 'Palestinians', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Fulani extremists', 'Sikh Extremists', 'Fulani extremists', 'Sikh Extremists', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Abu Sayyaf Group (ASG)', 'Basque Fatherland and Freedom (ETA)', 'Farabundo Marti National Liberation Front (FMLN)', 'African National Congress (South Africa)', 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Sikh Extremists', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Sikh Extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Sikh Extremists', 'Al-Qaida in Iraq', 'Sikh Extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Farabundo Marti National Liberation Front (FMLN)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Sikh Extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Sikh Extremists', "Donetsk People's Republic", 'Nicaraguan Democratic Force (FDN)', 'Al-Shabaab', 'Basque Fatherland and Freedom (ETA)', 'Houthi extremists (Ansar Allah)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Fulani extremists', 'Sikh Extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Sikh Extremists', 'Corsican National Liberation Front (FLNC)', 'Boko Haram', 'Farabundo Marti National Liberation Front (FMLN)', 'Ma ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
