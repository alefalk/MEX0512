# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
#{'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'partition': 'gtd300', 'n_class': 30, 'epochs': 300, 'final_evaluation': False}
param_grid = {
    'lr': [0.01],
    'n_tree': [120],
    'tree_depth': [7],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.1],
    'out_size_nrf': [768]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.1861
# Epoch 050 | NRF Loss: 2.8110 | Val Acc: 0.3661
# Epoch 100 | NRF Loss: 2.3484 | Val Acc: 0.4183
# Epoch 150 | NRF Loss: 2.0419 | Val Acc: 0.4583
# Epoch 200 | NRF Loss: 1.8377 | Val Acc: 0.4783
# Epoch 250 | NRF Loss: 1.6942 | Val Acc: 0.4939
# Epoch 300 | NRF Loss: 1.5965 | Val Acc: 0.4983
# Epoch 350 | NRF Loss: 1.5297 | Val Acc: 0.5006
# Epoch 400 | NRF Loss: 1.4780 | Val Acc: 0.5144
# Epoch 450 | NRF Loss: 1.4381 | Val Acc: 0.5150
# Epoch 500 | NRF Loss: 1.4078 | Val Acc: 0.5200
# Epoch 550 | NRF Loss: 1.3827 | Val Acc: 0.5200
# Epoch 600 | NRF Loss: 1.3633 | Val Acc: 0.5239
# Epoch 650 | NRF Loss: 1.3457 | Val Acc: 0.5278
# Epoch 700 | NRF Loss: 1.3312 | Val Acc: 0.5300
# Epoch 750 | NRF Loss: 1.3192 | Val Acc: 0.5317
# Epoch 800 | NRF Loss: 1.3083 | Val Acc: 0.5261
# Epoch 850 | NRF Loss: 1.2963 | Val Acc: 0.5278
# Epoch 900 | NRF Loss: 1.2884 | Val Acc: 0.5339
# Epoch 950 | NRF Loss: 1.2805 | Val Acc: 0.5350
# Epoch 1000 | NRF Loss: 1.2741 | Val Acc: 0.5372
# Epoch 1050 | NRF Loss: 1.2679 | Val Acc: 0.5378
# Epoch 1100 | NRF Loss: 1.2618 | Val Acc: 0.5367
# Epoch 1150 | NRF Loss: 1.2546 | Val Acc: 0.5417
# Epoch 1200 | NRF Loss: 1.2486 | Val Acc: 0.5372
# Epoch 1250 | NRF Loss: 1.2451 | Val Acc: 0.5422
# Epoch 1300 | NRF Loss: 1.2400 | Val Acc: 0.5422
# Epoch 1350 | NRF Loss: 1.2343 | Val Acc: 0.5417
# Epoch 1400 | NRF Loss: 1.2314 | Val Acc: 0.5428
# Epoch 1450 | NRF Loss: 1.2280 | Val Acc: 0.5406
# Epoch 1500 | NRF Loss: 1.2252 | Val Acc: 0.5422
# Epoch 1550 | NRF Loss: 1.2217 | Val Acc: 0.5406
# Epoch 1600 | NRF Loss: 1.2187 | Val Acc: 0.5489
# Epoch 1650 | NRF Loss: 1.2165 | Val Acc: 0.5428
# Epoch 1700 | NRF Loss: 1.2116 | Val Acc: 0.5483
# Epoch 1750 | NRF Loss: 1.2090 | Val Acc: 0.5467
# Epoch 1800 | NRF Loss: 1.2070 | Val Acc: 0.5483
# Epoch 1850 | NRF Loss: 1.2049 | Val Acc: 0.5456
# Early stopping at epoch 1892
# Best validation acc: 0.5522 @ epoch 1592
# Evaluating on test set using full graph...
# 0.5

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 70, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'out_size_nrf': 512, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.4927777945995331, 'epoch': 1411, 'y_pred': ['Corsican National Liberation Front (FLNC)', 'Nicaraguan Democratic Force (FDN)', 'Taliban', 'Maoists', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', "Kurdistan Workers' Party (PKK)", 'Irish Republican Army (IRA)', 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Irish Republican Army (IRA)', 'Fulani extremists', 'Houthi extremists (Ansar Allah)', 'Boko Haram', 'Basque Fatherland and Freedom (ETA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Muslim extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Sikh Extremists', 'Boko Haram', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in Iraq', 'Maoists', "Kurdistan Workers' Party (PKK)", 'Shining Path (SL)', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Farabundo Marti National Liberation Front (FMLN)', 'Palestinians', 'Nicaraguan Democratic Force (FDN)', "Kurdistan Workers' Party (PKK)", 'Tupac Amaru Revolutionary Movement (MRTA)', "Donetsk People's Republic", 'National Liberation Army of Colombia (ELN)', 'Houthi extremists (Ansar Allah)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Palestinians', 'Maoists', 'Taliban', 'Revolutionary Armed Forces of Colombia (FARC)', 'Basque Fatherland and Freedom (ETA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Taliban', 'Fulani extremists', 'Boko Haram', 'National Liberation Army of Colombia (ELN)', 'Sikh Extremists', 'Fulani extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Maoists', 'Palestinians', 'Houthi extremists (Ansar Allah)', "Donetsk People's Republic", 'Sikh Extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Taliban', 'National Liberation Army of Colombia (ELN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Irish Republican Army (IRA)', 'Taliban', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Al-Shabaab', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'Al-Shabaab', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Maoists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Nicaraguan Democratic Force (FDN)', 'African National Congress (South Africa)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Irish Republican Army (IRA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Irish Republican Army (IRA)', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Nicaraguan Democratic Force (FDN)', 'Irish Republican Army (IRA)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Kurdistan Workers' Party (PKK)", 'Communist Party of India - Maoist (CPI-Maoist)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Irish Republican Army (IRA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Kurdistan Workers' Party (PKK)", 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Maoists', 'Maoists', 'Basque Fatherland and Freedom (ETA)', 'Maoists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Corsican National Liberation Front (FLNC)', 'Maoist ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
