# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 478

# %%
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 9, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}

param_grid = {
    'lr': [0.01],
    'n_tree': [120, 150],
    'tree_depth': [7,8],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.2],
    'out_size_nrf': [512]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
#sampled_combos = random.sample(grid_combos, 50)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 500,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
            print(f"\nRetraining best config for {col} on partition {partition} with 3000 epochs...")
            best_args_final = best_run["args"].copy()
            best_args_final["epochs"] = 3000
            best_args_final["final_evaluation"] = True

            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, \
            p_micro, r_micro, f1_micro, \
            p_macro, r_macro, f1_macro, \
            auc_w, auc_mi, auc_ma, epoch_logs = train_joint(df, best_args_final, label_index, verbose=True)

            # overwrite with retrained results
            best_run.update({
                "args": best_args_final,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            })

            # Save results
            os.makedirs(f"Results{partition}", exist_ok=True)
            results_path = f"Results{partition}/Results_{col}_prediction"
            with open(results_path, "w") as f:
                f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
                f.write(f"Config: {best_run['args']}\n")
                f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
                f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
                f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
                f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

            log_path = f"Results{partition}/epoch_logs_{col}_prediction"
            with open(log_path, "w") as f:
                f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

            y_preds.append(best_run['y_pred'])
            y_trues.append(best_run['y_true'])

    print(f"Best score for partition {partition}: {best_score:.4f}")
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd478', 'n_class': 30, 'epochs': 500, 'final_evaluation': False}
# Epoch 000 | NRF Loss: 3.4011 | Val Acc: 0.1517
# Epoch 050 | NRF Loss: 2.8677 | Val Acc: 0.3326
# Epoch 100 | NRF Loss: 2.4357 | Val Acc: 0.3934
# Epoch 150 | NRF Loss: 2.1448 | Val Acc: 0.4264
# Epoch 200 | NRF Loss: 1.9525 | Val Acc: 0.4531
# Epoch 250 | NRF Loss: 1.8190 | Val Acc: 0.4774
# Epoch 300 | NRF Loss: 1.7252 | Val Acc: 0.4878
# Epoch 350 | NRF Loss: 1.6543 | Val Acc: 0.5010
# Epoch 400 | NRF Loss: 1.6050 | Val Acc: 0.5080
# Epoch 450 | NRF Loss: 1.5638 | Val Acc: 0.5115
# Best validation acc: 0.5181 @ epoch 496
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd478', 'n_class': 30, 'epochs': 500, 'final_evaluation': False}
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.1795
# Epoch 050 | NRF Loss: 2.8424 | Val Acc: 0.3389
# Epoch 100 | NRF Loss: 2.3868 | Val Acc: 0.4104
# Epoch 150 | NRF Loss: 2.0838 | Val Acc: 0.4378
# Epoch 200 | NRF Loss: 1.8843 | Val Acc: 0.4608
# Epoch 250 | NRF Loss: 1.7504 | Val Acc: 0.4854
# Epoch 300 | NRF Loss: 1.6552 | Val Acc: 0.5014
# Epoch 350 | NRF Loss: 1.5872 | Val Acc: 0.5128
# Epoch 400 | NRF Loss: 1.5334 | Val Acc: 0.5226
# Epoch 450 | NRF Loss: 1.4949 | Val Acc: 0.5312
# Best validation acc: 0.5365 @ epoch 494
# Running config: {'lr': 0.01, 'n_tree': 150, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd478', 'n_class': 30, 'epochs': 500, 'final_evaluation': False}
# Epoch 000 | NRF Loss: 3.4013 | Val Acc: 0.1507
# Epoch 050 | NRF Loss: 2.8707 | Val Acc: 0.3285
# Epoch 100 | NRF Loss: 2.4382 | Val Acc: 0.3924
# Epoch 150 | NRF Loss: 2.1443 | Val Acc: 0.4313
# Epoch 200 | NRF Loss: 1.9456 | Val Acc: 0.4556
# Epoch 250 | NRF Loss: 1.8121 | Val Acc: 0.4806
# Epoch 300 | NRF Loss: 1.7168 | Val Acc: 0.5000
# Epoch 350 | NRF Loss: 1.6489 | Val Acc: 0.5111
# Epoch 400 | NRF Loss: 1.5994 | Val Acc: 0.5184
# Epoch 450 | NRF Loss: 1.5598 | Val Acc: 0.5236
# Best validation acc: 0.5299 @ epoch 485
# Running config: {'lr': 0.01, 'n_tree': 150, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'partition': 'gtd478', 'n_class': 30, 'epochs': 500, 'final_evaluation': False}
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.1604
# Epoch 050 | NRF Loss: 2.8460 | Val Acc: 0.3344
# Epoch 100 | NRF Loss: 2.3900 | Val Acc: 0.4087
# Epoch 150 | NRF Loss: 2.0820 | Val Acc: 0.4406
# Epoch 200 | NRF Loss: 1.8799 | Val Acc: 0.4642
# Epoch 250 | NRF Loss: 1.7422 | Val Acc: 0.4885
# Epoch 300 | NRF Loss: 1.6471 | Val Acc: 0.5069
# Epoch 350 | NRF Loss: 1.5793 | Val Acc: 0.5174
# Epoch 400 | NRF Loss: 1.5273 | Val Acc: 0.5181
# Epoch 450 | NRF Loss: 1.4859 | Val Acc: 0.5299
# Best validation acc: 0.5354 @ epoch 478
#
# Retraining best config for weaptype1 on partition 478 with 3000 epochs...
# Epoch 000 | NRF Loss: 3.4012 | Val Acc: 0.1726
# Epoch 050 | NRF Loss: 2.8405 | Val Acc: 0.3399
# Epoch 100 | NRF Loss: 2.3817 | Val Acc: 0.4042
# Epoch 150 | NRF Loss: 2.0768 | Val Acc: 0.4361
# Epoch 200 | NRF Loss: 1.8778 | Val Acc: 0.4628
# Epoch 250 | NRF Loss: 1.7421 | Val Acc: 0.4823
# Epoch 300 | NRF Loss: 1.6477 | Val Acc: 0.4972
# Epoch 350 | NRF Loss: 1.5805 | Val Acc: 0.5083
# Epoch 400 | NRF Loss: 1.5273 | Val Acc: 0.5149
# Epoch 450 | NRF Loss: 1.4888 | Val Acc: 0.5243
# Epoch 500 | NRF Loss: 1.4573 | Val Acc: 0.5295
# Epoch 550 | NRF Loss: 1.4306 | Val Acc: 0.5392
# Epoch 600 | NRF Loss: 1.4088 | Val Acc: 0.5358
# Epoch 650 | NRF Loss: 1.3891 | Val Acc: 0.5437
# Epoch 700 | NRF Loss: 1.3735 | Val Acc: 0.5493
# Epoch 750 | NRF Loss: 1.3593 | Val Acc: 0.5528
# Epoch 800 | NRF Loss: 1.3453 | Val Acc: 0.5566
 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.5427083373069763, 'epoch': 2905, 'y_pred': ["New People's Army (NPA)", 'Irish Republican Army (IRA)', "Donetsk People's Republic", 'Fulani extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Revolutionary Armed Forces of Colombia (FARC)', "New People's Army (NPA)", 'Revolutionary Armed Forces of Colombia (FARC)', 'Al-Qaida in Iraq', 'Palestinians', 'Basque Fatherland and Freedom (ETA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', 'Taliban', 'Irish Republican Army (IRA)', "Donetsk People's Republic", 'Abu Sayyaf Group (ASG)', 'Maoists', 'Irish Republican Army (IRA)', 'Sikh Extremists', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'Boko Haram', "Kurdistan Workers' Party (PKK)", 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', "Kurdistan Workers' Party (PKK)", "New People's Army (NPA)", 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Maoists', "Donetsk People's Republic", 'Communist Party of India - Maoist (CPI-Maoist)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Farabundo Marti National Liberation Front (FMLN)', 'Fulani extremists', 'Nicaraguan Democratic Force (FDN)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Nicaraguan Democratic Force (FDN)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'Fulani extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'Shining Path (SL)', 'Basque Fatherland and Freedom (ETA)', 'Sikh Extremists', 'Sikh Extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Communist Party of India - Maoist (CPI-Maoist)', "Donetsk People's Republic", 'Sikh Extremists', 'African National Congress (South Africa)', 'Sikh Extremists', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Al-Shabaab', 'Al-Qaida in Iraq', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Al-Shabaab', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Corsican National Liberation Front (FLNC)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Taliban', 'Fulani extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', 'Sikh Extremists', 'African National Congress (South Africa)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Sikh Extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Fulani extremists', 'Nicaraguan Democratic Force (FDN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in Iraq', "Kurdistan Workers' Party (PKK)", 'Maoists', "New People's Army (NPA)", 'Maoists', 'African National Congress (South Africa)', 'Irish Republican Army (IRA)', 'Muslim extremists', 'Basque Fatherland and Freedom (ETA)', 'Nicaraguan Democratic Force (FDN)', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", "Kurdistan Workers' Party (PKK)", "Kurdistan Workers' Party (PKK)", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Corsican National Liberation Front (FLNC)', 'Maoists', "Kurdistan Workers' Party (PKK)", 'Corsican National Liberation Front (FLNC)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Basque Fatherland and Freedom (ETA)', 'Irish Republican Army (IRA)', 'Al-Shabaab', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Fulani extremists', 'Basque Fatherland and F ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
