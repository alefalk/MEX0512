# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch

# %%
partition = 478

# %%
df = pd.read_csv(f"../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}

param_grid = {
    'lr': [0.01],
    'n_tree': [120],
    'tree_depth': [7],
    'tree_feature_rate': [0.5],
    'feat_dropout': [0.2],
    'out_size_nrf': [512],
    'batch_size': [128]
    }



# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

#sampled_combos = random.sample(grid_combos, 10)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)
        print(acc)
        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
            print(f"\nRetraining best config for {col} on partition {partition} with 3000 epochs...")
            best_args_final = best_run["args"].copy()
            best_args_final["epochs"] = 3000
            best_args_final["final_evaluation"] = True

            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, \
            p_micro, r_micro, f1_micro, \
            p_macro, r_macro, f1_macro, \
            auc_w, auc_mi, auc_ma, epoch_logs = train_joint(df, best_args_final, label_index, verbose=True)

            # overwrite with retrained results
            best_run.update({
                "args": best_args_final,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            })

            # Save results
            os.makedirs(f"Results{partition}", exist_ok=True)
            results_path = f"Results{partition}/Results_{col}_prediction"
            with open(results_path, "w") as f:
                f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
                f.write(f"Config: {best_run['args']}\n")
                f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
                f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
                f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
                f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

            log_path = f"Results{partition}/epoch_logs_{col}_prediction"
            with open(log_path, "w") as f:
                f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

            y_preds.append(best_run['y_pred'])
            y_trues.append(best_run['y_true'])

    print(f"Best score for partition {partition}: {best_score:.4f}")
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 128, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1, 'final_evaluation': False}
# cuda
# Epoch 000 | NRF Loss: 3.1367 | Val Acc: 0.3146
# Best validation acc: 0.3146 @ epoch 0
# 0.31458333134651184
#
# Retraining best config for weaptype1 on partition 478 with 3000 epochs...
# cuda
# Epoch 000 | NRF Loss: 3.1391 | Val Acc: 0.3097
# Epoch 050 | NRF Loss: 1.6913 | Val Acc: 0.4878
# Epoch 100 | NRF Loss: 1.6025 | Val Acc: 0.5104
# Epoch 150 | NRF Loss: 1.5493 | Val Acc: 0.5194
# Epoch 200 | NRF Loss: 1.5004 | Val Acc: 0.5288
# Epoch 250 | NRF Loss: 1.4731 | Val Acc: 0.5406
# Epoch 300 | NRF Loss: 1.4358 | Val Acc: 0.5437
# Epoch 350 | NRF Loss: 1.4105 | Val Acc: 0.5458
# Epoch 400 | NRF Loss: 1.3982 | Val Acc: 0.5583
# Epoch 450 | NRF Loss: 1.3731 | Val Acc: 0.5503
# Epoch 500 | NRF Loss: 1.3536 | Val Acc: 0.5597
# Epoch 550 | NRF Loss: 1.3334 | Val Acc: 0.5590
# Epoch 600 | NRF Loss: 1.3321 | Val Acc: 0.5694
# Epoch 650 | NRF Loss: 1.3226 | Val Acc: 0.5681
# Epoch 700 | NRF Loss: 1.3043 | Val Acc: 0.5545
# Epoch 750 | NRF Loss: 1.2945 | Val Acc: 0.5778
# Epoch 800 | NRF Loss: 1.2812 | Val Acc: 0.5750
# Epoch 850 | NRF Loss: 1.2691 | Val Acc: 0.5875
# Epoch 900 | NRF Loss: 1.2856 | Val Acc: 0.5722
# Epoch 950 | NRF Loss: 1.2686 | Val Acc: 0.5736
# Epoch 1000 | NRF Loss: 1.2543 | Val Acc: 0.5851
# Epoch 1050 | NRF Loss: 1.2492 | Val Acc: 0.5677
# Epoch 1100 | NRF Loss: 1.2522 | Val Acc: 0.5813
# Epoch 1150 | NRF Loss: 1.2386 | Val Acc: 0.5722
# Epoch 1200 | NRF Loss: 1.2498 | Val Acc: 0.5622
# Epoch 1250 | NRF Loss: 1.2274 | Val Acc: 0.5670
# Epoch 1300 | NRF Loss: 1.2252 | Val Acc: 0.5819
# Epoch 1350 | NRF Loss: 1.2209 | Val Acc: 0.5802
# Epoch 1400 | NRF Loss: 1.2294 | Val Acc: 0.5736
# Epoch 1450 | NRF Loss: 1.2158 | Val Acc: 0.5865
# Epoch 1500 | NRF Loss: 1.2230 | Val Acc: 0.5778
# Epoch 1550 | NRF Loss: 1.2248 | Val Acc: 0.5830
# Epoch 1600 | NRF Loss: 1.1996 | Val Acc: 0.5951
# Epoch 1650 | NRF Loss: 1.2101 | Val Acc: 0.5819
# Epoch 1700 | NRF Loss: 1.1957 | Val Acc: 0.5844
# Early stopping at epoch 1716
# Best validation acc: 0.6007 @ epoch 1416
# Evaluating on test set using full graph...
# Best score for partition 478: 0.3146

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 128, 'partition': 'gtd478', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.5489583611488342, 'epoch': 1416, 'y_pred': ["Donetsk People's Republic", 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Houthi extremists (Ansar Allah)', 'Nicaraguan Democratic Force (FDN)', 'Fulani extremists', 'Maoists', 'Palestinians', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'National Liberation Army of Colombia (ELN)', 'Nicaraguan Democratic Force (FDN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Basque Fatherland and Freedom (ETA)', 'Boko Haram', 'National Liberation Army of Colombia (ELN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Abu Sayyaf Group (ASG)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in Iraq', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', "Kurdistan Workers' Party (PKK)", 'African National Congress (South Africa)', "Kurdistan Workers' Party (PKK)", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Abu Sayyaf Group (ASG)', 'Irish Republican Army (IRA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Maoists', 'Al-Shabaab', 'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in Iraq', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Fulani extremists', 'Maoists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Fulani extremists', 'Abu Sayyaf Group (ASG)', 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Basque Fatherland and Freedom (ETA)', 'Muslim extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Basque Fatherland and Freedom (ETA)', 'Fulani extremists', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'African National Congress (South Africa)', 'Islamic State of Iraq and the Levant (ISIL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Sikh Extremists', 'Muslim extremists', 'Al-Qaida in Iraq', 'Irish Republican Army (IRA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Basque Fatherland and Freedom (ETA)', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', "Kurdistan Workers' Party (PKK)", 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Fulani extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Sikh Extremists', 'Abu Sayyaf Group (ASG)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Maoists', 'Nicaraguan Democratic Force (FDN)', 'Shining Path (SL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Shabaab', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Maoists', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Islamic State of Iraq and the Levant (ISIL)', "Donetsk People's Republic", "Kurdistan Workers' Party (PKK)", 'Houthi extremists (Ansar Allah)', 'Boko Haram', 'Boko Haram', 'Houthi extremists (Ansar Allah)', 'Abu Sayyaf Group (ASG)', "New People's Army (NPA)", 'Houthi extremists (Ansar Allah)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tehrik-i-Taliban Pakist ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
