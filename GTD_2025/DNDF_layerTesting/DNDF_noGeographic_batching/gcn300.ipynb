# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}

param_grid = {
    'lr': [0.01],
    'n_tree': [20, 50, 80, 120],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.3,0.5],
    'feat_dropout': [0.2],
    'out_size_nrf': [512],
    'batch_size': [256]
    }


# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

#sampled_combos = random.sample(grid_combos, 10)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)
        print(acc)
        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
            print(f"\nRetraining best config for {col} on partition {partition} with 3000 epochs...")
            best_args_final = best_run["args"].copy()
            best_args_final["epochs"] = 3000
            best_args_final["final_evaluation"] = True

            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, \
            p_micro, r_micro, f1_micro, \
            p_macro, r_macro, f1_macro, \
            auc_w, auc_mi, auc_ma, epoch_logs = train_joint(df, best_args_final, label_index, verbose=True)

            # overwrite with retrained results
            best_run.update({
                "args": best_args_final,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            })

            # Save results
            os.makedirs(f"Results{partition}", exist_ok=True)
            results_path = f"Results{partition}/Results_{col}_prediction"
            with open(results_path, "w") as f:
                f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
                f.write(f"Config: {best_run['args']}\n")
                f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
                f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
                f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
                f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

            log_path = f"Results{partition}/epoch_logs_{col}_prediction"
            with open(log_path, "w") as f:
                f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

            y_preds.append(best_run['y_pred'])
            y_trues.append(best_run['y_true'])

    print(f"Best score for partition {partition}: {best_score:.4f}")
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# cuda
# Epoch 000 | NRF Loss: 3.2763 | Val Acc: 0.2506
# Epoch 050 | NRF Loss: 1.6843 | Val Acc: 0.4611
# Epoch 100 | NRF Loss: 1.5668 | Val Acc: 0.4906
# Epoch 150 | NRF Loss: 1.5125 | Val Acc: 0.4928
# Epoch 200 | NRF Loss: 1.4812 | Val Acc: 0.5083
# Epoch 250 | NRF Loss: 1.4538 | Val Acc: 0.5033
# Epoch 300 | NRF Loss: 1.4299 | Val Acc: 0.5156
# Epoch 350 | NRF Loss: 1.4034 | Val Acc: 0.5256
# Epoch 400 | NRF Loss: 1.3905 | Val Acc: 0.5272
# Epoch 450 | NRF Loss: 1.3723 | Val Acc: 0.5217
# Epoch 500 | NRF Loss: 1.3589 | Val Acc: 0.5333
# Epoch 550 | NRF Loss: 1.3416 | Val Acc: 0.5300
# Epoch 600 | NRF Loss: 1.3331 | Val Acc: 0.5328
# Epoch 650 | NRF Loss: 1.3212 | Val Acc: 0.5422
# Epoch 700 | NRF Loss: 1.3065 | Val Acc: 0.5494
# Epoch 750 | NRF Loss: 1.3051 | Val Acc: 0.5417
# Epoch 800 | NRF Loss: 1.2881 | Val Acc: 0.5394
# Epoch 850 | NRF Loss: 1.2798 | Val Acc: 0.5578
# Epoch 900 | NRF Loss: 1.2740 | Val Acc: 0.5494
# Epoch 950 | NRF Loss: 1.2589 | Val Acc: 0.5539
# Epoch 1000 | NRF Loss: 1.2558 | Val Acc: 0.5600
# Epoch 1050 | NRF Loss: 1.2455 | Val Acc: 0.5561
# Epoch 1100 | NRF Loss: 1.2453 | Val Acc: 0.5511
# Epoch 1150 | NRF Loss: 1.2360 | Val Acc: 0.5600
# Epoch 1200 | NRF Loss: 1.2301 | Val Acc: 0.5600
# Epoch 1250 | NRF Loss: 1.2220 | Val Acc: 0.5606
# Epoch 1300 | NRF Loss: 1.2167 | Val Acc: 0.5650
# Epoch 1350 | NRF Loss: 1.2116 | Val Acc: 0.5644
# Epoch 1400 | NRF Loss: 1.2120 | Val Acc: 0.5667
# Epoch 1450 | NRF Loss: 1.2040 | Val Acc: 0.5633
# Epoch 1499 | NRF Loss: 1.2021 | Val Acc: 0.5728
# Best validation acc: 0.5839 @ epoch 1487
# 0.5838888883590698
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# cuda
# Epoch 000 | NRF Loss: 3.2709 | Val Acc: 0.2867
# Epoch 050 | NRF Loss: 1.6320 | Val Acc: 0.4706
# Epoch 100 | NRF Loss: 1.5127 | Val Acc: 0.4883
# Epoch 150 | NRF Loss: 1.4648 | Val Acc: 0.5078
# Epoch 200 | NRF Loss: 1.4267 | Val Acc: 0.5122
# Epoch 250 | NRF Loss: 1.4023 | Val Acc: 0.5117
# Epoch 300 | NRF Loss: 1.3740 | Val Acc: 0.5167
# Epoch 350 | NRF Loss: 1.3532 | Val Acc: 0.5139
# Epoch 400 | NRF Loss: 1.3380 | Val Acc: 0.5294
# Early stopping at epoch 425
# Best validation acc: 0.5361 @ epoch 325
# 0.5361111164093018
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# cuda
# Epoch 000 | NRF Loss: 3.2614 | Val Acc: 0.2883
# Epoch 050 | NRF Loss: 1.5864 | Val Acc: 0.4928
# Epoch 100 | NRF Loss: 1.4722 | Val Acc: 0.5028
# Epoch 150 | NRF Loss: 1.4184 | Val Acc: 0.5194
# Epoch 200 | NRF Loss: 1.3792 | Val Acc: 0.5222
# Epoch 250 | NRF Loss: 1.3488 | Val Acc: 0.5406
# Epoch 300 | NRF Loss: 1.3332 | Val Acc: 0.5322
# Epoch 350 | NRF Loss: 1.3142 | Val Acc: 0.5361
# Epoch 400 | NRF Loss: 1.2925 | Val Acc: 0.5372
# Epoch 450 | NRF Loss: 1.2809 | Val Acc: 0.5511
# Epoch 500 | NRF Loss: 1.2597 | Val Acc: 0.5661
# Epoch 550 | NRF Loss: 1.2376 | Val Acc: 0.5611
# Epoch 600 | NRF Loss: 1.2231 | Val Acc: 0.5600
# Early stopping at epoch 615
# Best validation acc: 0.5717 @ epoch 515
# 0.5716666579246521
#
# Retraining best config for weaptype1 on partition 300 with 3000 epochs...
# cuda
# Epoch 000 | NRF Loss: 3.2741 | Val Acc: 0.2694
# Epoch 050 | NRF Loss: 1.6849 | Val Acc: 0.4678
# Epoch 100 | NRF Loss: 1.5713 | Val Acc: 0.4972
# Epoch 150 | NRF Loss: 1.5162 | Val Acc: 0.4972
# Epoch 200 | NRF Loss: 1.4818 | Val Acc: 0.5111
# Epoch 250 | NRF Loss: 1.4564 | Val Acc: 0.5161
# Epoch 300 | NRF Loss: 1.4358 | Val Acc: 0.5089
# Epoch 350 | NRF Loss: 1.4136 | Val Acc: 0.5150
# Epoch 400 | NRF Loss: 1.4017 | Val Acc: 0.5250
# Epoch 450 | NRF Loss: 1.3801 | Val Acc: 0.5350
# Epoch 500 | NRF Loss: 1.3638 | Val Acc: 0.5272
# Epoch 550 | NRF Loss: 1.3470 | Val Acc: 0.5433
# Epoch 600 | NRF Loss: 1.3418 | Val Acc: 0.5411
# Epoch 650 | NRF Loss: 1.3253 | Val Acc: 0.5361
# Epoch 700 | NRF Loss: 1.3173 | Val Acc: 0.5389
# Epoch 750 | NRF Loss: 1.3076 | Val Acc: 0.5428
# Epoch 800 | NRF Loss: 1.2970 | Val Acc: 0.5472
# Epoch 850 | NRF Loss: 1.2939 | Val Acc: 0.5456
# Epoch 900 | NRF Loss: 1.2795 | Val Acc: 0.5528
# Epoch 950 | NRF Loss: 1.2703 | Val Acc: 0.5500
# Epoch 1000 | NRF Loss: 1.2657 | Val Acc: 0.5567
# Epoch 1050 | NRF Loss: 1.2510 | Val Acc: 0.5539
# Epoch 1100 | NRF Loss: 1.2516 | Val Acc: 0.5533
# Epoch 1150 | NRF Loss: 1.2391 | Val Acc: 0.5683
# Epoch 1200 | NRF Loss: 1.2319 | Val Acc: 0.5589
# Epoch 1250 | NRF Loss: 1.2258 | Val Acc: 0.5578
# Epoch 1300 | NRF Loss: 1.2230 | Val Acc: 0.5644
# Epoch 1350 | NRF Loss: 1.2186 | Val Acc: 0.5683
# Epoch 1400 | NRF Loss: 1.2130 | Val Acc: 0.5650
# Epoch 1450 | NRF Loss: 1.2164 | Val Acc: 0.5600
# Epoch 1500 | NRF Loss: 1.2073 | Val Acc: 0.5717
# Epoch 1550 | NRF Loss: 1.2022 | Val Acc: 0.5639
# Epoch 1600 | NRF Loss: 1.1972 | Val Acc: 0.5733
# Epoch 1650 | NRF Loss: 1.1883 | Val Acc: 0.5689
# Epoch 1700 | NRF Loss: 1.1826 | Val Acc: 0.5639
# Epoch 1750 | NRF Loss: 1.1803 | Val Acc: 0.5817
# Epoch 1800 | NRF Loss: 1.1776 | Val Acc: 0.5733
# Epoch 1850 | NRF Loss: 1.1717 | Val Acc: 0.5756
# Epoch 1900 | NRF Loss: 1.1724 | Val Acc: 0.5750
# Epoch 1950 | NRF Loss: 1.1665 | Val Acc: 0.5800
# Epoch 2000 | NRF Loss: 1.1621 | Val Acc: 0.5772
# Early stopping at epoch 2037
# Best validation acc: 0.5933 @ epoch 1737
# Evaluating on test set using full graph...
# Best score for partition 300: 0.5839

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 256, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.5411111116409302, 'epoch': 2879, 'y_pred': ['Nicaraguan Democratic Force (FDN)', 'Shining Path (SL)', 'Abu Sayyaf Group (ASG)', 'Boko Haram', 'Abu Sayyaf Group (ASG)', 'Al-Qaida in Iraq', 'African National Congress (South Africa)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Basque Fatherland and Freedom (ETA)', "New People's Army (NPA)", 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Houthi extremists (Ansar Allah)', "Donetsk People's Republic", 'Maoists', 'Farabundo Marti National Liberation Front (FMLN)', 'Palestinians', 'African National Congress (South Africa)', "Kurdistan Workers' Party (PKK)", 'Maoists', "Kurdistan Workers' Party (PKK)", 'Al-Qaida in Iraq', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Shabaab', 'Farabundo Marti National Liberation Front (FMLN)', 'Maoists', 'Fulani extremists', "Donetsk People's Republic", 'Palestinians', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'African National Congress (South Africa)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)', 'Muslim extremists', 'Irish Republican Army (IRA)', 'Basque Fatherland and Freedom (ETA)', 'Houthi extremists (Ansar Allah)', 'Al-Qaida in Iraq', 'Fulani extremists', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in Iraq', 'Abu Sayyaf Group (ASG)', 'Corsican National Liberation Front (FLNC)', 'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Houthi extremists (Ansar Allah)', 'Corsican National Liberation Front (FLNC)', 'Fulani extremists', 'Nicaraguan Democratic Force (FDN)', 'Irish Republican Army (IRA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Shabaab', 'Irish Republican Army (IRA)', "Kurdistan Workers' Party (PKK)", 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in Iraq', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Sikh Extremists', 'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Nicaraguan Democratic Force (FDN)', 'Irish Republican Army (IRA)', 'Taliban', 'Nicaraguan Democratic Force (FDN)', 'Maoists', 'National Liberation Army of Colombia (ELN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Boko Haram', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'National Liberation Army of Colombia (ELN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Farabundo Marti National Liberation Front (FMLN)', 'Muslim extremists', 'Boko Haram', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'Islamic State of Iraq and the Levant (ISIL)', "Kurdistan Workers' Party (PKK)", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Palestinians', 'Tehrik-i-Taliban Pakistan (TTP)', 'Houthi extremists (Ansar Allah)', "Kurdistan Workers' Party (PKK)", 'Shining Path (SL)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Basque Fatherland and Freedom (ETA)', 'Maoists', 'Fulani extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Abu Sayyaf Group (ASG)', 'Basque Fatherland and Freedom (ETA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Boko Haram', 'Revolutionary Armed Forces of Colombia (FARC)', "Kurdistan Workers' Party (PKK)", "New People's Army (NPA)", 'Islamic  ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
