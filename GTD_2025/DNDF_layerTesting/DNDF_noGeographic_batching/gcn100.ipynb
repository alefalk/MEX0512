# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from train import *
import torch

# %%
partition = 100

# %%
df = pd.read_csv(f"../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 128, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}

param_grid = {
    'lr': [0.01],
    'n_tree': [120],
    'tree_depth': [7],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.2],
    'out_size_nrf': [512],
    'batch_size': [128]
    }


# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

#sampled_combos = random.sample(grid_combos, 50)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")
    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs =train_joint(df, args, label_index, verbose=True)
        print(acc)
        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
            print(f"\nRetraining best config for {col} on partition {partition} with 3000 epochs...")
            best_args_final = best_run["args"].copy()
            best_args_final["epochs"] = 3000
            best_args_final["final_evaluation"] = True

            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, \
            p_micro, r_micro, f1_micro, \
            p_macro, r_macro, f1_macro, \
            auc_w, auc_mi, auc_ma, epoch_logs = train_joint(df, best_args_final, label_index, verbose=True)

            # overwrite with retrained results
            best_run.update({
                "args": best_args_final,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            })

            # Save results
            os.makedirs(f"Results{partition}", exist_ok=True)
            results_path = f"Results{partition}/Results_{col}_prediction"
            with open(results_path, "w") as f:
                f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
                f.write(f"Config: {best_run['args']}\n")
                f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
                f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
                f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
                f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

            log_path = f"Results{partition}/epoch_logs_{col}_prediction"
            with open(log_path, "w") as f:
                f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

            y_preds.append(best_run['y_pred'])
            y_trues.append(best_run['y_true'])

    print(f"Best score for partition {partition}: {best_score:.4f}")
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 7, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 128, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1, 'final_evaluation': False}
# cuda
# 13
# Epoch 000 | NRF Loss: 3.3777 | Val Acc: 0.1817
# Best validation acc: 0.1817 @ epoch 0
# 0.18166667222976685
#
# Retraining best config for weaptype1 on partition 100 with 3000 epochs...
# cuda
# 13
# Epoch 000 | NRF Loss: 3.3784 | Val Acc: 0.1300
# Epoch 050 | NRF Loss: 1.6579 | Val Acc: 0.4100
# Epoch 100 | NRF Loss: 1.4579 | Val Acc: 0.4133
# Epoch 150 | NRF Loss: 1.3674 | Val Acc: 0.4200
# Epoch 200 | NRF Loss: 1.3138 | Val Acc: 0.4383
# Epoch 250 | NRF Loss: 1.2762 | Val Acc: 0.4517
# Epoch 300 | NRF Loss: 1.2475 | Val Acc: 0.4567
# Epoch 350 | NRF Loss: 1.2182 | Val Acc: 0.4633
# Epoch 400 | NRF Loss: 1.1951 | Val Acc: 0.4650
# Epoch 450 | NRF Loss: 1.1831 | Val Acc: 0.4633
# Epoch 500 | NRF Loss: 1.1603 | Val Acc: 0.4733
# Epoch 550 | NRF Loss: 1.1460 | Val Acc: 0.4800
# Epoch 600 | NRF Loss: 1.1277 | Val Acc: 0.4733
# Epoch 650 | NRF Loss: 1.1090 | Val Acc: 0.4800
# Epoch 700 | NRF Loss: 1.1041 | Val Acc: 0.4917
# Epoch 750 | NRF Loss: 1.0890 | Val Acc: 0.5000
# Epoch 800 | NRF Loss: 1.0839 | Val Acc: 0.4950
# Epoch 850 | NRF Loss: 1.0732 | Val Acc: 0.4900
# Epoch 900 | NRF Loss: 1.0655 | Val Acc: 0.4900
# Epoch 950 | NRF Loss: 1.0499 | Val Acc: 0.4967
# Epoch 1000 | NRF Loss: 1.0454 | Val Acc: 0.5100
# Epoch 1050 | NRF Loss: 1.0370 | Val Acc: 0.5183
# Epoch 1100 | NRF Loss: 1.0294 | Val Acc: 0.5050
# Epoch 1150 | NRF Loss: 1.0213 | Val Acc: 0.5233
# Epoch 1200 | NRF Loss: 1.0137 | Val Acc: 0.5167
# Epoch 1250 | NRF Loss: 1.0082 | Val Acc: 0.5150
# Epoch 1300 | NRF Loss: 1.0009 | Val Acc: 0.5133
# Epoch 1350 | NRF Loss: 0.9970 | Val Acc: 0.5067
# Epoch 1400 | NRF Loss: 0.9911 | Val Acc: 0.5167
# Epoch 1450 | NRF Loss: 0.9903 | Val Acc: 0.5017
# Epoch 1500 | NRF Loss: 0.9972 | Val Acc: 0.5033
# Epoch 1550 | NRF Loss: 0.9790 | Val Acc: 0.5267
# Epoch 1600 | NRF Loss: 0.9798 | Val Acc: 0.5167
# Epoch 1650 | NRF Loss: 0.9694 | Val Acc: 0.5217
# Epoch 1700 | NRF Loss: 0.9632 | Val Acc: 0.5350
# Epoch 1750 | NRF Loss: 0.9620 | Val Acc: 0.5167
# Epoch 1800 | NRF Loss: 0.9587 | Val Acc: 0.5283
# Epoch 1850 | NRF Loss: 0.9625 | Val Acc: 0.5183
# Epoch 1900 | NRF Loss: 0.9483 | Val Acc: 0.5283
# Epoch 1950 | NRF Loss: 0.9465 | Val Acc: 0.5300
# Early stopping at epoch 1996
# Best validation acc: 0.5433 @ epoch 1696
# Evaluating on test set using full graph...
# Best score for partition 100: 0.1817

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 120, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'out_size_nrf': 512, 'batch_size': 128, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.46000000834465027, 'epoch': 1656, 'y_pred': ["Donetsk People's Republic", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Abu Sayyaf Group (ASG)', 'Islamic State of Iraq and the Levant (ISIL)', 'Tupac Amaru Revolutionary Movement (MRTA)', "Donetsk People's Republic", 'Irish Republican Army (IRA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Corsican National Liberation Front (FLNC)', 'Farabundo Marti National Liberation Front (FMLN)', 'Houthi extremists (Ansar Allah)', "Donetsk People's Republic", 'Revolutionary Armed Forces of Colombia (FARC)', 'Al-Qaida in Iraq', "Kurdistan Workers' Party (PKK)", 'Abu Sayyaf Group (ASG)', 'African National Congress (South Africa)', 'Irish Republican Army (IRA)', 'Sikh Extremists', "Donetsk People's Republic", 'Al-Shabaab', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Boko Haram', 'National Liberation Army of Colombia (ELN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', 'Fulani extremists', "Donetsk People's Republic", 'Basque Fatherland and Freedom (ETA)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Islamic State of Iraq and the Levant (ISIL)', 'Maoists', 'Houthi extremists (Ansar Allah)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', 'Corsican National Liberation Front (FLNC)', 'Taliban', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Houthi extremists (Ansar Allah)', 'Muslim extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'Fulani extremists', 'Sikh Extremists', 'Palestinians', 'Fulani extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'National Liberation Army of Colombia (ELN)', 'Houthi extremists (Ansar Allah)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Abu Sayyaf Group (ASG)', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', "Kurdistan Workers' Party (PKK)", 'Communist Party of India - Maoist (CPI-Maoist)', 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'National Liberation Army of Colombia (ELN)', 'Farabundo Marti National Liberation Front (FMLN)', 'Muslim extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'National Liberation Army of Colombia (ELN)', 'National Liberation Army of Colombia (ELN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Houthi extremists (Ansar Allah)', "Donetsk People's Republic", 'Boko Haram', 'Fulani extremists', 'Al-Shabaab', 'Nicaraguan Democratic Force (FDN)', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Abu Sayyaf Group (ASG)', "Kurdistan Workers' Party (PKK)", 'Sikh Extremists', 'Palestinians', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Muslim extremists', 'Muslim extremists', 'Irish Republican Army (IRA)', 'Abu Sayyaf Group (ASG)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'African National Congress (South Africa)', ' ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
