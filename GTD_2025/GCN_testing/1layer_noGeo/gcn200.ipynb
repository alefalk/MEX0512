# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
#from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import os
import itertools
import numpy as np
import pandas as pd
from itertools import product
from scipy.sparse import coo_matrix
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from itertools import product
import numpy as np, torch
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from torch_geometric.utils import to_undirected, add_self_loops

from build_graph_data import *

# %%
partition = 200

# %% [markdown]
# # Read Data

# %%
path = f'../../data/top30groups/noGeographic/combined/combined{partition}.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')
#traindata, valdata, testdata = handle_leakage(df)

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'gname'],
#       dtype='object')

# %% [markdown]
# # Create train graph

# %%
# Creating df of the feature subset for node creation
#def create_node_dataframe(data, node_features, label_column='gname'):
 #   relevant_data = data[node_features + [label_column]].copy()
#    relevant_data['combination'] = list(zip(*(relevant_data[feat] for feat in node_features)))
 #   df_unique = relevant_data.drop_duplicates(subset=['combination'], keep='first').reset_index(drop=True)
  #  return df_unique[['combination', label_column]]

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

# %%
def induced_subgraph(edge_index, keep_mask):
    keep = keep_mask.nonzero(as_tuple=False).view(-1)
    # map old -> new ids
    new_id = -torch.ones(keep_mask.size(0), dtype=torch.long, device=edge_index.device)
    new_id[keep] = torch.arange(keep.numel(), device=edge_index.device)
    src, dst = edge_index
    m = keep_mask[src] & keep_mask[dst]
    ei = edge_index[:, m]
    ei = torch.stack([new_id[ei[0]], new_id[ei[1]]], dim=0)
    return ei, new_id

# %%
import itertools, time, numpy as np, pandas as pd, torch, torch.nn.functional as F
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from torch_geometric.nn import GCNConv

# ----------------------------
# Model with dropout
# ----------------------------
class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)
        self.dropout = torch.nn.Dropout(p=dropout)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        return x

#[[radius k=20 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.552 ACC=0.545 | TEST f1_ma=0.471 ACC=0.478
#[knn                k=24 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.532 ACC=0.537 | TEST f1_ma=0.474 ACC=0.482
#[hybrid_equal_knn   k=23 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.517 ACC=0.523 | TEST f1_ma=0.481 ACC=0.487
#[adaptive           k=23 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.542 ACC=0.545 | TEST f1_ma=0.482 ACC=0.488
#[knn                k=23 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.534 ACC=0.540 | TEST f1_ma=0.485 ACC=0.488
#[knn                k=23 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.543 | TEST f1_ma=0.479 ACC=0.488



# ----------------------------
# Metrics helper
# ----------------------------
def compute_all_metrics(y_true_np, logits_np, n_class):
    """Return dict of acc + P/R/F1 (weighted/micro/macro) + OVR ROC-AUC (w/mi/ma)."""
    y_pred_np = logits_np.argmax(axis=1)
    proba_np  = torch.softmax(torch.from_numpy(logits_np), dim=1).numpy()

    labels = list(range(n_class))
    out = {}
    # Accuracy
    out['acc'] = accuracy_score(y_true_np, y_pred_np)
    # Weighted
    out['prec_w'] = precision_score(y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['rec_w']  = recall_score(  y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['f1_w']   = f1_score(      y_true_np, y_pred_np, average='weighted')
    # Micro
    out['prec_mi'] = precision_score(y_true_np, y_pred_np, average='micro', zero_division=0)
    out['rec_mi']  = recall_score(  y_true_np, y_pred_np, average='micro',   zero_division=0)
    out['f1_mi']   = f1_score(      y_true_np, y_pred_np, average='micro')
    # Macro
    out['prec_ma'] = precision_score(y_true_np, y_pred_np, average='macro', zero_division=0)
    out['rec_ma']  = recall_score(  y_true_np, y_pred_np, average='macro',  zero_division=0)
    out['f1_ma']   = f1_score(      y_true_np, y_pred_np, average='macro')

    # OVR ROC-AUCs (robust if some classes missing in split)
    # If only one class present in y_true, roc_auc_score will raise; guard it.
    def safe_roc(avg):
        try:
            return roc_auc_score(y_true_np, proba_np, multi_class='ovr', average=avg, labels=labels)
        except Exception:
            return float('nan')

    out['roc_w']  = safe_roc('weighted')
    out['roc_mi'] = safe_roc('micro')
    out['roc_ma'] = safe_roc('macro')
    return out

# ----------------------------
# Hyperparameters to sweep
# ----------------------------
hidden_dims   = [16, 32, 64, 128, 256, 512]
lrs           = [0.01, 0.001]
optimizers    = ["adam", "adamw"]
dropouts      = [0.0, 0.3, 0.5]
num_epochs    = 2000
weight_decay  = 5e-4
patience      = 100
seed          = 42
device        = "cuda"

torch.manual_seed(seed); np.random.seed(seed)

# ----------------------------
# Data split (temporal)
# ----------------------------
df_all = df.copy()
train_idx, val_idx, test_idx = temporal_row_split(df_all, label_column='gname', train_ratio=0.6, val_ratio=0.2)

# Graph options
edge_modes = ["hybrid_equal_knn"]
#edge_modes = ["equal"]
k_values   = list(range(7, 13))

node_feature_cols = None
edge_feature_cols = ['attacktype1', 'target1', "nkill"]  # used for 'equal' part; fine to keep for others

def make_optimizer(name, params, lr, wd):
    name = name.lower()
    if name == "adam":  return torch.optim.Adam(params, lr=lr, weight_decay=wd)
    if name == "adamw": return torch.optim.AdamW(params, lr=lr, weight_decay=wd)
    raise ValueError(f"Unknown optimizer: {name}")

def train_one_model(x, edge_index, y, train_mask, val_mask, num_classes,
                    hidden_dim, lr, opt_name, dropout, max_epochs=num_epochs, patience=patience):
    model = PyTorchGCN(in_channels=x.size(1),
                       hidden_channels=hidden_dim,
                       num_classes=num_classes,
                       dropout=dropout).to(device)
    opt = make_optimizer(opt_name, model.parameters(), lr, weight_decay)
    best_state, best_val, patience_left = None, float('inf'), patience

    for epoch in range(1, max_epochs + 1):
        model.train(); opt.zero_grad()
        out = model(x, edge_index)
        loss_train = F.cross_entropy(out[train_mask], y[train_mask])
        loss_train.backward(); opt.step()

        model.eval()
        with torch.no_grad():
            out = model(x, edge_index)
            loss_val = F.cross_entropy(out[val_mask], y[val_mask])

        if loss_val.item() < best_val - 1e-6:
            best_val = loss_val.item()
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            patience_left = patience
        else:
            patience_left -= 1
            if patience_left <= 0:
                break

    if best_state is not None:
        model.load_state_dict({k: v.to(device) for k, v in best_state.items()})

    # Validation metrics (selection)
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_val_true = y[val_mask].detach().cpu().numpy()
    y_val_logits = logits[val_mask].detach().cpu().numpy()
    val_metrics = compute_all_metrics(y_val_true, y_val_logits, num_classes)
    val_metrics['val_loss'] = best_val
    return model, val_metrics

def split_metrics(model, x, edge_index, y, mask, num_classes, split_name):
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_true = y[mask].detach().cpu().numpy()
    logits_np = logits[mask].detach().cpu().numpy()
    mets = compute_all_metrics(y_true, logits_np, num_classes)
    return {f"{split_name}_{k}": v for k, v in mets.items()}

# ----------------------------
# Grid search
# ----------------------------
results = []
best_row = None
best_score = -1.0  # we’ll select by val_macro_F1

t_all = time.time()
for k in k_values:
    for edge_mode in edge_modes:
        # A) fit scalers ON TRAIN ONLY
        node_scaler, edge_scaler = fit_scalers(
            df_all,
            node_feature_cols=['extended','vicinity','multiple','success','suicide','attacktype1',
                               'targtype1','target1','individual','weaptype1','nkill','property','ishostkid'],
            edge_feature_cols=edge_feature_cols,
            train_idx=train_idx
        )

        # B) build TRAIN+VAL graph directly (neighbors computed within this set)
        trainval_idx = np.concatenate([train_idx, val_idx])
        x_tv, ei_tv, y_tv, _, _, _, label_index, chosen_radius = build_graph_on_index_set(
            df_all=df_all,
            idx_subset=trainval_idx,
            node_feature_cols=['extended','vicinity','multiple','success','suicide','attacktype1',
                               'targtype1','target1','individual','weaptype1','nkill','property','ishostkid'],
            edge_feature_cols=edge_feature_cols,
            node_scaler=node_scaler, edge_scaler=edge_scaler,
            label_column='gname',
            train_idx=train_idx, val_idx=val_idx, test_idx=None,
            edge_mode=edge_mode, equal_cols=edge_feature_cols, k=k, radius=None  # radius will be auto-picked from TRAIN in this set
        )

        # masks relative to the TRAIN+VAL subgraph:
        # (build them by mapping global indices -> local positions)
        pos_tv = {rid:i for i, rid in enumerate(trainval_idx)}
        train_mask_sub = torch.zeros(x_tv.size(0), dtype=torch.bool, device='cuda')
        val_mask_sub   = torch.zeros_like(train_mask_sub)
        for rid in train_idx: train_mask_sub[pos_tv[rid]] = True
        for rid in val_idx:   val_mask_sub[pos_tv[rid]]   = True

        num_classes = len(label_index)

        for hidden_dim, lr, opt_name, dropout in itertools.product(hidden_dims, lrs, optimizers, dropouts):
            t0 = time.time()
            model, val_m = train_one_model(
                x_tv, ei_tv, y_tv, train_mask_sub, val_mask_sub, num_classes,
                hidden_dim=hidden_dim, lr=lr, opt_name=opt_name, dropout=dropout,
                max_epochs=num_epochs, patience=patience
            )

            # C) build FULL graph (train+val+test) using SAME scalers and SAME edge params
            #    - For radius modes, reuse chosen_radius so ε doesn’t change between train and test graphs.
            x_full, ei_full, y_full, train_mask_full, val_mask_full, test_mask_full, _, _ = build_graph_on_index_set(
                df_all=df_all,
                idx_subset=df_all.index.to_numpy(),  # full
                node_feature_cols=['extended','vicinity','multiple','success','suicide','attacktype1',
                                   'targtype1','target1','individual','weaptype1','nkill','property','ishostkid'],
                edge_feature_cols=edge_feature_cols,
                node_scaler=node_scaler, edge_scaler=edge_scaler,
                label_column='gname',
                train_idx=train_idx, val_idx=val_idx, test_idx=test_idx,
                edge_mode=edge_mode, equal_cols=edge_feature_cols, k=k, radius=chosen_radius
            )

            # TESTA DENNA

            # (Optional stricter inference: one-way edges train→test only)
            ei_infer = make_infer_edge_index_strict(ei_full, train_mask_full | val_mask_full, test_mask_full)
            ei_infer, _ = add_self_loops(ei_infer, num_nodes=x_full.size(0))
            test_m = split_metrics(model, x_full, ei_infer, y_full, test_mask_full, num_classes, "test")

            # Standard transductive inference on full graph:
            #test_m = split_metrics(model, x_full, ei_full, y_full, test_mask_full, num_classes, "test")
            # Test split metrics
            #test_m = split_metrics(model, x, edge_index, y, test_mask, num_classes, split_name="test")
            elapsed = time.time() - t0

            row = dict(
                k=k, edge_mode=edge_mode, hidden_dim=hidden_dim, lr=lr,
                optimizer=opt_name, dropout=dropout, time_sec=elapsed,
                train_nodes=int(train_mask_full.sum().item()),
                val_nodes=int(val_mask_full.sum().item()),
                test_nodes=int(test_mask_full.sum().item()),
            )
            # attach val and test metrics
            for kmet, vmet in val_m.items():
                row[f"val_{kmet}"] = vmet
            row.update(test_m)

            results.append(row)

            # Selection criterion: validation macro-F1
            sel = val_m['f1_ma']
            if sel > best_score:
                best_score = sel
                best_row = row.copy()

            print(f"[{edge_mode:18s} k={k:2d} | h={hidden_dim:3d} lr={lr:<6} opt={opt_name:<5} drop={dropout}] "
                  f"VAL f1_ma={val_m['f1_ma']:.3f} ACC={val_m['acc']:.3f} | "
                  f"TEST f1_ma={test_m['test_f1_ma']:.3f} ACC={test_m['test_acc']:.3f}")

total_min = (time.time() - t_all)/60
print(f"\nGrid search finished in {total_min:.1f} min")

#results_df = pd.DataFrame(results)

# ----------------------------
# Save all runs + best summary
# ----------------------------
#results_csv = f"grid_search_results{partition}.csv"
#results_df.to_csv(results_csv, index=False)

best_txt = f"best_run_{partition}.txt"
with open(best_txt, "w") as f:
    f.write("=== Best configuration (by validation macro-F1) ===\n")
    f.write(f"edge_mode   : {best_row['edge_mode']}\n")
    f.write(f"k           : {best_row['k']}\n")
    f.write(f"hidden_dim  : {best_row['hidden_dim']}\n")
    f.write(f"optimizer   : {best_row['optimizer']}\n")
    f.write(f"lr          : {best_row['lr']}\n")
    f.write(f"dropout     : {best_row['dropout']}\n")
    f.write("\n--- Validation metrics ---\n")
    f.write(f"val_loss    : {best_row.get('val_val_loss', float('nan')):.6f}\n")
    f.write(f"val_acc     : {best_row.get('val_acc', float('nan')):.6f}\n")
    f.write(f"val_prec_w  : {best_row.get('val_prec_w', float('nan')):.6f}\n")
    f.write(f"val_rec_w   : {best_row.get('val_rec_w', float('nan')):.6f}\n")
    f.write(f"val_f1_w    : {best_row.get('val_f1_w', float('nan')):.6f}\n")
    f.write(f"val_prec_mi : {best_row.get('val_prec_mi', float('nan')):.6f}\n")
    f.write(f"val_rec_mi  : {best_row.get('val_rec_mi', float('nan')):.6f}\n")
    f.write(f"val_f1_mi   : {best_row.get('val_f1_mi', float('nan')):.6f}\n")
    f.write(f"val_prec_ma : {best_row.get('val_prec_ma', float('nan')):.6f}\n")
    f.write(f"val_rec_ma  : {best_row.get('val_rec_ma', float('nan')):.6f}\n")
    f.write(f"val_f1_ma   : {best_row.get('val_f1_ma', float('nan')):.6f}\n")
    f.write(f"val_roc_w   : {best_row.get('val_roc_w', float('nan')):.6f}\n")
    f.write(f"val_roc_mi  : {best_row.get('val_roc_mi', float('nan')):.6f}\n")
    f.write(f"val_roc_ma  : {best_row.get('val_roc_ma', float('nan')):.6f}\n")
    f.write("\n--- Test metrics ---\n")
    f.write(f"test_acc    : {best_row.get('test_acc', float('nan')):.6f}\n")
    f.write(f"test_prec_w : {best_row.get('test_prec_w', float('nan')):.6f}\n")
    f.write(f"test_rec_w  : {best_row.get('test_rec_w', float('nan')):.6f}\n")
    f.write(f"test_f1_w   : {best_row.get('test_f1_w', float('nan')):.6f}\n")
    f.write(f"test_prec_mi: {best_row.get('test_prec_mi', float('nan')):.6f}\n")
    f.write(f"test_rec_mi : {best_row.get('test_rec_mi', float('nan')):.6f}\n")
    f.write(f"test_f1_mi  : {best_row.get('test_f1_mi', float('nan')):.6f}\n")
    f.write(f"test_prec_ma: {best_row.get('test_prec_ma', float('nan')):.6f}\n")
    f.write(f"test_rec_ma : {best_row.get('test_rec_ma', float('nan')):.6f}\n")
    f.write(f"test_f1_ma  : {best_row.get('test_f1_ma', float('nan')):.6f}\n")
    f.write(f"test_roc_w  : {best_row.get('test_roc_w', float('nan')):.6f}\n")
    f.write(f"test_roc_mi : {best_row.get('test_roc_mi', float('nan')):.6f}\n")
    f.write(f"test_roc_ma : {best_row.get('test_roc_ma', float('nan')):.6f}\n")
    f.write("\n--- Data sizes ---\n")
    f.write(f"train_nodes : {best_row['train_nodes']}\n")
    f.write(f"val_nodes   : {best_row['val_nodes']}\n")
    f.write(f"test_nodes  : {best_row['test_nodes']}\n")
    #f.write(f"\nCSV of all runs: {results_csv}\n")

#print(f"Saved all runs to {results_csv} and best summary to {best_txt}")
# Out:
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.487 ACC=0.497 | TEST f1_ma=0.394 ACC=0.407
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.461 ACC=0.472 | TEST f1_ma=0.399 ACC=0.408
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.433 ACC=0.449 | TEST f1_ma=0.364 ACC=0.379
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.490 ACC=0.499 | TEST f1_ma=0.374 ACC=0.383
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.467 ACC=0.475 | TEST f1_ma=0.383 ACC=0.392
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.473 ACC=0.481 | TEST f1_ma=0.359 ACC=0.374
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.415 ACC=0.432 | TEST f1_ma=0.323 ACC=0.335
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.412 ACC=0.429 | TEST f1_ma=0.332 ACC=0.341
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.400 ACC=0.417 | TEST f1_ma=0.309 ACC=0.328
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.408 ACC=0.421 | TEST f1_ma=0.328 ACC=0.340
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.386 ACC=0.400 | TEST f1_ma=0.321 ACC=0.333
# [hybrid_equal_knn   k= 7 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.399 ACC=0.415 | TEST f1_ma=0.338 ACC=0.352
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.507 ACC=0.512 | TEST f1_ma=0.379 ACC=0.391
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.513 ACC=0.519 | TEST f1_ma=0.398 ACC=0.407
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.508 ACC=0.515 | TEST f1_ma=0.401 ACC=0.413
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.485 ACC=0.494 | TEST f1_ma=0.344 ACC=0.354
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.500 ACC=0.504 | TEST f1_ma=0.384 ACC=0.388
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.512 ACC=0.516 | TEST f1_ma=0.407 ACC=0.413
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.476 ACC=0.481 | TEST f1_ma=0.352 ACC=0.360
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.440 ACC=0.455 | TEST f1_ma=0.347 ACC=0.357
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.435 ACC=0.448 | TEST f1_ma=0.345 ACC=0.359
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.474 ACC=0.481 | TEST f1_ma=0.348 ACC=0.354
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.452 ACC=0.460 | TEST f1_ma=0.363 ACC=0.368
# [hybrid_equal_knn   k= 7 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.449 ACC=0.458 | TEST f1_ma=0.337 ACC=0.345
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.535 ACC=0.539 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.539 ACC=0.543 | TEST f1_ma=0.406 ACC=0.417
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.520 ACC=0.526 | TEST f1_ma=0.405 ACC=0.414
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.506 ACC=0.512 | TEST f1_ma=0.371 ACC=0.374
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.522 ACC=0.525 | TEST f1_ma=0.390 ACC=0.397
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.520 ACC=0.522 | TEST f1_ma=0.398 ACC=0.405
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.506 ACC=0.510 | TEST f1_ma=0.383 ACC=0.389
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.483 ACC=0.491 | TEST f1_ma=0.374 ACC=0.384
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.472 ACC=0.482 | TEST f1_ma=0.373 ACC=0.384
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.491 ACC=0.497 | TEST f1_ma=0.369 ACC=0.374
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.496 ACC=0.499 | TEST f1_ma=0.373 ACC=0.378
# [hybrid_equal_knn   k= 7 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.490 ACC=0.497 | TEST f1_ma=0.378 ACC=0.386
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.539 ACC=0.542 | TEST f1_ma=0.401 ACC=0.410
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.537 | TEST f1_ma=0.407 ACC=0.414
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.537 ACC=0.540 | TEST f1_ma=0.416 ACC=0.424
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.516 ACC=0.522 | TEST f1_ma=0.387 ACC=0.395
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.510 ACC=0.512 | TEST f1_ma=0.376 ACC=0.382
# [hybrid_equal_knn   k= 7 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.523 ACC=0.528 | TEST f1_ma=0.389 ACC=0.398
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.526 ACC=0.529 | TEST f1_ma=0.399 ACC=0.407
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.509 ACC=0.515 | TEST f1_ma=0.387 ACC=0.396
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.510 ACC=0.516 | TEST f1_ma=0.392 ACC=0.401
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.508 | TEST f1_ma=0.375 ACC=0.383
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.512 ACC=0.514 | TEST f1_ma=0.392 ACC=0.398
# [hybrid_equal_knn   k= 7 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.515 ACC=0.520 | TEST f1_ma=0.395 ACC=0.403
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.542 ACC=0.544 | TEST f1_ma=0.408 ACC=0.416
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.543 ACC=0.546 | TEST f1_ma=0.413 ACC=0.421
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.535 ACC=0.538 | TEST f1_ma=0.414 ACC=0.422
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.515 ACC=0.518 | TEST f1_ma=0.382 ACC=0.388
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.509 ACC=0.512 | TEST f1_ma=0.388 ACC=0.393
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.521 ACC=0.526 | TEST f1_ma=0.389 ACC=0.397
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.536 ACC=0.540 | TEST f1_ma=0.400 ACC=0.407
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.527 ACC=0.531 | TEST f1_ma=0.401 ACC=0.408
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.523 ACC=0.526 | TEST f1_ma=0.405 ACC=0.415
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.516 ACC=0.521 | TEST f1_ma=0.366 ACC=0.373
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.512 ACC=0.515 | TEST f1_ma=0.376 ACC=0.383
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.516 ACC=0.520 | TEST f1_ma=0.390 ACC=0.395
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.545 ACC=0.547 | TEST f1_ma=0.410 ACC=0.418
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.541 ACC=0.544 | TEST f1_ma=0.426 ACC=0.432
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.543 ACC=0.545 | TEST f1_ma=0.411 ACC=0.419
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.510 ACC=0.517 | TEST f1_ma=0.380 ACC=0.388
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.526 ACC=0.528 | TEST f1_ma=0.378 ACC=0.381
# [hybrid_equal_knn   k= 7 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.514 ACC=0.519 | TEST f1_ma=0.370 ACC=0.376
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.540 ACC=0.542 | TEST f1_ma=0.405 ACC=0.412
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.540 ACC=0.543 | TEST f1_ma=0.396 ACC=0.403
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.532 ACC=0.537 | TEST f1_ma=0.408 ACC=0.415
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.506 ACC=0.511 | TEST f1_ma=0.373 ACC=0.380
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.517 ACC=0.520 | TEST f1_ma=0.385 ACC=0.391
# [hybrid_equal_knn   k= 7 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.527 ACC=0.529 | TEST f1_ma=0.387 ACC=0.392
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.491 ACC=0.498 | TEST f1_ma=0.412 ACC=0.420
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.479 ACC=0.489 | TEST f1_ma=0.393 ACC=0.402
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.464 ACC=0.474 | TEST f1_ma=0.375 ACC=0.390
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.492 ACC=0.498 | TEST f1_ma=0.355 ACC=0.363
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.485 ACC=0.492 | TEST f1_ma=0.370 ACC=0.378
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.452 ACC=0.458 | TEST f1_ma=0.351 ACC=0.361
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.399 ACC=0.416 | TEST f1_ma=0.334 ACC=0.345
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.376 ACC=0.397 | TEST f1_ma=0.334 ACC=0.351
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.407 ACC=0.422 | TEST f1_ma=0.321 ACC=0.333
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.417 ACC=0.433 | TEST f1_ma=0.318 ACC=0.331
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.404 ACC=0.417 | TEST f1_ma=0.319 ACC=0.333
# [hybrid_equal_knn   k= 8 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.388 ACC=0.407 | TEST f1_ma=0.328 ACC=0.344
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.518 ACC=0.523 | TEST f1_ma=0.411 ACC=0.418
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.505 ACC=0.507 | TEST f1_ma=0.387 ACC=0.394
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.517 ACC=0.518 | TEST f1_ma=0.405 ACC=0.413
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.513 ACC=0.516 | TEST f1_ma=0.363 ACC=0.368
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.516 ACC=0.517 | TEST f1_ma=0.394 ACC=0.399
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.516 ACC=0.515 | TEST f1_ma=0.387 ACC=0.390
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.480 ACC=0.487 | TEST f1_ma=0.362 ACC=0.370
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.450 ACC=0.460 | TEST f1_ma=0.370 ACC=0.379
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.435 ACC=0.449 | TEST f1_ma=0.349 ACC=0.362
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.471 ACC=0.476 | TEST f1_ma=0.342 ACC=0.352
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.437 ACC=0.448 | TEST f1_ma=0.366 ACC=0.376
# [hybrid_equal_knn   k= 8 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.433 ACC=0.448 | TEST f1_ma=0.342 ACC=0.354
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.527 ACC=0.532 | TEST f1_ma=0.416 ACC=0.423
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.529 ACC=0.532 | TEST f1_ma=0.409 ACC=0.414
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.517 ACC=0.518 | TEST f1_ma=0.418 ACC=0.423
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.506 ACC=0.510 | TEST f1_ma=0.382 ACC=0.389
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.537 ACC=0.539 | TEST f1_ma=0.397 ACC=0.404
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.528 ACC=0.528 | TEST f1_ma=0.393 ACC=0.401
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.506 ACC=0.512 | TEST f1_ma=0.372 ACC=0.378
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.483 ACC=0.490 | TEST f1_ma=0.366 ACC=0.374
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.476 ACC=0.483 | TEST f1_ma=0.377 ACC=0.384
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.502 ACC=0.508 | TEST f1_ma=0.366 ACC=0.372
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.487 ACC=0.492 | TEST f1_ma=0.376 ACC=0.382
# [hybrid_equal_knn   k= 8 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.490 ACC=0.497 | TEST f1_ma=0.367 ACC=0.376
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.534 ACC=0.537 | TEST f1_ma=0.402 ACC=0.410
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.534 | TEST f1_ma=0.412 ACC=0.416
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.543 ACC=0.544 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.508 | TEST f1_ma=0.378 ACC=0.386
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.526 ACC=0.528 | TEST f1_ma=0.376 ACC=0.384
# [hybrid_equal_knn   k= 8 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.529 ACC=0.530 | TEST f1_ma=0.394 ACC=0.397
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.513 ACC=0.517 | TEST f1_ma=0.386 ACC=0.392
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.514 ACC=0.517 | TEST f1_ma=0.398 ACC=0.407
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.503 ACC=0.510 | TEST f1_ma=0.400 ACC=0.406
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.511 | TEST f1_ma=0.379 ACC=0.386
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.511 ACC=0.516 | TEST f1_ma=0.379 ACC=0.386
# [hybrid_equal_knn   k= 8 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.522 ACC=0.525 | TEST f1_ma=0.400 ACC=0.405
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.534 ACC=0.537 | TEST f1_ma=0.414 ACC=0.421
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.537 | TEST f1_ma=0.407 ACC=0.412
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.526 ACC=0.529 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.510 ACC=0.515 | TEST f1_ma=0.370 ACC=0.377
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.519 ACC=0.522 | TEST f1_ma=0.382 ACC=0.386
# [hybrid_equal_knn   k= 8 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.523 ACC=0.527 | TEST f1_ma=0.403 ACC=0.409
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.527 ACC=0.530 | TEST f1_ma=0.398 ACC=0.406
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.518 ACC=0.522 | TEST f1_ma=0.407 ACC=0.416
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.524 ACC=0.527 | TEST f1_ma=0.412 ACC=0.419
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.522 ACC=0.526 | TEST f1_ma=0.376 ACC=0.383
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.517 ACC=0.521 | TEST f1_ma=0.397 ACC=0.403
# [hybrid_equal_knn   k= 8 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.529 ACC=0.533 | TEST f1_ma=0.397 ACC=0.406
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.537 ACC=0.539 | TEST f1_ma=0.411 ACC=0.420
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.536 ACC=0.541 | TEST f1_ma=0.419 ACC=0.427
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.530 ACC=0.532 | TEST f1_ma=0.423 ACC=0.428
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.509 ACC=0.515 | TEST f1_ma=0.381 ACC=0.388
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.526 ACC=0.530 | TEST f1_ma=0.381 ACC=0.388
# [hybrid_equal_knn   k= 8 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.528 ACC=0.528 | TEST f1_ma=0.399 ACC=0.406
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.528 ACC=0.532 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.528 ACC=0.532 | TEST f1_ma=0.412 ACC=0.419
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.527 ACC=0.527 | TEST f1_ma=0.415 ACC=0.421
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.518 ACC=0.522 | TEST f1_ma=0.386 ACC=0.393
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.520 ACC=0.523 | TEST f1_ma=0.384 ACC=0.391
# [hybrid_equal_knn   k= 8 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.519 ACC=0.523 | TEST f1_ma=0.393 ACC=0.400
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.481 ACC=0.491 | TEST f1_ma=0.392 ACC=0.403
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.482 ACC=0.491 | TEST f1_ma=0.389 ACC=0.399
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.449 ACC=0.461 | TEST f1_ma=0.354 ACC=0.372
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.473 ACC=0.482 | TEST f1_ma=0.366 ACC=0.375
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.492 ACC=0.493 | TEST f1_ma=0.395 ACC=0.402
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.504 ACC=0.502 | TEST f1_ma=0.389 ACC=0.390
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.421 ACC=0.437 | TEST f1_ma=0.346 ACC=0.367
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.401 ACC=0.419 | TEST f1_ma=0.324 ACC=0.339
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.400 ACC=0.418 | TEST f1_ma=0.325 ACC=0.343
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.427 ACC=0.436 | TEST f1_ma=0.339 ACC=0.348
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.412 ACC=0.425 | TEST f1_ma=0.338 ACC=0.352
# [hybrid_equal_knn   k= 9 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.401 ACC=0.420 | TEST f1_ma=0.319 ACC=0.336
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.511 ACC=0.516 | TEST f1_ma=0.386 ACC=0.392
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.528 ACC=0.530 | TEST f1_ma=0.403 ACC=0.410
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.504 ACC=0.511 | TEST f1_ma=0.394 ACC=0.402
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.508 | TEST f1_ma=0.389 ACC=0.396
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.508 ACC=0.514 | TEST f1_ma=0.385 ACC=0.393
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.517 ACC=0.518 | TEST f1_ma=0.403 ACC=0.407
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.469 ACC=0.473 | TEST f1_ma=0.362 ACC=0.373
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.454 ACC=0.466 | TEST f1_ma=0.362 ACC=0.372
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.440 ACC=0.453 | TEST f1_ma=0.348 ACC=0.362
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.515 ACC=0.517 | TEST f1_ma=0.368 ACC=0.375
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.474 ACC=0.481 | TEST f1_ma=0.367 ACC=0.377
# [hybrid_equal_knn   k= 9 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.458 ACC=0.468 | TEST f1_ma=0.369 ACC=0.377
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.527 ACC=0.529 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.523 ACC=0.527 | TEST f1_ma=0.414 ACC=0.418
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.523 ACC=0.526 | TEST f1_ma=0.408 ACC=0.412
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.503 ACC=0.506 | TEST f1_ma=0.383 ACC=0.388
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.518 ACC=0.524 | TEST f1_ma=0.387 ACC=0.398
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.535 ACC=0.538 | TEST f1_ma=0.397 ACC=0.402
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.513 ACC=0.518 | TEST f1_ma=0.391 ACC=0.398
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.497 ACC=0.500 | TEST f1_ma=0.382 ACC=0.391
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.491 ACC=0.497 | TEST f1_ma=0.379 ACC=0.390
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.508 | TEST f1_ma=0.383 ACC=0.387
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.501 ACC=0.506 | TEST f1_ma=0.399 ACC=0.405
# [hybrid_equal_knn   k= 9 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.501 ACC=0.506 | TEST f1_ma=0.391 ACC=0.398
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.536 ACC=0.540 | TEST f1_ma=0.417 ACC=0.422
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.538 ACC=0.539 | TEST f1_ma=0.422 ACC=0.425
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.540 | TEST f1_ma=0.422 ACC=0.428
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.508 ACC=0.511 | TEST f1_ma=0.397 ACC=0.404
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.517 ACC=0.520 | TEST f1_ma=0.409 ACC=0.413
# [hybrid_equal_knn   k= 9 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.517 ACC=0.519 | TEST f1_ma=0.405 ACC=0.407
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.524 ACC=0.527 | TEST f1_ma=0.386 ACC=0.393
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.522 ACC=0.525 | TEST f1_ma=0.415 ACC=0.419
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.515 ACC=0.519 | TEST f1_ma=0.402 ACC=0.410
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.510 ACC=0.514 | TEST f1_ma=0.386 ACC=0.392
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.514 ACC=0.517 | TEST f1_ma=0.401 ACC=0.405
# [hybrid_equal_knn   k= 9 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.517 ACC=0.521 | TEST f1_ma=0.397 ACC=0.401
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.539 ACC=0.541 | TEST f1_ma=0.421 ACC=0.424
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.541 ACC=0.543 | TEST f1_ma=0.411 ACC=0.415
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.526 ACC=0.528 | TEST f1_ma=0.410 ACC=0.415
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.520 ACC=0.522 | TEST f1_ma=0.393 ACC=0.397
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.520 ACC=0.522 | TEST f1_ma=0.405 ACC=0.407
# [hybrid_equal_knn   k= 9 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.521 ACC=0.527 | TEST f1_ma=0.410 ACC=0.416
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.531 ACC=0.534 | TEST f1_ma=0.412 ACC=0.420
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.529 ACC=0.532 | TEST f1_ma=0.412 ACC=0.421
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.528 ACC=0.532 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.516 ACC=0.521 | TEST f1_ma=0.400 ACC=0.405
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.520 ACC=0.523 | TEST f1_ma=0.396 ACC=0.403
# [hybrid_equal_knn   k= 9 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.524 ACC=0.526 | TEST f1_ma=0.398 ACC=0.403
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.540 ACC=0.543 | TEST f1_ma=0.422 ACC=0.427
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.537 ACC=0.541 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.534 ACC=0.536 | TEST f1_ma=0.426 ACC=0.430
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.515 ACC=0.519 | TEST f1_ma=0.392 ACC=0.398
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.525 ACC=0.527 | TEST f1_ma=0.393 ACC=0.398
# [hybrid_equal_knn   k= 9 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.534 ACC=0.533 | TEST f1_ma=0.406 ACC=0.412
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.532 ACC=0.535 | TEST f1_ma=0.412 ACC=0.417
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.534 ACC=0.537 | TEST f1_ma=0.409 ACC=0.415
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.529 ACC=0.532 | TEST f1_ma=0.419 ACC=0.426
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.517 ACC=0.520 | TEST f1_ma=0.408 ACC=0.412
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.519 ACC=0.522 | TEST f1_ma=0.393 ACC=0.399
# [hybrid_equal_knn   k= 9 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.523 ACC=0.527 | TEST f1_ma=0.407 ACC=0.412
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.510 ACC=0.512 | TEST f1_ma=0.398 ACC=0.405
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.476 ACC=0.485 | TEST f1_ma=0.391 ACC=0.399
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.465 ACC=0.481 | TEST f1_ma=0.397 ACC=0.408
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.506 ACC=0.509 | TEST f1_ma=0.357 ACC=0.364
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.498 ACC=0.504 | TEST f1_ma=0.385 ACC=0.390
# [hybrid_equal_knn   k=10 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.486 ACC=0.492 | TEST f1_ma=0.371 ACC=0.373
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.435 ACC=0.447 | TEST f1_ma=0.343 ACC=0.357
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.404 ACC=0.425 | TEST f1_ma=0.322 ACC=0.342
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.406 ACC=0.429 | TEST f1_ma=0.319 ACC=0.339
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.427 ACC=0.437 | TEST f1_ma=0.345 ACC=0.357
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.421 ACC=0.433 | TEST f1_ma=0.349 ACC=0.362
# [hybrid_equal_knn   k=10 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.402 ACC=0.418 | TEST f1_ma=0.333 ACC=0.346
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.525 ACC=0.529 | TEST f1_ma=0.401 ACC=0.407
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.510 ACC=0.513 | TEST f1_ma=0.400 ACC=0.407
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.511 ACC=0.513 | TEST f1_ma=0.407 ACC=0.411
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.512 ACC=0.512 | TEST f1_ma=0.358 ACC=0.367
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.536 ACC=0.537 | TEST f1_ma=0.382 ACC=0.389
# [hybrid_equal_knn   k=10 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.523 ACC=0.527 | TEST f1_ma=0.382 ACC=0.388
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.479 ACC=0.483 | TEST f1_ma=0.373 ACC=0.383
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.468 ACC=0.477 | TEST f1_ma=0.354 ACC=0.362
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.444 ACC=0.457 | TEST f1_ma=0.364 ACC=0.374
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.480 ACC=0.482 | TEST f1_ma=0.367 ACC=0.375
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.479 ACC=0.486 | TEST f1_ma=0.355 ACC=0.364
# [hybrid_equal_knn   k=10 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.453 ACC=0.463 | TEST f1_ma=0.351 ACC=0.358
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.539 ACC=0.538 | TEST f1_ma=0.405 ACC=0.408
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.532 ACC=0.533 | TEST f1_ma=0.414 ACC=0.416
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.523 ACC=0.529 | TEST f1_ma=0.412 ACC=0.418
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.515 ACC=0.518 | TEST f1_ma=0.377 ACC=0.385
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.517 ACC=0.522 | TEST f1_ma=0.397 ACC=0.402
# [hybrid_equal_knn   k=10 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.518 ACC=0.522 | TEST f1_ma=0.404 ACC=0.404
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.513 ACC=0.514 | TEST f1_ma=0.378 ACC=0.386
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.498 ACC=0.502 | TEST f1_ma=0.381 ACC=0.386
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.490 ACC=0.495 | TEST f1_ma=0.389 ACC=0.395
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.518 ACC=0.520 | TEST f1_ma=0.365 ACC=0.372
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.504 ACC=0.509 | TEST f1_ma=0.381 ACC=0.387
# [hybrid_equal_knn   k=10 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.503 ACC=0.510 | TEST f1_ma=0.381 ACC=0.388
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.540 ACC=0.541 | TEST f1_ma=0.408 ACC=0.413
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.522 ACC=0.525 | TEST f1_ma=0.409 ACC=0.412
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.530 ACC=0.532 | TEST f1_ma=0.408 ACC=0.414
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.513 ACC=0.514 | TEST f1_ma=0.384 ACC=0.392
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.511 ACC=0.515 | TEST f1_ma=0.392 ACC=0.395
# [hybrid_equal_knn   k=10 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.518 ACC=0.521 | TEST f1_ma=0.389 ACC=0.393
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.528 ACC=0.530 | TEST f1_ma=0.396 ACC=0.402
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.524 ACC=0.528 | TEST f1_ma=0.396 ACC=0.404
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.515 ACC=0.520 | TEST f1_ma=0.388 ACC=0.396
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.512 ACC=0.515 | TEST f1_ma=0.382 ACC=0.387
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.525 ACC=0.527 | TEST f1_ma=0.392 ACC=0.397
# [hybrid_equal_knn   k=10 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.518 ACC=0.522 | TEST f1_ma=0.403 ACC=0.406
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.536 ACC=0.536 | TEST f1_ma=0.412 ACC=0.418
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.536 | TEST f1_ma=0.418 ACC=0.422
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.529 ACC=0.531 | TEST f1_ma=0.417 ACC=0.423
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.509 ACC=0.513 | TEST f1_ma=0.385 ACC=0.389
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.533 ACC=0.536 | TEST f1_ma=0.398 ACC=0.400
# [hybrid_equal_knn   k=10 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.532 ACC=0.533 | TEST f1_ma=0.403 ACC=0.409
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.534 ACC=0.535 | TEST f1_ma=0.404 ACC=0.410
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.527 ACC=0.531 | TEST f1_ma=0.396 ACC=0.403
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.522 ACC=0.523 | TEST f1_ma=0.404 ACC=0.409
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.517 ACC=0.517 | TEST f1_ma=0.382 ACC=0.388
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.521 ACC=0.525 | TEST f1_ma=0.387 ACC=0.393
# [hybrid_equal_knn   k=10 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.532 ACC=0.532 | TEST f1_ma=0.405 ACC=0.409
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.541 ACC=0.542 | TEST f1_ma=0.414 ACC=0.420
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.538 ACC=0.541 | TEST f1_ma=0.409 ACC=0.415
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.537 ACC=0.539 | TEST f1_ma=0.423 ACC=0.427
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.516 ACC=0.520 | TEST f1_ma=0.378 ACC=0.386
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.530 ACC=0.532 | TEST f1_ma=0.402 ACC=0.407
# [hybrid_equal_knn   k=10 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.520 ACC=0.522 | TEST f1_ma=0.397 ACC=0.399
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.540 ACC=0.540 | TEST f1_ma=0.408 ACC=0.412
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.536 ACC=0.535 | TEST f1_ma=0.411 ACC=0.415
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.530 ACC=0.532 | TEST f1_ma=0.404 ACC=0.407
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.516 ACC=0.517 | TEST f1_ma=0.388 ACC=0.393
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.519 ACC=0.523 | TEST f1_ma=0.391 ACC=0.395
# [hybrid_equal_knn   k=10 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.525 ACC=0.528 | TEST f1_ma=0.387 ACC=0.392
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.487 ACC=0.497 | TEST f1_ma=0.378 ACC=0.386
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.468 ACC=0.476 | TEST f1_ma=0.359 ACC=0.372
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.484 ACC=0.493 | TEST f1_ma=0.389 ACC=0.392
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.499 ACC=0.502 | TEST f1_ma=0.349 ACC=0.360
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.498 ACC=0.503 | TEST f1_ma=0.386 ACC=0.393
# [hybrid_equal_knn   k=11 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.467 ACC=0.471 | TEST f1_ma=0.379 ACC=0.383
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.442 ACC=0.454 | TEST f1_ma=0.338 ACC=0.348
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.431 ACC=0.446 | TEST f1_ma=0.329 ACC=0.343
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.406 ACC=0.427 | TEST f1_ma=0.332 ACC=0.348
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.447 ACC=0.456 | TEST f1_ma=0.348 ACC=0.359
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.431 ACC=0.442 | TEST f1_ma=0.339 ACC=0.352
# [hybrid_equal_knn   k=11 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.406 ACC=0.421 | TEST f1_ma=0.325 ACC=0.340
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.519 ACC=0.522 | TEST f1_ma=0.421 ACC=0.422
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.497 ACC=0.502 | TEST f1_ma=0.390 ACC=0.396
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.505 ACC=0.509 | TEST f1_ma=0.406 ACC=0.410
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.510 ACC=0.511 | TEST f1_ma=0.361 ACC=0.367
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.530 ACC=0.532 | TEST f1_ma=0.412 ACC=0.413
# [hybrid_equal_knn   k=11 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.518 ACC=0.519 | TEST f1_ma=0.402 ACC=0.404
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.495 ACC=0.500 | TEST f1_ma=0.363 ACC=0.373
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.460 ACC=0.468 | TEST f1_ma=0.368 ACC=0.376
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.465 ACC=0.474 | TEST f1_ma=0.362 ACC=0.377
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.507 ACC=0.510 | TEST f1_ma=0.383 ACC=0.384
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.487 ACC=0.491 | TEST f1_ma=0.361 ACC=0.367
# [hybrid_equal_knn   k=11 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.474 ACC=0.480 | TEST f1_ma=0.351 ACC=0.361
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.541 ACC=0.543 | TEST f1_ma=0.409 ACC=0.412
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.535 | TEST f1_ma=0.420 ACC=0.419
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.527 ACC=0.529 | TEST f1_ma=0.417 ACC=0.422
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.512 ACC=0.515 | TEST f1_ma=0.376 ACC=0.380
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.535 ACC=0.539 | TEST f1_ma=0.403 ACC=0.405
# [hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.529 ACC=0.530 | TEST f1_ma=0.400 ACC=0.403
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.511 ACC=0.515 | TEST f1_ma=0.403 ACC=0.408
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.499 ACC=0.503 | TEST f1_ma=0.388 ACC=0.395
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.493 ACC=0.498 | TEST f1_ma=0.396 ACC=0.401
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.518 ACC=0.517 | TEST f1_ma=0.397 ACC=0.400
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.511 ACC=0.511 | TEST f1_ma=0.395 ACC=0.398
# [hybrid_equal_knn   k=11 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.496 ACC=0.505 | TEST f1_ma=0.385 ACC=0.390
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.544 ACC=0.545 | TEST f1_ma=0.428 ACC=0.432
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.535 ACC=0.536 | TEST f1_ma=0.435 ACC=0.436
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.536 | TEST f1_ma=0.418 ACC=0.422
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.527 ACC=0.527 | TEST f1_ma=0.397 ACC=0.401
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.523 ACC=0.526 | TEST f1_ma=0.410 ACC=0.410
# [hybrid_equal_knn   k=11 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.522 ACC=0.522 | TEST f1_ma=0.410 ACC=0.412
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.532 ACC=0.532 | TEST f1_ma=0.411 ACC=0.413
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.516 ACC=0.517 | TEST f1_ma=0.411 ACC=0.414
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.519 ACC=0.518 | TEST f1_ma=0.402 ACC=0.403
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.522 ACC=0.522 | TEST f1_ma=0.400 ACC=0.404
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.520 ACC=0.522 | TEST f1_ma=0.397 ACC=0.399
# [hybrid_equal_knn   k=11 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.521 ACC=0.522 | TEST f1_ma=0.405 ACC=0.408
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.540 ACC=0.542 | TEST f1_ma=0.423 ACC=0.427
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.536 ACC=0.537 | TEST f1_ma=0.426 ACC=0.427
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.537 ACC=0.540 | TEST f1_ma=0.419 ACC=0.423
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.520 ACC=0.521 | TEST f1_ma=0.390 ACC=0.393
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.521 ACC=0.525 | TEST f1_ma=0.408 ACC=0.412
# [hybrid_equal_knn   k=11 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.521 ACC=0.526 | TEST f1_ma=0.404 ACC=0.409
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.533 ACC=0.533 | TEST f1_ma=0.418 ACC=0.421
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.531 ACC=0.534 | TEST f1_ma=0.417 ACC=0.421
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.530 ACC=0.531 | TEST f1_ma=0.416 ACC=0.416
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.531 ACC=0.531 | TEST f1_ma=0.396 ACC=0.400
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.525 ACC=0.529 | TEST f1_ma=0.401 ACC=0.407
# [hybrid_equal_knn   k=11 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.528 ACC=0.529 | TEST f1_ma=0.413 ACC=0.414
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.536 ACC=0.538 | TEST f1_ma=0.427 ACC=0.430
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.536 ACC=0.538 | TEST f1_ma=0.429 ACC=0.431
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.541 ACC=0.542 | TEST f1_ma=0.422 ACC=0.423
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.518 ACC=0.520 | TEST f1_ma=0.407 ACC=0.409
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.527 ACC=0.530 | TEST f1_ma=0.399 ACC=0.403
# [hybrid_equal_knn   k=11 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.524 ACC=0.528 | TEST f1_ma=0.403 ACC=0.404
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.535 ACC=0.537 | TEST f1_ma=0.419 ACC=0.422
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.537 ACC=0.538 | TEST f1_ma=0.427 ACC=0.427
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.531 ACC=0.533 | TEST f1_ma=0.419 ACC=0.420
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.527 ACC=0.527 | TEST f1_ma=0.404 ACC=0.407
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.524 ACC=0.527 | TEST f1_ma=0.413 ACC=0.414
# [hybrid_equal_knn   k=11 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.523 ACC=0.526 | TEST f1_ma=0.408 ACC=0.410
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.491 ACC=0.500 | TEST f1_ma=0.386 ACC=0.393
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.480 ACC=0.488 | TEST f1_ma=0.388 ACC=0.393
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.479 ACC=0.484 | TEST f1_ma=0.392 ACC=0.396
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.468 ACC=0.477 | TEST f1_ma=0.370 ACC=0.380
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.492 ACC=0.494 | TEST f1_ma=0.393 ACC=0.398
# [hybrid_equal_knn   k=12 | h= 16 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.479 ACC=0.485 | TEST f1_ma=0.403 ACC=0.406
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.427 ACC=0.443 | TEST f1_ma=0.336 ACC=0.352
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.407 ACC=0.427 | TEST f1_ma=0.320 ACC=0.334
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.421 ACC=0.441 | TEST f1_ma=0.327 ACC=0.341
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.459 ACC=0.463 | TEST f1_ma=0.358 ACC=0.366
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.422 ACC=0.436 | TEST f1_ma=0.325 ACC=0.344
# [hybrid_equal_knn   k=12 | h= 16 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.423 ACC=0.440 | TEST f1_ma=0.336 ACC=0.348
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.514 ACC=0.517 | TEST f1_ma=0.422 ACC=0.423
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.521 ACC=0.522 | TEST f1_ma=0.409 ACC=0.407
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.505 ACC=0.509 | TEST f1_ma=0.401 ACC=0.405
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.502 ACC=0.507 | TEST f1_ma=0.351 ACC=0.355
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.509 ACC=0.512 | TEST f1_ma=0.385 ACC=0.385
# [hybrid_equal_knn   k=12 | h= 32 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.526 ACC=0.524 | TEST f1_ma=0.412 ACC=0.416
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.491 ACC=0.497 | TEST f1_ma=0.385 ACC=0.391
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.467 ACC=0.473 | TEST f1_ma=0.353 ACC=0.363
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.458 ACC=0.469 | TEST f1_ma=0.351 ACC=0.362
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.505 ACC=0.506 | TEST f1_ma=0.377 ACC=0.384
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.470 ACC=0.472 | TEST f1_ma=0.374 ACC=0.383
# [hybrid_equal_knn   k=12 | h= 32 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.464 ACC=0.473 | TEST f1_ma=0.365 ACC=0.374
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.535 ACC=0.537 | TEST f1_ma=0.422 ACC=0.422
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.526 ACC=0.529 | TEST f1_ma=0.412 ACC=0.412
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.520 ACC=0.521 | TEST f1_ma=0.421 ACC=0.418
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.514 ACC=0.517 | TEST f1_ma=0.383 ACC=0.388
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.518 ACC=0.523 | TEST f1_ma=0.402 ACC=0.407
# [hybrid_equal_knn   k=12 | h= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.508 ACC=0.510 | TEST f1_ma=0.391 ACC=0.393
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.506 ACC=0.511 | TEST f1_ma=0.393 ACC=0.398
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.494 ACC=0.497 | TEST f1_ma=0.392 ACC=0.395
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.492 ACC=0.495 | TEST f1_ma=0.394 ACC=0.398
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.509 ACC=0.513 | TEST f1_ma=0.388 ACC=0.391
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.499 ACC=0.502 | TEST f1_ma=0.398 ACC=0.397
# [hybrid_equal_knn   k=12 | h= 64 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.494 ACC=0.497 | TEST f1_ma=0.397 ACC=0.401
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.533 ACC=0.537 | TEST f1_ma=0.428 ACC=0.431
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.527 ACC=0.531 | TEST f1_ma=0.420 ACC=0.421
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.532 ACC=0.532 | TEST f1_ma=0.428 ACC=0.422
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.507 ACC=0.507 | TEST f1_ma=0.397 ACC=0.399
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.523 ACC=0.525 | TEST f1_ma=0.407 ACC=0.412
# [hybrid_equal_knn   k=12 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.530 ACC=0.533 | TEST f1_ma=0.430 ACC=0.433
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.526 ACC=0.528 | TEST f1_ma=0.410 ACC=0.413
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.523 ACC=0.524 | TEST f1_ma=0.402 ACC=0.404
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.514 ACC=0.516 | TEST f1_ma=0.411 ACC=0.412
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.509 ACC=0.511 | TEST f1_ma=0.405 ACC=0.408
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.517 ACC=0.519 | TEST f1_ma=0.412 ACC=0.412
# [hybrid_equal_knn   k=12 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.515 ACC=0.517 | TEST f1_ma=0.403 ACC=0.404
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.537 ACC=0.540 | TEST f1_ma=0.422 ACC=0.427
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.534 ACC=0.536 | TEST f1_ma=0.428 ACC=0.432
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.533 ACC=0.537 | TEST f1_ma=0.422 ACC=0.422
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.524 ACC=0.526 | TEST f1_ma=0.397 ACC=0.398
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.525 ACC=0.526 | TEST f1_ma=0.401 ACC=0.403
# [hybrid_equal_knn   k=12 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.528 ACC=0.530 | TEST f1_ma=0.407 ACC=0.405
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.535 ACC=0.535 | TEST f1_ma=0.415 ACC=0.415
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.528 ACC=0.531 | TEST f1_ma=0.418 ACC=0.418
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.528 ACC=0.528 | TEST f1_ma=0.413 ACC=0.412
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.519 ACC=0.521 | TEST f1_ma=0.399 ACC=0.403
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.523 ACC=0.523 | TEST f1_ma=0.420 ACC=0.420
# [hybrid_equal_knn   k=12 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.514 ACC=0.517 | TEST f1_ma=0.407 ACC=0.408
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adam  drop=0.0] VAL f1_ma=0.533 ACC=0.536 | TEST f1_ma=0.426 ACC=0.429
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.540 ACC=0.541 | TEST f1_ma=0.427 ACC=0.429
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.536 | TEST f1_ma=0.421 ACC=0.422
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adamw drop=0.0] VAL f1_ma=0.514 ACC=0.515 | TEST f1_ma=0.397 ACC=0.398
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.523 ACC=0.525 | TEST f1_ma=0.402 ACC=0.402
# [hybrid_equal_knn   k=12 | h=512 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.526 ACC=0.527 | TEST f1_ma=0.408 ACC=0.406
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adam  drop=0.0] VAL f1_ma=0.536 ACC=0.537 | TEST f1_ma=0.425 ACC=0.427
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.529 ACC=0.529 | TEST f1_ma=0.417 ACC=0.417
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.531 ACC=0.532 | TEST f1_ma=0.417 ACC=0.415
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adamw drop=0.0] VAL f1_ma=0.519 ACC=0.519 | TEST f1_ma=0.401 ACC=0.402
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.519 ACC=0.522 | TEST f1_ma=0.405 ACC=0.409
# [hybrid_equal_knn   k=12 | h=512 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.515 ACC=0.517 | TEST f1_ma=0.405 ACC=0.406
#
# Grid search finished in 29.5 min

# %%
test_m
# Out:
# {'test_acc': 0.4058333333333333,
#  'test_prec_w': 0.42884284332439715,
#  'test_rec_w': 0.4058333333333333,
#  'test_f1_w': 0.4048205733217243,
#  'test_prec_mi': 0.4058333333333333,
#  'test_rec_mi': 0.4058333333333333,
#  'test_f1_mi': 0.4058333333333333,
#  'test_prec_ma': 0.42884284332439726,
#  'test_rec_ma': 0.4058333333333334,
#  'test_f1_ma': 0.40482057332172433,
#  'test_roc_w': 0.891028735632184,
#  'test_roc_mi': 0.893469995210728,
#  'test_roc_ma': 0.8910287356321839}

# %%
print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(classification_report(y_true, y_pred))
#
# NameError: name 'y_true' is not defined
