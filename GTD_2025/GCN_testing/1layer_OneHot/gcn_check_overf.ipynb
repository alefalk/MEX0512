# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
#from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import os
import itertools
import numpy as np
import pandas as pd
from itertools import product
from scipy.sparse import coo_matrix
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from itertools import product
import numpy as np, torch
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from torch_geometric.utils import to_undirected, add_self_loops

from build_graph_data import *
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %% [markdown]
# # Read Data

# %%
path = f'../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')
#traindata, valdata, testdata = handle_leakage(df)

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1',
#        ...
#        'longlat_(126.036107, 8.866664)', 'longlat_(126.055367, 7.823071)',
#        'longlat_(126.187778, 8.941944)', 'longlat_(126.23167, 9.02111)',
#        'longlat_(126.255202, 8.280488)', 'longlat_(126.300309, 8.892579)',
#        'longlat_(126.30035, 8.801867)', 'longlat_(126.314871, 8.217759)',
#        'longlat_(151.179691, -33.934491)', 'gname'],
#       dtype='object', length=1804)

# %% [markdown]
# # Create train graph

# %%
# Creating df of the feature subset for node creation
#def create_node_dataframe(data, node_features, label_column='gname'):
 #   relevant_data = data[node_features + [label_column]].copy()
#    relevant_data['combination'] = list(zip(*(relevant_data[feat] for feat in node_features)))
 #   df_unique = relevant_data.drop_duplicates(subset=['combination'], keep='first').reset_index(drop=True)
  #  return df_unique[['combination', label_column]]

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

# %%
def induced_subgraph(edge_index, keep_mask):
    keep = keep_mask.nonzero(as_tuple=False).view(-1)
    # map old -> new ids
    new_id = -torch.ones(keep_mask.size(0), dtype=torch.long, device=edge_index.device)
    new_id[keep] = torch.arange(keep.numel(), device=edge_index.device)
    src, dst = edge_index
    m = keep_mask[src] & keep_mask[dst]
    ei = edge_index[:, m]
    ei = torch.stack([new_id[ei[0]], new_id[ei[1]]], dim=0)
    return ei, new_id

# %%
import itertools, time, numpy as np, pandas as pd, torch, torch.nn.functional as F
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from torch_geometric.nn import GCNConv

# ----------------------------
# Model with dropout
# ----------------------------
class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)
        self.dropout = torch.nn.Dropout(p=dropout)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        return x

#[[radius k=20 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.552 ACC=0.545 | TEST f1_ma=0.471 ACC=0.478
#[knn                k=24 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.532 ACC=0.537 | TEST f1_ma=0.474 ACC=0.482
#[hybrid_equal_knn   k=23 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.517 ACC=0.523 | TEST f1_ma=0.481 ACC=0.487
#[adaptive           k=23 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.542 ACC=0.545 | TEST f1_ma=0.482 ACC=0.488
#[knn                k=23 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.534 ACC=0.540 | TEST f1_ma=0.485 ACC=0.488
#[knn                k=23 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.543 | TEST f1_ma=0.479 ACC=0.488


num_epochs    = 2000
patience      = 200


# ----------------------------
# Metrics helper
# ----------------------------
def compute_all_metrics(y_true_np, logits_np, n_class):
    """Return dict of acc + P/R/F1 (weighted/micro/macro) + OVR ROC-AUC (w/mi/ma)."""
    y_pred_np = logits_np.argmax(axis=1)
    proba_np  = torch.softmax(torch.from_numpy(logits_np), dim=1).numpy()

    labels = list(range(n_class))
    out = {}
    # Accuracy
    out['acc'] = accuracy_score(y_true_np, y_pred_np)
    # Weighted
    out['prec_w'] = precision_score(y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['rec_w']  = recall_score(  y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['f1_w']   = f1_score(      y_true_np, y_pred_np, average='weighted')
    # Micro
    out['prec_mi'] = precision_score(y_true_np, y_pred_np, average='micro', zero_division=0)
    out['rec_mi']  = recall_score(  y_true_np, y_pred_np, average='micro',   zero_division=0)
    out['f1_mi']   = f1_score(      y_true_np, y_pred_np, average='micro')
    # Macro
    out['prec_ma'] = precision_score(y_true_np, y_pred_np, average='macro', zero_division=0)
    out['rec_ma']  = recall_score(  y_true_np, y_pred_np, average='macro',  zero_division=0)
    out['f1_ma']   = f1_score(      y_true_np, y_pred_np, average='macro')

    # OVR ROC-AUCs (robust if some classes missing in split)
    # If only one class present in y_true, roc_auc_score will raise; guard it.
    def safe_roc(avg):
        try:
            return roc_auc_score(y_true_np, proba_np, multi_class='ovr', average=avg, labels=labels)
        except Exception:
            return float('nan')

    out['roc_w']  = safe_roc('weighted')
    out['roc_mi'] = safe_roc('micro')
    out['roc_ma'] = safe_roc('macro')
    return out

def train_one_model(x, edge_index, y, train_mask, val_mask, num_classes,
                    hidden_dim, lr, opt_name, dropout, max_epochs=num_epochs, patience=patience, wd=5e-4, fd=0):
    model = PyTorchGCN(in_channels=x.size(1),
                       hidden_channels=hidden_dim,
                       num_classes=num_classes,
                       dropout=dropout).to(device)
    opt = make_optimizer(opt_name, model.parameters(), lr, wd)
    best_state, best_val, patience_left = None, float('inf'), patience

    for epoch in range(1, max_epochs + 1):
        model.train(); opt.zero_grad()
        x_drop = F.dropout(x, p=fd, training=model.training)
        out = model(x, edge_index)
        loss_train = F.cross_entropy(out[train_mask], y[train_mask])
        loss_train.backward(); opt.step()

        model.eval()
        with torch.no_grad():
            out = model(x, edge_index)
            loss_val = F.cross_entropy(out[val_mask], y[val_mask])

        if loss_val.item() < best_val - 1e-6:
            best_val = loss_val.item()
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            patience_left = patience
        else:
            patience_left -= 1
            if patience_left <= 0:
                print(f"Early stopping at epoch {epoch}")
                break


    if best_state is not None:
        model.load_state_dict({k: v.to(device) for k, v in best_state.items()})

    # Validation metrics (selection)
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_val_true = y[val_mask].detach().cpu().numpy()
    y_val_logits = logits[val_mask].detach().cpu().numpy()
    val_metrics = compute_all_metrics(y_val_true, y_val_logits, num_classes)
    val_metrics['val_loss'] = best_val
    return model, val_metrics

def split_metrics(model, x, edge_index, y, mask, num_classes, split_name):
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_true = y[mask].detach().cpu().numpy()
    logits_np = logits[mask].detach().cpu().numpy()
    mets = compute_all_metrics(y_true, logits_np, num_classes)
    return {f"{split_name}_{k}": v for k, v in mets.items()}

def make_optimizer(name, params, lr, wd):
    name = name.lower()
    if name == "adam":  return torch.optim.Adam(params, lr=lr, weight_decay=wd)
    if name == "adamw": return torch.optim.AdamW(params, lr=lr, weight_decay=wd)
    raise ValueError(f"Unknown optimizer: {name}")

# ----------------------------
# Hyperparameters to sweep
# ----------------------------
#[hybrid_equal_knn   k=11 | h= 64 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.634 ACC=0.630 | TEST f1_ma=0.552 ACC=0.560
"""
edge_mode   : hybrid_equal_knn
k           : 6
hidden_dim  : 128
optimizer   : adamw
lr          : 0.001
dropout     : 0.5
"""
hidden_dims   = [128, 256]
lrs           = [0.01, 0.001]
optimizers    = ["adam", "adamw"]
dropouts      = [0.3, 0.5]
weight_decays  = [0.05, 0.08, 0.10, 0.12, 0.15]
feat_decays = [0, 0.1, 0.2]
seed          = 42
device        = "cuda"

torch.manual_seed(seed); np.random.seed(seed)

# ----------------------------
# Data split (temporal)
# ----------------------------
df_all = df.copy()
train_idx, val_idx, test_idx = temporal_row_split(df_all, label_column='gname', train_ratio=0.6, val_ratio=0.2)

# Graph options
edge_modes = ["hybrid_equal_knn"]
#edge_modes = ["equal"]
k_values   = list(range(3, 8))

node_feature_cols = None
edge_feature_cols = ['attacktype1', 'target1']  # used for 'equal' part; fine to keep for others

# ----------------------------
# Grid search
# ----------------------------
results = []
best_row = None
best_score = -1.0  # we’ll select by val_macro_F1

t_all = time.time()
equal_cols = [c for c in df_all.columns if c.startswith("longlat_")]

partitions = [300]
#node_feature_cols=['extended','vicinity','multiple','success','suicide','attacktype1',
#                                'targtype1','target1','individual','weaptype1','nkill','property','ishostkid']
node_feature_cols=[c for c in df_all.columns if c != 'gname']

for p in partitions:
    path = f'../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv'
    df_all = pd.read_csv(path, encoding='ISO-8859-1')
    for k in k_values:
        for edge_mode in edge_modes:
            # A) fit scalers ON TRAIN ONLY
            node_scaler, edge_scaler = fit_scalers(
                df_all,
                node_feature_cols=node_feature_cols,
                edge_feature_cols=edge_feature_cols,
                train_idx=train_idx
            )

            # B) build TRAIN+VAL graph directly (neighbors computed within this set)
            trainval_idx = np.concatenate([train_idx, val_idx])
            x_tv, ei_tv, y_tv, _, _, _, label_index, chosen_radius = build_graph_on_index_set(
                df_all=df_all,
                idx_subset=trainval_idx,
                node_feature_cols=node_feature_cols,
                edge_feature_cols=edge_feature_cols,
                node_scaler=node_scaler, edge_scaler=edge_scaler,
                label_column='gname',
                train_idx=train_idx, val_idx=val_idx, test_idx=None,
                edge_mode=edge_mode, equal_cols=equal_cols, k=k, radius=None  # radius will be auto-picked from TRAIN in this set
            )

            # masks relative to the TRAIN+VAL subgraph:
            # (build them by mapping global indices -> local positions)
            pos_tv = {rid:i for i, rid in enumerate(trainval_idx)}
            train_mask_sub = torch.zeros(x_tv.size(0), dtype=torch.bool, device='cuda')
            val_mask_sub   = torch.zeros_like(train_mask_sub)
            for rid in train_idx: train_mask_sub[pos_tv[rid]] = True
            for rid in val_idx:   val_mask_sub[pos_tv[rid]]   = True

            num_classes = len(label_index)

            for hidden_dim, lr, opt_name, dropout, wd, fd in itertools.product(hidden_dims, lrs, optimizers, dropouts, weight_decays, feat_decays):
                t0 = time.time()
                model, val_m = train_one_model(
                    x_tv, ei_tv, y_tv, train_mask_sub, val_mask_sub, num_classes,
                    hidden_dim=hidden_dim, lr=lr, opt_name=opt_name, dropout=dropout,
                    max_epochs=num_epochs, patience=patience, wd=wd, fd=fd
                )

                # C) build FULL graph (train+val+test) using SAME scalers and SAME edge params
                #    - For radius modes, reuse chosen_radius so ε doesn’t change between train and test graphs.
                x_full, ei_full, y_full, train_mask_full, val_mask_full, test_mask_full, _, _ = build_graph_on_index_set(
                    df_all=df_all,
                    idx_subset=df_all.index.to_numpy(),  # full
                    node_feature_cols=node_feature_cols,
                    edge_feature_cols=edge_feature_cols,
                    node_scaler=node_scaler, edge_scaler=edge_scaler,
                    label_column='gname',
                    train_idx=train_idx, val_idx=val_idx, test_idx=test_idx,
                    edge_mode=edge_mode, equal_cols=equal_cols, k=k, radius=chosen_radius
                )

                # TESTA DENNA

                # (Optional stricter inference: one-way edges train→test only)
                ei_infer = make_infer_edge_index_strict(ei_full, train_mask_full | val_mask_full, test_mask_full)
                ei_infer, _ = add_self_loops(ei_infer, num_nodes=x_full.size(0))
                test_m = split_metrics(model, x_full, ei_infer, y_full, test_mask_full, num_classes, "test")

                # Standard transductive inference on full graph:
                #test_m = split_metrics(model, x_full, ei_full, y_full, test_mask_full, num_classes, "test")
                # Test split metrics
                #test_m = split_metrics(model, x, edge_index, y, test_mask, num_classes, split_name="test")
                elapsed = time.time() - t0

                row = dict(
                    k=k, edge_mode=edge_mode, hidden_dim=hidden_dim, lr=lr,
                    optimizer=opt_name, dropout=dropout, wd=wd, time_sec=elapsed,
                    train_nodes=int(train_mask_full.sum().item()),
                    val_nodes=int(val_mask_full.sum().item()),
                    test_nodes=int(test_mask_full.sum().item()),
                )
                # attach val and test metrics
                for kmet, vmet in val_m.items():
                    row[f"val_{kmet}"] = vmet
                row.update(test_m)

                results.append(row)

                # Selection criterion: validation macro-F1
                sel = val_m['f1_ma']
                if sel > best_score:
                    best_score = sel
                    best_row = row.copy()

                print(f"[{edge_mode:18s} k={k:2d} | h={hidden_dim:3d} lr={lr:<6} opt={opt_name:<5} drop={dropout}] "
                    f"VAL f1_ma={val_m['f1_ma']:.3f} ACC={val_m['acc']:.3f} | "
                    f"TEST f1_ma={test_m['test_f1_ma']:.3f} ACC={test_m['test_acc']:.3f}")

    total_min = (time.time() - t_all)/60
    print(f"\nGrid search finished in {total_min:.1f} min")

    #results_df = pd.DataFrame(results)

    # ----------------------------
    # Save all runs + best summary
    # ----------------------------
    #results_csv = f"grid_search_results{partition}.csv"
    #results_df.to_csv(results_csv, index=False)

    best_txt = f"best_run_{p}.txt"
    with open(best_txt, "w") as f:
        f.write("=== Best configuration (by validation macro-F1) ===\n")
        f.write(f"edge_mode   : {best_row['edge_mode']}\n")
        f.write(f"k           : {best_row['k']}\n")
        f.write(f"hidden_dim  : {best_row['hidden_dim']}\n")
        f.write(f"optimizer   : {best_row['optimizer']}\n")
        f.write(f"lr          : {best_row['lr']}\n")
        f.write(f"dropout     : {best_row['dropout']}\n")
        f.write(f"wd          : {best_row['wd']}\n")
        f.write("\n--- Validation metrics ---\n")
        f.write(f"val_loss    : {best_row.get('val_val_loss', float('nan')):.6f}\n")
        f.write(f"val_acc     : {best_row.get('val_acc', float('nan')):.6f}\n")
        f.write(f"val_prec_w  : {best_row.get('val_prec_w', float('nan')):.6f}\n")
        f.write(f"val_rec_w   : {best_row.get('val_rec_w', float('nan')):.6f}\n")
        f.write(f"val_f1_w    : {best_row.get('val_f1_w', float('nan')):.6f}\n")
        f.write(f"val_prec_mi : {best_row.get('val_prec_mi', float('nan')):.6f}\n")
        f.write(f"val_rec_mi  : {best_row.get('val_rec_mi', float('nan')):.6f}\n")
        f.write(f"val_f1_mi   : {best_row.get('val_f1_mi', float('nan')):.6f}\n")
        f.write(f"val_prec_ma : {best_row.get('val_prec_ma', float('nan')):.6f}\n")
        f.write(f"val_rec_ma  : {best_row.get('val_rec_ma', float('nan')):.6f}\n")
        f.write(f"val_f1_ma   : {best_row.get('val_f1_ma', float('nan')):.6f}\n")
        f.write(f"val_roc_w   : {best_row.get('val_roc_w', float('nan')):.6f}\n")
        f.write(f"val_roc_mi  : {best_row.get('val_roc_mi', float('nan')):.6f}\n")
        f.write(f"val_roc_ma  : {best_row.get('val_roc_ma', float('nan')):.6f}\n")
        f.write("\n--- Test metrics ---\n")
        f.write(f"test_acc    : {best_row.get('test_acc', float('nan')):.6f}\n")
        f.write(f"test_prec_w : {best_row.get('test_prec_w', float('nan')):.6f}\n")
        f.write(f"test_rec_w  : {best_row.get('test_rec_w', float('nan')):.6f}\n")
        f.write(f"test_f1_w   : {best_row.get('test_f1_w', float('nan')):.6f}\n")
        f.write(f"test_prec_mi: {best_row.get('test_prec_mi', float('nan')):.6f}\n")
        f.write(f"test_rec_mi : {best_row.get('test_rec_mi', float('nan')):.6f}\n")
        f.write(f"test_f1_mi  : {best_row.get('test_f1_mi', float('nan')):.6f}\n")
        f.write(f"test_prec_ma: {best_row.get('test_prec_ma', float('nan')):.6f}\n")
        f.write(f"test_rec_ma : {best_row.get('test_rec_ma', float('nan')):.6f}\n")
        f.write(f"test_f1_ma  : {best_row.get('test_f1_ma', float('nan')):.6f}\n")
        f.write(f"test_roc_w  : {best_row.get('test_roc_w', float('nan')):.6f}\n")
        f.write(f"test_roc_mi : {best_row.get('test_roc_mi', float('nan')):.6f}\n")
        f.write(f"test_roc_ma : {best_row.get('test_roc_ma', float('nan')):.6f}\n")
        f.write("\n--- Data sizes ---\n")
        f.write(f"train_nodes : {best_row['train_nodes']}\n")
        f.write(f"val_nodes   : {best_row['val_nodes']}\n")
        f.write(f"test_nodes  : {best_row['test_nodes']}\n")
        #f.write(f"\nCSV of all runs: {results_csv}\n")

#print(f"Saved all runs to {results_csv} and best summary to {best_txt}")
# Out:
# Early stopping at epoch 538
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.710 ACC=0.713 | TEST f1_ma=0.598 ACC=0.610
# Early stopping at epoch 578
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.713 ACC=0.717 | TEST f1_ma=0.597 ACC=0.610
# Early stopping at epoch 545
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.715 ACC=0.718 | TEST f1_ma=0.601 ACC=0.612
# Early stopping at epoch 631
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.670 ACC=0.685 | TEST f1_ma=0.587 ACC=0.605
# Early stopping at epoch 515
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.671 ACC=0.687 | TEST f1_ma=0.576 ACC=0.595
# Early stopping at epoch 511
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.662 ACC=0.682 | TEST f1_ma=0.581 ACC=0.603
# Early stopping at epoch 469
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.612 ACC=0.642 | TEST f1_ma=0.530 ACC=0.565
# Early stopping at epoch 590
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.625 ACC=0.653 | TEST f1_ma=0.541 ACC=0.575
# Early stopping at epoch 476
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.637 ACC=0.660 | TEST f1_ma=0.548 ACC=0.580
# Early stopping at epoch 806
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.470 ACC=0.550 | TEST f1_ma=0.407 ACC=0.492
# Early stopping at epoch 561
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.435 ACC=0.522 | TEST f1_ma=0.398 ACC=0.485
# Early stopping at epoch 408
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.426 ACC=0.515 | TEST f1_ma=0.395 ACC=0.483
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.679 ACC=0.685 | TEST f1_ma=0.591 ACC=0.600
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.687 ACC=0.690 | TEST f1_ma=0.584 ACC=0.602
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.685 ACC=0.693 | TEST f1_ma=0.579 ACC=0.600
# Early stopping at epoch 338
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.711 ACC=0.713 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 452
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.705 ACC=0.708 | TEST f1_ma=0.611 ACC=0.623
# Early stopping at epoch 391
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.707 ACC=0.710 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 356
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.661 ACC=0.680 | TEST f1_ma=0.596 ACC=0.615
# Early stopping at epoch 436
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.678 ACC=0.693 | TEST f1_ma=0.589 ACC=0.610
# Early stopping at epoch 472
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.585 ACC=0.607
# Early stopping at epoch 451
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.617 ACC=0.647 | TEST f1_ma=0.533 ACC=0.567
# Early stopping at epoch 558
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.655 ACC=0.672 | TEST f1_ma=0.554 ACC=0.583
# Early stopping at epoch 382
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.605 ACC=0.637 | TEST f1_ma=0.523 ACC=0.562
# Early stopping at epoch 468
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.481 ACC=0.558 | TEST f1_ma=0.426 ACC=0.505
# Early stopping at epoch 768
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.422 ACC=0.510 | TEST f1_ma=0.396 ACC=0.480
# Early stopping at epoch 390
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.447 ACC=0.537 | TEST f1_ma=0.405 ACC=0.492
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.675 ACC=0.680 | TEST f1_ma=0.575 ACC=0.597
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.686 ACC=0.690 | TEST f1_ma=0.576 ACC=0.592
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.693 ACC=0.698 | TEST f1_ma=0.590 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.717 ACC=0.717 | TEST f1_ma=0.595 ACC=0.607
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.687 ACC=0.695 | TEST f1_ma=0.578 ACC=0.587
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.719 ACC=0.718 | TEST f1_ma=0.608 ACC=0.615
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.714 ACC=0.715 | TEST f1_ma=0.599 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.598 ACC=0.605
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.591 ACC=0.602
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.712 ACC=0.712 | TEST f1_ma=0.604 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.713 | TEST f1_ma=0.606 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.710 | TEST f1_ma=0.612 ACC=0.620
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.604 ACC=0.615
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.593 ACC=0.598
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.712 | TEST f1_ma=0.595 ACC=0.608
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.712 | TEST f1_ma=0.599 ACC=0.608
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.720 ACC=0.718 | TEST f1_ma=0.608 ACC=0.620
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.703 ACC=0.703 | TEST f1_ma=0.602 ACC=0.615
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.587 ACC=0.600
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.720 ACC=0.720 | TEST f1_ma=0.600 ACC=0.605
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.705 ACC=0.705 | TEST f1_ma=0.610 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.707 ACC=0.708 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.709 ACC=0.708 | TEST f1_ma=0.604 ACC=0.613
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.610 ACC=0.620
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.710 | TEST f1_ma=0.599 ACC=0.607
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.717 ACC=0.717 | TEST f1_ma=0.596 ACC=0.608
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.594 ACC=0.602
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.706 ACC=0.707 | TEST f1_ma=0.579 ACC=0.588
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.719 ACC=0.720 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.710 | TEST f1_ma=0.586 ACC=0.602
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.704 ACC=0.703 | TEST f1_ma=0.593 ACC=0.602
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.702 ACC=0.703 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.709 ACC=0.712 | TEST f1_ma=0.597 ACC=0.607
# Early stopping at epoch 1466
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.705 ACC=0.708 | TEST f1_ma=0.601 ACC=0.612
# Early stopping at epoch 1224
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.711 ACC=0.715 | TEST f1_ma=0.609 ACC=0.622
# Early stopping at epoch 1121
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.711 ACC=0.713 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 1791
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.675 ACC=0.690 | TEST f1_ma=0.588 ACC=0.608
# Early stopping at epoch 1339
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.671 ACC=0.688 | TEST f1_ma=0.583 ACC=0.605
# Early stopping at epoch 1986
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.589 ACC=0.608
# Early stopping at epoch 1395
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.589 ACC=0.627 | TEST f1_ma=0.521 ACC=0.565
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.612 ACC=0.643 | TEST f1_ma=0.531 ACC=0.567
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.614 ACC=0.645 | TEST f1_ma=0.543 ACC=0.578
# Early stopping at epoch 283
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.684 ACC=0.690 | TEST f1_ma=0.587 ACC=0.603
# Early stopping at epoch 283
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.691 ACC=0.697 | TEST f1_ma=0.595 ACC=0.613
# Early stopping at epoch 286
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.701 ACC=0.708 | TEST f1_ma=0.584 ACC=0.602
# Early stopping at epoch 268
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.693 ACC=0.698 | TEST f1_ma=0.601 ACC=0.617
# Early stopping at epoch 271
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.689 ACC=0.693 | TEST f1_ma=0.594 ACC=0.608
# Early stopping at epoch 269
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.693 ACC=0.698 | TEST f1_ma=0.577 ACC=0.597
# Early stopping at epoch 1054
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.707 ACC=0.710 | TEST f1_ma=0.602 ACC=0.615
# Early stopping at epoch 1235
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.706 ACC=0.708 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 1214
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.704 ACC=0.707 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 1400
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.683 | TEST f1_ma=0.585 ACC=0.607
# Early stopping at epoch 1948
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.674 ACC=0.688 | TEST f1_ma=0.587 ACC=0.607
# Early stopping at epoch 1892
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.665 ACC=0.682 | TEST f1_ma=0.587 ACC=0.607
# Early stopping at epoch 1900
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.593 ACC=0.628 | TEST f1_ma=0.525 ACC=0.563
# Early stopping at epoch 1732
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.611 ACC=0.643 | TEST f1_ma=0.527 ACC=0.567
# Early stopping at epoch 1833
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.611 ACC=0.645 | TEST f1_ma=0.519 ACC=0.563
# Early stopping at epoch 287
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.701 ACC=0.707 | TEST f1_ma=0.574 ACC=0.597
# Early stopping at epoch 288
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.698 ACC=0.703 | TEST f1_ma=0.588 ACC=0.610
# Early stopping at epoch 284
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.691 ACC=0.698 | TEST f1_ma=0.579 ACC=0.602
# Early stopping at epoch 270
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.692 ACC=0.698 | TEST f1_ma=0.600 ACC=0.618
# Early stopping at epoch 270
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.702 ACC=0.708 | TEST f1_ma=0.590 ACC=0.605
# Early stopping at epoch 269
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.703 ACC=0.708 | TEST f1_ma=0.583 ACC=0.600
# Early stopping at epoch 253
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.714 ACC=0.713 | TEST f1_ma=0.582 ACC=0.590
# Early stopping at epoch 252
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.710 | TEST f1_ma=0.583 ACC=0.592
# Early stopping at epoch 249
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.699 ACC=0.700 | TEST f1_ma=0.580 ACC=0.588
# Early stopping at epoch 251
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.707 ACC=0.705 | TEST f1_ma=0.595 ACC=0.595
# Early stopping at epoch 250
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.712 | TEST f1_ma=0.575 ACC=0.585
# Early stopping at epoch 251
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.721 ACC=0.722 | TEST f1_ma=0.570 ACC=0.582
# Early stopping at epoch 253
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.706 ACC=0.707 | TEST f1_ma=0.585 ACC=0.595
# Early stopping at epoch 251
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.715 ACC=0.715 | TEST f1_ma=0.576 ACC=0.583
# Early stopping at epoch 250
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.716 ACC=0.717 | TEST f1_ma=0.578 ACC=0.585
# Early stopping at epoch 251
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.707 | TEST f1_ma=0.587 ACC=0.595
# Early stopping at epoch 252
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.707 | TEST f1_ma=0.581 ACC=0.590
# Early stopping at epoch 252
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.699 ACC=0.698 | TEST f1_ma=0.582 ACC=0.588
# Early stopping at epoch 252
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.698 ACC=0.698 | TEST f1_ma=0.590 ACC=0.595
# Early stopping at epoch 254
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.701 ACC=0.700 | TEST f1_ma=0.592 ACC=0.593
# Early stopping at epoch 250
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.703 ACC=0.703 | TEST f1_ma=0.583 ACC=0.590
# Early stopping at epoch 253
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.700 ACC=0.702 | TEST f1_ma=0.588 ACC=0.595
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.706 ACC=0.707 | TEST f1_ma=0.588 ACC=0.595
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.710 | TEST f1_ma=0.590 ACC=0.598
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.704 ACC=0.703 | TEST f1_ma=0.586 ACC=0.595
# Early stopping at epoch 254
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.714 ACC=0.715 | TEST f1_ma=0.583 ACC=0.587
# Early stopping at epoch 253
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.701 ACC=0.700 | TEST f1_ma=0.585 ACC=0.592
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.716 ACC=0.717 | TEST f1_ma=0.590 ACC=0.592
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.719 ACC=0.718 | TEST f1_ma=0.587 ACC=0.597
# Early stopping at epoch 254
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.712 ACC=0.712 | TEST f1_ma=0.591 ACC=0.593
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.716 ACC=0.717 | TEST f1_ma=0.592 ACC=0.593
# Early stopping at epoch 253
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.710 ACC=0.710 | TEST f1_ma=0.589 ACC=0.597
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.701 ACC=0.700 | TEST f1_ma=0.582 ACC=0.590
# Early stopping at epoch 254
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.587 ACC=0.592
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.707 ACC=0.707 | TEST f1_ma=0.588 ACC=0.592
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 3 | h=128 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.714 ACC=0.713 | TEST f1_ma=0.585 ACC=0.592
# Early stopping at epoch 509
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.705 ACC=0.708 | TEST f1_ma=0.599 ACC=0.613
# Early stopping at epoch 466
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.707 ACC=0.710 | TEST f1_ma=0.604 ACC=0.615
# Early stopping at epoch 504
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.710 ACC=0.713 | TEST f1_ma=0.607 ACC=0.618
# Early stopping at epoch 456
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.672 ACC=0.687 | TEST f1_ma=0.589 ACC=0.607
# Early stopping at epoch 404
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.675 ACC=0.690 | TEST f1_ma=0.587 ACC=0.607
# Early stopping at epoch 393
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.670 ACC=0.687 | TEST f1_ma=0.592 ACC=0.612
# Early stopping at epoch 474
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.611 ACC=0.642 | TEST f1_ma=0.519 ACC=0.557
# Early stopping at epoch 283
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.626 ACC=0.657 | TEST f1_ma=0.533 ACC=0.568
# Early stopping at epoch 434
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.616 ACC=0.642 | TEST f1_ma=0.553 ACC=0.583
# Early stopping at epoch 502
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.463 ACC=0.538 | TEST f1_ma=0.428 ACC=0.503
# Early stopping at epoch 324
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.449 ACC=0.537 | TEST f1_ma=0.401 ACC=0.492
# Early stopping at epoch 572
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.448 ACC=0.535 | TEST f1_ma=0.406 ACC=0.490
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.661 ACC=0.668 | TEST f1_ma=0.604 ACC=0.615
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.684 ACC=0.688 | TEST f1_ma=0.595 ACC=0.608
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.699 ACC=0.702 | TEST f1_ma=0.585 ACC=0.597
# Early stopping at epoch 373
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.711 ACC=0.713 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 470
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.710 ACC=0.713 | TEST f1_ma=0.607 ACC=0.618
# Early stopping at epoch 441
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.710 ACC=0.713 | TEST f1_ma=0.606 ACC=0.618
# Early stopping at epoch 375
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.682 | TEST f1_ma=0.590 ACC=0.607
# Early stopping at epoch 427
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.675 ACC=0.690 | TEST f1_ma=0.585 ACC=0.605
# Early stopping at epoch 435
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.592 ACC=0.612
# Early stopping at epoch 391
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.624 ACC=0.652 | TEST f1_ma=0.551 ACC=0.582
# Early stopping at epoch 391
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.626 ACC=0.657 | TEST f1_ma=0.521 ACC=0.557
# Early stopping at epoch 303
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.624 ACC=0.653 | TEST f1_ma=0.521 ACC=0.558
# Early stopping at epoch 664
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.453 ACC=0.540 | TEST f1_ma=0.403 ACC=0.492
# Early stopping at epoch 305
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.452 ACC=0.533 | TEST f1_ma=0.414 ACC=0.493
# Early stopping at epoch 473
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.474 ACC=0.553 | TEST f1_ma=0.406 ACC=0.495
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.688 ACC=0.695 | TEST f1_ma=0.588 ACC=0.605
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.694 ACC=0.702 | TEST f1_ma=0.583 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.682 ACC=0.690 | TEST f1_ma=0.580 ACC=0.595
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.714 ACC=0.715 | TEST f1_ma=0.594 ACC=0.603
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.721 ACC=0.720 | TEST f1_ma=0.592 ACC=0.603
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.594 ACC=0.602
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.710 | TEST f1_ma=0.599 ACC=0.608
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.592 ACC=0.598
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.716 ACC=0.718 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.726 ACC=0.725 | TEST f1_ma=0.594 ACC=0.600
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.721 ACC=0.722 | TEST f1_ma=0.607 ACC=0.618
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.713 ACC=0.715 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.591 ACC=0.602
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.715 ACC=0.715 | TEST f1_ma=0.604 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.686 ACC=0.693 | TEST f1_ma=0.584 ACC=0.593
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.715 ACC=0.715 | TEST f1_ma=0.592 ACC=0.602
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.712 ACC=0.712 | TEST f1_ma=0.598 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.721 ACC=0.720 | TEST f1_ma=0.597 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.717 ACC=0.718 | TEST f1_ma=0.588 ACC=0.602
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.716 ACC=0.715 | TEST f1_ma=0.595 ACC=0.603
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.721 ACC=0.722 | TEST f1_ma=0.588 ACC=0.600
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.710 ACC=0.710 | TEST f1_ma=0.595 ACC=0.608
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.605 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.707 ACC=0.708 | TEST f1_ma=0.584 ACC=0.595
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.588 ACC=0.602
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.710 ACC=0.710 | TEST f1_ma=0.607 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.709 ACC=0.710 | TEST f1_ma=0.587 ACC=0.600
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.731 ACC=0.728 | TEST f1_ma=0.600 ACC=0.605
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.715 ACC=0.717 | TEST f1_ma=0.604 ACC=0.615
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.702 ACC=0.703 | TEST f1_ma=0.594 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.716 ACC=0.718 | TEST f1_ma=0.594 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.719 ACC=0.718 | TEST f1_ma=0.597 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.707 ACC=0.707 | TEST f1_ma=0.601 ACC=0.612
# Early stopping at epoch 1155
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.712 ACC=0.715 | TEST f1_ma=0.605 ACC=0.615
# Early stopping at epoch 1430
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.712 ACC=0.715 | TEST f1_ma=0.604 ACC=0.615
# Early stopping at epoch 1159
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.712 ACC=0.715 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 1420
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.675 ACC=0.690 | TEST f1_ma=0.589 ACC=0.608
# Early stopping at epoch 1361
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.587 ACC=0.605
# Early stopping at epoch 1064
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.587 ACC=0.605
# Early stopping at epoch 1423
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.611 ACC=0.643 | TEST f1_ma=0.534 ACC=0.572
# Early stopping at epoch 1974
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.610 ACC=0.642 | TEST f1_ma=0.528 ACC=0.567
# Early stopping at epoch 1224
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.610 ACC=0.643 | TEST f1_ma=0.523 ACC=0.565
# Early stopping at epoch 276
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.680 | TEST f1_ma=0.592 ACC=0.612
# Early stopping at epoch 273
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.685 ACC=0.693 | TEST f1_ma=0.590 ACC=0.612
# Early stopping at epoch 273
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.686 ACC=0.693 | TEST f1_ma=0.592 ACC=0.610
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.701 ACC=0.705 | TEST f1_ma=0.599 ACC=0.615
# Early stopping at epoch 258
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.690 ACC=0.695 | TEST f1_ma=0.593 ACC=0.608
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.698 ACC=0.702 | TEST f1_ma=0.596 ACC=0.610
# Early stopping at epoch 820
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.709 ACC=0.712 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 809
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.707 ACC=0.710 | TEST f1_ma=0.604 ACC=0.617
# Early stopping at epoch 1204
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.709 ACC=0.712 | TEST f1_ma=0.606 ACC=0.618
# Early stopping at epoch 1182
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.672 ACC=0.688 | TEST f1_ma=0.587 ACC=0.607
# Early stopping at epoch 1120
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.673 ACC=0.688 | TEST f1_ma=0.589 ACC=0.608
# Early stopping at epoch 1469
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.676 ACC=0.692 | TEST f1_ma=0.584 ACC=0.603
# Early stopping at epoch 1160
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.614 ACC=0.645 | TEST f1_ma=0.528 ACC=0.567
# Early stopping at epoch 1431
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.616 ACC=0.647 | TEST f1_ma=0.536 ACC=0.573
# Early stopping at epoch 1423
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.614 ACC=0.645 | TEST f1_ma=0.538 ACC=0.573
# Early stopping at epoch 276
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.682 ACC=0.688 | TEST f1_ma=0.595 ACC=0.615
# Early stopping at epoch 278
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.690 ACC=0.695 | TEST f1_ma=0.603 ACC=0.623
# Early stopping at epoch 276
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.690 ACC=0.698 | TEST f1_ma=0.584 ACC=0.603
# Early stopping at epoch 258
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.700 ACC=0.705 | TEST f1_ma=0.588 ACC=0.608
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.696 ACC=0.700 | TEST f1_ma=0.607 ACC=0.622
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.698 ACC=0.705 | TEST f1_ma=0.600 ACC=0.620
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.704 ACC=0.705 | TEST f1_ma=0.582 ACC=0.588
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.712 ACC=0.713 | TEST f1_ma=0.580 ACC=0.590
# Early stopping at epoch 234
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.710 | TEST f1_ma=0.591 ACC=0.595
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.708 | TEST f1_ma=0.596 ACC=0.598
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.720 ACC=0.720 | TEST f1_ma=0.587 ACC=0.590
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.706 ACC=0.707 | TEST f1_ma=0.578 ACC=0.587
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.710 | TEST f1_ma=0.584 ACC=0.588
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.716 ACC=0.717 | TEST f1_ma=0.588 ACC=0.598
# Early stopping at epoch 234
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.713 ACC=0.713 | TEST f1_ma=0.590 ACC=0.595
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.589 ACC=0.593
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.589 ACC=0.597
# Early stopping at epoch 234
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.718 ACC=0.717 | TEST f1_ma=0.583 ACC=0.588
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.710 | TEST f1_ma=0.577 ACC=0.587
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.711 ACC=0.710 | TEST f1_ma=0.579 ACC=0.588
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.714 ACC=0.713 | TEST f1_ma=0.585 ACC=0.595
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.712 ACC=0.712 | TEST f1_ma=0.587 ACC=0.590
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.711 ACC=0.712 | TEST f1_ma=0.600 ACC=0.603
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.717 ACC=0.717 | TEST f1_ma=0.586 ACC=0.592
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.713 ACC=0.712 | TEST f1_ma=0.590 ACC=0.598
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.709 ACC=0.710 | TEST f1_ma=0.590 ACC=0.598
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.705 ACC=0.705 | TEST f1_ma=0.590 ACC=0.600
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.714 ACC=0.713 | TEST f1_ma=0.589 ACC=0.597
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.712 ACC=0.713 | TEST f1_ma=0.580 ACC=0.592
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.582 ACC=0.590
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.714 ACC=0.715 | TEST f1_ma=0.592 ACC=0.597
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.716 ACC=0.715 | TEST f1_ma=0.587 ACC=0.595
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.710 ACC=0.712 | TEST f1_ma=0.598 ACC=0.603
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.708 ACC=0.708 | TEST f1_ma=0.588 ACC=0.595
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.705 ACC=0.705 | TEST f1_ma=0.588 ACC=0.593
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 3 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.704 ACC=0.703 | TEST f1_ma=0.602 ACC=0.607
# Early stopping at epoch 395
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.692 ACC=0.695 | TEST f1_ma=0.613 ACC=0.620
# Early stopping at epoch 561
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.689 ACC=0.690 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 404
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.698 ACC=0.702 | TEST f1_ma=0.607 ACC=0.615
# Early stopping at epoch 685
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.672 ACC=0.685 | TEST f1_ma=0.600 ACC=0.620
# Early stopping at epoch 559
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.669 ACC=0.682 | TEST f1_ma=0.599 ACC=0.618
# Early stopping at epoch 554
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.663 ACC=0.678 | TEST f1_ma=0.601 ACC=0.622
# Early stopping at epoch 656
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.588 ACC=0.623 | TEST f1_ma=0.532 ACC=0.580
# Early stopping at epoch 669
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.599 ACC=0.630 | TEST f1_ma=0.528 ACC=0.573
# Early stopping at epoch 323
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.572 ACC=0.612 | TEST f1_ma=0.500 ACC=0.553
# Early stopping at epoch 544
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.402 ACC=0.503 | TEST f1_ma=0.351 ACC=0.452
# Early stopping at epoch 499
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.404 ACC=0.505 | TEST f1_ma=0.352 ACC=0.453
# Early stopping at epoch 208
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.671 ACC=0.677 | TEST f1_ma=0.593 ACC=0.612
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.667 ACC=0.677 | TEST f1_ma=0.584 ACC=0.607
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.676 ACC=0.683 | TEST f1_ma=0.585 ACC=0.600
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.683 | TEST f1_ma=0.580 ACC=0.598
# Early stopping at epoch 432
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.692 ACC=0.695 | TEST f1_ma=0.602 ACC=0.610
# Early stopping at epoch 453
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.689 ACC=0.692 | TEST f1_ma=0.592 ACC=0.603
# Early stopping at epoch 360
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.696 ACC=0.698 | TEST f1_ma=0.605 ACC=0.615
# Early stopping at epoch 513
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.660 ACC=0.673 | TEST f1_ma=0.585 ACC=0.608
# Early stopping at epoch 696
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.673 ACC=0.685 | TEST f1_ma=0.592 ACC=0.613
# Early stopping at epoch 395
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.669 ACC=0.683 | TEST f1_ma=0.603 ACC=0.623
# Early stopping at epoch 597
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.593 ACC=0.627 | TEST f1_ma=0.536 ACC=0.575
# Early stopping at epoch 694
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.581 ACC=0.622 | TEST f1_ma=0.493 ACC=0.550
# Early stopping at epoch 559
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.598 ACC=0.632 | TEST f1_ma=0.505 ACC=0.557
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.686 ACC=0.692 | TEST f1_ma=0.591 ACC=0.605
# Early stopping at epoch 384
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.423 ACC=0.517 | TEST f1_ma=0.371 ACC=0.465
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.673 ACC=0.678 | TEST f1_ma=0.571 ACC=0.590
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.677 ACC=0.683 | TEST f1_ma=0.582 ACC=0.602
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.677 ACC=0.683 | TEST f1_ma=0.575 ACC=0.597
# Early stopping at epoch 207
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.677 ACC=0.683 | TEST f1_ma=0.581 ACC=0.595
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.699 ACC=0.698 | TEST f1_ma=0.587 ACC=0.597
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.710 ACC=0.708 | TEST f1_ma=0.607 ACC=0.613
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.694 ACC=0.695 | TEST f1_ma=0.606 ACC=0.613
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.697 ACC=0.697 | TEST f1_ma=0.601 ACC=0.607
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.707 | TEST f1_ma=0.607 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.673 ACC=0.677 | TEST f1_ma=0.576 ACC=0.583
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.708 ACC=0.707 | TEST f1_ma=0.592 ACC=0.600
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.698 ACC=0.698 | TEST f1_ma=0.594 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.692 ACC=0.693 | TEST f1_ma=0.598 ACC=0.610
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.694 ACC=0.695 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.696 ACC=0.695 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.697 ACC=0.698 | TEST f1_ma=0.592 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.704 ACC=0.703 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.709 ACC=0.707 | TEST f1_ma=0.588 ACC=0.595
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.689 ACC=0.688 | TEST f1_ma=0.611 ACC=0.618
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.719 ACC=0.717 | TEST f1_ma=0.591 ACC=0.600
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.704 ACC=0.705 | TEST f1_ma=0.605 ACC=0.615
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.705 ACC=0.703 | TEST f1_ma=0.596 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.702 ACC=0.700 | TEST f1_ma=0.594 ACC=0.602
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.702 ACC=0.702 | TEST f1_ma=0.610 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.705 ACC=0.705 | TEST f1_ma=0.610 ACC=0.618
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.698 ACC=0.698 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.701 ACC=0.700 | TEST f1_ma=0.594 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.703 ACC=0.705 | TEST f1_ma=0.601 ACC=0.613
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.692 ACC=0.692 | TEST f1_ma=0.592 ACC=0.605
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.709 ACC=0.707 | TEST f1_ma=0.596 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.694 ACC=0.693 | TEST f1_ma=0.589 ACC=0.600
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.691 ACC=0.692 | TEST f1_ma=0.592 ACC=0.603
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.691 ACC=0.692 | TEST f1_ma=0.596 ACC=0.608
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 4 | h=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.696 ACC=0.697 | TEST f1_ma=0.603 ACC=0.605
# Early stopping at epoch 1378
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.687 ACC=0.688 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 1545
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.687 ACC=0.688 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 1633
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.694 ACC=0.695 | TEST f1_ma=0.606 ACC=0.615
# Early stopping at epoch 1793
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.665 ACC=0.678 | TEST f1_ma=0.591 ACC=0.612
# Early stopping at epoch 1898
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.667 ACC=0.680 | TEST f1_ma=0.597 ACC=0.618
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.660 ACC=0.675 | TEST f1_ma=0.598 ACC=0.618
# Early stopping at epoch 1681
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.552 ACC=0.600 | TEST f1_ma=0.483 ACC=0.545
# Early stopping at epoch 1602
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.553 ACC=0.600 | TEST f1_ma=0.496 ACC=0.553
# Early stopping at epoch 1884
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.550 ACC=0.598 | TEST f1_ma=0.493 ACC=0.550
# Early stopping at epoch 278
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.677 ACC=0.687 | TEST f1_ma=0.568 ACC=0.598
# Early stopping at epoch 282
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.684 ACC=0.690 | TEST f1_ma=0.592 ACC=0.610
# Early stopping at epoch 280
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.687 ACC=0.692 | TEST f1_ma=0.600 ACC=0.610
# Early stopping at epoch 268
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.694 ACC=0.703 | TEST f1_ma=0.577 ACC=0.602
# Early stopping at epoch 267
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.692 ACC=0.700 | TEST f1_ma=0.575 ACC=0.595
# Early stopping at epoch 268
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.673 ACC=0.677 | TEST f1_ma=0.581 ACC=0.595
# Early stopping at epoch 1434
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.687 ACC=0.690 | TEST f1_ma=0.610 ACC=0.618
# Early stopping at epoch 1199
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.687 ACC=0.690 | TEST f1_ma=0.604 ACC=0.613
# Early stopping at epoch 1368
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.693 ACC=0.697 | TEST f1_ma=0.610 ACC=0.620
# Early stopping at epoch 1662
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.655 ACC=0.672 | TEST f1_ma=0.598 ACC=0.618
# Early stopping at epoch 1990
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.651 ACC=0.668 | TEST f1_ma=0.597 ACC=0.618
# Early stopping at epoch 1758
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.653 ACC=0.670 | TEST f1_ma=0.601 ACC=0.622
# Early stopping at epoch 1874
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.549 ACC=0.598 | TEST f1_ma=0.493 ACC=0.550
# Early stopping at epoch 1818
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.550 ACC=0.598 | TEST f1_ma=0.490 ACC=0.548
# Early stopping at epoch 1623
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.549 ACC=0.597 | TEST f1_ma=0.488 ACC=0.545
# Early stopping at epoch 281
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.686 ACC=0.693 | TEST f1_ma=0.593 ACC=0.607
# Early stopping at epoch 280
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.681 ACC=0.688 | TEST f1_ma=0.599 ACC=0.613
# Early stopping at epoch 281
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.684 ACC=0.688 | TEST f1_ma=0.595 ACC=0.610
# Early stopping at epoch 269
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.696 ACC=0.702 | TEST f1_ma=0.596 ACC=0.610
# Early stopping at epoch 269
# [hybrid_equal_knn   k= 4 | h=128 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.697 ACC=0.703 | TEST f1_ma=0.584 ACC=0.605
# ...
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.667 ACC=0.673 | TEST f1_ma=0.594 ACC=0.612
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.659 ACC=0.667 | TEST f1_ma=0.605 ACC=0.623
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.659 ACC=0.665 | TEST f1_ma=0.597 ACC=0.617
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.665 ACC=0.673 | TEST f1_ma=0.593 ACC=0.612
# Early stopping at epoch 745
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.665 ACC=0.665 | TEST f1_ma=0.601 ACC=0.613
# Early stopping at epoch 433
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.665 ACC=0.665 | TEST f1_ma=0.605 ACC=0.618
# Early stopping at epoch 345
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.667 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 776
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.630 ACC=0.650 | TEST f1_ma=0.585 ACC=0.615
# Early stopping at epoch 351
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.615 ACC=0.635 | TEST f1_ma=0.575 ACC=0.607
# Early stopping at epoch 599
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.627 ACC=0.648 | TEST f1_ma=0.572 ACC=0.605
# Early stopping at epoch 643
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.487 ACC=0.553 | TEST f1_ma=0.437 ACC=0.517
# Early stopping at epoch 453
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.501 ACC=0.563 | TEST f1_ma=0.435 ACC=0.513
# Early stopping at epoch 515
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.486 ACC=0.552 | TEST f1_ma=0.447 ACC=0.523
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.660 ACC=0.672 | TEST f1_ma=0.598 ACC=0.620
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.642 ACC=0.653 | TEST f1_ma=0.575 ACC=0.600
# Early stopping at epoch 206
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.664 ACC=0.673 | TEST f1_ma=0.585 ACC=0.608
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.647 ACC=0.657 | TEST f1_ma=0.589 ACC=0.610
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.655 ACC=0.665 | TEST f1_ma=0.580 ACC=0.607
# Early stopping at epoch 205
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adam  drop=0.5] VAL f1_ma=0.655 ACC=0.665 | TEST f1_ma=0.578 ACC=0.603
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.662 ACC=0.663 | TEST f1_ma=0.600 ACC=0.612
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.675 ACC=0.675 | TEST f1_ma=0.597 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.671 ACC=0.668 | TEST f1_ma=0.607 ACC=0.617
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.658 ACC=0.658 | TEST f1_ma=0.602 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.667 ACC=0.667 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.661 ACC=0.662 | TEST f1_ma=0.612 ACC=0.622
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.653 ACC=0.653 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.665 ACC=0.663 | TEST f1_ma=0.588 ACC=0.603
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.666 ACC=0.663 | TEST f1_ma=0.600 ACC=0.613
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.653 ACC=0.653 | TEST f1_ma=0.596 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.668 ACC=0.667 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.677 ACC=0.673 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.662 ACC=0.658 | TEST f1_ma=0.605 ACC=0.615
# Early stopping at epoch 203
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.660 ACC=0.658 | TEST f1_ma=0.603 ACC=0.615
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.669 ACC=0.667 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.664 ACC=0.663 | TEST f1_ma=0.598 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.666 ACC=0.665 | TEST f1_ma=0.600 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.667 ACC=0.667 | TEST f1_ma=0.607 ACC=0.617
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.671 ACC=0.668 | TEST f1_ma=0.603 ACC=0.617
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.662 ACC=0.662 | TEST f1_ma=0.590 ACC=0.603
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.673 ACC=0.672 | TEST f1_ma=0.602 ACC=0.612
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.668 ACC=0.667 | TEST f1_ma=0.601 ACC=0.610
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.676 ACC=0.675 | TEST f1_ma=0.606 ACC=0.615
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.672 ACC=0.672 | TEST f1_ma=0.596 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.669 ACC=0.667 | TEST f1_ma=0.612 ACC=0.622
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.667 ACC=0.665 | TEST f1_ma=0.596 ACC=0.607
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.670 ACC=0.667 | TEST f1_ma=0.603 ACC=0.613
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.671 ACC=0.672 | TEST f1_ma=0.606 ACC=0.618
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.675 ACC=0.673 | TEST f1_ma=0.612 ACC=0.620
# Early stopping at epoch 204
# [hybrid_equal_knn   k= 7 | h=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.677 ACC=0.675 | TEST f1_ma=0.599 ACC=0.610
# Early stopping at epoch 1066
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.668 ACC=0.668 | TEST f1_ma=0.603 ACC=0.617
# Early stopping at epoch 1202
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.667 ACC=0.667 | TEST f1_ma=0.601 ACC=0.613
# Early stopping at epoch 1606
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.668 ACC=0.668 | TEST f1_ma=0.602 ACC=0.615
# Early stopping at epoch 1397
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.627 ACC=0.648 | TEST f1_ma=0.582 ACC=0.612
# Early stopping at epoch 1389
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.631 ACC=0.652 | TEST f1_ma=0.574 ACC=0.605
# Early stopping at epoch 1232
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.629 ACC=0.650 | TEST f1_ma=0.581 ACC=0.610
# Early stopping at epoch 1197
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.433 ACC=0.513 | TEST f1_ma=0.409 ACC=0.500
# Early stopping at epoch 1457
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.430 ACC=0.513 | TEST f1_ma=0.403 ACC=0.497
# Early stopping at epoch 1710
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.434 ACC=0.517 | TEST f1_ma=0.408 ACC=0.500
# Early stopping at epoch 267
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.652 ACC=0.662 | TEST f1_ma=0.578 ACC=0.602
# Early stopping at epoch 266
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.659 ACC=0.667 | TEST f1_ma=0.575 ACC=0.602
# Early stopping at epoch 266
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.657 ACC=0.665 | TEST f1_ma=0.581 ACC=0.605
# Early stopping at epoch 257
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.661 ACC=0.668 | TEST f1_ma=0.585 ACC=0.612
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.661 ACC=0.670 | TEST f1_ma=0.586 ACC=0.612
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.653 ACC=0.663 | TEST f1_ma=0.585 ACC=0.610
# Early stopping at epoch 1155
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.667 | TEST f1_ma=0.603 ACC=0.617
# Early stopping at epoch 1324
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.662 ACC=0.662 | TEST f1_ma=0.606 ACC=0.618
# Early stopping at epoch 1295
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.667 | TEST f1_ma=0.607 ACC=0.620
# Early stopping at epoch 1350
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.632 ACC=0.652 | TEST f1_ma=0.581 ACC=0.612
# Early stopping at epoch 1296
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.630 ACC=0.652 | TEST f1_ma=0.577 ACC=0.608
# Early stopping at epoch 1160
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.625 ACC=0.648 | TEST f1_ma=0.574 ACC=0.607
# Early stopping at epoch 1364
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.437 ACC=0.520 | TEST f1_ma=0.408 ACC=0.500
# Early stopping at epoch 1562
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.436 ACC=0.517 | TEST f1_ma=0.403 ACC=0.497
# Early stopping at epoch 1480
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.436 ACC=0.515 | TEST f1_ma=0.410 ACC=0.500
# Early stopping at epoch 266
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.645 ACC=0.655 | TEST f1_ma=0.565 ACC=0.593
# Early stopping at epoch 265
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.666 ACC=0.673 | TEST f1_ma=0.584 ACC=0.610
# Early stopping at epoch 267
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.663 ACC=0.672 | TEST f1_ma=0.570 ACC=0.598
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.661 ACC=0.667 | TEST f1_ma=0.588 ACC=0.612
# Early stopping at epoch 256
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.663 ACC=0.670 | TEST f1_ma=0.582 ACC=0.603
# Early stopping at epoch 255
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.665 ACC=0.672 | TEST f1_ma=0.584 ACC=0.605
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.671 ACC=0.668 | TEST f1_ma=0.592 ACC=0.602
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.674 ACC=0.670 | TEST f1_ma=0.587 ACC=0.595
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.672 ACC=0.668 | TEST f1_ma=0.586 ACC=0.597
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.682 ACC=0.678 | TEST f1_ma=0.586 ACC=0.593
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.673 ACC=0.670 | TEST f1_ma=0.598 ACC=0.605
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.668 ACC=0.663 | TEST f1_ma=0.595 ACC=0.603
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.676 ACC=0.672 | TEST f1_ma=0.588 ACC=0.598
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.675 ACC=0.672 | TEST f1_ma=0.603 ACC=0.612
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.676 ACC=0.672 | TEST f1_ma=0.591 ACC=0.600
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.681 ACC=0.677 | TEST f1_ma=0.593 ACC=0.602
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.684 ACC=0.682 | TEST f1_ma=0.575 ACC=0.585
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.675 ACC=0.670 | TEST f1_ma=0.590 ACC=0.597
# Early stopping at epoch 235
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.673 ACC=0.670 | TEST f1_ma=0.591 ACC=0.602
# Early stopping at epoch 240
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.686 ACC=0.682 | TEST f1_ma=0.595 ACC=0.605
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.3] VAL f1_ma=0.677 ACC=0.673 | TEST f1_ma=0.595 ACC=0.603
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.680 ACC=0.675 | TEST f1_ma=0.594 ACC=0.605
# Early stopping at epoch 236
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.669 ACC=0.665 | TEST f1_ma=0.586 ACC=0.595
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.677 ACC=0.673 | TEST f1_ma=0.581 ACC=0.590
# Early stopping at epoch 239
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.673 ACC=0.670 | TEST f1_ma=0.599 ACC=0.607
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.671 ACC=0.667 | TEST f1_ma=0.593 ACC=0.602
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.682 ACC=0.678 | TEST f1_ma=0.592 ACC=0.602
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.673 ACC=0.670 | TEST f1_ma=0.591 ACC=0.600
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.677 ACC=0.673 | TEST f1_ma=0.589 ACC=0.598
# Early stopping at epoch 239
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.673 ACC=0.670 | TEST f1_ma=0.600 ACC=0.610
# Early stopping at epoch 239
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.672 ACC=0.668 | TEST f1_ma=0.602 ACC=0.610
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.667 ACC=0.665 | TEST f1_ma=0.587 ACC=0.598
# Early stopping at epoch 238
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.674 ACC=0.670 | TEST f1_ma=0.593 ACC=0.603
# Early stopping at epoch 239
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.674 ACC=0.670 | TEST f1_ma=0.593 ACC=0.602
# Early stopping at epoch 237
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.677 ACC=0.673 | TEST f1_ma=0.589 ACC=0.600
# Early stopping at epoch 240
# [hybrid_equal_knn   k= 7 | h=256 lr=0.001  opt=adamw drop=0.5] VAL f1_ma=0.669 ACC=0.665 | TEST f1_ma=0.606 ACC=0.612
#
# Grid search finished in 71.7 min

# %%
test_m
# Out:
# {'test_acc': 0.575,
#  'test_prec_w': 0.5857437114425522,
#  'test_rec_w': 0.575,
#  'test_f1_w': 0.5680161205628644,
#  'test_prec_mi': 0.575,
#  'test_rec_mi': 0.575,
#  'test_f1_mi': 0.575,
#  'test_prec_ma': 0.5857437114425521,
#  'test_rec_ma': 0.575,
#  'test_f1_ma': 0.5680161205628644,
#  'test_roc_w': 0.9203189655172413,
#  'test_roc_mi': 0.9226358237547894,
#  'test_roc_ma': 0.9203189655172413}

# %%
print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print(classification_report(y_true, y_pred))
#
# NameError: name 'y_true' is not defined
