# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
#from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import os
import itertools
import numpy as np
import pandas as pd
from itertools import product
from scipy.sparse import coo_matrix
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from itertools import product
import numpy as np, torch
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from torch_geometric.utils import to_undirected, add_self_loops

from build_graph_data import *

# %%
partition = 100

# %% [markdown]
# # Read Data

# %%
path = f'../../data/top30groups/noGeographic/combined/combined{partition}.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')
#traindata, valdata, testdata = handle_leakage(df)

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'gname'],
#       dtype='object')

# %% [markdown]
# # Create train graph

# %%
# Creating df of the feature subset for node creation
#def create_node_dataframe(data, node_features, label_column='gname'):
 #   relevant_data = data[node_features + [label_column]].copy()
#    relevant_data['combination'] = list(zip(*(relevant_data[feat] for feat in node_features)))
 #   df_unique = relevant_data.drop_duplicates(subset=['combination'], keep='first').reset_index(drop=True)
  #  return df_unique[['combination', label_column]]

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

# %%
def induced_subgraph(edge_index, keep_mask):
    keep = keep_mask.nonzero(as_tuple=False).view(-1)
    # map old -> new ids
    new_id = -torch.ones(keep_mask.size(0), dtype=torch.long, device=edge_index.device)
    new_id[keep] = torch.arange(keep.numel(), device=edge_index.device)
    src, dst = edge_index
    m = keep_mask[src] & keep_mask[dst]
    ei = edge_index[:, m]
    ei = torch.stack([new_id[ei[0]], new_id[ei[1]]], dim=0)
    return ei, new_id

# %%
import itertools, time, numpy as np, pandas as pd, torch, torch.nn.functional as F
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from torch_geometric.nn import GCNConv

# ----------------------------
# Model with dropout
# ----------------------------
class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, h1, h2, num_classes, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, h1)
        self.conv2 = GCNConv(h1, h2)
        self.conv3 = GCNConv(h2, num_classes)
        self.dropout = torch.nn.Dropout(p=dropout)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index)
        return x

#[[radius k=20 | h= 64 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.552 ACC=0.545 | TEST f1_ma=0.471 ACC=0.478
#[knn                k=24 | h=512 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.532 ACC=0.537 | TEST f1_ma=0.474 ACC=0.482
#[hybrid_equal_knn   k=23 | h= 32 lr=0.001  opt=adam  drop=0.3] VAL f1_ma=0.517 ACC=0.523 | TEST f1_ma=0.481 ACC=0.487
#[adaptive           k=23 | h= 32 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.542 ACC=0.545 | TEST f1_ma=0.482 ACC=0.488
#[knn                k=23 | h=256 lr=0.01   opt=adam  drop=0.3] VAL f1_ma=0.534 ACC=0.540 | TEST f1_ma=0.485 ACC=0.488
#[knn                k=23 | h= 64 lr=0.001  opt=adam  drop=0.5] VAL f1_ma=0.536 ACC=0.543 | TEST f1_ma=0.479 ACC=0.488



# ----------------------------
# Metrics helper
# ----------------------------
def compute_all_metrics(y_true_np, logits_np, n_class):
    """Return dict of acc + P/R/F1 (weighted/micro/macro) + OVR ROC-AUC (w/mi/ma)."""
    y_pred_np = logits_np.argmax(axis=1)
    proba_np  = torch.softmax(torch.from_numpy(logits_np), dim=1).numpy()

    labels = list(range(n_class))
    out = {}
    # Accuracy
    out['acc'] = accuracy_score(y_true_np, y_pred_np)
    # Weighted
    out['prec_w'] = precision_score(y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['rec_w']  = recall_score(  y_true_np, y_pred_np, average='weighted', zero_division=0)
    out['f1_w']   = f1_score(      y_true_np, y_pred_np, average='weighted')
    # Micro
    out['prec_mi'] = precision_score(y_true_np, y_pred_np, average='micro', zero_division=0)
    out['rec_mi']  = recall_score(  y_true_np, y_pred_np, average='micro',   zero_division=0)
    out['f1_mi']   = f1_score(      y_true_np, y_pred_np, average='micro')
    # Macro
    out['prec_ma'] = precision_score(y_true_np, y_pred_np, average='macro', zero_division=0)
    out['rec_ma']  = recall_score(  y_true_np, y_pred_np, average='macro',  zero_division=0)
    out['f1_ma']   = f1_score(      y_true_np, y_pred_np, average='macro')

    # OVR ROC-AUCs (robust if some classes missing in split)
    # If only one class present in y_true, roc_auc_score will raise; guard it.
    def safe_roc(avg):
        try:
            return roc_auc_score(y_true_np, proba_np, multi_class='ovr', average=avg, labels=labels)
        except Exception:
            return float('nan')

    out['roc_w']  = safe_roc('weighted')
    out['roc_mi'] = safe_roc('micro')
    out['roc_ma'] = safe_roc('macro')
    return out

# ----------------------------
# Hyperparameters to sweep
# ----------------------------
"""
k           : 7
h1          : 128
h2          : 128
optimizer   : adamw
lr          : 0.01
dropout     : 0.5
wd          : 0.12
fd          : 0
"""
h1_dims       = [64, 128, 256]
h2_dims       = [64, 128, 256]
lrs           = [0.01]
optimizers    = ["adamw"]
dropouts      = [0.1,0.3, 0.5]
num_epochs    = 2000
patience = 200
weight_decays  = [5e-4, 5e-3, 0.1]
feat_decays = [0, 0.1, 0.2]
seed          = 42
device        = "cuda"

torch.manual_seed(seed); np.random.seed(seed)

# ----------------------------
# Data split (temporal)
# ----------------------------

# Graph options
edge_modes = ["hybrid_equal_knn"]
#edge_modes = ["equal"]
k_values   = list(range(5, 9))

node_feature_cols = None
edge_feature_cols = ['attacktype1', 'target1']  # used for 'equal' part; fine to keep for others

def make_optimizer(name, params, lr, wd):
    name = name.lower()
    if name == "adam":  return torch.optim.Adam(params, lr=lr, weight_decay=wd)
    if name == "adamw": return torch.optim.AdamW(params, lr=lr, weight_decay=wd)
    raise ValueError(f"Unknown optimizer: {name}")

def train_one_model(x, edge_index, y, train_mask, val_mask, num_classes,
                    h1, h2, lr, opt_name, dropout, max_epochs=num_epochs, patience=patience, wd=5e-4, fd=0):
    model = PyTorchGCN(in_channels=x.size(1),
                       h1=h1,
                       h2=h2,
                       num_classes=num_classes,
                       dropout=dropout).to(device)
    opt = make_optimizer(opt_name, model.parameters(), lr, wd)
    best_state, best_val, patience_left = None, float('inf'), patience

    for epoch in range(1, max_epochs + 1):
        model.train(); opt.zero_grad()
        x_drop = F.dropout(x, p=fd, training=model.training)
        out = model(x, edge_index)
        loss_train = F.cross_entropy(out[train_mask], y[train_mask])
        loss_train.backward(); opt.step()

        model.eval()
        with torch.no_grad():
            out = model(x, edge_index)
            loss_val = F.cross_entropy(out[val_mask], y[val_mask])

        if loss_val.item() < best_val - 1e-6:
            best_val = loss_val.item()
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            patience_left = patience
        else:
            patience_left -= 1
            if patience_left <= 0:
                break

    if best_state is not None:
        model.load_state_dict({k: v.to(device) for k, v in best_state.items()})

    # Validation metrics (selection)
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_val_true = y[val_mask].detach().cpu().numpy()
    y_val_logits = logits[val_mask].detach().cpu().numpy()
    val_metrics = compute_all_metrics(y_val_true, y_val_logits, num_classes)
    val_metrics['val_loss'] = best_val
    return model, val_metrics

def split_metrics(model, x, edge_index, y, mask, num_classes, split_name):
    model.eval()
    with torch.no_grad():
        logits = model(x, edge_index)
    y_true = y[mask].detach().cpu().numpy()
    logits_np = logits[mask].detach().cpu().numpy()
    mets = compute_all_metrics(y_true, logits_np, num_classes)
    return {f"{split_name}_{k}": v for k, v in mets.items()}

# ----------------------------
# Grid search
# ----------------------------


partitions = [200, 300, 478]

for p in partitions:
    path = f'../../data/top30groups/noGeographic/combined/combined{p}.csv'
    df_all = pd.read_csv(path, encoding='ISO-8859-1')
    train_idx, val_idx, test_idx = temporal_row_split(df_all, label_column='gname', train_ratio=0.6, val_ratio=0.2)
    results = []
    best_row = None
    best_score = -1.0  # we’ll select by val_macro_F1
    node_feature_cols=[c for c in df_all.columns if c != 'gname']
    equal_cols = edge_feature_cols
    best_score = -1.0 
    t_all = time.time()
    for k in k_values:
        for edge_mode in edge_modes:
            # A) fit scalers ON TRAIN ONLY
            node_scaler, edge_scaler = fit_scalers(
                df_all,
                node_feature_cols=node_feature_cols,
                edge_feature_cols=edge_feature_cols,
                train_idx=train_idx
            )

            # B) build TRAIN+VAL graph directly (neighbors computed within this set)
            trainval_idx = np.concatenate([train_idx, val_idx])
            x_tv, ei_tv, y_tv, _, _, _, label_index, chosen_radius = build_graph_on_index_set(
                df_all=df_all,
                idx_subset=trainval_idx,
                node_feature_cols=node_feature_cols,
                edge_feature_cols=edge_feature_cols,
                node_scaler=node_scaler, edge_scaler=edge_scaler,
                label_column='gname',
                train_idx=train_idx, val_idx=val_idx, test_idx=None,
                edge_mode=edge_mode, equal_cols=equal_cols, k=k, radius=None  # radius will be auto-picked from TRAIN in this set
            )

            # masks relative to the TRAIN+VAL subgraph:
            # (build them by mapping global indices -> local positions)
            pos_tv = {rid:i for i, rid in enumerate(trainval_idx)}
            train_mask_sub = torch.zeros(x_tv.size(0), dtype=torch.bool, device='cuda')
            val_mask_sub   = torch.zeros_like(train_mask_sub)
            for rid in train_idx: train_mask_sub[pos_tv[rid]] = True
            for rid in val_idx:   val_mask_sub[pos_tv[rid]]   = True

            num_classes = len(label_index)

            for h1, h2, lr, opt_name, dropout, wd, fd in itertools.product(h1_dims, h2_dims, lrs, optimizers, dropouts, weight_decays, feat_decays):
                t0 = time.time()
                model, val_m = train_one_model(
                    x_tv, ei_tv, y_tv, train_mask_sub, val_mask_sub, num_classes,
                    h1=h1, h2=h2, lr=lr, opt_name=opt_name, dropout=dropout,
                    max_epochs=num_epochs, patience=patience, wd=wd, fd=fd
                )

                # C) build FULL graph (train+val+test) using SAME scalers and SAME edge params
                #    - For radius modes, reuse chosen_radius so ε doesn’t change between train and test graphs.
                x_full, ei_full, y_full, train_mask_full, val_mask_full, test_mask_full, _, _ = build_graph_on_index_set(
                    df_all=df_all,
                    idx_subset=df_all.index.to_numpy(),  # full
                    node_feature_cols=node_feature_cols,
                    edge_feature_cols=edge_feature_cols,
                    node_scaler=node_scaler, edge_scaler=edge_scaler,
                    label_column='gname',
                    train_idx=train_idx, val_idx=val_idx, test_idx=test_idx,
                    edge_mode=edge_mode, equal_cols=equal_cols, k=k, radius=chosen_radius
                )

                # TESTA DENNA

                # (Optional stricter inference: one-way edges train→test only)
                ei_infer = make_infer_edge_index_strict(ei_full, train_mask_full | val_mask_full, test_mask_full)
                ei_infer, _ = add_self_loops(ei_infer, num_nodes=x_full.size(0))
                test_m = split_metrics(model, x_full, ei_infer, y_full, test_mask_full, num_classes, "test")

                # Standard transductive inference on full graph:
                #test_m = split_metrics(model, x_full, ei_full, y_full, test_mask_full, num_classes, "test")
                # Test split metrics
                #test_m = split_metrics(model, x, edge_index, y, test_mask, num_classes, split_name="test")
                elapsed = time.time() - t0

                row = dict(
                    k=k, edge_mode=edge_mode, h1=h1, h2=h2, lr=lr, wd=wd, fd=fd,
                    optimizer=opt_name, dropout=dropout, time_sec=elapsed,
                    train_nodes=int(train_mask_full.sum().item()),
                    val_nodes=int(val_mask_full.sum().item()),
                    test_nodes=int(test_mask_full.sum().item()),
                )
                # attach val and test metrics
                for kmet, vmet in val_m.items():
                    row[f"val_{kmet}"] = vmet
                row.update(test_m)

                results.append(row)

                # Selection criterion: validation macro-F1
                sel = val_m['f1_ma']
                if sel > best_score:
                    best_score = sel
                    best_row = row.copy()

                print(f"[{edge_mode:18s} k={k:2d} | h1={h1:3d}  h2={h2:3d} lr={lr:<6} opt={opt_name:<5} drop={dropout}] "
                    f"VAL f1_ma={val_m['f1_ma']:.3f} ACC={val_m['acc']:.3f} | "
                    f"TEST f1_ma={test_m['test_f1_ma']:.3f} ACC={test_m['test_acc']:.3f}")

    total_min = (time.time() - t_all)/60
    print(f"\nGrid search finished in {total_min:.1f} min")

    #results_df = pd.DataFrame(results)

    # ----------------------------
    # Save all runs + best summary
    # ----------------------------
    #results_csv = f"grid_search_results{partition}.csv"
    #results_df.to_csv(results_csv, index=False)

    best_txt = f"best_run_{p}.txt"
    with open(best_txt, "w") as f:
        f.write("=== Best configuration (by validation macro-F1) ===\n")
        f.write(f"edge_mode   : {best_row['edge_mode']}\n")
        f.write(f"k           : {best_row['k']}\n")
        f.write(f"h1          : {best_row['h1']}\n")
        f.write(f"h2          : {best_row['h2']}\n")
        f.write(f"optimizer   : {best_row['optimizer']}\n")
        f.write(f"lr          : {best_row['lr']}\n")
        f.write(f"dropout     : {best_row['dropout']}\n")
        f.write(f"wd          : {best_row['wd']}\n")
        f.write(f"fd          : {best_row['fd']}\n")
        f.write("\n--- Validation metrics ---\n")
        f.write(f"val_loss    : {best_row.get('val_val_loss', float('nan')):.6f}\n")
        f.write(f"val_acc     : {best_row.get('val_acc', float('nan')):.6f}\n")
        f.write(f"val_prec_w  : {best_row.get('val_prec_w', float('nan')):.6f}\n")
        f.write(f"val_rec_w   : {best_row.get('val_rec_w', float('nan')):.6f}\n")
        f.write(f"val_f1_w    : {best_row.get('val_f1_w', float('nan')):.6f}\n")
        f.write(f"val_prec_mi : {best_row.get('val_prec_mi', float('nan')):.6f}\n")
        f.write(f"val_rec_mi  : {best_row.get('val_rec_mi', float('nan')):.6f}\n")
        f.write(f"val_f1_mi   : {best_row.get('val_f1_mi', float('nan')):.6f}\n")
        f.write(f"val_prec_ma : {best_row.get('val_prec_ma', float('nan')):.6f}\n")
        f.write(f"val_rec_ma  : {best_row.get('val_rec_ma', float('nan')):.6f}\n")
        f.write(f"val_f1_ma   : {best_row.get('val_f1_ma', float('nan')):.6f}\n")
        f.write(f"val_roc_w   : {best_row.get('val_roc_w', float('nan')):.6f}\n")
        f.write(f"val_roc_mi  : {best_row.get('val_roc_mi', float('nan')):.6f}\n")
        f.write(f"val_roc_ma  : {best_row.get('val_roc_ma', float('nan')):.6f}\n")
        f.write("\n--- Test metrics ---\n")
        f.write(f"test_acc    : {best_row.get('test_acc', float('nan')):.6f}\n")
        f.write(f"test_prec_w : {best_row.get('test_prec_w', float('nan')):.6f}\n")
        f.write(f"test_rec_w  : {best_row.get('test_rec_w', float('nan')):.6f}\n")
        f.write(f"test_f1_w   : {best_row.get('test_f1_w', float('nan')):.6f}\n")
        f.write(f"test_prec_mi: {best_row.get('test_prec_mi', float('nan')):.6f}\n")
        f.write(f"test_rec_mi : {best_row.get('test_rec_mi', float('nan')):.6f}\n")
        f.write(f"test_f1_mi  : {best_row.get('test_f1_mi', float('nan')):.6f}\n")
        f.write(f"test_prec_ma: {best_row.get('test_prec_ma', float('nan')):.6f}\n")
        f.write(f"test_rec_ma : {best_row.get('test_rec_ma', float('nan')):.6f}\n")
        f.write(f"test_f1_ma  : {best_row.get('test_f1_ma', float('nan')):.6f}\n")
        f.write(f"test_roc_w  : {best_row.get('test_roc_w', float('nan')):.6f}\n")
        f.write(f"test_roc_mi : {best_row.get('test_roc_mi', float('nan')):.6f}\n")
        f.write(f"test_roc_ma : {best_row.get('test_roc_ma', float('nan')):.6f}\n")
        f.write("\n--- Data sizes ---\n")
        f.write(f"train_nodes : {best_row['train_nodes']}\n")
        f.write(f"val_nodes   : {best_row['val_nodes']}\n")
        f.write(f"test_nodes  : {best_row['test_nodes']}\n")
        #f.write(f"\nCSV of all runs: {results_csv}\n")

#print(f"Saved all runs to {results_csv} and best summary to {best_txt}")
# Out:
# /home/jovyan/MEX0512/GTD_2025/GCN_testing/2layer_noGeo/build_graph_data.py:175: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   ei_knn = torch.tensor([rows, cols], dtype=torch.long, device=device)
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.403 ACC=0.414
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.570 | TEST f1_ma=0.409 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.552 ACC=0.556 | TEST f1_ma=0.396 ACC=0.406
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.559 | TEST f1_ma=0.398 ACC=0.409
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.568 | TEST f1_ma=0.400 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.408 ACC=0.418
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.407 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.576 | TEST f1_ma=0.402 ACC=0.416
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.578 ACC=0.581 | TEST f1_ma=0.425 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.566 ACC=0.567 | TEST f1_ma=0.418 ACC=0.430
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.580 ACC=0.582 | TEST f1_ma=0.423 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.584 ACC=0.585 | TEST f1_ma=0.426 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.570 | TEST f1_ma=0.406 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.562 ACC=0.565 | TEST f1_ma=0.410 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.417 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.570 ACC=0.572 | TEST f1_ma=0.424 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.426 ACC=0.439
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.570 | TEST f1_ma=0.425 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.569 ACC=0.570 | TEST f1_ma=0.411 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.570 ACC=0.573 | TEST f1_ma=0.436 ACC=0.447
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.562 ACC=0.565 | TEST f1_ma=0.428 ACC=0.435
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.548 ACC=0.552 | TEST f1_ma=0.410 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.564 ACC=0.568 | TEST f1_ma=0.423 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.576 | TEST f1_ma=0.416 ACC=0.425
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.422 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.568 ACC=0.568 | TEST f1_ma=0.423 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.597 ACC=0.598 | TEST f1_ma=0.435 ACC=0.446
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.553 | TEST f1_ma=0.401 ACC=0.414
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.566 ACC=0.572 | TEST f1_ma=0.406 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.571 | TEST f1_ma=0.409 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.557 ACC=0.558 | TEST f1_ma=0.395 ACC=0.409
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.561 ACC=0.558 | TEST f1_ma=0.404 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.570 | TEST f1_ma=0.429 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.561 | TEST f1_ma=0.429 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.576 | TEST f1_ma=0.438 ACC=0.446
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.571 ACC=0.573 | TEST f1_ma=0.397 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.569 | TEST f1_ma=0.414 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.569 | TEST f1_ma=0.413 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.553 ACC=0.556 | TEST f1_ma=0.408 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.415 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.416 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.418 ACC=0.425
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.572 | TEST f1_ma=0.427 ACC=0.435
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.570 | TEST f1_ma=0.423 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.591 ACC=0.593 | TEST f1_ma=0.413 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.429 ACC=0.440
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.556 ACC=0.559 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.554 ACC=0.558 | TEST f1_ma=0.419 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.575 | TEST f1_ma=0.425 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.563 ACC=0.562 | TEST f1_ma=0.429 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.558 ACC=0.560 | TEST f1_ma=0.416 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.559 ACC=0.560 | TEST f1_ma=0.411 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.424 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.576 ACC=0.578 | TEST f1_ma=0.435 ACC=0.443
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.550 ACC=0.554 | TEST f1_ma=0.420 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.568 | TEST f1_ma=0.413 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.558 ACC=0.560 | TEST f1_ma=0.399 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.556 ACC=0.557 | TEST f1_ma=0.404 ACC=0.419
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.555 ACC=0.559 | TEST f1_ma=0.410 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.571 | TEST f1_ma=0.410 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.562 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.406 ACC=0.416
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.577 ACC=0.577 | TEST f1_ma=0.412 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.568 ACC=0.574 | TEST f1_ma=0.417 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.564 ACC=0.563 | TEST f1_ma=0.411 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.563 ACC=0.562 | TEST f1_ma=0.418 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.559 ACC=0.560 | TEST f1_ma=0.414 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.555 ACC=0.555 | TEST f1_ma=0.406 ACC=0.413
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.576 | TEST f1_ma=0.415 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.579 ACC=0.581 | TEST f1_ma=0.424 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.571 | TEST f1_ma=0.404 ACC=0.416
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.575 ACC=0.578 | TEST f1_ma=0.405 ACC=0.415
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.438 ACC=0.448
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.557 ACC=0.559 | TEST f1_ma=0.430 ACC=0.439
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.555 ACC=0.560 | TEST f1_ma=0.418 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.569 | TEST f1_ma=0.407 ACC=0.411
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.574 ACC=0.573 | TEST f1_ma=0.425 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.569 ACC=0.570 | TEST f1_ma=0.430 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.440 ACC=0.446
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.562 ACC=0.565 | TEST f1_ma=0.414 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.578 ACC=0.579 | TEST f1_ma=0.411 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.572 | TEST f1_ma=0.411 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.562 | TEST f1_ma=0.418 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.419 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.427 ACC=0.436
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.423 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.559 | TEST f1_ma=0.413 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.564 | TEST f1_ma=0.404 ACC=0.413
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.571 | TEST f1_ma=0.426 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.395 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.560 ACC=0.563 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.561 ACC=0.559 | TEST f1_ma=0.408 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.574 ACC=0.579 | TEST f1_ma=0.417 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.570 | TEST f1_ma=0.422 ACC=0.436
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.552 ACC=0.552 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.554 ACC=0.554 | TEST f1_ma=0.412 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.570 | TEST f1_ma=0.429 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.559 ACC=0.560 | TEST f1_ma=0.412 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.559 ACC=0.560 | TEST f1_ma=0.400 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.569 ACC=0.572 | TEST f1_ma=0.414 ACC=0.425
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.438 ACC=0.448
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.563 ACC=0.564 | TEST f1_ma=0.408 ACC=0.416
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.436 ACC=0.448
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.563 ACC=0.566 | TEST f1_ma=0.425 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.565 ACC=0.566 | TEST f1_ma=0.416 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.581 ACC=0.583 | TEST f1_ma=0.424 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.566 ACC=0.566 | TEST f1_ma=0.433 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.590 ACC=0.592 | TEST f1_ma=0.444 ACC=0.454
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.563 ACC=0.563 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.558 ACC=0.561 | TEST f1_ma=0.413 ACC=0.425
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.584 ACC=0.586 | TEST f1_ma=0.413 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.540 ACC=0.542 | TEST f1_ma=0.390 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.424 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.561 | TEST f1_ma=0.421 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.571 | TEST f1_ma=0.428 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.561 ACC=0.562 | TEST f1_ma=0.404 ACC=0.415
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.556 ACC=0.558 | TEST f1_ma=0.406 ACC=0.418
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.549 ACC=0.553 | TEST f1_ma=0.412 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.563 ACC=0.566 | TEST f1_ma=0.404 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.572 ACC=0.571 | TEST f1_ma=0.420 ACC=0.430
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.566 ACC=0.566 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.562 ACC=0.567 | TEST f1_ma=0.392 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.554 ACC=0.557 | TEST f1_ma=0.410 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.570 ACC=0.572 | TEST f1_ma=0.413 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.425 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.422 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.579 ACC=0.579 | TEST f1_ma=0.427 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.555 ACC=0.555 | TEST f1_ma=0.412 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.576 ACC=0.578 | TEST f1_ma=0.447 ACC=0.453
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.577 | TEST f1_ma=0.427 ACC=0.436
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.562 ACC=0.562 | TEST f1_ma=0.426 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.591 ACC=0.591 | TEST f1_ma=0.430 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.416 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.579 ACC=0.578 | TEST f1_ma=0.418 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.573 | TEST f1_ma=0.406 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.574 | TEST f1_ma=0.410 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.566 ACC=0.565 | TEST f1_ma=0.409 ACC=0.415
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.553 | TEST f1_ma=0.410 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.572 | TEST f1_ma=0.418 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.557 | TEST f1_ma=0.410 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.568 | TEST f1_ma=0.414 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.571 ACC=0.573 | TEST f1_ma=0.400 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.416 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.576 ACC=0.577 | TEST f1_ma=0.411 ACC=0.418
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.576 ACC=0.578 | TEST f1_ma=0.413 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.558 ACC=0.557 | TEST f1_ma=0.413 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.550 ACC=0.553 | TEST f1_ma=0.419 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.552 ACC=0.552 | TEST f1_ma=0.394 ACC=0.401
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.408 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.575 | TEST f1_ma=0.420 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.561 ACC=0.560 | TEST f1_ma=0.401 ACC=0.410
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.572 ACC=0.571 | TEST f1_ma=0.409 ACC=0.419
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.568 ACC=0.566 | TEST f1_ma=0.420 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.564 ACC=0.562 | TEST f1_ma=0.412 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.556 ACC=0.561 | TEST f1_ma=0.409 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.569 ACC=0.572 | TEST f1_ma=0.423 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.554 ACC=0.558 | TEST f1_ma=0.396 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.573 | TEST f1_ma=0.424 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.568 ACC=0.570 | TEST f1_ma=0.415 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.559 ACC=0.560 | TEST f1_ma=0.411 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.586 ACC=0.590 | TEST f1_ma=0.429 ACC=0.440
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.550 ACC=0.552 | TEST f1_ma=0.417 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.566 | TEST f1_ma=0.402 ACC=0.412
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.553 | TEST f1_ma=0.396 ACC=0.404
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.554 | TEST f1_ma=0.404 ACC=0.412
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.549 ACC=0.551 | TEST f1_ma=0.404 ACC=0.414
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.554 ACC=0.555 | TEST f1_ma=0.413 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.569 | TEST f1_ma=0.397 ACC=0.408
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.561 ACC=0.564 | TEST f1_ma=0.415 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.571 | TEST f1_ma=0.392 ACC=0.405
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.567 | TEST f1_ma=0.410 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.409 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.553 ACC=0.552 | TEST f1_ma=0.407 ACC=0.421
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.571 | TEST f1_ma=0.407 ACC=0.413
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.567 | TEST f1_ma=0.401 ACC=0.412
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.571 | TEST f1_ma=0.425 ACC=0.436
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.551 ACC=0.549 | TEST f1_ma=0.407 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.567 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.558 ACC=0.561 | TEST f1_ma=0.420 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.556 ACC=0.557 | TEST f1_ma=0.424 ACC=0.430
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.571 ACC=0.573 | TEST f1_ma=0.404 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.561 ACC=0.562 | TEST f1_ma=0.416 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.553 ACC=0.555 | TEST f1_ma=0.439 ACC=0.448
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.568 ACC=0.568 | TEST f1_ma=0.397 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.570 ACC=0.570 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.576 ACC=0.578 | TEST f1_ma=0.423 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.565 ACC=0.569 | TEST f1_ma=0.419 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.574 | TEST f1_ma=0.438 ACC=0.449
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.558 ACC=0.564 | TEST f1_ma=0.418 ACC=0.425
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.549 ACC=0.550 | TEST f1_ma=0.400 ACC=0.409
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.555 ACC=0.556 | TEST f1_ma=0.402 ACC=0.413
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.561 ACC=0.564 | TEST f1_ma=0.395 ACC=0.407
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.557 ACC=0.557 | TEST f1_ma=0.421 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.553 ACC=0.552 | TEST f1_ma=0.409 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.557 ACC=0.562 | TEST f1_ma=0.404 ACC=0.414
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.556 ACC=0.558 | TEST f1_ma=0.416 ACC=0.429
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.557 ACC=0.562 | TEST f1_ma=0.416 ACC=0.429
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.546 ACC=0.547 | TEST f1_ma=0.408 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.425 ACC=0.435
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.558 ACC=0.559 | TEST f1_ma=0.411 ACC=0.418
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.556 ACC=0.559 | TEST f1_ma=0.395 ACC=0.406
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.544 ACC=0.547 | TEST f1_ma=0.396 ACC=0.406
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.425 ACC=0.435
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.577 ACC=0.576 | TEST f1_ma=0.414 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.417 ACC=0.427
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.566 ACC=0.570 | TEST f1_ma=0.416 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.561 ACC=0.562 | TEST f1_ma=0.415 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.576 ACC=0.577 | TEST f1_ma=0.428 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.579 ACC=0.581 | TEST f1_ma=0.421 ACC=0.429
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.574 ACC=0.576 | TEST f1_ma=0.412 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.549 ACC=0.553 | TEST f1_ma=0.421 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.548 ACC=0.552 | TEST f1_ma=0.410 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.561 ACC=0.566 | TEST f1_ma=0.424 ACC=0.437
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.559 ACC=0.562 | TEST f1_ma=0.425 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.565 ACC=0.567 | TEST f1_ma=0.415 ACC=0.429
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.554 ACC=0.558 | TEST f1_ma=0.401 ACC=0.414
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.551 ACC=0.555 | TEST f1_ma=0.411 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.558 | TEST f1_ma=0.405 ACC=0.418
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.563 ACC=0.562 | TEST f1_ma=0.409 ACC=0.420
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.562 | TEST f1_ma=0.420 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.555 ACC=0.556 | TEST f1_ma=0.397 ACC=0.409
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.563 ACC=0.565 | TEST f1_ma=0.396 ACC=0.408
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.560 ACC=0.559 | TEST f1_ma=0.414 ACC=0.424
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.563 ACC=0.568 | TEST f1_ma=0.418 ACC=0.428
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.572 | TEST f1_ma=0.408 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.566 ACC=0.568 | TEST f1_ma=0.415 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.558 ACC=0.559 | TEST f1_ma=0.413 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.560 ACC=0.563 | TEST f1_ma=0.403 ACC=0.417
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.561 ACC=0.562 | TEST f1_ma=0.424 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.571 | TEST f1_ma=0.411 ACC=0.422
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.568 ACC=0.571 | TEST f1_ma=0.419 ACC=0.432
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.574 ACC=0.573 | TEST f1_ma=0.427 ACC=0.433
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.554 ACC=0.555 | TEST f1_ma=0.406 ACC=0.412
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.565 ACC=0.568 | TEST f1_ma=0.419 ACC=0.430
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.572 ACC=0.575 | TEST f1_ma=0.424 ACC=0.438
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.578 | TEST f1_ma=0.421 ACC=0.431
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.557 ACC=0.562 | TEST f1_ma=0.428 ACC=0.439
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.561 ACC=0.564 | TEST f1_ma=0.409 ACC=0.423
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.563 ACC=0.562 | TEST f1_ma=0.416 ACC=0.426
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.570 ACC=0.568 | TEST f1_ma=0.422 ACC=0.434
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.563 ACC=0.562 | TEST f1_ma=0.403 ACC=0.412
# [hybrid_equal_knn   k= 5 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.410 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.585 ACC=0.585 | TEST f1_ma=0.408 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.562 | TEST f1_ma=0.400 ACC=0.410
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.588 ACC=0.588 | TEST f1_ma=0.417 ACC=0.421
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.572 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.580 ACC=0.581 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.578 ACC=0.579 | TEST f1_ma=0.388 ACC=0.397
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.575 ACC=0.575 | TEST f1_ma=0.417 ACC=0.423
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.574 ACC=0.576 | TEST f1_ma=0.414 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.566 ACC=0.568 | TEST f1_ma=0.415 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.574 ACC=0.574 | TEST f1_ma=0.444 ACC=0.448
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.572 | TEST f1_ma=0.408 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.575 | TEST f1_ma=0.406 ACC=0.413
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.586 ACC=0.589 | TEST f1_ma=0.430 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.575 ACC=0.577 | TEST f1_ma=0.414 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.584 ACC=0.584 | TEST f1_ma=0.431 ACC=0.433
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.575 ACC=0.578 | TEST f1_ma=0.393 ACC=0.400
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.418 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.572 ACC=0.571 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.584 ACC=0.586 | TEST f1_ma=0.436 ACC=0.443
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.570 ACC=0.567 | TEST f1_ma=0.414 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.576 ACC=0.577 | TEST f1_ma=0.430 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.581 ACC=0.580 | TEST f1_ma=0.425 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.588 ACC=0.588 | TEST f1_ma=0.438 ACC=0.443
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.577 | TEST f1_ma=0.414 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.596 ACC=0.598 | TEST f1_ma=0.442 ACC=0.447
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.586 ACC=0.584 | TEST f1_ma=0.426 ACC=0.431
# [hybrid_equal_knn   k= 6 | h1= 64  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.583 ACC=0.584 | TEST f1_ma=0.416 ACC=0.423
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.568 | TEST f1_ma=0.402 ACC=0.409
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.577 ACC=0.578 | TEST f1_ma=0.406 ACC=0.409
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.569 | TEST f1_ma=0.409 ACC=0.414
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.575 ACC=0.579 | TEST f1_ma=0.392 ACC=0.397
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.572 | TEST f1_ma=0.424 ACC=0.433
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.567 ACC=0.569 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.578 ACC=0.578 | TEST f1_ma=0.423 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.396 ACC=0.398
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.580 ACC=0.585 | TEST f1_ma=0.420 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.578 ACC=0.578 | TEST f1_ma=0.419 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.579 ACC=0.581 | TEST f1_ma=0.428 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.571 ACC=0.575 | TEST f1_ma=0.428 ACC=0.437
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.418 ACC=0.424
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.581 ACC=0.582 | TEST f1_ma=0.422 ACC=0.429
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.570 | TEST f1_ma=0.408 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.575 | TEST f1_ma=0.420 ACC=0.426
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.409 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.575 ACC=0.578 | TEST f1_ma=0.419 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.581 ACC=0.580 | TEST f1_ma=0.414 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.588 ACC=0.588 | TEST f1_ma=0.426 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.560 ACC=0.562 | TEST f1_ma=0.421 ACC=0.429
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.585 ACC=0.587 | TEST f1_ma=0.438 ACC=0.445
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.562 ACC=0.565 | TEST f1_ma=0.415 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.436 ACC=0.447
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.579 ACC=0.578 | TEST f1_ma=0.431 ACC=0.437
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.590 ACC=0.591 | TEST f1_ma=0.420 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1= 64  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.577 ACC=0.578 | TEST f1_ma=0.423 ACC=0.431
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.569 ACC=0.572 | TEST f1_ma=0.414 ACC=0.424
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.563 | TEST f1_ma=0.423 ACC=0.431
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.564 | TEST f1_ma=0.404 ACC=0.409
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.570 ACC=0.573 | TEST f1_ma=0.412 ACC=0.418
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.569 ACC=0.571 | TEST f1_ma=0.413 ACC=0.421
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.562 ACC=0.562 | TEST f1_ma=0.421 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.575 ACC=0.576 | TEST f1_ma=0.421 ACC=0.429
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.592 ACC=0.594 | TEST f1_ma=0.420 ACC=0.430
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.580 ACC=0.583 | TEST f1_ma=0.409 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.562 ACC=0.562 | TEST f1_ma=0.423 ACC=0.432
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.584 ACC=0.585 | TEST f1_ma=0.409 ACC=0.416
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.576 ACC=0.579 | TEST f1_ma=0.415 ACC=0.425
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.589 ACC=0.590 | TEST f1_ma=0.426 ACC=0.431
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.584 ACC=0.583 | TEST f1_ma=0.417 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.563 ACC=0.565 | TEST f1_ma=0.423 ACC=0.429
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.575 ACC=0.576 | TEST f1_ma=0.426 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.573 ACC=0.575 | TEST f1_ma=0.429 ACC=0.437
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.586 ACC=0.583 | TEST f1_ma=0.416 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.570 ACC=0.572 | TEST f1_ma=0.432 ACC=0.437
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.573 ACC=0.573 | TEST f1_ma=0.428 ACC=0.433
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.578 ACC=0.578 | TEST f1_ma=0.431 ACC=0.442
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.579 ACC=0.578 | TEST f1_ma=0.426 ACC=0.432
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.576 | TEST f1_ma=0.418 ACC=0.425
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.575 ACC=0.576 | TEST f1_ma=0.418 ACC=0.424
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.600 ACC=0.599 | TEST f1_ma=0.424 ACC=0.429
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.581 ACC=0.584 | TEST f1_ma=0.418 ACC=0.430
# [hybrid_equal_knn   k= 6 | h1= 64  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.572 ACC=0.578 | TEST f1_ma=0.425 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.565 ACC=0.569 | TEST f1_ma=0.404 ACC=0.413
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.563 ACC=0.565 | TEST f1_ma=0.393 ACC=0.403
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.578 ACC=0.577 | TEST f1_ma=0.407 ACC=0.412
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.569 | TEST f1_ma=0.410 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.587 ACC=0.585 | TEST f1_ma=0.419 ACC=0.425
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.568 | TEST f1_ma=0.416 ACC=0.423
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.573 ACC=0.575 | TEST f1_ma=0.402 ACC=0.408
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.583 ACC=0.586 | TEST f1_ma=0.405 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.406 ACC=0.412
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.577 ACC=0.582 | TEST f1_ma=0.417 ACC=0.424
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.564 ACC=0.563 | TEST f1_ma=0.423 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.582 ACC=0.585 | TEST f1_ma=0.427 ACC=0.432
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.583 ACC=0.581 | TEST f1_ma=0.423 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.561 ACC=0.558 | TEST f1_ma=0.414 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.565 ACC=0.567 | TEST f1_ma=0.409 ACC=0.414
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.589 ACC=0.588 | TEST f1_ma=0.410 ACC=0.418
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.570 ACC=0.573 | TEST f1_ma=0.398 ACC=0.411
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.568 ACC=0.568 | TEST f1_ma=0.427 ACC=0.432
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.592 ACC=0.591 | TEST f1_ma=0.419 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.571 ACC=0.571 | TEST f1_ma=0.432 ACC=0.440
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.584 ACC=0.584 | TEST f1_ma=0.431 ACC=0.437
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.583 | TEST f1_ma=0.440 ACC=0.446
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.584 ACC=0.584 | TEST f1_ma=0.417 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.569 ACC=0.568 | TEST f1_ma=0.420 ACC=0.428
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.577 ACC=0.580 | TEST f1_ma=0.425 ACC=0.433
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.590 ACC=0.591 | TEST f1_ma=0.424 ACC=0.424
# [hybrid_equal_knn   k= 6 | h1=128  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.577 ACC=0.578 | TEST f1_ma=0.416 ACC=0.426
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.570 | TEST f1_ma=0.401 ACC=0.411
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.572 ACC=0.574 | TEST f1_ma=0.413 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.568 ACC=0.570 | TEST f1_ma=0.406 ACC=0.415
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.569 ACC=0.572 | TEST f1_ma=0.425 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.575 ACC=0.577 | TEST f1_ma=0.415 ACC=0.421
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.583 ACC=0.584 | TEST f1_ma=0.401 ACC=0.409
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.559 ACC=0.559 | TEST f1_ma=0.422 ACC=0.426
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.574 ACC=0.575 | TEST f1_ma=0.423 ACC=0.430
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.572 ACC=0.573 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.567 ACC=0.568 | TEST f1_ma=0.411 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.579 ACC=0.579 | TEST f1_ma=0.414 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.569 ACC=0.569 | TEST f1_ma=0.425 ACC=0.430
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.580 ACC=0.581 | TEST f1_ma=0.411 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.566 ACC=0.568 | TEST f1_ma=0.411 ACC=0.417
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.557 ACC=0.561 | TEST f1_ma=0.411 ACC=0.419
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.557 ACC=0.556 | TEST f1_ma=0.421 ACC=0.427
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.570 ACC=0.573 | TEST f1_ma=0.417 ACC=0.425
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.563 ACC=0.567 | TEST f1_ma=0.414 ACC=0.422
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.564 ACC=0.566 | TEST f1_ma=0.430 ACC=0.434
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.582 | TEST f1_ma=0.429 ACC=0.438
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.586 ACC=0.584 | TEST f1_ma=0.425 ACC=0.432
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.582 ACC=0.579 | TEST f1_ma=0.413 ACC=0.420
# [hybrid_equal_knn   k= 6 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.567 ACC=0.567 | TEST f1_ma=0.413 ACC=0.420
# ...
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.609 ACC=0.608 | TEST f1_ma=0.441 ACC=0.446
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.608 ACC=0.605 | TEST f1_ma=0.442 ACC=0.447
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.612 ACC=0.611 | TEST f1_ma=0.438 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.609 ACC=0.609 | TEST f1_ma=0.419 ACC=0.429
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.601 ACC=0.599 | TEST f1_ma=0.435 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.610 ACC=0.610 | TEST f1_ma=0.418 ACC=0.428
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.606 ACC=0.604 | TEST f1_ma=0.443 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.599 ACC=0.601 | TEST f1_ma=0.432 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.616 ACC=0.616 | TEST f1_ma=0.447 ACC=0.452
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.612 ACC=0.613 | TEST f1_ma=0.455 ACC=0.460
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.607 | TEST f1_ma=0.438 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.598 ACC=0.598 | TEST f1_ma=0.444 ACC=0.450
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.610 ACC=0.611 | TEST f1_ma=0.436 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.601 ACC=0.601 | TEST f1_ma=0.431 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.609 ACC=0.609 | TEST f1_ma=0.453 ACC=0.458
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.612 ACC=0.611 | TEST f1_ma=0.434 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=128  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.611 ACC=0.610 | TEST f1_ma=0.450 ACC=0.453
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.603 ACC=0.604 | TEST f1_ma=0.432 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.606 ACC=0.601 | TEST f1_ma=0.419 ACC=0.425
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.595 ACC=0.596 | TEST f1_ma=0.426 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.606 ACC=0.606 | TEST f1_ma=0.436 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.597 ACC=0.599 | TEST f1_ma=0.412 ACC=0.418
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.602 ACC=0.603 | TEST f1_ma=0.422 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.608 ACC=0.605 | TEST f1_ma=0.434 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.604 ACC=0.603 | TEST f1_ma=0.425 ACC=0.431
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.606 ACC=0.607 | TEST f1_ma=0.429 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.606 ACC=0.607 | TEST f1_ma=0.428 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.604 ACC=0.604 | TEST f1_ma=0.439 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.610 ACC=0.609 | TEST f1_ma=0.440 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.600 ACC=0.599 | TEST f1_ma=0.433 ACC=0.438
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.607 ACC=0.604 | TEST f1_ma=0.436 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.595 ACC=0.596 | TEST f1_ma=0.426 ACC=0.435
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.605 ACC=0.603 | TEST f1_ma=0.426 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.614 ACC=0.613 | TEST f1_ma=0.438 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.600 ACC=0.601 | TEST f1_ma=0.428 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.601 ACC=0.602 | TEST f1_ma=0.428 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.610 | TEST f1_ma=0.439 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.601 ACC=0.601 | TEST f1_ma=0.441 ACC=0.446
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.610 ACC=0.609 | TEST f1_ma=0.441 ACC=0.447
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.613 ACC=0.611 | TEST f1_ma=0.428 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.603 ACC=0.602 | TEST f1_ma=0.438 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.602 ACC=0.601 | TEST f1_ma=0.441 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.606 ACC=0.606 | TEST f1_ma=0.433 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=128  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.597 ACC=0.597 | TEST f1_ma=0.427 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.589 ACC=0.589 | TEST f1_ma=0.429 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.610 ACC=0.611 | TEST f1_ma=0.442 ACC=0.450
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.607 ACC=0.607 | TEST f1_ma=0.436 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.607 ACC=0.605 | TEST f1_ma=0.433 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.604 ACC=0.603 | TEST f1_ma=0.435 ACC=0.443
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.603 ACC=0.602 | TEST f1_ma=0.421 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.605 ACC=0.604 | TEST f1_ma=0.415 ACC=0.422
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.609 ACC=0.608 | TEST f1_ma=0.444 ACC=0.452
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.604 ACC=0.603 | TEST f1_ma=0.431 ACC=0.437
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.596 ACC=0.595 | TEST f1_ma=0.434 ACC=0.437
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.602 ACC=0.601 | TEST f1_ma=0.429 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.613 ACC=0.613 | TEST f1_ma=0.420 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.602 ACC=0.601 | TEST f1_ma=0.437 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.600 ACC=0.598 | TEST f1_ma=0.429 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.610 ACC=0.610 | TEST f1_ma=0.433 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.615 ACC=0.616 | TEST f1_ma=0.444 ACC=0.452
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.601 ACC=0.603 | TEST f1_ma=0.428 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.611 ACC=0.610 | TEST f1_ma=0.424 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.603 ACC=0.605 | TEST f1_ma=0.420 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.601 ACC=0.599 | TEST f1_ma=0.425 ACC=0.432
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.602 ACC=0.602 | TEST f1_ma=0.416 ACC=0.425
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.596 ACC=0.595 | TEST f1_ma=0.432 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.608 | TEST f1_ma=0.435 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.611 ACC=0.609 | TEST f1_ma=0.431 ACC=0.438
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.602 ACC=0.603 | TEST f1_ma=0.428 ACC=0.437
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.613 ACC=0.613 | TEST f1_ma=0.439 ACC=0.443
# [hybrid_equal_knn   k= 8 | h1=256  h2= 64 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.607 ACC=0.607 | TEST f1_ma=0.432 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.605 ACC=0.602 | TEST f1_ma=0.433 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.599 ACC=0.601 | TEST f1_ma=0.424 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.598 ACC=0.598 | TEST f1_ma=0.426 ACC=0.433
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.602 ACC=0.600 | TEST f1_ma=0.424 ACC=0.431
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.603 ACC=0.600 | TEST f1_ma=0.436 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.599 ACC=0.599 | TEST f1_ma=0.414 ACC=0.423
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.596 ACC=0.599 | TEST f1_ma=0.421 ACC=0.432
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.596 ACC=0.598 | TEST f1_ma=0.436 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.609 ACC=0.606 | TEST f1_ma=0.430 ACC=0.436
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.598 ACC=0.597 | TEST f1_ma=0.434 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.604 ACC=0.605 | TEST f1_ma=0.445 ACC=0.455
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.604 ACC=0.603 | TEST f1_ma=0.435 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.609 ACC=0.607 | TEST f1_ma=0.435 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.607 ACC=0.607 | TEST f1_ma=0.434 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.605 ACC=0.605 | TEST f1_ma=0.442 ACC=0.451
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.611 ACC=0.611 | TEST f1_ma=0.421 ACC=0.430
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.605 ACC=0.604 | TEST f1_ma=0.435 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.598 ACC=0.598 | TEST f1_ma=0.432 ACC=0.438
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.599 ACC=0.599 | TEST f1_ma=0.426 ACC=0.435
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.605 ACC=0.604 | TEST f1_ma=0.435 ACC=0.443
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.604 ACC=0.605 | TEST f1_ma=0.436 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.602 ACC=0.600 | TEST f1_ma=0.429 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.604 ACC=0.604 | TEST f1_ma=0.438 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.618 ACC=0.617 | TEST f1_ma=0.441 ACC=0.447
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.609 ACC=0.608 | TEST f1_ma=0.434 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.603 ACC=0.603 | TEST f1_ma=0.434 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2=128 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.603 ACC=0.604 | TEST f1_ma=0.433 ACC=0.438
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.598 ACC=0.597 | TEST f1_ma=0.430 ACC=0.438
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.600 ACC=0.601 | TEST f1_ma=0.439 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.600 ACC=0.601 | TEST f1_ma=0.423 ACC=0.431
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.597 ACC=0.598 | TEST f1_ma=0.416 ACC=0.423
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.593 ACC=0.593 | TEST f1_ma=0.433 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.605 ACC=0.606 | TEST f1_ma=0.424 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.604 ACC=0.604 | TEST f1_ma=0.424 ACC=0.432
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.603 ACC=0.603 | TEST f1_ma=0.427 ACC=0.435
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.1] VAL f1_ma=0.607 ACC=0.605 | TEST f1_ma=0.418 ACC=0.425
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.599 ACC=0.601 | TEST f1_ma=0.438 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.600 ACC=0.599 | TEST f1_ma=0.427 ACC=0.434
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.609 ACC=0.605 | TEST f1_ma=0.441 ACC=0.446
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.597 ACC=0.595 | TEST f1_ma=0.444 ACC=0.446
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.599 ACC=0.599 | TEST f1_ma=0.417 ACC=0.425
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.603 ACC=0.603 | TEST f1_ma=0.435 ACC=0.442
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.599 ACC=0.597 | TEST f1_ma=0.436 ACC=0.440
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.602 ACC=0.603 | TEST f1_ma=0.429 ACC=0.437
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.3] VAL f1_ma=0.602 ACC=0.603 | TEST f1_ma=0.438 ACC=0.445
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.609 ACC=0.606 | TEST f1_ma=0.442 ACC=0.448
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.598 ACC=0.598 | TEST f1_ma=0.428 ACC=0.437
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.610 | TEST f1_ma=0.428 ACC=0.439
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.601 ACC=0.601 | TEST f1_ma=0.436 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.606 ACC=0.606 | TEST f1_ma=0.437 ACC=0.444
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.595 ACC=0.594 | TEST f1_ma=0.422 ACC=0.429
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.610 | TEST f1_ma=0.424 ACC=0.431
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.610 ACC=0.610 | TEST f1_ma=0.434 ACC=0.441
# [hybrid_equal_knn   k= 8 | h1=256  h2=256 lr=0.01   opt=adamw drop=0.5] VAL f1_ma=0.608 ACC=0.609 | TEST f1_ma=0.442 ACC=0.447
#
# Grid search finished in 62.3 min

# %%
print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(classification_report(y_true, y_pred))
#
# NameError: name 'y_true' is not defined
