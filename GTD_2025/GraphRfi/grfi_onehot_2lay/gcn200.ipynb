# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from training import *
import torch
from itertools import product
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv")

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %%
from pathlib import Path
import numpy as np
from datetime import datetime

def save_metrics_txt(best_metrics, partition, append=False):
    """
    Write best_metrics to results/results_{partition}.txt as key: value lines.
    Set append=True to add another block instead of overwriting.
    """
    results_dir = Path("results")
    results_dir.mkdir(parents=True, exist_ok=True)
    path = results_dir / f"results_{partition}.txt"
    mode = "a" if append else "w"

    # make JSON-friendly scalars for numpy types
    def to_scalar(v):
        if isinstance(v, (np.floating,)):
            return float(v)
        if isinstance(v, (np.integer,)):
            return int(v)
        return v

    with open(path, mode, encoding="utf-8") as f:
        if append:
            f.write("\n" + "="*60 + "\n")
        f.write(f"Run saved: {datetime.now().isoformat(timespec='seconds')}\n")
        # align keys for readability
        width = max(len(k) for k in best_metrics.keys())
        for k in sorted(best_metrics.keys()):
            f.write(f"{k:<{width}} : {to_scalar(best_metrics[k])}\n")

# usage:
# save_metrics_txt(best_metrics, partition="gtd300", append=False)

# %%
node_feature_cols = [c for c in df.columns if c!='gname']
edge_feature_cols = ['attacktype1', 'target1']
edge_mode = 'hybrid_equal_knn'
equal_cols = [c for c in df.columns if c.startswith("longlat_")]
k = 3

#{'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'out_size_nrf': 1024, 'epochs': 500, 'partition': 'gtd100', 'final_evaluation': False, 'n_class': 30}
import random
param_grid = {
    'h1': [16, 32, 64, 128, 256, 512],
    'h2': [16, 32, 64, 128, 256, 512],
    'dropout': [0.1, 0.3, 0.5],
    'lr': [0.01],
    'n_tree': [50, 80,100],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.1,0.3],
    'feat_dropout': [0.1,0.2,0.3],
    'out_size_nrf': [256,512,768,1024]
    }

grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 500)

best_acc = -1
for i,combo in enumerate(sampled_combos):
    print(f"combo {i+1} / {len(sampled_combos)}: {combo}")
    nrf_cfg = {
        **dict(zip(param_names, combo)),
        "epochs": 150,
        "partition": f"gtd{partition}",   # one of: "gtd100", "gtd200", "gtd300", "gtd478"
        "final_evaluation": False,
        "lr": 0.01,
        "n_class": 30
    }

    test_acc, best_epoch, best_metrics, epoch_logs = train_joint_gcn_nrf(
        df,
        node_feature_cols,
        edge_feature_cols,
        edge_mode,
        equal_cols,
        k,
        nrf_cfg,
        weight_decay=0.15,
        device="cuda"
    )

    if test_acc > best_acc:
        best_acc = test_acc
        best_params = nrf_cfg

print(best_params)
# Out:
# combo 1 / 500: (512, 64, 0.1, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5325 @ epoch 2
# combo 2 / 500: (512, 32, 0.5, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5183 @ epoch 3
# combo 3 / 500: (64, 16, 0.1, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5167 @ epoch 2
# combo 4 / 500: (16, 512, 0.5, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.4908 @ epoch 3
# combo 5 / 500: (256, 256, 0.3, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5042 @ epoch 1
# combo 6 / 500: (128, 256, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Best validation acc: 0.5125 @ epoch 125
# combo 7 / 500: (16, 128, 0.3, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.4958 @ epoch 2
# combo 8 / 500: (512, 256, 0.3, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5025 @ epoch 1
# combo 9 / 500: (512, 256, 0.1, 0.01, 50, 8, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.4892 @ epoch 6
# combo 10 / 500: (128, 64, 0.5, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.4942 @ epoch 6
# combo 11 / 500: (128, 256, 0.3, 0.01, 50, 9, 0.3, 0.1, 768)
# Best validation acc: 0.5100 @ epoch 123
# combo 12 / 500: (512, 64, 0.1, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5400 @ epoch 3
# combo 13 / 500: (64, 32, 0.3, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5150 @ epoch 1
# combo 14 / 500: (512, 512, 0.1, 0.01, 50, 7, 0.1, 0.2, 1024)
# Best validation acc: 0.4942 @ epoch 141
# combo 15 / 500: (512, 512, 0.3, 0.01, 100, 7, 0.3, 0.3, 1024)
# Best validation acc: 0.5017 @ epoch 127
# combo 16 / 500: (512, 512, 0.3, 0.01, 80, 7, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.4892 @ epoch 2
# combo 17 / 500: (512, 64, 0.5, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5167 @ epoch 4
# combo 18 / 500: (256, 64, 0.3, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5175 @ epoch 4
# combo 19 / 500: (64, 16, 0.5, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5025 @ epoch 2
# combo 20 / 500: (32, 64, 0.5, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5100 @ epoch 1
# combo 21 / 500: (512, 128, 0.1, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5217 @ epoch 3
# combo 22 / 500: (64, 128, 0.1, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5358 @ epoch 1
# combo 23 / 500: (16, 16, 0.1, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5042 @ epoch 4
# combo 24 / 500: (512, 256, 0.5, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.4975 @ epoch 1
# combo 25 / 500: (64, 512, 0.5, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.4950 @ epoch 5
# combo 26 / 500: (128, 512, 0.5, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.4933 @ epoch 8
# combo 27 / 500: (128, 256, 0.3, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5208 @ epoch 1
# combo 28 / 500: (256, 128, 0.3, 0.01, 100, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5175 @ epoch 3
# combo 29 / 500: (256, 128, 0.5, 0.01, 50, 8, 0.1, 0.1, 1024)
# Best validation acc: 0.5033 @ epoch 133
# combo 30 / 500: (32, 16, 0.5, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5100 @ epoch 2
# combo 31 / 500: (512, 64, 0.5, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5358 @ epoch 2
# combo 32 / 500: (512, 128, 0.1, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5067 @ epoch 2
# combo 33 / 500: (512, 64, 0.3, 0.01, 80, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5292 @ epoch 3
# combo 34 / 500: (256, 32, 0.1, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5433 @ epoch 2
# combo 35 / 500: (16, 16, 0.3, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5092 @ epoch 2
# combo 36 / 500: (256, 64, 0.5, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5017 @ epoch 5
# combo 37 / 500: (32, 64, 0.5, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5258 @ epoch 1
# combo 38 / 500: (512, 16, 0.5, 0.01, 50, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5183 @ epoch 1
# combo 39 / 500: (128, 64, 0.3, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5008 @ epoch 2
# combo 40 / 500: (64, 256, 0.1, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5042 @ epoch 1
# combo 41 / 500: (512, 512, 0.5, 0.01, 50, 7, 0.3, 0.2, 512)
# Best validation acc: 0.4933 @ epoch 113
# combo 42 / 500: (256, 256, 0.5, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5000 @ epoch 5
# combo 43 / 500: (128, 32, 0.1, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5267 @ epoch 6
# combo 44 / 500: (512, 16, 0.1, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5367 @ epoch 3
# combo 45 / 500: (512, 256, 0.1, 0.01, 80, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5233 @ epoch 1
# combo 46 / 500: (128, 64, 0.3, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5283 @ epoch 2
# combo 47 / 500: (512, 64, 0.5, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5075 @ epoch 5
# combo 48 / 500: (64, 512, 0.1, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 115
# Best validation acc: 0.5017 @ epoch 15
# combo 49 / 500: (128, 32, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5233 @ epoch 1
# combo 50 / 500: (256, 128, 0.1, 0.01, 50, 9, 0.3, 0.2, 256)
# Best validation acc: 0.5108 @ epoch 122
# combo 51 / 500: (256, 512, 0.1, 0.01, 100, 8, 0.1, 0.1, 1024)
# Best validation acc: 0.4992 @ epoch 130
# combo 52 / 500: (128, 32, 0.1, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5250 @ epoch 3
# combo 53 / 500: (32, 64, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 54 / 500: (32, 512, 0.3, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5017 @ epoch 2
# combo 55 / 500: (16, 512, 0.1, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5342 @ epoch 6
# combo 56 / 500: (128, 128, 0.1, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5325 @ epoch 1
# combo 57 / 500: (512, 64, 0.3, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5283 @ epoch 3
# combo 58 / 500: (16, 256, 0.1, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5183 @ epoch 1
# combo 59 / 500: (512, 512, 0.3, 0.01, 80, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4933 @ epoch 138
# combo 60 / 500: (64, 16, 0.1, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5092 @ epoch 3
# combo 61 / 500: (256, 256, 0.5, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5058 @ epoch 1
# combo 62 / 500: (64, 128, 0.5, 0.01, 50, 7, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5067 @ epoch 2
# combo 63 / 500: (64, 32, 0.1, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5217 @ epoch 5
# combo 64 / 500: (128, 16, 0.5, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5158 @ epoch 1
# combo 65 / 500: (16, 256, 0.5, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 111
# Best validation acc: 0.4900 @ epoch 11
# combo 66 / 500: (32, 32, 0.1, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5025 @ epoch 4
# combo 67 / 500: (256, 256, 0.5, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5008 @ epoch 1
# combo 68 / 500: (256, 16, 0.5, 0.01, 100, 8, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5008 @ epoch 1
# combo 69 / 500: (32, 64, 0.3, 0.01, 50, 8, 0.3, 0.2, 512)
# Early stopping at epoch 107
# Best validation acc: 0.4967 @ epoch 7
# combo 70 / 500: (128, 128, 0.1, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5100 @ epoch 3
# combo 71 / 500: (32, 256, 0.5, 0.01, 100, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.4917 @ epoch 4
# combo 72 / 500: (32, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.4983 @ epoch 2
# combo 73 / 500: (32, 16, 0.3, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5408 @ epoch 2
# combo 74 / 500: (256, 32, 0.3, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5200 @ epoch 3
# combo 75 / 500: (32, 512, 0.5, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5067 @ epoch 0
# combo 76 / 500: (128, 128, 0.1, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5442 @ epoch 4
# combo 77 / 500: (256, 128, 0.5, 0.01, 50, 7, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5017 @ epoch 3
# combo 78 / 500: (256, 256, 0.5, 0.01, 100, 9, 0.1, 0.3, 256)
# Best validation acc: 0.4967 @ epoch 149
# combo 79 / 500: (256, 512, 0.5, 0.01, 100, 8, 0.1, 0.3, 256)
# Best validation acc: 0.5025 @ epoch 141
# combo 80 / 500: (512, 256, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Best validation acc: 0.5058 @ epoch 148
# combo 81 / 500: (32, 128, 0.1, 0.01, 50, 7, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5250 @ epoch 6
# combo 82 / 500: (16, 16, 0.5, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5150 @ epoch 2
# combo 83 / 500: (128, 256, 0.3, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 131
# Best validation acc: 0.4933 @ epoch 31
# combo 84 / 500: (64, 64, 0.3, 0.01, 100, 7, 0.1, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.4958 @ epoch 7
# combo 85 / 500: (32, 64, 0.3, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.4958 @ epoch 4
# combo 86 / 500: (64, 512, 0.1, 0.01, 100, 7, 0.1, 0.3, 512)
# Early stopping at epoch 108
# Best validation acc: 0.5092 @ epoch 8
# combo 87 / 500: (512, 16, 0.1, 0.01, 100, 7, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5208 @ epoch 2
# combo 88 / 500: (512, 128, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5175 @ epoch 5
# combo 89 / 500: (16, 32, 0.3, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5017 @ epoch 3
# combo 90 / 500: (16, 32, 0.1, 0.01, 100, 9, 0.1, 0.2, 256)
# Early stopping at epoch 109
# Best validation acc: 0.4975 @ epoch 9
# combo 91 / 500: (256, 32, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5583 @ epoch 4
# combo 92 / 500: (32, 32, 0.1, 0.01, 50, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5242 @ epoch 1
# combo 93 / 500: (16, 256, 0.1, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5283 @ epoch 5
# combo 94 / 500: (128, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5000 @ epoch 1
# combo 95 / 500: (16, 64, 0.5, 0.01, 100, 7, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5167 @ epoch 1
# combo 96 / 500: (128, 512, 0.5, 0.01, 80, 9, 0.1, 0.2, 512)
# Best validation acc: 0.4983 @ epoch 127
# combo 97 / 500: (16, 16, 0.1, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5117 @ epoch 2
# combo 98 / 500: (32, 16, 0.3, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5108 @ epoch 4
# combo 99 / 500: (128, 64, 0.3, 0.01, 80, 7, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4983 @ epoch 5
# combo 100 / 500: (64, 256, 0.3, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 118
# Best validation acc: 0.4933 @ epoch 18
# combo 101 / 500: (256, 128, 0.5, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5042 @ epoch 6
# combo 102 / 500: (128, 256, 0.3, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5158 @ epoch 1
# combo 103 / 500: (256, 256, 0.5, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5267 @ epoch 1
# combo 104 / 500: (256, 32, 0.3, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5308 @ epoch 3
# combo 105 / 500: (512, 32, 0.5, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5042 @ epoch 4
# combo 106 / 500: (256, 32, 0.1, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5308 @ epoch 2
# combo 107 / 500: (256, 256, 0.3, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5000 @ epoch 1
# combo 108 / 500: (512, 16, 0.3, 0.01, 50, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 109 / 500: (256, 128, 0.3, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5017 @ epoch 2
# combo 110 / 500: (256, 32, 0.1, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5408 @ epoch 3
# combo 111 / 500: (128, 256, 0.3, 0.01, 80, 8, 0.1, 0.1, 768)
# Best validation acc: 0.5092 @ epoch 139
# combo 112 / 500: (256, 16, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5292 @ epoch 2
# combo 113 / 500: (16, 256, 0.3, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 114 / 500: (128, 256, 0.1, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5242 @ epoch 1
# combo 115 / 500: (64, 32, 0.1, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5400 @ epoch 1
# combo 116 / 500: (32, 128, 0.1, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5283 @ epoch 6
# combo 117 / 500: (256, 16, 0.1, 0.01, 50, 7, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5108 @ epoch 5
# combo 118 / 500: (256, 64, 0.3, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5292 @ epoch 4
# combo 119 / 500: (128, 512, 0.3, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5025 @ epoch 1
# combo 120 / 500: (512, 32, 0.1, 0.01, 80, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5175 @ epoch 3
# combo 121 / 500: (512, 32, 0.5, 0.01, 80, 7, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 122 / 500: (256, 32, 0.3, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5067 @ epoch 6
# combo 123 / 500: (16, 64, 0.1, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5167 @ epoch 3
# combo 124 / 500: (16, 512, 0.5, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.4958 @ epoch 1
# combo 125 / 500: (32, 128, 0.1, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5292 @ epoch 1
# combo 126 / 500: (32, 512, 0.5, 0.01, 100, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4950 @ epoch 145
# combo 127 / 500: (128, 16, 0.5, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5017 @ epoch 5
# combo 128 / 500: (16, 128, 0.5, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.4967 @ epoch 3
# combo 129 / 500: (512, 512, 0.5, 0.01, 50, 7, 0.3, 0.1, 256)
# Best validation acc: 0.4967 @ epoch 96
# combo 130 / 500: (16, 256, 0.1, 0.01, 50, 7, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5317 @ epoch 6
# combo 131 / 500: (512, 32, 0.1, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5167 @ epoch 3
# combo 132 / 500: (32, 16, 0.1, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5200 @ epoch 4
# combo 133 / 500: (64, 64, 0.1, 0.01, 100, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5183 @ epoch 2
# combo 134 / 500: (16, 128, 0.3, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5033 @ epoch 1
# combo 135 / 500: (16, 16, 0.3, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.4975 @ epoch 6
# combo 136 / 500: (16, 64, 0.1, 0.01, 100, 8, 0.1, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5108 @ epoch 7
# combo 137 / 500: (512, 32, 0.5, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5042 @ epoch 2
# combo 138 / 500: (128, 128, 0.1, 0.01, 80, 8, 0.3, 0.2, 1024)
# Best validation acc: 0.5133 @ epoch 67
# combo 139 / 500: (16, 16, 0.1, 0.01, 50, 7, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4983 @ epoch 5
# combo 140 / 500: (16, 32, 0.5, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.4983 @ epoch 4
# combo 141 / 500: (128, 16, 0.1, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5100 @ epoch 3
# combo 142 / 500: (256, 16, 0.5, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5000 @ epoch 5
# combo 143 / 500: (512, 32, 0.1, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5300 @ epoch 5
# combo 144 / 500: (256, 256, 0.1, 0.01, 50, 7, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5142 @ epoch 1
# combo 145 / 500: (256, 32, 0.3, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5250 @ epoch 4
# combo 146 / 500: (512, 64, 0.1, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5308 @ epoch 4
# combo 147 / 500: (512, 512, 0.3, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.4892 @ epoch 3
# combo 148 / 500: (32, 128, 0.3, 0.01, 80, 9, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.4983 @ epoch 2
# combo 149 / 500: (512, 128, 0.5, 0.01, 80, 7, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5100 @ epoch 5
# combo 150 / 500: (64, 64, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5050 @ epoch 3
# combo 151 / 500: (256, 512, 0.1, 0.01, 80, 8, 0.1, 0.3, 512)
# Best validation acc: 0.5042 @ epoch 113
# combo 152 / 500: (64, 512, 0.1, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5158 @ epoch 1
# combo 153 / 500: (512, 256, 0.5, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5042 @ epoch 2
# combo 154 / 500: (32, 16, 0.3, 0.01, 100, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5100 @ epoch 4
# combo 155 / 500: (64, 128, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 110
# Best validation acc: 0.4958 @ epoch 10
# combo 156 / 500: (256, 256, 0.1, 0.01, 80, 8, 0.3, 0.3, 1024)
# Best validation acc: 0.5025 @ epoch 98
# combo 157 / 500: (128, 256, 0.3, 0.01, 100, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5042 @ epoch 0
# combo 158 / 500: (64, 64, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5192 @ epoch 1
# combo 159 / 500: (256, 512, 0.3, 0.01, 80, 7, 0.3, 0.2, 512)
# Best validation acc: 0.5050 @ epoch 123
# combo 160 / 500: (16, 64, 0.1, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5050 @ epoch 4
# combo 161 / 500: (512, 16, 0.5, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5125 @ epoch 3
# combo 162 / 500: (128, 32, 0.5, 0.01, 80, 9, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5125 @ epoch 1
# combo 163 / 500: (512, 32, 0.1, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5308 @ epoch 3
# combo 164 / 500: (128, 16, 0.5, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5142 @ epoch 2
# combo 165 / 500: (256, 256, 0.3, 0.01, 50, 9, 0.3, 0.2, 768)
# Best validation acc: 0.5125 @ epoch 136
# combo 166 / 500: (128, 512, 0.3, 0.01, 100, 9, 0.1, 0.1, 768)
# Best validation acc: 0.5075 @ epoch 125
# combo 167 / 500: (16, 16, 0.5, 0.01, 80, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5142 @ epoch 3
# combo 168 / 500: (64, 16, 0.1, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5083 @ epoch 3
# combo 169 / 500: (128, 256, 0.5, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4983 @ epoch 2
# combo 170 / 500: (512, 256, 0.3, 0.01, 50, 7, 0.1, 0.3, 256)
# Best validation acc: 0.4950 @ epoch 89
# combo 171 / 500: (64, 16, 0.3, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5092 @ epoch 2
# combo 172 / 500: (512, 128, 0.5, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.4950 @ epoch 3
# combo 173 / 500: (16, 128, 0.5, 0.01, 80, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.4983 @ epoch 1
# combo 174 / 500: (64, 16, 0.5, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5008 @ epoch 6
# combo 175 / 500: (512, 64, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5100 @ epoch 3
# combo 176 / 500: (16, 16, 0.1, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5333 @ epoch 3
# combo 177 / 500: (16, 128, 0.1, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5000 @ epoch 6
# combo 178 / 500: (512, 512, 0.1, 0.01, 80, 8, 0.3, 0.2, 512)
# Best validation acc: 0.4892 @ epoch 76
# combo 179 / 500: (16, 256, 0.3, 0.01, 80, 9, 0.1, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.4983 @ epoch 4
# combo 180 / 500: (32, 32, 0.3, 0.01, 80, 9, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5283 @ epoch 1
# combo 181 / 500: (512, 512, 0.3, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4925 @ epoch 2
# combo 182 / 500: (16, 128, 0.3, 0.01, 80, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.4975 @ epoch 4
# combo 183 / 500: (64, 64, 0.5, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5242 @ epoch 1
# combo 184 / 500: (128, 64, 0.5, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.4958 @ epoch 6
# combo 185 / 500: (128, 64, 0.1, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5417 @ epoch 3
# combo 186 / 500: (16, 512, 0.5, 0.01, 50, 7, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.4958 @ epoch 1
# combo 187 / 500: (128, 64, 0.1, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5233 @ epoch 3
# combo 188 / 500: (16, 32, 0.1, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5208 @ epoch 4
# combo 189 / 500: (32, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5033 @ epoch 3
# combo 190 / 500: (16, 64, 0.3, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5000 @ epoch 2
# combo 191 / 500: (32, 32, 0.3, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5317 @ epoch 1
# combo 192 / 500: (512, 512, 0.3, 0.01, 80, 7, 0.3, 0.1, 256)
# Best validation acc: 0.4983 @ epoch 142
# combo 193 / 500: (128, 512, 0.5, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5050 @ epoch 2
# combo 194 / 500: (64, 256, 0.1, 0.01, 80, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5308 @ epoch 1
# combo 195 / 500: (16, 512, 0.5, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5208 @ epoch 1
# combo 196 / 500: (32, 64, 0.3, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5250 @ epoch 2
# combo 197 / 500: (64, 128, 0.5, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5100 @ epoch 2
# combo 198 / 500: (32, 16, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5100 @ epoch 1
# combo 199 / 500: (32, 128, 0.3, 0.01, 50, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5142 @ epoch 1
# combo 200 / 500: (256, 64, 0.5, 0.01, 50, 8, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.4983 @ epoch 5
# combo 201 / 500: (64, 16, 0.5, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4908 @ epoch 2
# combo 202 / 500: (256, 256, 0.3, 0.01, 100, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5100 @ epoch 1
# combo 203 / 500: (128, 16, 0.5, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5133 @ epoch 2
# combo 204 / 500: (128, 128, 0.3, 0.01, 50, 8, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5217 @ epoch 1
# combo 205 / 500: (16, 128, 0.3, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5133 @ epoch 1
# combo 206 / 500: (256, 128, 0.3, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5217 @ epoch 1
# combo 207 / 500: (16, 32, 0.1, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5067 @ epoch 2
# combo 208 / 500: (16, 256, 0.3, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.4942 @ epoch 4
# combo 209 / 500: (32, 512, 0.3, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.4908 @ epoch 2
# combo 210 / 500: (32, 64, 0.3, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 110
# Best validation acc: 0.4950 @ epoch 10
# combo 211 / 500: (128, 256, 0.1, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5242 @ epoch 2
# combo 212 / 500: (128, 16, 0.3, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5283 @ epoch 2
# combo 213 / 500: (16, 256, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5150 @ epoch 0
# combo 214 / 500: (128, 512, 0.3, 0.01, 50, 9, 0.1, 0.2, 1024)
# Best validation acc: 0.5092 @ epoch 113
# combo 215 / 500: (16, 64, 0.1, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5183 @ epoch 7
# combo 216 / 500: (16, 128, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5225 @ epoch 5
# combo 217 / 500: (128, 128, 0.1, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5233 @ epoch 4
# combo 218 / 500: (128, 256, 0.1, 0.01, 100, 7, 0.1, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5050 @ epoch 1
# combo 219 / 500: (128, 128, 0.3, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5408 @ epoch 4
# combo 220 / 500: (512, 512, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Best validation acc: 0.4992 @ epoch 145
# combo 221 / 500: (256, 128, 0.5, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5067 @ epoch 5
# combo 222 / 500: (512, 64, 0.3, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5300 @ epoch 2
# combo 223 / 500: (32, 16, 0.5, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5083 @ epoch 1
# combo 224 / 500: (512, 256, 0.1, 0.01, 100, 8, 0.1, 0.1, 256)
# Best validation acc: 0.4975 @ epoch 126
# combo 225 / 500: (256, 64, 0.5, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.4975 @ epoch 1
# combo 226 / 500: (16, 128, 0.5, 0.01, 80, 9, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5058 @ epoch 1
# combo 227 / 500: (512, 16, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5283 @ epoch 1
# combo 228 / 500: (256, 512, 0.3, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.4975 @ epoch 4
# combo 229 / 500: (128, 256, 0.1, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5283 @ epoch 1
# combo 230 / 500: (16, 128, 0.1, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5292 @ epoch 4
# combo 231 / 500: (64, 16, 0.1, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5242 @ epoch 5
# combo 232 / 500: (16, 128, 0.5, 0.01, 50, 8, 0.1, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5058 @ epoch 2
# combo 233 / 500: (32, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5192 @ epoch 5
# combo 234 / 500: (16, 128, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5050 @ epoch 2
# combo 235 / 500: (128, 128, 0.3, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5017 @ epoch 5
# combo 236 / 500: (256, 64, 0.5, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 114
# Best validation acc: 0.4942 @ epoch 14
# combo 237 / 500: (512, 16, 0.5, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4933 @ epoch 5
# combo 238 / 500: (128, 256, 0.1, 0.01, 100, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5108 @ epoch 1
# combo 239 / 500: (16, 32, 0.5, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4942 @ epoch 5
# combo 240 / 500: (32, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.4967 @ epoch 2
# combo 241 / 500: (32, 256, 0.5, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5133 @ epoch 1
# combo 242 / 500: (64, 512, 0.3, 0.01, 50, 7, 0.3, 0.1, 512)
# Best validation acc: 0.5042 @ epoch 145
# combo 243 / 500: (32, 32, 0.1, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5075 @ epoch 1
# combo 244 / 500: (16, 32, 0.3, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5017 @ epoch 1
# combo 245 / 500: (512, 256, 0.5, 0.01, 50, 9, 0.1, 0.3, 1024)
# Best validation acc: 0.4992 @ epoch 98
# combo 246 / 500: (512, 32, 0.5, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.4942 @ epoch 2
# combo 247 / 500: (256, 64, 0.5, 0.01, 100, 7, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4942 @ epoch 5
# combo 248 / 500: (128, 512, 0.3, 0.01, 80, 7, 0.1, 0.1, 1024)
# Best validation acc: 0.5142 @ epoch 133
# combo 249 / 500: (128, 128, 0.5, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.4975 @ epoch 1
# combo 250 / 500: (512, 128, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5225 @ epoch 3
# combo 251 / 500: (16, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5067 @ epoch 1
# combo 252 / 500: (256, 16, 0.5, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5150 @ epoch 1
# combo 253 / 500: (128, 16, 0.3, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5167 @ epoch 2
# combo 254 / 500: (128, 16, 0.3, 0.01, 50, 8, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5233 @ epoch 1
# combo 255 / 500: (256, 512, 0.1, 0.01, 80, 9, 0.3, 0.1, 1024)
# Best validation acc: 0.5000 @ epoch 136
# combo 256 / 500: (256, 512, 0.3, 0.01, 50, 8, 0.1, 0.1, 256)
# Best validation acc: 0.4958 @ epoch 140
# combo 257 / 500: (512, 512, 0.5, 0.01, 100, 7, 0.3, 0.3, 256)
# Best validation acc: 0.4992 @ epoch 139
# combo 258 / 500: (256, 128, 0.3, 0.01, 100, 7, 0.1, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5100 @ epoch 2
# combo 259 / 500: (256, 16, 0.1, 0.01, 80, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5458 @ epoch 3
# combo 260 / 500: (256, 256, 0.1, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 261 / 500: (512, 512, 0.5, 0.01, 100, 8, 0.3, 0.3, 1024)
# Best validation acc: 0.4917 @ epoch 90
# combo 262 / 500: (128, 16, 0.5, 0.01, 50, 7, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5067 @ epoch 2
# combo 263 / 500: (16, 16, 0.1, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5158 @ epoch 3
# combo 264 / 500: (512, 256, 0.1, 0.01, 80, 9, 0.3, 0.3, 512)
# Best validation acc: 0.4992 @ epoch 137
# combo 265 / 500: (64, 32, 0.3, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5042 @ epoch 3
# combo 266 / 500: (512, 64, 0.5, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 107
# Best validation acc: 0.4983 @ epoch 7
# combo 267 / 500: (256, 64, 0.5, 0.01, 100, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5000 @ epoch 4
# combo 268 / 500: (64, 512, 0.5, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5108 @ epoch 1
# combo 269 / 500: (512, 64, 0.3, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5033 @ epoch 4
# combo 270 / 500: (128, 32, 0.3, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 108
# Best validation acc: 0.5042 @ epoch 8
# combo 271 / 500: (256, 64, 0.5, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5200 @ epoch 1
# combo 272 / 500: (128, 64, 0.5, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5125 @ epoch 0
# combo 273 / 500: (16, 512, 0.5, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.4950 @ epoch 1
# combo 274 / 500: (256, 128, 0.1, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5025 @ epoch 4
# combo 275 / 500: (32, 32, 0.3, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5133 @ epoch 1
# combo 276 / 500: (16, 16, 0.5, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5275 @ epoch 0
# combo 277 / 500: (32, 32, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5042 @ epoch 1
# combo 278 / 500: (16, 32, 0.5, 0.01, 80, 9, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5200 @ epoch 4
# combo 279 / 500: (512, 32, 0.3, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5083 @ epoch 7
# combo 280 / 500: (128, 16, 0.1, 0.01, 80, 9, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5425 @ epoch 4
# combo 281 / 500: (512, 16, 0.3, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5333 @ epoch 4
# combo 282 / 500: (16, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4908 @ epoch 2
# combo 283 / 500: (128, 512, 0.3, 0.01, 50, 8, 0.3, 0.2, 1024)
# Best validation acc: 0.5075 @ epoch 119
# combo 284 / 500: (64, 256, 0.1, 0.01, 100, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5200 @ epoch 2
# combo 285 / 500: (32, 512, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 286 / 500: (16, 128, 0.5, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4975 @ epoch 2
# combo 287 / 500: (64, 256, 0.3, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5092 @ epoch 0
# combo 288 / 500: (512, 512, 0.3, 0.01, 80, 7, 0.1, 0.1, 1024)
# Best validation acc: 0.5008 @ epoch 116
# combo 289 / 500: (128, 16, 0.1, 0.01, 100, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5417 @ epoch 5
# combo 290 / 500: (16, 128, 0.1, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5267 @ epoch 4
# combo 291 / 500: (32, 64, 0.5, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5067 @ epoch 3
# combo 292 / 500: (16, 128, 0.3, 0.01, 100, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.4992 @ epoch 6
# combo 293 / 500: (64, 64, 0.3, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5150 @ epoch 1
# combo 294 / 500: (512, 16, 0.3, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5358 @ epoch 2
# combo 295 / 500: (64, 512, 0.1, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5067 @ epoch 4
# combo 296 / 500: (32, 64, 0.1, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5242 @ epoch 1
# combo 297 / 500: (64, 128, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5183 @ epoch 1
# combo 298 / 500: (512, 16, 0.1, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5392 @ epoch 4
# combo 299 / 500: (256, 128, 0.1, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5050 @ epoch 3
# combo 300 / 500: (128, 512, 0.5, 0.01, 80, 7, 0.1, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.4875 @ epoch 3
# combo 301 / 500: (512, 64, 0.1, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5383 @ epoch 4
# combo 302 / 500: (64, 16, 0.1, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5242 @ epoch 2
# combo 303 / 500: (512, 32, 0.3, 0.01, 50, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5117 @ epoch 4
# combo 304 / 500: (128, 128, 0.5, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5125 @ epoch 1
# combo 305 / 500: (128, 16, 0.1, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5100 @ epoch 6
# combo 306 / 500: (128, 64, 0.1, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5333 @ epoch 4
# combo 307 / 500: (128, 64, 0.5, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.4900 @ epoch 1
# combo 308 / 500: (512, 64, 0.5, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5092 @ epoch 2
# combo 309 / 500: (256, 64, 0.1, 0.01, 100, 8, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5450 @ epoch 2
# combo 310 / 500: (32, 128, 0.3, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 106
# Best validation acc: 0.4967 @ epoch 6
# combo 311 / 500: (64, 256, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5333 @ epoch 2
# combo 312 / 500: (16, 16, 0.5, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5333 @ epoch 1
# combo 313 / 500: (32, 64, 0.5, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5000 @ epoch 1
# combo 314 / 500: (128, 32, 0.1, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5417 @ epoch 3
# combo 315 / 500: (256, 128, 0.1, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5183 @ epoch 4
# combo 316 / 500: (16, 512, 0.3, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 108
# Best validation acc: 0.4933 @ epoch 8
# combo 317 / 500: (32, 512, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5333 @ epoch 1
# combo 318 / 500: (256, 32, 0.5, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5317 @ epoch 1
# combo 319 / 500: (64, 32, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5175 @ epoch 3
# combo 320 / 500: (512, 256, 0.1, 0.01, 50, 8, 0.3, 0.3, 1024)
# Best validation acc: 0.5008 @ epoch 92
# combo 321 / 500: (128, 128, 0.3, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 123
# Best validation acc: 0.4950 @ epoch 23
# combo 322 / 500: (16, 128, 0.1, 0.01, 100, 7, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5183 @ epoch 5
# combo 323 / 500: (32, 128, 0.1, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5192 @ epoch 6
# combo 324 / 500: (16, 128, 0.1, 0.01, 50, 9, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5217 @ epoch 5
# combo 325 / 500: (32, 32, 0.3, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5117 @ epoch 2
# combo 326 / 500: (256, 512, 0.1, 0.01, 100, 7, 0.1, 0.2, 1024)
# Best validation acc: 0.5067 @ epoch 143
# combo 327 / 500: (256, 64, 0.5, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5008 @ epoch 5
# combo 328 / 500: (256, 16, 0.3, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5150 @ epoch 3
# combo 329 / 500: (32, 512, 0.1, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5158 @ epoch 1
# combo 330 / 500: (128, 256, 0.1, 0.01, 50, 9, 0.3, 0.3, 256)
# Best validation acc: 0.5108 @ epoch 133
# combo 331 / 500: (256, 16, 0.5, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5225 @ epoch 1
# combo 332 / 500: (256, 64, 0.3, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 333 / 500: (128, 16, 0.5, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4975 @ epoch 5
# combo 334 / 500: (64, 512, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Best validation acc: 0.5058 @ epoch 84
# combo 335 / 500: (128, 256, 0.1, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5400 @ epoch 4
# combo 336 / 500: (32, 512, 0.3, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.4975 @ epoch 1
# combo 337 / 500: (64, 256, 0.3, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 108
# Best validation acc: 0.4950 @ epoch 8
# combo 338 / 500: (512, 256, 0.5, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 339 / 500: (128, 64, 0.3, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.4967 @ epoch 8
# combo 340 / 500: (16, 32, 0.3, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 341 / 500: (256, 32, 0.3, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5325 @ epoch 2
# combo 342 / 500: (512, 16, 0.1, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5150 @ epoch 2
# combo 343 / 500: (16, 16, 0.3, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5275 @ epoch 3
# combo 344 / 500: (256, 16, 0.5, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5258 @ epoch 2
# combo 345 / 500: (128, 32, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5000 @ epoch 4
# combo 346 / 500: (512, 256, 0.3, 0.01, 50, 8, 0.3, 0.2, 256)
# Best validation acc: 0.5025 @ epoch 149
# combo 347 / 500: (256, 64, 0.5, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5067 @ epoch 1
# combo 348 / 500: (256, 64, 0.3, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5142 @ epoch 3
# combo 349 / 500: (32, 128, 0.5, 0.01, 50, 9, 0.3, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.4950 @ epoch 5
# combo 350 / 500: (16, 16, 0.5, 0.01, 50, 9, 0.1, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5050 @ epoch 2
# combo 351 / 500: (64, 512, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 115
# Best validation acc: 0.5192 @ epoch 15
# combo 352 / 500: (16, 128, 0.3, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.4975 @ epoch 3
# combo 353 / 500: (64, 64, 0.5, 0.01, 50, 9, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.4967 @ epoch 3
# combo 354 / 500: (128, 32, 0.3, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 355 / 500: (128, 64, 0.5, 0.01, 100, 9, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.4975 @ epoch 2
# combo 356 / 500: (16, 32, 0.1, 0.01, 100, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5317 @ epoch 4
# combo 357 / 500: (512, 256, 0.1, 0.01, 80, 8, 0.3, 0.1, 768)
# Best validation acc: 0.5067 @ epoch 112
# combo 358 / 500: (32, 16, 0.1, 0.01, 80, 7, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5300 @ epoch 5
# combo 359 / 500: (256, 128, 0.5, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5025 @ epoch 4
# combo 360 / 500: (512, 256, 0.1, 0.01, 50, 7, 0.1, 0.3, 1024)
# Best validation acc: 0.5025 @ epoch 102
# combo 361 / 500: (16, 128, 0.3, 0.01, 100, 8, 0.1, 0.2, 512)
# Early stopping at epoch 107
# Best validation acc: 0.4933 @ epoch 7
# combo 362 / 500: (32, 256, 0.1, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5208 @ epoch 9
# combo 363 / 500: (64, 16, 0.1, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5275 @ epoch 3
# combo 364 / 500: (32, 256, 0.3, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5058 @ epoch 3
# combo 365 / 500: (512, 16, 0.1, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5317 @ epoch 3
# combo 366 / 500: (256, 256, 0.5, 0.01, 50, 7, 0.3, 0.3, 256)
# Best validation acc: 0.4942 @ epoch 136
# combo 367 / 500: (256, 512, 0.5, 0.01, 100, 8, 0.3, 0.1, 512)
# Best validation acc: 0.5017 @ epoch 146
# combo 368 / 500: (16, 512, 0.1, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.4983 @ epoch 5
# combo 369 / 500: (256, 32, 0.1, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5258 @ epoch 5
# combo 370 / 500: (256, 32, 0.1, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5408 @ epoch 3
# combo 371 / 500: (128, 128, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Best validation acc: 0.5125 @ epoch 147
# combo 372 / 500: (64, 32, 0.1, 0.01, 100, 9, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5167 @ epoch 4
# combo 373 / 500: (16, 128, 0.5, 0.01, 80, 8, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5017 @ epoch 2
# combo 374 / 500: (16, 256, 0.1, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5125 @ epoch 4
# combo 375 / 500: (256, 32, 0.3, 0.01, 100, 9, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5283 @ epoch 1
# combo 376 / 500: (256, 256, 0.1, 0.01, 100, 8, 0.1, 0.2, 1024)
# Best validation acc: 0.5233 @ epoch 107
# combo 377 / 500: (16, 64, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5050 @ epoch 1
# combo 378 / 500: (16, 128, 0.1, 0.01, 80, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5150 @ epoch 4
# combo 379 / 500: (512, 128, 0.5, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5158 @ epoch 2
# combo 380 / 500: (128, 512, 0.3, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 100
# Best validation acc: 0.4967 @ epoch 0
# combo 381 / 500: (32, 64, 0.5, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.4958 @ epoch 1
# combo 382 / 500: (64, 32, 0.5, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5033 @ epoch 2
# combo 383 / 500: (256, 32, 0.5, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5208 @ epoch 1
# combo 384 / 500: (512, 512, 0.1, 0.01, 80, 8, 0.1, 0.3, 1024)
# Best validation acc: 0.4933 @ epoch 145
# combo 385 / 500: (256, 128, 0.5, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 107
# Best validation acc: 0.4958 @ epoch 7
# combo 386 / 500: (32, 32, 0.5, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5058 @ epoch 1
# combo 387 / 500: (16, 64, 0.3, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5125 @ epoch 1
# combo 388 / 500: (64, 64, 0.5, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5108 @ epoch 1
# combo 389 / 500: (512, 512, 0.1, 0.01, 50, 8, 0.3, 0.3, 256)
# Best validation acc: 0.4900 @ epoch 69
# combo 390 / 500: (512, 16, 0.3, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5283 @ epoch 2
# combo 391 / 500: (16, 256, 0.5, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5283 @ epoch 1
# combo 392 / 500: (128, 16, 0.1, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5450 @ epoch 4
# combo 393 / 500: (512, 512, 0.1, 0.01, 50, 8, 0.3, 0.3, 768)
# Best validation acc: 0.4992 @ epoch 130
# combo 394 / 500: (512, 512, 0.1, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.4883 @ epoch 2
# combo 395 / 500: (128, 64, 0.1, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5208 @ epoch 3
# combo 396 / 500: (128, 64, 0.5, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5125 @ epoch 1
# combo 397 / 500: (16, 32, 0.1, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5108 @ epoch 4
# combo 398 / 500: (32, 16, 0.5, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5042 @ epoch 3
# combo 399 / 500: (16, 64, 0.1, 0.01, 80, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5133 @ epoch 4
# combo 400 / 500: (256, 256, 0.5, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5008 @ epoch 1
# combo 401 / 500: (16, 32, 0.3, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5175 @ epoch 2
# combo 402 / 500: (64, 512, 0.5, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5025 @ epoch 1
# combo 403 / 500: (256, 16, 0.5, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5042 @ epoch 1
# combo 404 / 500: (16, 512, 0.5, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 405 / 500: (256, 64, 0.1, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5275 @ epoch 4
# combo 406 / 500: (512, 64, 0.1, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5242 @ epoch 4
# combo 407 / 500: (256, 32, 0.3, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5217 @ epoch 3
# combo 408 / 500: (64, 16, 0.3, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5050 @ epoch 1
# combo 409 / 500: (128, 256, 0.3, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5208 @ epoch 1
# combo 410 / 500: (128, 64, 0.5, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.4925 @ epoch 2
# combo 411 / 500: (128, 256, 0.5, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.4900 @ epoch 2
# combo 412 / 500: (64, 256, 0.1, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 149
# Best validation acc: 0.5117 @ epoch 49
# combo 413 / 500: (512, 32, 0.1, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5225 @ epoch 6
# combo 414 / 500: (32, 32, 0.5, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.4975 @ epoch 5
# combo 415 / 500: (16, 512, 0.3, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.4950 @ epoch 6
# combo 416 / 500: (128, 32, 0.1, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5375 @ epoch 4
# combo 417 / 500: (256, 512, 0.3, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5017 @ epoch 1
# combo 418 / 500: (64, 16, 0.5, 0.01, 80, 8, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5083 @ epoch 3
# combo 419 / 500: (512, 32, 0.1, 0.01, 80, 7, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5367 @ epoch 3
# combo 420 / 500: (64, 512, 0.3, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 112
# Best validation acc: 0.4967 @ epoch 12
# combo 421 / 500: (128, 512, 0.1, 0.01, 80, 9, 0.1, 0.2, 512)
# Best validation acc: 0.5258 @ epoch 134
# combo 422 / 500: (128, 128, 0.3, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5058 @ epoch 0
# combo 423 / 500: (256, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5308 @ epoch 2
# combo 424 / 500: (512, 512, 0.5, 0.01, 100, 9, 0.3, 0.3, 256)
# Best validation acc: 0.4892 @ epoch 115
# combo 425 / 500: (512, 64, 0.5, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5108 @ epoch 3
# combo 426 / 500: (32, 64, 0.5, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5067 @ epoch 2
# combo 427 / 500: (128, 16, 0.5, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5017 @ epoch 2
# combo 428 / 500: (16, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5125 @ epoch 2
# combo 429 / 500: (512, 16, 0.1, 0.01, 80, 8, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5333 @ epoch 2
# combo 430 / 500: (64, 16, 0.1, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5208 @ epoch 2
# combo 431 / 500: (128, 16, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5208 @ epoch 1
# combo 432 / 500: (128, 64, 0.5, 0.01, 100, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5008 @ epoch 2
# combo 433 / 500: (16, 128, 0.5, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.4950 @ epoch 1
# combo 434 / 500: (64, 256, 0.1, 0.01, 100, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5075 @ epoch 2
# combo 435 / 500: (256, 512, 0.5, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 436 / 500: (32, 256, 0.1, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5217 @ epoch 1
# combo 437 / 500: (512, 256, 0.5, 0.01, 50, 8, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5133 @ epoch 1
# combo 438 / 500: (512, 128, 0.3, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5058 @ epoch 5
# combo 439 / 500: (16, 16, 0.5, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5025 @ epoch 4
# combo 440 / 500: (32, 64, 0.3, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 109
# Best validation acc: 0.4950 @ epoch 9
# combo 441 / 500: (64, 128, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5400 @ epoch 4
# combo 442 / 500: (16, 128, 0.1, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5108 @ epoch 5
# combo 443 / 500: (16, 128, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5175 @ epoch 4
# combo 444 / 500: (256, 512, 0.1, 0.01, 50, 7, 0.3, 0.2, 256)
# Best validation acc: 0.5067 @ epoch 118
# combo 445 / 500: (128, 256, 0.3, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5000 @ epoch 2
# combo 446 / 500: (256, 512, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Best validation acc: 0.5067 @ epoch 130
# combo 447 / 500: (128, 64, 0.1, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5292 @ epoch 2
# combo 448 / 500: (32, 16, 0.5, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5092 @ epoch 3
# combo 449 / 500: (128, 256, 0.3, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5092 @ epoch 2
# combo 450 / 500: (512, 256, 0.5, 0.01, 50, 8, 0.1, 0.1, 512)
# Best validation acc: 0.5042 @ epoch 80
# combo 451 / 500: (128, 512, 0.5, 0.01, 80, 7, 0.3, 0.2, 512)
# Best validation acc: 0.4933 @ epoch 97
# combo 452 / 500: (128, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5458 @ epoch 4
# combo 453 / 500: (128, 128, 0.3, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5117 @ epoch 1
# combo 454 / 500: (256, 128, 0.3, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5008 @ epoch 0
# combo 455 / 500: (512, 256, 0.3, 0.01, 50, 9, 0.1, 0.2, 256)
# Best validation acc: 0.5042 @ epoch 149
# combo 456 / 500: (256, 256, 0.1, 0.01, 100, 9, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5033 @ epoch 5
# combo 457 / 500: (512, 64, 0.3, 0.01, 100, 7, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5308 @ epoch 3
# combo 458 / 500: (64, 32, 0.1, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5233 @ epoch 5
# combo 459 / 500: (512, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5300 @ epoch 4
# combo 460 / 500: (32, 512, 0.1, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5025 @ epoch 1
# combo 461 / 500: (64, 64, 0.3, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5150 @ epoch 1
# combo 462 / 500: (64, 64, 0.5, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5225 @ epoch 1
# combo 463 / 500: (128, 16, 0.3, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5258 @ epoch 5
# combo 464 / 500: (64, 512, 0.5, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.4900 @ epoch 1
# combo 465 / 500: (64, 16, 0.5, 0.01, 50, 8, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5008 @ epoch 3
# combo 466 / 500: (256, 512, 0.3, 0.01, 80, 9, 0.1, 0.1, 256)
# Best validation acc: 0.4950 @ epoch 126
# combo 467 / 500: (64, 32, 0.5, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5008 @ epoch 2
# combo 468 / 500: (256, 64, 0.1, 0.01, 50, 9, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5200 @ epoch 4
# combo 469 / 500: (32, 64, 0.1, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5200 @ epoch 6
# combo 470 / 500: (16, 32, 0.1, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5133 @ epoch 1
# combo 471 / 500: (64, 128, 0.3, 0.01, 100, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5017 @ epoch 1
# combo 472 / 500: (32, 256, 0.3, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5017 @ epoch 1
# combo 473 / 500: (256, 16, 0.5, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5208 @ epoch 2
# combo 474 / 500: (256, 256, 0.1, 0.01, 80, 9, 0.3, 0.2, 256)
# Best validation acc: 0.5092 @ epoch 116
# combo 475 / 500: (64, 256, 0.5, 0.01, 100, 7, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5100 @ epoch 1
# combo 476 / 500: (512, 512, 0.3, 0.01, 50, 8, 0.1, 0.1, 768)
# Best validation acc: 0.4975 @ epoch 148
# combo 477 / 500: (128, 256, 0.5, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 108
# Best validation acc: 0.4942 @ epoch 8
# combo 478 / 500: (32, 256, 0.3, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5142 @ epoch 1
# combo 479 / 500: (64, 32, 0.1, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5258 @ epoch 4
# combo 480 / 500: (64, 32, 0.1, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5308 @ epoch 5
# combo 481 / 500: (16, 256, 0.3, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5125 @ epoch 1
# combo 482 / 500: (16, 32, 0.3, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5058 @ epoch 3
# combo 483 / 500: (256, 32, 0.1, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5267 @ epoch 2
# combo 484 / 500: (64, 128, 0.5, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.4942 @ epoch 6
# combo 485 / 500: (128, 512, 0.3, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 122
# Best validation acc: 0.4917 @ epoch 22
# combo 486 / 500: (512, 128, 0.5, 0.01, 50, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5092 @ epoch 5
# combo 487 / 500: (16, 16, 0.5, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 108
# Best validation acc: 0.4983 @ epoch 8
# combo 488 / 500: (32, 32, 0.1, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5150 @ epoch 5
# combo 489 / 500: (128, 128, 0.3, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5092 @ epoch 1
# combo 490 / 500: (64, 512, 0.5, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5017 @ epoch 1
# combo 491 / 500: (128, 16, 0.1, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5200 @ epoch 4
# combo 492 / 500: (512, 128, 0.3, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5192 @ epoch 1
# combo 493 / 500: (256, 64, 0.3, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5242 @ epoch 2
# combo 494 / 500: (32, 16, 0.5, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.4958 @ epoch 6
# combo 495 / 500: (512, 64, 0.5, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5192 @ epoch 4
# combo 496 / 500: (512, 256, 0.3, 0.01, 80, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5042 @ epoch 1
# combo 497 / 500: (32, 16, 0.5, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5183 @ epoch 2
# combo 498 / 500: (16, 256, 0.3, 0.01, 80, 8, 0.1, 0.1, 512)
# Early stopping at epoch 110
# Best validation acc: 0.4958 @ epoch 10
# combo 499 / 500: (256, 256, 0.3, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5200 @ epoch 1
# combo 500 / 500: (32, 64, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5333 @ epoch 6
# {'h1': 256, 'h2': 32, 'dropout': 0.1, 'lr': 0.01, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'out_size_nrf': 768, 'epochs': 150, 'partition': 'gtd200', 'final_evaluation': False, 'n_class': 30}

# %%
save_metrics_txt(best_metrics, partition)
