# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from training import *
import torch
from itertools import product
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv")

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %%
from pathlib import Path
import numpy as np
from datetime import datetime

def save_metrics_txt(best_metrics, partition, append=False):
    """
    Write best_metrics to results/results_{partition}.txt as key: value lines.
    Set append=True to add another block instead of overwriting.
    """
    results_dir = Path("results")
    results_dir.mkdir(parents=True, exist_ok=True)
    path = results_dir / f"results_{partition}.txt"
    mode = "a" if append else "w"

    # make JSON-friendly scalars for numpy types
    def to_scalar(v):
        if isinstance(v, (np.floating,)):
            return float(v)
        if isinstance(v, (np.integer,)):
            return int(v)
        return v

    with open(path, mode, encoding="utf-8") as f:
        if append:
            f.write("\n" + "="*60 + "\n")
        f.write(f"Run saved: {datetime.now().isoformat(timespec='seconds')}\n")
        # align keys for readability
        width = max(len(k) for k in best_metrics.keys())
        for k in sorted(best_metrics.keys()):
            f.write(f"{k:<{width}} : {to_scalar(best_metrics[k])}\n")

# usage:
# save_metrics_txt(best_metrics, partition="gtd300", append=False)

# %%
node_feature_cols = [c for c in df.columns if c!='gname']
edge_feature_cols = ['attacktype1', 'target1']
edge_mode = 'hybrid_equal_knn'
equal_cols = [c for c in df.columns if c.startswith("longlat_")]
k = 7

#{'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'out_size_nrf': 1024, 'epochs': 500, 'partition': 'gtd100', 'final_evaluation': False, 'n_class': 30}
import random
param_grid = {
    'h1': [16, 32, 64, 128, 256, 512],
    'h2': [16, 32, 64, 128, 256, 512],
    'dropout': [0.1, 0.3, 0.5],
    'lr': [0.01],
    'n_tree': [50, 80,100],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.1,0.3],
    'feat_dropout': [0.1,0.2,0.3],
    'out_size_nrf': [256,512,768,1024]
    }

grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 500)

best_acc = -1
for i,combo in enumerate(sampled_combos):
    print(f"combo {i+1} / {len(sampled_combos)}: {combo}")
    nrf_cfg = {
        **dict(zip(param_names, combo)),
        "epochs": 150,
        "partition": f"gtd{partition}",   # one of: "gtd100", "gtd200", "gtd300", "gtd478"
        "final_evaluation": False,
        "lr": 0.01,
        "n_class": 30
    }

    test_acc, best_epoch, best_metrics, epoch_logs = train_joint_gcn_nrf(
        df,
        node_feature_cols,
        edge_feature_cols,
        edge_mode,
        equal_cols,
        k,
        nrf_cfg,
        weight_decay=0.15,
        device="cuda"
    )

    if test_acc > best_acc:
        best_acc = test_acc
        best_params = nrf_cfg

print(best_params)
# Out:
# combo 1 / 500: (64, 128, 0.3, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 112
# Best validation acc: 0.5406 @ epoch 12
# combo 2 / 500: (256, 32, 0.5, 0.01, 100, 8, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 3 / 500: (256, 32, 0.1, 0.01, 80, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5561 @ epoch 3
# combo 4 / 500: (512, 64, 0.1, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5728 @ epoch 4
# combo 5 / 500: (32, 16, 0.5, 0.01, 50, 8, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5528 @ epoch 3
# combo 6 / 500: (256, 128, 0.1, 0.01, 80, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5683 @ epoch 2
# combo 7 / 500: (32, 256, 0.1, 0.01, 80, 7, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5494 @ epoch 4
# combo 8 / 500: (256, 16, 0.5, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5672 @ epoch 1
# combo 9 / 500: (512, 32, 0.3, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5678 @ epoch 2
# combo 10 / 500: (64, 256, 0.5, 0.01, 80, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5383 @ epoch 2
# combo 11 / 500: (32, 256, 0.5, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 12 / 500: (256, 512, 0.3, 0.01, 80, 9, 0.3, 0.1, 512)
# Best validation acc: 0.5483 @ epoch 136
# combo 13 / 500: (32, 32, 0.3, 0.01, 100, 8, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5456 @ epoch 5
# combo 14 / 500: (256, 16, 0.3, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5478 @ epoch 5
# combo 15 / 500: (64, 128, 0.5, 0.01, 80, 8, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5450 @ epoch 1
# combo 16 / 500: (128, 256, 0.5, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 17 / 500: (32, 32, 0.5, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5417 @ epoch 4
# combo 18 / 500: (128, 128, 0.3, 0.01, 100, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 19 / 500: (64, 256, 0.1, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 20 / 500: (128, 512, 0.3, 0.01, 100, 9, 0.3, 0.2, 256)
# Best validation acc: 0.5417 @ epoch 70
# combo 21 / 500: (256, 128, 0.5, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 22 / 500: (256, 16, 0.1, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5539 @ epoch 3
# combo 23 / 500: (32, 128, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 107
# Best validation acc: 0.5428 @ epoch 7
# combo 24 / 500: (32, 512, 0.1, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5561 @ epoch 10
# combo 25 / 500: (512, 32, 0.1, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5689 @ epoch 3
# combo 26 / 500: (16, 512, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5339 @ epoch 5
# combo 27 / 500: (32, 32, 0.1, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5617 @ epoch 6
# combo 28 / 500: (128, 128, 0.3, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5600 @ epoch 1
# combo 29 / 500: (64, 32, 0.5, 0.01, 100, 9, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5439 @ epoch 3
# combo 30 / 500: (32, 32, 0.1, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5633 @ epoch 4
# combo 31 / 500: (128, 128, 0.5, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5400 @ epoch 1
# combo 32 / 500: (16, 512, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 33 / 500: (64, 128, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5450 @ epoch 1
# combo 34 / 500: (16, 512, 0.3, 0.01, 100, 9, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5406 @ epoch 6
# combo 35 / 500: (128, 128, 0.3, 0.01, 80, 8, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5494 @ epoch 1
# combo 36 / 500: (512, 512, 0.3, 0.01, 80, 8, 0.3, 0.2, 512)
# Best validation acc: 0.5339 @ epoch 71
# combo 37 / 500: (128, 128, 0.1, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5794 @ epoch 4
# combo 38 / 500: (16, 256, 0.3, 0.01, 50, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 107
# Best validation acc: 0.5417 @ epoch 7
# combo 39 / 500: (64, 256, 0.3, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 40 / 500: (64, 512, 0.5, 0.01, 80, 8, 0.3, 0.1, 512)
# Best validation acc: 0.5344 @ epoch 96
# combo 41 / 500: (128, 128, 0.5, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5439 @ epoch 1
# combo 42 / 500: (128, 256, 0.1, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 43 / 500: (128, 16, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5556 @ epoch 1
# combo 44 / 500: (64, 128, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5483 @ epoch 0
# combo 45 / 500: (512, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5506 @ epoch 4
# combo 46 / 500: (256, 64, 0.1, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5422 @ epoch 4
# combo 47 / 500: (256, 256, 0.1, 0.01, 50, 7, 0.1, 0.1, 512)
# Best validation acc: 0.5700 @ epoch 117
# combo 48 / 500: (128, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5444 @ epoch 1
# combo 49 / 500: (512, 512, 0.1, 0.01, 80, 8, 0.3, 0.2, 768)
# Best validation acc: 0.5422 @ epoch 146
# combo 50 / 500: (64, 256, 0.1, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 51 / 500: (512, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5756 @ epoch 3
# combo 52 / 500: (128, 32, 0.1, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5633 @ epoch 5
# combo 53 / 500: (32, 64, 0.3, 0.01, 50, 9, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5389 @ epoch 2
# combo 54 / 500: (512, 256, 0.5, 0.01, 50, 8, 0.1, 0.2, 512)
# Best validation acc: 0.5450 @ epoch 118
# combo 55 / 500: (16, 32, 0.5, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5394 @ epoch 6
# combo 56 / 500: (32, 16, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5550 @ epoch 2
# combo 57 / 500: (64, 128, 0.3, 0.01, 50, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 119
# Best validation acc: 0.5411 @ epoch 19
# combo 58 / 500: (256, 64, 0.1, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5672 @ epoch 2
# combo 59 / 500: (128, 32, 0.1, 0.01, 100, 7, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 60 / 500: (512, 64, 0.1, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 61 / 500: (32, 512, 0.1, 0.01, 100, 8, 0.3, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5550 @ epoch 5
# combo 62 / 500: (16, 128, 0.1, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5461 @ epoch 6
# combo 63 / 500: (32, 64, 0.3, 0.01, 50, 8, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 64 / 500: (256, 32, 0.5, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5656 @ epoch 1
# combo 65 / 500: (16, 256, 0.1, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5750 @ epoch 4
# combo 66 / 500: (64, 32, 0.5, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 67 / 500: (512, 512, 0.3, 0.01, 80, 8, 0.3, 0.2, 256)
# Best validation acc: 0.5394 @ epoch 143
# combo 68 / 500: (128, 64, 0.3, 0.01, 80, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 69 / 500: (64, 512, 0.5, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 111
# Best validation acc: 0.5367 @ epoch 11
# combo 70 / 500: (32, 256, 0.3, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5400 @ epoch 4
# combo 71 / 500: (16, 512, 0.5, 0.01, 100, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5550 @ epoch 1
# combo 72 / 500: (128, 512, 0.1, 0.01, 80, 9, 0.1, 0.2, 768)
# Best validation acc: 0.5533 @ epoch 105
# combo 73 / 500: (16, 64, 0.5, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5556 @ epoch 0
# combo 74 / 500: (512, 32, 0.1, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5644 @ epoch 3
# combo 75 / 500: (512, 256, 0.3, 0.01, 100, 8, 0.1, 0.3, 512)
# Best validation acc: 0.5456 @ epoch 137
# combo 76 / 500: (32, 64, 0.3, 0.01, 50, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5467 @ epoch 1
# combo 77 / 500: (16, 512, 0.3, 0.01, 50, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5467 @ epoch 1
# combo 78 / 500: (512, 16, 0.1, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5522 @ epoch 3
# combo 79 / 500: (16, 16, 0.3, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5439 @ epoch 4
# combo 80 / 500: (512, 256, 0.5, 0.01, 50, 9, 0.1, 0.2, 1024)
# Best validation acc: 0.5461 @ epoch 134
# combo 81 / 500: (16, 128, 0.3, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5522 @ epoch 0
# combo 82 / 500: (128, 256, 0.5, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 119
# Best validation acc: 0.5372 @ epoch 19
# combo 83 / 500: (128, 256, 0.1, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5583 @ epoch 5
# combo 84 / 500: (512, 512, 0.1, 0.01, 100, 7, 0.1, 0.3, 512)
# Best validation acc: 0.5356 @ epoch 143
# combo 85 / 500: (16, 256, 0.5, 0.01, 80, 9, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5461 @ epoch 1
# combo 86 / 500: (16, 128, 0.1, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5494 @ epoch 4
# combo 87 / 500: (32, 256, 0.1, 0.01, 50, 9, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5550 @ epoch 4
# combo 88 / 500: (16, 128, 0.5, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 100
# Best validation acc: 0.5494 @ epoch 0
# combo 89 / 500: (32, 512, 0.3, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 90 / 500: (16, 256, 0.1, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5678 @ epoch 5
# combo 91 / 500: (512, 16, 0.5, 0.01, 80, 9, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5500 @ epoch 3
# combo 92 / 500: (128, 64, 0.3, 0.01, 100, 9, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5456 @ epoch 6
# combo 93 / 500: (32, 32, 0.1, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5567 @ epoch 4
# combo 94 / 500: (64, 256, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5533 @ epoch 4
# combo 95 / 500: (128, 128, 0.1, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 96 / 500: (32, 16, 0.3, 0.01, 100, 9, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 97 / 500: (512, 64, 0.5, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5617 @ epoch 1
# combo 98 / 500: (128, 16, 0.3, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5633 @ epoch 2
# combo 99 / 500: (256, 16, 0.3, 0.01, 100, 8, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5594 @ epoch 3
# combo 100 / 500: (512, 128, 0.5, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 101 / 500: (64, 32, 0.5, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 102 / 500: (16, 512, 0.1, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5561 @ epoch 5
# combo 103 / 500: (256, 32, 0.5, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5450 @ epoch 2
# combo 104 / 500: (64, 16, 0.3, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 105 / 500: (16, 64, 0.3, 0.01, 50, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5533 @ epoch 1
# combo 106 / 500: (256, 128, 0.5, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5444 @ epoch 6
# combo 107 / 500: (32, 256, 0.3, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 108 / 500: (512, 64, 0.3, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5506 @ epoch 3
# combo 109 / 500: (32, 16, 0.3, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5478 @ epoch 2
# combo 110 / 500: (16, 256, 0.3, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.5467 @ epoch 6
# combo 111 / 500: (16, 64, 0.1, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 112 / 500: (128, 512, 0.1, 0.01, 100, 7, 0.3, 0.1, 256)
# Best validation acc: 0.5517 @ epoch 144
# combo 113 / 500: (256, 256, 0.1, 0.01, 80, 8, 0.3, 0.3, 1024)
# Best validation acc: 0.5550 @ epoch 132
# combo 114 / 500: (32, 256, 0.5, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5417 @ epoch 1
# combo 115 / 500: (128, 256, 0.3, 0.01, 100, 7, 0.1, 0.1, 256)
# Best validation acc: 0.5417 @ epoch 97
# combo 116 / 500: (512, 256, 0.1, 0.01, 100, 8, 0.3, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5339 @ epoch 5
# combo 117 / 500: (16, 64, 0.5, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5517 @ epoch 2
# combo 118 / 500: (64, 32, 0.3, 0.01, 50, 9, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5433 @ epoch 3
# combo 119 / 500: (64, 512, 0.1, 0.01, 100, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5456 @ epoch 5
# combo 120 / 500: (16, 256, 0.1, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5611 @ epoch 4
# combo 121 / 500: (512, 512, 0.5, 0.01, 50, 8, 0.1, 0.2, 1024)
# Best validation acc: 0.5389 @ epoch 116
# combo 122 / 500: (32, 512, 0.5, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5356 @ epoch 1
# combo 123 / 500: (16, 32, 0.1, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5633 @ epoch 3
# combo 124 / 500: (512, 256, 0.3, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5444 @ epoch 1
# combo 125 / 500: (32, 16, 0.5, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5633 @ epoch 1
# combo 126 / 500: (512, 16, 0.1, 0.01, 50, 8, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5589 @ epoch 4
# combo 127 / 500: (512, 64, 0.1, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5633 @ epoch 3
# combo 128 / 500: (512, 128, 0.3, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5867 @ epoch 4
# combo 129 / 500: (128, 32, 0.3, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5528 @ epoch 1
# combo 130 / 500: (256, 512, 0.3, 0.01, 50, 7, 0.1, 0.2, 512)
# Best validation acc: 0.5478 @ epoch 149
# combo 131 / 500: (64, 32, 0.1, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5556 @ epoch 5
# combo 132 / 500: (16, 256, 0.3, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5422 @ epoch 1
# combo 133 / 500: (256, 256, 0.3, 0.01, 50, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5500 @ epoch 2
# combo 134 / 500: (64, 512, 0.1, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 135 / 500: (128, 32, 0.5, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 112
# Best validation acc: 0.5378 @ epoch 12
# combo 136 / 500: (128, 512, 0.1, 0.01, 50, 9, 0.3, 0.2, 512)
# Best validation acc: 0.5528 @ epoch 128
# combo 137 / 500: (128, 16, 0.5, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5483 @ epoch 3
# combo 138 / 500: (64, 128, 0.5, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5372 @ epoch 3
# combo 139 / 500: (128, 128, 0.5, 0.01, 100, 7, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5372 @ epoch 5
# combo 140 / 500: (32, 512, 0.5, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 141 / 500: (64, 128, 0.5, 0.01, 50, 8, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5417 @ epoch 4
# combo 142 / 500: (64, 64, 0.1, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 143 / 500: (256, 64, 0.5, 0.01, 50, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 144 / 500: (16, 16, 0.3, 0.01, 80, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5467 @ epoch 3
# combo 145 / 500: (64, 512, 0.3, 0.01, 100, 9, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5406 @ epoch 5
# combo 146 / 500: (16, 128, 0.1, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.5561 @ epoch 6
# combo 147 / 500: (128, 512, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5356 @ epoch 4
# combo 148 / 500: (256, 256, 0.5, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5356 @ epoch 1
# combo 149 / 500: (256, 128, 0.5, 0.01, 80, 7, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5439 @ epoch 1
# combo 150 / 500: (16, 256, 0.3, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5372 @ epoch 2
# combo 151 / 500: (128, 128, 0.3, 0.01, 50, 9, 0.3, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5411 @ epoch 5
# combo 152 / 500: (64, 256, 0.5, 0.01, 50, 7, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 153 / 500: (32, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5472 @ epoch 5
# combo 154 / 500: (16, 512, 0.1, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5556 @ epoch 1
# combo 155 / 500: (16, 64, 0.3, 0.01, 50, 7, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 156 / 500: (16, 64, 0.3, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5606 @ epoch 1
# combo 157 / 500: (32, 16, 0.5, 0.01, 50, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5600 @ epoch 2
# combo 158 / 500: (128, 256, 0.5, 0.01, 50, 7, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5400 @ epoch 8
# combo 159 / 500: (128, 128, 0.5, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 160 / 500: (16, 64, 0.3, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 161 / 500: (256, 32, 0.3, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5483 @ epoch 5
# combo 162 / 500: (512, 16, 0.5, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 163 / 500: (32, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 113
# Best validation acc: 0.5344 @ epoch 13
# combo 164 / 500: (16, 256, 0.3, 0.01, 80, 7, 0.1, 0.2, 512)
# Early stopping at epoch 108
# Best validation acc: 0.5361 @ epoch 8
# combo 165 / 500: (128, 16, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 166 / 500: (32, 128, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 167 / 500: (64, 64, 0.1, 0.01, 100, 8, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5506 @ epoch 6
# combo 168 / 500: (16, 64, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5517 @ epoch 6
# combo 169 / 500: (256, 256, 0.1, 0.01, 50, 8, 0.3, 0.2, 256)
# Best validation acc: 0.5494 @ epoch 147
# combo 170 / 500: (16, 64, 0.1, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5467 @ epoch 6
# combo 171 / 500: (16, 512, 0.1, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.5556 @ epoch 6
# combo 172 / 500: (256, 32, 0.5, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5450 @ epoch 6
# combo 173 / 500: (256, 128, 0.5, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5400 @ epoch 2
# combo 174 / 500: (256, 256, 0.3, 0.01, 50, 7, 0.3, 0.3, 512)
# Best validation acc: 0.5483 @ epoch 132
# combo 175 / 500: (64, 256, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.5511 @ epoch 6
# combo 176 / 500: (32, 32, 0.1, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 177 / 500: (32, 512, 0.5, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5378 @ epoch 1
# combo 178 / 500: (128, 256, 0.1, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5694 @ epoch 4
# combo 179 / 500: (128, 128, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5633 @ epoch 1
# combo 180 / 500: (16, 256, 0.3, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 100
# Best validation acc: 0.5472 @ epoch 0
# combo 181 / 500: (128, 256, 0.3, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 182 / 500: (16, 16, 0.3, 0.01, 50, 9, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5511 @ epoch 3
# combo 183 / 500: (32, 128, 0.5, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5383 @ epoch 1
# combo 184 / 500: (16, 512, 0.1, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5683 @ epoch 1
# combo 185 / 500: (512, 64, 0.1, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5722 @ epoch 2
# combo 186 / 500: (32, 128, 0.3, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5450 @ epoch 1
# combo 187 / 500: (128, 256, 0.3, 0.01, 50, 7, 0.3, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5439 @ epoch 4
# combo 188 / 500: (64, 256, 0.1, 0.01, 100, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5672 @ epoch 4
# combo 189 / 500: (128, 512, 0.1, 0.01, 100, 8, 0.1, 0.3, 256)
# Best validation acc: 0.5594 @ epoch 147
# combo 190 / 500: (16, 64, 0.1, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5556 @ epoch 5
# combo 191 / 500: (128, 32, 0.3, 0.01, 50, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 192 / 500: (32, 16, 0.1, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 193 / 500: (32, 256, 0.1, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5578 @ epoch 3
# combo 194 / 500: (32, 256, 0.1, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5589 @ epoch 5
# combo 195 / 500: (128, 32, 0.3, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5517 @ epoch 2
# combo 196 / 500: (256, 16, 0.3, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5411 @ epoch 4
# combo 197 / 500: (512, 128, 0.5, 0.01, 50, 7, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 198 / 500: (16, 32, 0.3, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5411 @ epoch 6
# combo 199 / 500: (64, 128, 0.3, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 112
# Best validation acc: 0.5439 @ epoch 12
# combo 200 / 500: (256, 32, 0.3, 0.01, 80, 8, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5561 @ epoch 3
# combo 201 / 500: (16, 16, 0.5, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5428 @ epoch 3
# combo 202 / 500: (256, 32, 0.3, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5506 @ epoch 4
# combo 203 / 500: (64, 512, 0.3, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5378 @ epoch 3
# combo 204 / 500: (16, 16, 0.3, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5589 @ epoch 1
# combo 205 / 500: (64, 128, 0.5, 0.01, 80, 7, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5356 @ epoch 6
# combo 206 / 500: (256, 16, 0.5, 0.01, 100, 9, 0.1, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5417 @ epoch 1
# combo 207 / 500: (128, 256, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5422 @ epoch 0
# combo 208 / 500: (16, 512, 0.5, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5289 @ epoch 8
# combo 209 / 500: (512, 512, 0.3, 0.01, 100, 8, 0.1, 0.3, 768)
# Best validation acc: 0.5389 @ epoch 130
# combo 210 / 500: (128, 512, 0.5, 0.01, 100, 7, 0.3, 0.1, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5400 @ epoch 0
# combo 211 / 500: (32, 16, 0.3, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 212 / 500: (32, 32, 0.5, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5567 @ epoch 0
# combo 213 / 500: (64, 512, 0.5, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5367 @ epoch 2
# combo 214 / 500: (64, 16, 0.5, 0.01, 50, 8, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 215 / 500: (128, 16, 0.1, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5606 @ epoch 4
# combo 216 / 500: (128, 256, 0.1, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5467 @ epoch 1
# combo 217 / 500: (32, 256, 0.5, 0.01, 80, 7, 0.3, 0.2, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5328 @ epoch 7
# combo 218 / 500: (128, 256, 0.3, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5461 @ epoch 1
# combo 219 / 500: (64, 64, 0.1, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5578 @ epoch 4
# combo 220 / 500: (32, 512, 0.5, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5344 @ epoch 8
# combo 221 / 500: (128, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5428 @ epoch 6
# combo 222 / 500: (256, 256, 0.5, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5389 @ epoch 1
# combo 223 / 500: (64, 16, 0.1, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 224 / 500: (64, 128, 0.5, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5406 @ epoch 2
# combo 225 / 500: (128, 16, 0.1, 0.01, 100, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5672 @ epoch 5
# combo 226 / 500: (128, 512, 0.5, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5339 @ epoch 7
# combo 227 / 500: (32, 32, 0.1, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5506 @ epoch 5
# combo 228 / 500: (64, 512, 0.1, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 121
# Best validation acc: 0.5483 @ epoch 21
# combo 229 / 500: (512, 256, 0.3, 0.01, 100, 7, 0.1, 0.3, 768)
# Best validation acc: 0.5378 @ epoch 65
# combo 230 / 500: (16, 64, 0.1, 0.01, 80, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5533 @ epoch 1
# combo 231 / 500: (32, 256, 0.5, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5506 @ epoch 0
# combo 232 / 500: (16, 32, 0.3, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 233 / 500: (64, 16, 0.1, 0.01, 80, 9, 0.1, 0.2, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5578 @ epoch 7
# combo 234 / 500: (128, 32, 0.3, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5578 @ epoch 3
# combo 235 / 500: (256, 64, 0.1, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5733 @ epoch 3
# combo 236 / 500: (128, 256, 0.5, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5333 @ epoch 9
# combo 237 / 500: (32, 512, 0.3, 0.01, 100, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 238 / 500: (16, 256, 0.3, 0.01, 80, 9, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 239 / 500: (256, 16, 0.3, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5628 @ epoch 3
# combo 240 / 500: (32, 64, 0.1, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5494 @ epoch 5
# combo 241 / 500: (128, 256, 0.5, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5383 @ epoch 5
# combo 242 / 500: (128, 32, 0.1, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5561 @ epoch 1
# combo 243 / 500: (32, 128, 0.5, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 244 / 500: (512, 256, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5378 @ epoch 1
# combo 245 / 500: (256, 16, 0.3, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5500 @ epoch 3
# combo 246 / 500: (512, 256, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5394 @ epoch 3
# combo 247 / 500: (128, 256, 0.5, 0.01, 80, 8, 0.1, 0.3, 768)
# Early stopping at epoch 109
# Best validation acc: 0.5383 @ epoch 9
# combo 248 / 500: (512, 32, 0.5, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 249 / 500: (32, 128, 0.5, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5500 @ epoch 1
# combo 250 / 500: (32, 32, 0.3, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5428 @ epoch 2
# combo 251 / 500: (64, 32, 0.1, 0.01, 50, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5644 @ epoch 4
# combo 252 / 500: (64, 256, 0.1, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5633 @ epoch 5
# combo 253 / 500: (16, 64, 0.1, 0.01, 100, 9, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5661 @ epoch 2
# combo 254 / 500: (128, 16, 0.1, 0.01, 80, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5717 @ epoch 4
# combo 255 / 500: (32, 32, 0.3, 0.01, 80, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 256 / 500: (256, 32, 0.5, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5722 @ epoch 1
# combo 257 / 500: (256, 512, 0.5, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5367 @ epoch 2
# combo 258 / 500: (64, 16, 0.1, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5639 @ epoch 5
# combo 259 / 500: (128, 128, 0.3, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 260 / 500: (64, 32, 0.5, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 261 / 500: (16, 256, 0.5, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 262 / 500: (16, 16, 0.5, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5633 @ epoch 1
# combo 263 / 500: (512, 128, 0.1, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5650 @ epoch 1
# combo 264 / 500: (512, 128, 0.5, 0.01, 50, 8, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 265 / 500: (32, 512, 0.5, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5322 @ epoch 3
# combo 266 / 500: (256, 256, 0.1, 0.01, 100, 9, 0.1, 0.3, 256)
# Best validation acc: 0.5567 @ epoch 149
# combo 267 / 500: (128, 128, 0.1, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 268 / 500: (64, 16, 0.5, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5394 @ epoch 1
# combo 269 / 500: (16, 128, 0.3, 0.01, 80, 8, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5689 @ epoch 1
# combo 270 / 500: (64, 32, 0.1, 0.01, 100, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5644 @ epoch 3
# combo 271 / 500: (16, 16, 0.3, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5411 @ epoch 9
# combo 272 / 500: (64, 32, 0.5, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5383 @ epoch 6
# combo 273 / 500: (256, 64, 0.3, 0.01, 100, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5583 @ epoch 4
# combo 274 / 500: (128, 512, 0.5, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 110
# Best validation acc: 0.5317 @ epoch 10
# combo 275 / 500: (16, 16, 0.5, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 276 / 500: (512, 32, 0.5, 0.01, 100, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 277 / 500: (16, 128, 0.1, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5489 @ epoch 5
# combo 278 / 500: (256, 16, 0.5, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5506 @ epoch 2
# combo 279 / 500: (16, 256, 0.3, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 280 / 500: (512, 16, 0.3, 0.01, 100, 8, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 281 / 500: (128, 512, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Best validation acc: 0.5494 @ epoch 121
# combo 282 / 500: (16, 256, 0.1, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5594 @ epoch 4
# combo 283 / 500: (512, 16, 0.3, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5511 @ epoch 5
# combo 284 / 500: (256, 16, 0.1, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5689 @ epoch 3
# combo 285 / 500: (256, 64, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 286 / 500: (256, 64, 0.5, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 287 / 500: (64, 16, 0.3, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 111
# Best validation acc: 0.5428 @ epoch 11
# combo 288 / 500: (128, 32, 0.1, 0.01, 80, 9, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5633 @ epoch 1
# combo 289 / 500: (256, 64, 0.3, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5611 @ epoch 5
# combo 290 / 500: (16, 256, 0.1, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5556 @ epoch 1
# combo 291 / 500: (128, 128, 0.5, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5372 @ epoch 1
# combo 292 / 500: (16, 512, 0.1, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5444 @ epoch 5
# combo 293 / 500: (256, 512, 0.3, 0.01, 100, 9, 0.3, 0.1, 512)
# Best validation acc: 0.5494 @ epoch 146
# combo 294 / 500: (64, 32, 0.3, 0.01, 80, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5428 @ epoch 5
# combo 295 / 500: (64, 512, 0.5, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5356 @ epoch 4
# combo 296 / 500: (128, 32, 0.3, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 297 / 500: (64, 128, 0.3, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5494 @ epoch 1
# combo 298 / 500: (32, 64, 0.3, 0.01, 80, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 299 / 500: (32, 128, 0.5, 0.01, 100, 7, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5328 @ epoch 5
# combo 300 / 500: (128, 32, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5478 @ epoch 2
# combo 301 / 500: (32, 64, 0.5, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5439 @ epoch 1
# combo 302 / 500: (16, 128, 0.3, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 303 / 500: (32, 16, 0.3, 0.01, 100, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 304 / 500: (512, 512, 0.1, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 109
# Best validation acc: 0.5300 @ epoch 9
# combo 305 / 500: (256, 16, 0.3, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5461 @ epoch 5
# combo 306 / 500: (32, 64, 0.1, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5556 @ epoch 5
# combo 307 / 500: (256, 64, 0.5, 0.01, 80, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5567 @ epoch 0
# combo 308 / 500: (16, 128, 0.3, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5367 @ epoch 3
# combo 309 / 500: (512, 16, 0.5, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5611 @ epoch 3
# combo 310 / 500: (512, 16, 0.3, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5672 @ epoch 1
# combo 311 / 500: (64, 32, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5600 @ epoch 1
# combo 312 / 500: (64, 16, 0.3, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 313 / 500: (256, 64, 0.3, 0.01, 80, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5689 @ epoch 2
# combo 314 / 500: (512, 64, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5661 @ epoch 4
# combo 315 / 500: (16, 512, 0.5, 0.01, 100, 7, 0.3, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5378 @ epoch 1
# combo 316 / 500: (16, 32, 0.3, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 317 / 500: (128, 128, 0.3, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 318 / 500: (16, 32, 0.1, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 319 / 500: (128, 32, 0.1, 0.01, 80, 8, 0.1, 0.1, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5567 @ epoch 6
# combo 320 / 500: (256, 512, 0.3, 0.01, 50, 8, 0.1, 0.3, 768)
# Best validation acc: 0.5489 @ epoch 148
# combo 321 / 500: (512, 32, 0.1, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5883 @ epoch 2
# combo 322 / 500: (512, 32, 0.5, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 323 / 500: (256, 512, 0.3, 0.01, 100, 7, 0.3, 0.2, 1024)
# Best validation acc: 0.5478 @ epoch 145
# combo 324 / 500: (64, 16, 0.5, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5489 @ epoch 4
# combo 325 / 500: (512, 64, 0.5, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 326 / 500: (256, 64, 0.3, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 327 / 500: (32, 256, 0.5, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5400 @ epoch 4
# combo 328 / 500: (16, 128, 0.1, 0.01, 50, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 329 / 500: (32, 256, 0.3, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 111
# Best validation acc: 0.5406 @ epoch 11
# combo 330 / 500: (64, 128, 0.3, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5467 @ epoch 1
# combo 331 / 500: (128, 16, 0.1, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5628 @ epoch 1
# combo 332 / 500: (512, 512, 0.1, 0.01, 100, 8, 0.1, 0.2, 256)
# Best validation acc: 0.5317 @ epoch 138
# combo 333 / 500: (256, 128, 0.1, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5511 @ epoch 4
# combo 334 / 500: (16, 16, 0.1, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5506 @ epoch 7
# combo 335 / 500: (32, 16, 0.1, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 336 / 500: (256, 16, 0.3, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5550 @ epoch 4
# combo 337 / 500: (32, 128, 0.1, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5650 @ epoch 4
# combo 338 / 500: (16, 256, 0.5, 0.01, 100, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 339 / 500: (512, 32, 0.3, 0.01, 100, 9, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5589 @ epoch 5
# combo 340 / 500: (64, 64, 0.5, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5417 @ epoch 3
# combo 341 / 500: (128, 32, 0.5, 0.01, 100, 9, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5544 @ epoch 2
# combo 342 / 500: (512, 512, 0.1, 0.01, 100, 8, 0.1, 0.1, 1024)
# Best validation acc: 0.5478 @ epoch 140
# combo 343 / 500: (64, 128, 0.3, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5400 @ epoch 8
# combo 344 / 500: (512, 128, 0.5, 0.01, 100, 8, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 345 / 500: (64, 32, 0.5, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5611 @ epoch 1
# combo 346 / 500: (128, 16, 0.3, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5456 @ epoch 2
# combo 347 / 500: (16, 32, 0.3, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5433 @ epoch 3
# combo 348 / 500: (16, 64, 0.3, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 349 / 500: (64, 32, 0.3, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5428 @ epoch 2
# combo 350 / 500: (32, 512, 0.1, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 351 / 500: (16, 128, 0.3, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5422 @ epoch 2
# combo 352 / 500: (32, 64, 0.5, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5422 @ epoch 3
# combo 353 / 500: (64, 256, 0.3, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5389 @ epoch 5
# combo 354 / 500: (64, 128, 0.1, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5611 @ epoch 5
# combo 355 / 500: (256, 128, 0.3, 0.01, 80, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5472 @ epoch 3
# combo 356 / 500: (512, 128, 0.5, 0.01, 100, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5567 @ epoch 0
# combo 357 / 500: (32, 256, 0.3, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5433 @ epoch 6
# combo 358 / 500: (256, 128, 0.1, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5444 @ epoch 4
# combo 359 / 500: (16, 64, 0.3, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 360 / 500: (16, 32, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5606 @ epoch 2
# combo 361 / 500: (16, 64, 0.5, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 362 / 500: (32, 16, 0.3, 0.01, 50, 8, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5667 @ epoch 2
# combo 363 / 500: (128, 32, 0.3, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 364 / 500: (256, 128, 0.5, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5422 @ epoch 5
# combo 365 / 500: (512, 64, 0.5, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 112
# Best validation acc: 0.5378 @ epoch 12
# combo 366 / 500: (256, 64, 0.3, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 367 / 500: (16, 256, 0.1, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5650 @ epoch 5
# combo 368 / 500: (512, 64, 0.3, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 369 / 500: (16, 64, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5456 @ epoch 5
# combo 370 / 500: (32, 64, 0.5, 0.01, 50, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 371 / 500: (64, 64, 0.3, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 372 / 500: (16, 32, 0.5, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5472 @ epoch 3
# combo 373 / 500: (256, 64, 0.3, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5456 @ epoch 5
# combo 374 / 500: (128, 16, 0.3, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 375 / 500: (64, 256, 0.3, 0.01, 100, 8, 0.1, 0.1, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5433 @ epoch 10
# combo 376 / 500: (256, 256, 0.5, 0.01, 50, 8, 0.3, 0.1, 768)
# Best validation acc: 0.5411 @ epoch 121
# combo 377 / 500: (32, 32, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5344 @ epoch 5
# combo 378 / 500: (32, 256, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 379 / 500: (128, 16, 0.5, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 380 / 500: (512, 256, 0.5, 0.01, 80, 9, 0.1, 0.2, 512)
# Best validation acc: 0.5444 @ epoch 100
# combo 381 / 500: (16, 512, 0.3, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 382 / 500: (512, 128, 0.5, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5617 @ epoch 3
# combo 383 / 500: (32, 16, 0.5, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5400 @ epoch 9
# combo 384 / 500: (256, 16, 0.3, 0.01, 100, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5622 @ epoch 1
# combo 385 / 500: (64, 512, 0.3, 0.01, 80, 8, 0.1, 0.3, 768)
# Best validation acc: 0.5461 @ epoch 147
# combo 386 / 500: (256, 64, 0.1, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 387 / 500: (16, 256, 0.1, 0.01, 50, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5494 @ epoch 5
# combo 388 / 500: (64, 32, 0.1, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5606 @ epoch 3
# combo 389 / 500: (128, 64, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5661 @ epoch 4
# combo 390 / 500: (32, 16, 0.1, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5456 @ epoch 8
# combo 391 / 500: (128, 64, 0.5, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 392 / 500: (128, 32, 0.5, 0.01, 100, 7, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 393 / 500: (64, 256, 0.1, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5622 @ epoch 4
# combo 394 / 500: (64, 256, 0.1, 0.01, 100, 7, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5617 @ epoch 5
# combo 395 / 500: (512, 256, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Best validation acc: 0.5389 @ epoch 76
# combo 396 / 500: (128, 512, 0.1, 0.01, 80, 8, 0.3, 0.2, 512)
# Best validation acc: 0.5506 @ epoch 127
# combo 397 / 500: (64, 64, 0.1, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5711 @ epoch 5
# combo 398 / 500: (512, 32, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5528 @ epoch 5
# combo 399 / 500: (256, 256, 0.1, 0.01, 100, 8, 0.1, 0.1, 1024)
# Best validation acc: 0.5533 @ epoch 129
# combo 400 / 500: (16, 512, 0.5, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5394 @ epoch 1
# combo 401 / 500: (256, 16, 0.3, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5444 @ epoch 4
# combo 402 / 500: (128, 128, 0.3, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5400 @ epoch 8
# combo 403 / 500: (64, 256, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5533 @ epoch 4
# combo 404 / 500: (64, 128, 0.1, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5683 @ epoch 5
# combo 405 / 500: (128, 16, 0.3, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5533 @ epoch 3
# combo 406 / 500: (64, 128, 0.5, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5411 @ epoch 1
# combo 407 / 500: (512, 128, 0.3, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5528 @ epoch 3
# combo 408 / 500: (512, 512, 0.1, 0.01, 100, 8, 0.3, 0.2, 256)
# Best validation acc: 0.5428 @ epoch 143
# combo 409 / 500: (16, 32, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5500 @ epoch 1
# combo 410 / 500: (16, 64, 0.5, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5411 @ epoch 4
# combo 411 / 500: (16, 512, 0.5, 0.01, 80, 8, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5433 @ epoch 2
# combo 412 / 500: (256, 16, 0.5, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5461 @ epoch 5
# combo 413 / 500: (64, 32, 0.5, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5439 @ epoch 2
# combo 414 / 500: (512, 512, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Best validation acc: 0.5356 @ epoch 95
# combo 415 / 500: (256, 512, 0.3, 0.01, 80, 9, 0.3, 0.2, 256)
# Best validation acc: 0.5494 @ epoch 147
# combo 416 / 500: (512, 32, 0.5, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5344 @ epoch 7
# combo 417 / 500: (128, 512, 0.5, 0.01, 50, 7, 0.1, 0.2, 1024)
# Best validation acc: 0.5461 @ epoch 143
# combo 418 / 500: (512, 32, 0.5, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5611 @ epoch 1
# combo 419 / 500: (512, 16, 0.3, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 420 / 500: (32, 512, 0.3, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 421 / 500: (256, 16, 0.1, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5561 @ epoch 4
# combo 422 / 500: (256, 128, 0.3, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5467 @ epoch 4
# combo 423 / 500: (512, 128, 0.5, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5644 @ epoch 2
# combo 424 / 500: (16, 256, 0.1, 0.01, 100, 8, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5639 @ epoch 6
# combo 425 / 500: (16, 16, 0.1, 0.01, 50, 7, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5389 @ epoch 5
# combo 426 / 500: (16, 256, 0.5, 0.01, 80, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 427 / 500: (256, 256, 0.5, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 111
# Best validation acc: 0.5361 @ epoch 11
# combo 428 / 500: (256, 512, 0.3, 0.01, 50, 8, 0.1, 0.1, 512)
# Best validation acc: 0.5417 @ epoch 137
# combo 429 / 500: (256, 512, 0.1, 0.01, 80, 9, 0.3, 0.3, 512)
# Best validation acc: 0.5461 @ epoch 115
# combo 430 / 500: (64, 64, 0.3, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5444 @ epoch 1
# combo 431 / 500: (512, 16, 0.5, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 432 / 500: (128, 256, 0.5, 0.01, 80, 8, 0.1, 0.3, 1024)
# Best validation acc: 0.5439 @ epoch 122
# combo 433 / 500: (256, 256, 0.3, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5378 @ epoch 6
# combo 434 / 500: (16, 512, 0.1, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5722 @ epoch 5
# combo 435 / 500: (64, 128, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5494 @ epoch 2
# combo 436 / 500: (128, 32, 0.3, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 437 / 500: (16, 16, 0.5, 0.01, 50, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 438 / 500: (16, 512, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 100
# Best validation acc: 0.5456 @ epoch 0
# combo 439 / 500: (16, 64, 0.3, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5500 @ epoch 2
# combo 440 / 500: (16, 64, 0.3, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5444 @ epoch 6
# combo 441 / 500: (16, 128, 0.5, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 442 / 500: (32, 256, 0.5, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5417 @ epoch 1
# combo 443 / 500: (256, 512, 0.1, 0.01, 80, 8, 0.1, 0.1, 256)
# Best validation acc: 0.5372 @ epoch 119
# combo 444 / 500: (128, 128, 0.1, 0.01, 100, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5767 @ epoch 2
# combo 445 / 500: (512, 512, 0.3, 0.01, 100, 8, 0.3, 0.2, 1024)
# Best validation acc: 0.5400 @ epoch 149
# combo 446 / 500: (32, 64, 0.5, 0.01, 80, 9, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 447 / 500: (16, 128, 0.3, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5494 @ epoch 2
# combo 448 / 500: (32, 512, 0.3, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 449 / 500: (512, 128, 0.5, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5494 @ epoch 1
# combo 450 / 500: (128, 64, 0.5, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 451 / 500: (256, 512, 0.5, 0.01, 80, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5444 @ epoch 1
# combo 452 / 500: (256, 32, 0.1, 0.01, 50, 8, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5739 @ epoch 3
# combo 453 / 500: (64, 256, 0.1, 0.01, 50, 9, 0.3, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5450 @ epoch 8
# combo 454 / 500: (256, 256, 0.5, 0.01, 50, 7, 0.3, 0.3, 1024)
# Best validation acc: 0.5417 @ epoch 139
# combo 455 / 500: (512, 16, 0.1, 0.01, 50, 9, 0.1, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5606 @ epoch 4
# combo 456 / 500: (32, 128, 0.3, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5422 @ epoch 1
# combo 457 / 500: (128, 32, 0.5, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5483 @ epoch 2
# combo 458 / 500: (256, 512, 0.3, 0.01, 80, 7, 0.1, 0.3, 1024)
# Best validation acc: 0.5528 @ epoch 138
# combo 459 / 500: (256, 64, 0.5, 0.01, 50, 8, 0.1, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5456 @ epoch 1
# combo 460 / 500: (32, 256, 0.1, 0.01, 50, 8, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5694 @ epoch 5
# combo 461 / 500: (16, 16, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 462 / 500: (64, 256, 0.3, 0.01, 80, 7, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 463 / 500: (128, 512, 0.3, 0.01, 50, 7, 0.1, 0.3, 1024)
# Best validation acc: 0.5483 @ epoch 137
# combo 464 / 500: (64, 512, 0.1, 0.01, 50, 8, 0.1, 0.2, 512)
# Best validation acc: 0.5539 @ epoch 115
# combo 465 / 500: (32, 128, 0.5, 0.01, 100, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 466 / 500: (128, 256, 0.3, 0.01, 80, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 106
# Best validation acc: 0.5422 @ epoch 6
# combo 467 / 500: (128, 64, 0.1, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5661 @ epoch 3
# combo 468 / 500: (16, 256, 0.5, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5300 @ epoch 8
# combo 469 / 500: (512, 256, 0.3, 0.01, 100, 9, 0.3, 0.3, 256)
# Best validation acc: 0.5406 @ epoch 120
# combo 470 / 500: (512, 128, 0.3, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 471 / 500: (64, 512, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 110
# Best validation acc: 0.5472 @ epoch 10
# combo 472 / 500: (16, 32, 0.3, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5400 @ epoch 2
# combo 473 / 500: (16, 64, 0.1, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5533 @ epoch 6
# combo 474 / 500: (256, 256, 0.1, 0.01, 100, 7, 0.1, 0.1, 768)
# Best validation acc: 0.5483 @ epoch 144
# combo 475 / 500: (128, 512, 0.1, 0.01, 100, 8, 0.3, 0.2, 512)
# Best validation acc: 0.5472 @ epoch 124
# combo 476 / 500: (256, 512, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Best validation acc: 0.5472 @ epoch 148
# combo 477 / 500: (128, 256, 0.1, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5550 @ epoch 5
# combo 478 / 500: (256, 128, 0.5, 0.01, 100, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 479 / 500: (16, 32, 0.5, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5417 @ epoch 2
# combo 480 / 500: (16, 256, 0.3, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5428 @ epoch 3
# combo 481 / 500: (16, 128, 0.5, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5444 @ epoch 2
# combo 482 / 500: (16, 256, 0.1, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5617 @ epoch 5
# combo 483 / 500: (64, 512, 0.3, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 112
# Best validation acc: 0.5361 @ epoch 12
# combo 484 / 500: (64, 512, 0.3, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5400 @ epoch 7
# combo 485 / 500: (64, 256, 0.3, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5456 @ epoch 7
# combo 486 / 500: (256, 64, 0.3, 0.01, 80, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5678 @ epoch 1
# combo 487 / 500: (16, 64, 0.1, 0.01, 80, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5506 @ epoch 3
# combo 488 / 500: (128, 16, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5500 @ epoch 3
# combo 489 / 500: (128, 64, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5500 @ epoch 4
# combo 490 / 500: (128, 64, 0.5, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 491 / 500: (64, 512, 0.1, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5428 @ epoch 5
# combo 492 / 500: (128, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5467 @ epoch 3
# combo 493 / 500: (64, 32, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5528 @ epoch 1
# combo 494 / 500: (16, 256, 0.5, 0.01, 80, 7, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 495 / 500: (128, 16, 0.3, 0.01, 50, 8, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5428 @ epoch 3
# combo 496 / 500: (512, 16, 0.1, 0.01, 80, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5806 @ epoch 3
# combo 497 / 500: (256, 512, 0.1, 0.01, 80, 9, 0.3, 0.2, 768)
# Best validation acc: 0.5517 @ epoch 144
# combo 498 / 500: (32, 16, 0.3, 0.01, 100, 8, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 499 / 500: (256, 256, 0.1, 0.01, 100, 8, 0.3, 0.3, 256)
# Best validation acc: 0.5444 @ epoch 146
# combo 500 / 500: (32, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5500 @ epoch 1
# {'h1': 512, 'h2': 32, 'dropout': 0.1, 'lr': 0.01, 'n_tree': 50, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'out_size_nrf': 768, 'epochs': 150, 'partition': 'gtd300', 'final_evaluation': False, 'n_class': 30}

# %%
save_metrics_txt(best_metrics, partition)
