# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from training import *
import torch
from itertools import product
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from pathlib import Path
import numpy as np
from datetime import datetime

def save_metrics_txt(best_metrics, partition, best_params, append=False):
    """
    Write best_metrics to results/results_{partition}.txt as key: value lines.
    Set append=True to add another block instead of overwriting.
    """
    results_dir = Path("results")
    results_dir.mkdir(parents=True, exist_ok=True)
    path = results_dir / f"results_{partition}.txt"
    mode = "a" if append else "w"

    # make JSON-friendly scalars for numpy types
    def to_scalar(v):
        if isinstance(v, (np.floating,)):
            return float(v)
        if isinstance(v, (np.integer,)):
            return int(v)
        return v

    with open(path, mode, encoding="utf-8") as f:
        if append:
            f.write("\n" + "="*60 + "\n")
        f.write(f"Run saved: {datetime.now().isoformat(timespec='seconds')}\n")
        # align keys for readability
        f.write(f"{best_params}\n")
        width = max(len(k) for k in best_metrics.keys())
        for k in sorted(best_metrics.keys()):
            f.write(f"{k:<{width}} : {to_scalar(best_metrics[k])}\n")

# usage:
# save_metrics_txt(best_metrics, partition="gtd300", append=False)

# %%
import random 
node_feature_cols = [c for c in df.columns if c!='gname']
edge_feature_cols = ['attacktype1', 'target1']
edge_mode = 'hybrid_equal_knn'
equal_cols = ['encodedlonglat']
k = 10
#{'hidden_dims': 128, 'dropouts_gcn': 0.1, 'lr': 0.01, 'n_tree': 100, 'tree_depth': 7, 'tree_feature_rate': 0.3, 'feat_dropout': 0.3, 'out_size_nrf': 256, 'epochs': 300, 'partition': 'gtd100', 'final_evaluation': False, 'n_class': 30}
# Test acc 52.83
"""param_grid = {
    'hidden_dims': [32,64,128],
    'dropouts_gcn': [0.1, 0.3, 0.5],
    'lr': [0.01],
    'n_tree': [50, 70, 100],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.1,0.3],
    'feat_dropout': [0.1,0.3],
    'out_size_nrf': [256,512,768]
    }"""
#{'hidden_dims': 256, 'dropouts_gcn': 0.1, 'lr': 0.01, 'n_tree': 100, 'tree_depth': 7, 'tree_feature_rate': 0.3, 'feat_dropout': 0.3, 'out_size_nrf': 256, 'epochs': 300, 'partition': 'gtd100', 'final_evaluation': False, 'n_class': 30}
"""
param_grid = {
    'hidden_dims': [128, 256],
    'dropouts_gcn': [0.1],
    'lr': [0.01],
    'n_tree': [100, 120],
    'tree_depth': [7],
    'tree_feature_rate': [0.1,0.3],
    'feat_dropout': [0.1,0.3],
    'out_size_nrf': [256,512]
    } FULL """

param_grid = {
    'hidden_dims': [128],
    'dropouts_gcn': [0.1,0.3,0.5],
    'lr': [0.01],
    'n_tree': [100,120,80],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.1,0.3,0.5],
    'feat_dropout': [0.1,0.3],
    'out_size_nrf': [512]
    }

grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
#sampled_combos = random.sample(grid_combos, 100)

best_acc = -1
for combo in grid_combos:
    param_dict = dict(zip(param_names, combo))
    print(combo)
    nrf_cfg = {
        **dict(zip(param_names, combo)),
        "epochs": 300,
        "partition": f"gtd{partition}",   # one of: "gtd100", "gtd200", "gtd300", "gtd478"
        "final_evaluation": False,
        "n_class": 30
    }

    test_acc, best_epoch, best_metrics, epoch_logs = train_joint_gcn_nrf(
        df,
        node_feature_cols,
        edge_feature_cols,
        edge_mode,
        equal_cols,
        k,
        param_dict['hidden_dims'],
        param_dict['dropouts_gcn'],
        nrf_cfg,
        weight_decay=5e-4,
        device="cuda"
    )

    if test_acc > best_acc:
        best_acc = test_acc
        best_params = nrf_cfg

print(best_params)
# Out:
# (128, 0.1, 0.01, 100, 7, 0.1, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 273
# (128, 0.1, 0.01, 100, 7, 0.1, 0.3, 512)
# Best validation acc: 0.4367 @ epoch 247
# (128, 0.1, 0.01, 100, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4367 @ epoch 283
# (128, 0.1, 0.01, 100, 7, 0.3, 0.3, 512)
# Best validation acc: 0.4483 @ epoch 277
# (128, 0.1, 0.01, 100, 7, 0.5, 0.1, 512)
# Best validation acc: 0.4267 @ epoch 233
# (128, 0.1, 0.01, 100, 7, 0.5, 0.3, 512)
# Best validation acc: 0.4283 @ epoch 228
# (128, 0.1, 0.01, 100, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4483 @ epoch 298
# (128, 0.1, 0.01, 100, 8, 0.1, 0.3, 512)
# Best validation acc: 0.4483 @ epoch 298
# (128, 0.1, 0.01, 100, 8, 0.3, 0.1, 512)
# Best validation acc: 0.4400 @ epoch 272
# (128, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Best validation acc: 0.4317 @ epoch 275
# (128, 0.1, 0.01, 100, 8, 0.5, 0.1, 512)
# Best validation acc: 0.4267 @ epoch 236
# (128, 0.1, 0.01, 100, 8, 0.5, 0.3, 512)
# Best validation acc: 0.4533 @ epoch 293
# (128, 0.1, 0.01, 100, 9, 0.1, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 282
# (128, 0.1, 0.01, 100, 9, 0.1, 0.3, 512)
# Best validation acc: 0.4333 @ epoch 299
# (128, 0.1, 0.01, 100, 9, 0.3, 0.1, 512)
# Best validation acc: 0.4317 @ epoch 250
# (128, 0.1, 0.01, 100, 9, 0.3, 0.3, 512)
# Best validation acc: 0.4583 @ epoch 291
# (128, 0.1, 0.01, 100, 9, 0.5, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 295
# (128, 0.1, 0.01, 100, 9, 0.5, 0.3, 512)
# Best validation acc: 0.4383 @ epoch 297
# (128, 0.1, 0.01, 120, 7, 0.1, 0.1, 512)
# Best validation acc: 0.4367 @ epoch 294
# (128, 0.1, 0.01, 120, 7, 0.1, 0.3, 512)
# Best validation acc: 0.4550 @ epoch 294
# (128, 0.1, 0.01, 120, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4400 @ epoch 288
# (128, 0.1, 0.01, 120, 7, 0.3, 0.3, 512)
# Best validation acc: 0.4467 @ epoch 288
# (128, 0.1, 0.01, 120, 7, 0.5, 0.1, 512)
# Best validation acc: 0.4533 @ epoch 282
# (128, 0.1, 0.01, 120, 7, 0.5, 0.3, 512)
# Best validation acc: 0.4450 @ epoch 297
# (128, 0.1, 0.01, 120, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4550 @ epoch 279
# (128, 0.1, 0.01, 120, 8, 0.1, 0.3, 512)
# Best validation acc: 0.4400 @ epoch 250
# (128, 0.1, 0.01, 120, 8, 0.3, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 294
# (128, 0.1, 0.01, 120, 8, 0.3, 0.3, 512)
# Best validation acc: 0.4417 @ epoch 271
# (128, 0.1, 0.01, 120, 8, 0.5, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 270
# (128, 0.1, 0.01, 120, 8, 0.5, 0.3, 512)
# Best validation acc: 0.4500 @ epoch 283
# (128, 0.1, 0.01, 120, 9, 0.1, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 298
# (128, 0.1, 0.01, 120, 9, 0.1, 0.3, 512)
# Best validation acc: 0.4533 @ epoch 290
# (128, 0.1, 0.01, 120, 9, 0.3, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 285
# (128, 0.1, 0.01, 120, 9, 0.3, 0.3, 512)
# Best validation acc: 0.4350 @ epoch 292
# (128, 0.1, 0.01, 120, 9, 0.5, 0.1, 512)
# Best validation acc: 0.4367 @ epoch 294
# (128, 0.1, 0.01, 120, 9, 0.5, 0.3, 512)
# Best validation acc: 0.4417 @ epoch 299
# (128, 0.1, 0.01, 80, 7, 0.1, 0.1, 512)
# Best validation acc: 0.4550 @ epoch 287
# (128, 0.1, 0.01, 80, 7, 0.1, 0.3, 512)
# Best validation acc: 0.4433 @ epoch 294
# (128, 0.1, 0.01, 80, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4500 @ epoch 296
# (128, 0.1, 0.01, 80, 7, 0.3, 0.3, 512)
# Best validation acc: 0.4367 @ epoch 271
# (128, 0.1, 0.01, 80, 7, 0.5, 0.1, 512)
# Best validation acc: 0.4250 @ epoch 294
# (128, 0.1, 0.01, 80, 7, 0.5, 0.3, 512)
# Best validation acc: 0.4433 @ epoch 293
# (128, 0.1, 0.01, 80, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4317 @ epoch 240
# (128, 0.1, 0.01, 80, 8, 0.1, 0.3, 512)
# Best validation acc: 0.4317 @ epoch 297
# (128, 0.1, 0.01, 80, 8, 0.3, 0.1, 512)
# Best validation acc: 0.4467 @ epoch 248
# (128, 0.1, 0.01, 80, 8, 0.3, 0.3, 512)
# Best validation acc: 0.4400 @ epoch 290
# (128, 0.1, 0.01, 80, 8, 0.5, 0.1, 512)
# Best validation acc: 0.4333 @ epoch 271
# (128, 0.1, 0.01, 80, 8, 0.5, 0.3, 512)
# Best validation acc: 0.4500 @ epoch 281
# (128, 0.1, 0.01, 80, 9, 0.1, 0.1, 512)
# Best validation acc: 0.4383 @ epoch 298
# (128, 0.1, 0.01, 80, 9, 0.1, 0.3, 512)
# Best validation acc: 0.4400 @ epoch 298
# (128, 0.1, 0.01, 80, 9, 0.3, 0.1, 512)
# Best validation acc: 0.4283 @ epoch 246
# (128, 0.1, 0.01, 80, 9, 0.3, 0.3, 512)
# Best validation acc: 0.4350 @ epoch 286
# (128, 0.1, 0.01, 80, 9, 0.5, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 278
# (128, 0.1, 0.01, 80, 9, 0.5, 0.3, 512)
# Best validation acc: 0.4433 @ epoch 297
# (128, 0.3, 0.01, 100, 7, 0.1, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 278
# (128, 0.3, 0.01, 100, 7, 0.1, 0.3, 512)
# Best validation acc: 0.4517 @ epoch 265
# (128, 0.3, 0.01, 100, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4400 @ epoch 283
# (128, 0.3, 0.01, 100, 7, 0.3, 0.3, 512)
# Best validation acc: 0.4533 @ epoch 294
# (128, 0.3, 0.01, 100, 7, 0.5, 0.1, 512)
# Best validation acc: 0.4283 @ epoch 269
# (128, 0.3, 0.01, 100, 7, 0.5, 0.3, 512)
# Best validation acc: 0.4350 @ epoch 261
# (128, 0.3, 0.01, 100, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 297
# (128, 0.3, 0.01, 100, 8, 0.1, 0.3, 512)
# Best validation acc: 0.4350 @ epoch 282
# (128, 0.3, 0.01, 100, 8, 0.3, 0.1, 512)
# Best validation acc: 0.4417 @ epoch 288
# (128, 0.3, 0.01, 100, 8, 0.3, 0.3, 512)
# Best validation acc: 0.4400 @ epoch 278
# (128, 0.3, 0.01, 100, 8, 0.5, 0.1, 512)
# Best validation acc: 0.4350 @ epoch 248
# (128, 0.3, 0.01, 100, 8, 0.5, 0.3, 512)
# Best validation acc: 0.4450 @ epoch 257
# (128, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 277
# (128, 0.3, 0.01, 100, 9, 0.1, 0.3, 512)
# Best validation acc: 0.4367 @ epoch 271
# (128, 0.3, 0.01, 100, 9, 0.3, 0.1, 512)
# Best validation acc: 0.4450 @ epoch 295
# (128, 0.3, 0.01, 100, 9, 0.3, 0.3, 512)
# Best validation acc: 0.4367 @ epoch 294
# (128, 0.3, 0.01, 100, 9, 0.5, 0.1, 512)
# Best validation acc: 0.4333 @ epoch 286
# (128, 0.3, 0.01, 100, 9, 0.5, 0.3, 512)
# Best validation acc: 0.4350 @ epoch 299
# (128, 0.3, 0.01, 120, 7, 0.1, 0.1, 512)
# Best validation acc: 0.4333 @ epoch 279
# (128, 0.3, 0.01, 120, 7, 0.1, 0.3, 512)
# Best validation acc: 0.4417 @ epoch 273
# (128, 0.3, 0.01, 120, 7, 0.3, 0.1, 512)
# Best validation acc: 0.4517 @ epoch 285
# (128, 0.3, 0.01, 120, 7, 0.3, 0.3, 512)
# Best validation acc: 0.4400 @ epoch 299
# (128, 0.3, 0.01, 120, 7, 0.5, 0.1, 512)
# Best validation acc: 0.4233 @ epoch 281
# (128, 0.3, 0.01, 120, 7, 0.5, 0.3, 512)
# Best validation acc: 0.4267 @ epoch 278
# (128, 0.3, 0.01, 120, 8, 0.1, 0.1, 512)
# Best validation acc: 0.4433 @ epoch 281
# (128, 0.3, 0.01, 120, 8, 0.1, 0.3, 512)
# Best validation acc: 0.4417 @ epoch 291
# (128, 0.3, 0.01, 120, 8, 0.3, 0.1, 512)
# Best validation acc: 0.4333 @ epoch 262
# (128, 0.3, 0.01, 120, 8, 0.3, 0.3, 512)
# Best validation acc: 0.4383 @ epoch 288
# (128, 0.3, 0.01, 120, 8, 0.5, 0.1, 512)
# Best validation acc: 0.4300 @ epoch 255
# (128, 0.3, 0.01, 120, 8, 0.5, 0.3, 512)
# Best validation acc: 0.4250 @ epoch 261
# (128, 0.3, 0.01, 120, 9, 0.1, 0.1, 512)
# Best validation acc: 0.4417 @ epoch 249
# (128, 0.3, 0.01, 120, 9, 0.1, 0.3, 512)

# %%
save_metrics_txt(best_metrics, partition, best_params)
