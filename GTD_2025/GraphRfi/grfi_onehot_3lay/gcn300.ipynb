# %% [markdown]
# # Import and Read data

# %%
# %pip install haversine torch_geometric
# Out:
# Requirement already satisfied: haversine in /opt/conda/lib/python3.11/site-packages (2.9.0)
# Requirement already satisfied: torch_geometric in /opt/conda/lib/python3.11/site-packages (2.7.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (2024.5.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (5.9.8)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (2024.7.4)
#
# [notice] A new release of pip is available: 24.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('.')  # Add current directory to path
from training import *
import torch
from itertools import product
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv")

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %%
from pathlib import Path
import numpy as np
from datetime import datetime

def save_metrics_txt(best_metrics, partition, append=False):
    """
    Write best_metrics to results/results_{partition}.txt as key: value lines.
    Set append=True to add another block instead of overwriting.
    """
    results_dir = Path("results")
    results_dir.mkdir(parents=True, exist_ok=True)
    path = results_dir / f"results_{partition}.txt"
    mode = "a" if append else "w"

    # make JSON-friendly scalars for numpy types
    def to_scalar(v):
        if isinstance(v, (np.floating,)):
            return float(v)
        if isinstance(v, (np.integer,)):
            return int(v)
        return v

    with open(path, mode, encoding="utf-8") as f:
        if append:
            f.write("\n" + "="*60 + "\n")
        f.write(f"Run saved: {datetime.now().isoformat(timespec='seconds')}\n")
        # align keys for readability
        width = max(len(k) for k in best_metrics.keys())
        for k in sorted(best_metrics.keys()):
            f.write(f"{k:<{width}} : {to_scalar(best_metrics[k])}\n")

# usage:
# save_metrics_txt(best_metrics, partition="gtd300", append=False)

# %%
node_feature_cols = [c for c in df.columns if c!='gname']
edge_feature_cols = ['attacktype1', 'target1']
edge_mode = 'hybrid_equal_knn'
equal_cols = [c for c in df.columns if c.startswith("longlat_")]
k = 5

#{'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'out_size_nrf': 1024, 'epochs': 500, 'partition': 'gtd100', 'final_evaluation': False, 'n_class': 30}
import random
param_grid = {
    'h1': [16, 32, 64, 128, 256, 512],
    'h2': [16, 32, 64, 128, 256, 512],
    'h3': [16, 32, 64, 128],
    'dropout': [0.1, 0.3, 0.5],
    'lr': [0.01],
    'n_tree': [50, 80,100],
    'tree_depth': [7,8,9],
    'tree_feature_rate': [0.1,0.3],
    'feat_dropout': [0.1,0.2,0.3],
    'out_size_nrf': [256,512,768,1024]
    }

grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 500)

best_acc = -1
for i,combo in enumerate(sampled_combos):
    print(f"combo {i+1} / {len(sampled_combos)}: {combo}")
    nrf_cfg = {
        **dict(zip(param_names, combo)),
        "epochs": 150,
        "partition": f"gtd{partition}",   # one of: "gtd100", "gtd200", "gtd300", "gtd478"
        "final_evaluation": False,
        "lr": 0.01,
        "n_class": 30
    }

    test_acc, best_epoch, best_metrics, epoch_logs = train_joint_gcn_nrf(
        df,
        node_feature_cols,
        edge_feature_cols,
        edge_mode,
        equal_cols,
        k,
        nrf_cfg,
        weight_decay=5e-4,
        device="cuda"
    )

    if test_acc > best_acc:
        best_acc = test_acc
        best_params = nrf_cfg

print(best_params)
# Out:
# combo 1 / 500: (32, 16, 32, 0.3, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 2 / 500: (256, 128, 32, 0.5, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 3 / 500: (256, 32, 128, 0.5, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5456 @ epoch 2
# combo 4 / 500: (64, 16, 64, 0.1, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5567 @ epoch 3
# combo 5 / 500: (256, 32, 64, 0.1, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5594 @ epoch 5
# combo 6 / 500: (64, 128, 32, 0.3, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 7 / 500: (256, 128, 128, 0.3, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5511 @ epoch 3
# combo 8 / 500: (512, 128, 128, 0.3, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5606 @ epoch 2
# combo 9 / 500: (64, 64, 32, 0.3, 0.01, 50, 8, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 10 / 500: (16, 32, 128, 0.1, 0.01, 50, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 11 / 500: (128, 128, 16, 0.1, 0.01, 100, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5628 @ epoch 2
# combo 12 / 500: (64, 16, 16, 0.5, 0.01, 80, 7, 0.1, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5439 @ epoch 4
# combo 13 / 500: (64, 64, 32, 0.1, 0.01, 100, 7, 0.3, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5567 @ epoch 6
# combo 14 / 500: (512, 32, 32, 0.3, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5628 @ epoch 2
# combo 15 / 500: (64, 256, 128, 0.1, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 16 / 500: (16, 16, 128, 0.5, 0.01, 50, 9, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 17 / 500: (16, 256, 128, 0.1, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 18 / 500: (32, 64, 128, 0.1, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5544 @ epoch 6
# combo 19 / 500: (16, 32, 16, 0.1, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 20 / 500: (512, 64, 32, 0.3, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5450 @ epoch 8
# combo 21 / 500: (64, 32, 64, 0.3, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5622 @ epoch 1
# combo 22 / 500: (32, 512, 64, 0.5, 0.01, 50, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 23 / 500: (256, 64, 128, 0.3, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 24 / 500: (32, 512, 16, 0.5, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5550 @ epoch 3
# combo 25 / 500: (64, 128, 16, 0.1, 0.01, 80, 8, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5606 @ epoch 1
# combo 26 / 500: (16, 64, 128, 0.1, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5528 @ epoch 1
# combo 27 / 500: (512, 512, 32, 0.5, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5600 @ epoch 2
# combo 28 / 500: (128, 256, 32, 0.3, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5511 @ epoch 3
# combo 29 / 500: (64, 512, 128, 0.1, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 30 / 500: (256, 16, 128, 0.1, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5683 @ epoch 2
# combo 31 / 500: (64, 64, 64, 0.1, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5667 @ epoch 4
# combo 32 / 500: (32, 16, 32, 0.5, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5528 @ epoch 3
# combo 33 / 500: (512, 32, 128, 0.5, 0.01, 80, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5528 @ epoch 2
# combo 34 / 500: (256, 64, 32, 0.3, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5444 @ epoch 2
# combo 35 / 500: (512, 32, 32, 0.5, 0.01, 50, 9, 0.3, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5428 @ epoch 7
# combo 36 / 500: (512, 32, 128, 0.3, 0.01, 50, 8, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5417 @ epoch 5
# combo 37 / 500: (32, 128, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5439 @ epoch 7
# combo 38 / 500: (256, 64, 16, 0.5, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5433 @ epoch 4
# combo 39 / 500: (256, 32, 16, 0.5, 0.01, 80, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5489 @ epoch 2
# combo 40 / 500: (16, 16, 32, 0.5, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5428 @ epoch 4
# combo 41 / 500: (64, 16, 16, 0.5, 0.01, 50, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 42 / 500: (16, 32, 64, 0.3, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 43 / 500: (16, 64, 64, 0.5, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5417 @ epoch 3
# combo 44 / 500: (32, 16, 128, 0.3, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 45 / 500: (16, 16, 64, 0.1, 0.01, 80, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 46 / 500: (32, 512, 32, 0.3, 0.01, 100, 8, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 47 / 500: (128, 512, 128, 0.3, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5372 @ epoch 5
# combo 48 / 500: (64, 256, 64, 0.1, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5678 @ epoch 1
# combo 49 / 500: (64, 512, 128, 0.1, 0.01, 50, 7, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5456 @ epoch 1
# combo 50 / 500: (512, 512, 128, 0.1, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5383 @ epoch 4
# combo 51 / 500: (256, 512, 128, 0.1, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 52 / 500: (256, 256, 32, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5472 @ epoch 6
# combo 53 / 500: (64, 64, 32, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5600 @ epoch 1
# combo 54 / 500: (128, 128, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5383 @ epoch 3
# combo 55 / 500: (512, 128, 16, 0.1, 0.01, 50, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5556 @ epoch 4
# combo 56 / 500: (64, 64, 128, 0.5, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 57 / 500: (512, 32, 16, 0.5, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5394 @ epoch 8
# combo 58 / 500: (128, 32, 128, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5661 @ epoch 2
# combo 59 / 500: (32, 256, 128, 0.3, 0.01, 50, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5594 @ epoch 2
# combo 60 / 500: (128, 512, 32, 0.1, 0.01, 50, 7, 0.1, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5444 @ epoch 4
# combo 61 / 500: (128, 256, 128, 0.3, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 62 / 500: (64, 256, 32, 0.3, 0.01, 100, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 63 / 500: (256, 64, 128, 0.3, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 64 / 500: (256, 32, 64, 0.1, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5550 @ epoch 2
# combo 65 / 500: (32, 256, 32, 0.1, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5789 @ epoch 1
# combo 66 / 500: (512, 16, 128, 0.1, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 67 / 500: (16, 16, 64, 0.5, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5517 @ epoch 2
# combo 68 / 500: (64, 16, 128, 0.1, 0.01, 100, 7, 0.3, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5611 @ epoch 4
# combo 69 / 500: (512, 32, 16, 0.1, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 70 / 500: (128, 32, 32, 0.1, 0.01, 100, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5622 @ epoch 3
# combo 71 / 500: (16, 512, 128, 0.5, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 72 / 500: (16, 16, 32, 0.1, 0.01, 100, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5528 @ epoch 2
# combo 73 / 500: (256, 16, 16, 0.5, 0.01, 80, 7, 0.1, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5589 @ epoch 3
# combo 74 / 500: (64, 128, 64, 0.5, 0.01, 100, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5556 @ epoch 1
# combo 75 / 500: (256, 256, 32, 0.1, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5628 @ epoch 3
# combo 76 / 500: (256, 32, 32, 0.1, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5489 @ epoch 5
# combo 77 / 500: (32, 32, 128, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 78 / 500: (32, 64, 16, 0.1, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5556 @ epoch 4
# combo 79 / 500: (128, 512, 128, 0.1, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5389 @ epoch 9
# combo 80 / 500: (64, 64, 128, 0.1, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5583 @ epoch 4
# combo 81 / 500: (128, 256, 64, 0.1, 0.01, 50, 8, 0.1, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5411 @ epoch 7
# combo 82 / 500: (256, 128, 64, 0.5, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5433 @ epoch 10
# combo 83 / 500: (32, 32, 128, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 84 / 500: (64, 512, 32, 0.1, 0.01, 80, 9, 0.1, 0.3, 768)
# Early stopping at epoch 108
# Best validation acc: 0.5478 @ epoch 8
# combo 85 / 500: (256, 128, 128, 0.3, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 86 / 500: (64, 256, 32, 0.5, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5494 @ epoch 2
# combo 87 / 500: (512, 16, 16, 0.5, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5478 @ epoch 5
# combo 88 / 500: (16, 32, 32, 0.3, 0.01, 80, 7, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5522 @ epoch 3
# combo 89 / 500: (64, 64, 128, 0.3, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 90 / 500: (256, 128, 128, 0.5, 0.01, 80, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 91 / 500: (64, 512, 16, 0.5, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5406 @ epoch 4
# combo 92 / 500: (64, 512, 16, 0.3, 0.01, 50, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5639 @ epoch 2
# combo 93 / 500: (128, 16, 128, 0.5, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5444 @ epoch 4
# combo 94 / 500: (512, 128, 32, 0.3, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5561 @ epoch 2
# combo 95 / 500: (64, 32, 64, 0.1, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5561 @ epoch 4
# combo 96 / 500: (32, 256, 64, 0.1, 0.01, 100, 7, 0.1, 0.2, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5517 @ epoch 7
# combo 97 / 500: (32, 512, 16, 0.1, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5506 @ epoch 3
# combo 98 / 500: (16, 512, 32, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5683 @ epoch 1
# combo 99 / 500: (128, 256, 128, 0.1, 0.01, 80, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5706 @ epoch 1
# combo 100 / 500: (32, 32, 128, 0.1, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5456 @ epoch 2
# combo 101 / 500: (256, 128, 16, 0.1, 0.01, 100, 9, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5489 @ epoch 4
# combo 102 / 500: (16, 256, 64, 0.1, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5511 @ epoch 6
# combo 103 / 500: (64, 128, 64, 0.1, 0.01, 50, 9, 0.1, 0.1, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5622 @ epoch 6
# combo 104 / 500: (256, 64, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5722 @ epoch 2
# combo 105 / 500: (16, 32, 16, 0.5, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 106 / 500: (256, 64, 16, 0.1, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5533 @ epoch 4
# combo 107 / 500: (32, 64, 128, 0.5, 0.01, 50, 9, 0.3, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5389 @ epoch 6
# combo 108 / 500: (512, 512, 64, 0.3, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5450 @ epoch 5
# combo 109 / 500: (512, 256, 64, 0.3, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 110 / 500: (16, 128, 64, 0.3, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5506 @ epoch 2
# combo 111 / 500: (32, 32, 16, 0.3, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5628 @ epoch 4
# combo 112 / 500: (64, 128, 128, 0.1, 0.01, 80, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 113 / 500: (32, 16, 32, 0.1, 0.01, 50, 7, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5611 @ epoch 4
# combo 114 / 500: (256, 128, 16, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 115 / 500: (128, 32, 128, 0.5, 0.01, 80, 7, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5439 @ epoch 1
# combo 116 / 500: (256, 128, 128, 0.5, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5400 @ epoch 5
# combo 117 / 500: (32, 16, 128, 0.5, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 118 / 500: (16, 64, 16, 0.3, 0.01, 50, 8, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 119 / 500: (64, 512, 128, 0.3, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 120 / 500: (32, 128, 128, 0.3, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5483 @ epoch 6
# combo 121 / 500: (128, 64, 16, 0.5, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5472 @ epoch 3
# combo 122 / 500: (16, 256, 32, 0.5, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 123 / 500: (16, 256, 32, 0.1, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5556 @ epoch 4
# combo 124 / 500: (128, 512, 16, 0.3, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 125 / 500: (64, 256, 64, 0.1, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5611 @ epoch 1
# combo 126 / 500: (256, 64, 128, 0.5, 0.01, 100, 7, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5478 @ epoch 2
# combo 127 / 500: (256, 16, 32, 0.1, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5567 @ epoch 3
# combo 128 / 500: (16, 16, 128, 0.1, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 129 / 500: (128, 128, 16, 0.3, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5456 @ epoch 4
# combo 130 / 500: (16, 32, 32, 0.3, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5483 @ epoch 3
# combo 131 / 500: (512, 32, 16, 0.5, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5600 @ epoch 3
# combo 132 / 500: (16, 32, 64, 0.5, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5383 @ epoch 6
# combo 133 / 500: (64, 256, 16, 0.1, 0.01, 100, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5617 @ epoch 2
# combo 134 / 500: (16, 32, 128, 0.1, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5367 @ epoch 6
# combo 135 / 500: (64, 128, 32, 0.1, 0.01, 80, 7, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5672 @ epoch 3
# combo 136 / 500: (256, 512, 128, 0.3, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5411 @ epoch 5
# combo 137 / 500: (16, 128, 64, 0.5, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 138 / 500: (256, 256, 32, 0.1, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 139 / 500: (32, 64, 64, 0.3, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 140 / 500: (64, 64, 128, 0.3, 0.01, 100, 7, 0.1, 0.2, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5444 @ epoch 5
# combo 141 / 500: (128, 64, 128, 0.1, 0.01, 50, 8, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5522 @ epoch 4
# combo 142 / 500: (32, 512, 64, 0.1, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 143 / 500: (128, 256, 16, 0.3, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5594 @ epoch 3
# combo 144 / 500: (128, 16, 16, 0.3, 0.01, 80, 8, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5489 @ epoch 5
# combo 145 / 500: (128, 256, 32, 0.3, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5500 @ epoch 2
# combo 146 / 500: (128, 16, 128, 0.5, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5506 @ epoch 1
# combo 147 / 500: (64, 32, 128, 0.5, 0.01, 50, 8, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5350 @ epoch 5
# combo 148 / 500: (512, 64, 16, 0.3, 0.01, 80, 8, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5617 @ epoch 3
# combo 149 / 500: (32, 128, 32, 0.5, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5450 @ epoch 3
# combo 150 / 500: (256, 64, 16, 0.3, 0.01, 50, 7, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5483 @ epoch 3
# combo 151 / 500: (16, 512, 32, 0.3, 0.01, 100, 7, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5650 @ epoch 1
# combo 152 / 500: (128, 64, 16, 0.3, 0.01, 80, 9, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5589 @ epoch 3
# combo 153 / 500: (512, 32, 16, 0.3, 0.01, 80, 7, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 154 / 500: (64, 128, 32, 0.5, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5556 @ epoch 1
# combo 155 / 500: (128, 16, 16, 0.5, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5378 @ epoch 6
# combo 156 / 500: (32, 128, 64, 0.1, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 157 / 500: (512, 16, 64, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5483 @ epoch 3
# combo 158 / 500: (128, 128, 32, 0.5, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 159 / 500: (32, 16, 32, 0.5, 0.01, 80, 9, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5456 @ epoch 4
# combo 160 / 500: (128, 32, 64, 0.5, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5378 @ epoch 2
# combo 161 / 500: (32, 32, 64, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 162 / 500: (128, 32, 32, 0.1, 0.01, 80, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 163 / 500: (64, 64, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5389 @ epoch 10
# combo 164 / 500: (32, 32, 16, 0.3, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5628 @ epoch 2
# combo 165 / 500: (512, 128, 64, 0.3, 0.01, 80, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5572 @ epoch 2
# combo 166 / 500: (128, 64, 16, 0.5, 0.01, 100, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 167 / 500: (16, 64, 32, 0.5, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5450 @ epoch 3
# combo 168 / 500: (16, 128, 128, 0.3, 0.01, 50, 7, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5378 @ epoch 8
# combo 169 / 500: (256, 16, 64, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5528 @ epoch 3
# combo 170 / 500: (128, 256, 64, 0.1, 0.01, 80, 8, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5567 @ epoch 4
# combo 171 / 500: (256, 64, 32, 0.5, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5567 @ epoch 0
# combo 172 / 500: (512, 32, 64, 0.3, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5428 @ epoch 5
# combo 173 / 500: (128, 16, 64, 0.3, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 174 / 500: (512, 16, 64, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 175 / 500: (128, 256, 64, 0.3, 0.01, 100, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5544 @ epoch 2
# combo 176 / 500: (512, 32, 32, 0.5, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 177 / 500: (512, 32, 128, 0.5, 0.01, 50, 7, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 178 / 500: (16, 16, 16, 0.5, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5617 @ epoch 3
# combo 179 / 500: (512, 64, 32, 0.3, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 180 / 500: (128, 16, 128, 0.3, 0.01, 50, 7, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5561 @ epoch 2
# combo 181 / 500: (512, 64, 128, 0.1, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5728 @ epoch 2
# combo 182 / 500: (512, 32, 32, 0.3, 0.01, 100, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 183 / 500: (32, 128, 32, 0.5, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 184 / 500: (32, 32, 64, 0.3, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 185 / 500: (256, 16, 16, 0.5, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5444 @ epoch 4
# combo 186 / 500: (128, 512, 32, 0.3, 0.01, 100, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 187 / 500: (512, 32, 64, 0.5, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5378 @ epoch 3
# combo 188 / 500: (32, 512, 64, 0.3, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 189 / 500: (512, 128, 64, 0.3, 0.01, 80, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5478 @ epoch 4
# combo 190 / 500: (16, 512, 128, 0.5, 0.01, 100, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5533 @ epoch 1
# combo 191 / 500: (16, 512, 128, 0.5, 0.01, 100, 9, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5472 @ epoch 4
# combo 192 / 500: (16, 32, 64, 0.5, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5428 @ epoch 0
# combo 193 / 500: (128, 256, 128, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 194 / 500: (16, 512, 16, 0.5, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5717 @ epoch 1
# combo 195 / 500: (256, 256, 16, 0.3, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 196 / 500: (256, 512, 32, 0.5, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5533 @ epoch 5
# combo 197 / 500: (16, 32, 128, 0.5, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5356 @ epoch 3
# combo 198 / 500: (128, 128, 32, 0.1, 0.01, 80, 7, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5600 @ epoch 4
# combo 199 / 500: (512, 256, 32, 0.1, 0.01, 80, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5567 @ epoch 2
# combo 200 / 500: (32, 256, 128, 0.5, 0.01, 80, 9, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5494 @ epoch 3
# combo 201 / 500: (256, 32, 64, 0.3, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 202 / 500: (64, 64, 128, 0.1, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5711 @ epoch 5
# combo 203 / 500: (32, 64, 32, 0.1, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5544 @ epoch 4
# combo 204 / 500: (64, 64, 128, 0.1, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5672 @ epoch 5
# combo 205 / 500: (128, 512, 32, 0.3, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5711 @ epoch 2
# combo 206 / 500: (64, 16, 32, 0.1, 0.01, 100, 9, 0.1, 0.3, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5433 @ epoch 10
# combo 207 / 500: (256, 64, 32, 0.5, 0.01, 50, 8, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 208 / 500: (32, 256, 64, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5450 @ epoch 4
# combo 209 / 500: (16, 256, 32, 0.3, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 210 / 500: (32, 512, 64, 0.1, 0.01, 100, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5661 @ epoch 1
# combo 211 / 500: (64, 256, 128, 0.1, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5483 @ epoch 7
# combo 212 / 500: (32, 16, 32, 0.1, 0.01, 50, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5683 @ epoch 3
# combo 213 / 500: (512, 128, 128, 0.1, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5706 @ epoch 1
# combo 214 / 500: (128, 128, 128, 0.3, 0.01, 100, 9, 0.3, 0.1, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5661 @ epoch 0
# combo 215 / 500: (16, 16, 32, 0.5, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5589 @ epoch 1
# combo 216 / 500: (16, 16, 32, 0.5, 0.01, 100, 8, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5444 @ epoch 5
# combo 217 / 500: (16, 32, 16, 0.5, 0.01, 100, 7, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5528 @ epoch 3
# combo 218 / 500: (32, 64, 128, 0.3, 0.01, 100, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5417 @ epoch 2
# combo 219 / 500: (512, 16, 32, 0.5, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 220 / 500: (32, 16, 64, 0.3, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5494 @ epoch 2
# combo 221 / 500: (64, 16, 64, 0.5, 0.01, 100, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5483 @ epoch 1
# combo 222 / 500: (16, 128, 16, 0.5, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5439 @ epoch 4
# combo 223 / 500: (32, 64, 64, 0.5, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5433 @ epoch 1
# combo 224 / 500: (32, 16, 16, 0.1, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5700 @ epoch 1
# combo 225 / 500: (64, 32, 16, 0.3, 0.01, 50, 7, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 226 / 500: (512, 32, 32, 0.1, 0.01, 80, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5556 @ epoch 3
# combo 227 / 500: (32, 16, 16, 0.1, 0.01, 50, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5572 @ epoch 2
# combo 228 / 500: (64, 64, 32, 0.1, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5633 @ epoch 1
# combo 229 / 500: (32, 64, 64, 0.3, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 230 / 500: (32, 128, 32, 0.1, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 106
# Best validation acc: 0.5578 @ epoch 6
# combo 231 / 500: (64, 512, 64, 0.3, 0.01, 50, 9, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5372 @ epoch 2
# combo 232 / 500: (128, 16, 64, 0.3, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5500 @ epoch 4
# combo 233 / 500: (16, 256, 128, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5456 @ epoch 2
# combo 234 / 500: (128, 512, 128, 0.5, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5378 @ epoch 4
# combo 235 / 500: (256, 128, 128, 0.1, 0.01, 50, 7, 0.3, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 236 / 500: (64, 32, 128, 0.5, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5378 @ epoch 5
# combo 237 / 500: (512, 256, 16, 0.3, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5511 @ epoch 4
# combo 238 / 500: (256, 64, 128, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5628 @ epoch 3
# combo 239 / 500: (32, 32, 128, 0.1, 0.01, 100, 8, 0.1, 0.2, 768)
# Early stopping at epoch 107
# Best validation acc: 0.5533 @ epoch 7
# combo 240 / 500: (256, 128, 32, 0.3, 0.01, 100, 9, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5644 @ epoch 2
# combo 241 / 500: (32, 512, 128, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5611 @ epoch 1
# combo 242 / 500: (64, 32, 128, 0.5, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5450 @ epoch 3
# combo 243 / 500: (64, 16, 128, 0.3, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5461 @ epoch 0
# combo 244 / 500: (128, 64, 32, 0.1, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5828 @ epoch 2
# combo 245 / 500: (16, 128, 32, 0.1, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5478 @ epoch 8
# combo 246 / 500: (512, 256, 128, 0.1, 0.01, 50, 9, 0.1, 0.3, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5394 @ epoch 9
# combo 247 / 500: (256, 512, 64, 0.5, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 248 / 500: (16, 512, 16, 0.1, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 249 / 500: (256, 256, 16, 0.1, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5678 @ epoch 2
# combo 250 / 500: (16, 256, 32, 0.1, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5572 @ epoch 3
# combo 251 / 500: (256, 256, 128, 0.5, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 252 / 500: (128, 32, 64, 0.5, 0.01, 50, 8, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 253 / 500: (64, 256, 64, 0.1, 0.01, 80, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5583 @ epoch 4
# combo 254 / 500: (256, 128, 64, 0.5, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 255 / 500: (256, 256, 64, 0.1, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5506 @ epoch 4
# combo 256 / 500: (64, 32, 32, 0.3, 0.01, 80, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5450 @ epoch 4
# combo 257 / 500: (512, 64, 16, 0.3, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5378 @ epoch 3
# combo 258 / 500: (64, 512, 32, 0.1, 0.01, 50, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5611 @ epoch 2
# combo 259 / 500: (32, 64, 64, 0.1, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5756 @ epoch 4
# combo 260 / 500: (128, 64, 64, 0.5, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 261 / 500: (256, 512, 32, 0.3, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 262 / 500: (64, 512, 128, 0.3, 0.01, 80, 9, 0.1, 0.1, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5394 @ epoch 4
# combo 263 / 500: (256, 16, 128, 0.5, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 264 / 500: (32, 16, 16, 0.1, 0.01, 80, 9, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5644 @ epoch 1
# combo 265 / 500: (32, 128, 16, 0.5, 0.01, 80, 7, 0.1, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5483 @ epoch 2
# combo 266 / 500: (256, 32, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5528 @ epoch 2
# combo 267 / 500: (512, 32, 64, 0.5, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 268 / 500: (128, 128, 16, 0.3, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5461 @ epoch 4
# combo 269 / 500: (128, 16, 64, 0.1, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5372 @ epoch 7
# combo 270 / 500: (16, 16, 32, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 271 / 500: (32, 32, 32, 0.1, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5633 @ epoch 2
# combo 272 / 500: (32, 16, 16, 0.5, 0.01, 50, 7, 0.1, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5433 @ epoch 4
# combo 273 / 500: (32, 512, 64, 0.3, 0.01, 50, 8, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5444 @ epoch 3
# combo 274 / 500: (256, 64, 16, 0.3, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 275 / 500: (64, 32, 64, 0.5, 0.01, 80, 8, 0.1, 0.1, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5361 @ epoch 5
# combo 276 / 500: (32, 32, 32, 0.5, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 277 / 500: (512, 32, 128, 0.3, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5428 @ epoch 7
# combo 278 / 500: (64, 16, 16, 0.1, 0.01, 80, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 279 / 500: (256, 256, 128, 0.5, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5472 @ epoch 3
# combo 280 / 500: (256, 64, 64, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5572 @ epoch 3
# combo 281 / 500: (64, 32, 64, 0.1, 0.01, 100, 9, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5606 @ epoch 1
# combo 282 / 500: (256, 32, 16, 0.1, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 283 / 500: (256, 256, 128, 0.3, 0.01, 100, 8, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5361 @ epoch 5
# combo 284 / 500: (256, 64, 16, 0.3, 0.01, 100, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5561 @ epoch 2
# combo 285 / 500: (256, 32, 128, 0.1, 0.01, 80, 9, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5683 @ epoch 4
# combo 286 / 500: (16, 32, 128, 0.1, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5678 @ epoch 1
# combo 287 / 500: (256, 32, 16, 0.3, 0.01, 80, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5506 @ epoch 2
# combo 288 / 500: (16, 64, 32, 0.5, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 289 / 500: (64, 128, 32, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5439 @ epoch 3
# combo 290 / 500: (256, 32, 16, 0.1, 0.01, 80, 9, 0.3, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5750 @ epoch 3
# combo 291 / 500: (32, 512, 16, 0.1, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5550 @ epoch 3
# combo 292 / 500: (128, 512, 32, 0.5, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 293 / 500: (256, 32, 16, 0.5, 0.01, 100, 9, 0.1, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 294 / 500: (16, 16, 128, 0.5, 0.01, 100, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5467 @ epoch 5
# combo 295 / 500: (512, 16, 32, 0.5, 0.01, 80, 7, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5450 @ epoch 4
# combo 296 / 500: (512, 256, 16, 0.1, 0.01, 80, 7, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5594 @ epoch 2
# combo 297 / 500: (256, 128, 128, 0.5, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5328 @ epoch 10
# combo 298 / 500: (32, 128, 128, 0.5, 0.01, 50, 7, 0.1, 0.2, 256)
# Early stopping at epoch 111
# Best validation acc: 0.5311 @ epoch 11
# combo 299 / 500: (256, 32, 64, 0.1, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5622 @ epoch 2
# combo 300 / 500: (32, 512, 32, 0.3, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5456 @ epoch 2
# combo 301 / 500: (64, 16, 32, 0.3, 0.01, 80, 8, 0.1, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5517 @ epoch 5
# combo 302 / 500: (32, 64, 64, 0.3, 0.01, 50, 9, 0.1, 0.2, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5400 @ epoch 9
# combo 303 / 500: (256, 128, 128, 0.1, 0.01, 100, 7, 0.3, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5500 @ epoch 5
# combo 304 / 500: (32, 16, 16, 0.3, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 305 / 500: (256, 32, 128, 0.5, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5422 @ epoch 4
# combo 306 / 500: (256, 128, 32, 0.3, 0.01, 100, 8, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 307 / 500: (32, 256, 128, 0.1, 0.01, 100, 8, 0.3, 0.2, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5506 @ epoch 0
# combo 308 / 500: (128, 512, 16, 0.5, 0.01, 100, 7, 0.1, 0.1, 256)
# Early stopping at epoch 111
# Best validation acc: 0.5367 @ epoch 11
# combo 309 / 500: (512, 32, 32, 0.1, 0.01, 50, 7, 0.3, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5622 @ epoch 3
# combo 310 / 500: (16, 16, 32, 0.1, 0.01, 50, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 311 / 500: (256, 64, 16, 0.5, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5522 @ epoch 4
# combo 312 / 500: (64, 16, 32, 0.3, 0.01, 100, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5739 @ epoch 1
# combo 313 / 500: (64, 128, 16, 0.1, 0.01, 80, 9, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5583 @ epoch 2
# combo 314 / 500: (64, 64, 32, 0.5, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 113
# Best validation acc: 0.5389 @ epoch 13
# combo 315 / 500: (32, 32, 16, 0.5, 0.01, 80, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 316 / 500: (256, 512, 16, 0.5, 0.01, 50, 7, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5789 @ epoch 2
# combo 317 / 500: (512, 64, 32, 0.3, 0.01, 100, 9, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5628 @ epoch 2
# combo 318 / 500: (512, 16, 16, 0.3, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5578 @ epoch 2
# combo 319 / 500: (16, 512, 64, 0.5, 0.01, 80, 7, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 320 / 500: (256, 256, 16, 0.3, 0.01, 80, 8, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5611 @ epoch 4
# combo 321 / 500: (32, 256, 64, 0.3, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 322 / 500: (32, 512, 64, 0.1, 0.01, 100, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5622 @ epoch 1
# combo 323 / 500: (32, 128, 64, 0.1, 0.01, 100, 9, 0.1, 0.1, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5506 @ epoch 7
# combo 324 / 500: (128, 16, 32, 0.3, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 107
# Best validation acc: 0.5417 @ epoch 7
# combo 325 / 500: (128, 32, 64, 0.1, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5528 @ epoch 6
# combo 326 / 500: (128, 256, 64, 0.1, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5661 @ epoch 1
# combo 327 / 500: (16, 32, 16, 0.3, 0.01, 50, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 328 / 500: (256, 256, 128, 0.5, 0.01, 100, 7, 0.1, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5422 @ epoch 1
# combo 329 / 500: (512, 32, 32, 0.5, 0.01, 50, 9, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5628 @ epoch 1
# combo 330 / 500: (32, 64, 128, 0.5, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5450 @ epoch 2
# combo 331 / 500: (128, 256, 16, 0.5, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5517 @ epoch 5
# combo 332 / 500: (16, 64, 64, 0.5, 0.01, 100, 8, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5528 @ epoch 1
# combo 333 / 500: (512, 128, 128, 0.1, 0.01, 100, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5489 @ epoch 4
# combo 334 / 500: (32, 256, 16, 0.5, 0.01, 100, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5639 @ epoch 1
# combo 335 / 500: (16, 64, 16, 0.1, 0.01, 80, 9, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5506 @ epoch 3
# combo 336 / 500: (256, 64, 128, 0.5, 0.01, 100, 9, 0.3, 0.2, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5572 @ epoch 0
# combo 337 / 500: (64, 512, 16, 0.5, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 105
# Best validation acc: 0.5506 @ epoch 5
# combo 338 / 500: (128, 32, 32, 0.5, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 339 / 500: (32, 64, 32, 0.5, 0.01, 100, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 340 / 500: (256, 16, 64, 0.3, 0.01, 50, 9, 0.3, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5511 @ epoch 3
# combo 341 / 500: (512, 16, 32, 0.5, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5544 @ epoch 3
# combo 342 / 500: (512, 16, 64, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5572 @ epoch 4
# combo 343 / 500: (512, 256, 128, 0.1, 0.01, 100, 7, 0.1, 0.2, 256)
# Early stopping at epoch 110
# Best validation acc: 0.5372 @ epoch 10
# combo 344 / 500: (512, 64, 16, 0.1, 0.01, 100, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5744 @ epoch 1
# combo 345 / 500: (256, 64, 16, 0.3, 0.01, 50, 7, 0.3, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 346 / 500: (256, 128, 32, 0.1, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5639 @ epoch 3
# combo 347 / 500: (256, 64, 32, 0.3, 0.01, 100, 9, 0.1, 0.2, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 348 / 500: (16, 512, 128, 0.1, 0.01, 100, 7, 0.1, 0.3, 256)
# Early stopping at epoch 108
# Best validation acc: 0.5417 @ epoch 8
# combo 349 / 500: (256, 64, 128, 0.1, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 350 / 500: (256, 512, 32, 0.1, 0.01, 80, 7, 0.1, 0.3, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5456 @ epoch 3
# combo 351 / 500: (64, 32, 32, 0.1, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5661 @ epoch 2
# combo 352 / 500: (256, 256, 32, 0.5, 0.01, 80, 9, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 353 / 500: (512, 64, 16, 0.3, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 354 / 500: (256, 16, 32, 0.1, 0.01, 80, 9, 0.1, 0.2, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5583 @ epoch 5
# combo 355 / 500: (512, 64, 128, 0.3, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5656 @ epoch 1
# combo 356 / 500: (512, 512, 16, 0.1, 0.01, 80, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5656 @ epoch 1
# combo 357 / 500: (32, 128, 128, 0.5, 0.01, 80, 8, 0.1, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5450 @ epoch 1
# combo 358 / 500: (64, 16, 128, 0.1, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5594 @ epoch 1
# combo 359 / 500: (128, 64, 64, 0.5, 0.01, 80, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 360 / 500: (64, 32, 128, 0.3, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5644 @ epoch 1
# combo 361 / 500: (16, 64, 64, 0.5, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 362 / 500: (32, 128, 32, 0.1, 0.01, 50, 9, 0.1, 0.1, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5600 @ epoch 4
# combo 363 / 500: (256, 256, 32, 0.3, 0.01, 100, 8, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 364 / 500: (64, 128, 16, 0.3, 0.01, 50, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5667 @ epoch 1
# combo 365 / 500: (256, 64, 128, 0.1, 0.01, 80, 7, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5600 @ epoch 2
# combo 366 / 500: (256, 64, 128, 0.3, 0.01, 80, 8, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5461 @ epoch 4
# combo 367 / 500: (32, 32, 64, 0.1, 0.01, 80, 7, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5783 @ epoch 2
# combo 368 / 500: (64, 512, 128, 0.5, 0.01, 80, 8, 0.1, 0.2, 256)
# Early stopping at epoch 103
# ...
# Best validation acc: 0.5550 @ epoch 4
# combo 381 / 500: (512, 256, 128, 0.5, 0.01, 50, 8, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5378 @ epoch 6
# combo 382 / 500: (128, 512, 16, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5667 @ epoch 2
# combo 383 / 500: (256, 128, 128, 0.5, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 105
# Best validation acc: 0.5411 @ epoch 5
# combo 384 / 500: (256, 512, 32, 0.3, 0.01, 50, 7, 0.1, 0.2, 512)
# Early stopping at epoch 106
# Best validation acc: 0.5411 @ epoch 6
# combo 385 / 500: (128, 16, 32, 0.3, 0.01, 80, 9, 0.3, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 386 / 500: (256, 512, 64, 0.1, 0.01, 50, 7, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5289 @ epoch 5
# combo 387 / 500: (256, 128, 16, 0.1, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 388 / 500: (32, 64, 16, 0.1, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5533 @ epoch 2
# combo 389 / 500: (256, 512, 128, 0.1, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5439 @ epoch 1
# combo 390 / 500: (128, 512, 16, 0.5, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5517 @ epoch 3
# combo 391 / 500: (64, 256, 64, 0.3, 0.01, 80, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5578 @ epoch 3
# combo 392 / 500: (256, 32, 16, 0.5, 0.01, 80, 8, 0.1, 0.3, 512)
# Early stopping at epoch 108
# Best validation acc: 0.5461 @ epoch 8
# combo 393 / 500: (256, 16, 128, 0.1, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5678 @ epoch 2
# combo 394 / 500: (32, 512, 64, 0.5, 0.01, 80, 8, 0.3, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 395 / 500: (128, 64, 16, 0.3, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5522 @ epoch 3
# combo 396 / 500: (512, 16, 128, 0.3, 0.01, 100, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5483 @ epoch 5
# combo 397 / 500: (16, 256, 64, 0.5, 0.01, 50, 8, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5661 @ epoch 2
# combo 398 / 500: (32, 16, 16, 0.1, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5522 @ epoch 2
# combo 399 / 500: (256, 64, 16, 0.1, 0.01, 50, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5656 @ epoch 2
# combo 400 / 500: (512, 512, 64, 0.1, 0.01, 100, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 401 / 500: (16, 32, 32, 0.1, 0.01, 80, 8, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5583 @ epoch 5
# combo 402 / 500: (16, 64, 64, 0.3, 0.01, 80, 9, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5383 @ epoch 4
# combo 403 / 500: (128, 128, 32, 0.3, 0.01, 50, 8, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5417 @ epoch 1
# combo 404 / 500: (256, 512, 128, 0.3, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 105
# Best validation acc: 0.5422 @ epoch 5
# combo 405 / 500: (16, 128, 32, 0.3, 0.01, 100, 9, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 406 / 500: (256, 256, 32, 0.1, 0.01, 50, 9, 0.1, 0.3, 768)
# Early stopping at epoch 107
# Best validation acc: 0.5467 @ epoch 7
# combo 407 / 500: (64, 64, 128, 0.3, 0.01, 100, 8, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5411 @ epoch 2
# combo 408 / 500: (512, 256, 32, 0.5, 0.01, 100, 9, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 409 / 500: (32, 64, 16, 0.1, 0.01, 50, 9, 0.3, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5539 @ epoch 4
# combo 410 / 500: (512, 256, 64, 0.1, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 411 / 500: (128, 32, 128, 0.1, 0.01, 100, 7, 0.1, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5683 @ epoch 5
# combo 412 / 500: (512, 64, 32, 0.3, 0.01, 50, 7, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5611 @ epoch 1
# combo 413 / 500: (32, 64, 16, 0.3, 0.01, 100, 7, 0.3, 0.3, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5450 @ epoch 1
# combo 414 / 500: (16, 512, 32, 0.1, 0.01, 100, 9, 0.1, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 415 / 500: (128, 16, 64, 0.5, 0.01, 50, 9, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 416 / 500: (16, 256, 16, 0.5, 0.01, 50, 9, 0.3, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5550 @ epoch 3
# combo 417 / 500: (32, 512, 128, 0.1, 0.01, 50, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 418 / 500: (32, 128, 128, 0.3, 0.01, 80, 7, 0.1, 0.3, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5489 @ epoch 3
# combo 419 / 500: (128, 512, 16, 0.3, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5511 @ epoch 1
# combo 420 / 500: (16, 512, 32, 0.1, 0.01, 50, 9, 0.3, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5461 @ epoch 3
# combo 421 / 500: (128, 256, 128, 0.5, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5444 @ epoch 2
# combo 422 / 500: (32, 512, 64, 0.1, 0.01, 100, 7, 0.1, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5606 @ epoch 4
# combo 423 / 500: (16, 64, 128, 0.5, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5356 @ epoch 5
# combo 424 / 500: (64, 128, 128, 0.5, 0.01, 50, 9, 0.1, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5467 @ epoch 1
# combo 425 / 500: (16, 128, 32, 0.1, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5567 @ epoch 1
# combo 426 / 500: (32, 128, 32, 0.3, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 427 / 500: (16, 32, 128, 0.1, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5472 @ epoch 1
# combo 428 / 500: (128, 512, 32, 0.3, 0.01, 50, 8, 0.3, 0.3, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5444 @ epoch 7
# combo 429 / 500: (128, 128, 16, 0.5, 0.01, 100, 7, 0.1, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5483 @ epoch 2
# combo 430 / 500: (32, 32, 32, 0.3, 0.01, 80, 8, 0.3, 0.2, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5594 @ epoch 0
# combo 431 / 500: (32, 256, 128, 0.5, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5422 @ epoch 1
# combo 432 / 500: (16, 16, 64, 0.5, 0.01, 100, 7, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5461 @ epoch 1
# combo 433 / 500: (256, 128, 128, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5394 @ epoch 4
# combo 434 / 500: (32, 256, 128, 0.3, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5606 @ epoch 1
# combo 435 / 500: (256, 128, 16, 0.3, 0.01, 50, 8, 0.1, 0.2, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5556 @ epoch 3
# combo 436 / 500: (32, 256, 128, 0.3, 0.01, 80, 9, 0.1, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5372 @ epoch 4
# combo 437 / 500: (64, 16, 128, 0.5, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5467 @ epoch 2
# combo 438 / 500: (16, 256, 16, 0.3, 0.01, 100, 9, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5478 @ epoch 3
# combo 439 / 500: (16, 64, 16, 0.3, 0.01, 80, 8, 0.1, 0.3, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5456 @ epoch 4
# combo 440 / 500: (512, 16, 128, 0.1, 0.01, 50, 7, 0.1, 0.1, 512)
# Early stopping at epoch 107
# Best validation acc: 0.5478 @ epoch 7
# combo 441 / 500: (64, 64, 64, 0.3, 0.01, 50, 8, 0.3, 0.2, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5478 @ epoch 1
# combo 442 / 500: (32, 256, 128, 0.1, 0.01, 80, 8, 0.3, 0.3, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5550 @ epoch 2
# combo 443 / 500: (64, 128, 64, 0.3, 0.01, 100, 7, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5567 @ epoch 2
# combo 444 / 500: (256, 16, 128, 0.1, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5600 @ epoch 2
# combo 445 / 500: (128, 64, 32, 0.5, 0.01, 80, 7, 0.3, 0.1, 256)
# Early stopping at epoch 103
# Best validation acc: 0.5606 @ epoch 3
# combo 446 / 500: (16, 128, 16, 0.3, 0.01, 50, 9, 0.1, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5539 @ epoch 1
# combo 447 / 500: (32, 16, 64, 0.1, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 106
# Best validation acc: 0.5433 @ epoch 6
# combo 448 / 500: (16, 32, 128, 0.3, 0.01, 50, 9, 0.1, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5406 @ epoch 3
# combo 449 / 500: (512, 64, 32, 0.3, 0.01, 100, 9, 0.3, 0.2, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5578 @ epoch 1
# combo 450 / 500: (64, 256, 64, 0.5, 0.01, 80, 7, 0.1, 0.2, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5517 @ epoch 1
# combo 451 / 500: (16, 128, 16, 0.3, 0.01, 100, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5544 @ epoch 1
# combo 452 / 500: (512, 256, 32, 0.3, 0.01, 50, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5644 @ epoch 2
# combo 453 / 500: (128, 512, 32, 0.1, 0.01, 80, 8, 0.3, 0.2, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5611 @ epoch 2
# combo 454 / 500: (128, 64, 16, 0.1, 0.01, 80, 9, 0.1, 0.1, 768)
# Early stopping at epoch 103
# Best validation acc: 0.5661 @ epoch 3
# combo 455 / 500: (512, 256, 16, 0.1, 0.01, 100, 9, 0.1, 0.1, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5461 @ epoch 2
# combo 456 / 500: (32, 256, 16, 0.1, 0.01, 80, 9, 0.1, 0.3, 256)
# Early stopping at epoch 109
# Best validation acc: 0.5428 @ epoch 9
# combo 457 / 500: (256, 32, 128, 0.3, 0.01, 100, 7, 0.3, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5528 @ epoch 2
# combo 458 / 500: (32, 256, 16, 0.5, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5594 @ epoch 2
# combo 459 / 500: (64, 512, 128, 0.3, 0.01, 100, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 104
# Best validation acc: 0.5461 @ epoch 4
# combo 460 / 500: (128, 256, 16, 0.1, 0.01, 100, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5667 @ epoch 2
# combo 461 / 500: (32, 256, 32, 0.5, 0.01, 80, 9, 0.3, 0.2, 768)
# Early stopping at epoch 100
# Best validation acc: 0.5561 @ epoch 0
# combo 462 / 500: (32, 64, 32, 0.5, 0.01, 80, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5483 @ epoch 3
# combo 463 / 500: (32, 64, 64, 0.1, 0.01, 100, 9, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5528 @ epoch 1
# combo 464 / 500: (16, 512, 16, 0.5, 0.01, 80, 7, 0.1, 0.1, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5728 @ epoch 0
# combo 465 / 500: (128, 16, 64, 0.3, 0.01, 100, 8, 0.3, 0.3, 512)
# Early stopping at epoch 104
# Best validation acc: 0.5472 @ epoch 4
# combo 466 / 500: (256, 128, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5511 @ epoch 2
# combo 467 / 500: (128, 32, 128, 0.3, 0.01, 50, 7, 0.3, 0.1, 256)
# Early stopping at epoch 105
# Best validation acc: 0.5400 @ epoch 5
# combo 468 / 500: (16, 16, 64, 0.5, 0.01, 80, 7, 0.1, 0.2, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5483 @ epoch 4
# combo 469 / 500: (512, 64, 16, 0.3, 0.01, 80, 8, 0.1, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5561 @ epoch 2
# combo 470 / 500: (16, 256, 128, 0.1, 0.01, 50, 9, 0.3, 0.3, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5528 @ epoch 2
# combo 471 / 500: (16, 256, 32, 0.3, 0.01, 80, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5511 @ epoch 3
# combo 472 / 500: (64, 64, 32, 0.5, 0.01, 50, 9, 0.3, 0.1, 512)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 473 / 500: (256, 512, 32, 0.3, 0.01, 100, 7, 0.3, 0.2, 256)
# Early stopping at epoch 107
# Best validation acc: 0.5489 @ epoch 7
# combo 474 / 500: (128, 512, 16, 0.1, 0.01, 100, 8, 0.3, 0.3, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5511 @ epoch 4
# combo 475 / 500: (256, 256, 64, 0.5, 0.01, 80, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5539 @ epoch 2
# combo 476 / 500: (256, 16, 128, 0.3, 0.01, 80, 8, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 477 / 500: (32, 32, 64, 0.1, 0.01, 80, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 478 / 500: (512, 32, 128, 0.3, 0.01, 50, 7, 0.3, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5583 @ epoch 1
# combo 479 / 500: (64, 256, 16, 0.3, 0.01, 80, 8, 0.1, 0.2, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 480 / 500: (32, 64, 16, 0.5, 0.01, 50, 7, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5556 @ epoch 2
# combo 481 / 500: (128, 64, 16, 0.5, 0.01, 50, 8, 0.1, 0.3, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5517 @ epoch 2
# combo 482 / 500: (64, 64, 128, 0.1, 0.01, 100, 7, 0.3, 0.1, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5544 @ epoch 3
# combo 483 / 500: (256, 16, 16, 0.5, 0.01, 50, 8, 0.1, 0.1, 256)
# Early stopping at epoch 104
# Best validation acc: 0.5400 @ epoch 4
# combo 484 / 500: (32, 16, 128, 0.3, 0.01, 100, 8, 0.1, 0.1, 1024)
# Early stopping at epoch 102
# Best validation acc: 0.5433 @ epoch 2
# combo 485 / 500: (512, 32, 64, 0.3, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5589 @ epoch 2
# combo 486 / 500: (16, 256, 16, 0.1, 0.01, 50, 8, 0.3, 0.1, 512)
# Early stopping at epoch 101
# Best validation acc: 0.5683 @ epoch 1
# combo 487 / 500: (16, 32, 32, 0.3, 0.01, 50, 7, 0.3, 0.3, 256)
# Early stopping at epoch 102
# Best validation acc: 0.5478 @ epoch 2
# combo 488 / 500: (16, 256, 64, 0.3, 0.01, 50, 8, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5472 @ epoch 2
# combo 489 / 500: (64, 16, 128, 0.1, 0.01, 100, 7, 0.3, 0.3, 1024)
# Early stopping at epoch 100
# Best validation acc: 0.5617 @ epoch 0
# combo 490 / 500: (64, 64, 64, 0.3, 0.01, 100, 9, 0.1, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5489 @ epoch 2
# combo 491 / 500: (32, 32, 16, 0.3, 0.01, 50, 9, 0.1, 0.2, 768)
# Early stopping at epoch 104
# Best validation acc: 0.5428 @ epoch 4
# combo 492 / 500: (128, 128, 32, 0.1, 0.01, 50, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 103
# Best validation acc: 0.5650 @ epoch 3
# combo 493 / 500: (32, 16, 16, 0.5, 0.01, 50, 9, 0.1, 0.2, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5572 @ epoch 1
# combo 494 / 500: (256, 32, 128, 0.3, 0.01, 80, 8, 0.3, 0.2, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5433 @ epoch 2
# combo 495 / 500: (64, 64, 128, 0.5, 0.01, 50, 9, 0.3, 0.3, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5500 @ epoch 1
# combo 496 / 500: (128, 256, 16, 0.3, 0.01, 80, 7, 0.1, 0.3, 512)
# Early stopping at epoch 103
# Best validation acc: 0.5522 @ epoch 3
# combo 497 / 500: (16, 512, 64, 0.1, 0.01, 50, 8, 0.3, 0.3, 768)
# Early stopping at epoch 101
# Best validation acc: 0.5522 @ epoch 1
# combo 498 / 500: (512, 512, 64, 0.1, 0.01, 50, 9, 0.3, 0.1, 256)
# Early stopping at epoch 101
# Best validation acc: 0.5622 @ epoch 1
# combo 499 / 500: (64, 16, 128, 0.5, 0.01, 100, 9, 0.3, 0.1, 1024)
# Early stopping at epoch 101
# Best validation acc: 0.5489 @ epoch 1
# combo 500 / 500: (64, 16, 128, 0.1, 0.01, 50, 9, 0.3, 0.1, 768)
# Early stopping at epoch 102
# Best validation acc: 0.5689 @ epoch 2
# {'h1': 128, 'h2': 64, 'h3': 32, 'dropout': 0.1, 'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'out_size_nrf': 1024, 'epochs': 150, 'partition': 'gtd300', 'final_evaluation': False, 'n_class': 30}

# %%
save_metrics_txt(best_metrics, partition)
