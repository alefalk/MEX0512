# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
partition = 200

# %%
trainpath = f'../../../data/top30groups/LongLatCombined/train1/train{partition}.csv'
testpath = f'../../../data/top30groups/LongLatCombined/test1/test{partition}.csv'
traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
traindata.columns
# Out:
# Index(['extended', 'latitude', 'longitude', 'vicinity', 'multiple', 'success',
#        'suicide', 'attacktype1', 'targtype1', 'target1', 'individual',
#        'weaptype1', 'nkill', 'property', 'ishostkid', 'gname'],
#       dtype='object')

# %%
combined = pd.concat([traindata, testdata], axis = 0)

# %%
combined.shape
# Out:
# (6000, 16)

# %%
data = combined

# %%
data.columns
# Out:
# Index(['extended', 'latitude', 'longitude', 'vicinity', 'multiple', 'success',
#        'suicide', 'attacktype1', 'targtype1', 'target1', 'individual',
#        'weaptype1', 'nkill', 'property', 'ishostkid', 'gname'],
#       dtype='object')

# %%
# Filter dataset to only contain unique coordinates
print("Entries before dropping long/lat duplicates: ", data.shape)

#data.sort_values(by=['longitude', 'latitude', 'attack_date'], inplace=True)

# Keep only relevant columns
data = data[['longitude', 'latitude', 'gname']]
# Drop duplicates based on location, keep the earliest attack
data['longlat'] = list(zip(data['longitude'], data['latitude']))
df_unique = data.drop_duplicates(subset=['longlat'], keep='first').reset_index(drop=True)

df_unique = df_unique.drop(columns=['longitude', 'latitude'])
print(df_unique.columns)
print("Entries after dropping long/lat duplicates (#Nodes): ", df_unique.shape)
# Out:
# Entries before dropping long/lat duplicates:  (6000, 16)
# Index(['gname', 'longlat'], dtype='object')
# Entries after dropping long/lat duplicates (#Nodes):  (3160, 2)
# /tmp/ipykernel_69953/691971201.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['longlat'] = list(zip(data['longitude'], data['latitude']))

# %%
df_unique["gname"].value_counts()
# Out:
# gname
# New People's Army (NPA)                             182
# Maoists                                             174
# Fulani extremists                                   169
# Taliban                                             166
# Kurdistan Workers' Party (PKK)                      159
# Communist Party of India - Maoist (CPI-Maoist)      158
# Revolutionary Armed Forces of Colombia (FARC)       155
# Nicaraguan Democratic Force (FDN)                   146
# Boko Haram                                          126
# Muslim extremists                                   123
# Abu Sayyaf Group (ASG)                              120
# Tehrik-i-Taliban Pakistan (TTP)                     116
# National Liberation Army of Colombia (ELN)          109
# Liberation Tigers of Tamil Eelam (LTTE)             109
# Islamic State of Iraq and the Levant (ISIL)         107
# Farabundo Marti National Liberation Front (FMLN)    103
# Houthi extremists (Ansar Allah)                      96
# Sikh Extremists                                      89
# Al-Shabaab                                           85
# Basque Fatherland and Freedom (ETA)                  81
# Al-Qaida in the Arabian Peninsula (AQAP)             80
# Shining Path (SL)                                    79
# African National Congress (South Africa)             79
# Donetsk People's Republic                            68
# Palestinians                                         68
# Irish Republican Army (IRA)                          58
# Al-Qaida in Iraq                                     54
# Corsican National Liberation Front (FLNC)            45
# Tupac Amaru Revolutionary Movement (MRTA)            35
# Manuel Rodriguez Patriotic Front (FPMR)              21
# Name: count, dtype: int64

# %%
split_point = int(0.7 * len(df_unique))
train_df = df_unique[:split_point]
test_df = df_unique[split_point:]

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

df_unique['longlat'] = df_unique['longlat'].apply(to_tuple_if_needed)

# %%
from sklearn.model_selection import train_test_split

# 1. Build coord_to_index from the full dataset
full_coords = df_unique[['longlat']]
coord_to_index = {row['longlat']: i for i, row in full_coords.iterrows()}

# 2. Build the global graph
adj_matrix, feature_matrix, label_index = build_graph_data(df_unique, coord_to_index)

# 3. Build train node indices and labels
train_nodes = [coord_to_index[row['longlat']] for _, row in train_df.iterrows()]
train_labels = [label_index[row['gname']] for _, row in train_df.iterrows()]

# 4. Split train into train and validation
train_idx, val_idx, train_lbls, val_lbls = train_test_split(
    train_nodes, train_labels, test_size=0.2, stratify=train_labels, random_state=42
)

# 5. Build test node indices and labels
test_nodes = [coord_to_index[row['longlat']] for _, row in test_df.iterrows()]
test_labels = [label_index[row['gname']] for _, row in test_df.iterrows()]
# Out:
# Number of total nodes (unique coordinates): 3160
# Number of unique labels in this set: 30

# %%
print(adj_matrix.shape)
# Out:
# (3160, 3160)

# %% [markdown]
# # A simple GCN

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes, dropout=0.0, activation=F.relu):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)
        self.dropout = dropout
        self.activation = activation

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.activation(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return x
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
def run_epoch(model, data, labels, mask, optimizer=None, return_preds=False):
    is_training = optimizer is not None
    if is_training:
        model.train()
    else:
        model.eval()

    out = model(data.x, data.edge_index)
    loss_fn = torch.nn.CrossEntropyLoss()
    loss = loss_fn(out[mask], labels[mask])

    if is_training:
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    pred = out[mask].argmax(dim=1)
    acc = (pred == labels[mask]).float().mean().item()

    if return_preds:
        return acc, loss.item(), pred.cpu(), labels[mask].cpu(), out[mask].softmax(dim=1).cpu()
    else:
        return acc, loss.item()

# %%
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

# 1. Convert adjacency matrix to edge_index
A_coo = coo_matrix(adj_matrix)
edge_index = torch.tensor(np.vstack((A_coo.row, A_coo.col)), dtype=torch.long)

# 2. Feature matrix
coords = np.array(list(coord_to_index.keys()), dtype=np.float32)
x = torch.tensor(coords, dtype=torch.float32)
num_nodes = x.shape[0]

# 3. Label tensor
y = torch.full((num_nodes,), -1, dtype=torch.long)

# 4. Masks
train_mask = torch.zeros(num_nodes, dtype=torch.bool)
val_mask = torch.zeros(num_nodes, dtype=torch.bool)
test_mask = torch.zeros(num_nodes, dtype=torch.bool)

# 5. Assign labels and masks
for idx, label in zip(train_idx, train_lbls):
    y[idx] = label
    train_mask[idx] = True

for idx, label in zip(val_idx, val_lbls):
    y[idx] = label
    val_mask[idx] = True

for idx, label in zip(test_nodes, test_labels):
    y[idx] = label
    test_mask[idx] = True

# 6. Create PyG data object
data = Data(x=x, edge_index=edge_index)

# %%
from itertools import product
import copy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report


hidden_dims = [10, 50, 100, 150]
lrs = [0.01, 0.001, 0.0001]
weight_decays = [0]
dropouts = [0.0]
activation_functions = [F.relu, torch.tanh]

best_config = None
best_val_acc = 0

patience = 100
max_epochs_search = 500
max_epochs_final = 1500

# --------------------------
# Grid search (NO test use!)
# --------------------------
for hidden, lr, wd, do, act in product(hidden_dims, lrs, weight_decays, dropouts, activation_functions):
    model = PyTorchGCN(
        in_channels=x.shape[1],
        hidden_channels=hidden,
        num_classes=len(label_index),
        dropout=do,
        activation=act
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    best_val_acc_run = 0
    patience_counter = 0

    for epoch in range(max_epochs_search):
        train_acc, train_loss = run_epoch(model, data, y, train_mask, optimizer)
        val_acc, val_loss = run_epoch(model, data, y, val_mask)

        if epoch == 0:
            print(f"Evaluating hidden={hidden}, lr={lr}, weight_decay={wd}, dropout={do}, activation={act.__name__}")
        elif epoch % 100 == 0 or epoch == max_epochs_search - 1:
            print(f"Epoch {epoch:04d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
                f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc_run:
            best_val_acc_run = val_acc
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping.")
            break

    # Track best config
    if best_val_acc_run > best_val_acc:
        best_val_acc = best_val_acc_run
        best_config = (hidden, lr, wd, do, act)

print(f"\nBest config found:")
print(f"hidden={best_config[0]}, lr={best_config[1]}, weight_decay={best_config[2]}, dropout={best_config[3]}, activation={best_config[4].__name__}")
print(f"Best validation accuracy: {best_val_acc:.4f}")

# --------------------------
# Retrain best config, then test
# --------------------------

# Rebuild model and optimizer
model = PyTorchGCN(
    in_channels=x.shape[1],
    hidden_channels=best_config[0],
    num_classes=len(label_index),
    dropout=best_config[3],
    activation=best_config[4]
)
optimizer = torch.optim.Adam(model.parameters(), lr=best_config[1], weight_decay=best_config[2])

# Early stopping on validation again
best_val_acc_run = 0
patience_counter = 0
best_model_state = None

for epoch in range(max_epochs_final):
    train_acc, train_loss = run_epoch(model, data, y, train_mask, optimizer)
    val_acc, val_loss = run_epoch(model, data, y, val_mask)

    if val_acc > best_val_acc_run:
        best_val_acc_run = val_acc
        best_model_state = copy.deepcopy(model.state_dict())
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print(f"Early stopping during final retrain. Epoch: {epoch}")
        break

# Load best model
model.load_state_dict(best_model_state)
model.eval()

# Final test evaluation
test_acc, test_loss, preds, targets, probs = run_epoch(model, data, y, test_mask, return_preds=True)

print(f"\nFinal test accuracy after retraining with best config: {test_acc:.4f}")

# Compute metrics
accuracy = accuracy_score(targets, preds)
precision = precision_score(targets, preds, average='weighted', zero_division=0)
recall = recall_score(targets, preds, average='weighted', zero_division=0)
f1_micro = f1_score(targets, preds, average='micro', zero_division=0)
f1_macro = f1_score(targets, preds, average='macro', zero_division=0)

try:
    y_true_bin = torch.nn.functional.one_hot(targets, num_classes=probs.shape[1]).detach().numpy()
    rocauc = roc_auc_score(y_true_bin, probs.detach().numpy(), average='weighted', multi_class='ovr')
except Exception as e:
    print("ROCAUC computation failed:", e)
    rocauc = None

# Write to file
with open(f"test_metricsgtd{partition}.txt", "w") as f:
    f.write("Best Model Hyperparameters:\n")
    f.write(f"  Hidden dim     : {best_config[0]}\n")
    f.write(f"  Learning rate  : {best_config[1]}\n")
    f.write(f"  Weight decay   : {best_config[2]}\n")
    f.write(f"  Dropout        : {best_config[3]}\n")
    f.write(f"  Activation     : {best_config[4].__name__}\n")
    f.write("\nPerformance on Test Set:\n")
    f.write(f"Test Accuracy        : {accuracy:.4f}\n")
    f.write(f"Precision (weighted) : {precision:.4f}\n")
    f.write(f"Recall (weighted)    : {recall:.4f}\n")
    f.write(f"F1 Score (micro)     : {f1_micro:.4f}\n")
    f.write(f"F1 Score (macro)     : {f1_macro:.4f}\n")
    if rocauc is not None:
        f.write(f"ROC AUC (weighted)   : {rocauc:.4f}\n")
    else:
        f.write("ROC AUC              : Not computed (only one class or failed)\n")
# Out:
# Evaluating hidden=10, lr=0.01, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.5164 | Val Loss: 1.5806 | Train Acc: 0.4771 | Val Acc: 0.4853
# Epoch 0200 | Train Loss: 1.1896 | Val Loss: 1.2267 | Train Acc: 0.5523 | Val Acc: 0.5463
# Epoch 0300 | Train Loss: 0.9845 | Val Loss: 1.0189 | Train Acc: 0.6365 | Val Acc: 0.6546
# Epoch 0400 | Train Loss: 0.8677 | Val Loss: 0.9001 | Train Acc: 0.6874 | Val Acc: 0.6953
# Epoch 0499 | Train Loss: 0.7904 | Val Loss: 0.8183 | Train Acc: 0.7241 | Val Acc: 0.7336
# Evaluating hidden=10, lr=0.01, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 1.9261 | Val Loss: 1.9111 | Train Acc: 0.3335 | Val Acc: 0.3363
# Epoch 0200 | Train Loss: 1.3807 | Val Loss: 1.3793 | Train Acc: 0.4488 | Val Acc: 0.4537
# Epoch 0300 | Train Loss: 1.1556 | Val Loss: 1.1674 | Train Acc: 0.5783 | Val Acc: 0.5711
# Epoch 0400 | Train Loss: 1.0677 | Val Loss: 1.0910 | Train Acc: 0.6032 | Val Acc: 0.5914
# Epoch 0499 | Train Loss: 1.0131 | Val Loss: 1.0442 | Train Acc: 0.6083 | Val Acc: 0.5982
# Evaluating hidden=10, lr=0.001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 9.9680 | Val Loss: 9.8298 | Train Acc: 0.0820 | Val Acc: 0.0767
# Epoch 0200 | Train Loss: 2.4968 | Val Loss: 2.4668 | Train Acc: 0.2838 | Val Acc: 0.2867
# Epoch 0300 | Train Loss: 1.8288 | Val Loss: 1.8211 | Train Acc: 0.2985 | Val Acc: 0.3047
# Epoch 0400 | Train Loss: 1.6485 | Val Loss: 1.6361 | Train Acc: 0.3522 | Val Acc: 0.3589
# Epoch 0499 | Train Loss: 1.5435 | Val Loss: 1.5304 | Train Acc: 0.3878 | Val Acc: 0.3995
# Evaluating hidden=10, lr=0.001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 2.9343 | Val Loss: 2.9259 | Train Acc: 0.1504 | Val Acc: 0.1490
# Epoch 0200 | Train Loss: 2.5582 | Val Loss: 2.5506 | Train Acc: 0.2216 | Val Acc: 0.2235
# Epoch 0300 | Train Loss: 2.2923 | Val Loss: 2.2851 | Train Acc: 0.3013 | Val Acc: 0.2980
# Early stopping.
# Evaluating hidden=10, lr=0.0001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 22.9026 | Val Loss: 22.9830 | Train Acc: 0.0311 | Val Acc: 0.0293
# Early stopping.
# Evaluating hidden=10, lr=0.0001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 3.5292 | Val Loss: 3.5197 | Train Acc: 0.0509 | Val Acc: 0.0542
# Early stopping.
# Evaluating hidden=50, lr=0.01, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.1290 | Val Loss: 1.1536 | Train Acc: 0.5811 | Val Acc: 0.5892
# Epoch 0200 | Train Loss: 0.8426 | Val Loss: 0.8377 | Train Acc: 0.6874 | Val Acc: 0.7156
# Epoch 0300 | Train Loss: 0.6856 | Val Loss: 0.7256 | Train Acc: 0.7665 | Val Acc: 0.7675
# Epoch 0400 | Train Loss: 0.5984 | Val Loss: 0.6691 | Train Acc: 0.7954 | Val Acc: 0.7968
# Early stopping.
# Evaluating hidden=50, lr=0.01, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 0.9623 | Val Loss: 0.9523 | Train Acc: 0.6230 | Val Acc: 0.6230
# Epoch 0200 | Train Loss: 0.6442 | Val Loss: 0.6545 | Train Acc: 0.7564 | Val Acc: 0.7540
# Epoch 0300 | Train Loss: 0.5496 | Val Loss: 0.5824 | Train Acc: 0.7931 | Val Acc: 0.7856
# Epoch 0400 | Train Loss: 0.5000 | Val Loss: 0.5592 | Train Acc: 0.8055 | Val Acc: 0.7968
# Epoch 0499 | Train Loss: 0.4744 | Val Loss: 0.5552 | Train Acc: 0.8061 | Val Acc: 0.8036
# Evaluating hidden=50, lr=0.001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.7861 | Val Loss: 1.8325 | Train Acc: 0.3335 | Val Acc: 0.3341
# Epoch 0200 | Train Loss: 1.4928 | Val Loss: 1.5354 | Train Acc: 0.4358 | Val Acc: 0.4334
# Epoch 0300 | Train Loss: 1.3595 | Val Loss: 1.4008 | Train Acc: 0.4862 | Val Acc: 0.4831
# Epoch 0400 | Train Loss: 1.2606 | Val Loss: 1.2954 | Train Acc: 0.5144 | Val Acc: 0.5169
# Epoch 0499 | Train Loss: 1.1750 | Val Loss: 1.2037 | Train Acc: 0.5376 | Val Acc: 0.5598
# Evaluating hidden=50, lr=0.001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 1.9103 | Val Loss: 1.9038 | Train Acc: 0.4613 | Val Acc: 0.4695
# Epoch 0200 | Train Loss: 1.5527 | Val Loss: 1.5450 | Train Acc: 0.5088 | Val Acc: 0.5011
# Epoch 0300 | Train Loss: 1.3321 | Val Loss: 1.3291 | Train Acc: 0.5890 | Val Acc: 0.5869
# Epoch 0400 | Train Loss: 1.1704 | Val Loss: 1.1709 | Train Acc: 0.6552 | Val Acc: 0.6411
# Epoch 0499 | Train Loss: 1.0488 | Val Loss: 1.0501 | Train Acc: 0.6783 | Val Acc: 0.6749
# Evaluating hidden=50, lr=0.0001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 14.8474 | Val Loss: 14.9719 | Train Acc: 0.0492 | Val Acc: 0.0497
# Early stopping.
# Evaluating hidden=50, lr=0.0001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 3.2664 | Val Loss: 3.2651 | Train Acc: 0.1345 | Val Acc: 0.1400
# Epoch 0200 | Train Loss: 2.8955 | Val Loss: 2.8927 | Train Acc: 0.2380 | Val Acc: 0.2393
# Epoch 0300 | Train Loss: 2.6349 | Val Loss: 2.6327 | Train Acc: 0.3086 | Val Acc: 0.3093
# Epoch 0400 | Train Loss: 2.4691 | Val Loss: 2.4678 | Train Acc: 0.3194 | Val Acc: 0.3183
# Epoch 0499 | Train Loss: 2.3437 | Val Loss: 2.3411 | Train Acc: 0.3313 | Val Acc: 0.3251
# Evaluating hidden=100, lr=0.01, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.0136 | Val Loss: 1.0431 | Train Acc: 0.5834 | Val Acc: 0.6005
# Epoch 0200 | Train Loss: 0.7162 | Val Loss: 0.7322 | Train Acc: 0.7513 | Val Acc: 0.7472
# Epoch 0300 | Train Loss: 0.5712 | Val Loss: 0.6300 | Train Acc: 0.7835 | Val Acc: 0.7788
# Epoch 0400 | Train Loss: 0.5246 | Val Loss: 0.6188 | Train Acc: 0.7942 | Val Acc: 0.7946
# Epoch 0499 | Train Loss: 0.5049 | Val Loss: 0.6553 | Train Acc: 0.7903 | Val Acc: 0.7923
# Evaluating hidden=100, lr=0.01, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 0.7026 | Val Loss: 0.7012 | Train Acc: 0.7456 | Val Acc: 0.7404
# Epoch 0200 | Train Loss: 0.5433 | Val Loss: 0.5752 | Train Acc: 0.7959 | Val Acc: 0.7765
# Epoch 0300 | Train Loss: 0.4932 | Val Loss: 0.5567 | Train Acc: 0.7999 | Val Acc: 0.7968
# Epoch 0400 | Train Loss: 0.4645 | Val Loss: 0.5504 | Train Acc: 0.8044 | Val Acc: 0.8104
# Early stopping.
# Evaluating hidden=100, lr=0.001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.5502 | Val Loss: 1.5650 | Train Acc: 0.4098 | Val Acc: 0.4041
# Epoch 0200 | Train Loss: 1.3400 | Val Loss: 1.3555 | Train Acc: 0.5302 | Val Acc: 0.5305
# Epoch 0300 | Train Loss: 1.1942 | Val Loss: 1.2033 | Train Acc: 0.5495 | Val Acc: 0.5734
# Epoch 0400 | Train Loss: 1.0692 | Val Loss: 1.0745 | Train Acc: 0.5811 | Val Acc: 0.5982
# Epoch 0499 | Train Loss: 0.9680 | Val Loss: 0.9670 | Train Acc: 0.6235 | Val Acc: 0.6343
# Evaluating hidden=100, lr=0.001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 1.5788 | Val Loss: 1.5656 | Train Acc: 0.4805 | Val Acc: 0.4808
# Epoch 0200 | Train Loss: 1.2366 | Val Loss: 1.2290 | Train Acc: 0.5591 | Val Acc: 0.5576
# Epoch 0300 | Train Loss: 1.0501 | Val Loss: 1.0451 | Train Acc: 0.6631 | Val Acc: 0.6524
# Epoch 0400 | Train Loss: 0.9221 | Val Loss: 0.9210 | Train Acc: 0.7010 | Val Acc: 0.6930
# Epoch 0499 | Train Loss: 0.8281 | Val Loss: 0.8304 | Train Acc: 0.7123 | Val Acc: 0.6975
# Evaluating hidden=100, lr=0.0001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 7.2049 | Val Loss: 7.2651 | Train Acc: 0.0582 | Val Acc: 0.0700
# Epoch 0200 | Train Loss: 3.6643 | Val Loss: 3.7560 | Train Acc: 0.1345 | Val Acc: 0.1196
# Epoch 0300 | Train Loss: 2.6267 | Val Loss: 2.7163 | Train Acc: 0.3024 | Val Acc: 0.3115
# Epoch 0400 | Train Loss: 2.1855 | Val Loss: 2.2657 | Train Acc: 0.3505 | Val Acc: 0.3521
# Early stopping.
# Evaluating hidden=100, lr=0.0001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 3.0609 | Val Loss: 3.0537 | Train Acc: 0.2086 | Val Acc: 0.2077
# Epoch 0200 | Train Loss: 2.5815 | Val Loss: 2.5741 | Train Acc: 0.2798 | Val Acc: 0.2867
# Epoch 0300 | Train Loss: 2.2979 | Val Loss: 2.2911 | Train Acc: 0.3742 | Val Acc: 0.3770
# Epoch 0400 | Train Loss: 2.1172 | Val Loss: 2.1087 | Train Acc: 0.3934 | Val Acc: 0.3883
# Early stopping.
# Evaluating hidden=150, lr=0.01, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 0.9887 | Val Loss: 1.0108 | Train Acc: 0.6133 | Val Acc: 0.6253
# Epoch 0200 | Train Loss: 0.7090 | Val Loss: 0.7660 | Train Acc: 0.7558 | Val Acc: 0.7381
# Epoch 0300 | Train Loss: 0.5668 | Val Loss: 0.6712 | Train Acc: 0.7739 | Val Acc: 0.7833
# Epoch 0400 | Train Loss: 0.5095 | Val Loss: 0.7013 | Train Acc: 0.8084 | Val Acc: 0.7946
# Epoch 0499 | Train Loss: 0.4917 | Val Loss: 0.7672 | Train Acc: 0.8010 | Val Acc: 0.8059
# Evaluating hidden=150, lr=0.01, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 0.6383 | Val Loss: 0.6429 | Train Acc: 0.7462 | Val Acc: 0.7540
# Epoch 0200 | Train Loss: 0.5112 | Val Loss: 0.5609 | Train Acc: 0.7982 | Val Acc: 0.8014
# Epoch 0300 | Train Loss: 0.4723 | Val Loss: 0.5473 | Train Acc: 0.8010 | Val Acc: 0.8014
# Epoch 0400 | Train Loss: 0.4537 | Val Loss: 0.5544 | Train Acc: 0.7954 | Val Acc: 0.7946
# Epoch 0499 | Train Loss: 0.4331 | Val Loss: 0.5421 | Train Acc: 0.8310 | Val Acc: 0.8352
# Evaluating hidden=150, lr=0.001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 1.5154 | Val Loss: 1.5441 | Train Acc: 0.4268 | Val Acc: 0.4312
# Epoch 0200 | Train Loss: 1.2828 | Val Loss: 1.3012 | Train Acc: 0.5444 | Val Acc: 0.5463
# Epoch 0300 | Train Loss: 1.1229 | Val Loss: 1.1372 | Train Acc: 0.5760 | Val Acc: 0.5892
# Epoch 0400 | Train Loss: 0.9942 | Val Loss: 1.0206 | Train Acc: 0.6133 | Val Acc: 0.6230
# Epoch 0499 | Train Loss: 0.9007 | Val Loss: 0.9348 | Train Acc: 0.6614 | Val Acc: 0.6682
# Evaluating hidden=150, lr=0.001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 1.5122 | Val Loss: 1.5035 | Train Acc: 0.4980 | Val Acc: 0.4898
# Epoch 0200 | Train Loss: 1.1460 | Val Loss: 1.1397 | Train Acc: 0.6116 | Val Acc: 0.6117
# Epoch 0300 | Train Loss: 0.9445 | Val Loss: 0.9406 | Train Acc: 0.7151 | Val Acc: 0.7246
# Epoch 0400 | Train Loss: 0.8192 | Val Loss: 0.8169 | Train Acc: 0.7236 | Val Acc: 0.7359
# Epoch 0499 | Train Loss: 0.7355 | Val Loss: 0.7379 | Train Acc: 0.7332 | Val Acc: 0.7449
# Evaluating hidden=150, lr=0.0001, weight_decay=0, dropout=0.0, activation=relu
# Epoch 0100 | Train Loss: 4.8849 | Val Loss: 4.8736 | Train Acc: 0.1605 | Val Acc: 0.1670
# Epoch 0200 | Train Loss: 2.3996 | Val Loss: 2.4479 | Train Acc: 0.2595 | Val Acc: 0.2528
# Epoch 0300 | Train Loss: 1.9358 | Val Loss: 1.9836 | Train Acc: 0.2951 | Val Acc: 0.2935
# Epoch 0400 | Train Loss: 1.7506 | Val Loss: 1.7923 | Train Acc: 0.3838 | Val Acc: 0.3973
# Epoch 0499 | Train Loss: 1.6467 | Val Loss: 1.6836 | Train Acc: 0.4211 | Val Acc: 0.4312
# Evaluating hidden=150, lr=0.0001, weight_decay=0, dropout=0.0, activation=tanh
# Epoch 0100 | Train Loss: 2.9154 | Val Loss: 2.8932 | Train Acc: 0.2109 | Val Acc: 0.2144
# Epoch 0200 | Train Loss: 2.3860 | Val Loss: 2.3688 | Train Acc: 0.3019 | Val Acc: 0.3093
# Epoch 0300 | Train Loss: 2.0992 | Val Loss: 2.0855 | Train Acc: 0.4161 | Val Acc: 0.4041
# Early stopping.
#
# Best config found:
# hidden=150, lr=0.01, weight_decay=0, dropout=0.0, activation=tanh
# Best validation accuracy: 0.8375
# Early stopping during final retrain. Epoch: 279
#
# Final test accuracy after retraining with best config: 0.7605

# %%
print(best_config)
# Out:
# (150, 0.01, 0, 0.0, <built-in method tanh of type object at 0x7f61f00817c0>)

# %%
model = PyTorchGCN(
    in_channels=x.shape[1],
    hidden_channels=best_config[0],
    num_classes=len(label_index),
    dropout=best_config[3],
    activation=best_config[4]
)
model.load_state_dict(best_model_state)
model.eval()
# Out:
# PyTorchGCN(
#   (conv1): GCNConv(2, 150)
#   (conv2): GCNConv(150, 30)
# )

# %%
id_to_label = {v: k for k, v in label_index.items()}
target_names = [id_to_label[i] for i in sorted(id_to_label)]
print(classification_report(targets, preds, target_names=target_names))
# Out:
#                                                   precision    recall  f1-score   support
#
#                                          Taliban       0.95      0.73      0.83        49
#    Revolutionary Armed Forces of Colombia (FARC)       0.76      0.65      0.70        48
#   Communist Party of India - Maoist (CPI-Maoist)       0.58      0.63      0.61        49
#                      Irish Republican Army (IRA)       0.83      0.91      0.87        11
#                                          Maoists       0.59      0.65      0.62        54
#              Basque Fatherland and Freedom (ETA)       0.91      0.95      0.93        21
#                                  Sikh Extremists       0.81      0.73      0.77        30
#       National Liberation Army of Colombia (ELN)       0.65      0.67      0.66        42
#                   Kurdistan Workers' Party (PKK)       0.79      0.85      0.81        52
#                          New People's Army (NPA)       0.91      0.83      0.87        59
#                                Shining Path (SL)       0.74      1.00      0.85        26
#                        Donetsk People's Republic       0.90      1.00      0.95        18
#                  Houthi extremists (Ansar Allah)       0.86      0.63      0.73        38
# Farabundo Marti National Liberation Front (FMLN)       0.53      1.00      0.70        24
#      Islamic State of Iraq and the Levant (ISIL)       0.62      0.64      0.63        36
#          Manuel Rodriguez Patriotic Front (FPMR)       0.83      1.00      0.91         5
#                                       Al-Shabaab       1.00      1.00      1.00        22
#                                       Boko Haram       0.87      0.81      0.84        42
#                  Tehrik-i-Taliban Pakistan (TTP)       0.62      0.91      0.74        33
#                           Abu Sayyaf Group (ASG)       0.71      0.81      0.76        27
#        Tupac Amaru Revolutionary Movement (MRTA)       0.00      0.00      0.00         9
#                                Muslim extremists       0.89      0.42      0.58        40
#          Liberation Tigers of Tamil Eelam (LTTE)       0.97      1.00      0.98        28
#                                Fulani extremists       0.87      0.90      0.89        61
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.58      0.86      0.69        22
#                                 Al-Qaida in Iraq       0.50      0.33      0.40        15
#         African National Congress (South Africa)       1.00      1.00      1.00        15
#        Corsican National Liberation Front (FLNC)       0.58      0.88      0.70         8
#                Nicaraguan Democratic Force (FDN)       0.78      0.50      0.61        42
#                                     Palestinians       0.83      0.91      0.87        22
#
#                                         accuracy                           0.76       948
#                                        macro avg       0.75      0.77      0.75       948
#                                     weighted avg       0.77      0.76      0.75       948
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(targets, preds)
plt.figure(figsize=(12, 10))  # Adjust size as needed
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names,
            yticklabels=target_names)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig(f"confusion_matrix_gtd{partition}.png", dpi=300)

plt.show()

# %%
plt.savefig(f"confusion_matrix_gtd{partition}.png", dpi=300)
