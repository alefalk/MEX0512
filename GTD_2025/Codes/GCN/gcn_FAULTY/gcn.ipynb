# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from build_graph_data import *


from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
trainpath = '../../data/top30groups/traindata/train100.csv'
traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testpath = '../../data/top30groups/testdata/test100.csv'
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
# Read and preprocess
#traindata_uniques = create_data(traindata)
#testdata_uniques = create_data(testdata)

# Build graph data
#adj_train, idx_train, coord_train, X_train, label_index = build_graph_data(traindata_uniques)

#adj_test, idx_test, coord_test, X_test, _ = build_graph_data(testdata_uniques)

# Step 1: Merge train and test to get global coordinate space
combined_df = pd.concat([traindata, testdata])
combined_unique = create_data(combined_df)
_, _, coord_to_index, global_feature_matrix, global_label_index = build_graph_data(combined_unique)

# Step 2: Filter to only first attack per group in train/test separately
train_unique = create_data(traindata)
test_unique = create_data(testdata)

# Step 3: Build graph data using shared coord_to_index and feature matrix
adj_train, idx_train, _, _, _ = build_graph_data(train_unique, coord_to_index=coord_to_index)
adj_test, idx_test, _, _, _ = build_graph_data(test_unique, coord_to_index=coord_to_index)

# Step 4: Use the same global_feature_matrix and label_index
X_train = X_test = global_feature_matrix
label_index = global_label_index
# Out:
#        longitude   latitude                                             gname
# 1472  124.599145   6.637796                            Abu Sayyaf Group (ASG)
# 820    28.427501 -26.141151          African National Congress (South Africa)
# 874    44.371773  33.303566                                  Al-Qaida in Iraq
# 662    39.174905  21.543155          Al-Qaida in the Arabian Peninsula (AQAP)
# 229    45.326115   2.059819                                        Al-Shabaab
# 837    -2.052454  43.189944               Basque Fatherland and Freedom (ETA)
# 674    13.141459  11.840929                                        Boko Haram
# 524    87.319000  22.424000    Communist Party of India - Maoist (CPI-Maoist)
# 1832    8.742907  41.930607         Corsican National Liberation Front (FLNC)
# 60     37.613808  48.851688                         Donetsk People's Republic
# 289   -90.529068  14.622869  Farabundo Marti National Liberation Front (FMLN)
# 1095    8.885243   9.933381                                 Fulani extremists
# 210    42.575260  16.893194                   Houthi extremists (Ansar Allah)
# 102    -5.956210  54.607712                       Irish Republican Army (IRA)
# 893    43.143570  36.354145       Islamic State of Iraq and the Levant (ISIL)
# 926    40.393750  37.170607                    Kurdistan Workers' Party (PKK)
# 115    80.388133   8.345185           Liberation Tigers of Tamil Eelam (LTTE)
# 2081  -70.505302 -33.366238           Manuel Rodriguez Patriotic Front (FPMR)
# 1642   71.192381  22.258652                                           Maoists
# 680    81.268402   8.457907                                 Muslim extremists
# 1066  -75.564766   6.242026        National Liberation Army of Colombia (ELN)
# 1932  120.763556  15.544809                           New People's Army (NPA)
# 1302  -84.900000  12.100000                 Nicaraguan Democratic Force (FDN)
# 954    35.203400  31.771599                                      Palestinians
# 297   -73.950146   6.313712     Revolutionary Armed Forces of Colombia (FARC)
# 1511  -74.218628 -13.152712                                 Shining Path (SL)
# 114    75.341218  31.147131                                   Sikh Extremists
# 412    70.449593  34.417122                                           Taliban
# 339    71.440620  33.590603                   Tehrik-i-Taliban Pakistan (TTP)
# 455   -76.978462 -11.967368         Tupac Amaru Revolutionary Movement (MRTA)
# Number of unique coordinates (nodes): 30
# Number of unique labels:  30
#        longitude   latitude                                             gname
# 174  123.878250  10.295334                           New People's Army (NPA)
# 455  -86.345742  13.131923                 Nicaraguan Democratic Force (FDN)
# 821   35.203400  31.771599                                      Palestinians
# 297  -73.950146   6.313712     Revolutionary Armed Forces of Colombia (FARC)
# 798  -77.042793 -12.046374                                 Shining Path (SL)
# 441   75.341218  31.147131                                   Sikh Extremists
# 71    65.675942  31.617667                                           Taliban
# 895   69.329167  32.781111                   Tehrik-i-Taliban Pakistan (TTP)
# 474  -76.978462 -11.967368         Tupac Amaru Revolutionary Movement (MRTA)
# Number of unique coordinates (nodes): 30
# Number of unique labels:  30
# Number of unique coordinates (nodes): 30
# Number of unique labels:  30

# %% [markdown]
# # Data is now sorted by date and gname

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# %%
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

print(len(label_index))

from torch_geometric.data import Data
from scipy.sparse import coo_matrix

def run_epoch(model, adjacency_matrices, first_attack_indices, feature_matrix, label_index, is_training=True):
    correct = 0
    total = 0

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    loss_fn = torch.nn.NLLLoss()

    model.train() if is_training else model.eval()
    for group_name, A_np in adjacency_matrices.items():
        if group_name not in label_index:
            continue  # skip if label not found

        label = torch.tensor([label_index[group_name]], dtype=torch.long)
        node_idx = node_indices[group_name][0]  # get the first node only

        A_coo = coo_matrix(A_np)
        edge_index = torch.tensor(np.vstack((A_coo.row, A_coo.col)), dtype=torch.long)
        x = torch.tensor(feature_matrix, dtype=torch.float32)
        data = Data(x=x, edge_index=edge_index)

        output = model(data.x, data.edge_index)
        pred = output[node_idx]
        loss = loss_fn(pred.unsqueeze(0), label)

        if is_training:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        predicted_class = pred.argmax().item()
        correct += int(predicted_class == label.item())
        total += 1

    return correct / total if total > 0 else 0.0
# Out:
# 30

# %%
model = PyTorchGCN(in_channels=X_train.shape[1], hidden_channels=16, num_classes=len(label_index))

for epoch in range(10):
    train_acc = run_epoch(model, adj_train, idx_train, X_train, label_index, is_training=True)
    test_acc = run_epoch(model, adj_test, idx_test, X_test, label_index, is_training=False)
    print(f"Epoch {epoch+1} - Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 4
#       1 model = PyTorchGCN(in_channels=X_train.shape[1], hidden_channels=16, num_classes=len(label_index))
#       3 for epoch in range(10):
# ----> 4     train_acc = run_epoch(model, adj_train, idx_train, X_train, label_index, is_training=True)
#       5     test_acc = run_epoch(model, adj_test, idx_test, X_test, label_index, is_training=False)
#       6     print(f"Epoch {epoch+1} - Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")
#
# Cell In[14], line 31, in run_epoch(model, adjacency_matrices, first_attack_indices, feature_matrix, label_index, is_training)
#      29 output = model(data.x, data.edge_index)
#      30 pred = output[node_idx]
# ---> 31 loss = loss_fn(pred.unsqueeze(0), label)
#      33 if is_training:
#      34     optimizer.zero_grad()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\nn\modules\loss.py:251, in NLLLoss.forward(self, input, target)
#     250 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 251     return F.nll_loss(
#     252         input,
#     253         target,
#     254         weight=self.weight,
#     255         ignore_index=self.ignore_index,
#     256         reduction=self.reduction,
#     257     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\nn\functional.py:3158, in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    3156 if size_average is not None or reduce is not None:
#    3157     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3158 return torch._C._nn.nll_loss_nd(
#    3159     input, target, weight, _Reduction.get_enum(reduction), ignore_index
#    3160 )
#
# RuntimeError: Expected target size [1, 30], got [1]
