# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
partition = 200

# %%
trainpath = f'../../../data/top30groups/noGeographic/train1/train{partition}.csv'
testpath = f'../../../data/top30groups/noGeographic/test1/test{partition}.csv'
traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
combined = pd.concat([traindata, testdata], axis = 0)
data = combined

# %%
import itertools

def create_node_dataframe(data, node_features, label_column='gname'):
    relevant_data = data[node_features + [label_column]].copy()
    relevant_data['combination'] = list(zip(*(relevant_data[feat] for feat in node_features)))
    df_unique = relevant_data.drop_duplicates(subset=['combination'], keep='first').reset_index(drop=True)
    return df_unique[['combination', label_column]]

# All possible features to try
all_features = ['attacktype1', 'target1', 'weaptype1', 'nkill']
label_column = 'gname'

min_nodes = 1000
combination_dfs = {}
kept_combinations = []  # To store info about kept subsets

for r in range(2, len(all_features) + 1):
    for feature_subset in itertools.combinations(all_features, r):
        feature_subset = list(feature_subset)
        df_filtered = create_node_dataframe(data, feature_subset, label_column=label_column)

        n_nodes = df_filtered.shape[0]
        key = ", ".join(feature_subset)

        if n_nodes >= min_nodes:
            combination_dfs[key] = df_filtered
            kept_combinations.append((key, feature_subset, n_nodes))
            print(f"Subset: {key}, Nodes: {n_nodes}")
        else:
            print(f"Subset: {key} had too few unique combinations: {n_nodes}, discarding.")

# After the loop, print a summary of kept combinations
print("\n--- Kept Combinations ---")
for key, features, n_nodes in kept_combinations:
    print(f"Key: {key} | Features: {features} | Nodes: {n_nodes}")
# Out:
# Subset: attacktype1, target1, Nodes: 3658
# Subset: attacktype1, weaptype1 had too few unique combinations: 35, discarding.
# Subset: attacktype1, nkill had too few unique combinations: 195, discarding.
# Subset: target1, weaptype1, Nodes: 3614
# Subset: target1, nkill, Nodes: 4077
# Subset: weaptype1, nkill had too few unique combinations: 162, discarding.
# Subset: attacktype1, target1, weaptype1, Nodes: 3730
# Subset: attacktype1, target1, nkill, Nodes: 4322
# Subset: attacktype1, weaptype1, nkill had too few unique combinations: 286, discarding.
# Subset: target1, weaptype1, nkill, Nodes: 4289
# Subset: attacktype1, target1, weaptype1, nkill, Nodes: 4392
#
# --- Kept Combinations ---
# Key: attacktype1, target1 | Features: ['attacktype1', 'target1'] | Nodes: 3658
# Key: target1, weaptype1 | Features: ['target1', 'weaptype1'] | Nodes: 3614
# Key: target1, nkill | Features: ['target1', 'nkill'] | Nodes: 4077
# Key: attacktype1, target1, weaptype1 | Features: ['attacktype1', 'target1', 'weaptype1'] | Nodes: 3730
# Key: attacktype1, target1, nkill | Features: ['attacktype1', 'target1', 'nkill'] | Nodes: 4322
# Key: target1, weaptype1, nkill | Features: ['target1', 'weaptype1', 'nkill'] | Nodes: 4289
# Key: attacktype1, target1, weaptype1, nkill | Features: ['attacktype1', 'target1', 'weaptype1', 'nkill'] | Nodes: 4392

# %%
def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

def run_epoch(model, data, labels, mask, optimizer=None):
    is_training = optimizer is not None
    if is_training:
        model.train()
    else:
        model.eval()

    out = model(data.x, data.edge_index)
    loss_fn = torch.nn.CrossEntropyLoss()

    loss = loss_fn(out[mask], labels[mask])

    if is_training:
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Accuracy
    pred = out[mask].argmax(dim=1)
    acc = (pred == labels[mask]).float().mean().item()
    return acc, loss.item()

# %%
import os 
if not os.path.isdir(f"Results"):
    os.mkdir(f"Results")

# %%
import os
import ast
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

# Ensure results directory exists
os.makedirs("Results", exist_ok=True)

output_path = f"Results/gcn_{partition}.txt"

# Initialize results and clear output file
results = {}
with open(output_path, "w") as f:
    f.write("Subset\tTest Accuracy\tEpoch\tFeatures Used\n")

# Loop through each feature combination
for key, df_unique in combination_dfs.items():
    print(f"\n--- Processing feature subset: {key} ---")

    # Ensure tuple format
    df_unique = df_unique.copy()
    df_unique['combination'] = df_unique['combination'].apply(to_tuple_if_needed)

    # Build coord_to_index
    coord_to_index = {row['combination']: i for i, row in df_unique.iterrows()}

    # Build graph data
    adj_matrix, feature_matrix, label_index = build_graph_data(df_unique, coord_to_index)

    # Get original data mapped to current node set
    features_used = key.split(', ')
    full_data = data[features_used + ['gname']].copy()
    full_data['combination'] = list(zip(*(full_data[feat] for feat in features_used)))
    full_data['combination'] = full_data['combination'].apply(to_tuple_if_needed)
    full_data = full_data[full_data['combination'].isin(coord_to_index)]

    # Split into train/test
    split_point = int(0.7 * len(full_data))
    train_df = full_data[:split_point]
    test_df = full_data[split_point:]

    # Feature matrix
    coords = np.array(list(coord_to_index.keys()), dtype=np.float32)
    x = torch.tensor(coords, dtype=torch.float32)

    # Label and mask tensors
    num_nodes = x.shape[0]
    y = torch.full((num_nodes,), -1, dtype=torch.long)
    train_mask = torch.zeros(num_nodes, dtype=torch.bool)
    test_mask = torch.zeros(num_nodes, dtype=torch.bool)

    for _, row in train_df.iterrows():
        idx = coord_to_index[row['combination']]
        y[idx] = label_index[row['gname']]
        train_mask[idx] = True

    for _, row in test_df.iterrows():
        idx = coord_to_index[row['combination']]
        y[idx] = label_index[row['gname']]
        test_mask[idx] = True

    # Graph edges
    A_coo = coo_matrix(adj_matrix)
    edge_index = torch.tensor(np.vstack((A_coo.row, A_coo.col)), dtype=torch.long)

    # Build graph object
    data_obj = Data(x=x, edge_index=edge_index)

    # Model and optimizer
    model = PyTorchGCN(in_channels=x.shape[1], hidden_channels=16, num_classes=len(label_index))
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    # Training loop
    max_test_acc = 0
    max_test_epoch = -1
    for epoch in range(2000):
        train_acc, train_loss = run_epoch(model, data_obj, y, train_mask, optimizer)
        test_acc, test_loss = run_epoch(model, data_obj, y, test_mask)
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            max_test_epoch = epoch + 1
        if (epoch + 1) % 100 == 0 or epoch == 1999:
            print(f"Epoch {epoch+1} | Train Acc: {train_acc:.4f} | Test Acc: {test_acc:.4f} | "
                  f"Train Loss: {train_loss:.4f} | Test Loss: {test_loss:.4f}")

    print(f"Best test accuracy for {key}: {max_test_acc:.4f} at epoch {max_test_epoch}")
    results[key] = max_test_acc

    # Append result to summary file
    with open(output_path, "a") as f:
        f.write(f"Subset: {key}\n")
        f.write(f"Best test Acc: {max_test_acc:.4f}\n")
        f.write(f"Best epoch: {max_test_epoch}\n")
        f.write(f"{'-' * 37}\n\n")
# Out:
# --- Processing feature subset: attacktype1, target1 ---
# Number of total nodes (unique coordinates): 3658
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0529 | Test Acc: 0.0473 | Train Loss: 8.9092 | Test Loss: 9.5715
# Epoch 200 | Train Acc: 0.0795 | Test Acc: 0.0669 | Train Loss: 3.1478 | Test Loss: 3.3488
# Epoch 300 | Train Acc: 0.1426 | Test Acc: 0.0914 | Train Loss: 2.9594 | Test Loss: 3.1003
# Epoch 400 | Train Acc: 0.1715 | Test Acc: 0.1265 | Train Loss: 2.8847 | Test Loss: 2.9973
# Epoch 500 | Train Acc: 0.1970 | Test Acc: 0.1502 | Train Loss: 2.8723 | Test Loss: 3.1698
# Epoch 600 | Train Acc: 0.1250 | Test Acc: 0.1322 | Train Loss: 5.6485 | Test Loss: 5.5387
# Epoch 700 | Train Acc: 0.2424 | Test Acc: 0.1894 | Train Loss: 2.7532 | Test Loss: 2.8698
# Epoch 800 | Train Acc: 0.2454 | Test Acc: 0.1698 | Train Loss: 2.7161 | Test Loss: 2.8374
# Epoch 900 | Train Acc: 0.2694 | Test Acc: 0.2024 | Train Loss: 2.6830 | Test Loss: 2.8073
# Epoch 1000 | Train Acc: 0.2720 | Test Acc: 0.2302 | Train Loss: 2.6534 | Test Loss: 2.7808
# Epoch 1100 | Train Acc: 0.2743 | Test Acc: 0.2359 | Train Loss: 2.6290 | Test Loss: 2.7597
# Epoch 1200 | Train Acc: 0.2780 | Test Acc: 0.2351 | Train Loss: 2.6068 | Test Loss: 2.7418
# Epoch 1300 | Train Acc: 0.2829 | Test Acc: 0.2335 | Train Loss: 2.5863 | Test Loss: 2.7255
# Epoch 1400 | Train Acc: 0.2889 | Test Acc: 0.2343 | Train Loss: 2.5670 | Test Loss: 2.7087
# Epoch 1500 | Train Acc: 0.2754 | Test Acc: 0.2351 | Train Loss: 2.5484 | Test Loss: 2.6928
# Epoch 1600 | Train Acc: 0.1644 | Test Acc: 0.1641 | Train Loss: 5.0497 | Test Loss: 5.1081
# Epoch 1700 | Train Acc: 0.2848 | Test Acc: 0.2539 | Train Loss: 2.5110 | Test Loss: 2.6628
# Epoch 1800 | Train Acc: 0.3347 | Test Acc: 0.2645 | Train Loss: 2.4903 | Test Loss: 2.6531
# Epoch 1900 | Train Acc: 0.3407 | Test Acc: 0.2653 | Train Loss: 2.4729 | Test Loss: 2.6458
# Epoch 2000 | Train Acc: 0.3418 | Test Acc: 0.2637 | Train Loss: 2.4563 | Test Loss: 2.6320
# Best test accuracy for attacktype1, target1: 0.2669 at epoch 1507
#
# --- Processing feature subset: target1, weaptype1 ---
# Number of total nodes (unique coordinates): 3614
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0520 | Test Acc: 0.0423 | Train Loss: 12.9959 | Test Loss: 13.0930
# Epoch 200 | Train Acc: 0.1127 | Test Acc: 0.0878 | Train Loss: 3.2581 | Test Loss: 3.4718
# Epoch 300 | Train Acc: 0.1431 | Test Acc: 0.0903 | Train Loss: 2.8822 | Test Loss: 2.9908
# Epoch 400 | Train Acc: 0.1966 | Test Acc: 0.1674 | Train Loss: 2.7139 | Test Loss: 2.8560
# Epoch 500 | Train Acc: 0.2660 | Test Acc: 0.1856 | Train Loss: 2.5566 | Test Loss: 2.7440
# Epoch 600 | Train Acc: 0.1882 | Test Acc: 0.0953 | Train Loss: 5.4814 | Test Loss: 5.4668
# Epoch 700 | Train Acc: 0.2030 | Test Acc: 0.1980 | Train Loss: 2.6953 | Test Loss: 2.8292
# Epoch 800 | Train Acc: 0.2846 | Test Acc: 0.2585 | Train Loss: 2.4161 | Test Loss: 2.5999
# Epoch 900 | Train Acc: 0.3165 | Test Acc: 0.2618 | Train Loss: 2.3546 | Test Loss: 2.5642
# Epoch 1000 | Train Acc: 0.3222 | Test Acc: 0.2701 | Train Loss: 2.3115 | Test Loss: 2.5113
# Epoch 1100 | Train Acc: 0.3275 | Test Acc: 0.2676 | Train Loss: 2.2805 | Test Loss: 2.4969
# Epoch 1200 | Train Acc: 0.3313 | Test Acc: 0.2850 | Train Loss: 2.2598 | Test Loss: 2.4880
# Epoch 1300 | Train Acc: 0.3051 | Test Acc: 0.2759 | Train Loss: 2.2499 | Test Loss: 2.4927
# Epoch 1400 | Train Acc: 0.1662 | Test Acc: 0.1019 | Train Loss: 4.5341 | Test Loss: 5.7216
# Epoch 1500 | Train Acc: 0.3268 | Test Acc: 0.2560 | Train Loss: 2.2821 | Test Loss: 2.4886
# Epoch 1600 | Train Acc: 0.3617 | Test Acc: 0.2916 | Train Loss: 2.2320 | Test Loss: 2.4635
# Epoch 1700 | Train Acc: 0.3495 | Test Acc: 0.2734 | Train Loss: 2.2202 | Test Loss: 2.4643
# Epoch 1800 | Train Acc: 0.3461 | Test Acc: 0.2568 | Train Loss: 2.2110 | Test Loss: 2.4625
# Epoch 1900 | Train Acc: 0.3731 | Test Acc: 0.2883 | Train Loss: 2.2026 | Test Loss: 2.4571
# Epoch 2000 | Train Acc: 0.3237 | Test Acc: 0.2701 | Train Loss: 2.3354 | Test Loss: 2.5114
# Best test accuracy for target1, weaptype1: 0.3654 at epoch 1919
#
# --- Processing feature subset: target1, nkill ---
# Number of total nodes (unique coordinates): 4077
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0455 | Test Acc: 0.0495 | Train Loss: 19.8706 | Test Loss: 18.7562
# Epoch 200 | Train Acc: 0.0499 | Test Acc: 0.0429 | Train Loss: 9.5828 | Test Loss: 9.1796
# Epoch 300 | Train Acc: 0.1082 | Test Acc: 0.0982 | Train Loss: 2.9689 | Test Loss: 3.0995
# Epoch 400 | Train Acc: 0.1403 | Test Acc: 0.1156 | Train Loss: 3.0116 | Test Loss: 3.1364
# Epoch 500 | Train Acc: 0.1916 | Test Acc: 0.1673 | Train Loss: 2.9400 | Test Loss: 3.0402
# Epoch 600 | Train Acc: 0.2033 | Test Acc: 0.1622 | Train Loss: 2.9073 | Test Loss: 3.0041
# Epoch 700 | Train Acc: 0.2026 | Test Acc: 0.1636 | Train Loss: 2.8624 | Test Loss: 2.9799
# Epoch 800 | Train Acc: 0.1165 | Test Acc: 0.0989 | Train Loss: 8.7748 | Test Loss: 9.4861
# Epoch 900 | Train Acc: 0.1343 | Test Acc: 0.1149 | Train Loss: 3.6810 | Test Loss: 3.5686
# Epoch 1000 | Train Acc: 0.2719 | Test Acc: 0.2335 | Train Loss: 2.7582 | Test Loss: 2.8782
# Epoch 1100 | Train Acc: 0.2569 | Test Acc: 0.2422 | Train Loss: 2.7203 | Test Loss: 2.8491
# Epoch 1200 | Train Acc: 0.2565 | Test Acc: 0.2422 | Train Loss: 2.7016 | Test Loss: 2.8389
# Epoch 1300 | Train Acc: 0.2572 | Test Acc: 0.2407 | Train Loss: 2.6847 | Test Loss: 2.8266
# Epoch 1400 | Train Acc: 0.2616 | Test Acc: 0.2415 | Train Loss: 2.6688 | Test Loss: 2.8136
# Epoch 1500 | Train Acc: 0.2632 | Test Acc: 0.2400 | Train Loss: 2.6535 | Test Loss: 2.7923
# Epoch 1600 | Train Acc: 0.2659 | Test Acc: 0.2509 | Train Loss: 2.6355 | Test Loss: 2.7590
# Epoch 1700 | Train Acc: 0.2304 | Test Acc: 0.2036 | Train Loss: 2.7881 | Test Loss: 2.7749
# Epoch 1800 | Train Acc: 0.2150 | Test Acc: 0.1745 | Train Loss: 2.8107 | Test Loss: 2.8639
# Epoch 1900 | Train Acc: 0.2816 | Test Acc: 0.2342 | Train Loss: 2.5880 | Test Loss: 2.7172
# Epoch 2000 | Train Acc: 0.2837 | Test Acc: 0.2342 | Train Loss: 2.5590 | Test Loss: 2.7028
# Best test accuracy for target1, nkill: 0.2807 at epoch 1674
#
# --- Processing feature subset: attacktype1, target1, weaptype1 ---
# Number of total nodes (unique coordinates): 3730
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0673 | Test Acc: 0.0586 | Train Loss: 19.7529 | Test Loss: 19.9768
# Epoch 200 | Train Acc: 0.0879 | Test Acc: 0.0996 | Train Loss: 9.6769 | Test Loss: 9.5797
# Epoch 300 | Train Acc: 0.1191 | Test Acc: 0.0635 | Train Loss: 8.0828 | Test Loss: 9.6298
# Epoch 400 | Train Acc: 0.1463 | Test Acc: 0.1020 | Train Loss: 5.9466 | Test Loss: 5.6889
# Epoch 500 | Train Acc: 0.2404 | Test Acc: 0.1920 | Train Loss: 2.4426 | Test Loss: 2.6077
# Epoch 600 | Train Acc: 0.2776 | Test Acc: 0.2394 | Train Loss: 2.3966 | Test Loss: 2.5667
# Epoch 700 | Train Acc: 0.2838 | Test Acc: 0.2659 | Train Loss: 2.3588 | Test Loss: 2.5334
# Epoch 800 | Train Acc: 0.2974 | Test Acc: 0.2635 | Train Loss: 2.3266 | Test Loss: 2.5164
# Epoch 900 | Train Acc: 0.3066 | Test Acc: 0.2747 | Train Loss: 2.2982 | Test Loss: 2.4946
# Epoch 1000 | Train Acc: 0.3180 | Test Acc: 0.2948 | Train Loss: 2.2625 | Test Loss: 2.4545
# Epoch 1100 | Train Acc: 0.3246 | Test Acc: 0.2988 | Train Loss: 2.2349 | Test Loss: 2.4345
# Epoch 1200 | Train Acc: 0.3051 | Test Acc: 0.2635 | Train Loss: 2.2449 | Test Loss: 2.4656
# Epoch 1300 | Train Acc: 0.1971 | Test Acc: 0.1028 | Train Loss: 6.0201 | Test Loss: 7.5411
# Epoch 1400 | Train Acc: 0.3151 | Test Acc: 0.2916 | Train Loss: 2.2469 | Test Loss: 2.4526
# Epoch 1500 | Train Acc: 0.3423 | Test Acc: 0.3390 | Train Loss: 2.2141 | Test Loss: 2.4299
# Epoch 1600 | Train Acc: 0.3482 | Test Acc: 0.3414 | Train Loss: 2.1987 | Test Loss: 2.4190
# Epoch 1700 | Train Acc: 0.3607 | Test Acc: 0.3462 | Train Loss: 2.1855 | Test Loss: 2.4116
# Epoch 1800 | Train Acc: 0.3673 | Test Acc: 0.3478 | Train Loss: 2.1733 | Test Loss: 2.4040
# Epoch 1900 | Train Acc: 0.3783 | Test Acc: 0.3486 | Train Loss: 2.1627 | Test Loss: 2.4012
# Epoch 2000 | Train Acc: 0.3824 | Test Acc: 0.3333 | Train Loss: 2.1534 | Test Loss: 2.3995
# Best test accuracy for attacktype1, target1, weaptype1: 0.3606 at epoch 1424
#
# --- Processing feature subset: attacktype1, target1, nkill ---
# Number of total nodes (unique coordinates): 4322
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0598 | Test Acc: 0.0485 | Train Loss: 4.1242 | Test Loss: 4.0910
# Epoch 200 | Train Acc: 0.0981 | Test Acc: 0.0744 | Train Loss: 3.0450 | Test Loss: 3.2250
# Epoch 300 | Train Acc: 0.1586 | Test Acc: 0.1188 | Train Loss: 2.9035 | Test Loss: 2.9558
# Epoch 400 | Train Acc: 0.1602 | Test Acc: 0.1270 | Train Loss: 2.9827 | Test Loss: 3.1910
# Epoch 500 | Train Acc: 0.1041 | Test Acc: 0.1092 | Train Loss: 4.3135 | Test Loss: 4.6527
# Epoch 600 | Train Acc: 0.2042 | Test Acc: 0.1590 | Train Loss: 2.8013 | Test Loss: 2.9475
# Epoch 700 | Train Acc: 0.2206 | Test Acc: 0.1495 | Train Loss: 2.7184 | Test Loss: 2.9762
# Epoch 800 | Train Acc: 0.2099 | Test Acc: 0.1782 | Train Loss: 2.7600 | Test Loss: 2.9212
# Epoch 900 | Train Acc: 0.2374 | Test Acc: 0.1877 | Train Loss: 2.7468 | Test Loss: 2.9369
# Epoch 1000 | Train Acc: 0.2172 | Test Acc: 0.2075 | Train Loss: 2.6081 | Test Loss: 2.8079
# Epoch 1100 | Train Acc: 0.1415 | Test Acc: 0.1365 | Train Loss: 3.4348 | Test Loss: 3.7515
# Epoch 1200 | Train Acc: 0.1823 | Test Acc: 0.1631 | Train Loss: 2.7350 | Test Loss: 2.9170
# Epoch 1300 | Train Acc: 0.2232 | Test Acc: 0.1631 | Train Loss: 2.6531 | Test Loss: 3.0720
# Epoch 1400 | Train Acc: 0.2599 | Test Acc: 0.2007 | Train Loss: 2.5338 | Test Loss: 2.7471
# Epoch 1500 | Train Acc: 0.2577 | Test Acc: 0.2089 | Train Loss: 2.5162 | Test Loss: 2.7424
# Epoch 1600 | Train Acc: 0.2688 | Test Acc: 0.2341 | Train Loss: 2.4976 | Test Loss: 2.7319
# Epoch 1700 | Train Acc: 0.2700 | Test Acc: 0.1802 | Train Loss: 2.5278 | Test Loss: 2.7732
# Epoch 1800 | Train Acc: 0.2729 | Test Acc: 0.1816 | Train Loss: 2.5109 | Test Loss: 2.7388
# Epoch 1900 | Train Acc: 0.1953 | Test Acc: 0.1065 | Train Loss: 2.7271 | Test Loss: 2.9779
# Epoch 2000 | Train Acc: 0.2491 | Test Acc: 0.1877 | Train Loss: 2.6536 | Test Loss: 2.8852
# Best test accuracy for attacktype1, target1, nkill: 0.2689 at epoch 1767
#
# --- Processing feature subset: target1, weaptype1, nkill ---
# Number of total nodes (unique coordinates): 4289
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0847 | Test Acc: 0.0613 | Train Loss: 3.7495 | Test Loss: 3.6848
# Epoch 200 | Train Acc: 0.1144 | Test Acc: 0.1013 | Train Loss: 2.9676 | Test Loss: 3.0580
# Epoch 300 | Train Acc: 0.1255 | Test Acc: 0.0972 | Train Loss: 2.9001 | Test Loss: 3.0171
# Epoch 400 | Train Acc: 0.1599 | Test Acc: 0.1220 | Train Loss: 2.8432 | Test Loss: 2.9867
# Epoch 500 | Train Acc: 0.1682 | Test Acc: 0.1289 | Train Loss: 2.7960 | Test Loss: 2.9669
# Epoch 600 | Train Acc: 0.1841 | Test Acc: 0.1427 | Train Loss: 2.7574 | Test Loss: 2.9461
# Epoch 700 | Train Acc: 0.2291 | Test Acc: 0.1702 | Train Loss: 2.7244 | Test Loss: 2.9314
# Epoch 800 | Train Acc: 0.1032 | Test Acc: 0.0662 | Train Loss: 19.1124 | Test Loss: 20.1908
# Epoch 900 | Train Acc: 0.2392 | Test Acc: 0.2185 | Train Loss: 2.7688 | Test Loss: 2.9691
# Epoch 1000 | Train Acc: 0.2265 | Test Acc: 0.2074 | Train Loss: 2.6587 | Test Loss: 2.8600
# Epoch 1100 | Train Acc: 0.2555 | Test Acc: 0.2136 | Train Loss: 2.6012 | Test Loss: 2.7917
# Epoch 1200 | Train Acc: 0.2631 | Test Acc: 0.2205 | Train Loss: 2.5646 | Test Loss: 2.7746
# Epoch 1300 | Train Acc: 0.2651 | Test Acc: 0.2185 | Train Loss: 2.5375 | Test Loss: 2.7622
# Epoch 1400 | Train Acc: 0.2370 | Test Acc: 0.1737 | Train Loss: 2.5753 | Test Loss: 2.9168
# Epoch 1500 | Train Acc: 0.2469 | Test Acc: 0.2371 | Train Loss: 2.5871 | Test Loss: 2.8963
# Epoch 1600 | Train Acc: 0.2870 | Test Acc: 0.2254 | Train Loss: 2.5510 | Test Loss: 2.8221
# Epoch 1700 | Train Acc: 0.2886 | Test Acc: 0.2267 | Train Loss: 2.4816 | Test Loss: 2.7749
# Epoch 1800 | Train Acc: 0.2641 | Test Acc: 0.2591 | Train Loss: 2.4379 | Test Loss: 2.7496
# Epoch 1900 | Train Acc: 0.2832 | Test Acc: 0.2323 | Train Loss: 2.4896 | Test Loss: 2.7644
# Epoch 2000 | Train Acc: 0.3093 | Test Acc: 0.2653 | Train Loss: 2.3871 | Test Loss: 2.7036
# Best test accuracy for target1, weaptype1, nkill: 0.2977 at epoch 1943
#
# --- Processing feature subset: attacktype1, target1, weaptype1, nkill ---
# Number of total nodes (unique coordinates): 4392
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0946 | Test Acc: 0.0701 | Train Loss: 3.1026 | Test Loss: 3.1812
# Epoch 200 | Train Acc: 0.1115 | Test Acc: 0.0863 | Train Loss: 2.9206 | Test Loss: 3.0077
# Epoch 300 | Train Acc: 0.1491 | Test Acc: 0.1106 | Train Loss: 2.8260 | Test Loss: 2.9297
# Epoch 400 | Train Acc: 0.2092 | Test Acc: 0.1281 | Train Loss: 2.7571 | Test Loss: 2.8903
# Epoch 500 | Train Acc: 0.2070 | Test Acc: 0.1537 | Train Loss: 2.6969 | Test Loss: 2.8616
# Epoch 600 | Train Acc: 0.2319 | Test Acc: 0.1618 | Train Loss: 2.5926 | Test Loss: 2.7893
# Epoch 700 | Train Acc: 0.2793 | Test Acc: 0.2016 | Train Loss: 2.5087 | Test Loss: 2.6913
# Epoch 800 | Train Acc: 0.3107 | Test Acc: 0.2535 | Train Loss: 2.4305 | Test Loss: 2.6539
# Epoch 900 | Train Acc: 0.3257 | Test Acc: 0.2576 | Train Loss: 2.3802 | Test Loss: 2.6299
# Epoch 1000 | Train Acc: 0.3247 | Test Acc: 0.2670 | Train Loss: 2.3500 | Test Loss: 2.6108
# Epoch 1100 | Train Acc: 0.2740 | Test Acc: 0.2165 | Train Loss: 2.4103 | Test Loss: 2.6466
# Epoch 1200 | Train Acc: 0.3437 | Test Acc: 0.2805 | Train Loss: 2.2909 | Test Loss: 2.5820
# Epoch 1300 | Train Acc: 0.3285 | Test Acc: 0.2610 | Train Loss: 2.3265 | Test Loss: 2.6120
# Epoch 1400 | Train Acc: 0.3518 | Test Acc: 0.2812 | Train Loss: 2.2575 | Test Loss: 2.5551
# Epoch 1500 | Train Acc: 0.2752 | Test Acc: 0.1773 | Train Loss: 2.3243 | Test Loss: 2.6373
# Epoch 1600 | Train Acc: 0.3720 | Test Acc: 0.2434 | Train Loss: 2.2278 | Test Loss: 2.5569
# Epoch 1700 | Train Acc: 0.3272 | Test Acc: 0.2846 | Train Loss: 2.2283 | Test Loss: 2.5491
# Epoch 1800 | Train Acc: 0.3839 | Test Acc: 0.2556 | Train Loss: 2.2062 | Test Loss: 2.5473
# Epoch 1900 | Train Acc: 0.2282 | Test Acc: 0.1598 | Train Loss: 3.0003 | Test Loss: 3.0382
# Epoch 2000 | Train Acc: 0.3982 | Test Acc: 0.2980 | Train Loss: 2.1704 | Test Loss: 2.5329
# Best test accuracy for attacktype1, target1, weaptype1, nkill: 0.3264 at epoch 1934
