# %%
import numpy as np
import pandas as pd
import os
import networkx as nx
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from build_graph_data import *
from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
partition = 300

# %%
trainpath = f'../../../data/top30groups/noGeographic/train1/train{partition}.csv'
testpath = f'../../../data/top30groups/noGeographic/test1/test{partition}.csv'
traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
combined = pd.concat([traindata, testdata], axis = 0)
data = combined

# %%
import itertools

def create_node_dataframe(data, node_features, label_column='gname'):
    relevant_data = data[node_features + [label_column]].copy()
    relevant_data['combination'] = list(zip(*(relevant_data[feat] for feat in node_features)))
    df_unique = relevant_data.drop_duplicates(subset=['combination'], keep='first').reset_index(drop=True)
    return df_unique[['combination', label_column]]

# All possible features to try
all_features = ['attacktype1', 'target1', 'weaptype1', 'nkill']
label_column = 'gname'

min_nodes = len(data) * 0.4
print(min_nodes)
combination_dfs = {}
kept_combinations = []  # To store info about kept subsets

for r in range(2, len(all_features) + 1):
    for feature_subset in itertools.combinations(all_features, r):
        feature_subset = list(feature_subset)
        df_filtered = create_node_dataframe(data, feature_subset, label_column=label_column)

        n_nodes = df_filtered.shape[0]
        key = ", ".join(feature_subset)

        if n_nodes >= min_nodes:
            combination_dfs[key] = df_filtered
            kept_combinations.append((key, feature_subset, n_nodes))
            print(f"Subset: {key}, Nodes: {n_nodes}")
        else:
            print(f"Subset: {key} had too few unique combinations: {n_nodes}, discarding.")

# After the loop, print a summary of kept combinations
print("\n--- Kept Combinations ---")
for key, features, n_nodes in kept_combinations:
    print(f"Key: {key} | Features: {features} | Nodes: {n_nodes}")
# Out:
# 3600.0
# Subset: attacktype1, target1, Nodes: 5208
# Subset: attacktype1, weaptype1 had too few unique combinations: 39, discarding.
# Subset: attacktype1, nkill had too few unique combinations: 237, discarding.
# Subset: target1, weaptype1, Nodes: 5157
# Subset: target1, nkill, Nodes: 5813
# Subset: weaptype1, nkill had too few unique combinations: 196, discarding.
# Subset: attacktype1, target1, weaptype1, Nodes: 5307
# Subset: attacktype1, target1, nkill, Nodes: 6161
# Subset: attacktype1, weaptype1, nkill had too few unique combinations: 349, discarding.
# Subset: target1, weaptype1, nkill, Nodes: 6113
# Subset: attacktype1, target1, weaptype1, nkill, Nodes: 6260
#
# --- Kept Combinations ---
# Key: attacktype1, target1 | Features: ['attacktype1', 'target1'] | Nodes: 5208
# Key: target1, weaptype1 | Features: ['target1', 'weaptype1'] | Nodes: 5157
# Key: target1, nkill | Features: ['target1', 'nkill'] | Nodes: 5813
# Key: attacktype1, target1, weaptype1 | Features: ['attacktype1', 'target1', 'weaptype1'] | Nodes: 5307
# Key: attacktype1, target1, nkill | Features: ['attacktype1', 'target1', 'nkill'] | Nodes: 6161
# Key: target1, weaptype1, nkill | Features: ['target1', 'weaptype1', 'nkill'] | Nodes: 6113
# Key: attacktype1, target1, weaptype1, nkill | Features: ['attacktype1', 'target1', 'weaptype1', 'nkill'] | Nodes: 6260

# %%
def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class PyTorchGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

def run_epoch(model, data, labels, mask, optimizer=None):
    is_training = optimizer is not None
    if is_training:
        model.train()
    else:
        model.eval()

    out = model(data.x, data.edge_index)
    loss_fn = torch.nn.CrossEntropyLoss()

    loss = loss_fn(out[mask], labels[mask])

    if is_training:
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Accuracy
    pred = out[mask].argmax(dim=1)
    acc = (pred == labels[mask]).float().mean().item()
    return acc, loss.item()

# %%
import os 
if not os.path.isdir(f"Results"):
    os.mkdir(f"Results")

# %%
import os
import ast
from torch_geometric.data import Data
from scipy.sparse import coo_matrix

# Ensure results directory exists
os.makedirs("Results", exist_ok=True)

output_path = f"Results/gcn_{partition}.txt"

# Initialize results and clear output file
results = {}
with open(output_path, "w") as f:
    f.write("Subset\tTest Accuracy\tEpoch\tFeatures Used\n")

# Loop through each feature combination
for key, df_unique in combination_dfs.items():
    print(f"\n--- Processing feature subset: {key} ---")

    # Ensure tuple format
    df_unique = df_unique.copy()
    df_unique['combination'] = df_unique['combination'].apply(to_tuple_if_needed)

    # Build coord_to_index
    coord_to_index = {row['combination']: i for i, row in df_unique.iterrows()}

    # Build graph data
    adj_matrix, feature_matrix, label_index = build_graph_data(df_unique, coord_to_index)

    # Get original data mapped to current node set
    features_used = key.split(', ')
    full_data = data[features_used + ['gname']].copy()
    full_data['combination'] = list(zip(*(full_data[feat] for feat in features_used)))
    full_data['combination'] = full_data['combination'].apply(to_tuple_if_needed)
    full_data = full_data[full_data['combination'].isin(coord_to_index)]

    # Split into train/test
    split_point = int(0.7 * len(full_data))
    train_df = full_data[:split_point]
    test_df = full_data[split_point:]

    # Feature matrix
    coords = np.array(list(coord_to_index.keys()), dtype=np.float32)
    x = torch.tensor(coords, dtype=torch.float32)

    # Label and mask tensors
    num_nodes = x.shape[0]
    y = torch.full((num_nodes,), -1, dtype=torch.long)
    train_mask = torch.zeros(num_nodes, dtype=torch.bool)
    test_mask = torch.zeros(num_nodes, dtype=torch.bool)

    for _, row in train_df.iterrows():
        idx = coord_to_index[row['combination']]
        y[idx] = label_index[row['gname']]
        train_mask[idx] = True

    for _, row in test_df.iterrows():
        idx = coord_to_index[row['combination']]
        y[idx] = label_index[row['gname']]
        test_mask[idx] = True

    # Graph edges
    A_coo = coo_matrix(adj_matrix)
    edge_index = torch.tensor(np.vstack((A_coo.row, A_coo.col)), dtype=torch.long)

    # Build graph object
    data_obj = Data(x=x, edge_index=edge_index)

    # Model and optimizer
    model = PyTorchGCN(in_channels=x.shape[1], hidden_channels=16, num_classes=len(label_index))
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    # Training loop
    max_test_acc = 0
    max_test_epoch = -1
    for epoch in range(2000):
        train_acc, train_loss = run_epoch(model, data_obj, y, train_mask, optimizer)
        test_acc, test_loss = run_epoch(model, data_obj, y, test_mask)
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            max_test_epoch = epoch + 1
        if (epoch + 1) % 100 == 0 or epoch == 1999:
            print(f"Epoch {epoch+1} | Train Acc: {train_acc:.4f} | Test Acc: {test_acc:.4f} | "
                  f"Train Loss: {train_loss:.4f} | Test Loss: {test_loss:.4f}")

    print(f"Best test accuracy for {key}: {max_test_acc:.4f} at epoch {max_test_epoch}")
    results[key] = max_test_acc

    # Append result to summary file
    with open(output_path, "a") as f:
        f.write(f"Subset: {key}\n")
        f.write(f"Best test Acc: {max_test_acc:.4f}\n")
        f.write(f"Best epoch: {max_test_epoch}\n")
        f.write(f"{'-' * 37}\n\n")
# Out:
# --- Processing feature subset: attacktype1, target1 ---
# Number of total nodes (unique coordinates): 5208
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0441 | Test Acc: 0.0382 | Train Loss: 36.3969 | Test Loss: 39.1164
# Epoch 200 | Train Acc: 0.0716 | Test Acc: 0.0706 | Train Loss: 35.0902 | Test Loss: 38.8328
# Epoch 300 | Train Acc: 0.1178 | Test Acc: 0.0661 | Train Loss: 17.6411 | Test Loss: 14.9855
# Epoch 400 | Train Acc: 0.1120 | Test Acc: 0.0905 | Train Loss: 8.7412 | Test Loss: 9.2872
# Epoch 500 | Train Acc: 0.2242 | Test Acc: 0.1566 | Train Loss: 2.8004 | Test Loss: 2.9730
# Epoch 600 | Train Acc: 0.2394 | Test Acc: 0.1999 | Train Loss: 2.7163 | Test Loss: 2.8584
# Epoch 700 | Train Acc: 0.2460 | Test Acc: 0.2010 | Train Loss: 2.6726 | Test Loss: 2.8011
# Epoch 800 | Train Acc: 0.2557 | Test Acc: 0.2079 | Train Loss: 2.6355 | Test Loss: 2.7582
# Epoch 900 | Train Acc: 0.2172 | Test Acc: 0.2386 | Train Loss: 2.6262 | Test Loss: 2.7454
# Epoch 1000 | Train Acc: 0.0968 | Test Acc: 0.0951 | Train Loss: 13.7806 | Test Loss: 14.5798
# Epoch 1100 | Train Acc: 0.2295 | Test Acc: 0.2301 | Train Loss: 2.6653 | Test Loss: 2.7467
# Epoch 1200 | Train Acc: 0.2651 | Test Acc: 0.2415 | Train Loss: 2.5510 | Test Loss: 2.6641
# Epoch 1300 | Train Acc: 0.2725 | Test Acc: 0.2392 | Train Loss: 2.5300 | Test Loss: 2.6616
# Epoch 1400 | Train Acc: 0.2738 | Test Acc: 0.2392 | Train Loss: 2.5147 | Test Loss: 2.6547
# Epoch 1500 | Train Acc: 0.2586 | Test Acc: 0.2221 | Train Loss: 2.5010 | Test Loss: 2.6476
# Epoch 1600 | Train Acc: 0.2785 | Test Acc: 0.2472 | Train Loss: 2.4883 | Test Loss: 2.6397
# Epoch 1700 | Train Acc: 0.2819 | Test Acc: 0.2466 | Train Loss: 2.4760 | Test Loss: 2.6318
# Epoch 1800 | Train Acc: 0.2848 | Test Acc: 0.2449 | Train Loss: 2.4639 | Test Loss: 2.6231
# Epoch 1900 | Train Acc: 0.2867 | Test Acc: 0.2437 | Train Loss: 2.4524 | Test Loss: 2.6154
# Epoch 2000 | Train Acc: 0.2793 | Test Acc: 0.2284 | Train Loss: 2.4764 | Test Loss: 2.6259
# Best test accuracy for attacktype1, target1: 0.3007 at epoch 1968
#
# --- Processing feature subset: target1, weaptype1 ---
# Number of total nodes (unique coordinates): 5157
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0793 | Test Acc: 0.0506 | Train Loss: 10.1097 | Test Loss: 11.1604
# Epoch 200 | Train Acc: 0.1247 | Test Acc: 0.1190 | Train Loss: 4.0832 | Test Loss: 4.3180
# Epoch 300 | Train Acc: 0.1520 | Test Acc: 0.1310 | Train Loss: 5.4732 | Test Loss: 5.5143
# Epoch 400 | Train Acc: 0.1748 | Test Acc: 0.1626 | Train Loss: 2.7895 | Test Loss: 2.9119
# Epoch 500 | Train Acc: 0.2475 | Test Acc: 0.1833 | Train Loss: 2.6620 | Test Loss: 2.8162
# Epoch 600 | Train Acc: 0.2655 | Test Acc: 0.2115 | Train Loss: 2.5818 | Test Loss: 2.7331
# Epoch 700 | Train Acc: 0.1538 | Test Acc: 0.1086 | Train Loss: 4.7051 | Test Loss: 5.5972
# Epoch 800 | Train Acc: 0.2271 | Test Acc: 0.2023 | Train Loss: 2.7792 | Test Loss: 2.8801
# Epoch 900 | Train Acc: 0.2743 | Test Acc: 0.2356 | Train Loss: 2.4669 | Test Loss: 2.6530
# Epoch 1000 | Train Acc: 0.2952 | Test Acc: 0.1902 | Train Loss: 2.4453 | Test Loss: 2.6480
# Epoch 1100 | Train Acc: 0.1952 | Test Acc: 0.1046 | Train Loss: 4.3804 | Test Loss: 3.9186
# Epoch 1200 | Train Acc: 0.2122 | Test Acc: 0.2046 | Train Loss: 2.7023 | Test Loss: 2.8064
# Epoch 1300 | Train Acc: 0.2899 | Test Acc: 0.2615 | Train Loss: 2.4654 | Test Loss: 2.6359
# Epoch 1400 | Train Acc: 0.3080 | Test Acc: 0.2230 | Train Loss: 2.3708 | Test Loss: 2.5721
# Epoch 1500 | Train Acc: 0.2889 | Test Acc: 0.2017 | Train Loss: 2.3520 | Test Loss: 2.5636
# Epoch 1600 | Train Acc: 0.1228 | Test Acc: 0.1609 | Train Loss: 5.9260 | Test Loss: 4.3825
# Epoch 1700 | Train Acc: 0.2427 | Test Acc: 0.2282 | Train Loss: 2.5785 | Test Loss: 2.7482
# Epoch 1800 | Train Acc: 0.2658 | Test Acc: 0.1948 | Train Loss: 2.5030 | Test Loss: 2.6753
# Epoch 1900 | Train Acc: 0.3029 | Test Acc: 0.2460 | Train Loss: 2.4621 | Test Loss: 2.6381
# Epoch 2000 | Train Acc: 0.3294 | Test Acc: 0.2557 | Train Loss: 2.4337 | Test Loss: 2.6085
# Best test accuracy for target1, weaptype1: 0.2937 at epoch 1436
#
# --- Processing feature subset: target1, nkill ---
# Number of total nodes (unique coordinates): 5813
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0524 | Test Acc: 0.0453 | Train Loss: 25.6189 | Test Loss: 25.0250
# Epoch 200 | Train Acc: 0.0545 | Test Acc: 0.0478 | Train Loss: 17.1619 | Test Loss: 18.3134
# Epoch 300 | Train Acc: 0.0463 | Test Acc: 0.0509 | Train Loss: 7.7093 | Test Loss: 8.5951
# Epoch 400 | Train Acc: 0.1029 | Test Acc: 0.0826 | Train Loss: 7.7008 | Test Loss: 8.0036
# Epoch 500 | Train Acc: 0.1461 | Test Acc: 0.1168 | Train Loss: 3.1656 | Test Loss: 3.4788
# Epoch 600 | Train Acc: 0.1266 | Test Acc: 0.0921 | Train Loss: 3.0787 | Test Loss: 3.3630
# Epoch 700 | Train Acc: 0.1386 | Test Acc: 0.1037 | Train Loss: 3.0002 | Test Loss: 3.2508
# Epoch 800 | Train Acc: 0.1487 | Test Acc: 0.1148 | Train Loss: 2.9276 | Test Loss: 3.1439
# Epoch 900 | Train Acc: 0.1579 | Test Acc: 0.1229 | Train Loss: 2.8641 | Test Loss: 3.0455
# Epoch 1000 | Train Acc: 0.1978 | Test Acc: 0.1309 | Train Loss: 2.8163 | Test Loss: 2.9694
# Epoch 1100 | Train Acc: 0.1231 | Test Acc: 0.0866 | Train Loss: 17.0696 | Test Loss: 15.4260
# Epoch 1200 | Train Acc: 0.1485 | Test Acc: 0.1777 | Train Loss: 2.9540 | Test Loss: 3.0616
# Epoch 1300 | Train Acc: 0.2542 | Test Acc: 0.2064 | Train Loss: 2.7876 | Test Loss: 2.9010
# Epoch 1400 | Train Acc: 0.2531 | Test Acc: 0.2054 | Train Loss: 2.7737 | Test Loss: 2.8915
# Epoch 1500 | Train Acc: 0.2592 | Test Acc: 0.2105 | Train Loss: 2.7632 | Test Loss: 2.8858
# Epoch 1600 | Train Acc: 0.2627 | Test Acc: 0.2160 | Train Loss: 2.7532 | Test Loss: 2.8790
# Epoch 1700 | Train Acc: 0.2831 | Test Acc: 0.2195 | Train Loss: 2.7283 | Test Loss: 2.8788
# Epoch 1800 | Train Acc: 0.2944 | Test Acc: 0.2261 | Train Loss: 2.7084 | Test Loss: 2.8463
# Epoch 1900 | Train Acc: 0.1750 | Test Acc: 0.1707 | Train Loss: 2.7503 | Test Loss: 2.9301
# Epoch 2000 | Train Acc: 0.1640 | Test Acc: 0.1626 | Train Loss: 3.3101 | Test Loss: 3.5700
# Best test accuracy for target1, nkill: 0.2432 at epoch 1879
#
# --- Processing feature subset: attacktype1, target1, weaptype1 ---
# Number of total nodes (unique coordinates): 5307
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0525 | Test Acc: 0.0515 | Train Loss: 27.3966 | Test Loss: 29.4144
# Epoch 200 | Train Acc: 0.0612 | Test Acc: 0.0386 | Train Loss: 13.5266 | Test Loss: 12.9540
# Epoch 300 | Train Acc: 0.0651 | Test Acc: 0.0448 | Train Loss: 5.7916 | Test Loss: 5.9065
# Epoch 400 | Train Acc: 0.2004 | Test Acc: 0.1545 | Train Loss: 2.8148 | Test Loss: 2.9170
# Epoch 500 | Train Acc: 0.2158 | Test Acc: 0.1781 | Train Loss: 2.7423 | Test Loss: 2.8644
# Epoch 600 | Train Acc: 0.2395 | Test Acc: 0.1825 | Train Loss: 2.6563 | Test Loss: 2.7925
# Epoch 700 | Train Acc: 0.2531 | Test Acc: 0.1971 | Train Loss: 2.6032 | Test Loss: 2.7390
# Epoch 800 | Train Acc: 0.1070 | Test Acc: 0.1153 | Train Loss: 13.5337 | Test Loss: 11.4558
# Epoch 900 | Train Acc: 0.1903 | Test Acc: 0.1635 | Train Loss: 2.8747 | Test Loss: 3.0288
# Epoch 1000 | Train Acc: 0.2425 | Test Acc: 0.2128 | Train Loss: 2.6307 | Test Loss: 2.7513
# Epoch 1100 | Train Acc: 0.2598 | Test Acc: 0.2139 | Train Loss: 2.6018 | Test Loss: 2.7317
# Epoch 1200 | Train Acc: 0.2690 | Test Acc: 0.2139 | Train Loss: 2.5773 | Test Loss: 2.7122
# Epoch 1300 | Train Acc: 0.2731 | Test Acc: 0.2139 | Train Loss: 2.5547 | Test Loss: 2.6927
# Epoch 1400 | Train Acc: 0.2652 | Test Acc: 0.2357 | Train Loss: 2.5403 | Test Loss: 2.6910
# Epoch 1500 | Train Acc: 0.2667 | Test Acc: 0.2105 | Train Loss: 2.5268 | Test Loss: 2.6968
# Epoch 1600 | Train Acc: 0.1901 | Test Acc: 0.1153 | Train Loss: 5.2417 | Test Loss: 5.9744
# Epoch 1700 | Train Acc: 0.2361 | Test Acc: 0.2016 | Train Loss: 2.7407 | Test Loss: 2.8723
# Epoch 1800 | Train Acc: 0.2850 | Test Acc: 0.2262 | Train Loss: 2.5490 | Test Loss: 2.6899
# Epoch 1900 | Train Acc: 0.2901 | Test Acc: 0.2212 | Train Loss: 2.4969 | Test Loss: 2.6395
# Epoch 2000 | Train Acc: 0.2891 | Test Acc: 0.2178 | Train Loss: 2.4621 | Test Loss: 2.6065
# Best test accuracy for attacktype1, target1, weaptype1: 0.2693 at epoch 1721
#
# --- Processing feature subset: attacktype1, target1, nkill ---
# Number of total nodes (unique coordinates): 6161
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0694 | Test Acc: 0.0519 | Train Loss: 18.6360 | Test Loss: 18.5972
# Epoch 200 | Train Acc: 0.0559 | Test Acc: 0.0400 | Train Loss: 10.0771 | Test Loss: 10.4926
# Epoch 300 | Train Acc: 0.1070 | Test Acc: 0.0790 | Train Loss: 5.5943 | Test Loss: 5.3639
# Epoch 400 | Train Acc: 0.1172 | Test Acc: 0.0871 | Train Loss: 4.6003 | Test Loss: 4.1342
# Epoch 500 | Train Acc: 0.1345 | Test Acc: 0.1000 | Train Loss: 4.0270 | Test Loss: 4.0550
# Epoch 600 | Train Acc: 0.1809 | Test Acc: 0.1505 | Train Loss: 2.7973 | Test Loss: 2.9435
# Epoch 700 | Train Acc: 0.2263 | Test Acc: 0.1571 | Train Loss: 2.7165 | Test Loss: 2.8821
# Epoch 800 | Train Acc: 0.1219 | Test Acc: 0.1110 | Train Loss: 3.0963 | Test Loss: 3.2850
# Epoch 900 | Train Acc: 0.1578 | Test Acc: 0.0900 | Train Loss: 6.4037 | Test Loss: 6.8244
# Epoch 1000 | Train Acc: 0.1764 | Test Acc: 0.1114 | Train Loss: 2.8907 | Test Loss: 3.0633
# Epoch 1100 | Train Acc: 0.2205 | Test Acc: 0.1862 | Train Loss: 2.6853 | Test Loss: 2.8687
# Epoch 1200 | Train Acc: 0.2484 | Test Acc: 0.2376 | Train Loss: 2.5820 | Test Loss: 2.7645
# Epoch 1300 | Train Acc: 0.1917 | Test Acc: 0.1519 | Train Loss: 3.2236 | Test Loss: 3.2125
# Epoch 1400 | Train Acc: 0.1742 | Test Acc: 0.1490 | Train Loss: 3.4753 | Test Loss: 3.4099
# Epoch 1500 | Train Acc: 0.2383 | Test Acc: 0.1895 | Train Loss: 2.6133 | Test Loss: 2.8005
# Epoch 1600 | Train Acc: 0.2635 | Test Acc: 0.2224 | Train Loss: 2.5471 | Test Loss: 2.7315
# Epoch 1700 | Train Acc: 0.2396 | Test Acc: 0.1762 | Train Loss: 2.5541 | Test Loss: 2.7769
# Epoch 1800 | Train Acc: 0.1871 | Test Acc: 0.1438 | Train Loss: 3.2971 | Test Loss: 3.3111
# Epoch 1900 | Train Acc: 0.2518 | Test Acc: 0.1838 | Train Loss: 2.6133 | Test Loss: 2.8040
# Epoch 2000 | Train Acc: 0.2509 | Test Acc: 0.1905 | Train Loss: 2.5873 | Test Loss: 2.7884
# Best test accuracy for attacktype1, target1, nkill: 0.2476 at epoch 1219
#
# --- Processing feature subset: target1, weaptype1, nkill ---
# Number of total nodes (unique coordinates): 6113
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0451 | Test Acc: 0.0379 | Train Loss: 26.7704 | Test Loss: 25.4165
# Epoch 200 | Train Acc: 0.0699 | Test Acc: 0.0455 | Train Loss: 14.3903 | Test Loss: 13.6499
# Epoch 300 | Train Acc: 0.0753 | Test Acc: 0.0781 | Train Loss: 13.9824 | Test Loss: 13.1124
# Epoch 400 | Train Acc: 0.0828 | Test Acc: 0.0940 | Train Loss: 7.4352 | Test Loss: 7.4288
# Epoch 500 | Train Acc: 0.1762 | Test Acc: 0.1572 | Train Loss: 4.0389 | Test Loss: 4.0782
# Epoch 600 | Train Acc: 0.2365 | Test Acc: 0.1592 | Train Loss: 2.6502 | Test Loss: 2.8043
# Epoch 700 | Train Acc: 0.2546 | Test Acc: 0.1793 | Train Loss: 2.6164 | Test Loss: 2.7703
# Epoch 800 | Train Acc: 0.2537 | Test Acc: 0.1697 | Train Loss: 2.6196 | Test Loss: 2.8023
# Epoch 900 | Train Acc: 0.1824 | Test Acc: 0.1059 | Train Loss: 2.8493 | Test Loss: 3.0164
# Epoch 1000 | Train Acc: 0.0949 | Test Acc: 0.0499 | Train Loss: 7.1975 | Test Loss: 6.9211
# Epoch 1100 | Train Acc: 0.1925 | Test Acc: 0.1443 | Train Loss: 2.7953 | Test Loss: 2.9332
# Epoch 1200 | Train Acc: 0.2139 | Test Acc: 0.1668 | Train Loss: 2.7574 | Test Loss: 2.9053
# Epoch 1300 | Train Acc: 0.2097 | Test Acc: 0.1678 | Train Loss: 2.7277 | Test Loss: 2.8914
# Epoch 1400 | Train Acc: 0.2142 | Test Acc: 0.1726 | Train Loss: 2.7040 | Test Loss: 2.8779
# Epoch 1500 | Train Acc: 0.2166 | Test Acc: 0.1798 | Train Loss: 2.6836 | Test Loss: 2.8608
# Epoch 1600 | Train Acc: 0.2528 | Test Acc: 0.2071 | Train Loss: 2.6292 | Test Loss: 2.8188
# Epoch 1700 | Train Acc: 0.2354 | Test Acc: 0.1937 | Train Loss: 2.6606 | Test Loss: 2.8597
# Epoch 1800 | Train Acc: 0.1617 | Test Acc: 0.1357 | Train Loss: 3.4762 | Test Loss: 3.2033
# Epoch 1900 | Train Acc: 0.1179 | Test Acc: 0.0935 | Train Loss: 3.5079 | Test Loss: 3.6666
# Epoch 2000 | Train Acc: 0.1309 | Test Acc: 0.0968 | Train Loss: 2.9552 | Test Loss: 3.1063
# Best test accuracy for target1, weaptype1, nkill: 0.2502 at epoch 1659
#
# --- Processing feature subset: attacktype1, target1, weaptype1, nkill ---
# Number of total nodes (unique coordinates): 6260
# Number of unique labels in this set: 30
# Epoch 100 | Train Acc: 0.0585 | Test Acc: 0.0666 | Train Loss: 38.5065 | Test Loss: 35.5360
# Epoch 200 | Train Acc: 0.0883 | Test Acc: 0.0567 | Train Loss: 25.6241 | Test Loss: 23.6854
# Epoch 300 | Train Acc: 0.0794 | Test Acc: 0.0888 | Train Loss: 17.8553 | Test Loss: 17.4580
# Epoch 400 | Train Acc: 0.1097 | Test Acc: 0.0812 | Train Loss: 14.7884 | Test Loss: 15.0137
# Epoch 500 | Train Acc: 0.0772 | Test Acc: 0.0604 | Train Loss: 9.6621 | Test Loss: 10.8463
# Epoch 600 | Train Acc: 0.1566 | Test Acc: 0.1058 | Train Loss: 4.4878 | Test Loss: 4.5067
# Epoch 700 | Train Acc: 0.1817 | Test Acc: 0.1596 | Train Loss: 2.7852 | Test Loss: 2.9158
# Epoch 800 | Train Acc: 0.1983 | Test Acc: 0.1662 | Train Loss: 2.7342 | Test Loss: 2.8692
# Epoch 900 | Train Acc: 0.1996 | Test Acc: 0.1695 | Train Loss: 2.7112 | Test Loss: 2.8476
# Epoch 1000 | Train Acc: 0.1998 | Test Acc: 0.1690 | Train Loss: 2.6919 | Test Loss: 2.8337
# Epoch 1100 | Train Acc: 0.2002 | Test Acc: 0.1686 | Train Loss: 2.6752 | Test Loss: 2.8255
# Epoch 1200 | Train Acc: 0.2046 | Test Acc: 0.1761 | Train Loss: 2.6552 | Test Loss: 2.8282
# Epoch 1300 | Train Acc: 0.2242 | Test Acc: 0.1893 | Train Loss: 2.6236 | Test Loss: 2.8165
# Epoch 1400 | Train Acc: 0.1385 | Test Acc: 0.1379 | Train Loss: 8.4938 | Test Loss: 7.9559
# Epoch 1500 | Train Acc: 0.1782 | Test Acc: 0.1756 | Train Loss: 2.9427 | Test Loss: 2.9321
# Epoch 1600 | Train Acc: 0.2443 | Test Acc: 0.2035 | Train Loss: 2.5958 | Test Loss: 2.7510
# Epoch 1700 | Train Acc: 0.2510 | Test Acc: 0.2068 | Train Loss: 2.5689 | Test Loss: 2.7326
# Epoch 1800 | Train Acc: 0.2558 | Test Acc: 0.2219 | Train Loss: 2.5500 | Test Loss: 2.7184
# Epoch 1900 | Train Acc: 0.2979 | Test Acc: 0.2068 | Train Loss: 2.5366 | Test Loss: 2.7118
# Epoch 2000 | Train Acc: 0.2907 | Test Acc: 0.2040 | Train Loss: 2.5375 | Test Loss: 2.7172
# Best test accuracy for attacktype1, target1, weaptype1, nkill: 0.2375 at epoch 1889
