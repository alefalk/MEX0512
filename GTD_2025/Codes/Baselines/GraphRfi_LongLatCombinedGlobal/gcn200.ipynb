# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds = []
y_trues = []
logs = []

# Default config (from previous best)
default_args = {
    'partition': f"gtd{partition}",
    #'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    #'n_tree': 80,
    'tree_depth': 10,
    #'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': False
}

import os

embed_dim_grid = [8, 16, 32]
n_tree_grid = [40, 80, 120]
feature_rate_grid = [0.1, 0.3, 0.5]

for col in continuous_cols:
    print(f"\nRunning grid search for {col} prediction...")

    data, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_overall_acc = -1.0
    best_config = {}

    for embed_dim in embed_dim_grid:
        for n_tree in n_tree_grid:
            for tree_feature_rate in feature_rate_grid:
                print(f"\nTraining with embed_dim={embed_dim}, n_tree={n_tree}, tree_feature_rate={tree_feature_rate}")

                args = default_args.copy()
                args['embed_dim'] = embed_dim
                args['n_tree'] = n_tree
                args['tree_feature_rate'] = tree_feature_rate

                best_acc, best_epoch, best_precision, best_recall, best_f1, y_pred_decoded, y_true_decoded, \
                best_precision_micro, best_recall_micro, best_f1_micro, best_precision_macro, best_recall_macro, best_f1_macro, \
                roc_auc_weighted, roc_auc_micro, roc_auc_macro, epoch_logs = train_joint(
                    data, data.edge_index, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask,
                    args, row_to_node_index, index_to_label, verbose=True)

                y_preds.append(y_pred_decoded)
                y_trues.append(y_true_decoded)
                logs.append(epoch_logs)

                os.makedirs(f"Results{partition}", exist_ok=True)

                results_path = f"Results{partition}/Results_{col}_embed{embed_dim}_nTree{n_tree}_fRate{tree_feature_rate}"
                with open(results_path, "w") as f:
                    f.write(f"Best acc: {best_acc:.4f} at epoch {best_epoch} for {col} prediction\n")
                    f.write(f"Weighted Precision: {best_precision:.4f}, Recall: {best_recall:.4f}, F1: {best_f1:.4f}\n")
                    f.write(f"Macro Precision: {best_precision_macro:.4f}, Recall: {best_recall_macro:.4f}, F1: {best_f1_macro:.4f}\n")
                    f.write(f"Micro Precision: {best_precision_micro:.4f}, Recall: {best_recall_micro:.4f}, F1: {best_f1_micro:.4f}\n")
                    f.write(f"AUROC Weighted: {roc_auc_weighted:.4f}, Micro: {roc_auc_micro:.4f}, Macro: {roc_auc_macro:.4f}\n")

                log_path = f"Results{partition}/epoch_logs_{col}_embed{embed_dim}_nTree{n_tree}_fRate{tree_feature_rate}"
                with open(log_path, "w") as f:
                    f.write('\n'.join(f"{x:.4f}" for x in epoch_logs))

                if best_acc > best_overall_acc:
                    best_overall_acc = best_acc
                    best_config = {
                        'embed_dim': embed_dim,
                        'n_tree': n_tree,
                        'tree_feature_rate': tree_feature_rate,
                        'best_acc': best_acc,
                        'epoch': best_epoch,
                        'macro_f1': best_f1_macro,
                        'micro_f1': best_f1_micro,
                        'weighted_f1': best_f1
                    }

    # Save best config
    summary_path = f"Results{partition}/BestConfig_{col}.txt"
    with open(summary_path, "w") as f:
        f.write(f"Best configuration for {col} prediction:\n")
        for k, v in best_config.items():
            f.write(f"{k}: {v}\n")
# Out:
# Running grid search for weaptype1 prediction...
#
# Training with embed_dim=8, n_tree=40, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.1146 | NRF Loss: 3.4011 | JOINT Loss: 4.5157 | NRF Acc: 0.1846
# Epoch 51 | GCN MSE Loss: 1.0444 | NRF Loss: 3.2501 | JOINT Loss: 4.2945 | NRF Acc: 0.4225
# Epoch 101 | GCN MSE Loss: 1.0318 | NRF Loss: 3.0327 | JOINT Loss: 4.0645 | NRF Acc: 0.5644
# Epoch 151 | GCN MSE Loss: 1.0239 | NRF Loss: 2.8402 | JOINT Loss: 3.8640 | NRF Acc: 0.6697
# Epoch 201 | GCN MSE Loss: 1.0195 | NRF Loss: 2.6754 | JOINT Loss: 3.6949 | NRF Acc: 0.7509
# Epoch 251 | GCN MSE Loss: 1.0173 | NRF Loss: 2.5254 | JOINT Loss: 3.5428 | NRF Acc: 0.8032
# Epoch 301 | GCN MSE Loss: 1.0160 | NRF Loss: 2.3876 | JOINT Loss: 3.4035 | NRF Acc: 0.8042
# Epoch 351 | GCN MSE Loss: 1.0149 | NRF Loss: 2.2609 | JOINT Loss: 3.2758 | NRF Acc: 0.8238
# Epoch 401 | GCN MSE Loss: 1.0138 | NRF Loss: 2.1462 | JOINT Loss: 3.1600 | NRF Acc: 0.8471
# Epoch 451 | GCN MSE Loss: 1.0128 | NRF Loss: 2.0422 | JOINT Loss: 3.0549 | NRF Acc: 0.8568
# Epoch 501 | GCN MSE Loss: 1.0117 | NRF Loss: 1.9456 | JOINT Loss: 2.9573 | NRF Acc: 0.8671
# Epoch 551 | GCN MSE Loss: 1.0106 | NRF Loss: 1.8566 | JOINT Loss: 2.8672 | NRF Acc: 0.8739
# Epoch 601 | GCN MSE Loss: 1.0096 | NRF Loss: 1.7730 | JOINT Loss: 2.7826 | NRF Acc: 0.8780
# Epoch 651 | GCN MSE Loss: 1.0088 | NRF Loss: 1.6965 | JOINT Loss: 2.7053 | NRF Acc: 0.8814
# Epoch 701 | GCN MSE Loss: 1.0081 | NRF Loss: 1.6255 | JOINT Loss: 2.6336 | NRF Acc: 0.8836
# Epoch 751 | GCN MSE Loss: 1.0075 | NRF Loss: 1.5594 | JOINT Loss: 2.5669 | NRF Acc: 0.8879
# Epoch 801 | GCN MSE Loss: 1.0070 | NRF Loss: 1.4970 | JOINT Loss: 2.5039 | NRF Acc: 0.8910
# Epoch 851 | GCN MSE Loss: 1.0063 | NRF Loss: 1.4389 | JOINT Loss: 2.4452 | NRF Acc: 0.8966
# Epoch 901 | GCN MSE Loss: 1.0058 | NRF Loss: 1.3841 | JOINT Loss: 2.3899 | NRF Acc: 0.8973
# Epoch 951 | GCN MSE Loss: 1.0053 | NRF Loss: 1.3332 | JOINT Loss: 2.3385 | NRF Acc: 0.9041
# Best acc/epoch: 0.9081568717956543, epoch 998
#
# Training with embed_dim=8, n_tree=40, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.4084 | NRF Loss: 3.4013 | JOINT Loss: 4.8098 | NRF Acc: 0.3116
# Epoch 51 | GCN MSE Loss: 1.2034 | NRF Loss: 3.1188 | JOINT Loss: 4.3221 | NRF Acc: 0.5364
# Epoch 101 | GCN MSE Loss: 1.1030 | NRF Loss: 2.9092 | JOINT Loss: 4.0122 | NRF Acc: 0.7189
# Epoch 151 | GCN MSE Loss: 1.0573 | NRF Loss: 2.7440 | JOINT Loss: 3.8013 | NRF Acc: 0.8154
# Epoch 201 | GCN MSE Loss: 1.0390 | NRF Loss: 2.5972 | JOINT Loss: 3.6361 | NRF Acc: 0.8453
# Epoch 251 | GCN MSE Loss: 1.0312 | NRF Loss: 2.4636 | JOINT Loss: 3.4948 | NRF Acc: 0.8639
# Epoch 301 | GCN MSE Loss: 1.0262 | NRF Loss: 2.3407 | JOINT Loss: 3.3669 | NRF Acc: 0.8667
# Epoch 351 | GCN MSE Loss: 1.0225 | NRF Loss: 2.2275 | JOINT Loss: 3.2500 | NRF Acc: 0.8711
# Epoch 401 | GCN MSE Loss: 1.0201 | NRF Loss: 2.1237 | JOINT Loss: 3.1438 | NRF Acc: 0.8780
# Epoch 451 | GCN MSE Loss: 1.0182 | NRF Loss: 2.0270 | JOINT Loss: 3.0452 | NRF Acc: 0.8820
# Epoch 501 | GCN MSE Loss: 1.0159 | NRF Loss: 1.9364 | JOINT Loss: 2.9523 | NRF Acc: 0.8854
# Epoch 551 | GCN MSE Loss: 1.0142 | NRF Loss: 1.8508 | JOINT Loss: 2.8651 | NRF Acc: 0.8885
# Epoch 601 | GCN MSE Loss: 1.0135 | NRF Loss: 1.7712 | JOINT Loss: 2.7847 | NRF Acc: 0.8907
# Epoch 651 | GCN MSE Loss: 1.0128 | NRF Loss: 1.6956 | JOINT Loss: 2.7084 | NRF Acc: 0.8957
# Epoch 701 | GCN MSE Loss: 1.0123 | NRF Loss: 1.6236 | JOINT Loss: 2.6359 | NRF Acc: 0.8988
# Epoch 751 | GCN MSE Loss: 1.0117 | NRF Loss: 1.5568 | JOINT Loss: 2.5685 | NRF Acc: 0.8994
# Epoch 801 | GCN MSE Loss: 1.0113 | NRF Loss: 1.4941 | JOINT Loss: 2.5054 | NRF Acc: 0.8994
# Epoch 851 | GCN MSE Loss: 1.0109 | NRF Loss: 1.4359 | JOINT Loss: 2.4468 | NRF Acc: 0.9035
# Epoch 901 | GCN MSE Loss: 1.0106 | NRF Loss: 1.3810 | JOINT Loss: 2.3916 | NRF Acc: 0.9038
# Epoch 951 | GCN MSE Loss: 1.0103 | NRF Loss: 1.3292 | JOINT Loss: 2.3395 | NRF Acc: 0.9047
# Best acc/epoch: 0.9066002368927002, epoch 975
#
# Training with embed_dim=8, n_tree=40, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.2986 | NRF Loss: 3.4013 | JOINT Loss: 4.6998 | NRF Acc: 0.3029
# Epoch 51 | GCN MSE Loss: 1.1143 | NRF Loss: 3.0578 | JOINT Loss: 4.1721 | NRF Acc: 0.6087
# Epoch 101 | GCN MSE Loss: 1.0603 | NRF Loss: 2.8662 | JOINT Loss: 3.9264 | NRF Acc: 0.7799
# Epoch 151 | GCN MSE Loss: 1.0363 | NRF Loss: 2.7148 | JOINT Loss: 3.7511 | NRF Acc: 0.8313
# Epoch 201 | GCN MSE Loss: 1.0240 | NRF Loss: 2.5801 | JOINT Loss: 3.6041 | NRF Acc: 0.8611
# Epoch 251 | GCN MSE Loss: 1.0170 | NRF Loss: 2.4571 | JOINT Loss: 3.4741 | NRF Acc: 0.8801
# Epoch 301 | GCN MSE Loss: 1.0121 | NRF Loss: 2.3416 | JOINT Loss: 3.3537 | NRF Acc: 0.8848
# Epoch 351 | GCN MSE Loss: 1.0099 | NRF Loss: 2.2339 | JOINT Loss: 3.2438 | NRF Acc: 0.8929
# Epoch 401 | GCN MSE Loss: 1.0082 | NRF Loss: 2.1331 | JOINT Loss: 3.1413 | NRF Acc: 0.8988
# Epoch 451 | GCN MSE Loss: 1.0067 | NRF Loss: 2.0384 | JOINT Loss: 3.0451 | NRF Acc: 0.8969
# Epoch 501 | GCN MSE Loss: 1.0054 | NRF Loss: 1.9485 | JOINT Loss: 2.9539 | NRF Acc: 0.9013
# Epoch 551 | GCN MSE Loss: 1.0045 | NRF Loss: 1.8647 | JOINT Loss: 2.8692 | NRF Acc: 0.9032
# Epoch 601 | GCN MSE Loss: 1.0038 | NRF Loss: 1.7854 | JOINT Loss: 2.7893 | NRF Acc: 0.9054
# Epoch 651 | GCN MSE Loss: 1.0032 | NRF Loss: 1.7107 | JOINT Loss: 2.7139 | NRF Acc: 0.9066
# Epoch 701 | GCN MSE Loss: 1.0027 | NRF Loss: 1.6411 | JOINT Loss: 2.6438 | NRF Acc: 0.9088
# Epoch 751 | GCN MSE Loss: 1.0024 | NRF Loss: 1.5753 | JOINT Loss: 2.5777 | NRF Acc: 0.9116
# Epoch 801 | GCN MSE Loss: 1.0019 | NRF Loss: 1.5126 | JOINT Loss: 2.5145 | NRF Acc: 0.9131
# Epoch 851 | GCN MSE Loss: 1.0014 | NRF Loss: 1.4529 | JOINT Loss: 2.4543 | NRF Acc: 0.9153
# Epoch 901 | GCN MSE Loss: 1.0005 | NRF Loss: 1.3966 | JOINT Loss: 2.3971 | NRF Acc: 0.9169
# Epoch 951 | GCN MSE Loss: 1.0000 | NRF Loss: 1.3442 | JOINT Loss: 2.3441 | NRF Acc: 0.9181
# Best acc/epoch: 0.9187421798706055, epoch 958
#
# Training with embed_dim=8, n_tree=80, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.1442 | NRF Loss: 3.4011 | JOINT Loss: 4.5454 | NRF Acc: 0.2092
# Epoch 51 | GCN MSE Loss: 1.0448 | NRF Loss: 3.2515 | JOINT Loss: 4.2963 | NRF Acc: 0.4054
# Epoch 101 | GCN MSE Loss: 1.0333 | NRF Loss: 3.0322 | JOINT Loss: 4.0655 | NRF Acc: 0.5399
# Epoch 151 | GCN MSE Loss: 1.0275 | NRF Loss: 2.8394 | JOINT Loss: 3.8669 | NRF Acc: 0.6560
# Epoch 201 | GCN MSE Loss: 1.0232 | NRF Loss: 2.6752 | JOINT Loss: 3.6984 | NRF Acc: 0.7316
# Epoch 251 | GCN MSE Loss: 1.0201 | NRF Loss: 2.5270 | JOINT Loss: 3.5471 | NRF Acc: 0.7842
# Epoch 301 | GCN MSE Loss: 1.0181 | NRF Loss: 2.3904 | JOINT Loss: 3.4085 | NRF Acc: 0.8014
# Epoch 351 | GCN MSE Loss: 1.0168 | NRF Loss: 2.2645 | JOINT Loss: 3.2813 | NRF Acc: 0.8229
# Epoch 401 | GCN MSE Loss: 1.0159 | NRF Loss: 2.1483 | JOINT Loss: 3.1643 | NRF Acc: 0.8422
# Epoch 451 | GCN MSE Loss: 1.0151 | NRF Loss: 2.0420 | JOINT Loss: 3.0571 | NRF Acc: 0.8555
# Epoch 501 | GCN MSE Loss: 1.0144 | NRF Loss: 1.9444 | JOINT Loss: 2.9588 | NRF Acc: 0.8615
# Epoch 551 | GCN MSE Loss: 1.0136 | NRF Loss: 1.8546 | JOINT Loss: 2.8682 | NRF Acc: 0.8643
# Epoch 601 | GCN MSE Loss: 1.0126 | NRF Loss: 1.7721 | JOINT Loss: 2.7848 | NRF Acc: 0.8711
# Epoch 651 | GCN MSE Loss: 1.0119 | NRF Loss: 1.6965 | JOINT Loss: 2.7083 | NRF Acc: 0.8736
# Epoch 701 | GCN MSE Loss: 1.0110 | NRF Loss: 1.6258 | JOINT Loss: 2.6368 | NRF Acc: 0.8786
# Epoch 751 | GCN MSE Loss: 1.0104 | NRF Loss: 1.5602 | JOINT Loss: 2.5706 | NRF Acc: 0.8833
# Epoch 801 | GCN MSE Loss: 1.0098 | NRF Loss: 1.4978 | JOINT Loss: 2.5076 | NRF Acc: 0.8842
# Epoch 851 | GCN MSE Loss: 1.0092 | NRF Loss: 1.4395 | JOINT Loss: 2.4487 | NRF Acc: 0.8876
# Epoch 901 | GCN MSE Loss: 1.0086 | NRF Loss: 1.3854 | JOINT Loss: 2.3940 | NRF Acc: 0.8904
# Epoch 951 | GCN MSE Loss: 1.0081 | NRF Loss: 1.3345 | JOINT Loss: 2.3426 | NRF Acc: 0.8923
# Best acc/epoch: 0.8969489336013794, epoch 993
#
# Training with embed_dim=8, n_tree=80, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.5144 | NRF Loss: 3.4012 | JOINT Loss: 4.9156 | NRF Acc: 0.2923
# Epoch 51 | GCN MSE Loss: 1.2549 | NRF Loss: 3.1169 | JOINT Loss: 4.3718 | NRF Acc: 0.5517
# Epoch 101 | GCN MSE Loss: 1.1260 | NRF Loss: 2.9087 | JOINT Loss: 4.0348 | NRF Acc: 0.7288
# Epoch 151 | GCN MSE Loss: 1.0642 | NRF Loss: 2.7471 | JOINT Loss: 3.8113 | NRF Acc: 0.8039
# Epoch 201 | GCN MSE Loss: 1.0388 | NRF Loss: 2.6020 | JOINT Loss: 3.6408 | NRF Acc: 0.8406
# Epoch 251 | GCN MSE Loss: 1.0288 | NRF Loss: 2.4680 | JOINT Loss: 3.4968 | NRF Acc: 0.8611
# Epoch 301 | GCN MSE Loss: 1.0248 | NRF Loss: 2.3453 | JOINT Loss: 3.3702 | NRF Acc: 0.8724
# Epoch 351 | GCN MSE Loss: 1.0227 | NRF Loss: 2.2318 | JOINT Loss: 3.2545 | NRF Acc: 0.8770
# Epoch 401 | GCN MSE Loss: 1.0207 | NRF Loss: 2.1271 | JOINT Loss: 3.1479 | NRF Acc: 0.8829
# Epoch 451 | GCN MSE Loss: 1.0191 | NRF Loss: 2.0304 | JOINT Loss: 3.0494 | NRF Acc: 0.8885
# Epoch 501 | GCN MSE Loss: 1.0177 | NRF Loss: 1.9407 | JOINT Loss: 2.9585 | NRF Acc: 0.8948
# Epoch 551 | GCN MSE Loss: 1.0167 | NRF Loss: 1.8574 | JOINT Loss: 2.8741 | NRF Acc: 0.8979
# Epoch 601 | GCN MSE Loss: 1.0159 | NRF Loss: 1.7798 | JOINT Loss: 2.7956 | NRF Acc: 0.9038
# Epoch 651 | GCN MSE Loss: 1.0152 | NRF Loss: 1.7070 | JOINT Loss: 2.7221 | NRF Acc: 0.9082
# Epoch 701 | GCN MSE Loss: 1.0145 | NRF Loss: 1.6385 | JOINT Loss: 2.6530 | NRF Acc: 0.9125
# Epoch 751 | GCN MSE Loss: 1.0139 | NRF Loss: 1.5724 | JOINT Loss: 2.5864 | NRF Acc: 0.9156
# Epoch 801 | GCN MSE Loss: 1.0135 | NRF Loss: 1.5109 | JOINT Loss: 2.5244 | NRF Acc: 0.9172
# Epoch 851 | GCN MSE Loss: 1.0131 | NRF Loss: 1.4531 | JOINT Loss: 2.4661 | NRF Acc: 0.9184
# Epoch 901 | GCN MSE Loss: 1.0127 | NRF Loss: 1.3981 | JOINT Loss: 2.4108 | NRF Acc: 0.9197
# Epoch 951 | GCN MSE Loss: 1.0123 | NRF Loss: 1.3460 | JOINT Loss: 2.3583 | NRF Acc: 0.9191
# Early stopping at epoch 994
# Best acc/epoch: 0.9196761846542358, epoch 894
#
# Training with embed_dim=8, n_tree=80, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.1667 | NRF Loss: 3.4012 | JOINT Loss: 4.5680 | NRF Acc: 0.3689
# Epoch 51 | GCN MSE Loss: 1.0632 | NRF Loss: 3.0572 | JOINT Loss: 4.1203 | NRF Acc: 0.6099
# Epoch 101 | GCN MSE Loss: 1.0354 | NRF Loss: 2.8685 | JOINT Loss: 3.9039 | NRF Acc: 0.7821
# Epoch 151 | GCN MSE Loss: 1.0240 | NRF Loss: 2.7196 | JOINT Loss: 3.7436 | NRF Acc: 0.8341
# Epoch 201 | GCN MSE Loss: 1.0182 | NRF Loss: 2.5849 | JOINT Loss: 3.6030 | NRF Acc: 0.8658
# Epoch 251 | GCN MSE Loss: 1.0149 | NRF Loss: 2.4601 | JOINT Loss: 3.4751 | NRF Acc: 0.8804
# Epoch 301 | GCN MSE Loss: 1.0125 | NRF Loss: 2.3437 | JOINT Loss: 3.3562 | NRF Acc: 0.8889
# Epoch 351 | GCN MSE Loss: 1.0104 | NRF Loss: 2.2345 | JOINT Loss: 3.2449 | NRF Acc: 0.8963
# Epoch 401 | GCN MSE Loss: 1.0088 | NRF Loss: 2.1326 | JOINT Loss: 3.1414 | NRF Acc: 0.8998
# Epoch 451 | GCN MSE Loss: 1.0077 | NRF Loss: 2.0375 | JOINT Loss: 3.0451 | NRF Acc: 0.9038
# Epoch 501 | GCN MSE Loss: 1.0069 | NRF Loss: 1.9476 | JOINT Loss: 2.9545 | NRF Acc: 0.9060
# Epoch 551 | GCN MSE Loss: 1.0064 | NRF Loss: 1.8636 | JOINT Loss: 2.8700 | NRF Acc: 0.9110
# Epoch 601 | GCN MSE Loss: 1.0058 | NRF Loss: 1.7848 | JOINT Loss: 2.7907 | NRF Acc: 0.9159
# Epoch 651 | GCN MSE Loss: 1.0053 | NRF Loss: 1.7110 | JOINT Loss: 2.7164 | NRF Acc: 0.9178
# Epoch 701 | GCN MSE Loss: 1.0049 | NRF Loss: 1.6410 | JOINT Loss: 2.6458 | NRF Acc: 0.9184
# Epoch 751 | GCN MSE Loss: 1.0044 | NRF Loss: 1.5749 | JOINT Loss: 2.5794 | NRF Acc: 0.9191
# Epoch 801 | GCN MSE Loss: 1.0040 | NRF Loss: 1.5127 | JOINT Loss: 2.5167 | NRF Acc: 0.9212
# Epoch 851 | GCN MSE Loss: 1.0035 | NRF Loss: 1.4540 | JOINT Loss: 2.4575 | NRF Acc: 0.9222
# Epoch 901 | GCN MSE Loss: 1.0031 | NRF Loss: 1.3984 | JOINT Loss: 2.4015 | NRF Acc: 0.9222
# Epoch 951 | GCN MSE Loss: 1.0026 | NRF Loss: 1.3464 | JOINT Loss: 2.3490 | NRF Acc: 0.9231
# Best acc/epoch: 0.9237235188484192, epoch 964
#
# Training with embed_dim=8, n_tree=120, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.0710 | NRF Loss: 3.4013 | JOINT Loss: 4.4723 | NRF Acc: 0.1918
# Epoch 51 | GCN MSE Loss: 1.0382 | NRF Loss: 3.2585 | JOINT Loss: 4.2968 | NRF Acc: 0.4088
# Epoch 101 | GCN MSE Loss: 1.0294 | NRF Loss: 3.0401 | JOINT Loss: 4.0696 | NRF Acc: 0.5486
# Epoch 151 | GCN MSE Loss: 1.0244 | NRF Loss: 2.8478 | JOINT Loss: 3.8722 | NRF Acc: 0.6491
# Epoch 201 | GCN MSE Loss: 1.0212 | NRF Loss: 2.6836 | JOINT Loss: 3.7047 | NRF Acc: 0.7282
# Epoch 251 | GCN MSE Loss: 1.0190 | NRF Loss: 2.5343 | JOINT Loss: 3.5533 | NRF Acc: 0.7867
# Epoch 301 | GCN MSE Loss: 1.0175 | NRF Loss: 2.3969 | JOINT Loss: 3.4143 | NRF Acc: 0.8163
# Epoch 351 | GCN MSE Loss: 1.0160 | NRF Loss: 2.2711 | JOINT Loss: 3.2870 | NRF Acc: 0.8344
# Epoch 401 | GCN MSE Loss: 1.0145 | NRF Loss: 2.1558 | JOINT Loss: 3.1703 | NRF Acc: 0.8499
# Epoch 451 | GCN MSE Loss: 1.0136 | NRF Loss: 2.0502 | JOINT Loss: 3.0638 | NRF Acc: 0.8636
# Epoch 501 | GCN MSE Loss: 1.0126 | NRF Loss: 1.9534 | JOINT Loss: 2.9661 | NRF Acc: 0.8615
# Epoch 551 | GCN MSE Loss: 1.0116 | NRF Loss: 1.8645 | JOINT Loss: 2.8761 | NRF Acc: 0.8699
# Epoch 601 | GCN MSE Loss: 1.0106 | NRF Loss: 1.7819 | JOINT Loss: 2.7925 | NRF Acc: 0.8745
# Epoch 651 | GCN MSE Loss: 1.0099 | NRF Loss: 1.7051 | JOINT Loss: 2.7150 | NRF Acc: 0.8767
# Epoch 701 | GCN MSE Loss: 1.0092 | NRF Loss: 1.6343 | JOINT Loss: 2.6435 | NRF Acc: 0.8814
# Epoch 751 | GCN MSE Loss: 1.0087 | NRF Loss: 1.5682 | JOINT Loss: 2.5769 | NRF Acc: 0.8829
# Epoch 801 | GCN MSE Loss: 1.0081 | NRF Loss: 1.5062 | JOINT Loss: 2.5143 | NRF Acc: 0.8873
# Epoch 851 | GCN MSE Loss: 1.0075 | NRF Loss: 1.4483 | JOINT Loss: 2.4558 | NRF Acc: 0.8895
# Epoch 901 | GCN MSE Loss: 1.0069 | NRF Loss: 1.3940 | JOINT Loss: 2.4009 | NRF Acc: 0.8907
# Epoch 951 | GCN MSE Loss: 1.0062 | NRF Loss: 1.3436 | JOINT Loss: 2.3499 | NRF Acc: 0.8917
# Best acc/epoch: 0.8935242295265198, epoch 984
#
# Training with embed_dim=8, n_tree=120, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.7140 | NRF Loss: 3.4011 | JOINT Loss: 5.1151 | NRF Acc: 0.2151
# Epoch 51 | GCN MSE Loss: 1.2541 | NRF Loss: 3.1275 | JOINT Loss: 4.3817 | NRF Acc: 0.5103
# Epoch 101 | GCN MSE Loss: 1.1155 | NRF Loss: 2.9166 | JOINT Loss: 4.0320 | NRF Acc: 0.7095
# Epoch 151 | GCN MSE Loss: 1.0790 | NRF Loss: 2.7527 | JOINT Loss: 3.8317 | NRF Acc: 0.7995
# Epoch 201 | GCN MSE Loss: 1.0651 | NRF Loss: 2.6075 | JOINT Loss: 3.6726 | NRF Acc: 0.8285
# Epoch 251 | GCN MSE Loss: 1.0563 | NRF Loss: 2.4761 | JOINT Loss: 3.5324 | NRF Acc: 0.8484
# Epoch 301 | GCN MSE Loss: 1.0498 | NRF Loss: 2.3557 | JOINT Loss: 3.4055 | NRF Acc: 0.8552
# Epoch 351 | GCN MSE Loss: 1.0447 | NRF Loss: 2.2442 | JOINT Loss: 3.2889 | NRF Acc: 0.8686
# Epoch 401 | GCN MSE Loss: 1.0405 | NRF Loss: 2.1404 | JOINT Loss: 3.1809 | NRF Acc: 0.8770
# Epoch 451 | GCN MSE Loss: 1.0372 | NRF Loss: 2.0439 | JOINT Loss: 3.0811 | NRF Acc: 0.8870
# Epoch 501 | GCN MSE Loss: 1.0342 | NRF Loss: 1.9537 | JOINT Loss: 2.9879 | NRF Acc: 0.8901
# Epoch 551 | GCN MSE Loss: 1.0313 | NRF Loss: 1.8697 | JOINT Loss: 2.9010 | NRF Acc: 0.8904
# Epoch 601 | GCN MSE Loss: 1.0285 | NRF Loss: 1.7911 | JOINT Loss: 2.8196 | NRF Acc: 0.8938
# Epoch 651 | GCN MSE Loss: 1.0258 | NRF Loss: 1.7174 | JOINT Loss: 2.7433 | NRF Acc: 0.9013
# Epoch 701 | GCN MSE Loss: 1.0236 | NRF Loss: 1.6477 | JOINT Loss: 2.6714 | NRF Acc: 0.9050
# Epoch 751 | GCN MSE Loss: 1.0218 | NRF Loss: 1.5821 | JOINT Loss: 2.6038 | NRF Acc: 0.9057
# Epoch 801 | GCN MSE Loss: 1.0203 | NRF Loss: 1.5203 | JOINT Loss: 2.5406 | NRF Acc: 0.9078
# Epoch 851 | GCN MSE Loss: 1.0191 | NRF Loss: 1.4626 | JOINT Loss: 2.4817 | NRF Acc: 0.9103
# Epoch 901 | GCN MSE Loss: 1.0181 | NRF Loss: 1.4085 | JOINT Loss: 2.4265 | NRF Acc: 0.9110
# Epoch 951 | GCN MSE Loss: 1.0172 | NRF Loss: 1.3575 | JOINT Loss: 2.3747 | NRF Acc: 0.9122
# Best acc/epoch: 0.9140722155570984, epoch 998
#
# Training with embed_dim=8, n_tree=120, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.2620 | NRF Loss: 3.4011 | JOINT Loss: 4.6631 | NRF Acc: 0.3092
# Epoch 51 | GCN MSE Loss: 1.1056 | NRF Loss: 3.0586 | JOINT Loss: 4.1643 | NRF Acc: 0.6015
# Epoch 101 | GCN MSE Loss: 1.0549 | NRF Loss: 2.8735 | JOINT Loss: 3.9284 | NRF Acc: 0.7749
# Epoch 151 | GCN MSE Loss: 1.0375 | NRF Loss: 2.7252 | JOINT Loss: 3.7627 | NRF Acc: 0.8409
# Epoch 201 | GCN MSE Loss: 1.0302 | NRF Loss: 2.5910 | JOINT Loss: 3.6212 | NRF Acc: 0.8639
# Epoch 251 | GCN MSE Loss: 1.0262 | NRF Loss: 2.4663 | JOINT Loss: 3.4925 | NRF Acc: 0.8783
# Epoch 301 | GCN MSE Loss: 1.0239 | NRF Loss: 2.3503 | JOINT Loss: 3.3742 | NRF Acc: 0.8864
# Epoch 351 | GCN MSE Loss: 1.0224 | NRF Loss: 2.2428 | JOINT Loss: 3.2651 | NRF Acc: 0.8929
# Epoch 401 | GCN MSE Loss: 1.0212 | NRF Loss: 2.1428 | JOINT Loss: 3.1640 | NRF Acc: 0.8985
# Epoch 451 | GCN MSE Loss: 1.0201 | NRF Loss: 2.0490 | JOINT Loss: 3.0691 | NRF Acc: 0.8991
# Epoch 501 | GCN MSE Loss: 1.0190 | NRF Loss: 1.9609 | JOINT Loss: 2.9798 | NRF Acc: 0.9038
# Epoch 551 | GCN MSE Loss: 1.0176 | NRF Loss: 1.8779 | JOINT Loss: 2.8955 | NRF Acc: 0.9060
# Epoch 601 | GCN MSE Loss: 1.0165 | NRF Loss: 1.7992 | JOINT Loss: 2.8157 | NRF Acc: 0.9078
# Epoch 651 | GCN MSE Loss: 1.0157 | NRF Loss: 1.7245 | JOINT Loss: 2.7401 | NRF Acc: 0.9091
# Epoch 701 | GCN MSE Loss: 1.0150 | NRF Loss: 1.6546 | JOINT Loss: 2.6696 | NRF Acc: 0.9119
# Epoch 751 | GCN MSE Loss: 1.0145 | NRF Loss: 1.5886 | JOINT Loss: 2.6030 | NRF Acc: 0.9147
# Epoch 801 | GCN MSE Loss: 1.0139 | NRF Loss: 1.5262 | JOINT Loss: 2.5401 | NRF Acc: 0.9166
# Epoch 851 | GCN MSE Loss: 1.0134 | NRF Loss: 1.4672 | JOINT Loss: 2.4806 | NRF Acc: 0.9181
# Epoch 901 | GCN MSE Loss: 1.0129 | NRF Loss: 1.4114 | JOINT Loss: 2.4244 | NRF Acc: 0.9228
# Epoch 951 | GCN MSE Loss: 1.0126 | NRF Loss: 1.3585 | JOINT Loss: 2.3710 | NRF Acc: 0.9203
# Best acc/epoch: 0.9234121441841125, epoch 905
#
# Training with embed_dim=16, n_tree=40, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.1752 | NRF Loss: 3.4011 | JOINT Loss: 4.5763 | NRF Acc: 0.2469
# Epoch 51 | GCN MSE Loss: 1.0641 | NRF Loss: 3.2532 | JOINT Loss: 4.3173 | NRF Acc: 0.3966
# Epoch 101 | GCN MSE Loss: 1.0505 | NRF Loss: 3.0368 | JOINT Loss: 4.0873 | NRF Acc: 0.5517
# Epoch 151 | GCN MSE Loss: 1.0421 | NRF Loss: 2.8416 | JOINT Loss: 3.8837 | NRF Acc: 0.6594
# Epoch 201 | GCN MSE Loss: 1.0351 | NRF Loss: 2.6765 | JOINT Loss: 3.7117 | NRF Acc: 0.7435
# Epoch 251 | GCN MSE Loss: 1.0296 | NRF Loss: 2.5279 | JOINT Loss: 3.5575 | NRF Acc: 0.7814
# Epoch 301 | GCN MSE Loss: 1.0257 | NRF Loss: 2.3911 | JOINT Loss: 3.4168 | NRF Acc: 0.7983
# Epoch 351 | GCN MSE Loss: 1.0226 | NRF Loss: 2.2651 | JOINT Loss: 3.2877 | NRF Acc: 0.8054
# Epoch 401 | GCN MSE Loss: 1.0200 | NRF Loss: 2.1481 | JOINT Loss: 3.1681 | NRF Acc: 0.8135
# Epoch 451 | GCN MSE Loss: 1.0176 | NRF Loss: 2.0399 | JOINT Loss: 3.0576 | NRF Acc: 0.8347
# Epoch 501 | GCN MSE Loss: 1.0151 | NRF Loss: 1.9409 | JOINT Loss: 2.9559 | NRF Acc: 0.8418
# Epoch 551 | GCN MSE Loss: 1.0130 | NRF Loss: 1.8509 | JOINT Loss: 2.8640 | NRF Acc: 0.8509
# Epoch 601 | GCN MSE Loss: 1.0117 | NRF Loss: 1.7672 | JOINT Loss: 2.7789 | NRF Acc: 0.8515
# Epoch 651 | GCN MSE Loss: 1.0107 | NRF Loss: 1.6896 | JOINT Loss: 2.7003 | NRF Acc: 0.8549
# Epoch 701 | GCN MSE Loss: 1.0095 | NRF Loss: 1.6176 | JOINT Loss: 2.6271 | NRF Acc: 0.8667
# Epoch 751 | GCN MSE Loss: 1.0080 | NRF Loss: 1.5503 | JOINT Loss: 2.5584 | NRF Acc: 0.8745
# Epoch 801 | GCN MSE Loss: 1.0055 | NRF Loss: 1.4878 | JOINT Loss: 2.4933 | NRF Acc: 0.8798
# Epoch 851 | GCN MSE Loss: 1.0033 | NRF Loss: 1.4292 | JOINT Loss: 2.4325 | NRF Acc: 0.8854
# Epoch 901 | GCN MSE Loss: 1.0013 | NRF Loss: 1.3751 | JOINT Loss: 2.3764 | NRF Acc: 0.8913
# Epoch 951 | GCN MSE Loss: 0.9996 | NRF Loss: 1.3245 | JOINT Loss: 2.3242 | NRF Acc: 0.8938
# Best acc/epoch: 0.896014928817749, epoch 985
#
# Training with embed_dim=16, n_tree=40, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.8721 | NRF Loss: 3.4008 | JOINT Loss: 5.2729 | NRF Acc: 0.2400
# Epoch 51 | GCN MSE Loss: 1.3721 | NRF Loss: 3.1216 | JOINT Loss: 4.4937 | NRF Acc: 0.5227
# Epoch 101 | GCN MSE Loss: 1.1718 | NRF Loss: 2.9102 | JOINT Loss: 4.0821 | NRF Acc: 0.7173
# Epoch 151 | GCN MSE Loss: 1.0925 | NRF Loss: 2.7463 | JOINT Loss: 3.8388 | NRF Acc: 0.7942
# Epoch 201 | GCN MSE Loss: 1.0629 | NRF Loss: 2.6031 | JOINT Loss: 3.6660 | NRF Acc: 0.8148
# Epoch 251 | GCN MSE Loss: 1.0504 | NRF Loss: 2.4727 | JOINT Loss: 3.5231 | NRF Acc: 0.8319
# Epoch 301 | GCN MSE Loss: 1.0413 | NRF Loss: 2.3516 | JOINT Loss: 3.3929 | NRF Acc: 0.8459
# Epoch 351 | GCN MSE Loss: 1.0329 | NRF Loss: 2.2400 | JOINT Loss: 3.2728 | NRF Acc: 0.8708
# Epoch 401 | GCN MSE Loss: 1.0261 | NRF Loss: 2.1382 | JOINT Loss: 3.1643 | NRF Acc: 0.8839
# Epoch 451 | GCN MSE Loss: 1.0205 | NRF Loss: 2.0419 | JOINT Loss: 3.0624 | NRF Acc: 0.8892
# Epoch 501 | GCN MSE Loss: 1.0157 | NRF Loss: 1.9510 | JOINT Loss: 2.9667 | NRF Acc: 0.8926
# Epoch 551 | GCN MSE Loss: 1.0121 | NRF Loss: 1.8664 | JOINT Loss: 2.8785 | NRF Acc: 0.8960
# Epoch 601 | GCN MSE Loss: 1.0093 | NRF Loss: 1.7873 | JOINT Loss: 2.7966 | NRF Acc: 0.8988
# Epoch 651 | GCN MSE Loss: 1.0070 | NRF Loss: 1.7130 | JOINT Loss: 2.7200 | NRF Acc: 0.8998
# Epoch 701 | GCN MSE Loss: 1.0050 | NRF Loss: 1.6406 | JOINT Loss: 2.6456 | NRF Acc: 0.9029
# Epoch 751 | GCN MSE Loss: 1.0030 | NRF Loss: 1.5726 | JOINT Loss: 2.5756 | NRF Acc: 0.9054
# Epoch 801 | GCN MSE Loss: 1.0012 | NRF Loss: 1.5100 | JOINT Loss: 2.5112 | NRF Acc: 0.9103
# Epoch 851 | GCN MSE Loss: 1.0000 | NRF Loss: 1.4505 | JOINT Loss: 2.4505 | NRF Acc: 0.9125
# Epoch 901 | GCN MSE Loss: 0.9990 | NRF Loss: 1.3942 | JOINT Loss: 2.3932 | NRF Acc: 0.9128
# Epoch 951 | GCN MSE Loss: 0.9983 | NRF Loss: 1.3406 | JOINT Loss: 2.3389 | NRF Acc: 0.9144
# Best acc/epoch: 0.9150062203407288, epoch 996
#
# Training with embed_dim=16, n_tree=40, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.2000 | NRF Loss: 3.4011 | JOINT Loss: 4.6011 | NRF Acc: 0.2889
# Epoch 51 | GCN MSE Loss: 1.0830 | NRF Loss: 3.0553 | JOINT Loss: 4.1383 | NRF Acc: 0.6127
# Epoch 101 | GCN MSE Loss: 1.0479 | NRF Loss: 2.8661 | JOINT Loss: 3.9139 | NRF Acc: 0.7755
# Epoch 151 | GCN MSE Loss: 1.0303 | NRF Loss: 2.7143 | JOINT Loss: 3.7446 | NRF Acc: 0.8244
# Epoch 201 | GCN MSE Loss: 1.0206 | NRF Loss: 2.5782 | JOINT Loss: 3.5988 | NRF Acc: 0.8605
# Epoch 251 | GCN MSE Loss: 1.0145 | NRF Loss: 2.4530 | JOINT Loss: 3.4675 | NRF Acc: 0.8783
# Epoch 301 | GCN MSE Loss: 1.0101 | NRF Loss: 2.3362 | JOINT Loss: 3.3463 | NRF Acc: 0.8857
# Epoch 351 | GCN MSE Loss: 1.0076 | NRF Loss: 2.2268 | JOINT Loss: 3.2343 | NRF Acc: 0.8929
# Epoch 401 | GCN MSE Loss: 1.0055 | NRF Loss: 2.1231 | JOINT Loss: 3.1286 | NRF Acc: 0.8945
# Epoch 451 | GCN MSE Loss: 1.0030 | NRF Loss: 2.0282 | JOINT Loss: 3.0312 | NRF Acc: 0.8991
# Epoch 501 | GCN MSE Loss: 1.0010 | NRF Loss: 1.9387 | JOINT Loss: 2.9397 | NRF Acc: 0.9032
# Epoch 551 | GCN MSE Loss: 0.9995 | NRF Loss: 1.8542 | JOINT Loss: 2.8537 | NRF Acc: 0.9057
# Epoch 601 | GCN MSE Loss: 0.9983 | NRF Loss: 1.7747 | JOINT Loss: 2.7730 | NRF Acc: 0.9097
# Epoch 651 | GCN MSE Loss: 0.9970 | NRF Loss: 1.7011 | JOINT Loss: 2.6981 | NRF Acc: 0.9094
# Epoch 701 | GCN MSE Loss: 0.9959 | NRF Loss: 1.6309 | JOINT Loss: 2.6268 | NRF Acc: 0.9088
# Early stopping at epoch 729
# Best acc/epoch: 0.9112702012062073, epoch 629
#
# Training with embed_dim=16, n_tree=80, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.1318 | NRF Loss: 3.4012 | JOINT Loss: 4.5330 | NRF Acc: 0.1578
# Epoch 51 | GCN MSE Loss: 1.0347 | NRF Loss: 3.2536 | JOINT Loss: 4.2883 | NRF Acc: 0.4047
# Epoch 101 | GCN MSE Loss: 1.0200 | NRF Loss: 3.0337 | JOINT Loss: 4.0538 | NRF Acc: 0.5573
# Epoch 151 | GCN MSE Loss: 1.0157 | NRF Loss: 2.8411 | JOINT Loss: 3.8568 | NRF Acc: 0.6597
# Epoch 201 | GCN MSE Loss: 1.0129 | NRF Loss: 2.6757 | JOINT Loss: 3.6886 | NRF Acc: 0.7344
# Epoch 251 | GCN MSE Loss: 1.0109 | NRF Loss: 2.5258 | JOINT Loss: 3.5367 | NRF Acc: 0.7889
# Epoch 301 | GCN MSE Loss: 1.0094 | NRF Loss: 2.3876 | JOINT Loss: 3.3970 | NRF Acc: 0.8126
# Epoch 351 | GCN MSE Loss: 1.0083 | NRF Loss: 2.2613 | JOINT Loss: 3.2696 | NRF Acc: 0.8266
# Epoch 401 | GCN MSE Loss: 1.0072 | NRF Loss: 2.1458 | JOINT Loss: 3.1531 | NRF Acc: 0.8381
# Epoch 451 | GCN MSE Loss: 1.0060 | NRF Loss: 2.0401 | JOINT Loss: 3.0461 | NRF Acc: 0.8524
# Epoch 501 | GCN MSE Loss: 1.0044 | NRF Loss: 1.9427 | JOINT Loss: 2.9472 | NRF Acc: 0.8611
# Epoch 551 | GCN MSE Loss: 1.0025 | NRF Loss: 1.8531 | JOINT Loss: 2.8556 | NRF Acc: 0.8621
# Epoch 601 | GCN MSE Loss: 1.0008 | NRF Loss: 1.7693 | JOINT Loss: 2.7701 | NRF Acc: 0.8649
# Epoch 651 | GCN MSE Loss: 0.9989 | NRF Loss: 1.6922 | JOINT Loss: 2.6911 | NRF Acc: 0.8736
# Epoch 701 | GCN MSE Loss: 0.9966 | NRF Loss: 1.6211 | JOINT Loss: 2.6176 | NRF Acc: 0.8780
# Epoch 751 | GCN MSE Loss: 0.9952 | NRF Loss: 1.5547 | JOINT Loss: 2.5500 | NRF Acc: 0.8817
# Epoch 801 | GCN MSE Loss: 0.9940 | NRF Loss: 1.4933 | JOINT Loss: 2.4873 | NRF Acc: 0.8820
# Epoch 851 | GCN MSE Loss: 0.9928 | NRF Loss: 1.4362 | JOINT Loss: 2.4289 | NRF Acc: 0.8833
# Epoch 901 | GCN MSE Loss: 0.9916 | NRF Loss: 1.3824 | JOINT Loss: 2.3740 | NRF Acc: 0.8857
# Epoch 951 | GCN MSE Loss: 0.9904 | NRF Loss: 1.3320 | JOINT Loss: 2.3224 | NRF Acc: 0.8892
# Best acc/epoch: 0.8897882699966431, epoch 984
#
# Training with embed_dim=16, n_tree=80, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.5461 | NRF Loss: 3.4013 | JOINT Loss: 4.9474 | NRF Acc: 0.3440
# Epoch 51 | GCN MSE Loss: 1.1967 | NRF Loss: 3.1150 | JOINT Loss: 4.3117 | NRF Acc: 0.5290
# Epoch 101 | GCN MSE Loss: 1.0692 | NRF Loss: 2.9053 | JOINT Loss: 3.9745 | NRF Acc: 0.7263
# Epoch 151 | GCN MSE Loss: 1.0333 | NRF Loss: 2.7424 | JOINT Loss: 3.7757 | NRF Acc: 0.7992
# Epoch 201 | GCN MSE Loss: 1.0248 | NRF Loss: 2.5982 | JOINT Loss: 3.6231 | NRF Acc: 0.8362
# Epoch 251 | GCN MSE Loss: 1.0217 | NRF Loss: 2.4660 | JOINT Loss: 3.4877 | NRF Acc: 0.8608
# Epoch 301 | GCN MSE Loss: 1.0191 | NRF Loss: 2.3460 | JOINT Loss: 3.3651 | NRF Acc: 0.8730
# Epoch 351 | GCN MSE Loss: 1.0161 | NRF Loss: 2.2347 | JOINT Loss: 3.2508 | NRF Acc: 0.8801
# Epoch 401 | GCN MSE Loss: 1.0147 | NRF Loss: 2.1316 | JOINT Loss: 3.1464 | NRF Acc: 0.8848
# Epoch 451 | GCN MSE Loss: 1.0137 | NRF Loss: 2.0347 | JOINT Loss: 3.0483 | NRF Acc: 0.8935
# Epoch 501 | GCN MSE Loss: 1.0128 | NRF Loss: 1.9441 | JOINT Loss: 2.9568 | NRF Acc: 0.8966
# Epoch 551 | GCN MSE Loss: 1.0121 | NRF Loss: 1.8586 | JOINT Loss: 2.8707 | NRF Acc: 0.8985
# Epoch 601 | GCN MSE Loss: 1.0116 | NRF Loss: 1.7791 | JOINT Loss: 2.7907 | NRF Acc: 0.9019
# Epoch 651 | GCN MSE Loss: 1.0109 | NRF Loss: 1.7044 | JOINT Loss: 2.7153 | NRF Acc: 0.9066
# Epoch 701 | GCN MSE Loss: 1.0100 | NRF Loss: 1.6338 | JOINT Loss: 2.6438 | NRF Acc: 0.9047
# Epoch 751 | GCN MSE Loss: 1.0093 | NRF Loss: 1.5677 | JOINT Loss: 2.5770 | NRF Acc: 0.9091
# Epoch 801 | GCN MSE Loss: 1.0087 | NRF Loss: 1.5061 | JOINT Loss: 2.5148 | NRF Acc: 0.9119
# Epoch 851 | GCN MSE Loss: 1.0081 | NRF Loss: 1.4488 | JOINT Loss: 2.4570 | NRF Acc: 0.9144
# Epoch 901 | GCN MSE Loss: 1.0076 | NRF Loss: 1.3948 | JOINT Loss: 2.4023 | NRF Acc: 0.9178
# Epoch 951 | GCN MSE Loss: 1.0070 | NRF Loss: 1.3431 | JOINT Loss: 2.3501 | NRF Acc: 0.9203
# Best acc/epoch: 0.922478199005127, epoch 989
#
# Training with embed_dim=16, n_tree=80, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.0433 | NRF Loss: 3.4013 | JOINT Loss: 4.4446 | NRF Acc: 0.3692
# Epoch 51 | GCN MSE Loss: 1.0206 | NRF Loss: 3.0592 | JOINT Loss: 4.0798 | NRF Acc: 0.6037
# Epoch 101 | GCN MSE Loss: 1.0138 | NRF Loss: 2.8706 | JOINT Loss: 3.8844 | NRF Acc: 0.7858
# Epoch 151 | GCN MSE Loss: 1.0083 | NRF Loss: 2.7205 | JOINT Loss: 3.7288 | NRF Acc: 0.8347
# Epoch 201 | GCN MSE Loss: 1.0045 | NRF Loss: 2.5842 | JOINT Loss: 3.5886 | NRF Acc: 0.8664
# Epoch 251 | GCN MSE Loss: 1.0015 | NRF Loss: 2.4594 | JOINT Loss: 3.4609 | NRF Acc: 0.8792
# Epoch 301 | GCN MSE Loss: 0.9986 | NRF Loss: 2.3434 | JOINT Loss: 3.3420 | NRF Acc: 0.8839
# Epoch 351 | GCN MSE Loss: 0.9954 | NRF Loss: 2.2353 | JOINT Loss: 3.2307 | NRF Acc: 0.8913
# Epoch 401 | GCN MSE Loss: 0.9925 | NRF Loss: 2.1351 | JOINT Loss: 3.1276 | NRF Acc: 0.8982
# Epoch 451 | GCN MSE Loss: 0.9902 | NRF Loss: 2.0414 | JOINT Loss: 3.0316 | NRF Acc: 0.9022
# Epoch 501 | GCN MSE Loss: 0.9883 | NRF Loss: 1.9528 | JOINT Loss: 2.9411 | NRF Acc: 0.9054
# Epoch 551 | GCN MSE Loss: 0.9867 | NRF Loss: 1.8687 | JOINT Loss: 2.8554 | NRF Acc: 0.9069
# Epoch 601 | GCN MSE Loss: 0.9855 | NRF Loss: 1.7888 | JOINT Loss: 2.7742 | NRF Acc: 0.9088
# Epoch 651 | GCN MSE Loss: 0.9843 | NRF Loss: 1.7135 | JOINT Loss: 2.6978 | NRF Acc: 0.9113
# Epoch 701 | GCN MSE Loss: 0.9833 | NRF Loss: 1.6422 | JOINT Loss: 2.6255 | NRF Acc: 0.9138
# Epoch 751 | GCN MSE Loss: 0.9824 | NRF Loss: 1.5755 | JOINT Loss: 2.5579 | NRF Acc: 0.9141
# Epoch 801 | GCN MSE Loss: 0.9816 | NRF Loss: 1.5120 | JOINT Loss: 2.4936 | NRF Acc: 0.9131
# Epoch 851 | GCN MSE Loss: 0.9808 | NRF Loss: 1.4522 | JOINT Loss: 2.4330 | NRF Acc: 0.9156
# Epoch 901 | GCN MSE Loss: 0.9802 | NRF Loss: 1.3965 | JOINT Loss: 2.3767 | NRF Acc: 0.9163
# Epoch 951 | GCN MSE Loss: 0.9796 | NRF Loss: 1.3438 | JOINT Loss: 2.3234 | NRF Acc: 0.9163
# Best acc/epoch: 0.9171855449676514, epoch 930
#
# Training with embed_dim=16, n_tree=120, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.2001 | NRF Loss: 3.4014 | JOINT Loss: 4.6014 | NRF Acc: 0.2777
# Epoch 51 | GCN MSE Loss: 1.0634 | NRF Loss: 3.2567 | JOINT Loss: 4.3201 | NRF Acc: 0.4019
# Epoch 101 | GCN MSE Loss: 1.0358 | NRF Loss: 3.0374 | JOINT Loss: 4.0733 | NRF Acc: 0.5504
# Epoch 151 | GCN MSE Loss: 1.0266 | NRF Loss: 2.8454 | JOINT Loss: 3.8720 | NRF Acc: 0.6610
# Epoch 201 | GCN MSE Loss: 1.0201 | NRF Loss: 2.6820 | JOINT Loss: 3.7021 | NRF Acc: 0.7472
# Epoch 251 | GCN MSE Loss: 1.0156 | NRF Loss: 2.5345 | JOINT Loss: 3.5500 | NRF Acc: 0.8082
# Epoch 301 | GCN MSE Loss: 1.0119 | NRF Loss: 2.3975 | JOINT Loss: 3.4094 | NRF Acc: 0.8300
# Epoch 351 | GCN MSE Loss: 1.0095 | NRF Loss: 2.2706 | JOINT Loss: 3.2801 | NRF Acc: 0.8443
# Epoch 401 | GCN MSE Loss: 1.0079 | NRF Loss: 2.1545 | JOINT Loss: 3.1624 | NRF Acc: 0.8493
# Epoch 451 | GCN MSE Loss: 1.0067 | NRF Loss: 2.0481 | JOINT Loss: 3.0548 | NRF Acc: 0.8587
# Epoch 501 | GCN MSE Loss: 1.0057 | NRF Loss: 1.9502 | JOINT Loss: 2.9559 | NRF Acc: 0.8661
# Epoch 551 | GCN MSE Loss: 1.0048 | NRF Loss: 1.8601 | JOINT Loss: 2.8649 | NRF Acc: 0.8711
# Epoch 601 | GCN MSE Loss: 1.0040 | NRF Loss: 1.7770 | JOINT Loss: 2.7810 | NRF Acc: 0.8752
# Epoch 651 | GCN MSE Loss: 1.0031 | NRF Loss: 1.7005 | JOINT Loss: 2.7036 | NRF Acc: 0.8780
# Epoch 701 | GCN MSE Loss: 1.0022 | NRF Loss: 1.6297 | JOINT Loss: 2.6320 | NRF Acc: 0.8814
# Epoch 751 | GCN MSE Loss: 1.0015 | NRF Loss: 1.5635 | JOINT Loss: 2.5651 | NRF Acc: 0.8873
# Epoch 801 | GCN MSE Loss: 1.0009 | NRF Loss: 1.5018 | JOINT Loss: 2.5027 | NRF Acc: 0.8889
# Epoch 851 | GCN MSE Loss: 1.0003 | NRF Loss: 1.4443 | JOINT Loss: 2.4446 | NRF Acc: 0.8901
# Epoch 901 | GCN MSE Loss: 0.9997 | NRF Loss: 1.3901 | JOINT Loss: 2.3899 | NRF Acc: 0.8910
# Epoch 951 | GCN MSE Loss: 0.9992 | NRF Loss: 1.3394 | JOINT Loss: 2.3385 | NRF Acc: 0.8938
# Best acc/epoch: 0.8981942534446716, epoch 995
#
# Training with embed_dim=16, n_tree=120, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.5147 | NRF Loss: 3.4013 | JOINT Loss: 4.9160 | NRF Acc: 0.3512
# Epoch 51 | GCN MSE Loss: 1.1831 | NRF Loss: 3.1134 | JOINT Loss: 4.2966 | NRF Acc: 0.5277
# Epoch 101 | GCN MSE Loss: 1.0828 | NRF Loss: 2.9074 | JOINT Loss: 3.9902 | NRF Acc: 0.7245
# Epoch 151 | GCN MSE Loss: 1.0530 | NRF Loss: 2.7460 | JOINT Loss: 3.7991 | NRF Acc: 0.8054
# Epoch 201 | GCN MSE Loss: 1.0406 | NRF Loss: 2.6021 | JOINT Loss: 3.6427 | NRF Acc: 0.8375
# Epoch 251 | GCN MSE Loss: 1.0312 | NRF Loss: 2.4702 | JOINT Loss: 3.5014 | NRF Acc: 0.8580
# Epoch 301 | GCN MSE Loss: 1.0251 | NRF Loss: 2.3491 | JOINT Loss: 3.3743 | NRF Acc: 0.8692
# Epoch 351 | GCN MSE Loss: 1.0224 | NRF Loss: 2.2378 | JOINT Loss: 3.2602 | NRF Acc: 0.8736
# Epoch 401 | GCN MSE Loss: 1.0195 | NRF Loss: 2.1350 | JOINT Loss: 3.1545 | NRF Acc: 0.8811
# Epoch 451 | GCN MSE Loss: 1.0170 | NRF Loss: 2.0393 | JOINT Loss: 3.0562 | NRF Acc: 0.8898
# Epoch 501 | GCN MSE Loss: 1.0149 | NRF Loss: 1.9502 | JOINT Loss: 2.9650 | NRF Acc: 0.8966
# Epoch 551 | GCN MSE Loss: 1.0133 | NRF Loss: 1.8659 | JOINT Loss: 2.8792 | NRF Acc: 0.8985
# Epoch 601 | GCN MSE Loss: 1.0119 | NRF Loss: 1.7861 | JOINT Loss: 2.7981 | NRF Acc: 0.9001
# Epoch 651 | GCN MSE Loss: 1.0108 | NRF Loss: 1.7114 | JOINT Loss: 2.7221 | NRF Acc: 0.9035
# Epoch 701 | GCN MSE Loss: 1.0096 | NRF Loss: 1.6404 | JOINT Loss: 2.6500 | NRF Acc: 0.9069
# Epoch 751 | GCN MSE Loss: 1.0087 | NRF Loss: 1.5739 | JOINT Loss: 2.5826 | NRF Acc: 0.9100
# Epoch 801 | GCN MSE Loss: 1.0079 | NRF Loss: 1.5117 | JOINT Loss: 2.5197 | NRF Acc: 0.9110
# Epoch 851 | GCN MSE Loss: 1.0071 | NRF Loss: 1.4537 | JOINT Loss: 2.4608 | NRF Acc: 0.9119
# Epoch 901 | GCN MSE Loss: 1.0064 | NRF Loss: 1.3988 | JOINT Loss: 2.4051 | NRF Acc: 0.9122
# Epoch 951 | GCN MSE Loss: 1.0055 | NRF Loss: 1.3473 | JOINT Loss: 2.3529 | NRF Acc: 0.9122
# Early stopping at epoch 971
# Best acc/epoch: 0.913138210773468, epoch 871
#
# Training with embed_dim=16, n_tree=120, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.1383 | NRF Loss: 3.4012 | JOINT Loss: 4.5395 | NRF Acc: 0.3344
# Epoch 51 | GCN MSE Loss: 1.0563 | NRF Loss: 3.0596 | JOINT Loss: 4.1158 | NRF Acc: 0.6161
# Epoch 101 | GCN MSE Loss: 1.0344 | NRF Loss: 2.8727 | JOINT Loss: 3.9071 | NRF Acc: 0.7836
# Epoch 151 | GCN MSE Loss: 1.0214 | NRF Loss: 2.7239 | JOINT Loss: 3.7452 | NRF Acc: 0.8331
# Epoch 201 | GCN MSE Loss: 1.0131 | NRF Loss: 2.5898 | JOINT Loss: 3.6029 | NRF Acc: 0.8624
# Epoch 251 | GCN MSE Loss: 1.0076 | NRF Loss: 2.4649 | JOINT Loss: 3.4725 | NRF Acc: 0.8814
# Epoch 301 | GCN MSE Loss: 1.0039 | NRF Loss: 2.3481 | JOINT Loss: 3.3520 | NRF Acc: 0.8857
# Epoch 351 | GCN MSE Loss: 1.0012 | NRF Loss: 2.2394 | JOINT Loss: 3.2406 | NRF Acc: 0.8966
# Epoch 401 | GCN MSE Loss: 0.9992 | NRF Loss: 2.1373 | JOINT Loss: 3.1365 | NRF Acc: 0.9022
# Epoch 451 | GCN MSE Loss: 0.9975 | NRF Loss: 2.0416 | JOINT Loss: 3.0391 | NRF Acc: 0.9038
# Epoch 501 | GCN MSE Loss: 0.9960 | NRF Loss: 1.9515 | JOINT Loss: 2.9476 | NRF Acc: 0.9088
# Epoch 551 | GCN MSE Loss: 0.9947 | NRF Loss: 1.8668 | JOINT Loss: 2.8615 | NRF Acc: 0.9119
# Epoch 601 | GCN MSE Loss: 0.9934 | NRF Loss: 1.7874 | JOINT Loss: 2.7808 | NRF Acc: 0.9122
# Epoch 651 | GCN MSE Loss: 0.9922 | NRF Loss: 1.7125 | JOINT Loss: 2.7046 | NRF Acc: 0.9113
# Epoch 701 | GCN MSE Loss: 0.9911 | NRF Loss: 1.6417 | JOINT Loss: 2.6328 | NRF Acc: 0.9150
# Epoch 751 | GCN MSE Loss: 0.9900 | NRF Loss: 1.5746 | JOINT Loss: 2.5646 | NRF Acc: 0.9131
# Epoch 801 | GCN MSE Loss: 0.9888 | NRF Loss: 1.5119 | JOINT Loss: 2.5007 | NRF Acc: 0.9166
# Epoch 851 | GCN MSE Loss: 0.9875 | NRF Loss: 1.4533 | JOINT Loss: 2.4407 | NRF Acc: 0.9175
# Epoch 901 | GCN MSE Loss: 0.9863 | NRF Loss: 1.3983 | JOINT Loss: 2.3845 | NRF Acc: 0.9191
# Epoch 951 | GCN MSE Loss: 0.9852 | NRF Loss: 1.3465 | JOINT Loss: 2.3317 | NRF Acc: 0.9197
# Best acc/epoch: 0.9202988743782043, epoch 997
#
# Training with embed_dim=32, n_tree=40, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.0748 | NRF Loss: 3.4011 | JOINT Loss: 4.4759 | NRF Acc: 0.1417
# Epoch 51 | GCN MSE Loss: 1.0220 | NRF Loss: 3.2484 | JOINT Loss: 4.2704 | NRF Acc: 0.4293
# Epoch 101 | GCN MSE Loss: 1.0138 | NRF Loss: 3.0245 | JOINT Loss: 4.0382 | NRF Acc: 0.5427
# Epoch 151 | GCN MSE Loss: 1.0081 | NRF Loss: 2.8329 | JOINT Loss: 3.8410 | NRF Acc: 0.6610
# Epoch 201 | GCN MSE Loss: 1.0038 | NRF Loss: 2.6694 | JOINT Loss: 3.6732 | NRF Acc: 0.7400
# Epoch 251 | GCN MSE Loss: 0.9999 | NRF Loss: 2.5208 | JOINT Loss: 3.5206 | NRF Acc: 0.7917
# Epoch 301 | GCN MSE Loss: 0.9962 | NRF Loss: 2.3831 | JOINT Loss: 3.3792 | NRF Acc: 0.8169
# Epoch 351 | GCN MSE Loss: 0.9930 | NRF Loss: 2.2559 | JOINT Loss: 3.2488 | NRF Acc: 0.8331
# Epoch 401 | GCN MSE Loss: 0.9900 | NRF Loss: 2.1400 | JOINT Loss: 3.1300 | NRF Acc: 0.8453
# Epoch 451 | GCN MSE Loss: 0.9874 | NRF Loss: 2.0343 | JOINT Loss: 3.0217 | NRF Acc: 0.8549
# Epoch 501 | GCN MSE Loss: 0.9848 | NRF Loss: 1.9375 | JOINT Loss: 2.9223 | NRF Acc: 0.8636
# Epoch 551 | GCN MSE Loss: 0.9827 | NRF Loss: 1.8467 | JOINT Loss: 2.8294 | NRF Acc: 0.8677
# Epoch 601 | GCN MSE Loss: 0.9808 | NRF Loss: 1.7639 | JOINT Loss: 2.7447 | NRF Acc: 0.8724
# Epoch 651 | GCN MSE Loss: 0.9790 | NRF Loss: 1.6872 | JOINT Loss: 2.6662 | NRF Acc: 0.8767
# Epoch 701 | GCN MSE Loss: 0.9771 | NRF Loss: 1.6162 | JOINT Loss: 2.5933 | NRF Acc: 0.8836
# Epoch 751 | GCN MSE Loss: 0.9752 | NRF Loss: 1.5498 | JOINT Loss: 2.5250 | NRF Acc: 0.8861
# Epoch 801 | GCN MSE Loss: 0.9734 | NRF Loss: 1.4876 | JOINT Loss: 2.4610 | NRF Acc: 0.8873
# Epoch 851 | GCN MSE Loss: 0.9718 | NRF Loss: 1.4304 | JOINT Loss: 2.4022 | NRF Acc: 0.8889
# Epoch 901 | GCN MSE Loss: 0.9702 | NRF Loss: 1.3769 | JOINT Loss: 2.3472 | NRF Acc: 0.8910
# Epoch 951 | GCN MSE Loss: 0.9685 | NRF Loss: 1.3275 | JOINT Loss: 2.2960 | NRF Acc: 0.8951
# Best acc/epoch: 0.8975715637207031, epoch 986
#
# Training with embed_dim=32, n_tree=40, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.1121 | NRF Loss: 3.4013 | JOINT Loss: 4.5135 | NRF Acc: 0.2267
# Epoch 51 | GCN MSE Loss: 1.0274 | NRF Loss: 3.1095 | JOINT Loss: 4.1369 | NRF Acc: 0.5299
# Epoch 101 | GCN MSE Loss: 1.0209 | NRF Loss: 2.8987 | JOINT Loss: 3.9195 | NRF Acc: 0.7323
# Epoch 151 | GCN MSE Loss: 1.0172 | NRF Loss: 2.7341 | JOINT Loss: 3.7513 | NRF Acc: 0.8088
# Epoch 201 | GCN MSE Loss: 1.0136 | NRF Loss: 2.5881 | JOINT Loss: 3.6017 | NRF Acc: 0.8422
# Epoch 251 | GCN MSE Loss: 1.0109 | NRF Loss: 2.4557 | JOINT Loss: 3.4666 | NRF Acc: 0.8667
# Epoch 301 | GCN MSE Loss: 1.0087 | NRF Loss: 2.3341 | JOINT Loss: 3.3429 | NRF Acc: 0.8699
# Epoch 351 | GCN MSE Loss: 1.0067 | NRF Loss: 2.2223 | JOINT Loss: 3.2290 | NRF Acc: 0.8627
# Early stopping at epoch 373
# Best acc/epoch: 0.8717309832572937, epoch 273
#
# Training with embed_dim=32, n_tree=40, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.2028 | NRF Loss: 3.4013 | JOINT Loss: 4.6041 | NRF Acc: 0.3141
# Epoch 51 | GCN MSE Loss: 1.0376 | NRF Loss: 3.0586 | JOINT Loss: 4.0962 | NRF Acc: 0.6136
# Epoch 101 | GCN MSE Loss: 1.0145 | NRF Loss: 2.8680 | JOINT Loss: 3.8825 | NRF Acc: 0.7870
# Epoch 151 | GCN MSE Loss: 1.0069 | NRF Loss: 2.7146 | JOINT Loss: 3.7215 | NRF Acc: 0.8316
# Epoch 201 | GCN MSE Loss: 1.0030 | NRF Loss: 2.5785 | JOINT Loss: 3.5814 | NRF Acc: 0.8624
# Epoch 251 | GCN MSE Loss: 0.9995 | NRF Loss: 2.4541 | JOINT Loss: 3.4535 | NRF Acc: 0.8767
# Epoch 301 | GCN MSE Loss: 0.9972 | NRF Loss: 2.3372 | JOINT Loss: 3.3345 | NRF Acc: 0.8898
# Epoch 351 | GCN MSE Loss: 0.9956 | NRF Loss: 2.2280 | JOINT Loss: 3.2235 | NRF Acc: 0.8963
# Epoch 401 | GCN MSE Loss: 0.9937 | NRF Loss: 2.1268 | JOINT Loss: 3.1206 | NRF Acc: 0.9013
# Epoch 451 | GCN MSE Loss: 0.9921 | NRF Loss: 2.0310 | JOINT Loss: 3.0231 | NRF Acc: 0.9047
# Epoch 501 | GCN MSE Loss: 0.9906 | NRF Loss: 1.9397 | JOINT Loss: 2.9303 | NRF Acc: 0.9088
# Epoch 551 | GCN MSE Loss: 0.9891 | NRF Loss: 1.8542 | JOINT Loss: 2.8433 | NRF Acc: 0.9094
# Epoch 601 | GCN MSE Loss: 0.9876 | NRF Loss: 1.7741 | JOINT Loss: 2.7617 | NRF Acc: 0.9119
# Epoch 651 | GCN MSE Loss: 0.9860 | NRF Loss: 1.6991 | JOINT Loss: 2.6851 | NRF Acc: 0.9091
# Epoch 701 | GCN MSE Loss: 0.9845 | NRF Loss: 1.6292 | JOINT Loss: 2.6136 | NRF Acc: 0.9159
# Epoch 751 | GCN MSE Loss: 0.9829 | NRF Loss: 1.5628 | JOINT Loss: 2.5457 | NRF Acc: 0.9166
# Epoch 801 | GCN MSE Loss: 0.9812 | NRF Loss: 1.5002 | JOINT Loss: 2.4815 | NRF Acc: 0.9200
# Epoch 851 | GCN MSE Loss: 0.9800 | NRF Loss: 1.4421 | JOINT Loss: 2.4221 | NRF Acc: 0.9215
# Epoch 901 | GCN MSE Loss: 0.9789 | NRF Loss: 1.3876 | JOINT Loss: 2.3665 | NRF Acc: 0.9237
# Epoch 951 | GCN MSE Loss: 0.9779 | NRF Loss: 1.3364 | JOINT Loss: 2.3143 | NRF Acc: 0.9234
# Best acc/epoch: 0.9265254735946655, epoch 999
#
# Training with embed_dim=32, n_tree=80, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.0374 | NRF Loss: 3.4010 | JOINT Loss: 4.4384 | NRF Acc: 0.1759
# Epoch 51 | GCN MSE Loss: 1.0125 | NRF Loss: 3.2540 | JOINT Loss: 4.2665 | NRF Acc: 0.4057
# Epoch 101 | GCN MSE Loss: 1.0058 | NRF Loss: 3.0354 | JOINT Loss: 4.0412 | NRF Acc: 0.5464
# Epoch 151 | GCN MSE Loss: 1.0012 | NRF Loss: 2.8418 | JOINT Loss: 3.8430 | NRF Acc: 0.6613
# Epoch 201 | GCN MSE Loss: 0.9972 | NRF Loss: 2.6762 | JOINT Loss: 3.6734 | NRF Acc: 0.7391
# Epoch 251 | GCN MSE Loss: 0.9936 | NRF Loss: 2.5269 | JOINT Loss: 3.5205 | NRF Acc: 0.7892
# Epoch 301 | GCN MSE Loss: 0.9902 | NRF Loss: 2.3896 | JOINT Loss: 3.3799 | NRF Acc: 0.8098
# Epoch 351 | GCN MSE Loss: 0.9867 | NRF Loss: 2.2642 | JOINT Loss: 3.2509 | NRF Acc: 0.8306
# Epoch 401 | GCN MSE Loss: 0.9831 | NRF Loss: 2.1485 | JOINT Loss: 3.1315 | NRF Acc: 0.8493
# Epoch 451 | GCN MSE Loss: 0.9797 | NRF Loss: 2.0412 | JOINT Loss: 3.0209 | NRF Acc: 0.8599
# Epoch 501 | GCN MSE Loss: 0.9768 | NRF Loss: 1.9427 | JOINT Loss: 2.9194 | NRF Acc: 0.8658
# Epoch 551 | GCN MSE Loss: 0.9739 | NRF Loss: 1.8525 | JOINT Loss: 2.8264 | NRF Acc: 0.8736
# Epoch 601 | GCN MSE Loss: 0.9712 | NRF Loss: 1.7691 | JOINT Loss: 2.7403 | NRF Acc: 0.8776
# Epoch 651 | GCN MSE Loss: 0.9686 | NRF Loss: 1.6918 | JOINT Loss: 2.6603 | NRF Acc: 0.8801
# Epoch 701 | GCN MSE Loss: 0.9662 | NRF Loss: 1.6198 | JOINT Loss: 2.5860 | NRF Acc: 0.8857
# Epoch 751 | GCN MSE Loss: 0.9643 | NRF Loss: 1.5532 | JOINT Loss: 2.5175 | NRF Acc: 0.8889
# Epoch 801 | GCN MSE Loss: 0.9624 | NRF Loss: 1.4909 | JOINT Loss: 2.4533 | NRF Acc: 0.8923
# Epoch 851 | GCN MSE Loss: 0.9604 | NRF Loss: 1.4333 | JOINT Loss: 2.3937 | NRF Acc: 0.8941
# Epoch 901 | GCN MSE Loss: 0.9586 | NRF Loss: 1.3794 | JOINT Loss: 2.3379 | NRF Acc: 0.8954
# Epoch 951 | GCN MSE Loss: 0.9568 | NRF Loss: 1.3294 | JOINT Loss: 2.2862 | NRF Acc: 0.8979
# Best acc/epoch: 0.900996208190918, epoch 998
#
# Training with embed_dim=32, n_tree=80, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.0884 | NRF Loss: 3.4012 | JOINT Loss: 4.4896 | NRF Acc: 0.2923
# Epoch 51 | GCN MSE Loss: 1.0220 | NRF Loss: 3.1188 | JOINT Loss: 4.1408 | NRF Acc: 0.5230
# Epoch 101 | GCN MSE Loss: 1.0128 | NRF Loss: 2.9089 | JOINT Loss: 3.9218 | NRF Acc: 0.7151
# Epoch 151 | GCN MSE Loss: 1.0081 | NRF Loss: 2.7477 | JOINT Loss: 3.7558 | NRF Acc: 0.8023
# Epoch 201 | GCN MSE Loss: 1.0048 | NRF Loss: 2.6041 | JOINT Loss: 3.6089 | NRF Acc: 0.8387
# Epoch 251 | GCN MSE Loss: 1.0021 | NRF Loss: 2.4725 | JOINT Loss: 3.4745 | NRF Acc: 0.8608
# Epoch 301 | GCN MSE Loss: 0.9997 | NRF Loss: 2.3512 | JOINT Loss: 3.3508 | NRF Acc: 0.8727
# Epoch 351 | GCN MSE Loss: 0.9975 | NRF Loss: 2.2395 | JOINT Loss: 3.2370 | NRF Acc: 0.8801
# Epoch 401 | GCN MSE Loss: 0.9952 | NRF Loss: 2.1366 | JOINT Loss: 3.1318 | NRF Acc: 0.8895
# Epoch 451 | GCN MSE Loss: 0.9930 | NRF Loss: 2.0408 | JOINT Loss: 3.0338 | NRF Acc: 0.8954
# Epoch 501 | GCN MSE Loss: 0.9911 | NRF Loss: 1.9508 | JOINT Loss: 2.9419 | NRF Acc: 0.9007
# Epoch 551 | GCN MSE Loss: 0.9893 | NRF Loss: 1.8661 | JOINT Loss: 2.8554 | NRF Acc: 0.9069
# Epoch 601 | GCN MSE Loss: 0.9876 | NRF Loss: 1.7864 | JOINT Loss: 2.7739 | NRF Acc: 0.9110
# Epoch 651 | GCN MSE Loss: 0.9856 | NRF Loss: 1.7117 | JOINT Loss: 2.6974 | NRF Acc: 0.9116
# Epoch 701 | GCN MSE Loss: 0.9839 | NRF Loss: 1.6419 | JOINT Loss: 2.6258 | NRF Acc: 0.9144
# Epoch 751 | GCN MSE Loss: 0.9823 | NRF Loss: 1.5767 | JOINT Loss: 2.5590 | NRF Acc: 0.9134
# Epoch 801 | GCN MSE Loss: 0.9812 | NRF Loss: 1.5156 | JOINT Loss: 2.4968 | NRF Acc: 0.9131
# Early stopping at epoch 812
# Best acc/epoch: 0.9159401655197144, epoch 712
#
# Training with embed_dim=32, n_tree=80, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.3636 | NRF Loss: 3.4012 | JOINT Loss: 4.7648 | NRF Acc: 0.3269
# Epoch 51 | GCN MSE Loss: 1.0711 | NRF Loss: 3.0617 | JOINT Loss: 4.1328 | NRF Acc: 0.5974
# Epoch 101 | GCN MSE Loss: 1.0265 | NRF Loss: 2.8726 | JOINT Loss: 3.8991 | NRF Acc: 0.7808
# Epoch 151 | GCN MSE Loss: 1.0159 | NRF Loss: 2.7210 | JOINT Loss: 3.7369 | NRF Acc: 0.8306
# Epoch 201 | GCN MSE Loss: 1.0117 | NRF Loss: 2.5849 | JOINT Loss: 3.5966 | NRF Acc: 0.8611
# Epoch 251 | GCN MSE Loss: 1.0099 | NRF Loss: 2.4598 | JOINT Loss: 3.4696 | NRF Acc: 0.8792
# Epoch 301 | GCN MSE Loss: 1.0086 | NRF Loss: 2.3442 | JOINT Loss: 3.3527 | NRF Acc: 0.8867
# Epoch 351 | GCN MSE Loss: 1.0076 | NRF Loss: 2.2366 | JOINT Loss: 3.2442 | NRF Acc: 0.8904
# Epoch 401 | GCN MSE Loss: 1.0067 | NRF Loss: 2.1362 | JOINT Loss: 3.1429 | NRF Acc: 0.8994
# Epoch 451 | GCN MSE Loss: 1.0058 | NRF Loss: 2.0406 | JOINT Loss: 3.0464 | NRF Acc: 0.9047
# Epoch 501 | GCN MSE Loss: 1.0050 | NRF Loss: 1.9507 | JOINT Loss: 2.9557 | NRF Acc: 0.9116
# Epoch 551 | GCN MSE Loss: 1.0042 | NRF Loss: 1.8664 | JOINT Loss: 2.8706 | NRF Acc: 0.9138
# Epoch 601 | GCN MSE Loss: 1.0035 | NRF Loss: 1.7865 | JOINT Loss: 2.7899 | NRF Acc: 0.9159
# Epoch 651 | GCN MSE Loss: 1.0026 | NRF Loss: 1.7112 | JOINT Loss: 2.7138 | NRF Acc: 0.9169
# Epoch 701 | GCN MSE Loss: 1.0018 | NRF Loss: 1.6403 | JOINT Loss: 2.6421 | NRF Acc: 0.9197
# Epoch 751 | GCN MSE Loss: 1.0009 | NRF Loss: 1.5739 | JOINT Loss: 2.5748 | NRF Acc: 0.9197
# Epoch 801 | GCN MSE Loss: 1.0001 | NRF Loss: 1.5113 | JOINT Loss: 2.5113 | NRF Acc: 0.9240
# Epoch 851 | GCN MSE Loss: 0.9992 | NRF Loss: 1.4523 | JOINT Loss: 2.4515 | NRF Acc: 0.9237
# Epoch 901 | GCN MSE Loss: 0.9982 | NRF Loss: 1.3968 | JOINT Loss: 2.3950 | NRF Acc: 0.9243
# Epoch 951 | GCN MSE Loss: 0.9973 | NRF Loss: 1.3450 | JOINT Loss: 2.3423 | NRF Acc: 0.9243
# Early stopping at epoch 988
# Best acc/epoch: 0.9252801537513733, epoch 888
#
# Training with embed_dim=32, n_tree=120, tree_feature_rate=0.1
# Epoch 01 | GCN MSE Loss: 1.2439 | NRF Loss: 3.4013 | JOINT Loss: 4.6452 | NRF Acc: 0.2151
# Epoch 51 | GCN MSE Loss: 1.0529 | NRF Loss: 3.2541 | JOINT Loss: 4.3070 | NRF Acc: 0.3904
# Epoch 101 | GCN MSE Loss: 1.0273 | NRF Loss: 3.0354 | JOINT Loss: 4.0627 | NRF Acc: 0.5212
# Epoch 151 | GCN MSE Loss: 1.0205 | NRF Loss: 2.8450 | JOINT Loss: 3.8655 | NRF Acc: 0.6485
# Epoch 201 | GCN MSE Loss: 1.0166 | NRF Loss: 2.6813 | JOINT Loss: 3.6979 | NRF Acc: 0.7276
# Epoch 251 | GCN MSE Loss: 1.0142 | NRF Loss: 2.5327 | JOINT Loss: 3.5469 | NRF Acc: 0.7855
# Epoch 301 | GCN MSE Loss: 1.0115 | NRF Loss: 2.3962 | JOINT Loss: 3.4078 | NRF Acc: 0.8064
# Epoch 351 | GCN MSE Loss: 1.0098 | NRF Loss: 2.2709 | JOINT Loss: 3.2807 | NRF Acc: 0.8232
# Epoch 401 | GCN MSE Loss: 1.0081 | NRF Loss: 2.1557 | JOINT Loss: 3.1638 | NRF Acc: 0.8347
# Epoch 451 | GCN MSE Loss: 1.0064 | NRF Loss: 2.0498 | JOINT Loss: 3.0562 | NRF Acc: 0.8499
# Epoch 501 | GCN MSE Loss: 1.0046 | NRF Loss: 1.9529 | JOINT Loss: 2.9576 | NRF Acc: 0.8583
# Epoch 551 | GCN MSE Loss: 1.0031 | NRF Loss: 1.8639 | JOINT Loss: 2.8670 | NRF Acc: 0.8633
# Epoch 601 | GCN MSE Loss: 1.0011 | NRF Loss: 1.7820 | JOINT Loss: 2.7831 | NRF Acc: 0.8646
# Epoch 651 | GCN MSE Loss: 0.9985 | NRF Loss: 1.7060 | JOINT Loss: 2.7044 | NRF Acc: 0.8730
# Epoch 701 | GCN MSE Loss: 0.9963 | NRF Loss: 1.6344 | JOINT Loss: 2.6308 | NRF Acc: 0.8773
# Epoch 751 | GCN MSE Loss: 0.9944 | NRF Loss: 1.5676 | JOINT Loss: 2.5620 | NRF Acc: 0.8870
# Epoch 801 | GCN MSE Loss: 0.9925 | NRF Loss: 1.5051 | JOINT Loss: 2.4976 | NRF Acc: 0.8895
# Epoch 851 | GCN MSE Loss: 0.9906 | NRF Loss: 1.4466 | JOINT Loss: 2.4372 | NRF Acc: 0.8910
# Epoch 901 | GCN MSE Loss: 0.9888 | NRF Loss: 1.3924 | JOINT Loss: 2.3812 | NRF Acc: 0.8938
# Epoch 951 | GCN MSE Loss: 0.9870 | NRF Loss: 1.3417 | JOINT Loss: 2.3287 | NRF Acc: 0.8954
# Best acc/epoch: 0.8975715637207031, epoch 991
#
# Training with embed_dim=32, n_tree=120, tree_feature_rate=0.3
# Epoch 01 | GCN MSE Loss: 1.2793 | NRF Loss: 3.4012 | JOINT Loss: 4.6805 | NRF Acc: 0.2344
# Epoch 51 | GCN MSE Loss: 1.0315 | NRF Loss: 3.1175 | JOINT Loss: 4.1490 | NRF Acc: 0.5159
# Epoch 101 | GCN MSE Loss: 1.0209 | NRF Loss: 2.9090 | JOINT Loss: 3.9299 | NRF Acc: 0.7210
# Epoch 151 | GCN MSE Loss: 1.0173 | NRF Loss: 2.7481 | JOINT Loss: 3.7654 | NRF Acc: 0.8007
# Epoch 201 | GCN MSE Loss: 1.0148 | NRF Loss: 2.6054 | JOINT Loss: 3.6202 | NRF Acc: 0.8362
# Epoch 251 | GCN MSE Loss: 1.0127 | NRF Loss: 2.4746 | JOINT Loss: 3.4873 | NRF Acc: 0.8605
# Epoch 301 | GCN MSE Loss: 1.0112 | NRF Loss: 2.3534 | JOINT Loss: 3.3646 | NRF Acc: 0.8711
# Epoch 351 | GCN MSE Loss: 1.0100 | NRF Loss: 2.2408 | JOINT Loss: 3.2508 | NRF Acc: 0.8748
# Epoch 401 | GCN MSE Loss: 1.0090 | NRF Loss: 2.1359 | JOINT Loss: 3.1450 | NRF Acc: 0.8792
# Epoch 451 | GCN MSE Loss: 1.0084 | NRF Loss: 2.0385 | JOINT Loss: 3.0469 | NRF Acc: 0.8867
# Epoch 501 | GCN MSE Loss: 1.0077 | NRF Loss: 1.9475 | JOINT Loss: 2.9553 | NRF Acc: 0.8895
# Epoch 551 | GCN MSE Loss: 1.0071 | NRF Loss: 1.8628 | JOINT Loss: 2.8700 | NRF Acc: 0.8923
# Epoch 601 | GCN MSE Loss: 1.0066 | NRF Loss: 1.7839 | JOINT Loss: 2.7905 | NRF Acc: 0.8979
# Epoch 651 | GCN MSE Loss: 1.0060 | NRF Loss: 1.7101 | JOINT Loss: 2.7161 | NRF Acc: 0.9026
# Epoch 701 | GCN MSE Loss: 1.0055 | NRF Loss: 1.6410 | JOINT Loss: 2.6465 | NRF Acc: 0.9047
# Epoch 751 | GCN MSE Loss: 1.0049 | NRF Loss: 1.5760 | JOINT Loss: 2.5809 | NRF Acc: 0.9069
# Epoch 801 | GCN MSE Loss: 1.0042 | NRF Loss: 1.5149 | JOINT Loss: 2.5191 | NRF Acc: 0.9069
# Epoch 851 | GCN MSE Loss: 1.0035 | NRF Loss: 1.4571 | JOINT Loss: 2.4605 | NRF Acc: 0.9075
# Epoch 901 | GCN MSE Loss: 1.0026 | NRF Loss: 1.4032 | JOINT Loss: 2.4058 | NRF Acc: 0.9091
# Epoch 951 | GCN MSE Loss: 1.0017 | NRF Loss: 1.3524 | JOINT Loss: 2.3541 | NRF Acc: 0.9110
# Best acc/epoch: 0.9115815162658691, epoch 954
#
# Training with embed_dim=32, n_tree=120, tree_feature_rate=0.5
# Epoch 01 | GCN MSE Loss: 1.1239 | NRF Loss: 3.4013 | JOINT Loss: 4.5252 | NRF Acc: 0.3646
# Epoch 51 | GCN MSE Loss: 1.0340 | NRF Loss: 3.0651 | JOINT Loss: 4.0991 | NRF Acc: 0.6083
# Epoch 101 | GCN MSE Loss: 1.0187 | NRF Loss: 2.8758 | JOINT Loss: 3.8946 | NRF Acc: 0.7836
# Epoch 151 | GCN MSE Loss: 1.0126 | NRF Loss: 2.7243 | JOINT Loss: 3.7369 | NRF Acc: 0.8428
# Epoch 201 | GCN MSE Loss: 1.0074 | NRF Loss: 2.5888 | JOINT Loss: 3.5961 | NRF Acc: 0.8633
# Epoch 251 | GCN MSE Loss: 1.0036 | NRF Loss: 2.4647 | JOINT Loss: 3.4682 | NRF Acc: 0.8761
# Epoch 301 | GCN MSE Loss: 1.0004 | NRF Loss: 2.3494 | JOINT Loss: 3.3498 | NRF Acc: 0.8873
# Epoch 351 | GCN MSE Loss: 0.9976 | NRF Loss: 2.2424 | JOINT Loss: 3.2400 | NRF Acc: 0.8932
# Epoch 401 | GCN MSE Loss: 0.9951 | NRF Loss: 2.1425 | JOINT Loss: 3.1376 | NRF Acc: 0.8973
# Epoch 451 | GCN MSE Loss: 0.9928 | NRF Loss: 2.0488 | JOINT Loss: 3.0416 | NRF Acc: 0.9013
# Epoch 501 | GCN MSE Loss: 0.9906 | NRF Loss: 1.9607 | JOINT Loss: 2.9513 | NRF Acc: 0.9054
# Epoch 551 | GCN MSE Loss: 0.9883 | NRF Loss: 1.8769 | JOINT Loss: 2.8652 | NRF Acc: 0.9075
# Epoch 601 | GCN MSE Loss: 0.9864 | NRF Loss: 1.7981 | JOINT Loss: 2.7844 | NRF Acc: 0.9091
# Epoch 651 | GCN MSE Loss: 0.9848 | NRF Loss: 1.7240 | JOINT Loss: 2.7088 | NRF Acc: 0.9119
# Epoch 701 | GCN MSE Loss: 0.9835 | NRF Loss: 1.6541 | JOINT Loss: 2.6375 | NRF Acc: 0.9131
# Epoch 751 | GCN MSE Loss: 0.9824 | NRF Loss: 1.5884 | JOINT Loss: 2.5707 | NRF Acc: 0.9178
# Epoch 801 | GCN MSE Loss: 0.9813 | NRF Loss: 1.5260 | JOINT Loss: 2.5073 | NRF Acc: 0.9191
# Epoch 851 | GCN MSE Loss: 0.9803 | NRF Loss: 1.4677 | JOINT Loss: 2.4480 | NRF Acc: 0.9184
# Epoch 901 | GCN MSE Loss: 0.9791 | NRF Loss: 1.4123 | JOINT Loss: 2.3914 | NRF Acc: 0.9206
# Epoch 951 | GCN MSE Loss: 0.9780 | NRF Loss: 1.3602 | JOINT Loss: 2.3383 | NRF Acc: 0.9234
# Best acc/epoch: 0.9243461489677429, epoch 973

# %%
best_args = default_args.copy()
best_args['embed_dim'] = best_config['embed_dim']
best_args['n_tree'] = best_config['n_tree']
best_args['tree_feature_rate'] = best_config['tree_feature_rate']
best_args['final_evaluation'] = True  # now do full test evaluation
best_args['epochs'] = 3000

# You may want to reload the data again here
data, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
    combined_geo, label_index, continuous_col='weaptype1')

test_acc, best_epoch, best_precision, best_recall, best_f1, y_pred_decoded, y_true_decoded, best_precision_micro, best_recall_micro, best_f1_micro, best_precision_macro, best_recall_macro, best_f1_macro, roc_auc_weighted, roc_auc_micro, roc_auc_macro, epoch_logs = train_joint(
    data, data.edge_index, y_gcn, y_nrf, non_geo_features,
    train_mask, val_mask, test_mask,
    best_args, row_to_node_index, index_to_label, verbose=True
)
# Out:
# Epoch 01 | GCN MSE Loss: 1.1989 | NRF Loss: 3.4012 | JOINT Loss: 4.6001 | NRF Acc: 0.3998
# Epoch 51 | GCN MSE Loss: 1.0275 | NRF Loss: 3.0553 | JOINT Loss: 4.0828 | NRF Acc: 0.6034
# Epoch 101 | GCN MSE Loss: 1.0190 | NRF Loss: 2.8668 | JOINT Loss: 3.8858 | NRF Acc: 0.7818
# Epoch 151 | GCN MSE Loss: 1.0141 | NRF Loss: 2.7173 | JOINT Loss: 3.7314 | NRF Acc: 0.8154
# Epoch 201 | GCN MSE Loss: 1.0101 | NRF Loss: 2.5814 | JOINT Loss: 3.5916 | NRF Acc: 0.8456
# Epoch 251 | GCN MSE Loss: 1.0072 | NRF Loss: 2.4568 | JOINT Loss: 3.4640 | NRF Acc: 0.8549
# Epoch 301 | GCN MSE Loss: 1.0052 | NRF Loss: 2.3396 | JOINT Loss: 3.3448 | NRF Acc: 0.8845
# Epoch 351 | GCN MSE Loss: 1.0034 | NRF Loss: 2.2310 | JOINT Loss: 3.2344 | NRF Acc: 0.8926
# Epoch 401 | GCN MSE Loss: 1.0018 | NRF Loss: 2.1300 | JOINT Loss: 3.1318 | NRF Acc: 0.8951
# Epoch 451 | GCN MSE Loss: 1.0003 | NRF Loss: 2.0358 | JOINT Loss: 3.0360 | NRF Acc: 0.8951
# Epoch 501 | GCN MSE Loss: 0.9987 | NRF Loss: 1.9473 | JOINT Loss: 2.9460 | NRF Acc: 0.8982
# Epoch 551 | GCN MSE Loss: 0.9972 | NRF Loss: 1.8639 | JOINT Loss: 2.8611 | NRF Acc: 0.9026
# Epoch 601 | GCN MSE Loss: 0.9956 | NRF Loss: 1.7844 | JOINT Loss: 2.7800 | NRF Acc: 0.9060
# Epoch 651 | GCN MSE Loss: 0.9944 | NRF Loss: 1.7104 | JOINT Loss: 2.7048 | NRF Acc: 0.9078
# Epoch 701 | GCN MSE Loss: 0.9933 | NRF Loss: 1.6395 | JOINT Loss: 2.6328 | NRF Acc: 0.9094
# Epoch 751 | GCN MSE Loss: 0.9923 | NRF Loss: 1.5728 | JOINT Loss: 2.5651 | NRF Acc: 0.9110
# Epoch 801 | GCN MSE Loss: 0.9915 | NRF Loss: 1.5092 | JOINT Loss: 2.5007 | NRF Acc: 0.9138
# Epoch 851 | GCN MSE Loss: 0.9907 | NRF Loss: 1.4508 | JOINT Loss: 2.4416 | NRF Acc: 0.9150
# Epoch 901 | GCN MSE Loss: 0.9900 | NRF Loss: 1.3961 | JOINT Loss: 2.3861 | NRF Acc: 0.9150
# Early stopping at epoch 916
# Best acc/epoch: 0.9153175354003906, epoch 816
# Predicting on test set

# %%
test_acc
# Out:
# 0.9114004373550415

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# '\nBest acc: 0.9205 at epoch 750 for weaptype1 prediction\nWeighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191\nMacro Precision: 0.9176, Recall: 0.9107, F1: 0.9105\nMicro Precision: 0.9205, Recall: 0.9205, F1: 0.9205\nAUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963\n\n'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       1.00      0.94      0.97        98
#         African National Congress (South Africa)       0.99      1.00      1.00       126
#                                 Al-Qaida in Iraq       0.95      0.74      0.83       180
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.93      0.87      0.90       127
#                                       Al-Shabaab       1.00      1.00      1.00       116
#              Basque Fatherland and Freedom (ETA)       1.00      1.00      1.00       126
#                                       Boko Haram       0.98      0.96      0.97        92
#   Communist Party of India - Maoist (CPI-Maoist)       0.98      0.92      0.95        65
#        Corsican National Liberation Front (FLNC)       1.00      0.99      1.00       145
#                        Donetsk People's Republic       0.99      0.99      0.99       115
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.76      0.86       128
#                                Fulani extremists       0.93      0.96      0.94        52
#                  Houthi extremists (Ansar Allah)       0.89      0.93      0.91       120
#                      Irish Republican Army (IRA)       1.00      0.99      1.00       143
#      Islamic State of Iraq and the Levant (ISIL)       0.54      0.88      0.67        65
#                   Kurdistan Workers' Party (PKK)       0.92      0.84      0.88        70
#          Liberation Tigers of Tamil Eelam (LTTE)       1.00      0.99      0.99        94
#          Manuel Rodriguez Patriotic Front (FPMR)       0.99      1.00      1.00       181
#                                          Maoists       0.94      0.96      0.95        53
#                                Muslim extremists       0.78      0.92      0.85        78
#       National Liberation Army of Colombia (ELN)       0.98      0.88      0.93       118
#                          New People's Army (NPA)       0.87      0.96      0.91        48
#                Nicaraguan Democratic Force (FDN)       0.50      1.00      0.67        32
#                                     Palestinians       0.96      0.97      0.97       137
#    Revolutionary Armed Forces of Colombia (FARC)       0.82      0.97      0.89        62
#                                Shining Path (SL)       0.99      0.72      0.83       178
#                                  Sikh Extremists       0.98      0.96      0.97       107
#                                          Taliban       0.48      0.59      0.53        51
#                  Tehrik-i-Taliban Pakistan (TTP)       0.80      0.72      0.76       114
#        Tupac Amaru Revolutionary Movement (MRTA)       0.72      0.99      0.84       128
#
#                                         accuracy                           0.91      3149
#                                        macro avg       0.90      0.91      0.90      3149
#                                     weighted avg       0.93      0.91      0.91      3149

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Saved confusion matrix for partition 200 to Results200/cm_200_weaptype1.png
