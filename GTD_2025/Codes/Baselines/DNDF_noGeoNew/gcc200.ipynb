# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../../data/top30groups/noGeographic/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
"""geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)"""
# Out:
# "geodata = ['longitude', 'latitude']\ncombined_geo = df.copy()\ncombined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))\ncombined_geo = combined_geo.drop(columns=geodata)"

# %%
"""import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)"""
# Out:
# "import ast\n\ndef to_tuple_if_needed(val):\n    if isinstance(val, str):\n        return ast.literal_eval(val)\n    return val  # already a tuple\n\ncombined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)"

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
param_grid = {
    'lr': [0.001],
    'n_tree': [100],
    'tree_depth': [10],
    'tree_feature_rate': [0.5],
    'feat_dropout': [0.1],
    'embed_dim': [32]
}

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    y_nrf, nrf_input, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        df, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            y_nrf, nrf_input, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | NRF Loss: 3.4012 | Joint: 3.4012 | Val Acc: 0.1933
# Epoch 050 | NRF Loss: 3.1777 | Joint: 3.1777 | Val Acc: 0.2842
# Epoch 100 | NRF Loss: 3.0489 | Joint: 3.0489 | Val Acc: 0.3792
# Epoch 150 | NRF Loss: 2.9451 | Joint: 2.9451 | Val Acc: 0.4050
# Epoch 200 | NRF Loss: 2.8525 | Joint: 2.8525 | Val Acc: 0.4283
# Epoch 250 | NRF Loss: 2.7666 | Joint: 2.7666 | Val Acc: 0.4417
# Epoch 300 | NRF Loss: 2.6856 | Joint: 2.6856 | Val Acc: 0.4600
# Epoch 350 | NRF Loss: 2.6094 | Joint: 2.6094 | Val Acc: 0.4758
# Epoch 400 | NRF Loss: 2.5372 | Joint: 2.5372 | Val Acc: 0.4875
# Epoch 450 | NRF Loss: 2.4688 | Joint: 2.4688 | Val Acc: 0.4983
# Epoch 500 | NRF Loss: 2.4039 | Joint: 2.4039 | Val Acc: 0.5033
# Epoch 550 | NRF Loss: 2.3425 | Joint: 2.3425 | Val Acc: 0.5067
# Epoch 600 | NRF Loss: 2.2844 | Joint: 2.2844 | Val Acc: 0.5125
# Epoch 650 | NRF Loss: 2.2293 | Joint: 2.2293 | Val Acc: 0.5150
# Epoch 700 | NRF Loss: 2.1771 | Joint: 2.1771 | Val Acc: 0.5217
# Epoch 750 | NRF Loss: 2.1276 | Joint: 2.1276 | Val Acc: 0.5233
# Epoch 800 | NRF Loss: 2.0807 | Joint: 2.0807 | Val Acc: 0.5250
# Epoch 850 | NRF Loss: 2.0363 | Joint: 2.0363 | Val Acc: 0.5250
# Epoch 900 | NRF Loss: 1.9941 | Joint: 1.9941 | Val Acc: 0.5242
# Epoch 950 | NRF Loss: 1.9540 | Joint: 1.9540 | Val Acc: 0.5242
# Epoch 1000 | NRF Loss: 1.9160 | Joint: 1.9160 | Val Acc: 0.5250
# Epoch 1050 | NRF Loss: 1.8798 | Joint: 1.8798 | Val Acc: 0.5217
# Epoch 1100 | NRF Loss: 1.8453 | Joint: 1.8453 | Val Acc: 0.5242
# Early stopping at epoch 1127
# Best validation acc: 0.5275 @ epoch 827
# Evaluating on test set using full graph...
# 0.4858333468437195

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.4858333468437195, 'epoch': 827, 'y_pred': ['Corsican National Liberation Front (FLNC)', 'Fulani extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Fulani extremists', 'Boko Haram', 'African National Congress (South Africa)', 'Fulani extremists', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Al-Shabaab', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', 'Corsican National Liberation Front (FLNC)', 'Taliban', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Corsican National Liberation Front (FLNC)', 'Al-Shabaab', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Fulani extremists', 'Al-Shabaab', 'Al-Qaida in Iraq', 'Sikh Extremists', 'Palestinians', 'Taliban', 'African National Congress (South Africa)', 'Boko Haram', 'Corsican National Liberation Front (FLNC)', 'Islamic State of Iraq and the Levant (ISIL)', 'African National Congress (South Africa)', 'Sikh Extremists', 'Palestinians', 'Maoists', 'Muslim extremists', 'Houthi extremists (Ansar Allah)', "New People's Army (NPA)", 'National Liberation Army of Colombia (ELN)', 'Abu Sayyaf Group (ASG)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Shining Path (SL)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Al-Shabaab', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Palestinians', 'Fulani extremists', 'Irish Republican Army (IRA)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', "New People's Army (NPA)", "Donetsk People's Republic", 'Al-Shabaab', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Irish Republican Army (IRA)', 'Abu Sayyaf Group (ASG)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Taliban', 'Farabundo Marti National Liberation Front (FMLN)', 'Fulani extremists', 'National Liberation Army of Colombia (ELN)', 'Boko Haram', "New People's Army (NPA)", 'Tupac Amaru Revolutionary Movement (MRTA)', "Donetsk People's Republic", 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Farabundo Marti National Liberation Front (FMLN)', 'Houthi extremists (Ansar Allah)', 'African National Congress (South Africa)', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Houthi extremists (Ansar Allah)', 'African National Congress (South Africa)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Manuel Rodriguez Patriotic Front (FPMR)', "New People's Army (NPA)", 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Farabundo Marti National Liberation Front (FMLN)', 'Abu Sayyaf Group (ASG)', 'Boko Haram', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Corsican National Liberation Front (FLNC)', 'Farabundo Marti National Liberation Front (FMLN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Irish Republican Army (IRA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Nicaraguan Democratic Force (FDN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Corsican Nation ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# '\nBest acc: 0.9205 at epoch 750 for weaptype1 prediction\nWeighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191\nMacro Precision: 0.9176, Recall: 0.9107, F1: 0.9105\nMicro Precision: 0.9205, Recall: 0.9205, F1: 0.9205\nAUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963\n\n'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.98      0.93      0.95        43
#         African National Congress (South Africa)       0.98      1.00      0.99        58
#                                 Al-Qaida in Iraq       1.00      0.79      0.88        87
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.98      0.92      0.95        50
#                                       Al-Shabaab       1.00      1.00      1.00        58
#              Basque Fatherland and Freedom (ETA)       0.98      0.90      0.94        60
#                                       Boko Haram       0.93      0.95      0.94        41
#   Communist Party of India - Maoist (CPI-Maoist)       1.00      0.92      0.96        24
#        Corsican National Liberation Front (FLNC)       0.97      0.96      0.97        78
#                        Donetsk People's Republic       1.00      1.00      1.00        59
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.85      0.92        55
#                                Fulani extremists       0.93      0.89      0.91        28
#                  Houthi extremists (Ansar Allah)       0.95      0.96      0.96        57
#                      Irish Republican Army (IRA)       0.95      1.00      0.97        71
#      Islamic State of Iraq and the Levant (ISIL)       0.65      0.93      0.76        40
#                   Kurdistan Workers' Party (PKK)       0.93      0.87      0.90        30
#          Liberation Tigers of Tamil Eelam (LTTE)       0.98      0.96      0.97        45
#          Manuel Rodriguez Patriotic Front (FPMR)       0.99      1.00      0.99        77
#                                          Maoists       0.92      0.96      0.94        25
#                                Muslim extremists       0.76      0.97      0.85        30
#       National Liberation Army of Colombia (ELN)       0.94      0.90      0.92        51
#                          New People's Army (NPA)       0.81      0.94      0.87        18
#                Nicaraguan Democratic Force (FDN)       0.67      0.94      0.78        17
#                                     Palestinians       0.98      0.97      0.98        65
#    Revolutionary Armed Forces of Colombia (FARC)       0.85      0.88      0.86        32
#                                Shining Path (SL)       0.79      0.98      0.87        46
#                                  Sikh Extremists       0.97      0.98      0.97        57
#                                          Taliban       0.59      0.73      0.65        22
#                  Tehrik-i-Taliban Pakistan (TTP)       0.90      0.83      0.87        54
#        Tupac Amaru Revolutionary Movement (MRTA)       0.99      0.86      0.92        96
#
#                                         accuracy                           0.93      1474
#                                        macro avg       0.91      0.93      0.92      1474
#                                     weighted avg       0.94      0.93      0.93      1474

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Saved confusion matrix for partition 100 to Results100/cm_100_weaptype1.png
