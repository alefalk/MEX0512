# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
param_grid = {
    'lr': [0.001, 0.01],
    'n_tree': [50, 80, 120],
    'tree_depth': [9, 10, 12],
    'tree_feature_rate': [0.1, 0.3,0.5],
    'feat_dropout': [0.1],
    'embed_dim': [32, 64]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 20)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# tensor(1142)
# tensor(459)
# tensor(470)
# tensor(2328)
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4819 | NRF Loss: 3.4012 | Joint: 6.8831 | Val Acc: 0.3050
# Epoch 050 | GCN Loss: 3.1785 | NRF Loss: 3.0318 | Joint: 6.2103 | Val Acc: 0.5600
# Epoch 100 | GCN Loss: 2.8619 | NRF Loss: 2.8177 | Joint: 5.6796 | Val Acc: 0.7467
# Epoch 150 | GCN Loss: 2.5496 | NRF Loss: 2.6680 | Joint: 5.2176 | Val Acc: 0.7933
# Epoch 200 | GCN Loss: 2.2933 | NRF Loss: 2.5378 | Joint: 4.8311 | Val Acc: 0.8233
# Epoch 250 | GCN Loss: 2.0929 | NRF Loss: 2.4188 | Joint: 4.5117 | Val Acc: 0.8283
# Epoch 300 | GCN Loss: 1.9317 | NRF Loss: 2.3082 | Joint: 4.2399 | Val Acc: 0.8367
# Epoch 350 | GCN Loss: 1.7981 | NRF Loss: 2.2061 | Joint: 4.0042 | Val Acc: 0.8400
# Epoch 400 | GCN Loss: 1.6841 | NRF Loss: 2.1107 | Joint: 3.7948 | Val Acc: 0.8417
# Epoch 450 | GCN Loss: 1.5843 | NRF Loss: 2.0203 | Joint: 3.6046 | Val Acc: 0.8533
# Epoch 500 | GCN Loss: 1.4957 | NRF Loss: 1.9348 | Joint: 3.4306 | Val Acc: 0.8583
# Epoch 550 | GCN Loss: 1.4164 | NRF Loss: 1.8547 | Joint: 3.2711 | Val Acc: 0.8633
# Epoch 600 | GCN Loss: 1.3457 | NRF Loss: 1.7788 | Joint: 3.1246 | Val Acc: 0.8633
# Epoch 650 | GCN Loss: 1.2826 | NRF Loss: 1.7073 | Joint: 2.9898 | Val Acc: 0.8717
# Epoch 700 | GCN Loss: 1.2259 | NRF Loss: 1.6391 | Joint: 2.8650 | Val Acc: 0.8717
# Epoch 750 | GCN Loss: 1.1754 | NRF Loss: 1.5745 | Joint: 2.7499 | Val Acc: 0.8750
# Epoch 800 | GCN Loss: 1.1302 | NRF Loss: 1.5145 | Joint: 2.6447 | Val Acc: 0.8750
# Epoch 850 | GCN Loss: 1.0898 | NRF Loss: 1.4562 | Joint: 2.5460 | Val Acc: 0.8717
# Epoch 900 | GCN Loss: 1.0536 | NRF Loss: 1.4015 | Joint: 2.4551 | Val Acc: 0.8733
# Epoch 950 | GCN Loss: 1.0210 | NRF Loss: 1.3502 | Joint: 2.3712 | Val Acc: 0.8750
# Early stopping at epoch 978
# Best validation acc: 0.8767 @ epoch 678
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4447 | NRF Loss: 3.4012 | Joint: 6.8459 | Val Acc: 0.3517
# Epoch 050 | GCN Loss: 1.5808 | NRF Loss: 2.2644 | Joint: 3.8452 | Val Acc: 0.8167
# Epoch 100 | GCN Loss: 1.0296 | NRF Loss: 1.5301 | Joint: 2.5597 | Val Acc: 0.8583
# Epoch 150 | GCN Loss: 0.8287 | NRF Loss: 1.0945 | Joint: 1.9232 | Val Acc: 0.8633
# Epoch 200 | GCN Loss: 0.7283 | NRF Loss: 0.8610 | Joint: 1.5893 | Val Acc: 0.8650
# Epoch 250 | GCN Loss: 0.6618 | NRF Loss: 0.7296 | Joint: 1.3914 | Val Acc: 0.8700
# Epoch 300 | GCN Loss: 0.6107 | NRF Loss: 0.6477 | Joint: 1.2583 | Val Acc: 0.8683
# Epoch 350 | GCN Loss: 0.5698 | NRF Loss: 0.5936 | Joint: 1.1634 | Val Acc: 0.8700
# Epoch 400 | GCN Loss: 0.5350 | NRF Loss: 0.5558 | Joint: 1.0908 | Val Acc: 0.8783
# Epoch 450 | GCN Loss: 0.5086 | NRF Loss: 0.5288 | Joint: 1.0374 | Val Acc: 0.8783
# Epoch 500 | GCN Loss: 0.4884 | NRF Loss: 0.5067 | Joint: 0.9950 | Val Acc: 0.8700
# Epoch 550 | GCN Loss: 0.4719 | NRF Loss: 0.4899 | Joint: 0.9619 | Val Acc: 0.8767
# Epoch 600 | GCN Loss: 0.4590 | NRF Loss: 0.4760 | Joint: 0.9350 | Val Acc: 0.8733
# Epoch 650 | GCN Loss: 0.4483 | NRF Loss: 0.4632 | Joint: 0.9115 | Val Acc: 0.8767
# Epoch 700 | GCN Loss: 0.4392 | NRF Loss: 0.4516 | Joint: 0.8909 | Val Acc: 0.8767
# Epoch 750 | GCN Loss: 0.4314 | NRF Loss: 0.4429 | Joint: 0.8743 | Val Acc: 0.8767
# Epoch 800 | GCN Loss: 0.4244 | NRF Loss: 0.4352 | Joint: 0.8595 | Val Acc: 0.8800
# Epoch 850 | GCN Loss: 0.4180 | NRF Loss: 0.4294 | Joint: 0.8474 | Val Acc: 0.8750
# Epoch 900 | GCN Loss: 0.4124 | NRF Loss: 0.4243 | Joint: 0.8367 | Val Acc: 0.8800
# Epoch 950 | GCN Loss: 0.4072 | NRF Loss: 0.4199 | Joint: 0.8270 | Val Acc: 0.8817
# Epoch 1000 | GCN Loss: 0.4027 | NRF Loss: 0.4145 | Joint: 0.8172 | Val Acc: 0.8883
# Epoch 1050 | GCN Loss: 0.3983 | NRF Loss: 0.4111 | Joint: 0.8095 | Val Acc: 0.8817
# Early stopping at epoch 1056
# Best validation acc: 0.8917 @ epoch 756
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4200 | NRF Loss: 3.4012 | Joint: 6.8212 | Val Acc: 0.3400
# Epoch 050 | GCN Loss: 1.5451 | NRF Loss: 2.2366 | Joint: 3.7817 | Val Acc: 0.8233
# Epoch 100 | GCN Loss: 1.0121 | NRF Loss: 1.5003 | Joint: 2.5125 | Val Acc: 0.8550
# Epoch 150 | GCN Loss: 0.8210 | NRF Loss: 1.0532 | Joint: 1.8742 | Val Acc: 0.8533
# Epoch 200 | GCN Loss: 0.7225 | NRF Loss: 0.8162 | Joint: 1.5387 | Val Acc: 0.8650
# Epoch 250 | GCN Loss: 0.6566 | NRF Loss: 0.6857 | Joint: 1.3423 | Val Acc: 0.8633
# Epoch 300 | GCN Loss: 0.6052 | NRF Loss: 0.6041 | Joint: 1.2093 | Val Acc: 0.8683
# Epoch 350 | GCN Loss: 0.5664 | NRF Loss: 0.5489 | Joint: 1.1154 | Val Acc: 0.8800
# Epoch 400 | GCN Loss: 0.5374 | NRF Loss: 0.5116 | Joint: 1.0490 | Val Acc: 0.8750
# Epoch 450 | GCN Loss: 0.5147 | NRF Loss: 0.4846 | Joint: 0.9992 | Val Acc: 0.8750
# Epoch 500 | GCN Loss: 0.4961 | NRF Loss: 0.4644 | Joint: 0.9606 | Val Acc: 0.8800
# Epoch 550 | GCN Loss: 0.4811 | NRF Loss: 0.4498 | Joint: 0.9309 | Val Acc: 0.8683
# Epoch 600 | GCN Loss: 0.4683 | NRF Loss: 0.4338 | Joint: 0.9021 | Val Acc: 0.8800
# Epoch 650 | GCN Loss: 0.4575 | NRF Loss: 0.4248 | Joint: 0.8822 | Val Acc: 0.8850
# Epoch 700 | GCN Loss: 0.4481 | NRF Loss: 0.4137 | Joint: 0.8618 | Val Acc: 0.8833
# Epoch 750 | GCN Loss: 0.4396 | NRF Loss: 0.4046 | Joint: 0.8441 | Val Acc: 0.8750
# Epoch 800 | GCN Loss: 0.4321 | NRF Loss: 0.3986 | Joint: 0.8307 | Val Acc: 0.8817
# Epoch 850 | GCN Loss: 0.4254 | NRF Loss: 0.3914 | Joint: 0.8168 | Val Acc: 0.8800
# Epoch 900 | GCN Loss: 0.4197 | NRF Loss: 0.3857 | Joint: 0.8054 | Val Acc: 0.8917
# Early stopping at epoch 928
# Best validation acc: 0.8950 @ epoch 628
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4854 | NRF Loss: 3.4012 | Joint: 6.8866 | Val Acc: 0.3317
# Epoch 050 | GCN Loss: 1.2911 | NRF Loss: 2.2927 | Joint: 3.5838 | Val Acc: 0.8133
# Epoch 100 | GCN Loss: 0.8525 | NRF Loss: 1.5862 | Joint: 2.4387 | Val Acc: 0.8500
# Epoch 150 | GCN Loss: 0.7078 | NRF Loss: 1.1610 | Joint: 1.8688 | Val Acc: 0.8517
# Epoch 200 | GCN Loss: 0.6235 | NRF Loss: 0.9351 | Joint: 1.5586 | Val Acc: 0.8600
# Epoch 250 | GCN Loss: 0.5647 | NRF Loss: 0.8077 | Joint: 1.3724 | Val Acc: 0.8533
# Epoch 300 | GCN Loss: 0.5233 | NRF Loss: 0.7307 | Joint: 1.2540 | Val Acc: 0.8533
# Epoch 350 | GCN Loss: 0.4946 | NRF Loss: 0.6788 | Joint: 1.1734 | Val Acc: 0.8600
# Epoch 400 | GCN Loss: 0.4734 | NRF Loss: 0.6430 | Joint: 1.1164 | Val Acc: 0.8667
# Epoch 450 | GCN Loss: 0.4573 | NRF Loss: 0.6169 | Joint: 1.0742 | Val Acc: 0.8800
# Epoch 500 | GCN Loss: 0.4437 | NRF Loss: 0.5997 | Joint: 1.0434 | Val Acc: 0.8667
# Epoch 550 | GCN Loss: 0.4324 | NRF Loss: 0.5796 | Joint: 1.0120 | Val Acc: 0.8783
# Epoch 600 | GCN Loss: 0.4227 | NRF Loss: 0.5649 | Joint: 0.9876 | Val Acc: 0.8850
# Epoch 650 | GCN Loss: 0.4143 | NRF Loss: 0.5534 | Joint: 0.9677 | Val Acc: 0.8850
# Epoch 700 | GCN Loss: 0.4070 | NRF Loss: 0.5440 | Joint: 0.9509 | Val Acc: 0.8850
# Epoch 750 | GCN Loss: 0.4006 | NRF Loss: 0.5359 | Joint: 0.9365 | Val Acc: 0.8850
# Epoch 800 | GCN Loss: 0.3949 | NRF Loss: 0.5307 | Joint: 0.9256 | Val Acc: 0.8917
# Epoch 850 | GCN Loss: 0.3893 | NRF Loss: 0.5239 | Joint: 0.9131 | Val Acc: 0.8767
# Epoch 900 | GCN Loss: 0.3846 | NRF Loss: 0.5177 | Joint: 0.9023 | Val Acc: 0.8800
# Epoch 950 | GCN Loss: 0.3800 | NRF Loss: 0.5117 | Joint: 0.8917 | Val Acc: 0.8883
# Epoch 1000 | GCN Loss: 0.3754 | NRF Loss: 0.5061 | Joint: 0.8815 | Val Acc: 0.8817
# Epoch 1050 | GCN Loss: 0.3713 | NRF Loss: 0.5020 | Joint: 0.8733 | Val Acc: 0.8783
# Epoch 1100 | GCN Loss: 0.3670 | NRF Loss: 0.4960 | Joint: 0.8630 | Val Acc: 0.8867
# Early stopping at epoch 1107
# Best validation acc: 0.8983 @ epoch 807
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 120, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4771 | NRF Loss: 3.4012 | Joint: 6.8783 | Val Acc: 0.2117
# Epoch 050 | GCN Loss: 3.1829 | NRF Loss: 3.2507 | Joint: 6.4336 | Val Acc: 0.2367
# Epoch 100 | GCN Loss: 2.8730 | NRF Loss: 2.9745 | Joint: 5.8474 | Val Acc: 0.5367
# Epoch 150 | GCN Loss: 2.5728 | NRF Loss: 2.7631 | Joint: 5.3360 | Val Acc: 0.6450
# Epoch 200 | GCN Loss: 2.3201 | NRF Loss: 2.5986 | Joint: 4.9187 | Val Acc: 0.7333
# Epoch 250 | GCN Loss: 2.1156 | NRF Loss: 2.4604 | Joint: 4.5760 | Val Acc: 0.7600
# Epoch 300 | GCN Loss: 1.9509 | NRF Loss: 2.3385 | Joint: 4.2894 | Val Acc: 0.7667
# Epoch 350 | GCN Loss: 1.8143 | NRF Loss: 2.2290 | Joint: 4.0433 | Val Acc: 0.7817
# Epoch 400 | GCN Loss: 1.6983 | NRF Loss: 2.1303 | Joint: 3.8286 | Val Acc: 0.7950
# Epoch 450 | GCN Loss: 1.5973 | NRF Loss: 2.0394 | Joint: 3.6367 | Val Acc: 0.7983
# Epoch 500 | GCN Loss: 1.5089 | NRF Loss: 1.9557 | Joint: 3.4646 | Val Acc: 0.7917
# Epoch 550 | GCN Loss: 1.4307 | NRF Loss: 1.8782 | Joint: 3.3089 | Val Acc: 0.7917
# Epoch 600 | GCN Loss: 1.3611 | NRF Loss: 1.8057 | Joint: 3.1668 | Val Acc: 0.7883
# Epoch 650 | GCN Loss: 1.2986 | NRF Loss: 1.7380 | Joint: 3.0366 | Val Acc: 0.7933
# Epoch 700 | GCN Loss: 1.2424 | NRF Loss: 1.6750 | Joint: 2.9174 | Val Acc: 0.8017
# Epoch 750 | GCN Loss: 1.1917 | NRF Loss: 1.6163 | Joint: 2.8080 | Val Acc: 0.7950
# Epoch 800 | GCN Loss: 1.1458 | NRF Loss: 1.5595 | Joint: 2.7053 | Val Acc: 0.8067
# Epoch 850 | GCN Loss: 1.1045 | NRF Loss: 1.5075 | Joint: 2.6119 | Val Acc: 0.8083
# Epoch 900 | GCN Loss: 1.0671 | NRF Loss: 1.4579 | Joint: 2.5250 | Val Acc: 0.8133
# Epoch 950 | GCN Loss: 1.0332 | NRF Loss: 1.4115 | Joint: 2.4448 | Val Acc: 0.8167
# Epoch 1000 | GCN Loss: 1.0025 | NRF Loss: 1.3677 | Joint: 2.3702 | Val Acc: 0.8033
# Epoch 1050 | GCN Loss: 0.9745 | NRF Loss: 1.3272 | Joint: 2.3016 | Val Acc: 0.8117
# Epoch 1100 | GCN Loss: 0.9489 | NRF Loss: 1.2879 | Joint: 2.2367 | Val Acc: 0.8083
# Epoch 1150 | GCN Loss: 0.9253 | NRF Loss: 1.2509 | Joint: 2.1763 | Val Acc: 0.8133
# Epoch 1200 | GCN Loss: 0.9037 | NRF Loss: 1.2163 | Joint: 2.1200 | Val Acc: 0.8117
# Early stopping at epoch 1237
# Best validation acc: 0.8250 @ epoch 937
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4283 | NRF Loss: 3.4012 | Joint: 6.8295 | Val Acc: 0.2867
# Epoch 050 | GCN Loss: 3.0140 | NRF Loss: 3.1012 | Joint: 6.1152 | Val Acc: 0.4367
# Epoch 100 | GCN Loss: 2.5911 | NRF Loss: 2.8478 | Joint: 5.4390 | Val Acc: 0.6817
# Epoch 150 | GCN Loss: 2.2418 | NRF Loss: 2.6871 | Joint: 4.9289 | Val Acc: 0.7450
# Epoch 200 | GCN Loss: 1.9831 | NRF Loss: 2.5538 | Joint: 4.5369 | Val Acc: 0.7850
# Epoch 250 | GCN Loss: 1.7867 | NRF Loss: 2.4362 | Joint: 4.2229 | Val Acc: 0.7983
# Epoch 300 | GCN Loss: 1.6321 | NRF Loss: 2.3282 | Joint: 3.9603 | Val Acc: 0.8017
# Epoch 350 | GCN Loss: 1.5055 | NRF Loss: 2.2282 | Joint: 3.7337 | Val Acc: 0.7983
# Epoch 400 | GCN Loss: 1.3995 | NRF Loss: 2.1353 | Joint: 3.5348 | Val Acc: 0.8017
# Epoch 450 | GCN Loss: 1.3090 | NRF Loss: 2.0499 | Joint: 3.3589 | Val Acc: 0.8083
# Epoch 500 | GCN Loss: 1.2310 | NRF Loss: 1.9685 | Joint: 3.1995 | Val Acc: 0.8183
# Epoch 550 | GCN Loss: 1.1633 | NRF Loss: 1.8909 | Joint: 3.0542 | Val Acc: 0.8200
# Epoch 600 | GCN Loss: 1.1047 | NRF Loss: 1.8166 | Joint: 2.9213 | Val Acc: 0.8250
# Epoch 650 | GCN Loss: 1.0536 | NRF Loss: 1.7470 | Joint: 2.8005 | Val Acc: 0.8333
# Epoch 700 | GCN Loss: 1.0088 | NRF Loss: 1.6809 | Joint: 2.6897 | Val Acc: 0.8350
# Epoch 750 | GCN Loss: 0.9697 | NRF Loss: 1.6185 | Joint: 2.5882 | Val Acc: 0.8367
# Epoch 800 | GCN Loss: 0.9355 | NRF Loss: 1.5603 | Joint: 2.4957 | Val Acc: 0.8400
# Epoch 850 | GCN Loss: 0.9050 | NRF Loss: 1.5043 | Joint: 2.4094 | Val Acc: 0.8333
# Epoch 900 | GCN Loss: 0.8778 | NRF Loss: 1.4516 | Joint: 2.3295 | Val Acc: 0.8350
# Epoch 950 | GCN Loss: 0.8533 | NRF Loss: 1.4021 | Joint: 2.2554 | Val Acc: 0.8383
# Epoch 1000 | GCN Loss: 0.8311 | NRF Loss: 1.3544 | Joint: 2.1856 | Val Acc: 0.8483
# Epoch 1050 | GCN Loss: 0.8108 | NRF Loss: 1.3096 | Joint: 2.1204 | Val Acc: 0.8517
# Epoch 1100 | GCN Loss: 0.7920 | NRF Loss: 1.2677 | Joint: 2.0598 | Val Acc: 0.8367
# Epoch 1150 | GCN Loss: 0.7745 | NRF Loss: 1.2281 | Joint: 2.0026 | Val Acc: 0.8333
# Epoch 1200 | GCN Loss: 0.7581 | NRF Loss: 1.1903 | Joint: 1.9485 | Val Acc: 0.8367
# Epoch 1250 | GCN Loss: 0.7427 | NRF Loss: 1.1552 | Joint: 1.8979 | Val Acc: 0.8350
# Epoch 1300 | GCN Loss: 0.7283 | NRF Loss: 1.1218 | Joint: 1.8501 | Val Acc: 0.8500
# Epoch 1350 | GCN Loss: 0.7146 | NRF Loss: 1.0899 | Joint: 1.8045 | Val Acc: 0.8483
# Epoch 1400 | GCN Loss: 0.7016 | NRF Loss: 1.0604 | Joint: 1.7621 | Val Acc: 0.8467
# Epoch 1450 | GCN Loss: 0.6892 | NRF Loss: 1.0325 | Joint: 1.7218 | Val Acc: 0.8500
# Epoch 1500 | GCN Loss: 0.6773 | NRF Loss: 1.0063 | Joint: 1.6836 | Val Acc: 0.8517
# Epoch 1550 | GCN Loss: 0.6658 | NRF Loss: 0.9808 | Joint: 1.6466 | Val Acc: 0.8550
# Epoch 1600 | GCN Loss: 0.6547 | NRF Loss: 0.9569 | Joint: 1.6116 | Val Acc: 0.8533
# Epoch 1650 | GCN Loss: 0.6441 | NRF Loss: 0.9339 | Joint: 1.5780 | Val Acc: 0.8517
# Epoch 1700 | GCN Loss: 0.6340 | NRF Loss: 0.9128 | Joint: 1.5468 | Val Acc: 0.8533
# Early stopping at epoch 1703
# Best validation acc: 0.8600 @ epoch 1403
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4368 | NRF Loss: 3.4012 | Joint: 6.8380 | Val Acc: 0.1850
# Epoch 050 | GCN Loss: 2.9975 | NRF Loss: 3.2199 | Joint: 6.2174 | Val Acc: 0.2350
# Epoch 100 | GCN Loss: 2.5382 | NRF Loss: 2.9206 | Joint: 5.4589 | Val Acc: 0.5900
# Epoch 150 | GCN Loss: 2.2006 | NRF Loss: 2.7234 | Joint: 4.9239 | Val Acc: 0.6683
# Epoch 200 | GCN Loss: 1.9703 | NRF Loss: 2.5742 | Joint: 4.5446 | Val Acc: 0.7133
# Epoch 250 | GCN Loss: 1.7907 | NRF Loss: 2.4465 | Joint: 4.2372 | Val Acc: 0.7267
# Epoch 300 | GCN Loss: 1.6384 | NRF Loss: 2.3344 | Joint: 3.9728 | Val Acc: 0.7250
# Epoch 350 | GCN Loss: 1.5059 | NRF Loss: 2.2325 | Joint: 3.7384 | Val Acc: 0.7333
# Epoch 400 | GCN Loss: 1.3929 | NRF Loss: 2.1389 | Joint: 3.5318 | Val Acc: 0.7567
# Epoch 450 | GCN Loss: 1.2976 | NRF Loss: 2.0523 | Joint: 3.3499 | Val Acc: 0.7633
# Epoch 500 | GCN Loss: 1.2173 | NRF Loss: 1.9722 | Joint: 3.1895 | Val Acc: 0.7783
# Epoch 550 | GCN Loss: 1.1492 | NRF Loss: 1.8967 | Joint: 3.0458 | Val Acc: 0.7983
# Epoch 600 | GCN Loss: 1.0909 | NRF Loss: 1.8259 | Joint: 2.9169 | Val Acc: 0.8083
# Epoch 650 | GCN Loss: 1.0408 | NRF Loss: 1.7600 | Joint: 2.8008 | Val Acc: 0.8167
# Epoch 700 | GCN Loss: 0.9975 | NRF Loss: 1.6985 | Joint: 2.6960 | Val Acc: 0.8150
# Epoch 750 | GCN Loss: 0.9598 | NRF Loss: 1.6404 | Joint: 2.6002 | Val Acc: 0.8133
# Epoch 800 | GCN Loss: 0.9267 | NRF Loss: 1.5846 | Joint: 2.5113 | Val Acc: 0.8133
# Epoch 850 | GCN Loss: 0.8974 | NRF Loss: 1.5329 | Joint: 2.4304 | Val Acc: 0.8150
# Epoch 900 | GCN Loss: 0.8714 | NRF Loss: 1.4830 | Joint: 2.3544 | Val Acc: 0.8133
# Epoch 950 | GCN Loss: 0.8479 | NRF Loss: 1.4369 | Joint: 2.2849 | Val Acc: 0.8133
# Early stopping at epoch 991
# Best validation acc: 0.8233 @ epoch 691
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 9, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4188 | NRF Loss: 3.4012 | Joint: 6.8201 | Val Acc: 0.3567
# Epoch 050 | GCN Loss: 1.2902 | NRF Loss: 2.3285 | Joint: 3.6187 | Val Acc: 0.7417
# Epoch 100 | GCN Loss: 0.8541 | NRF Loss: 1.6124 | Joint: 2.4665 | Val Acc: 0.8067
# Epoch 150 | GCN Loss: 0.6960 | NRF Loss: 1.2012 | Joint: 1.8972 | Val Acc: 0.8167
# Epoch 200 | GCN Loss: 0.6074 | NRF Loss: 0.9819 | Joint: 1.5893 | Val Acc: 0.8183
# Epoch 250 | GCN Loss: 0.5518 | NRF Loss: 0.8581 | Joint: 1.4099 | Val Acc: 0.8317
# Epoch 300 | GCN Loss: 0.5133 | NRF Loss: 0.7809 | Joint: 1.2943 | Val Acc: 0.8300
# Epoch 350 | GCN Loss: 0.4854 | NRF Loss: 0.7315 | Joint: 1.2169 | Val Acc: 0.8450
# Epoch 400 | GCN Loss: 0.4640 | NRF Loss: 0.6940 | Joint: 1.1580 | Val Acc: 0.8583
# Epoch 450 | GCN Loss: 0.4471 | NRF Loss: 0.6668 | Joint: 1.1139 | Val Acc: 0.8483
# Epoch 500 | GCN Loss: 0.4327 | NRF Loss: 0.6476 | Joint: 1.0802 | Val Acc: 0.8483
# Epoch 550 | GCN Loss: 0.4211 | NRF Loss: 0.6297 | Joint: 1.0508 | Val Acc: 0.8433
# Epoch 600 | GCN Loss: 0.4104 | NRF Loss: 0.6160 | Joint: 1.0265 | Val Acc: 0.8467
# Epoch 650 | GCN Loss: 0.4018 | NRF Loss: 0.6062 | Joint: 1.0079 | Val Acc: 0.8450
# Epoch 700 | GCN Loss: 0.3940 | NRF Loss: 0.5940 | Joint: 0.9880 | Val Acc: 0.8433
# Early stopping at epoch 701
# Best validation acc: 0.8617 @ epoch 401
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4148 | NRF Loss: 3.4013 | Joint: 6.8161 | Val Acc: 0.2900
# Epoch 050 | GCN Loss: 3.1238 | NRF Loss: 3.0582 | Joint: 6.1820 | Val Acc: 0.5500
# Epoch 100 | GCN Loss: 2.7972 | NRF Loss: 2.8629 | Joint: 5.6602 | Val Acc: 0.7333
# Epoch 150 | GCN Loss: 2.4899 | NRF Loss: 2.7234 | Joint: 5.2132 | Val Acc: 0.7783
# Epoch 200 | GCN Loss: 2.2487 | NRF Loss: 2.6016 | Joint: 4.8503 | Val Acc: 0.8033
# Epoch 250 | GCN Loss: 2.0602 | NRF Loss: 2.4905 | Joint: 4.5507 | Val Acc: 0.8200
# Epoch 300 | GCN Loss: 1.9053 | NRF Loss: 2.3876 | Joint: 4.2929 | Val Acc: 0.8350
# Epoch 350 | GCN Loss: 1.7728 | NRF Loss: 2.2910 | Joint: 4.0638 | Val Acc: 0.8333
# Epoch 400 | GCN Loss: 1.6578 | NRF Loss: 2.1998 | Joint: 3.8576 | Val Acc: 0.8417
# Epoch 450 | GCN Loss: 1.5576 | NRF Loss: 2.1135 | Joint: 3.6711 | Val Acc: 0.8333
# Epoch 500 | GCN Loss: 1.4693 | NRF Loss: 2.0313 | Joint: 3.5006 | Val Acc: 0.8383
# Epoch 550 | GCN Loss: 1.3909 | NRF Loss: 1.9526 | Joint: 3.3435 | Val Acc: 0.8433
# Epoch 600 | GCN Loss: 1.3211 | NRF Loss: 1.8779 | Joint: 3.1990 | Val Acc: 0.8567
# Epoch 650 | GCN Loss: 1.2592 | NRF Loss: 1.8080 | Joint: 3.0672 | Val Acc: 0.8517
# Epoch 700 | GCN Loss: 1.2044 | NRF Loss: 1.7416 | Joint: 2.9460 | Val Acc: 0.8483
# Epoch 750 | GCN Loss: 1.1558 | NRF Loss: 1.6785 | Joint: 2.8343 | Val Acc: 0.8450
# Epoch 800 | GCN Loss: 1.1128 | NRF Loss: 1.6191 | Joint: 2.7319 | Val Acc: 0.8483
# Epoch 850 | GCN Loss: 1.0744 | NRF Loss: 1.5623 | Joint: 2.6367 | Val Acc: 0.8467
# Epoch 900 | GCN Loss: 1.0401 | NRF Loss: 1.5091 | Joint: 2.5492 | Val Acc: 0.8533
# Early stopping at epoch 928
# Best validation acc: 0.8583 @ epoch 628
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3766 | NRF Loss: 3.4012 | Joint: 6.7778 | Val Acc: 0.3617
# Epoch 050 | GCN Loss: 1.2778 | NRF Loss: 2.2992 | Joint: 3.5770 | Val Acc: 0.7917
# Epoch 100 | GCN Loss: 0.8570 | NRF Loss: 1.5772 | Joint: 2.4342 | Val Acc: 0.8000
# Epoch 150 | GCN Loss: 0.7074 | NRF Loss: 1.1650 | Joint: 1.8724 | Val Acc: 0.8217
# Epoch 200 | GCN Loss: 0.6207 | NRF Loss: 0.9458 | Joint: 1.5665 | Val Acc: 0.8350
# Epoch 250 | GCN Loss: 0.5604 | NRF Loss: 0.8303 | Joint: 1.3907 | Val Acc: 0.8383
# Epoch 300 | GCN Loss: 0.5174 | NRF Loss: 0.7592 | Joint: 1.2766 | Val Acc: 0.8517
# Epoch 350 | GCN Loss: 0.4856 | NRF Loss: 0.7092 | Joint: 1.1948 | Val Acc: 0.8617
# Epoch 400 | GCN Loss: 0.4625 | NRF Loss: 0.6757 | Joint: 1.1382 | Val Acc: 0.8550
# Epoch 450 | GCN Loss: 0.4450 | NRF Loss: 0.6499 | Joint: 1.0949 | Val Acc: 0.8617
# Epoch 500 | GCN Loss: 0.4308 | NRF Loss: 0.6300 | Joint: 1.0608 | Val Acc: 0.8583
# Epoch 550 | GCN Loss: 0.4192 | NRF Loss: 0.6121 | Joint: 1.0313 | Val Acc: 0.8667
# Epoch 600 | GCN Loss: 0.4094 | NRF Loss: 0.5981 | Joint: 1.0075 | Val Acc: 0.8717
# Epoch 650 | GCN Loss: 0.4009 | NRF Loss: 0.5862 | Joint: 0.9871 | Val Acc: 0.8667
# Epoch 700 | GCN Loss: 0.3932 | NRF Loss: 0.5739 | Joint: 0.9671 | Val Acc: 0.8767
# Epoch 750 | GCN Loss: 0.3860 | NRF Loss: 0.5583 | Joint: 0.9444 | Val Acc: 0.8683
# Epoch 800 | GCN Loss: 0.3798 | NRF Loss: 0.5481 | Joint: 0.9279 | Val Acc: 0.8717
# Epoch 850 | GCN Loss: 0.3738 | NRF Loss: 0.5401 | Joint: 0.9139 | Val Acc: 0.8900
# Epoch 900 | GCN Loss: 0.3688 | NRF Loss: 0.5335 | Joint: 0.9023 | Val Acc: 0.8900
# Epoch 950 | GCN Loss: 0.3641 | NRF Loss: 0.5257 | Joint: 0.8898 | Val Acc: 0.8917
# Epoch 1000 | GCN Loss: 0.3597 | NRF Loss: 0.5192 | Joint: 0.8789 | Val Acc: 0.8967
# Epoch 1050 | GCN Loss: 0.3559 | NRF Loss: 0.5158 | Joint: 0.8717 | Val Acc: 0.8933
# Epoch 1100 | GCN Loss: 0.3535 | NRF Loss: 0.5109 | Joint: 0.8644 | Val Acc: 0.8983
# Epoch 1150 | GCN Loss: 0.3485 | NRF Loss: 0.5062 | Joint: 0.8547 | Val Acc: 0.8917
# Epoch 1200 | GCN Loss: 0.3453 | NRF Loss: 0.5022 | Joint: 0.8475 | Val Acc: 0.8933
# Epoch 1250 | GCN Loss: 0.3423 | NRF Loss: 0.4986 | Joint: 0.8408 | Val Acc: 0.8883
# Epoch 1300 | GCN Loss: 0.3389 | NRF Loss: 0.4956 | Joint: 0.8345 | Val Acc: 0.8950
# Epoch 1350 | GCN Loss: 0.3363 | NRF Loss: 0.4913 | Joint: 0.8276 | Val Acc: 0.8933
# Epoch 1400 | GCN Loss: 0.3333 | NRF Loss: 0.4911 | Joint: 0.8244 | Val Acc: 0.8933
# Early stopping at epoch 1410
# Best validation acc: 0.9083 @ epoch 1110
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4490 | NRF Loss: 3.4012 | Joint: 6.8502 | Val Acc: 0.3417
# Epoch 050 | GCN Loss: 1.5654 | NRF Loss: 2.2133 | Joint: 3.7787 | Val Acc: 0.8100
# Epoch 100 | GCN Loss: 1.0306 | NRF Loss: 1.4485 | Joint: 2.4791 | Val Acc: 0.8400
# Epoch 150 | GCN Loss: 0.8146 | NRF Loss: 1.0007 | Joint: 1.8154 | Val Acc: 0.8550
# Epoch 200 | GCN Loss: 0.7100 | NRF Loss: 0.7707 | Joint: 1.4807 | Val Acc: 0.8717
# Epoch 250 | GCN Loss: 0.6432 | NRF Loss: 0.6450 | Joint: 1.2882 | Val Acc: 0.8833
# Epoch 300 | GCN Loss: 0.5934 | NRF Loss: 0.5701 | Joint: 1.1635 | Val Acc: 0.8850
# Epoch 350 | GCN Loss: 0.5560 | NRF Loss: 0.5191 | Joint: 1.0751 | Val Acc: 0.8800
# Epoch 400 | GCN Loss: 0.5277 | NRF Loss: 0.4854 | Joint: 1.0131 | Val Acc: 0.8783
# Epoch 450 | GCN Loss: 0.5058 | NRF Loss: 0.4579 | Joint: 0.9638 | Val Acc: 0.8833
# Epoch 500 | GCN Loss: 0.4882 | NRF Loss: 0.4376 | Joint: 0.9258 | Val Acc: 0.8883
# Epoch 550 | GCN Loss: 0.4739 | NRF Loss: 0.4226 | Joint: 0.8965 | Val Acc: 0.8883
# Epoch 600 | GCN Loss: 0.4618 | NRF Loss: 0.4082 | Joint: 0.8700 | Val Acc: 0.8867
# Epoch 650 | GCN Loss: 0.4516 | NRF Loss: 0.3965 | Joint: 0.8480 | Val Acc: 0.8900
# Epoch 700 | GCN Loss: 0.4423 | NRF Loss: 0.3877 | Joint: 0.8300 | Val Acc: 0.8917
# Epoch 750 | GCN Loss: 0.4338 | NRF Loss: 0.3819 | Joint: 0.8157 | Val Acc: 0.8867
# Epoch 800 | GCN Loss: 0.4264 | NRF Loss: 0.3734 | Joint: 0.7997 | Val Acc: 0.8933
# Epoch 850 | GCN Loss: 0.4200 | NRF Loss: 0.3670 | Joint: 0.7870 | Val Acc: 0.8950
# Epoch 900 | GCN Loss: 0.4145 | NRF Loss: 0.3617 | Joint: 0.7762 | Val Acc: 0.8900
# Early stopping at epoch 934
# Best validation acc: 0.9000 @ epoch 634
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4499 | NRF Loss: 3.4012 | Joint: 6.8511 | Val Acc: 0.3400
# Epoch 050 | GCN Loss: 1.6082 | NRF Loss: 2.3277 | Joint: 3.9359 | Val Acc: 0.7600
# Epoch 100 | GCN Loss: 1.0420 | NRF Loss: 1.5875 | Joint: 2.6296 | Val Acc: 0.8133
# Epoch 150 | GCN Loss: 0.8296 | NRF Loss: 1.1629 | Joint: 1.9925 | Val Acc: 0.8350
# Epoch 200 | GCN Loss: 0.7267 | NRF Loss: 0.9412 | Joint: 1.6679 | Val Acc: 0.8433
# Epoch 250 | GCN Loss: 0.6560 | NRF Loss: 0.8211 | Joint: 1.4771 | Val Acc: 0.8550
# Epoch 300 | GCN Loss: 0.6013 | NRF Loss: 0.7469 | Joint: 1.3482 | Val Acc: 0.8533
# Epoch 350 | GCN Loss: 0.5601 | NRF Loss: 0.6972 | Joint: 1.2573 | Val Acc: 0.8450
# Epoch 400 | GCN Loss: 0.5292 | NRF Loss: 0.6614 | Joint: 1.1906 | Val Acc: 0.8517
# Epoch 450 | GCN Loss: 0.5057 | NRF Loss: 0.6345 | Joint: 1.1402 | Val Acc: 0.8633
# Epoch 500 | GCN Loss: 0.4874 | NRF Loss: 0.6110 | Joint: 1.0984 | Val Acc: 0.8517
# Epoch 550 | GCN Loss: 0.4727 | NRF Loss: 0.5933 | Joint: 1.0660 | Val Acc: 0.8533
# Early stopping at epoch 596
# Best validation acc: 0.8683 @ epoch 296
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4214 | NRF Loss: 3.4012 | Joint: 6.8226 | Val Acc: 0.3450
# Epoch 050 | GCN Loss: 1.5553 | NRF Loss: 2.2740 | Joint: 3.8293 | Val Acc: 0.8267
# Epoch 100 | GCN Loss: 1.0110 | NRF Loss: 1.5427 | Joint: 2.5536 | Val Acc: 0.8650
# Epoch 150 | GCN Loss: 0.8136 | NRF Loss: 1.1074 | Joint: 1.9210 | Val Acc: 0.8733
# Epoch 200 | GCN Loss: 0.7162 | NRF Loss: 0.8795 | Joint: 1.5957 | Val Acc: 0.8800
# Epoch 250 | GCN Loss: 0.6507 | NRF Loss: 0.7538 | Joint: 1.4045 | Val Acc: 0.8783
# Epoch 300 | GCN Loss: 0.5998 | NRF Loss: 0.6748 | Joint: 1.2747 | Val Acc: 0.8800
# Epoch 350 | GCN Loss: 0.5610 | NRF Loss: 0.6245 | Joint: 1.1855 | Val Acc: 0.8883
# Epoch 400 | GCN Loss: 0.5310 | NRF Loss: 0.5858 | Joint: 1.1168 | Val Acc: 0.8883
# Epoch 450 | GCN Loss: 0.5074 | NRF Loss: 0.5582 | Joint: 1.0656 | Val Acc: 0.8883
# Epoch 500 | GCN Loss: 0.4878 | NRF Loss: 0.5376 | Joint: 1.0254 | Val Acc: 0.8817
# Early stopping at epoch 510
# Best validation acc: 0.8917 @ epoch 210
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4371 | NRF Loss: 3.4012 | Joint: 6.8383 | Val Acc: 0.3567
# Epoch 050 | GCN Loss: 1.5551 | NRF Loss: 2.2948 | Joint: 3.8500 | Val Acc: 0.7500
# Epoch 100 | GCN Loss: 1.0434 | NRF Loss: 1.5280 | Joint: 2.5713 | Val Acc: 0.7900
# Epoch 150 | GCN Loss: 0.8376 | NRF Loss: 1.1007 | Joint: 1.9383 | Val Acc: 0.7950
# Epoch 200 | GCN Loss: 0.7276 | NRF Loss: 0.8829 | Joint: 1.6105 | Val Acc: 0.8167
# Epoch 250 | GCN Loss: 0.6552 | NRF Loss: 0.7621 | Joint: 1.4173 | Val Acc: 0.8250
# Epoch 300 | GCN Loss: 0.6010 | NRF Loss: 0.6892 | Joint: 1.2901 | Val Acc: 0.8350
# Epoch 350 | GCN Loss: 0.5608 | NRF Loss: 0.6385 | Joint: 1.1993 | Val Acc: 0.8550
# Epoch 400 | GCN Loss: 0.5303 | NRF Loss: 0.6029 | Joint: 1.1333 | Val Acc: 0.8517
# Epoch 450 | GCN Loss: 0.5067 | NRF Loss: 0.5757 | Joint: 1.0824 | Val Acc: 0.8617
# Epoch 500 | GCN Loss: 0.4882 | NRF Loss: 0.5545 | Joint: 1.0427 | Val Acc: 0.8567
# Epoch 550 | GCN Loss: 0.4721 | NRF Loss: 0.5372 | Joint: 1.0092 | Val Acc: 0.8533
# Epoch 600 | GCN Loss: 0.4589 | NRF Loss: 0.5226 | Joint: 0.9815 | Val Acc: 0.8633
# Epoch 650 | GCN Loss: 0.4479 | NRF Loss: 0.5092 | Joint: 0.9571 | Val Acc: 0.8633
# Epoch 700 | GCN Loss: 0.4385 | NRF Loss: 0.4985 | Joint: 0.9371 | Val Acc: 0.8650
# Epoch 750 | GCN Loss: 0.4304 | NRF Loss: 0.4896 | Joint: 0.9200 | Val Acc: 0.8683
# Epoch 800 | GCN Loss: 0.4233 | NRF Loss: 0.4816 | Joint: 0.9049 | Val Acc: 0.8717
# Epoch 850 | GCN Loss: 0.4170 | NRF Loss: 0.4743 | Joint: 0.8913 | Val Acc: 0.8667
# Epoch 900 | GCN Loss: 0.4111 | NRF Loss: 0.4668 | Joint: 0.8779 | Val Acc: 0.8650
# Epoch 950 | GCN Loss: 0.4059 | NRF Loss: 0.4593 | Joint: 0.8652 | Val Acc: 0.8517
# Epoch 1000 | GCN Loss: 0.4006 | NRF Loss: 0.4527 | Joint: 0.8533 | Val Acc: 0.8633
# Epoch 1050 | GCN Loss: 0.3958 | NRF Loss: 0.4471 | Joint: 0.8429 | Val Acc: 0.8667
# Early stopping at epoch 1099
# Best validation acc: 0.8767 @ epoch 799
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 12, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4461 | NRF Loss: 3.4012 | Joint: 6.8473 | Val Acc: 0.3633
# Epoch 050 | GCN Loss: 1.2713 | NRF Loss: 2.2272 | Joint: 3.4985 | Val Acc: 0.8200
# Epoch 100 | GCN Loss: 0.8464 | NRF Loss: 1.5006 | Joint: 2.3469 | Val Acc: 0.8617
# Epoch 150 | GCN Loss: 0.7046 | NRF Loss: 1.0654 | Joint: 1.7700 | Val Acc: 0.8550
# Epoch 200 | GCN Loss: 0.6210 | NRF Loss: 0.8386 | Joint: 1.4596 | Val Acc: 0.8600
# Epoch 250 | GCN Loss: 0.5636 | NRF Loss: 0.7127 | Joint: 1.2762 | Val Acc: 0.8667
# Epoch 300 | GCN Loss: 0.5236 | NRF Loss: 0.6362 | Joint: 1.1598 | Val Acc: 0.8700
# Epoch 350 | GCN Loss: 0.4946 | NRF Loss: 0.5882 | Joint: 1.0828 | Val Acc: 0.8700
# Epoch 400 | GCN Loss: 0.4727 | NRF Loss: 0.5519 | Joint: 1.0246 | Val Acc: 0.8800
# Epoch 450 | GCN Loss: 0.4560 | NRF Loss: 0.5313 | Joint: 0.9873 | Val Acc: 0.8867
# Epoch 500 | GCN Loss: 0.4428 | NRF Loss: 0.5096 | Joint: 0.9524 | Val Acc: 0.8783
# Epoch 550 | GCN Loss: 0.4317 | NRF Loss: 0.4933 | Joint: 0.9250 | Val Acc: 0.8867
# Epoch 600 | GCN Loss: 0.4221 | NRF Loss: 0.4836 | Joint: 0.9058 | Val Acc: 0.8833
# Epoch 650 | GCN Loss: 0.4135 | NRF Loss: 0.4720 | Joint: 0.8856 | Val Acc: 0.8833
# Epoch 700 | GCN Loss: 0.4061 | NRF Loss: 0.4642 | Joint: 0.8703 | Val Acc: 0.8783
# Epoch 750 | GCN Loss: 0.3995 | NRF Loss: 0.4556 | Joint: 0.8552 | Val Acc: 0.8800
# Early stopping at epoch 760
# Best validation acc: 0.8917 @ epoch 460
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 9, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3846 | NRF Loss: 3.4012 | Joint: 6.7858 | Val Acc: 0.3617
# Epoch 050 | GCN Loss: 1.5694 | NRF Loss: 2.3164 | Joint: 3.8858 | Val Acc: 0.7850
# Epoch 100 | GCN Loss: 1.0329 | NRF Loss: 1.5763 | Joint: 2.6092 | Val Acc: 0.8317
# Epoch 150 | GCN Loss: 0.8224 | NRF Loss: 1.1567 | Joint: 1.9791 | Val Acc: 0.8517
# Epoch 200 | GCN Loss: 0.7188 | NRF Loss: 0.9364 | Joint: 1.6553 | Val Acc: 0.8733
# Epoch 250 | GCN Loss: 0.6517 | NRF Loss: 0.8140 | Joint: 1.4657 | Val Acc: 0.8850
# Epoch 300 | GCN Loss: 0.6037 | NRF Loss: 0.7394 | Joint: 1.3431 | Val Acc: 0.8850
# Epoch 350 | GCN Loss: 0.5653 | NRF Loss: 0.6879 | Joint: 1.2532 | Val Acc: 0.8883
# Epoch 400 | GCN Loss: 0.5357 | NRF Loss: 0.6505 | Joint: 1.1861 | Val Acc: 0.8967
# Epoch 450 | GCN Loss: 0.5121 | NRF Loss: 0.6233 | Joint: 1.1354 | Val Acc: 0.8883
# Epoch 500 | GCN Loss: 0.4922 | NRF Loss: 0.6010 | Joint: 1.0932 | Val Acc: 0.8867
# Epoch 550 | GCN Loss: 0.4760 | NRF Loss: 0.5820 | Joint: 1.0580 | Val Acc: 0.8833
# Epoch 600 | GCN Loss: 0.4619 | NRF Loss: 0.5677 | Joint: 1.0296 | Val Acc: 0.8933
# Epoch 650 | GCN Loss: 0.4505 | NRF Loss: 0.5560 | Joint: 1.0066 | Val Acc: 0.8933
# Epoch 700 | GCN Loss: 0.4408 | NRF Loss: 0.5444 | Joint: 0.9852 | Val Acc: 0.8917
# Early stopping at epoch 725
# Best validation acc: 0.9000 @ epoch 425
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 120, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3690 | NRF Loss: 3.4012 | Joint: 6.7702 | Val Acc: 0.3283
# Epoch 050 | GCN Loss: 3.0738 | NRF Loss: 3.1056 | Joint: 6.1794 | Val Acc: 0.4767
# Epoch 100 | GCN Loss: 2.7447 | NRF Loss: 2.8807 | Joint: 5.6254 | Val Acc: 0.6967
# Epoch 150 | GCN Loss: 2.4379 | NRF Loss: 2.7250 | Joint: 5.1629 | Val Acc: 0.7667
# Epoch 200 | GCN Loss: 2.2044 | NRF Loss: 2.5934 | Joint: 4.7978 | Val Acc: 0.8067
# Epoch 250 | GCN Loss: 2.0263 | NRF Loss: 2.4761 | Joint: 4.5024 | Val Acc: 0.8217
# Epoch 300 | GCN Loss: 1.8805 | NRF Loss: 2.3691 | Joint: 4.2496 | Val Acc: 0.8317
# Epoch 350 | GCN Loss: 1.7576 | NRF Loss: 2.2710 | Joint: 4.0286 | Val Acc: 0.8417
# Epoch 400 | GCN Loss: 1.6519 | NRF Loss: 2.1791 | Joint: 3.8311 | Val Acc: 0.8450
# Epoch 450 | GCN Loss: 1.5591 | NRF Loss: 2.0935 | Joint: 3.6526 | Val Acc: 0.8467
# Epoch 500 | GCN Loss: 1.4767 | NRF Loss: 2.0132 | Joint: 3.4899 | Val Acc: 0.8467
# Epoch 550 | GCN Loss: 1.4030 | NRF Loss: 1.9365 | Joint: 3.3396 | Val Acc: 0.8550
# Epoch 600 | GCN Loss: 1.3368 | NRF Loss: 1.8641 | Joint: 3.2008 | Val Acc: 0.8650
# Epoch 650 | GCN Loss: 1.2766 | NRF Loss: 1.7950 | Joint: 3.0716 | Val Acc: 0.8700
# Epoch 700 | GCN Loss: 1.2217 | NRF Loss: 1.7302 | Joint: 2.9519 | Val Acc: 0.8650
# Epoch 750 | GCN Loss: 1.1713 | NRF Loss: 1.6683 | Joint: 2.8396 | Val Acc: 0.8650
# Epoch 800 | GCN Loss: 1.1251 | NRF Loss: 1.6109 | Joint: 2.7359 | Val Acc: 0.8633
# Epoch 850 | GCN Loss: 1.0834 | NRF Loss: 1.5545 | Joint: 2.6379 | Val Acc: 0.8667
# Epoch 900 | GCN Loss: 1.0462 | NRF Loss: 1.5020 | Joint: 2.5483 | Val Acc: 0.8667
# Early stopping at epoch 935
# Best validation acc: 0.8717 @ epoch 635
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4137 | NRF Loss: 3.4012 | Joint: 6.8149 | Val Acc: 0.2200
# Epoch 050 | GCN Loss: 2.9873 | NRF Loss: 3.0923 | Joint: 6.0796 | Val Acc: 0.4633
# Epoch 100 | GCN Loss: 2.5415 | NRF Loss: 2.8598 | Joint: 5.4014 | Val Acc: 0.6983
# Epoch 150 | GCN Loss: 2.1870 | NRF Loss: 2.7089 | Joint: 4.8960 | Val Acc: 0.7650
# Epoch 200 | GCN Loss: 1.9399 | NRF Loss: 2.5835 | Joint: 4.5234 | Val Acc: 0.7917
# Epoch 250 | GCN Loss: 1.7531 | NRF Loss: 2.4721 | Joint: 4.2252 | Val Acc: 0.8217
# Epoch 300 | GCN Loss: 1.6025 | NRF Loss: 2.3697 | Joint: 3.9722 | Val Acc: 0.8233
# Epoch 350 | GCN Loss: 1.4782 | NRF Loss: 2.2743 | Joint: 3.7526 | Val Acc: 0.8267
# Epoch 400 | GCN Loss: 1.3741 | NRF Loss: 2.1855 | Joint: 3.5596 | Val Acc: 0.8317
# Epoch 450 | GCN Loss: 1.2855 | NRF Loss: 2.1016 | Joint: 3.3871 | Val Acc: 0.8300
# Epoch 500 | GCN Loss: 1.2098 | NRF Loss: 2.0223 | Joint: 3.2322 | Val Acc: 0.8383
# Epoch 550 | GCN Loss: 1.1448 | NRF Loss: 1.9465 | Joint: 3.0913 | Val Acc: 0.8433
# Epoch 600 | GCN Loss: 1.0887 | NRF Loss: 1.8745 | Joint: 2.9632 | Val Acc: 0.8433
# Epoch 650 | GCN Loss: 1.0400 | NRF Loss: 1.8067 | Joint: 2.8467 | Val Acc: 0.8450
# Epoch 700 | GCN Loss: 0.9975 | NRF Loss: 1.7414 | Joint: 2.7389 | Val Acc: 0.8467
# Epoch 750 | GCN Loss: 0.9603 | NRF Loss: 1.6795 | Joint: 2.6398 | Val Acc: 0.8483
# Epoch 800 | GCN Loss: 0.9276 | NRF Loss: 1.6206 | Joint: 2.5481 | Val Acc: 0.8417
# Epoch 850 | GCN Loss: 0.8984 | NRF Loss: 1.5651 | Joint: 2.4635 | Val Acc: 0.8400
# Epoch 900 | GCN Loss: 0.8724 | NRF Loss: 1.5119 | Joint: 2.3843 | Val Acc: 0.8467
# Epoch 950 | GCN Loss: 0.8490 | NRF Loss: 1.4621 | Joint: 2.3111 | Val Acc: 0.8517
# Epoch 1000 | GCN Loss: 0.8278 | NRF Loss: 1.4141 | Joint: 2.2419 | Val Acc: 0.8433
# Early stopping at epoch 1017
# Best validation acc: 0.8567 @ epoch 717
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3933 | NRF Loss: 3.4012 | Joint: 6.7945 | Val Acc: 0.3317
# Epoch 050 | GCN Loss: 2.9810 | NRF Loss: 3.0479 | Joint: 6.0289 | Val Acc: 0.5500
# Epoch 100 | GCN Loss: 2.5389 | NRF Loss: 2.8432 | Joint: 5.3821 | Val Acc: 0.7467
# Epoch 150 | GCN Loss: 2.2015 | NRF Loss: 2.7022 | Joint: 4.9037 | Val Acc: 0.8017
# Epoch 200 | GCN Loss: 1.9591 | NRF Loss: 2.5817 | Joint: 4.5408 | Val Acc: 0.8117
# Epoch 250 | GCN Loss: 1.7694 | NRF Loss: 2.4732 | Joint: 4.2427 | Val Acc: 0.8150
# Epoch 300 | GCN Loss: 1.6160 | NRF Loss: 2.3714 | Joint: 3.9875 | Val Acc: 0.8317
# Epoch 350 | GCN Loss: 1.4901 | NRF Loss: 2.2771 | Joint: 3.7673 | Val Acc: 0.8433
# Epoch 400 | GCN Loss: 1.3847 | NRF Loss: 2.1873 | Joint: 3.5720 | Val Acc: 0.8467
# Epoch 450 | GCN Loss: 1.2950 | NRF Loss: 2.1018 | Joint: 3.3968 | Val Acc: 0.8483
# Epoch 500 | GCN Loss: 1.2182 | NRF Loss: 2.0212 | Joint: 3.2393 | Val Acc: 0.8517
# Epoch 550 | GCN Loss: 1.1520 | NRF Loss: 1.9449 | Joint: 3.0969 | Val Acc: 0.8517
# Epoch 600 | GCN Loss: 1.0949 | NRF Loss: 1.8729 | Joint: 2.9678 | Val Acc: 0.8483
# Epoch 650 | GCN Loss: 1.0453 | NRF Loss: 1.8040 | Joint: 2.8493 | Val Acc: 0.8550
# Epoch 700 | GCN Loss: 1.0022 | NRF Loss: 1.7388 | Joint: 2.7410 | Val Acc: 0.8483
# Epoch 750 | GCN Loss: 0.9644 | NRF Loss: 1.6764 | Joint: 2.6408 | Val Acc: 0.8517
# Epoch 800 | GCN Loss: 0.9308 | NRF Loss: 1.6179 | Joint: 2.5487 | Val Acc: 0.8533
# Epoch 850 | GCN Loss: 0.9010 | NRF Loss: 1.5623 | Joint: 2.4633 | Val Acc: 0.8533
# Epoch 900 | GCN Loss: 0.8743 | NRF Loss: 1.5089 | Joint: 2.3832 | Val Acc: 0.8517
# Early stopping at epoch 930
# Best validation acc: 0.8617 @ epoch 630
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 120, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4613 | NRF Loss: 3.4012 | Joint: 6.8625 | Val Acc: 0.3350
# Epoch 050 | GCN Loss: 3.1639 | NRF Loss: 3.0634 | Joint: 6.2273 | Val Acc: 0.5300
# Epoch 100 | GCN Loss: 2.8637 | NRF Loss: 2.8671 | Joint: 5.7308 | Val Acc: 0.7300
# Epoch 150 | GCN Loss: 2.5617 | NRF Loss: 2.7267 | Joint: 5.2885 | Val Acc: 0.7900
# Epoch 200 | GCN Loss: 2.3020 | NRF Loss: 2.6058 | Joint: 4.9078 | Val Acc: 0.8083
# Epoch 250 | GCN Loss: 2.0957 | NRF Loss: 2.4944 | Joint: 4.5901 | Val Acc: 0.8300
# Epoch 300 | GCN Loss: 1.9287 | NRF Loss: 2.3905 | Joint: 4.3193 | Val Acc: 0.8350
# Epoch 350 | GCN Loss: 1.7909 | NRF Loss: 2.2931 | Joint: 4.0839 | Val Acc: 0.8467
# Epoch 400 | GCN Loss: 1.6753 | NRF Loss: 2.2012 | Joint: 3.8765 | Val Acc: 0.8450
# Epoch 450 | GCN Loss: 1.5772 | NRF Loss: 2.1149 | Joint: 3.6922 | Val Acc: 0.8450
# Epoch 500 | GCN Loss: 1.4924 | NRF Loss: 2.0331 | Joint: 3.5255 | Val Acc: 0.8533
# Epoch 550 | GCN Loss: 1.4175 | NRF Loss: 1.9559 | Joint: 3.3735 | Val Acc: 0.8567
# Epoch 600 | GCN Loss: 1.3503 | NRF Loss: 1.8830 | Joint: 3.2333 | Val Acc: 0.8583
# Epoch 650 | GCN Loss: 1.2897 | NRF Loss: 1.8137 | Joint: 3.1034 | Val Acc: 0.8617
# Epoch 700 | GCN Loss: 1.2348 | NRF Loss: 1.7484 | Joint: 2.9832 | Val Acc: 0.8650
# Epoch 750 | GCN Loss: 1.1850 | NRF Loss: 1.6862 | Joint: 2.8713 | Val Acc: 0.8633
# Epoch 800 | GCN Loss: 1.1401 | NRF Loss: 1.6265 | Joint: 2.7666 | Val Acc: 0.8633
# Epoch 850 | GCN Loss: 1.0995 | NRF Loss: 1.5702 | Joint: 2.6698 | Val Acc: 0.8667
# Epoch 900 | GCN Loss: 1.0628 | NRF Loss: 1.5157 | Joint: 2.5784 | Val Acc: 0.8667
# Epoch 950 | GCN Loss: 1.0294 | NRF Loss: 1.4644 | Joint: 2.4938 | Val Acc: 0.8717
# Epoch 1000 | GCN Loss: 0.9989 | NRF Loss: 1.4158 | Joint: 2.4147 | Val Acc: 0.8717
# Epoch 1050 | GCN Loss: 0.9711 | NRF Loss: 1.3695 | Joint: 2.3406 | Val Acc: 0.8717
# Epoch 1100 | GCN Loss: 0.9457 | NRF Loss: 1.3262 | Joint: 2.2719 | Val Acc: 0.8733
# Epoch 1150 | GCN Loss: 0.9222 | NRF Loss: 1.2846 | Joint: 2.2068 | Val Acc: 0.8683
# Epoch 1200 | GCN Loss: 0.9006 | NRF Loss: 1.2459 | Joint: 2.1465 | Val Acc: 0.8767
# Epoch 1250 | GCN Loss: 0.8807 | NRF Loss: 1.2090 | Joint: 2.0897 | Val Acc: 0.8750
# Epoch 1300 | GCN Loss: 0.8622 | NRF Loss: 1.1739 | Joint: 2.0362 | Val Acc: 0.8717
# Epoch 1350 | GCN Loss: 0.8450 | NRF Loss: 1.1404 | Joint: 1.9854 | Val Acc: 0.8733
# Epoch 1400 | GCN Loss: 0.8290 | NRF Loss: 1.1089 | Joint: 1.9380 | Val Acc: 0.8767
# Epoch 1450 | GCN Loss: 0.8140 | NRF Loss: 1.0791 | Joint: 1.8931 | Val Acc: 0.8783
# Epoch 1500 | GCN Loss: 0.7999 | NRF Loss: 1.0514 | Joint: 1.8513 | Val Acc: 0.8733
# Epoch 1550 | GCN Loss: 0.7866 | NRF Loss: 1.0244 | Joint: 1.8111 | Val Acc: 0.8783
# Epoch 1600 | GCN Loss: 0.7740 | NRF Loss: 1.0003 | Joint: 1.7743 | Val Acc: 0.8833
# Epoch 1650 | GCN Loss: 0.7621 | NRF Loss: 0.9758 | Joint: 1.7380 | Val Acc: 0.8800
# Epoch 1700 | GCN Loss: 0.7509 | NRF Loss: 0.9537 | Joint: 1.7046 | Val Acc: 0.8833
# Epoch 1750 | GCN Loss: 0.7403 | NRF Loss: 0.9319 | Joint: 1.6723 | Val Acc: 0.8833
# Epoch 1800 | GCN Loss: 0.7303 | NRF Loss: 0.9117 | Joint: 1.6420 | Val Acc: 0.8850
# Epoch 1850 | GCN Loss: 0.7206 | NRF Loss: 0.8923 | Joint: 1.6129 | Val Acc: 0.8883
# Epoch 1900 | GCN Loss: 0.7114 | NRF Loss: 0.8743 | Joint: 1.5857 | Val Acc: 0.8933
# Epoch 1950 | GCN Loss: 0.7025 | NRF Loss: 0.8563 | Joint: 1.5588 | Val Acc: 0.8900
# Epoch 2000 | GCN Loss: 0.6940 | NRF Loss: 0.8402 | Joint: 1.5342 | Val Acc: 0.8917
# Epoch 2050 | GCN Loss: 0.6858 | NRF Loss: 0.8247 | Joint: 1.5105 | Val Acc: 0.8883
# Epoch 2100 | GCN Loss: 0.6778 | NRF Loss: 0.8096 | Joint: 1.4874 | Val Acc: 0.8900
# Epoch 2150 | GCN Loss: 0.6701 | NRF Loss: 0.7961 | Joint: 1.4662 | Val Acc: 0.8867
# Epoch 2200 | GCN Loss: 0.6626 | NRF Loss: 0.7819 | Joint: 1.4446 | Val Acc: 0.8917
# Epoch 2250 | GCN Loss: 0.6553 | NRF Loss: 0.7694 | Joint: 1.4247 | Val Acc: 0.8900
# Epoch 2300 | GCN Loss: 0.6482 | NRF Loss: 0.7579 | Joint: 1.4061 | Val Acc: 0.8933
# Epoch 2350 | GCN Loss: 0.6412 | NRF Loss: 0.7456 | Joint: 1.3868 | Val Acc: 0.8917
# Epoch 2400 | GCN Loss: 0.6344 | NRF Loss: 0.7348 | Joint: 1.3691 | Val Acc: 0.8917
# Epoch 2450 | GCN Loss: 0.6277 | NRF Loss: 0.7244 | Joint: 1.3521 | Val Acc: 0.8967
# Early stopping at epoch 2489
# Best validation acc: 0.9000 @ epoch 2189
# Evaluating on test set using semi-transductive/inductive logic...
# 0.8866667151451111

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.8866667151451111, 'epoch': 634, 'y_pred': ['Tehrik-i-Taliban Pakistan (TTP)', 'Palestinians', 'Palestinians', 'Palestinians', "New People's Army (NPA)", 'Taliban', 'National Liberation Army of Colombia (ELN)', 'Revolutionary Armed Forces of Colombia (FARC)', "New People's Army (NPA)", 'African National Congress (South Africa)', 'Palestinians', 'Nicaraguan Democratic Force (FDN)', 'Corsican National Liberation Front (FLNC)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Houthi extremists (Ansar Allah)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Boko Haram', 'Boko Haram', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Taliban', 'Shining Path (SL)', 'Sikh Extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'Boko Haram', 'Nicaraguan Democratic Force (FDN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'National Liberation Army of Colombia (ELN)', 'Abu Sayyaf Group (ASG)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Taliban', 'Irish Republican Army (IRA)', 'Abu Sayyaf Group (ASG)', "Donetsk People's Republic", 'Corsican National Liberation Front (FLNC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Boko Haram', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Irish Republican Army (IRA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Maoists', 'Irish Republican Army (IRA)', 'Taliban', 'Shining Path (SL)', "Kurdistan Workers' Party (PKK)", 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Islamic State of Iraq and the Levant (ISIL)', 'Maoists', 'Al-Qaida in Iraq', 'Houthi extremists (Ansar Allah)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Muslim extremists', 'Palestinians', 'Farabundo Marti National Liberation Front (FMLN)', "New People's Army (NPA)", 'Houthi extremists (Ansar Allah)', 'Irish Republican Army (IRA)', "New People's Army (NPA)", 'Maoists', 'Farabundo Marti National Liberation Front (FMLN)', 'Shining Path (SL)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Sikh Extremists', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Irish Republican Army (IRA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Al-Shabaab', "New People's Army (NPA)", 'Corsican National Liberation Front (FLNC)', 'Abu Sayyaf Group (ASG)', 'Muslim extremists', 'Taliban', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'Maoists', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Boko Haram', "Donetsk People's Republic", "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)' ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
