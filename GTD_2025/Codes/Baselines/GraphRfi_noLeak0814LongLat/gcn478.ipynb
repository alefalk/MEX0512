# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 478

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#{'lr': 0.01, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd478', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Dataset: gtd478
 # Hidden Dim: 768
#  n_tree: 50, tree_depth: 13, tree_feature_rate: 0.1
#  Batch size: 512, Dropout: 0.2, LR: 0.01
param_grid = {
    'lr': [0.01],
    'n_tree': [50],
    'tree_depth': [13],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.2],
    'embed_dim': [32, 64]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 2)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# tensor(4200)
# tensor(1743)
# tensor(1719)
# tensor(12101)
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 13, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 46
#      37 args = {
#      38     **dict(zip(param_names, combo)),
#      39     'partition': f"gtd{partition}",
#    (...)
#      42     'final_evaluation': True
#      43 }
#      45 print(f"Running config: {args}")
# ---> 46 acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
#      47     combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask,
#      48     args, row_to_node_index, index_to_label, verbose=True)
#      50 if acc > best_score:
#      51     best_score = acc
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0814LongLat/haversine_build_graph_and_train.py:280, in train_joint(df, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask, args, row_to_node_index, index_to_label, verbose)
#     277 # NRF only sees TRAIN rows
#     278 input_features_train = torch.cat([non_geo_features[row_train_mask],
#     279                                   emb_per_row[row_train_mask]], dim=1)
# --> 280 out_forest_train = neural_forest(input_features_train)
#     282 # Losses
#     283 loss1 = F.cross_entropy(pred_nodes[train_mask], y_gcn[train_mask])   # node-level CE
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0814LongLat/ndf.py:241, in NeuralDecisionForest.forward(self, x)
#     239 out = self.feature_layer(x)
#     240 out = out.view(x.size()[0], -1)
# --> 241 out = self.forest(out)
#     242 return out
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0814LongLat/ndf.py:224, in Forest.forward(self, x)
#     222 probs = []
#     223 for tree in self.trees:
# --> 224     mu = tree(x)
#     225     p=tree.cal_prob(mu,tree.get_pi())
#     226     probs.append(p.unsqueeze(2))
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0814LongLat/ndf.py:167, in Tree.forward(self, x)
#     164     self.feature_mask = self.feature_mask.cuda()
#     166 feats = torch.mm(x,self.feature_mask) # ->[batch_size,n_used_feature]
# --> 167 decision = self.decision(feats) # ->[batch_size,n_leaf]
#     169 decision = torch.unsqueeze(decision,dim=2)
#     170 decision_comp = 1-decision
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/activation.py:292, in Sigmoid.forward(self, input)
#     291 def forward(self, input: Tensor) -> Tensor:
# --> 292     return torch.sigmoid(input)
#
# RuntimeError: NVML_SUCCESS == r INTERNAL ASSERT FAILED at "../c10/cuda/CUDACachingAllocator.cpp":844, please report a bug to PyTorch.

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd478', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.8652778267860413, 'epoch': 2967, 'y_pred': ['Shining Path (SL)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'National Liberation Army of Colombia (ELN)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Shining Path (SL)', 'Shining Path (SL)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', 'Irish Republican Army (IRA)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Shining Path (SL)', 'Shining Path (SL)', "Kurdistan Workers' Party (PKK)", "Kurdistan Workers' Party (PKK)", 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'National Liberation Army of Colombia (ELN)', 'Basque Fatherland and Freedom (ETA)', 'National Liberation Army of Colombia (ELN)', "Kurdistan Workers' Party (PKK)", 'Irish Republican Army (IRA)', "Kurdistan Workers' Party (PKK)", 'African National Congress (South Africa)', "Kurdistan Workers' Party (PKK)", 'National Liberation Army of Colombia (ELN)', "New People's Army (NPA)", "Kurdistan Workers' Party (PKK)", 'African National Congress (South Africa)', 'Taliban', 'Taliban', "Kurdistan Workers' Party (PKK)", 'Palestinians', 'Palestinians', 'African National Congress (South Africa)', 'Palestinians', "Kurdistan Workers' Party (PKK)", 'Basque Fatherland and Freedom (ETA)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Nicaraguan Democratic Force (FDN)', 'Nicaraguan Democratic Force (FDN)', "New People's Army (NPA)", 'National Liberation Army of Colombia (ELN)', "Kurdistan Workers' Party (PKK)", 'Basque Fatherland and Freedom (ETA)', "New People's Army (NPA)", 'Palestinians', 'Nicaraguan Democratic Force (FDN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', 'Al-Shabaab', 'Liberation Tigers of Tamil Eelam (LTTE)', "Kurdistan Workers' Party (PKK)", 'Muslim extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', 'Taliban', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Nicaraguan Democratic Force (FDN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Sikh Extremists', 'Shining Path (SL)', 'Shining Path (SL)', 'Shining Path (SL)', 'Basque Fatherland and Freedom (ETA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Islamic State of Iraq and the Levant (ISIL)', 'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Shining Path (SL)', 'Shining Path (SL)', 'Al-Qaida in Iraq', "New People's Army (NPA)", 'Shining Path (SL)', 'African National Congress (South Africa)', 'Al-Shabaab', 'Shining Path (SL)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Islamic State of Iraq and  ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
