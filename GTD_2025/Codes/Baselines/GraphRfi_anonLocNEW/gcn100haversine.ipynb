# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
param_grid = {
    'lr': [0.001],
    'n_tree': [100],
    'tree_depth': [10],
    'tree_feature_rate': [0.5],
    'feat_dropout': [0.1],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, nrf_input, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            data, edge_index_full, y_gcn, y_nrf, nrf_input,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 1943
# tensor(1220)
# tensor(463)
# tensor(466)
# tensor(2249)
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4000 | NRF Loss: 3.4012 | Joint: 6.8012 | Val Acc: 0.2234
# Epoch 050 | GCN Loss: 3.1563 | NRF Loss: 3.1952 | Joint: 6.3514 | Val Acc: 0.2895
# Epoch 100 | GCN Loss: 2.5454 | NRF Loss: 3.0117 | Joint: 5.5571 | Val Acc: 0.3936
# Epoch 150 | GCN Loss: 1.7288 | NRF Loss: 2.8490 | Joint: 4.5778 | Val Acc: 0.4734
# Epoch 200 | GCN Loss: 0.9662 | NRF Loss: 2.6986 | Joint: 3.6648 | Val Acc: 0.5068
# Epoch 250 | GCN Loss: 0.4897 | NRF Loss: 2.5626 | Joint: 3.0523 | Val Acc: 0.5441
# Epoch 300 | GCN Loss: 0.2673 | NRF Loss: 2.4394 | Joint: 2.7067 | Val Acc: 0.5631
# Epoch 350 | GCN Loss: 0.1655 | NRF Loss: 2.3266 | Joint: 2.4921 | Val Acc: 0.5760
# Epoch 400 | GCN Loss: 0.1126 | NRF Loss: 2.2228 | Joint: 2.3354 | Val Acc: 0.5859
# Epoch 450 | GCN Loss: 0.0815 | NRF Loss: 2.1257 | Joint: 2.2072 | Val Acc: 0.5965
# Epoch 500 | GCN Loss: 0.0618 | NRF Loss: 2.0345 | Joint: 2.0962 | Val Acc: 0.6018
# Epoch 550 | GCN Loss: 0.0485 | NRF Loss: 1.9489 | Joint: 1.9974 | Val Acc: 0.6087
# Epoch 600 | GCN Loss: 0.0392 | NRF Loss: 1.8683 | Joint: 1.9075 | Val Acc: 0.6117
# Epoch 650 | GCN Loss: 0.0324 | NRF Loss: 1.7927 | Joint: 1.8252 | Val Acc: 0.6125
# Epoch 700 | GCN Loss: 0.0273 | NRF Loss: 1.7218 | Joint: 1.7492 | Val Acc: 0.6170
# Epoch 750 | GCN Loss: 0.0234 | NRF Loss: 1.6546 | Joint: 1.6780 | Val Acc: 0.6193
# Epoch 800 | GCN Loss: 0.0203 | NRF Loss: 1.5910 | Joint: 1.6112 | Val Acc: 0.6201
# Epoch 850 | GCN Loss: 0.0177 | NRF Loss: 1.5310 | Joint: 1.5487 | Val Acc: 0.6216
# Epoch 900 | GCN Loss: 0.0157 | NRF Loss: 1.4747 | Joint: 1.4904 | Val Acc: 0.6239
# Epoch 950 | GCN Loss: 0.0140 | NRF Loss: 1.4214 | Joint: 1.4354 | Val Acc: 0.6261
# Epoch 1000 | GCN Loss: 0.0125 | NRF Loss: 1.3715 | Joint: 1.3841 | Val Acc: 0.6292
# Epoch 1050 | GCN Loss: 0.0113 | NRF Loss: 1.3249 | Joint: 1.3362 | Val Acc: 0.6284
# Epoch 1100 | GCN Loss: 0.0102 | NRF Loss: 1.2807 | Joint: 1.2910 | Val Acc: 0.6277
# Epoch 1150 | GCN Loss: 0.0093 | NRF Loss: 1.2392 | Joint: 1.2485 | Val Acc: 0.6299
# Epoch 1200 | GCN Loss: 0.0085 | NRF Loss: 1.1998 | Joint: 1.2084 | Val Acc: 0.6284
# Epoch 1250 | GCN Loss: 0.0078 | NRF Loss: 1.1629 | Joint: 1.1707 | Val Acc: 0.6299
# Epoch 1300 | GCN Loss: 0.0072 | NRF Loss: 1.1279 | Joint: 1.1351 | Val Acc: 0.6337
# Epoch 1350 | GCN Loss: 0.0067 | NRF Loss: 1.0947 | Joint: 1.1014 | Val Acc: 0.6322
# Epoch 1400 | GCN Loss: 0.0062 | NRF Loss: 1.0634 | Joint: 1.0695 | Val Acc: 0.6322
# Epoch 1450 | GCN Loss: 0.0057 | NRF Loss: 1.0339 | Joint: 1.0396 | Val Acc: 0.6330
# Epoch 1500 | GCN Loss: 0.0054 | NRF Loss: 1.0061 | Joint: 1.0115 | Val Acc: 0.6337
# Epoch 1550 | GCN Loss: 0.0050 | NRF Loss: 0.9801 | Joint: 0.9851 | Val Acc: 0.6353
# Epoch 1600 | GCN Loss: 0.0047 | NRF Loss: 0.9553 | Joint: 0.9600 | Val Acc: 0.6353
# Epoch 1650 | GCN Loss: 0.0044 | NRF Loss: 0.9317 | Joint: 0.9361 | Val Acc: 0.6330
# Epoch 1700 | GCN Loss: 0.0041 | NRF Loss: 0.9094 | Joint: 0.9135 | Val Acc: 0.6345
# Epoch 1750 | GCN Loss: 0.0039 | NRF Loss: 0.8879 | Joint: 0.8918 | Val Acc: 0.6337
# Epoch 1800 | GCN Loss: 0.0037 | NRF Loss: 0.8678 | Joint: 0.8714 | Val Acc: 0.6360
# Epoch 1850 | GCN Loss: 0.0034 | NRF Loss: 0.8488 | Joint: 0.8522 | Val Acc: 0.6360
# Epoch 1900 | GCN Loss: 0.0033 | NRF Loss: 0.8307 | Joint: 0.8340 | Val Acc: 0.6383
# Epoch 1950 | GCN Loss: 0.0031 | NRF Loss: 0.8137 | Joint: 0.8168 | Val Acc: 0.6398
# Epoch 2000 | GCN Loss: 0.0029 | NRF Loss: 0.7975 | Joint: 0.8004 | Val Acc: 0.6391
# Epoch 2050 | GCN Loss: 0.0028 | NRF Loss: 0.7821 | Joint: 0.7848 | Val Acc: 0.6391
# Epoch 2100 | GCN Loss: 0.0026 | NRF Loss: 0.7672 | Joint: 0.7699 | Val Acc: 0.6383
# Epoch 2150 | GCN Loss: 0.0025 | NRF Loss: 0.7531 | Joint: 0.7556 | Val Acc: 0.6391
# Epoch 2200 | GCN Loss: 0.0024 | NRF Loss: 0.7398 | Joint: 0.7422 | Val Acc: 0.6375
# Early stopping at epoch 2210
# Best validation acc: 0.6406 @ epoch 1910
# Evaluating on test set using full graph...
# 0.6392128467559814

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.6392128467559814, 'epoch': 1910, 'y_pred': ['Maoists', 'Nicaraguan Democratic Force (FDN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'Corsican National Liberation Front (FLNC)', 'Islamic State of Iraq and the Levant (ISIL)', 'Fulani extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Taliban', 'Nicaraguan Democratic Force (FDN)', 'Abu Sayyaf Group (ASG)', 'Boko Haram', "Kurdistan Workers' Party (PKK)", 'Corsican National Liberation Front (FLNC)', 'Taliban', 'Al-Qaida in Iraq', 'Muslim extremists', 'Nicaraguan Democratic Force (FDN)', 'Nicaraguan Democratic Force (FDN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', "New People's Army (NPA)", 'Boko Haram', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in Iraq', 'Nicaraguan Democratic Force (FDN)', 'Muslim extremists', 'Boko Haram', 'Boko Haram', 'Tehrik-i-Taliban Pakistan (TTP)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'Al-Qaida in Iraq', "Donetsk People's Republic", "Kurdistan Workers' Party (PKK)", "Kurdistan Workers' Party (PKK)", 'Al-Shabaab', 'Al-Qaida in Iraq', 'Fulani extremists', 'Corsican National Liberation Front (FLNC)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Islamic State of Iraq and the Levant (ISIL)', 'Taliban', 'Abu Sayyaf Group (ASG)', 'Al-Shabaab', "Donetsk People's Republic", 'Maoists', 'Corsican National Liberation Front (FLNC)', 'Maoists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Muslim extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Shabaab', 'Boko Haram', 'Fulani extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'Nicaraguan Democratic Force (FDN)', 'Maoists', 'Maoists', 'Taliban', "Kurdistan Workers' Party (PKK)", 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'Maoists', 'Fulani extremists', 'Sikh Extremists', 'Corsican National Liberation Front (FLNC)', 'Fulani extremists', 'Shining Path (SL)', 'Maoists', "New People's Army (NPA)", 'Al-Shabaab', 'Islamic State of Iraq and the Levant (ISIL)', 'Nicaraguan Democratic Force (FDN)', 'Boko Haram', 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Fulani extremists', 'Fulani extremists', 'Corsican National Liberation Front (FLNC)', 'Fulani extremists', 'Al-Shabaab', 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Taliban', 'Houthi extremists (Ansar Allah)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'National Liberation Army of Colombia (ELN)', 'Al-Shabaab', 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", "New People's Army (NPA)", 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Shabaab', "Donetsk People's Republic", 'Palestinians', 'Taliban', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'National Liberation Army of Colombia (ELN)', 'Maoists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Abu Sayyaf Group (ASG)', 'Muslim extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'Fulani extremists', 'Abu Sayyaf Group (ASG)', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Nicaraguan Democratic Force (FDN)', 'Maoists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'Corsican National Liberation Front (FLNC)', ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# '\nBest acc: 0.9205 at epoch 750 for weaptype1 prediction\nWeighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191\nMacro Precision: 0.9176, Recall: 0.9107, F1: 0.9105\nMicro Precision: 0.9205, Recall: 0.9205, F1: 0.9205\nAUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963\n\n'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.98      0.93      0.95        43
#         African National Congress (South Africa)       0.98      1.00      0.99        58
#                                 Al-Qaida in Iraq       1.00      0.79      0.88        87
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.98      0.92      0.95        50
#                                       Al-Shabaab       1.00      1.00      1.00        58
#              Basque Fatherland and Freedom (ETA)       0.98      0.90      0.94        60
#                                       Boko Haram       0.93      0.95      0.94        41
#   Communist Party of India - Maoist (CPI-Maoist)       1.00      0.92      0.96        24
#        Corsican National Liberation Front (FLNC)       0.97      0.96      0.97        78
#                        Donetsk People's Republic       1.00      1.00      1.00        59
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.85      0.92        55
#                                Fulani extremists       0.93      0.89      0.91        28
#                  Houthi extremists (Ansar Allah)       0.95      0.96      0.96        57
#                      Irish Republican Army (IRA)       0.95      1.00      0.97        71
#      Islamic State of Iraq and the Levant (ISIL)       0.65      0.93      0.76        40
#                   Kurdistan Workers' Party (PKK)       0.93      0.87      0.90        30
#          Liberation Tigers of Tamil Eelam (LTTE)       0.98      0.96      0.97        45
#          Manuel Rodriguez Patriotic Front (FPMR)       0.99      1.00      0.99        77
#                                          Maoists       0.92      0.96      0.94        25
#                                Muslim extremists       0.76      0.97      0.85        30
#       National Liberation Army of Colombia (ELN)       0.94      0.90      0.92        51
#                          New People's Army (NPA)       0.81      0.94      0.87        18
#                Nicaraguan Democratic Force (FDN)       0.67      0.94      0.78        17
#                                     Palestinians       0.98      0.97      0.98        65
#    Revolutionary Armed Forces of Colombia (FARC)       0.85      0.88      0.86        32
#                                Shining Path (SL)       0.79      0.98      0.87        46
#                                  Sikh Extremists       0.97      0.98      0.97        57
#                                          Taliban       0.59      0.73      0.65        22
#                  Tehrik-i-Taliban Pakistan (TTP)       0.90      0.83      0.87        54
#        Tupac Amaru Revolutionary Movement (MRTA)       0.99      0.86      0.92        96
#
#                                         accuracy                           0.93      1474
#                                        macro avg       0.91      0.93      0.92      1474
#                                     weighted avg       0.94      0.93      0.93      1474

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Saved confusion matrix for partition 100 to Results100/cm_100_weaptype1.png
