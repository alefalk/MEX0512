# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
param_grid = {
    'lr': [0.001],
    'n_tree': [40, 80],
    'tree_depth': [8, 10],
    'tree_feature_rate': [0.1, 0.3, 0.5],
    'feat_dropout': [0.0, 0.1, 0.2],
    'embed_dim': [32, 64]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1500,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        try:
            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
                data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask,
                args, row_to_node_index, index_to_label, verbose=False)

            if acc > best_score:
                best_score = acc
                best_run = {
                    "args": args,
                    "acc": acc,
                    "epoch": epoch,
                    "y_pred": y_pred_decoded,
                    "y_true": y_true_decoded,
                    "precision": p,
                    "recall": r,
                    "f1": f1,
                    "micro": (p_micro, r_micro, f1_micro),
                    "macro": (p_macro, r_macro, f1_macro),
                    "auroc": (auc_w, auc_mi, auc_ma),
                    "epoch_logs": epoch_logs
                }
        except Exception as e:
            print(f"Error with config {args}: {e}")
            continue

    # Save best results
    if best_run:
        best_args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {best_args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.8760 @ epoch 1496
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9051 @ epoch 1495
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1352
# Best validation acc: 0.8959 @ epoch 1252
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1499
# Best validation acc: 0.8969 @ epoch 1399
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1289
# Best validation acc: 0.8914 @ epoch 1189
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1471
# Best validation acc: 0.8942 @ epoch 1371
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1270
# Best validation acc: 0.9067 @ epoch 1170
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1238
# Best validation acc: 0.9113 @ epoch 1138
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 930
# Best validation acc: 0.9023 @ epoch 830
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1062
# Best validation acc: 0.9119 @ epoch 962
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1274
# Best validation acc: 0.9109 @ epoch 1174
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1174
# Best validation acc: 0.9087 @ epoch 1074
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1327
# Best validation acc: 0.9127 @ epoch 1227
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 584
# Best validation acc: 0.8932 @ epoch 484
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 743
# Best validation acc: 0.9067 @ epoch 643
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1222
# Best validation acc: 0.9224 @ epoch 1122
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1092
# Best validation acc: 0.9123 @ epoch 992
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 957
# Best validation acc: 0.9067 @ epoch 857
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 575
# Best validation acc: 0.8524 @ epoch 475
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1391
# Best validation acc: 0.9027 @ epoch 1291
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 495
# Best validation acc: 0.8398 @ epoch 395
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9083 @ epoch 1477
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 458
# Best validation acc: 0.8257 @ epoch 358
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9087 @ epoch 1488
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1481
# Best validation acc: 0.9186 @ epoch 1381
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1301
# Best validation acc: 0.9152 @ epoch 1201
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1290
# Best validation acc: 0.9200 @ epoch 1190
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1471
# Best validation acc: 0.9156 @ epoch 1371
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 814
# Best validation acc: 0.9101 @ epoch 714
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1149
# Best validation acc: 0.9154 @ epoch 1049
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 730
# Best validation acc: 0.9047 @ epoch 630
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 813
# Best validation acc: 0.9111 @ epoch 713
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 851
# Best validation acc: 0.9152 @ epoch 751
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1035
# Best validation acc: 0.9198 @ epoch 935
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 786
# Best validation acc: 0.9196 @ epoch 686
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9343 @ epoch 1489
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1352
# Best validation acc: 0.8973 @ epoch 1252
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.8969 @ epoch 1496
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1383
# Best validation acc: 0.8910 @ epoch 1283
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9003 @ epoch 1477
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.8999 @ epoch 1490
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1123
# Best validation acc: 0.8860 @ epoch 1023
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9127 @ epoch 1480
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 704
# Best validation acc: 0.8922 @ epoch 604
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9101 @ epoch 1477
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 961
# Best validation acc: 0.9059 @ epoch 861
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1490
# Best validation acc: 0.9127 @ epoch 1390
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1329
# Best validation acc: 0.9144 @ epoch 1229
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 772
# Best validation acc: 0.9097 @ epoch 672
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1191
# Best validation acc: 0.9156 @ epoch 1091
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1331
# Best validation acc: 0.9206 @ epoch 1231
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1204
# Best validation acc: 0.9200 @ epoch 1104
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1313
# Best validation acc: 0.9236 @ epoch 1213
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 660
# Best validation acc: 0.9009 @ epoch 560
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9085 @ epoch 1463
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9069 @ epoch 1495
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1280
# Best validation acc: 0.9097 @ epoch 1180
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9093 @ epoch 1477
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9007 @ epoch 1499
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9019 @ epoch 1475
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1349
# Best validation acc: 0.9148 @ epoch 1249
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Best validation acc: 0.9242 @ epoch 1401
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 870
# Best validation acc: 0.9047 @ epoch 770
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1068
# Best validation acc: 0.9113 @ epoch 968
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1411
# Best validation acc: 0.9178 @ epoch 1311
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1035
# Best validation acc: 0.9113 @ epoch 935
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1268
# Best validation acc: 0.9210 @ epoch 1168
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1312
# Best validation acc: 0.9184 @ epoch 1212
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1179
# Best validation acc: 0.9230 @ epoch 1079
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1134
# Best validation acc: 0.9244 @ epoch 1034
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 811
# Best validation acc: 0.9117 @ epoch 711
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1091
# Best validation acc: 0.9154 @ epoch 991
# 0.9343414306640625

# %%
"""
Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
Best validation acc: 0.9343 @ epoch 1489
"""

# %%
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
#0.9300

# %%
final_args = best_run['args'].copy()
final_args['epochs'] = 3000
final_args['final_evaluation'] = True

print("\nRunning final evaluation with best config:")
print(final_args)

data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
    combined_geo, label_index, continuous_col=continuous_cols[0])

# Run final training and testing
final_acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
    data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask,
    final_args, row_to_node_index, index_to_label, verbose=True)

print(f"\nTest Accuracy: {final_acc:.4f}")
# Out:
# Running final evaluation with best config:
# {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 1.0887 | NRF Loss: 3.4011 | Joint: 4.4898 | Val Acc: 0.4192
# Epoch 050 | GCN Loss: 1.0555 | NRF Loss: 3.0593 | Joint: 4.1148 | Val Acc: 0.6058
# Epoch 100 | GCN Loss: 1.0448 | NRF Loss: 2.8701 | Joint: 3.9149 | Val Acc: 0.7748
# Epoch 150 | GCN Loss: 1.0379 | NRF Loss: 2.7182 | Joint: 3.7562 | Val Acc: 0.8247
# Epoch 200 | GCN Loss: 1.0317 | NRF Loss: 2.5814 | Joint: 3.6131 | Val Acc: 0.8472
# Epoch 250 | GCN Loss: 1.0252 | NRF Loss: 2.4561 | Joint: 3.4813 | Val Acc: 0.8609
# Epoch 300 | GCN Loss: 1.0191 | NRF Loss: 2.3414 | Joint: 3.3605 | Val Acc: 0.8739
# Epoch 350 | GCN Loss: 1.0142 | NRF Loss: 2.2358 | Joint: 3.2501 | Val Acc: 0.8858
# Epoch 400 | GCN Loss: 1.0099 | NRF Loss: 2.1366 | Joint: 3.1465 | Val Acc: 0.8928
# Epoch 450 | GCN Loss: 1.0065 | NRF Loss: 2.0435 | Joint: 3.0500 | Val Acc: 0.8981
# Epoch 500 | GCN Loss: 1.0036 | NRF Loss: 1.9566 | Joint: 2.9602 | Val Acc: 0.9063
# Epoch 550 | GCN Loss: 1.0012 | NRF Loss: 1.8743 | Joint: 2.8756 | Val Acc: 0.9117
# Epoch 600 | GCN Loss: 0.9989 | NRF Loss: 1.7969 | Joint: 2.7958 | Val Acc: 0.9135
# Epoch 650 | GCN Loss: 0.9968 | NRF Loss: 1.7232 | Joint: 2.7200 | Val Acc: 0.9170
# Epoch 700 | GCN Loss: 0.9947 | NRF Loss: 1.6534 | Joint: 2.6482 | Val Acc: 0.9176
# Epoch 750 | GCN Loss: 0.9928 | NRF Loss: 1.5874 | Joint: 2.5802 | Val Acc: 0.9180
# Epoch 800 | GCN Loss: 0.9910 | NRF Loss: 1.5247 | Joint: 2.5157 | Val Acc: 0.9146
# Early stopping at epoch 850
# Best validation acc: 0.9180 @ epoch 750
# Evaluating on test set using full graph...
#
# Test Accuracy: 0.9161

# %%
import os
import json

# Create results directory
os.makedirs(f"Results{partition}", exist_ok=True)

# Save metrics and config
results_path = f"Results{partition}/FinalResults_{continuous_cols[0]}_prediction.txt"
with open(results_path, "w") as f:
    f.write(f"Final Test Accuracy: {final_acc:.4f} at epoch {epoch} for {continuous_cols[0]} prediction\n")
    f.write(f"Final Config: {final_args}\n\n")
    f.write(f"Weighted Precision: {p:.4f}, Recall: {r:.4f}, F1: {f1:.4f}\n")
    f.write(f"Macro Precision: {p_macro:.4f}, Recall: {r_macro:.4f}, F1: {f1_macro:.4f}\n")
    f.write(f"Micro Precision: {p_micro:.4f}, Recall: {r_micro:.4f}, F1: {f1_micro:.4f}\n")
    f.write(f"AUROC Weighted: {auc_w:.4f}, Micro: {auc_mi:.4f}, Macro: {auc_ma:.4f}\n")


# Save predictions
with open(f"Results{partition}/FinalPredictions_{continuous_cols[0]}.csv", "w") as f:
    f.write("predicted,true\n")
    for pred, true in zip(y_pred_decoded, y_true_decoded):
        f.write(f"{pred},{true}\n")

# Save epoch logs
with open(f"Results{partition}/FinalEpochLogs_{continuous_cols[0]}.txt", "w") as f:
    f.write('\n'.join(f"{x:.4f}" for x in epoch_logs))

print("✅ Final evaluation results saved.")
# Out:
# ✅ Final evaluation results saved.

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}, 'acc': 0.9343414306640625, 'epoch': 1489, 'y_pred': ['Tupac Amaru Revolutionary Movement (MRTA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', 'Muslim extremists', 'Muslim extremists', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', "Donetsk People's Republic", 'Fulani extremists', 'Abu Sayyaf Group (ASG)', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", 'Abu Sayyaf Group (ASG)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Basque Fatherland and Freedom (ETA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Muslim extremists', "Donetsk People's Republic", 'Boko Haram', 'African National Congress (South Africa)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Shabaab', 'Sikh Extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Shabaab', 'Palestinians', 'Al-Qaida in Iraq', 'Irish Republican Army (IRA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Basque Fatherland and Freedom (ETA)', 'Houthi extremists (Ansar Allah)', 'Al-Qaida in Iraq', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Shabaab', 'Shining Path (SL)', 'Corsican National Liberation Front (FLNC)', 'Shining Path (SL)', 'Shining Path (SL)', 'Basque Fatherland and Freedom (ETA)', 'Farabundo Marti National Liberation Front (FMLN)', 'African National Congress (South Africa)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Muslim extremists', 'Basque Fatherland and Freedom (ETA)', 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Donetsk People's Republic", "Donetsk People's Republic", 'Tehrik-i-Taliban Pakistan (TTP)', 'Fulani extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Islamic State of Iraq and the Levant (ISIL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Farabundo Marti National Liberation Front (FMLN)', 'African National Congress (South Africa)', 'Farabundo Marti National Liberation Front (FMLN)', "Donetsk People's Republic", 'Sikh Extremists', 'Shining Path (SL)', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Palestinians', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Irish Republican Army (IRA)', 'Fulani extremists', 'Al-Shabaab', 'Palestinians', 'Muslim extremists', 'Nicaraguan Democratic Force (FDN)', "Donetsk People's Republic", 'Tehrik-i-Taliban Pakistan (TTP)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Houthi extremists (Ansar Allah)', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Palestinians', 'National Liberation Army of Colombia (ELN)', 'Sikh Extremists', 'Corsican National Liberation Front (FLNC)', 'Muslim extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Abu Sayyaf Group (ASG)', 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', "Donetsk People's Republic", 'Al-Shabaab', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Al-Qaida in Iraq', 'Tupac Amaru Revolutionary  ...

# %%
print(best_run['args'])
# Out:
# {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_score
# Out:
# 0.9343414306640625

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# '\nBest acc: 0.9205 at epoch 750 for weaptype1 prediction\nWeighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191\nMacro Precision: 0.9176, Recall: 0.9107, F1: 0.9105\nMicro Precision: 0.9205, Recall: 0.9205, F1: 0.9205\nAUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963\n\n'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_preds[-1], y_trues[-1]))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.99      0.96      0.98       159
#         African National Congress (South Africa)       0.99      1.00      1.00       181
#                                 Al-Qaida in Iraq       0.95      0.78      0.86       287
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.98      0.84      0.90       235
#                                       Al-Shabaab       1.00      1.00      1.00       200
#              Basque Fatherland and Freedom (ETA)       0.97      1.00      0.98       189
#                                       Boko Haram       0.99      0.97      0.98       124
#   Communist Party of India - Maoist (CPI-Maoist)       0.98      0.94      0.96       104
#        Corsican National Liberation Front (FLNC)       1.00      0.97      0.99       248
#                        Donetsk People's Republic       1.00      1.00      1.00       214
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.89      0.94       177
#                                Fulani extremists       0.96      0.99      0.97        97
#                  Houthi extremists (Ansar Allah)       0.81      0.97      0.88       157
#                      Irish Republican Army (IRA)       1.00      1.00      1.00       222
#      Islamic State of Iraq and the Levant (ISIL)       0.62      0.88      0.73       113
#                   Kurdistan Workers' Party (PKK)       0.97      0.97      0.97        93
#          Liberation Tigers of Tamil Eelam (LTTE)       1.00      0.97      0.98       169
#          Manuel Rodriguez Patriotic Front (FPMR)       1.00      1.00      1.00       266
#                                          Maoists       0.95      0.96      0.96        84
#                                Muslim extremists       0.88      0.93      0.90       149
#       National Liberation Army of Colombia (ELN)       0.97      0.88      0.92       169
#                          New People's Army (NPA)       0.91      0.97      0.94        72
#                Nicaraguan Democratic Force (FDN)       0.84      1.00      0.91       102
#                                     Palestinians       0.96      1.00      0.98       216
#    Revolutionary Armed Forces of Colombia (FARC)       0.81      0.96      0.88        93
#                                Shining Path (SL)       0.89      0.86      0.88       201
#                                  Sikh Extremists       0.97      0.98      0.97       179
#                                          Taliban       0.68      0.68      0.68        96
#                  Tehrik-i-Taliban Pakistan (TTP)       0.82      0.82      0.82       173
#        Tupac Amaru Revolutionary Movement (MRTA)       0.90      0.91      0.91       257
#
#                                         accuracy                           0.93      5026
#                                        macro avg       0.93      0.94      0.93      5026
#                                     weighted avg       0.94      0.93      0.94      5026

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Saved confusion matrix for partition 300 to Results300/cm_300_weaptype1.png
