# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from build_graph_gname import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Weapon type prediction

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %%
torch.cuda.empty_cache()

# %%
import random


label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
param_grid = {
    'lr': [0.001],
    'n_tree': [80, 100],
    'tree_depth': [8, 10],
    'tree_feature_rate': [0.1, 0.3, 0.5],
    'feat_dropout': [0.0, 0.1],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product), then randomly sample 10
all_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

# Sample 10 random configurations from the full grid
random.seed(42)  # for reproducibility
grid_combos = random.sample(all_combos, k=20)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1
    best_args = None

    # -----------------------------
    # STAGE 1: Hyperparameter search
    # -----------------------------
    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1500,
            'final_evaluation': False  # <-- Only validate
        }

        print(f"[SEARCH] Trying config: {args}")
        
        acc, epoch, *_ = train_joint(
            data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=False)

        if acc > best_score:
            best_score = acc
            best_args = args.copy()


    # -----------------------------
    # STAGE 2: Final evaluation
    # -----------------------------
    if best_args:
        print(f"\n[FINAL] Retraining with best config from search: {best_args}")
        best_args['epochs'] = 3000
        best_args['final_evaluation'] = True

        try:
            acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
                data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask,
                best_args, row_to_node_index, index_to_label, verbose=False)

            best_run = {
                "args": best_args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }

        except Exception as e:
            print(f"Error during final evaluation with config {best_args}: {e}")

    # -----------------------------
    # SAVE RESULTS
    # -----------------------------
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 831
# Best validation acc: 0.9235 @ epoch 731
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1063
# Best validation acc: 0.9235 @ epoch 963
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1034
# Best validation acc: 0.9001 @ epoch 934
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1014
# Best validation acc: 0.9283 @ epoch 914
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1264
# Best validation acc: 0.9090 @ epoch 1164
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 603
# Best validation acc: 0.8835 @ epoch 503
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1111
# Best validation acc: 0.9235 @ epoch 1011
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 675
# Best validation acc: 0.9283 @ epoch 575
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 947
# Best validation acc: 0.9242 @ epoch 847
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 979
# Best validation acc: 0.9256 @ epoch 879
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 751
# Best validation acc: 0.8863 @ epoch 651
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1259
# Best validation acc: 0.9283 @ epoch 1159
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1389
# Best validation acc: 0.9118 @ epoch 1289
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 616
# Best validation acc: 0.8429 @ epoch 516
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 774
# Best validation acc: 0.9249 @ epoch 674
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 904
# Best validation acc: 0.9263 @ epoch 804
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 809
# Best validation acc: 0.9263 @ epoch 709
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 701
# Best validation acc: 0.9187 @ epoch 601
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1094
# Best validation acc: 0.9345 @ epoch 994
# [SEARCH] Trying config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1094
# Best validation acc: 0.9008 @ epoch 994
#
# [FINAL] Retraining with best config from search: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Early stopping at epoch 1714
# Best validation acc: 0.9387 @ epoch 1414
# Evaluating on test set using full graph...
# 0.9345278739929199

# %%
"""
Best acc: 0.9355 at epoch 976 for weaptype1 prediction
Config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
Weighted Precision: 0.9333, Recall: 0.9276, F1: 0.9249
Macro Precision: 0.9307, Recall: 0.9050, F1: 0.9102
Micro Precision: 0.9276, Recall: 0.9276, F1: 0.9276
AUROC Weighted: 0.9980, Micro: 0.9984, Macro: 0.9976
"""
# Out:
# "\nBest acc: 0.9355 at epoch 976 for weaptype1 prediction\nConfig: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}\nWeighted Precision: 0.9333, Recall: 0.9276, F1: 0.9249\nMacro Precision: 0.9307, Recall: 0.9050, F1: 0.9102\nMicro Precision: 0.9276, Recall: 0.9276, F1: 0.9276\nAUROC Weighted: 0.9980, Micro: 0.9984, Macro: 0.9976\n"

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9375848174095154, 'epoch': 1414, 'y_pred': ['Shining Path (SL)', 'Revolutionary Armed Forces of Colombia (FARC)', 'African National Congress (South Africa)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Irish Republican Army (IRA)', 'Maoists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Corsican National Liberation Front (FLNC)', "Donetsk People's Republic", 'African National Congress (South Africa)', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Qaida in Iraq', 'Irish Republican Army (IRA)', 'Islamic State of Iraq and the Levant (ISIL)', 'African National Congress (South Africa)', 'Irish Republican Army (IRA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Sikh Extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'National Liberation Army of Colombia (ELN)', 'Corsican National Liberation Front (FLNC)', 'Muslim extremists', 'Muslim extremists', 'Abu Sayyaf Group (ASG)', 'Houthi extremists (Ansar Allah)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Corsican National Liberation Front (FLNC)', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Sikh Extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Farabundo Marti National Liberation Front (FMLN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Irish Republican Army (IRA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Shabaab', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Sikh Extremists', 'Basque Fatherland and Freedom (ETA)', 'Abu Sayyaf Group (ASG)', 'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)', 'Irish Republican Army (IRA)', 'Al-Shabaab', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Al-Qaida in Iraq', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Abu Sayyaf Group (ASG)', 'Palestinians', 'Palestinians', 'Al-Qaida in Iraq', 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Palestinians', 'Sikh Extremists', 'Palestinians', 'Sikh Extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Shining Path (SL)', 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Sikh Extremists', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'National Liberation Army of Colombia (ELN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'African National Congress (South Africa)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'National Liberation Army of Colombia (ELN)', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", 'Revolutionary Armed Forces of Colombia (FARC)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Farabundo Marti National Liberation F ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
