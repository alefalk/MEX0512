# %%
import sys
import os

sys.path.append(os.path.abspath("../Classifiers"))

from RF import *

# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,  f1_score, precision_score, recall_score

# %%
feature_type = "OneHotLongLatCombined"

# %%
if not os.path.isdir("Results"):
    os.mkdir("Results")
if not os.path.isdir(f"Results/{feature_type}"):
    os.mkdir(f"Results/{feature_type}")

# %% [markdown]
# ### Paths to top30 from GTD data

# %%
trains = ['train100', 'train200', 'train300', 'train478']
tests = ['test100', 'test200', 'test300', 'test478', ]
traindir = f'../../../../data/top30groups/{feature_type}/train1'
testdir = f'../../../../data/top30groups/{feature_type}/test1'

trainpaths = []
testpaths = []
for i, partition in enumerate(trains):
    trainpaths.append(f'{traindir}/{partition}.csv')
    testpaths.append(f'{testdir}/{tests[i]}.csv')

# %% [markdown]
# ### Training models and computing accuracy

# %%
models = []
accuracies = []
predictions = []
truths = []
probas = []
n = [100, 200, 300, 478]
train_times = []
for i, path in enumerate(trainpaths):
    print(f'Computing for partition {i+1}, balanced classes with {n[i]} entries for each class')

    # run classifier on data
    rfc, accuracy, y_pred_rfc, labels, proba, train_time = main(trainpaths[i], testpaths[i])

    #  saving models, accuracies, predictions, and truths in case we need it for statistics later
    models.append(rfc)
    accuracies.append(accuracy)
    predictions.append(y_pred_rfc)
    truths.append(labels)
    probas.append(proba)
    train_times.append(train_time)

    print("---------------------------------------------------")
# Out:
# Computing for partition 1, balanced classes with 100 entries for each class
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 45.67%
# ---------------------------------------------------
# Computing for partition 2, balanced classes with 200 entries for each class
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 48.61%
# ---------------------------------------------------
# Computing for partition 3, balanced classes with 300 entries for each class
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 51.07%
# ---------------------------------------------------
# Computing for partition 4, balanced classes with 478 entries for each class
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 56.41%
# ---------------------------------------------------

# %%
for i in range(len(truths)):
    print(f'Classification report size {n[i]}')
    print(classification_report(predictions[i], truths[i]))
    print('--------------------------------------')
# Out:
# Classification report size 100
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.57      0.38      0.45        45
#         African National Congress (South Africa)       0.50      0.52      0.51        29
#                                 Al-Qaida in Iraq       0.70      0.54      0.61        39
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.47      0.88      0.61        16
#                                       Al-Shabaab       0.43      0.93      0.59        14
#              Basque Fatherland and Freedom (ETA)       0.50      0.79      0.61        19
#                                       Boko Haram       0.20      1.00      0.33         6
#   Communist Party of India - Maoist (CPI-Maoist)       0.10      0.43      0.16         7
#        Corsican National Liberation Front (FLNC)       0.93      0.24      0.38       116
#                        Donetsk People's Republic       0.67      0.57      0.62        35
# Farabundo Marti National Liberation Front (FMLN)       0.30      0.90      0.45        10
#                                Fulani extremists       0.77      0.26      0.39        87
#                  Houthi extremists (Ansar Allah)       0.50      0.71      0.59        21
#                      Irish Republican Army (IRA)       0.67      0.71      0.69        28
#      Islamic State of Iraq and the Levant (ISIL)       0.30      0.21      0.25        43
#                   Kurdistan Workers' Party (PKK)       0.17      0.42      0.24        12
#          Liberation Tigers of Tamil Eelam (LTTE)       0.33      0.83      0.48        12
#          Manuel Rodriguez Patriotic Front (FPMR)       0.87      0.81      0.84        32
#                                          Maoists       0.20      0.27      0.23        22
#                                Muslim extremists       0.20      0.86      0.32         7
#       National Liberation Army of Colombia (ELN)       0.27      0.89      0.41         9
#                          New People's Army (NPA)       0.07      0.11      0.08        19
#                Nicaraguan Democratic Force (FDN)       0.70      0.26      0.38        82
#                                     Palestinians       0.83      0.56      0.67        45
#    Revolutionary Armed Forces of Colombia (FARC)       0.27      0.47      0.34        17
#                                Shining Path (SL)       0.20      0.60      0.30        10
#                                  Sikh Extremists       0.77      0.40      0.53        57
#                                          Taliban       0.07      0.40      0.11         5
#                  Tehrik-i-Taliban Pakistan (TTP)       0.27      0.50      0.35        16
#        Tupac Amaru Revolutionary Movement (MRTA)       0.90      0.68      0.77        40
#
#                                         accuracy                           0.46       900
#                                        macro avg       0.46      0.57      0.44       900
#                                     weighted avg       0.63      0.46      0.47       900
#
# --------------------------------------
# Classification report size 200
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.50      0.37      0.43        81
#         African National Congress (South Africa)       0.68      0.55      0.61        74
#                                 Al-Qaida in Iraq       0.67      0.48      0.56        83
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.32      0.95      0.47        20
#                                       Al-Shabaab       0.50      0.97      0.66        31
#              Basque Fatherland and Freedom (ETA)       0.48      1.00      0.65        29
#                                       Boko Haram       0.25      0.88      0.39        17
#   Communist Party of India - Maoist (CPI-Maoist)       0.08      0.71      0.15         7
#        Corsican National Liberation Front (FLNC)       0.98      0.29      0.45       202
#                        Donetsk People's Republic       0.70      0.46      0.56        91
# Farabundo Marti National Liberation Front (FMLN)       0.25      1.00      0.40        15
#                                Fulani extremists       0.78      0.30      0.43       157
#                  Houthi extremists (Ansar Allah)       0.48      0.45      0.46        65
#                      Irish Republican Army (IRA)       0.77      0.69      0.72        67
#      Islamic State of Iraq and the Levant (ISIL)       0.32      0.28      0.30        68
#                   Kurdistan Workers' Party (PKK)       0.05      1.00      0.10         3
#          Liberation Tigers of Tamil Eelam (LTTE)       0.38      0.41      0.40        56
#          Manuel Rodriguez Patriotic Front (FPMR)       0.88      0.68      0.77        78
#                                          Maoists       0.20      0.23      0.21        52
#                                Muslim extremists       0.22      1.00      0.36        13
#       National Liberation Army of Colombia (ELN)       0.42      0.89      0.57        28
#                          New People's Army (NPA)       0.23      0.38      0.29        37
#                Nicaraguan Democratic Force (FDN)       0.92      0.25      0.40       216
#                                     Palestinians       0.83      0.77      0.80        65
#    Revolutionary Armed Forces of Colombia (FARC)       0.22      0.81      0.34        16
#                                Shining Path (SL)       0.32      0.86      0.46        22
#                                  Sikh Extremists       0.78      0.59      0.67        80
#                                          Taliban       0.10      0.75      0.18         8
#                  Tehrik-i-Taliban Pakistan (TTP)       0.42      0.68      0.52        37
#        Tupac Amaru Revolutionary Movement (MRTA)       0.85      0.62      0.72        82
#
#                                         accuracy                           0.49      1800
#                                        macro avg       0.49      0.64      0.47      1800
#                                     weighted avg       0.68      0.49      0.50      1800
#
# --------------------------------------
# Classification report size 300
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.54      0.33      0.41       147
#         African National Congress (South Africa)       0.56      1.00      0.71        50
#                                 Al-Qaida in Iraq       0.79      0.60      0.68       119
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.54      0.84      0.66        58
#                                       Al-Shabaab       0.61      1.00      0.76        55
#              Basque Fatherland and Freedom (ETA)       0.62      0.98      0.76        57
#                                       Boko Haram       0.39      0.32      0.35       110
#   Communist Party of India - Maoist (CPI-Maoist)       0.12      0.85      0.21        13
#        Corsican National Liberation Front (FLNC)       0.90      0.28      0.43       285
#                        Donetsk People's Republic       0.73      0.54      0.62       123
# Farabundo Marti National Liberation Front (FMLN)       0.47      1.00      0.64        42
#                                Fulani extremists       0.64      0.48      0.55       122
#                  Houthi extremists (Ansar Allah)       0.44      0.91      0.60        44
#                      Irish Republican Army (IRA)       0.69      1.00      0.82        62
#      Islamic State of Iraq and the Levant (ISIL)       0.41      0.37      0.39        99
#                   Kurdistan Workers' Party (PKK)       0.13      1.00      0.24        12
#          Liberation Tigers of Tamil Eelam (LTTE)       0.58      1.00      0.73        52
#          Manuel Rodriguez Patriotic Front (FPMR)       0.81      0.50      0.62       146
#                                          Maoists       0.29      0.19      0.23       136
#                                Muslim extremists       0.33      0.97      0.50        31
#       National Liberation Army of Colombia (ELN)       0.39      0.81      0.53        43
#                          New People's Army (NPA)       0.24      0.18      0.21       124
#                Nicaraguan Democratic Force (FDN)       0.81      0.32      0.46       225
#                                     Palestinians       0.64      0.65      0.65        89
#    Revolutionary Armed Forces of Colombia (FARC)       0.11      0.62      0.19        16
#                                Shining Path (SL)       0.11      0.59      0.19        17
#                                  Sikh Extremists       0.81      0.35      0.49       210
#                                          Taliban       0.20      0.78      0.32        23
#                  Tehrik-i-Taliban Pakistan (TTP)       0.48      0.81      0.60        53
#        Tupac Amaru Revolutionary Movement (MRTA)       0.91      0.60      0.72       137
#
#                                         accuracy                           0.51      2700
#                                        macro avg       0.51      0.66      0.51      2700
#                                     weighted avg       0.63      0.51      0.51      2700
#
# --------------------------------------
# Classification report size 478
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.63      0.41      0.50       221
#         African National Congress (South Africa)       0.68      0.60      0.64       162
#                                 Al-Qaida in Iraq       0.77      0.63      0.69       176
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.55      0.82      0.66        96
#                                       Al-Shabaab       0.60      0.88      0.72        99
#              Basque Fatherland and Freedom (ETA)       0.61      0.90      0.73        98
#                                       Boko Haram       0.35      0.78      0.49        65
#   Communist Party of India - Maoist (CPI-Maoist)       0.24      0.69      0.36        51
#        Corsican National Liberation Front (FLNC)       0.99      0.38      0.54       378
#                        Donetsk People's Republic       0.81      0.68      0.74       171
# Farabundo Marti National Liberation Front (FMLN)       0.54      0.97      0.70        80
#                                Fulani extremists       0.86      0.33      0.47       379
#                  Houthi extremists (Ansar Allah)       0.44      0.82      0.58        78
#                      Irish Republican Army (IRA)       0.80      0.98      0.88       117
#      Islamic State of Iraq and the Levant (ISIL)       0.45      0.44      0.45       147
#                   Kurdistan Workers' Party (PKK)       0.19      1.00      0.33        28
#          Liberation Tigers of Tamil Eelam (LTTE)       0.59      0.74      0.66       115
#          Manuel Rodriguez Patriotic Front (FPMR)       0.96      0.40      0.56       346
#                                          Maoists       0.35      0.32      0.34       159
#                                Muslim extremists       0.42      0.87      0.57        70
#       National Liberation Army of Colombia (ELN)       0.48      0.72      0.57        96
#                          New People's Army (NPA)       0.15      0.56      0.24        39
#                Nicaraguan Democratic Force (FDN)       0.85      0.30      0.45       404
#                                     Palestinians       0.80      0.79      0.79       146
#    Revolutionary Armed Forces of Colombia (FARC)       0.16      0.62      0.25        37
#                                Shining Path (SL)       0.31      0.88      0.46        51
#                                  Sikh Extremists       0.78      0.49      0.60       230
#                                          Taliban       0.22      0.89      0.36        36
#                  Tehrik-i-Taliban Pakistan (TTP)       0.49      0.88      0.63        81
#        Tupac Amaru Revolutionary Movement (MRTA)       0.82      0.72      0.77       164
#
#                                         accuracy                           0.56      4320
#                                        macro avg       0.56      0.68      0.56      4320
#                                     weighted avg       0.71      0.56      0.57      4320
#
# --------------------------------------

# %%
from sklearn.metrics import roc_auc_score

with open(f"Results/{feature_type}/rf_top30_{feature_type}.txt", "w") as f:
    for i in range(len(trainpaths)):
        f.write(f"Partition {i+1} - {n[i]} samples per class, with longitude and latitude data\n")
        f.write(f"Accuracy: {accuracies[i]*100:.2f}%\n")
        f.write(f"Precision Score weighted: {precision_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"recall Score weighted: {recall_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"f1 Score weighted: {f1_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"Precision Score micro: {precision_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"recall Score micro: {recall_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"f1 Score micro: {f1_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"Precision Score macro: {precision_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"recall Score macro: {recall_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"f1 Score macro: {f1_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"roc auc weighted: {roc_auc_score(truths[i], probas[i],multi_class='ovr', average='weighted'):.4f}\n")
        f.write(f"roc auc macro: {roc_auc_score(truths[i], probas[i], multi_class='ovr', average='macro'):.4f}\n")
        f.write(f"roc auc micro: {roc_auc_score(truths[i], probas[i], multi_class='ovr', average='micro'):.4f}\n")
        f.write("---------------------------------------------------\n")

for partition in n:
    with open(f"Results/{feature_type}/traintimes_gtd{partition}.txt", "w") as f:
        f.write(str(train_times[i]))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition_id):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition {partition_id})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results/{feature_type}/confusion_matrix_partition_{partition_id}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition_id} to {save_path}")

# %%
for i in range(len(truths)):
    y_true = truths[i]
    y_pred = predictions[i]

    # Get all unique class labels from the truths
    class_labels = np.unique(np.concatenate(truths))

    plot_confusion_matrix(y_true, y_pred, labels=class_labels, partition_id=i + 1)

# Combined
all_true = np.concatenate(truths)
all_pred = np.concatenate(predictions)
all_labels = np.unique(all_true)

plot_confusion_matrix(all_true, all_pred, labels=all_labels, partition_id="All")
# Out:
# Saved confusion matrix for partition 1 to Results/OneHotLongLatCombined/confusion_matrix_partition_1.png
# Saved confusion matrix for partition 2 to Results/OneHotLongLatCombined/confusion_matrix_partition_2.png
# Saved confusion matrix for partition 3 to Results/OneHotLongLatCombined/confusion_matrix_partition_3.png
# Saved confusion matrix for partition 4 to Results/OneHotLongLatCombined/confusion_matrix_partition_4.png
# Saved confusion matrix for partition All to Results/OneHotLongLatCombined/confusion_matrix_partition_All.png

# %%
top_k = 20

for i, rfc in enumerate(models):
    importances = rfc.feature_importances_

    feature_names = rfc.feature_names_in_

    indices = np.argsort(importances)[::-1][:top_k]
    top_features = [feature_names[j] for j in indices]
    top_importances = importances[indices]

    plt.figure(figsize=(8, 4))
    plt.barh(top_features[::-1], top_importances[::-1])
    plt.xlabel("Importance")
    plt.title(f"Top {top_k} Feature Importances - Partition {i+1}, classes with {n[i]} entries")
    plt.tight_layout()
    plt.show()
