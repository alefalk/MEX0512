# %%
import sys
import os

sys.path.append(os.path.abspath("../Classifiers"))

from RF_OneHotLongLatCombined import *

# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ### Paths to top30 from GTD data

# %%
trains = ['train100', 'train200', 'train300', 'train478']
tests = ['test100', 'test200', 'test300', 'test478', ]
traindir = '../../../../data/top30groups/traindata'
testdir = '../../../../data/top30groups/testdata'

trainpaths = []
testpaths = []
for i, partition in enumerate(trains):
    trainpaths.append(f'{traindir}/{partition}.csv')
    testpaths.append(f'{testdir}/{tests[i]}.csv')

# %% [markdown]
# ### Training models and computing accuracy

# %%
models = []
accuracies = []
predictions = []
truths = []
n = [100, 200, 300, 478]
for i, path in enumerate(trainpaths):
    print(f'Computing for partition {i+1}, balanced classes with {n[i]} entries for each class and one hot encoded geodata')

    # run classifier on data
    rfc, accuracy, y_pred_rfc, labels = main(trainpaths[i], testpaths[i])

    #  saving models, accuracies, predictions, and truths in case we need it for statistics later
    models.append(rfc)
    accuracies.append(accuracy)
    predictions.append(y_pred_rfc)
    truths.append(labels)

    print("---------------------------------------------------")
# Out:
# Computing for partition 1, balanced classes with 100 entries for each class and one hot encoded geodata
# (2100, 3582)
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 45.44%
# ---------------------------------------------------
# Computing for partition 2, balanced classes with 200 entries for each class and one hot encoded geodata
# (4200, 6305)
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 45.67%
# ---------------------------------------------------
# Computing for partition 3, balanced classes with 300 entries for each class and one hot encoded geodata
# (6300, 8724)
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 43.07%
# ---------------------------------------------------
# Computing for partition 4, balanced classes with 478 entries for each class and one hot encoded geodata
# (10020, 12511)
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 43.17%
# ---------------------------------------------------

# %%
for i in range(len(models)):
    print(classification_report(predictions[i], truths[i]))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.57      0.40      0.47        42
#         African National Congress (South Africa)       0.40      1.00      0.57        12
#                                 Al-Qaida in Iraq       0.70      0.47      0.56        45
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.40      0.86      0.55        14
#                                       Al-Shabaab       0.57      1.00      0.72        17
#              Basque Fatherland and Freedom (ETA)       0.57      1.00      0.72        17
#                                       Boko Haram       0.30      1.00      0.46         9
#   Communist Party of India - Maoist (CPI-Maoist)       0.07      0.50      0.12         4
#        Corsican National Liberation Front (FLNC)       0.87      0.48      0.62        54
#                        Donetsk People's Republic       0.47      1.00      0.64        14
# Farabundo Marti National Liberation Front (FMLN)       0.37      0.12      0.19        88
#                                Fulani extremists       0.77      0.36      0.49        64
#                  Houthi extremists (Ansar Allah)       0.37      0.85      0.51        13
#                      Irish Republican Army (IRA)       0.60      0.95      0.73        19
#      Islamic State of Iraq and the Levant (ISIL)       0.33      0.29      0.31        35
#                   Kurdistan Workers' Party (PKK)       0.13      0.57      0.22         7
#          Liberation Tigers of Tamil Eelam (LTTE)       0.43      1.00      0.60        13
#          Manuel Rodriguez Patriotic Front (FPMR)       0.83      0.42      0.56        60
#                                          Maoists       0.33      0.14      0.19        73
#                                Muslim extremists       0.20      1.00      0.33         6
#       National Liberation Army of Colombia (ELN)       0.37      0.85      0.51        13
#                          New People's Army (NPA)       0.10      0.09      0.10        32
#                Nicaraguan Democratic Force (FDN)       0.60      0.26      0.36        70
#                                     Palestinians       0.83      0.78      0.81        32
#    Revolutionary Armed Forces of Colombia (FARC)       0.10      0.50      0.17         6
#                                Shining Path (SL)       0.13      0.80      0.23         5
#                                  Sikh Extremists       0.93      0.35      0.51        80
#                                          Taliban       0.10      0.60      0.17         5
#                  Tehrik-i-Taliban Pakistan (TTP)       0.27      0.80      0.40        10
#        Tupac Amaru Revolutionary Movement (MRTA)       0.93      0.68      0.79        41
#
#                                         accuracy                           0.45       900
#                                        macro avg       0.45      0.64      0.45       900
#                                     weighted avg       0.59      0.45      0.46       900
#
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.53      0.34      0.42        94
#         African National Congress (South Africa)       0.58      0.57      0.58        61
#                                 Al-Qaida in Iraq       0.68      0.39      0.49       106
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.33      0.91      0.49        22
#                                       Al-Shabaab       0.50      0.94      0.65        32
#              Basque Fatherland and Freedom (ETA)       0.48      0.94      0.64        31
#                                       Boko Haram       0.22      0.81      0.34        16
#   Communist Party of India - Maoist (CPI-Maoist)       0.07      0.80      0.12         5
#        Corsican National Liberation Front (FLNC)       0.98      0.26      0.41       229
#                        Donetsk People's Republic       0.58      0.56      0.57        63
# Farabundo Marti National Liberation Front (FMLN)       0.23      1.00      0.38        14
#                                Fulani extremists       0.65      0.31      0.42       125
#                  Houthi extremists (Ansar Allah)       0.47      0.49      0.48        57
#                      Irish Republican Army (IRA)       0.70      1.00      0.82        42
#      Islamic State of Iraq and the Levant (ISIL)       0.32      0.34      0.33        56
#                   Kurdistan Workers' Party (PKK)       0.08      1.00      0.15         5
#          Liberation Tigers of Tamil Eelam (LTTE)       0.42      0.40      0.41        63
#          Manuel Rodriguez Patriotic Front (FPMR)       0.90      0.83      0.86        65
#                                          Maoists       0.23      0.20      0.22        70
#                                Muslim extremists       0.18      0.79      0.30        14
#       National Liberation Army of Colombia (ELN)       0.38      0.88      0.53        26
#                          New People's Army (NPA)       0.13      0.22      0.16        37
#                Nicaraguan Democratic Force (FDN)       0.90      0.21      0.34       262
#                                     Palestinians       0.65      0.97      0.78        40
#    Revolutionary Armed Forces of Colombia (FARC)       0.17      0.30      0.22        33
#                                Shining Path (SL)       0.25      1.00      0.40        15
#                                  Sikh Extremists       0.75      0.49      0.59        92
#                                          Taliban       0.12      0.58      0.19        12
#                  Tehrik-i-Taliban Pakistan (TTP)       0.32      0.70      0.44        27
#        Tupac Amaru Revolutionary Movement (MRTA)       0.88      0.62      0.73        86
#
#                                         accuracy                           0.46      1800
#                                        macro avg       0.46      0.63      0.45      1800
#                                     weighted avg       0.65      0.46      0.46      1800
#
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.44      0.44      0.44        90
#         African National Congress (South Africa)       0.42      0.63      0.51        60
#                                 Al-Qaida in Iraq       0.76      0.65      0.70       105
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.38      0.85      0.52        40
#                                       Al-Shabaab       0.48      1.00      0.65        43
#              Basque Fatherland and Freedom (ETA)       0.40      1.00      0.57        36
#                                       Boko Haram       0.27      0.80      0.40        30
#   Communist Party of India - Maoist (CPI-Maoist)       0.03      0.75      0.06         4
#        Corsican National Liberation Front (FLNC)       0.96      0.18      0.31       466
#                        Donetsk People's Republic       0.60      0.51      0.55       106
# Farabundo Marti National Liberation Front (FMLN)       0.30      1.00      0.46        27
#                                Fulani extremists       0.74      0.37      0.50       179
#                  Houthi extremists (Ansar Allah)       0.54      0.31      0.40       156
#                      Irish Republican Army (IRA)       0.62      1.00      0.77        56
#      Islamic State of Iraq and the Levant (ISIL)       0.50      0.23      0.32       193
#                   Kurdistan Workers' Party (PKK)       0.04      1.00      0.09         4
#          Liberation Tigers of Tamil Eelam (LTTE)       0.33      1.00      0.50        30
#          Manuel Rodriguez Patriotic Front (FPMR)       0.70      1.00      0.82        63
#                                          Maoists       0.02      1.00      0.04         2
#                                Muslim extremists       0.24      1.00      0.39        22
#       National Liberation Army of Colombia (ELN)       0.36      0.89      0.51        36
#                          New People's Army (NPA)       0.10      0.18      0.13        51
#                Nicaraguan Democratic Force (FDN)       0.87      0.18      0.29       443
#                                     Palestinians       0.61      0.80      0.69        69
#    Revolutionary Armed Forces of Colombia (FARC)       0.07      0.22      0.10        27
#                                Shining Path (SL)       0.04      1.00      0.09         4
#                                  Sikh Extremists       0.63      0.42      0.51       135
#                                          Taliban       0.01      0.12      0.02         8
#                  Tehrik-i-Taliban Pakistan (TTP)       0.54      0.57      0.56        86
#        Tupac Amaru Revolutionary Movement (MRTA)       0.90      0.63      0.74       129
#
#                                         accuracy                           0.43      2700
#                                        macro avg       0.43      0.66      0.42      2700
#                                     weighted avg       0.68      0.43      0.44      2700
#
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.51      0.36      0.42       208
#         African National Congress (South Africa)       0.70      0.22      0.34       458
#                                 Al-Qaida in Iraq       0.72      0.36      0.48       291
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.40      0.85      0.55        68
#                                       Al-Shabaab       0.45      0.97      0.62        67
#              Basque Fatherland and Freedom (ETA)       0.44      1.00      0.61        63
#                                       Boko Haram       0.23      1.00      0.37        33
#   Communist Party of India - Maoist (CPI-Maoist)       0.03      1.00      0.07         5
#        Corsican National Liberation Front (FLNC)       0.76      0.66      0.71       167
#                        Donetsk People's Republic       0.59      0.96      0.73        89
# Farabundo Marti National Liberation Front (FMLN)       0.33      1.00      0.50        48
#                                Fulani extremists       0.81      0.31      0.45       380
#                  Houthi extremists (Ansar Allah)       0.38      0.90      0.53        60
#                      Irish Republican Army (IRA)       0.63      0.99      0.77        92
#      Islamic State of Iraq and the Levant (ISIL)       0.35      0.22      0.27       233
#                   Kurdistan Workers' Party (PKK)       0.09      1.00      0.17        13
#          Liberation Tigers of Tamil Eelam (LTTE)       0.44      1.00      0.62        64
#          Manuel Rodriguez Patriotic Front (FPMR)       0.81      0.99      0.89       117
#                                          Maoists       0.12      0.18      0.15       101
#                                Muslim extremists       0.22      0.91      0.35        34
#       National Liberation Army of Colombia (ELN)       0.24      0.69      0.36        51
#                          New People's Army (NPA)       0.04      0.40      0.08        15
#                Nicaraguan Democratic Force (FDN)       0.78      0.14      0.24       794
#                                     Palestinians       0.74      0.24      0.36       453
#    Revolutionary Armed Forces of Colombia (FARC)       0.01      0.50      0.01         2
#                                Shining Path (SL)       0.12      0.95      0.22        19
#                                  Sikh Extremists       0.46      0.99      0.63        67
#                                          Taliban       0.13      0.76      0.22        25
#                  Tehrik-i-Taliban Pakistan (TTP)       0.48      0.78      0.59        89
#        Tupac Amaru Revolutionary Movement (MRTA)       0.90      0.61      0.73       214
#
#                                         accuracy                           0.43      4320
#                                        macro avg       0.43      0.70      0.43      4320
#                                     weighted avg       0.65      0.43      0.43      4320

# %%
with open("Results/rf_top30_OneHotLongLatCombined.txt", "w") as f:
    for i in range(len(trainpaths)):
        f.write(f"Partition {i+1} - {n[i]} samples per class, without geograpgical data except long/lat which are one hot encoded\n")
        f.write(f"Accuracy: {accuracies[i]*100:.2f}%\n")
        f.write("---------------------------------------------------\n")

# %%
top_k = 10

for i, rfc in enumerate(models):
    importances = rfc.feature_importances_

    feature_names = rfc.feature_names_in_

    indices = np.argsort(importances)[::-1][:top_k]
    top_features = [feature_names[j] for j in indices]
    top_importances = importances[indices]

    plt.figure(figsize=(8, 4))
    plt.barh(top_features[::-1], top_importances[::-1])
    plt.xlabel("Importance")
    plt.title(f"Top {top_k} Feature Importances - Partition {i+1}, classes with {n[i]} entries")
    plt.tight_layout()
    plt.show()
