# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
#Config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
param_grid = {
    'lr': [0.001],
    'n_tree': [20],
    'tree_depth': [12],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.1],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 1)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 3614
# tensor(2293)
# tensor(838)
# tensor(842)
# tensor(4646)
# Running config: {'lr': 0.001, 'n_tree': 20, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4010 | NRF Loss: 3.4012 | Joint: 6.8022 | Val Acc: 0.0775
# Epoch 050 | GCN Loss: 3.1370 | NRF Loss: 3.3226 | Joint: 6.4596 | Val Acc: 0.1875
# Epoch 100 | GCN Loss: 2.5127 | NRF Loss: 3.1351 | Joint: 5.6478 | Val Acc: 0.2617
# Epoch 150 | GCN Loss: 1.6917 | NRF Loss: 2.9359 | Joint: 4.6276 | Val Acc: 0.3250
# Epoch 200 | GCN Loss: 0.9386 | NRF Loss: 2.7429 | Joint: 3.6815 | Val Acc: 0.3375
# Epoch 250 | GCN Loss: 0.4785 | NRF Loss: 2.5659 | Joint: 3.0444 | Val Acc: 0.3275
# Epoch 300 | GCN Loss: 0.2619 | NRF Loss: 2.4077 | Joint: 2.6696 | Val Acc: 0.3292
# Epoch 350 | GCN Loss: 0.1604 | NRF Loss: 2.2703 | Joint: 2.4307 | Val Acc: 0.3150
# Epoch 400 | GCN Loss: 0.1079 | NRF Loss: 2.1512 | Joint: 2.2592 | Val Acc: 0.3067
# Epoch 450 | GCN Loss: 0.0780 | NRF Loss: 2.0453 | Joint: 2.1233 | Val Acc: 0.2975
# Early stopping at epoch 495
# Best validation acc: 0.3417 @ epoch 195
# Evaluating on test set using full graph...
# 0.3333333432674408

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 20, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.3333333432674408, 'epoch': 195, 'y_pred': ['Al-Qaida in the Arabian Peninsula (AQAP)', "New People's Army (NPA)", "Kurdistan Workers' Party (PKK)", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Fulani extremists', 'Fulani extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Shining Path (SL)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Revolutionary Armed Forces of Colombia (FARC)', "Kurdistan Workers' Party (PKK)", 'Al-Qaida in Iraq', 'Shining Path (SL)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Kurdistan Workers' Party (PKK)", "New People's Army (NPA)", 'Al-Qaida in Iraq', 'Al-Qaida in Iraq', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Kurdistan Workers' Party (PKK)", 'Farabundo Marti National Liberation Front (FMLN)', "Kurdistan Workers' Party (PKK)", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Maoists', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Taliban', 'Al-Shabaab', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Houthi extremists (Ansar Allah)', "Donetsk People's Republic", 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Kurdistan Workers' Party (PKK)", 'Revolutionary Armed Forces of Colombia (FARC)', 'Nicaraguan Democratic Force (FDN)', "Donetsk People's Republic", 'Boko Haram', 'Revolutionary Armed Forces of Colombia (FARC)', 'Maoists', 'Shining Path (SL)', 'Boko Haram', 'Abu Sayyaf Group (ASG)', 'Shining Path (SL)', 'Taliban', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", 'Boko Haram', 'Nicaraguan Democratic Force (FDN)', 'Boko Haram', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in Iraq', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Shabaab', 'Revolutionary Armed Forces of Colombia (FARC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in Iraq', "Kurdistan Workers' Party (PKK)", 'Revolutionary Armed Forces of Colombia (FARC)', "Donetsk People's Republic", 'Corsican National Liberation Front (FLNC)', 'Al-Shabaab', 'Farabundo Marti National Liberation Front (FMLN)', 'Corsican National Liberation Front (FLNC)', 'Maoists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', "Donetsk People's Republic", 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Maoists', "Donetsk People's Republic", "Kurdistan Workers' Party (PKK)", "Kurdistan Workers' Party (PKK)", 'Al-Shabaab', 'Communist Party of India - Maoist (CPI-Maoist)', 'Maoists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in Iraq', 'Revolutionary Armed Forces of Colombia (FARC)', 'Maoists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Fulani extremists', 'Fulani extremists', 'Maoists', "Kurdistan Workers' Party (PKK)", 'Communist Party of India - Maoist (CPI-Maoist)', "Donetsk People's Republic", 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Islamic State of Iraq and the Levant (ISIL)', 'Farabundo Marti National Liberation Front (FMLN)', 'Palestinians', 'Liberation Tigers of Tamil Eelam (LTTE)', "New People's Army (NPA)", 'Liberation Tigers of Tamil Eelam (LTTE)', "Kurdistan Workers' Party (PKK)", "New People's Army (NPA)", 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', "Donetsk People's Republic", 'Al-Shabaab', 'Farabundo Marti National Liberation Front (FMLN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Sh ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
