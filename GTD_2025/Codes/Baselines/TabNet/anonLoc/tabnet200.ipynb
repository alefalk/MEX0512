# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer
import sys

# %%
partition = 200

# %%
# !{sys.executable} -m pip install pytorch-tabnet --upgrade
# Out:
# Requirement already satisfied: pytorch-tabnet in /opt/conda/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.5.0)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.14.0)
# Requirement already satisfied: torch>=1.3 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (2.3.1)
# Requirement already satisfied: tqdm>=4.36 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3->pytorch-tabnet) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
trainpath = f'../../../../data/top30groups/anonLoc/train1/train{partition}.csv'
testpath = f'../../../../data/top30groups/anonLoc/test1/test{partition}.csv'

traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
torch.cuda.empty_cache()

# %%
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

def split_data(dftrain, dftest):
    Xtrain = dftrain.drop(columns=['gname']).values.astype(float)
    Ytrain = dftrain['gname'].values
    Xtest = dftest.drop(columns=['gname']).values.astype(float)
    Ytest = dftest['gname'].values

    le = LabelEncoder()
    Ytrain = le.fit_transform(Ytrain)
    Ytest = le.transform(Ytest)

    #y_pred_decoded = model.label_encoder.inverse_transform(y_pred)
    y_true_decoded = le.inverse_transform(Ytest)

    return Xtrain, Ytrain, Xtest, Ytest, y_true_decoded, le

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
from pytorch_tabnet.tab_model import TabNetClassifier

class TabNetClassifierWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, n_d=8, n_a=8, n_steps=3, gamma=1.3, lambda_sparse=1e-3, optimizer_params=None):
        self.n_d = n_d
        self.n_a = n_a
        self.n_steps = n_steps
        self.gamma = gamma
        self.lambda_sparse = lambda_sparse
        self.optimizer_params = optimizer_params or {'lr': 0.01}
        self.model = None

    def fit(self, X, y):
        self.model = TabNetClassifier(
            n_d=self.n_d,
            n_a=self.n_a,
            n_steps=self.n_steps,
            gamma=self.gamma,
            lambda_sparse=self.lambda_sparse,
            optimizer_params=self.optimizer_params,
            seed=42,
            verbose=0
        )

        self.model.fit(
            X, y,
            eval_set=[(X, y)],
            max_epochs=500,
            patience=120,
            batch_size=1024,
            virtual_batch_size=128,
            eval_metric=['accuracy']
        )

        self.classes_ = np.unique(y)  
        return self

    def predict(self, X):
        return self.model.predict(X)

    def score(self, X, y):
        preds = self.predict(X)
        return (preds == y).mean()

# %%
#from pytorch_tabnet.sklearn import TabNetClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor

def find_best_tabnet(Xtrain, Ytrain, n_iter=20):
    print("Starting TabNet grid search")
    print("CUDA available:", torch.cuda.is_available())

    param_dist = {
        'n_d': [8, 16, 24],
        'n_a': [8, 16, 24],
        'n_steps': [3, 4, 5],
        'gamma': [1.0, 1.3, 1.5],
        'lambda_sparse': [1e-4, 1e-3, 1e-2],
        'optimizer_params': [{'lr': 0.01}]
    }

    random_search = RandomizedSearchCV(
        estimator=TabNetClassifierWrapper(),
        param_distributions=param_dist,
        n_iter=n_iter,
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
        scoring='accuracy',
        verbose=1,
        n_jobs=-1,
        random_state=42
    )

    random_search.fit(Xtrain, Ytrain)
    print("Best parameters:", random_search.best_params_)
    print("Best accuracy:", random_search.best_score_)

    return random_search.best_params_

# %%
from pytorch_tabnet.callbacks import Callback
import time

class EpochTimer(Callback):
    def __init__(self):
        self.epoch_times = []

    def on_epoch_begin(self, epoch_idx, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch_idx, logs=None):
        duration = time.time() - self.start_time
        self.epoch_times.append(duration)
        print(f"⏱️ Epoch {epoch_idx + 1} took {duration:.2f} seconds")

# %%
Xtrain, Ytrain, Xtest, Ytest, Ytest_decoded, le = split_data(traindata, testdata)
best_tabnet_params = find_best_tabnet(Xtrain, Ytrain)

from sklearn.model_selection import train_test_split

# Split 80% train, 20% validation
X_tr, X_val, y_tr, y_val = train_test_split(
    Xtrain, Ytrain,
    test_size=0.2,
    random_state=42,
    stratify=Ytrain
)

# Re-initialize TabNet with best params
final_model = TabNetClassifier(
    **{k: v for k, v in best_tabnet_params.items()},
    verbose=1,
    seed=42
)

epoch_timer = EpochTimer()

# Retrain on full training data
final_model.fit(
    X_tr, y_tr,
    eval_set=[(X_val, y_val)],
    max_epochs=1000,
    patience=200,
    batch_size=1024,
    virtual_batch_size=128,
    callbacks=[epoch_timer]
)
# Out:
# Starting TabNet grid search
# CUDA available: True
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.74464
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.81101
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.79107
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 420 and best_val_0_accuracy = 0.6756
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 453 and best_val_0_accuracy = 0.66339
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.69077
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 484 and best_val_0_accuracy = 0.6878
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 479 and best_val_0_accuracy = 0.70685
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 484 and best_val_0_accuracy = 0.67887
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.69494
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.73542
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.73036
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Early stopping occurred at epoch 449 with best_epoch = 329 and best_val_0_accuracy = 0.62054
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.72143
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 460 and best_val_0_accuracy = 0.74345
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.67202
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.64792
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 427 and best_val_0_accuracy = 0.69911
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.65655
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.66994
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 476 and best_val_0_accuracy = 0.80952
# Best parameters: {'optimizer_params': {'lr': 0.01}, 'n_steps': 3, 'n_d': 24, 'n_a': 24, 'lambda_sparse': 0.0001, 'gamma': 1.0}
# Best accuracy: nan
# epoch 0  | loss: 4.24388 | val_0_accuracy: 0.02738 |  0:00:00s
# ⏱️ Epoch 1 took 0.09 seconds
# epoch 1  | loss: 3.70894 | val_0_accuracy: 0.04286 |  0:00:00s
# ⏱️ Epoch 2 took 0.09 seconds
# epoch 2  | loss: 3.52845 | val_0_accuracy: 0.05595 |  0:00:00s
# ⏱️ Epoch 3 took 0.09 seconds
# epoch 3  | loss: 3.40522 | val_0_accuracy: 0.05714 |  0:00:00s
# ⏱️ Epoch 4 took 0.08 seconds
# epoch 4  | loss: 3.34559 | val_0_accuracy: 0.05119 |  0:00:00s
# ⏱️ Epoch 5 took 0.08 seconds
# epoch 5  | loss: 3.2705  | val_0_accuracy: 0.02738 |  0:00:00s
# ⏱️ Epoch 6 took 0.07 seconds
# epoch 6  | loss: 3.19115 | val_0_accuracy: 0.03095 |  0:00:00s
# ⏱️ Epoch 7 took 0.09 seconds
# epoch 7  | loss: 3.10046 | val_0_accuracy: 0.02143 |  0:00:00s
# ⏱️ Epoch 8 took 0.09 seconds
# epoch 8  | loss: 3.03966 | val_0_accuracy: 0.0369  |  0:00:00s
# ⏱️ Epoch 9 took 0.09 seconds
# epoch 9  | loss: 2.96156 | val_0_accuracy: 0.03929 |  0:00:00s
# ⏱️ Epoch 10 took 0.10 seconds
# epoch 10 | loss: 2.90482 | val_0_accuracy: 0.03452 |  0:00:00s
# ⏱️ Epoch 11 took 0.10 seconds
# epoch 11 | loss: 2.83099 | val_0_accuracy: 0.04524 |  0:00:01s
# ⏱️ Epoch 12 took 0.10 seconds
# epoch 12 | loss: 2.77949 | val_0_accuracy: 0.04405 |  0:00:01s
# ⏱️ Epoch 13 took 0.10 seconds
# epoch 13 | loss: 2.71658 | val_0_accuracy: 0.05119 |  0:00:01s
# ⏱️ Epoch 14 took 0.09 seconds
# epoch 14 | loss: 2.69308 | val_0_accuracy: 0.04524 |  0:00:01s
# ⏱️ Epoch 15 took 0.10 seconds
# epoch 15 | loss: 2.61588 | val_0_accuracy: 0.04405 |  0:00:01s
# ⏱️ Epoch 16 took 0.09 seconds
# epoch 16 | loss: 2.58494 | val_0_accuracy: 0.04524 |  0:00:01s
# ⏱️ Epoch 17 took 0.10 seconds
# epoch 17 | loss: 2.55203 | val_0_accuracy: 0.05476 |  0:00:01s
# ⏱️ Epoch 18 took 0.12 seconds
# epoch 18 | loss: 2.50202 | val_0_accuracy: 0.05476 |  0:00:01s
# ⏱️ Epoch 19 took 0.09 seconds
# epoch 19 | loss: 2.46049 | val_0_accuracy: 0.05952 |  0:00:01s
# ⏱️ Epoch 20 took 0.10 seconds
# epoch 20 | loss: 2.41707 | val_0_accuracy: 0.06786 |  0:00:01s
# ⏱️ Epoch 21 took 0.10 seconds
# epoch 21 | loss: 2.37399 | val_0_accuracy: 0.08571 |  0:00:02s
# ⏱️ Epoch 22 took 0.10 seconds
# epoch 22 | loss: 2.34151 | val_0_accuracy: 0.0881  |  0:00:02s
# ⏱️ Epoch 23 took 0.09 seconds
# epoch 23 | loss: 2.30317 | val_0_accuracy: 0.0631  |  0:00:02s
# ⏱️ Epoch 24 took 0.09 seconds
# epoch 24 | loss: 2.2953  | val_0_accuracy: 0.05714 |  0:00:02s
# ⏱️ Epoch 25 took 0.09 seconds
# epoch 25 | loss: 2.23429 | val_0_accuracy: 0.05238 |  0:00:02s
# ⏱️ Epoch 26 took 0.09 seconds
# epoch 26 | loss: 2.23195 | val_0_accuracy: 0.06429 |  0:00:02s
# ⏱️ Epoch 27 took 0.09 seconds
# epoch 27 | loss: 2.21668 | val_0_accuracy: 0.08214 |  0:00:02s
# ⏱️ Epoch 28 took 0.09 seconds
# epoch 28 | loss: 2.19881 | val_0_accuracy: 0.0869  |  0:00:02s
# ⏱️ Epoch 29 took 0.09 seconds
# epoch 29 | loss: 2.1549  | val_0_accuracy: 0.06905 |  0:00:02s
# ⏱️ Epoch 30 took 0.09 seconds
# epoch 30 | loss: 2.13096 | val_0_accuracy: 0.06429 |  0:00:02s
# ⏱️ Epoch 31 took 0.09 seconds
# epoch 31 | loss: 2.12724 | val_0_accuracy: 0.06905 |  0:00:02s
# ⏱️ Epoch 32 took 0.09 seconds
# epoch 32 | loss: 2.11566 | val_0_accuracy: 0.07381 |  0:00:03s
# ⏱️ Epoch 33 took 0.08 seconds
# epoch 33 | loss: 2.13287 | val_0_accuracy: 0.06667 |  0:00:03s
# ⏱️ Epoch 34 took 0.08 seconds
# epoch 34 | loss: 2.10174 | val_0_accuracy: 0.07262 |  0:00:03s
# ⏱️ Epoch 35 took 0.08 seconds
# epoch 35 | loss: 2.05381 | val_0_accuracy: 0.08095 |  0:00:03s
# ⏱️ Epoch 36 took 0.09 seconds
# epoch 36 | loss: 2.02926 | val_0_accuracy: 0.0881  |  0:00:03s
# ⏱️ Epoch 37 took 0.09 seconds
# epoch 37 | loss: 2.01183 | val_0_accuracy: 0.08571 |  0:00:03s
# ⏱️ Epoch 38 took 0.09 seconds
# epoch 38 | loss: 2.00489 | val_0_accuracy: 0.09286 |  0:00:03s
# ⏱️ Epoch 39 took 0.10 seconds
# epoch 39 | loss: 1.97732 | val_0_accuracy: 0.07738 |  0:00:03s
# ⏱️ Epoch 40 took 0.09 seconds
# epoch 40 | loss: 1.98122 | val_0_accuracy: 0.08929 |  0:00:03s
# ⏱️ Epoch 41 took 0.09 seconds
# epoch 41 | loss: 1.92378 | val_0_accuracy: 0.09643 |  0:00:03s
# ⏱️ Epoch 42 took 0.10 seconds
# epoch 42 | loss: 1.92198 | val_0_accuracy: 0.08929 |  0:00:03s
# ⏱️ Epoch 43 took 0.10 seconds
# epoch 43 | loss: 1.91222 | val_0_accuracy: 0.08214 |  0:00:04s
# ⏱️ Epoch 44 took 0.10 seconds
# epoch 44 | loss: 1.88642 | val_0_accuracy: 0.07857 |  0:00:04s
# ⏱️ Epoch 45 took 0.08 seconds
# epoch 45 | loss: 1.88891 | val_0_accuracy: 0.10119 |  0:00:04s
# ⏱️ Epoch 46 took 0.10 seconds
# epoch 46 | loss: 1.88196 | val_0_accuracy: 0.10119 |  0:00:04s
# ⏱️ Epoch 47 took 0.09 seconds
# epoch 47 | loss: 1.86564 | val_0_accuracy: 0.1     |  0:00:04s
# ⏱️ Epoch 48 took 0.09 seconds
# epoch 48 | loss: 1.83608 | val_0_accuracy: 0.1119  |  0:00:04s
# ⏱️ Epoch 49 took 0.09 seconds
# epoch 49 | loss: 1.84409 | val_0_accuracy: 0.125   |  0:00:04s
# ⏱️ Epoch 50 took 0.10 seconds
# epoch 50 | loss: 1.80147 | val_0_accuracy: 0.125   |  0:00:04s
# ⏱️ Epoch 51 took 0.10 seconds
# epoch 51 | loss: 1.83583 | val_0_accuracy: 0.13214 |  0:00:04s
# ⏱️ Epoch 52 took 0.09 seconds
# epoch 52 | loss: 1.80757 | val_0_accuracy: 0.1381  |  0:00:04s
# ⏱️ Epoch 53 took 0.10 seconds
# epoch 53 | loss: 1.75537 | val_0_accuracy: 0.14643 |  0:00:04s
# ⏱️ Epoch 54 took 0.10 seconds
# epoch 54 | loss: 1.75528 | val_0_accuracy: 0.13571 |  0:00:05s
# ⏱️ Epoch 55 took 0.09 seconds
# epoch 55 | loss: 1.74534 | val_0_accuracy: 0.12619 |  0:00:05s
# ⏱️ Epoch 56 took 0.09 seconds
# epoch 56 | loss: 1.73234 | val_0_accuracy: 0.12976 |  0:00:05s
# ⏱️ Epoch 57 took 0.09 seconds
# epoch 57 | loss: 1.76238 | val_0_accuracy: 0.15476 |  0:00:05s
# ⏱️ Epoch 58 took 0.09 seconds
# epoch 58 | loss: 1.74934 | val_0_accuracy: 0.18571 |  0:00:05s
# ⏱️ Epoch 59 took 0.09 seconds
# epoch 59 | loss: 1.70631 | val_0_accuracy: 0.17857 |  0:00:05s
# ⏱️ Epoch 60 took 0.08 seconds
# epoch 60 | loss: 1.73478 | val_0_accuracy: 0.1881  |  0:00:05s
# ⏱️ Epoch 61 took 0.09 seconds
# epoch 61 | loss: 1.74109 | val_0_accuracy: 0.17619 |  0:00:05s
# ⏱️ Epoch 62 took 0.09 seconds
# epoch 62 | loss: 1.69324 | val_0_accuracy: 0.18095 |  0:00:05s
# ⏱️ Epoch 63 took 0.09 seconds
# epoch 63 | loss: 1.71748 | val_0_accuracy: 0.19405 |  0:00:05s
# ⏱️ Epoch 64 took 0.09 seconds
# epoch 64 | loss: 1.69791 | val_0_accuracy: 0.19286 |  0:00:05s
# ⏱️ Epoch 65 took 0.09 seconds
# epoch 65 | loss: 1.68768 | val_0_accuracy: 0.19048 |  0:00:06s
# ⏱️ Epoch 66 took 0.07 seconds
# epoch 66 | loss: 1.71085 | val_0_accuracy: 0.22024 |  0:00:06s
# ⏱️ Epoch 67 took 0.09 seconds
# epoch 67 | loss: 1.68369 | val_0_accuracy: 0.2381  |  0:00:06s
# ⏱️ Epoch 68 took 0.08 seconds
# epoch 68 | loss: 1.68327 | val_0_accuracy: 0.21786 |  0:00:06s
# ⏱️ Epoch 69 took 0.08 seconds
# epoch 69 | loss: 1.67227 | val_0_accuracy: 0.20595 |  0:00:06s
# ⏱️ Epoch 70 took 0.09 seconds
# epoch 70 | loss: 1.68829 | val_0_accuracy: 0.22738 |  0:00:06s
# ⏱️ Epoch 71 took 0.09 seconds
# epoch 71 | loss: 1.66265 | val_0_accuracy: 0.26548 |  0:00:06s
# ⏱️ Epoch 72 took 0.11 seconds
# epoch 72 | loss: 1.65722 | val_0_accuracy: 0.24286 |  0:00:06s
# ⏱️ Epoch 73 took 0.09 seconds
# epoch 73 | loss: 1.64955 | val_0_accuracy: 0.27381 |  0:00:06s
# ⏱️ Epoch 74 took 0.10 seconds
# epoch 74 | loss: 1.62427 | val_0_accuracy: 0.29405 |  0:00:06s
# ⏱️ Epoch 75 took 0.10 seconds
# epoch 75 | loss: 1.64324 | val_0_accuracy: 0.27976 |  0:00:06s
# ⏱️ Epoch 76 took 0.10 seconds
# epoch 76 | loss: 1.66068 | val_0_accuracy: 0.28452 |  0:00:07s
# ⏱️ Epoch 77 took 0.09 seconds
# epoch 77 | loss: 1.62317 | val_0_accuracy: 0.27976 |  0:00:07s
# ⏱️ Epoch 78 took 0.08 seconds
# epoch 78 | loss: 1.60577 | val_0_accuracy: 0.27976 |  0:00:07s
# ⏱️ Epoch 79 took 0.09 seconds
# epoch 79 | loss: 1.57192 | val_0_accuracy: 0.29048 |  0:00:07s
# ⏱️ Epoch 80 took 0.09 seconds
# epoch 80 | loss: 1.59873 | val_0_accuracy: 0.31667 |  0:00:07s
# ⏱️ Epoch 81 took 0.09 seconds
# epoch 81 | loss: 1.56667 | val_0_accuracy: 0.3369  |  0:00:07s
# ⏱️ Epoch 82 took 0.09 seconds
# epoch 82 | loss: 1.56655 | val_0_accuracy: 0.29048 |  0:00:07s
# ⏱️ Epoch 83 took 0.09 seconds
# epoch 83 | loss: 1.5777  | val_0_accuracy: 0.32619 |  0:00:07s
# ⏱️ Epoch 84 took 0.26 seconds
# epoch 84 | loss: 1.54431 | val_0_accuracy: 0.3381  |  0:00:07s
# ⏱️ Epoch 85 took 0.10 seconds
# epoch 85 | loss: 1.55058 | val_0_accuracy: 0.3381  |  0:00:07s
# ⏱️ Epoch 86 took 0.08 seconds
# epoch 86 | loss: 1.57163 | val_0_accuracy: 0.32619 |  0:00:08s
# ⏱️ Epoch 87 took 0.10 seconds
# epoch 87 | loss: 1.55983 | val_0_accuracy: 0.32619 |  0:00:08s
# ⏱️ Epoch 88 took 0.11 seconds
# epoch 88 | loss: 1.56233 | val_0_accuracy: 0.39643 |  0:00:08s
# ⏱️ Epoch 89 took 0.10 seconds
# epoch 89 | loss: 1.54334 | val_0_accuracy: 0.3881  |  0:00:08s
# ⏱️ Epoch 90 took 0.09 seconds
# epoch 90 | loss: 1.52082 | val_0_accuracy: 0.38929 |  0:00:08s
# ⏱️ Epoch 91 took 0.09 seconds
# epoch 91 | loss: 1.55298 | val_0_accuracy: 0.33929 |  0:00:08s
# ⏱️ Epoch 92 took 0.09 seconds
# epoch 92 | loss: 1.51019 | val_0_accuracy: 0.37143 |  0:00:08s
# ⏱️ Epoch 93 took 0.09 seconds
# epoch 93 | loss: 1.58262 | val_0_accuracy: 0.37381 |  0:00:08s
# ⏱️ Epoch 94 took 0.07 seconds
# epoch 94 | loss: 1.5219  | val_0_accuracy: 0.43929 |  0:00:08s
# ⏱️ Epoch 95 took 0.08 seconds
# epoch 95 | loss: 1.50986 | val_0_accuracy: 0.425   |  0:00:08s
# ⏱️ Epoch 96 took 0.08 seconds
# epoch 96 | loss: 1.5088  | val_0_accuracy: 0.4131  |  0:00:08s
# ⏱️ Epoch 97 took 0.09 seconds
# epoch 97 | loss: 1.49007 | val_0_accuracy: 0.40238 |  0:00:09s
# ⏱️ Epoch 98 took 0.09 seconds
# epoch 98 | loss: 1.50285 | val_0_accuracy: 0.4131  |  0:00:09s
# ⏱️ Epoch 99 took 0.10 seconds
# epoch 99 | loss: 1.50837 | val_0_accuracy: 0.37262 |  0:00:09s
# ⏱️ Epoch 100 took 0.13 seconds
# epoch 100| loss: 1.50723 | val_0_accuracy: 0.40833 |  0:00:09s
# ⏱️ Epoch 101 took 0.11 seconds
# epoch 101| loss: 1.48881 | val_0_accuracy: 0.41071 |  0:00:09s
# ⏱️ Epoch 102 took 0.09 seconds
# epoch 102| loss: 1.48029 | val_0_accuracy: 0.45595 |  0:00:09s
# ⏱️ Epoch 103 took 0.09 seconds
# epoch 103| loss: 1.46479 | val_0_accuracy: 0.46905 |  0:00:09s
# ⏱️ Epoch 104 took 0.09 seconds
# epoch 104| loss: 1.4711  | val_0_accuracy: 0.47024 |  0:00:09s
# ⏱️ Epoch 105 took 0.10 seconds
# epoch 105| loss: 1.41021 | val_0_accuracy: 0.46071 |  0:00:09s
# ⏱️ Epoch 106 took 0.09 seconds
# epoch 106| loss: 1.52115 | val_0_accuracy: 0.41905 |  0:00:09s
# ⏱️ Epoch 107 took 0.09 seconds
# epoch 107| loss: 1.44691 | val_0_accuracy: 0.42976 |  0:00:10s
# ⏱️ Epoch 108 took 0.08 seconds
# epoch 108| loss: 1.49284 | val_0_accuracy: 0.45714 |  0:00:10s
# ⏱️ Epoch 109 took 0.08 seconds
# epoch 109| loss: 1.46852 | val_0_accuracy: 0.50833 |  0:00:10s
# ⏱️ Epoch 110 took 0.10 seconds
# epoch 110| loss: 1.44354 | val_0_accuracy: 0.48929 |  0:00:10s
# ⏱️ Epoch 111 took 0.09 seconds
# epoch 111| loss: 1.45135 | val_0_accuracy: 0.47381 |  0:00:10s
# ⏱️ Epoch 112 took 0.09 seconds
# epoch 112| loss: 1.39852 | val_0_accuracy: 0.43333 |  0:00:10s
# ⏱️ Epoch 113 took 0.09 seconds
# epoch 113| loss: 1.41625 | val_0_accuracy: 0.45357 |  0:00:10s
# ⏱️ Epoch 114 took 0.09 seconds
# epoch 114| loss: 1.43722 | val_0_accuracy: 0.475   |  0:00:10s
# ⏱️ Epoch 115 took 0.09 seconds
# epoch 115| loss: 1.37103 | val_0_accuracy: 0.50714 |  0:00:10s
# ⏱️ Epoch 116 took 0.09 seconds
# epoch 116| loss: 1.39486 | val_0_accuracy: 0.50952 |  0:00:10s
# ⏱️ Epoch 117 took 0.08 seconds
# epoch 117| loss: 1.39187 | val_0_accuracy: 0.50119 |  0:00:10s
# ⏱️ Epoch 118 took 0.08 seconds
# epoch 118| loss: 1.36819 | val_0_accuracy: 0.43095 |  0:00:10s
# ⏱️ Epoch 119 took 0.09 seconds
# epoch 119| loss: 1.37233 | val_0_accuracy: 0.45357 |  0:00:11s
# ⏱️ Epoch 120 took 0.09 seconds
# epoch 120| loss: 1.38074 | val_0_accuracy: 0.50952 |  0:00:11s
# ⏱️ Epoch 121 took 0.09 seconds
# epoch 121| loss: 1.42479 | val_0_accuracy: 0.45119 |  0:00:11s
# ⏱️ Epoch 122 took 0.09 seconds
# epoch 122| loss: 1.3707  | val_0_accuracy: 0.47619 |  0:00:11s
# ⏱️ Epoch 123 took 0.10 seconds
# epoch 123| loss: 1.40185 | val_0_accuracy: 0.475   |  0:00:11s
# ⏱️ Epoch 124 took 0.09 seconds
# epoch 124| loss: 1.42226 | val_0_accuracy: 0.50952 |  0:00:11s
# ⏱️ Epoch 125 took 0.08 seconds
# epoch 125| loss: 1.37085 | val_0_accuracy: 0.50952 |  0:00:11s
# ⏱️ Epoch 126 took 0.09 seconds
# epoch 126| loss: 1.38744 | val_0_accuracy: 0.49762 |  0:00:11s
# ⏱️ Epoch 127 took 0.09 seconds
# epoch 127| loss: 1.36327 | val_0_accuracy: 0.52143 |  0:00:11s
# ⏱️ Epoch 128 took 0.09 seconds
# epoch 128| loss: 1.35166 | val_0_accuracy: 0.51071 |  0:00:11s
# ⏱️ Epoch 129 took 0.09 seconds
# epoch 129| loss: 1.37883 | val_0_accuracy: 0.52857 |  0:00:11s
# ⏱️ Epoch 130 took 0.09 seconds
# epoch 130| loss: 1.37165 | val_0_accuracy: 0.52857 |  0:00:12s
# ⏱️ Epoch 131 took 0.08 seconds
# epoch 131| loss: 1.38058 | val_0_accuracy: 0.5119  |  0:00:12s
# ⏱️ Epoch 132 took 0.08 seconds
# epoch 132| loss: 1.39874 | val_0_accuracy: 0.47143 |  0:00:12s
# ⏱️ Epoch 133 took 0.07 seconds
# epoch 133| loss: 1.38544 | val_0_accuracy: 0.51071 |  0:00:12s
# ⏱️ Epoch 134 took 0.08 seconds
# epoch 134| loss: 1.39068 | val_0_accuracy: 0.48095 |  0:00:12s
# ⏱️ Epoch 135 took 0.09 seconds
# epoch 135| loss: 1.38549 | val_0_accuracy: 0.49524 |  0:00:12s
# ⏱️ Epoch 136 took 0.08 seconds
# epoch 136| loss: 1.33943 | val_0_accuracy: 0.45238 |  0:00:12s
# ⏱️ Epoch 137 took 0.08 seconds
# epoch 137| loss: 1.36172 | val_0_accuracy: 0.50238 |  0:00:12s
# ⏱️ Epoch 138 took 0.07 seconds
# epoch 138| loss: 1.35554 | val_0_accuracy: 0.52857 |  0:00:12s
# ⏱️ Epoch 139 took 0.13 seconds
# epoch 139| loss: 1.33144 | val_0_accuracy: 0.50952 |  0:00:12s
# ⏱️ Epoch 140 took 0.08 seconds
# epoch 140| loss: 1.30221 | val_0_accuracy: 0.53929 |  0:00:12s
# ⏱️ Epoch 141 took 0.12 seconds
# epoch 141| loss: 1.32379 | val_0_accuracy: 0.50476 |  0:00:13s
# ⏱️ Epoch 142 took 0.12 seconds
# epoch 142| loss: 1.3494  | val_0_accuracy: 0.54286 |  0:00:13s
# ⏱️ Epoch 143 took 0.11 seconds
# epoch 143| loss: 1.2944  | val_0_accuracy: 0.54405 |  0:00:13s
# ⏱️ Epoch 144 took 0.09 seconds
# epoch 144| loss: 1.33555 | val_0_accuracy: 0.54048 |  0:00:13s
# ⏱️ Epoch 145 took 0.08 seconds
# epoch 145| loss: 1.33302 | val_0_accuracy: 0.53452 |  0:00:13s
# ⏱️ Epoch 146 took 0.10 seconds
# epoch 146| loss: 1.35215 | val_0_accuracy: 0.5381  |  0:00:13s
# ⏱️ Epoch 147 took 0.08 seconds
# epoch 147| loss: 1.3386  | val_0_accuracy: 0.50595 |  0:00:13s
# ⏱️ Epoch 148 took 0.08 seconds
# epoch 148| loss: 1.33484 | val_0_accuracy: 0.53452 |  0:00:13s
# ⏱️ Epoch 149 took 0.09 seconds
# epoch 149| loss: 1.30969 | val_0_accuracy: 0.54167 |  0:00:13s
# ⏱️ Epoch 150 took 0.09 seconds
# epoch 150| loss: 1.27202 | val_0_accuracy: 0.53452 |  0:00:13s
# ⏱️ Epoch 151 took 0.09 seconds
# epoch 151| loss: 1.2944  | val_0_accuracy: 0.52262 |  0:00:13s
# ⏱️ Epoch 152 took 0.08 seconds
# epoch 152| loss: 1.31743 | val_0_accuracy: 0.55    |  0:00:14s
# ⏱️ Epoch 153 took 0.09 seconds
# epoch 153| loss: 1.29903 | val_0_accuracy: 0.55714 |  0:00:14s
# ⏱️ Epoch 154 took 0.08 seconds
# epoch 154| loss: 1.33362 | val_0_accuracy: 0.56548 |  0:00:14s
# ⏱️ Epoch 155 took 0.08 seconds
# epoch 155| loss: 1.25684 | val_0_accuracy: 0.54881 |  0:00:14s
# ⏱️ Epoch 156 took 0.09 seconds
# epoch 156| loss: 1.3317  | val_0_accuracy: 0.53095 |  0:00:14s
# ⏱️ Epoch 157 took 0.09 seconds
# epoch 157| loss: 1.27058 | val_0_accuracy: 0.55238 |  0:00:14s
# ⏱️ Epoch 158 took 0.09 seconds
# epoch 158| loss: 1.25139 | val_0_accuracy: 0.56071 |  0:00:14s
# ⏱️ Epoch 159 took 0.08 seconds
# epoch 159| loss: 1.27199 | val_0_accuracy: 0.54167 |  0:00:14s
# ⏱️ Epoch 160 took 0.08 seconds
# epoch 160| loss: 1.32206 | val_0_accuracy: 0.5631  |  0:00:14s
# ⏱️ Epoch 161 took 0.07 seconds
# epoch 161| loss: 1.26512 | val_0_accuracy: 0.52738 |  0:00:14s
# ⏱️ Epoch 162 took 0.09 seconds
# epoch 162| loss: 1.27258 | val_0_accuracy: 0.55238 |  0:00:14s
# ⏱️ Epoch 163 took 0.08 seconds
# epoch 163| loss: 1.26966 | val_0_accuracy: 0.54048 |  0:00:14s
# ⏱️ Epoch 164 took 0.08 seconds
# epoch 164| loss: 1.24585 | val_0_accuracy: 0.55119 |  0:00:15s
# ⏱️ Epoch 165 took 0.08 seconds
# epoch 165| loss: 1.26426 | val_0_accuracy: 0.55595 |  0:00:15s
# ⏱️ Epoch 166 took 0.07 seconds
# epoch 166| loss: 1.24025 | val_0_accuracy: 0.53929 |  0:00:15s
# ⏱️ Epoch 167 took 0.08 seconds
# epoch 167| loss: 1.20364 | val_0_accuracy: 0.54881 |  0:00:15s
# ⏱️ Epoch 168 took 0.08 seconds
# epoch 168| loss: 1.26175 | val_0_accuracy: 0.55119 |  0:00:15s
# ⏱️ Epoch 169 took 0.08 seconds
# epoch 169| loss: 1.26062 | val_0_accuracy: 0.54762 |  0:00:15s
# ⏱️ Epoch 170 took 0.08 seconds
# epoch 170| loss: 1.23912 | val_0_accuracy: 0.55    |  0:00:15s
# ⏱️ Epoch 171 took 0.07 seconds
# epoch 171| loss: 1.20115 | val_0_accuracy: 0.55    |  0:00:15s
# ⏱️ Epoch 172 took 0.08 seconds
# epoch 172| loss: 1.25384 | val_0_accuracy: 0.5619  |  0:00:15s
# ⏱️ Epoch 173 took 0.08 seconds
# epoch 173| loss: 1.27078 | val_0_accuracy: 0.55238 |  0:00:15s
# ⏱️ Epoch 174 took 0.09 seconds
# epoch 174| loss: 1.20107 | val_0_accuracy: 0.55952 |  0:00:15s
# ⏱️ Epoch 175 took 0.09 seconds
# epoch 175| loss: 1.19825 | val_0_accuracy: 0.53929 |  0:00:15s
# ⏱️ Epoch 176 took 0.09 seconds
# epoch 176| loss: 1.26105 | val_0_accuracy: 0.52976 |  0:00:16s
# ⏱️ Epoch 177 took 0.09 seconds
# epoch 177| loss: 1.19952 | val_0_accuracy: 0.54405 |  0:00:16s
# ⏱️ Epoch 178 took 0.08 seconds
# epoch 178| loss: 1.17366 | val_0_accuracy: 0.55714 |  0:00:16s
# ⏱️ Epoch 179 took 0.08 seconds
# epoch 179| loss: 1.17377 | val_0_accuracy: 0.56905 |  0:00:16s
# ⏱️ Epoch 180 took 0.09 seconds
# epoch 180| loss: 1.18106 | val_0_accuracy: 0.54881 |  0:00:16s
# ⏱️ Epoch 181 took 0.09 seconds
# epoch 181| loss: 1.22831 | val_0_accuracy: 0.54405 |  0:00:16s
# ⏱️ Epoch 182 took 0.08 seconds
# epoch 182| loss: 1.21726 | val_0_accuracy: 0.54762 |  0:00:16s
# ⏱️ Epoch 183 took 0.09 seconds
# epoch 183| loss: 1.20445 | val_0_accuracy: 0.56071 |  0:00:16s
# ⏱️ Epoch 184 took 0.10 seconds
# epoch 184| loss: 1.17445 | val_0_accuracy: 0.57262 |  0:00:16s
# ⏱️ Epoch 185 took 0.09 seconds
# epoch 185| loss: 1.18592 | val_0_accuracy: 0.57262 |  0:00:16s
# ⏱️ Epoch 186 took 0.08 seconds
# epoch 186| loss: 1.18064 | val_0_accuracy: 0.56548 |  0:00:16s
# ⏱️ Epoch 187 took 0.09 seconds
# epoch 187| loss: 1.24191 | val_0_accuracy: 0.57857 |  0:00:16s
# ⏱️ Epoch 188 took 0.09 seconds
# epoch 188| loss: 1.22257 | val_0_accuracy: 0.56905 |  0:00:17s
# ⏱️ Epoch 189 took 0.09 seconds
# epoch 189| loss: 1.21152 | val_0_accuracy: 0.53571 |  0:00:17s
# ⏱️ Epoch 190 took 0.09 seconds
# epoch 190| loss: 1.17771 | val_0_accuracy: 0.57381 |  0:00:17s
# ⏱️ Epoch 191 took 0.09 seconds
# epoch 191| loss: 1.2016  | val_0_accuracy: 0.54048 |  0:00:17s
# ⏱️ Epoch 192 took 0.09 seconds
# epoch 192| loss: 1.14815 | val_0_accuracy: 0.54762 |  0:00:17s
# ⏱️ Epoch 193 took 0.08 seconds
# epoch 193| loss: 1.20653 | val_0_accuracy: 0.55595 |  0:00:17s
# ⏱️ Epoch 194 took 0.08 seconds
# epoch 194| loss: 1.21323 | val_0_accuracy: 0.5131  |  0:00:17s
# ⏱️ Epoch 195 took 0.08 seconds
# epoch 195| loss: 1.2058  | val_0_accuracy: 0.5369  |  0:00:17s
# ⏱️ Epoch 196 took 0.08 seconds
# epoch 196| loss: 1.21864 | val_0_accuracy: 0.52262 |  0:00:17s
# ⏱️ Epoch 197 took 0.09 seconds
# epoch 197| loss: 1.17884 | val_0_accuracy: 0.54405 |  0:00:17s
# ⏱️ Epoch 198 took 0.09 seconds
# epoch 198| loss: 1.22655 | val_0_accuracy: 0.55357 |  0:00:17s
# ⏱️ Epoch 199 took 0.08 seconds
# epoch 199| loss: 1.21033 | val_0_accuracy: 0.5619  |  0:00:18s
# ⏱️ Epoch 200 took 0.07 seconds
# epoch 200| loss: 1.17556 | val_0_accuracy: 0.54762 |  0:00:18s
# ⏱️ Epoch 201 took 0.08 seconds
# epoch 201| loss: 1.17921 | val_0_accuracy: 0.55    |  0:00:18s
# ⏱️ Epoch 202 took 0.08 seconds
# epoch 202| loss: 1.2309  | val_0_accuracy: 0.55714 |  0:00:18s
# ⏱️ Epoch 203 took 0.09 seconds
# epoch 203| loss: 1.16089 | val_0_accuracy: 0.57024 |  0:00:18s
# ⏱️ Epoch 204 took 0.10 seconds
# epoch 204| loss: 1.20002 | val_0_accuracy: 0.54286 |  0:00:18s
# ⏱️ Epoch 205 took 0.08 seconds
# epoch 205| loss: 1.17168 | val_0_accuracy: 0.55595 |  0:00:18s
# ⏱️ Epoch 206 took 0.07 seconds
# epoch 206| loss: 1.26975 | val_0_accuracy: 0.55714 |  0:00:18s
# ⏱️ Epoch 207 took 0.09 seconds
# epoch 207| loss: 1.23017 | val_0_accuracy: 0.56548 |  0:00:18s
# ⏱️ Epoch 208 took 0.09 seconds
# epoch 208| loss: 1.20289 | val_0_accuracy: 0.5619  |  0:00:18s
# ⏱️ Epoch 209 took 0.09 seconds
# epoch 209| loss: 1.16358 | val_0_accuracy: 0.57262 |  0:00:18s
# ⏱️ Epoch 210 took 0.09 seconds
# epoch 210| loss: 1.14888 | val_0_accuracy: 0.55357 |  0:00:18s
# ⏱️ Epoch 211 took 0.09 seconds
# epoch 211| loss: 1.13037 | val_0_accuracy: 0.55833 |  0:00:19s
# ⏱️ Epoch 212 took 0.09 seconds
# epoch 212| loss: 1.14523 | val_0_accuracy: 0.57143 |  0:00:19s
# ⏱️ Epoch 213 took 0.08 seconds
# epoch 213| loss: 1.14754 | val_0_accuracy: 0.56429 |  0:00:19s
# ⏱️ Epoch 214 took 0.09 seconds
# epoch 214| loss: 1.12157 | val_0_accuracy: 0.55952 |  0:00:19s
# ⏱️ Epoch 215 took 0.08 seconds
# epoch 215| loss: 1.2174  | val_0_accuracy: 0.55357 |  0:00:19s
# ⏱️ Epoch 216 took 0.09 seconds
# epoch 216| loss: 1.16335 | val_0_accuracy: 0.5369  |  0:00:19s
# ⏱️ Epoch 217 took 0.09 seconds
# epoch 217| loss: 1.13064 | val_0_accuracy: 0.58333 |  0:00:19s
# ⏱️ Epoch 218 took 0.09 seconds
# epoch 218| loss: 1.14423 | val_0_accuracy: 0.58095 |  0:00:19s
# ⏱️ Epoch 219 took 0.08 seconds
# epoch 219| loss: 1.13071 | val_0_accuracy: 0.57619 |  0:00:19s
# ⏱️ Epoch 220 took 0.08 seconds
# epoch 220| loss: 1.12681 | val_0_accuracy: 0.57619 |  0:00:19s
# ⏱️ Epoch 221 took 0.08 seconds
# epoch 221| loss: 1.16328 | val_0_accuracy: 0.55595 |  0:00:19s
# ⏱️ Epoch 222 took 0.09 seconds
# epoch 222| loss: 1.13267 | val_0_accuracy: 0.5631  |  0:00:19s
# ⏱️ Epoch 223 took 0.09 seconds
# epoch 223| loss: 1.11539 | val_0_accuracy: 0.56548 |  0:00:20s
# ⏱️ Epoch 224 took 0.08 seconds
# epoch 224| loss: 1.11949 | val_0_accuracy: 0.56786 |  0:00:20s
# ⏱️ Epoch 225 took 0.08 seconds
# epoch 225| loss: 1.12966 | val_0_accuracy: 0.57262 |  0:00:20s
# ⏱️ Epoch 226 took 0.08 seconds
# epoch 226| loss: 1.13525 | val_0_accuracy: 0.55119 |  0:00:20s
# ⏱️ Epoch 227 took 0.08 seconds
# epoch 227| loss: 1.23787 | val_0_accuracy: 0.56786 |  0:00:20s
# ⏱️ Epoch 228 took 0.09 seconds
# epoch 228| loss: 1.16448 | val_0_accuracy: 0.55714 |  0:00:20s
# ⏱️ Epoch 229 took 0.08 seconds
# epoch 229| loss: 1.13243 | val_0_accuracy: 0.56071 |  0:00:20s
# ⏱️ Epoch 230 took 0.08 seconds
# epoch 230| loss: 1.10207 | val_0_accuracy: 0.58333 |  0:00:20s
# ⏱️ Epoch 231 took 0.09 seconds
# epoch 231| loss: 1.08855 | val_0_accuracy: 0.58452 |  0:00:20s
# ⏱️ Epoch 232 took 0.09 seconds
# epoch 232| loss: 1.09013 | val_0_accuracy: 0.56905 |  0:00:20s
# ⏱️ Epoch 233 took 0.08 seconds
# epoch 233| loss: 1.12229 | val_0_accuracy: 0.57857 |  0:00:20s
# ⏱️ Epoch 234 took 0.08 seconds
# epoch 234| loss: 1.09643 | val_0_accuracy: 0.56548 |  0:00:20s
# ⏱️ Epoch 235 took 0.08 seconds
# epoch 235| loss: 1.14174 | val_0_accuracy: 0.56071 |  0:00:21s
# ⏱️ Epoch 236 took 0.08 seconds
# epoch 236| loss: 1.07879 | val_0_accuracy: 0.57738 |  0:00:21s
# ⏱️ Epoch 237 took 0.08 seconds
# epoch 237| loss: 1.11731 | val_0_accuracy: 0.56071 |  0:00:21s
# ⏱️ Epoch 238 took 0.07 seconds
# epoch 238| loss: 1.10731 | val_0_accuracy: 0.59167 |  0:00:21s
# ⏱️ Epoch 239 took 0.09 seconds
# epoch 239| loss: 1.10996 | val_0_accuracy: 0.57857 |  0:00:21s
# ⏱️ Epoch 240 took 0.08 seconds
# epoch 240| loss: 1.08212 | val_0_accuracy: 0.59524 |  0:00:21s
# ⏱️ Epoch 241 took 0.09 seconds
# epoch 241| loss: 1.05989 | val_0_accuracy: 0.55357 |  0:00:21s
# ⏱️ Epoch 242 took 0.08 seconds
# epoch 242| loss: 1.1124  | val_0_accuracy: 0.575   |  0:00:21s
# ⏱️ Epoch 243 took 0.10 seconds
# epoch 243| loss: 1.08914 | val_0_accuracy: 0.57381 |  0:00:21s
# ⏱️ Epoch 244 took 0.10 seconds
# epoch 244| loss: 1.09665 | val_0_accuracy: 0.5631  |  0:00:21s
# ⏱️ Epoch 245 took 0.08 seconds
# epoch 245| loss: 1.06059 | val_0_accuracy: 0.57857 |  0:00:21s
# ⏱️ Epoch 246 took 0.08 seconds
# epoch 246| loss: 1.027   | val_0_accuracy: 0.56667 |  0:00:21s
# ⏱️ Epoch 247 took 0.09 seconds
# epoch 247| loss: 1.07671 | val_0_accuracy: 0.57262 |  0:00:22s
# ⏱️ Epoch 248 took 0.09 seconds
# epoch 248| loss: 1.08095 | val_0_accuracy: 0.56429 |  0:00:22s
# ⏱️ Epoch 249 took 0.11 seconds
# epoch 249| loss: 1.09487 | val_0_accuracy: 0.56429 |  0:00:22s
# ⏱️ Epoch 250 took 0.14 seconds
# epoch 250| loss: 1.0715  | val_0_accuracy: 0.5619  |  0:00:22s
# ⏱️ Epoch 251 took 0.13 seconds
# epoch 251| loss: 1.05354 | val_0_accuracy: 0.56429 |  0:00:22s
# ⏱️ Epoch 252 took 0.12 seconds
# epoch 252| loss: 1.12844 | val_0_accuracy: 0.5619  |  0:00:22s
# ⏱️ Epoch 253 took 0.26 seconds
# epoch 253| loss: 1.06202 | val_0_accuracy: 0.48333 |  0:00:22s
# ⏱️ Epoch 254 took 0.08 seconds
# epoch 254| loss: 1.13559 | val_0_accuracy: 0.54524 |  0:00:23s
# ⏱️ Epoch 255 took 0.09 seconds
# epoch 255| loss: 1.10119 | val_0_accuracy: 0.5869  |  0:00:23s
# ⏱️ Epoch 256 took 0.09 seconds
# epoch 256| loss: 1.03322 | val_0_accuracy: 0.58452 |  0:00:23s
# ⏱️ Epoch 257 took 0.09 seconds
# epoch 257| loss: 1.09028 | val_0_accuracy: 0.57857 |  0:00:23s
# ⏱️ Epoch 258 took 0.09 seconds
# epoch 258| loss: 1.04085 | val_0_accuracy: 0.59643 |  0:00:23s
# ⏱️ Epoch 259 took 0.09 seconds
# epoch 259| loss: 1.04613 | val_0_accuracy: 0.57976 |  0:00:23s
# ⏱️ Epoch 260 took 0.10 seconds
# epoch 260| loss: 1.07106 | val_0_accuracy: 0.58333 |  0:00:23s
# ⏱️ Epoch 261 took 0.09 seconds
# epoch 261| loss: 1.08629 | val_0_accuracy: 0.54881 |  0:00:23s
# ⏱️ Epoch 262 took 0.08 seconds
# epoch 262| loss: 1.05968 | val_0_accuracy: 0.55357 |  0:00:23s
# ⏱️ Epoch 263 took 0.10 seconds
# epoch 263| loss: 1.04286 | val_0_accuracy: 0.60714 |  0:00:23s
# ⏱️ Epoch 264 took 0.09 seconds
# epoch 264| loss: 1.06129 | val_0_accuracy: 0.57976 |  0:00:23s
# ⏱️ Epoch 265 took 0.11 seconds
# epoch 265| loss: 1.10885 | val_0_accuracy: 0.56905 |  0:00:24s
# ⏱️ Epoch 266 took 0.08 seconds
# epoch 266| loss: 1.06509 | val_0_accuracy: 0.56071 |  0:00:24s
# ⏱️ Epoch 267 took 0.09 seconds
# epoch 267| loss: 1.04243 | val_0_accuracy: 0.56548 |  0:00:24s
# ⏱️ Epoch 268 took 0.09 seconds
# epoch 268| loss: 1.05914 | val_0_accuracy: 0.54286 |  0:00:24s
# ⏱️ Epoch 269 took 0.09 seconds
# epoch 269| loss: 1.14296 | val_0_accuracy: 0.57738 |  0:00:24s
# ⏱️ Epoch 270 took 0.08 seconds
# epoch 270| loss: 1.09087 | val_0_accuracy: 0.54881 |  0:00:24s
# ⏱️ Epoch 271 took 0.07 seconds
# epoch 271| loss: 1.0788  | val_0_accuracy: 0.52381 |  0:00:24s
# ⏱️ Epoch 272 took 0.08 seconds
# epoch 272| loss: 1.08722 | val_0_accuracy: 0.55952 |  0:00:24s
# ⏱️ Epoch 273 took 0.09 seconds
# epoch 273| loss: 1.06728 | val_0_accuracy: 0.56905 |  0:00:24s
# ⏱️ Epoch 274 took 0.09 seconds
# epoch 274| loss: 1.02814 | val_0_accuracy: 0.57738 |  0:00:24s
# ⏱️ Epoch 275 took 0.09 seconds
# epoch 275| loss: 1.05711 | val_0_accuracy: 0.55833 |  0:00:24s
# ⏱️ Epoch 276 took 0.09 seconds
# epoch 276| loss: 1.13996 | val_0_accuracy: 0.55    |  0:00:24s
# ⏱️ Epoch 277 took 0.08 seconds
# epoch 277| loss: 1.0798  | val_0_accuracy: 0.56071 |  0:00:25s
# ⏱️ Epoch 278 took 0.08 seconds
# epoch 278| loss: 1.07676 | val_0_accuracy: 0.5131  |  0:00:25s
# ⏱️ Epoch 279 took 0.09 seconds
# epoch 279| loss: 1.02329 | val_0_accuracy: 0.53571 |  0:00:25s
# ⏱️ Epoch 280 took 0.09 seconds
# epoch 280| loss: 1.04672 | val_0_accuracy: 0.56548 |  0:00:25s
# ⏱️ Epoch 281 took 0.09 seconds
# epoch 281| loss: 1.04761 | val_0_accuracy: 0.53929 |  0:00:25s
# ⏱️ Epoch 282 took 0.09 seconds
# epoch 282| loss: 1.01968 | val_0_accuracy: 0.57262 |  0:00:25s
# ⏱️ Epoch 283 took 0.09 seconds
# epoch 283| loss: 1.01246 | val_0_accuracy: 0.55476 |  0:00:25s
# ⏱️ Epoch 284 took 0.08 seconds
# epoch 284| loss: 1.0405  | val_0_accuracy: 0.54405 |  0:00:25s
# ⏱️ Epoch 285 took 0.08 seconds
# epoch 285| loss: 0.9661  | val_0_accuracy: 0.575   |  0:00:25s
# ⏱️ Epoch 286 took 0.09 seconds
# epoch 286| loss: 0.98688 | val_0_accuracy: 0.57738 |  0:00:25s
# ⏱️ Epoch 287 took 0.09 seconds
# epoch 287| loss: 1.01283 | val_0_accuracy: 0.57262 |  0:00:25s
# ⏱️ Epoch 288 took 0.09 seconds
# epoch 288| loss: 1.04076 | val_0_accuracy: 0.575   |  0:00:25s
# ⏱️ Epoch 289 took 0.09 seconds
# epoch 289| loss: 1.02663 | val_0_accuracy: 0.54881 |  0:00:26s
# ⏱️ Epoch 290 took 0.09 seconds
# epoch 290| loss: 1.06146 | val_0_accuracy: 0.575   |  0:00:26s
# ⏱️ Epoch 291 took 0.08 seconds
# epoch 291| loss: 1.07951 | val_0_accuracy: 0.575   |  0:00:26s
# ⏱️ Epoch 292 took 0.08 seconds
# epoch 292| loss: 1.05643 | val_0_accuracy: 0.57976 |  0:00:26s
# ⏱️ Epoch 293 took 0.09 seconds
# epoch 293| loss: 1.0034  | val_0_accuracy: 0.57262 |  0:00:26s
# ⏱️ Epoch 294 took 0.09 seconds
# epoch 294| loss: 1.03468 | val_0_accuracy: 0.56429 |  0:00:26s
# ⏱️ Epoch 295 took 0.09 seconds
# epoch 295| loss: 0.98793 | val_0_accuracy: 0.55    |  0:00:26s
# ⏱️ Epoch 296 took 0.09 seconds
# epoch 296| loss: 0.99899 | val_0_accuracy: 0.5619  |  0:00:26s
# ⏱️ Epoch 297 took 0.08 seconds
# epoch 297| loss: 1.01726 | val_0_accuracy: 0.58095 |  0:00:26s
# ⏱️ Epoch 298 took 0.08 seconds
# epoch 298| loss: 1.02325 | val_0_accuracy: 0.57619 |  0:00:26s
# ⏱️ Epoch 299 took 0.08 seconds
# epoch 299| loss: 0.99338 | val_0_accuracy: 0.59524 |  0:00:26s
# ⏱️ Epoch 300 took 0.08 seconds
# epoch 300| loss: 0.99445 | val_0_accuracy: 0.575   |  0:00:26s
# ⏱️ Epoch 301 took 0.10 seconds
# epoch 301| loss: 0.98798 | val_0_accuracy: 0.56667 |  0:00:27s
# ⏱️ Epoch 302 took 0.10 seconds
# epoch 302| loss: 0.99748 | val_0_accuracy: 0.5881  |  0:00:27s
# ⏱️ Epoch 303 took 0.08 seconds
# epoch 303| loss: 0.98237 | val_0_accuracy: 0.5869  |  0:00:27s
# ⏱️ Epoch 304 took 0.09 seconds
# epoch 304| loss: 1.0317  | val_0_accuracy: 0.58214 |  0:00:27s
# ⏱️ Epoch 305 took 0.08 seconds
# epoch 305| loss: 0.98578 | val_0_accuracy: 0.57619 |  0:00:27s
# ⏱️ Epoch 306 took 0.08 seconds
# epoch 306| loss: 0.99682 | val_0_accuracy: 0.58333 |  0:00:27s
# ⏱️ Epoch 307 took 0.08 seconds
# epoch 307| loss: 0.98237 | val_0_accuracy: 0.55952 |  0:00:27s
# ⏱️ Epoch 308 took 0.08 seconds
# epoch 308| loss: 0.9627  | val_0_accuracy: 0.58571 |  0:00:27s
# ⏱️ Epoch 309 took 0.09 seconds
# epoch 309| loss: 1.01715 | val_0_accuracy: 0.56429 |  0:00:27s
# ⏱️ Epoch 310 took 0.09 seconds
# epoch 310| loss: 0.99373 | val_0_accuracy: 0.57857 |  0:00:27s
# ⏱️ Epoch 311 took 0.08 seconds
# epoch 311| loss: 1.02945 | val_0_accuracy: 0.5881  |  0:00:27s
# ⏱️ Epoch 312 took 0.08 seconds
# epoch 312| loss: 0.98631 | val_0_accuracy: 0.57976 |  0:00:27s
# ⏱️ Epoch 313 took 0.09 seconds
# epoch 313| loss: 0.99724 | val_0_accuracy: 0.57262 |  0:00:28s
# ⏱️ Epoch 314 took 0.08 seconds
# epoch 314| loss: 0.94939 | val_0_accuracy: 0.55714 |  0:00:28s
# ⏱️ Epoch 315 took 0.09 seconds
# epoch 315| loss: 0.95449 | val_0_accuracy: 0.57381 |  0:00:28s
# ⏱️ Epoch 316 took 0.08 seconds
# epoch 316| loss: 0.97774 | val_0_accuracy: 0.56429 |  0:00:28s
# ⏱️ Epoch 317 took 0.09 seconds
# epoch 317| loss: 0.94776 | val_0_accuracy: 0.58571 |  0:00:28s
# ⏱️ Epoch 318 took 0.08 seconds
# epoch 318| loss: 0.97181 | val_0_accuracy: 0.58214 |  0:00:28s
# ⏱️ Epoch 319 took 0.08 seconds
# epoch 319| loss: 0.94217 | val_0_accuracy: 0.55357 |  0:00:28s
# ⏱️ Epoch 320 took 0.09 seconds
# epoch 320| loss: 1.04976 | val_0_accuracy: 0.49881 |  0:00:28s
# ⏱️ Epoch 321 took 0.09 seconds
# epoch 321| loss: 1.04155 | val_0_accuracy: 0.55833 |  0:00:28s
# ⏱️ Epoch 322 took 0.09 seconds
# epoch 322| loss: 0.98394 | val_0_accuracy: 0.57857 |  0:00:28s
# ⏱️ Epoch 323 took 0.08 seconds
# epoch 323| loss: 0.98191 | val_0_accuracy: 0.57381 |  0:00:28s
# ⏱️ Epoch 324 took 0.07 seconds
# epoch 324| loss: 0.97351 | val_0_accuracy: 0.57143 |  0:00:28s
# ⏱️ Epoch 325 took 0.08 seconds
# epoch 325| loss: 1.03982 | val_0_accuracy: 0.59286 |  0:00:29s
# ⏱️ Epoch 326 took 0.09 seconds
# epoch 326| loss: 0.98343 | val_0_accuracy: 0.56071 |  0:00:29s
# ⏱️ Epoch 327 took 0.09 seconds
# epoch 327| loss: 0.98417 | val_0_accuracy: 0.57976 |  0:00:29s
# ⏱️ Epoch 328 took 0.09 seconds
# epoch 328| loss: 0.976   | val_0_accuracy: 0.55952 |  0:00:29s
# ⏱️ Epoch 329 took 0.09 seconds
# epoch 329| loss: 1.00788 | val_0_accuracy: 0.58214 |  0:00:29s
# ⏱️ Epoch 330 took 0.08 seconds
# epoch 330| loss: 1.02467 | val_0_accuracy: 0.54762 |  0:00:29s
# ⏱️ Epoch 331 took 0.08 seconds
# epoch 331| loss: 0.97102 | val_0_accuracy: 0.575   |  0:00:29s
# ⏱️ Epoch 332 took 0.08 seconds
# epoch 332| loss: 0.98165 | val_0_accuracy: 0.54167 |  0:00:29s
# ⏱️ Epoch 333 took 0.08 seconds
# epoch 333| loss: 1.01631 | val_0_accuracy: 0.5869  |  0:00:29s
# ⏱️ Epoch 334 took 0.09 seconds
# epoch 334| loss: 0.94978 | val_0_accuracy: 0.57738 |  0:00:29s
# ⏱️ Epoch 335 took 0.09 seconds
# epoch 335| loss: 0.94923 | val_0_accuracy: 0.57619 |  0:00:29s
# ⏱️ Epoch 336 took 0.08 seconds
# epoch 336| loss: 0.94309 | val_0_accuracy: 0.57976 |  0:00:30s
# ⏱️ Epoch 337 took 0.08 seconds
# epoch 337| loss: 0.94021 | val_0_accuracy: 0.57619 |  0:00:30s
# ⏱️ Epoch 338 took 0.08 seconds
# epoch 338| loss: 0.95527 | val_0_accuracy: 0.58452 |  0:00:30s
# ⏱️ Epoch 339 took 0.08 seconds
# epoch 339| loss: 0.95466 | val_0_accuracy: 0.57857 |  0:00:30s
# ⏱️ Epoch 340 took 0.09 seconds
# epoch 340| loss: 0.98621 | val_0_accuracy: 0.57262 |  0:00:30s
# ⏱️ Epoch 341 took 0.08 seconds
# epoch 341| loss: 0.92767 | val_0_accuracy: 0.55476 |  0:00:30s
# ⏱️ Epoch 342 took 0.07 seconds
# epoch 342| loss: 0.9449  | val_0_accuracy: 0.58333 |  0:00:30s
# ⏱️ Epoch 343 took 0.09 seconds
# epoch 343| loss: 1.02262 | val_0_accuracy: 0.56905 |  0:00:30s
# ⏱️ Epoch 344 took 0.08 seconds
# epoch 344| loss: 0.99455 | val_0_accuracy: 0.57262 |  0:00:30s
# ⏱️ Epoch 345 took 0.09 seconds
# epoch 345| loss: 0.95204 | val_0_accuracy: 0.58571 |  0:00:30s
# ⏱️ Epoch 346 took 0.08 seconds
# epoch 346| loss: 0.92007 | val_0_accuracy: 0.57143 |  0:00:30s
# ⏱️ Epoch 347 took 0.08 seconds
# epoch 347| loss: 1.01045 | val_0_accuracy: 0.5881  |  0:00:30s
# ⏱️ Epoch 348 took 0.09 seconds
# epoch 348| loss: 0.97113 | val_0_accuracy: 0.55952 |  0:00:31s
# ⏱️ Epoch 349 took 0.09 seconds
# epoch 349| loss: 0.94725 | val_0_accuracy: 0.5631  |  0:00:31s
# ⏱️ Epoch 350 took 0.09 seconds
# epoch 350| loss: 0.93751 | val_0_accuracy: 0.57619 |  0:00:31s
# ⏱️ Epoch 351 took 0.09 seconds
# epoch 351| loss: 1.04574 | val_0_accuracy: 0.57143 |  0:00:31s
# ⏱️ Epoch 352 took 0.09 seconds
# epoch 352| loss: 0.92169 | val_0_accuracy: 0.55357 |  0:00:31s
# ⏱️ Epoch 353 took 0.09 seconds
# epoch 353| loss: 0.91358 | val_0_accuracy: 0.5619  |  0:00:31s
# ⏱️ Epoch 354 took 0.09 seconds
# epoch 354| loss: 0.90011 | val_0_accuracy: 0.57143 |  0:00:31s
# ⏱️ Epoch 355 took 0.08 seconds
# epoch 355| loss: 0.91753 | val_0_accuracy: 0.5869  |  0:00:31s
# ⏱️ Epoch 356 took 0.08 seconds
# epoch 356| loss: 0.89976 | val_0_accuracy: 0.59048 |  0:00:31s
# ⏱️ Epoch 357 took 0.08 seconds
# epoch 357| loss: 0.94777 | val_0_accuracy: 0.59048 |  0:00:31s
# ⏱️ Epoch 358 took 0.09 seconds
# epoch 358| loss: 0.93268 | val_0_accuracy: 0.57381 |  0:00:31s
# ⏱️ Epoch 359 took 0.09 seconds
# epoch 359| loss: 1.03046 | val_0_accuracy: 0.57262 |  0:00:31s
# ⏱️ Epoch 360 took 0.08 seconds
# epoch 360| loss: 0.90877 | val_0_accuracy: 0.55952 |  0:00:32s
# ⏱️ Epoch 361 took 0.08 seconds
# epoch 361| loss: 0.89278 | val_0_accuracy: 0.58571 |  0:00:32s
# ⏱️ Epoch 362 took 0.08 seconds
# epoch 362| loss: 0.95626 | val_0_accuracy: 0.5619  |  0:00:32s
# ⏱️ Epoch 363 took 0.08 seconds
# epoch 363| loss: 0.92949 | val_0_accuracy: 0.5631  |  0:00:32s
# ⏱️ Epoch 364 took 0.08 seconds
# epoch 364| loss: 0.86945 | val_0_accuracy: 0.575   |  0:00:32s
# ⏱️ Epoch 365 took 0.09 seconds
# epoch 365| loss: 0.90542 | val_0_accuracy: 0.58452 |  0:00:32s
# ⏱️ Epoch 366 took 0.08 seconds
# epoch 366| loss: 0.89631 | val_0_accuracy: 0.54762 |  0:00:32s
# ⏱️ Epoch 367 took 0.09 seconds
# epoch 367| loss: 0.89797 | val_0_accuracy: 0.5869  |  0:00:32s
# ⏱️ Epoch 368 took 0.08 seconds
# epoch 368| loss: 0.96629 | val_0_accuracy: 0.57381 |  0:00:32s
# ⏱️ Epoch 369 took 0.09 seconds
# epoch 369| loss: 0.89499 | val_0_accuracy: 0.57738 |  0:00:32s
# ⏱️ Epoch 370 took 0.08 seconds
# epoch 370| loss: 0.9128  | val_0_accuracy: 0.5369  |  0:00:32s
# ⏱️ Epoch 371 took 0.09 seconds
# epoch 371| loss: 0.94453 | val_0_accuracy: 0.56786 |  0:00:32s
# ⏱️ Epoch 372 took 0.09 seconds
# epoch 372| loss: 0.91714 | val_0_accuracy: 0.57024 |  0:00:33s
# ⏱️ Epoch 373 took 0.09 seconds
# epoch 373| loss: 0.90786 | val_0_accuracy: 0.57024 |  0:00:33s
# ⏱️ Epoch 374 took 0.08 seconds
# epoch 374| loss: 0.93467 | val_0_accuracy: 0.58214 |  0:00:33s
# ⏱️ Epoch 375 took 0.07 seconds
# epoch 375| loss: 0.90235 | val_0_accuracy: 0.57976 |  0:00:33s
# ⏱️ Epoch 376 took 0.08 seconds
# epoch 376| loss: 0.89639 | val_0_accuracy: 0.57857 |  0:00:33s
# ⏱️ Epoch 377 took 0.08 seconds
# epoch 377| loss: 0.91368 | val_0_accuracy: 0.58214 |  0:00:33s
# ⏱️ Epoch 378 took 0.08 seconds
# epoch 378| loss: 0.92143 | val_0_accuracy: 0.56429 |  0:00:33s
# ⏱️ Epoch 379 took 0.08 seconds
# epoch 379| loss: 0.94441 | val_0_accuracy: 0.55357 |  0:00:33s
# ⏱️ Epoch 380 took 0.07 seconds
# epoch 380| loss: 0.87955 | val_0_accuracy: 0.57976 |  0:00:33s
# ⏱️ Epoch 381 took 0.09 seconds
# epoch 381| loss: 0.90008 | val_0_accuracy: 0.55595 |  0:00:33s
# ⏱️ Epoch 382 took 0.08 seconds
# epoch 382| loss: 0.87464 | val_0_accuracy: 0.58571 |  0:00:33s
# ⏱️ Epoch 383 took 0.08 seconds
# epoch 383| loss: 0.85931 | val_0_accuracy: 0.55595 |  0:00:33s
# ⏱️ Epoch 384 took 0.08 seconds
# epoch 384| loss: 0.95806 | val_0_accuracy: 0.56071 |  0:00:34s
# ⏱️ Epoch 385 took 0.08 seconds
# epoch 385| loss: 0.89542 | val_0_accuracy: 0.56905 |  0:00:34s
# ⏱️ Epoch 386 took 0.11 seconds
# epoch 386| loss: 0.89717 | val_0_accuracy: 0.56548 |  0:00:34s
# ⏱️ Epoch 387 took 0.09 seconds
# epoch 387| loss: 0.89785 | val_0_accuracy: 0.57976 |  0:00:34s
# ⏱️ Epoch 388 took 0.09 seconds
# epoch 388| loss: 0.92231 | val_0_accuracy: 0.58214 |  0:00:34s
# ⏱️ Epoch 389 took 0.09 seconds
# epoch 389| loss: 0.9197  | val_0_accuracy: 0.59881 |  0:00:34s
# ⏱️ Epoch 390 took 0.10 seconds
# epoch 390| loss: 0.93786 | val_0_accuracy: 0.57976 |  0:00:34s
# ⏱️ Epoch 391 took 0.10 seconds
# epoch 391| loss: 0.94314 | val_0_accuracy: 0.575   |  0:00:34s
# ⏱️ Epoch 392 took 0.09 seconds
# epoch 392| loss: 0.93681 | val_0_accuracy: 0.57976 |  0:00:34s
# ⏱️ Epoch 393 took 0.09 seconds
# epoch 393| loss: 0.95674 | val_0_accuracy: 0.58571 |  0:00:34s
# ⏱️ Epoch 394 took 0.09 seconds
# epoch 394| loss: 0.91253 | val_0_accuracy: 0.58452 |  0:00:34s
# ⏱️ Epoch 395 took 0.08 seconds
# epoch 395| loss: 0.89297 | val_0_accuracy: 0.55714 |  0:00:35s
# ⏱️ Epoch 396 took 0.08 seconds
# epoch 396| loss: 0.88512 | val_0_accuracy: 0.57738 |  0:00:35s
# ⏱️ Epoch 397 took 0.09 seconds
# epoch 397| loss: 0.84939 | val_0_accuracy: 0.53333 |  0:00:35s
# ⏱️ Epoch 398 took 0.09 seconds
# epoch 398| loss: 0.91406 | val_0_accuracy: 0.54762 |  0:00:35s
# ⏱️ Epoch 399 took 0.09 seconds
# epoch 399| loss: 0.83767 | val_0_accuracy: 0.55595 |  0:00:35s
# ⏱️ Epoch 400 took 0.09 seconds
# epoch 400| loss: 0.87543 | val_0_accuracy: 0.5631  |  0:00:35s
# ⏱️ Epoch 401 took 0.08 seconds
# epoch 401| loss: 0.87123 | val_0_accuracy: 0.56786 |  0:00:35s
# ⏱️ Epoch 402 took 0.08 seconds
# epoch 402| loss: 0.90584 | val_0_accuracy: 0.54405 |  0:00:35s
# ⏱️ Epoch 403 took 0.09 seconds
# epoch 403| loss: 0.9053  | val_0_accuracy: 0.60357 |  0:00:35s
# ⏱️ Epoch 404 took 0.09 seconds
# epoch 404| loss: 0.8783  | val_0_accuracy: 0.59048 |  0:00:35s
# ⏱️ Epoch 405 took 0.08 seconds
# epoch 405| loss: 0.92478 | val_0_accuracy: 0.58571 |  0:00:35s
# ⏱️ Epoch 406 took 0.09 seconds
# epoch 406| loss: 0.87296 | val_0_accuracy: 0.59286 |  0:00:35s
# ⏱️ Epoch 407 took 0.08 seconds
# epoch 407| loss: 0.87262 | val_0_accuracy: 0.59405 |  0:00:36s
# ⏱️ Epoch 408 took 0.08 seconds
# epoch 408| loss: 0.96279 | val_0_accuracy: 0.58929 |  0:00:36s
# ⏱️ Epoch 409 took 0.08 seconds
# epoch 409| loss: 0.89666 | val_0_accuracy: 0.59048 |  0:00:36s
# ⏱️ Epoch 410 took 0.09 seconds
# epoch 410| loss: 0.88947 | val_0_accuracy: 0.57381 |  0:00:36s
# ⏱️ Epoch 411 took 0.09 seconds
# epoch 411| loss: 0.90482 | val_0_accuracy: 0.54524 |  0:00:36s
# ⏱️ Epoch 412 took 0.08 seconds
# epoch 412| loss: 0.88715 | val_0_accuracy: 0.56429 |  0:00:36s
# ⏱️ Epoch 413 took 0.08 seconds
# epoch 413| loss: 0.90877 | val_0_accuracy: 0.57619 |  0:00:36s
# ⏱️ Epoch 414 took 0.07 seconds
# epoch 414| loss: 0.86798 | val_0_accuracy: 0.54286 |  0:00:36s
# ⏱️ Epoch 415 took 0.08 seconds
# epoch 415| loss: 0.92176 | val_0_accuracy: 0.57262 |  0:00:36s
# ⏱️ Epoch 416 took 0.09 seconds
# epoch 416| loss: 0.98877 | val_0_accuracy: 0.5631  |  0:00:36s
# ⏱️ Epoch 417 took 0.08 seconds
# epoch 417| loss: 0.89632 | val_0_accuracy: 0.57143 |  0:00:36s
# ⏱️ Epoch 418 took 0.08 seconds
# epoch 418| loss: 0.85403 | val_0_accuracy: 0.52857 |  0:00:36s
# ⏱️ Epoch 419 took 0.07 seconds
# epoch 419| loss: 0.89898 | val_0_accuracy: 0.55595 |  0:00:37s
# ⏱️ Epoch 420 took 0.08 seconds
# epoch 420| loss: 0.86603 | val_0_accuracy: 0.59405 |  0:00:37s
# ⏱️ Epoch 421 took 0.09 seconds
# epoch 421| loss: 0.89798 | val_0_accuracy: 0.59524 |  0:00:37s
# ⏱️ Epoch 422 took 0.09 seconds
# epoch 422| loss: 0.90639 | val_0_accuracy: 0.59167 |  0:00:37s
# ⏱️ Epoch 423 took 0.10 seconds
# epoch 423| loss: 0.8851  | val_0_accuracy: 0.575   |  0:00:37s
# ⏱️ Epoch 424 took 0.10 seconds
# epoch 424| loss: 0.85528 | val_0_accuracy: 0.58214 |  0:00:37s
# ⏱️ Epoch 425 took 0.11 seconds
# epoch 425| loss: 0.87    | val_0_accuracy: 0.55238 |  0:00:37s
# ⏱️ Epoch 426 took 0.10 seconds
# epoch 426| loss: 0.89474 | val_0_accuracy: 0.57143 |  0:00:37s
# ⏱️ Epoch 427 took 0.09 seconds
# epoch 427| loss: 0.91391 | val_0_accuracy: 0.5619  |  0:00:37s
# ⏱️ Epoch 428 took 0.09 seconds
# epoch 428| loss: 0.86128 | val_0_accuracy: 0.59762 |  0:00:37s
# ⏱️ Epoch 429 took 0.09 seconds
# epoch 429| loss: 0.85831 | val_0_accuracy: 0.58214 |  0:00:37s
# ⏱️ Epoch 430 took 0.09 seconds
# epoch 430| loss: 0.85838 | val_0_accuracy: 0.57857 |  0:00:38s
# ⏱️ Epoch 431 took 0.10 seconds
# epoch 431| loss: 0.86079 | val_0_accuracy: 0.5869  |  0:00:38s
# ⏱️ Epoch 432 took 0.09 seconds
# epoch 432| loss: 0.88913 | val_0_accuracy: 0.56905 |  0:00:38s
# ⏱️ Epoch 433 took 0.08 seconds
# epoch 433| loss: 0.92304 | val_0_accuracy: 0.575   |  0:00:38s
# ⏱️ Epoch 434 took 0.08 seconds
# epoch 434| loss: 0.82522 | val_0_accuracy: 0.59881 |  0:00:38s
# ⏱️ Epoch 435 took 0.09 seconds
# epoch 435| loss: 0.8913  | val_0_accuracy: 0.57738 |  0:00:38s
# ⏱️ Epoch 436 took 0.09 seconds
# epoch 436| loss: 0.82952 | val_0_accuracy: 0.57738 |  0:00:38s
# ⏱️ Epoch 437 took 0.09 seconds
# epoch 437| loss: 0.84544 | val_0_accuracy: 0.57857 |  0:00:38s
# ⏱️ Epoch 438 took 0.25 seconds
# epoch 438| loss: 0.87057 | val_0_accuracy: 0.59643 |  0:00:38s
# ⏱️ Epoch 439 took 0.09 seconds
# epoch 439| loss: 0.83804 | val_0_accuracy: 0.56071 |  0:00:38s
# ⏱️ Epoch 440 took 0.09 seconds
# epoch 440| loss: 0.86098 | val_0_accuracy: 0.59286 |  0:00:39s
# ⏱️ Epoch 441 took 0.09 seconds
# epoch 441| loss: 0.83436 | val_0_accuracy: 0.59643 |  0:00:39s
# ⏱️ Epoch 442 took 0.09 seconds
# epoch 442| loss: 0.86951 | val_0_accuracy: 0.57381 |  0:00:39s
# ⏱️ Epoch 443 took 0.08 seconds
# epoch 443| loss: 0.834   | val_0_accuracy: 0.58333 |  0:00:39s
# ⏱️ Epoch 444 took 0.07 seconds
# epoch 444| loss: 0.84331 | val_0_accuracy: 0.57262 |  0:00:39s
# ⏱️ Epoch 445 took 0.08 seconds
# epoch 445| loss: 0.85546 | val_0_accuracy: 0.6     |  0:00:39s
# ⏱️ Epoch 446 took 0.09 seconds
# epoch 446| loss: 0.86465 | val_0_accuracy: 0.54167 |  0:00:39s
# ⏱️ Epoch 447 took 0.08 seconds
# epoch 447| loss: 0.86571 | val_0_accuracy: 0.55    |  0:00:39s
# ⏱️ Epoch 448 took 0.08 seconds
# epoch 448| loss: 0.85384 | val_0_accuracy: 0.56667 |  0:00:39s
# ⏱️ Epoch 449 took 0.07 seconds
# epoch 449| loss: 0.83901 | val_0_accuracy: 0.60357 |  0:00:39s
# ⏱️ Epoch 450 took 0.09 seconds
# epoch 450| loss: 0.83907 | val_0_accuracy: 0.58333 |  0:00:39s
# ⏱️ Epoch 451 took 0.08 seconds
# epoch 451| loss: 0.86111 | val_0_accuracy: 0.60238 |  0:00:39s
# ⏱️ Epoch 452 took 0.08 seconds
# epoch 452| loss: 0.8536  | val_0_accuracy: 0.5869  |  0:00:40s
# ⏱️ Epoch 453 took 0.08 seconds
# epoch 453| loss: 0.85415 | val_0_accuracy: 0.59762 |  0:00:40s
# ⏱️ Epoch 454 took 0.10 seconds
# epoch 454| loss: 0.85053 | val_0_accuracy: 0.56071 |  0:00:40s
# ⏱️ Epoch 455 took 0.08 seconds
# epoch 455| loss: 0.80497 | val_0_accuracy: 0.59167 |  0:00:40s
# ⏱️ Epoch 456 took 0.09 seconds
# epoch 456| loss: 0.84602 | val_0_accuracy: 0.60476 |  0:00:40s
# ⏱️ Epoch 457 took 0.08 seconds
# epoch 457| loss: 0.85699 | val_0_accuracy: 0.57857 |  0:00:40s
# ⏱️ Epoch 458 took 0.09 seconds
# epoch 458| loss: 0.81851 | val_0_accuracy: 0.56548 |  0:00:40s
# ⏱️ Epoch 459 took 0.09 seconds
# epoch 459| loss: 0.87813 | val_0_accuracy: 0.57143 |  0:00:40s
# ⏱️ Epoch 460 took 0.08 seconds
# epoch 460| loss: 0.82021 | val_0_accuracy: 0.5369  |  0:00:40s
# ⏱️ Epoch 461 took 0.08 seconds
# epoch 461| loss: 0.83523 | val_0_accuracy: 0.5631  |  0:00:40s
# ⏱️ Epoch 462 took 0.09 seconds
# epoch 462| loss: 0.80981 | val_0_accuracy: 0.5631  |  0:00:40s
# ⏱️ Epoch 463 took 0.09 seconds
# epoch 463| loss: 0.85383 | val_0_accuracy: 0.57619 |  0:00:40s
# ⏱️ Epoch 464 took 0.08 seconds
#
# Early stopping occurred at epoch 463 with best_epoch = 263 and best_val_0_accuracy = 0.60714

# %%
_, _, _, _, _, le = split_data(traindata, testdata)

# %%
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

file_path = os.path.join("results", f"gtd{partition}.txt")

# Predict class indices for test set
y_pred = final_model.predict(Xtest)
y_proba = final_model.predict_proba(Xtest)
y_pred_decoded = le.inverse_transform(y_pred)
y_true_decoded = le.inverse_transform(Ytest)

# Make sure the directory exists
os.makedirs("results", exist_ok=True)

# Compute accuracy from decoded labels
acc = accuracy_score(y_true_decoded, y_pred_decoded)

# Write metrics to file
with open(file_path, "w") as file:
    file.write(f"Accuracy: {acc:.4f}\n")
    file.write(f"Precision weighted: {precision_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Recall weighted: {recall_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"F1 Score weighted: {f1_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Precision micro: {precision_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Recall micro: {recall_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"F1 Score micro: {f1_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Precision macro: {precision_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"Recall macro: {recall_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"F1 Score macro: {f1_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"roc auc weighted: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='weighted'):.4f}\n")
    file.write(f"roc auc macro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='macro'):.4f}\n")
    file.write(f"roc auc micro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='micro'):.4f}\n")

with open(f"results/epoch_time_gtd{partition}.txt", "w") as f:
    f.write('\n'.join(str(x) for x in epoch_timer.epoch_times))

# %%
print(classification_report(Ytest_decoded, y_pred_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.31      0.18      0.23        60
#         African National Congress (South Africa)       0.49      0.65      0.56        60
#                                 Al-Qaida in Iraq       0.37      0.57      0.45        60
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.24      0.33      0.28        60
#                                       Al-Shabaab       0.33      0.25      0.29        60
#              Basque Fatherland and Freedom (ETA)       0.55      0.78      0.65        60
#                                       Boko Haram       0.28      0.27      0.27        60
#   Communist Party of India - Maoist (CPI-Maoist)       0.53      0.65      0.58        60
#        Corsican National Liberation Front (FLNC)       0.61      0.72      0.66        60
#                        Donetsk People's Republic       0.55      0.57      0.56        60
# Farabundo Marti National Liberation Front (FMLN)       0.59      0.53      0.56        60
#                                Fulani extremists       0.61      0.78      0.69        60
#                  Houthi extremists (Ansar Allah)       0.48      0.48      0.48        60
#                      Irish Republican Army (IRA)       0.84      0.78      0.81        60
#      Islamic State of Iraq and the Levant (ISIL)       0.29      0.22      0.25        60
#                   Kurdistan Workers' Party (PKK)       0.25      0.28      0.27        60
#          Liberation Tigers of Tamil Eelam (LTTE)       0.56      0.67      0.61        60
#          Manuel Rodriguez Patriotic Front (FPMR)       0.75      0.83      0.79        60
#                                          Maoists       0.51      0.45      0.48        60
#                                Muslim extremists       0.47      0.28      0.35        60
#       National Liberation Army of Colombia (ELN)       0.76      0.53      0.63        60
#                          New People's Army (NPA)       0.62      0.53      0.57        60
#                Nicaraguan Democratic Force (FDN)       0.57      0.77      0.65        60
#                                     Palestinians       0.84      0.72      0.77        60
#    Revolutionary Armed Forces of Colombia (FARC)       0.50      0.32      0.39        60
#                                Shining Path (SL)       0.56      0.53      0.55        60
#                                  Sikh Extremists       0.67      0.48      0.56        60
#                                          Taliban       0.38      0.30      0.33        60
#                  Tehrik-i-Taliban Pakistan (TTP)       0.65      0.52      0.57        60
#        Tupac Amaru Revolutionary Movement (MRTA)       0.66      0.75      0.70        60
#
#                                         accuracy                           0.52      1800
#                                        macro avg       0.53      0.52      0.52      1800
#                                     weighted avg       0.53      0.52      0.52      1800

# %%
def plot_confusion_matrix(y_true, y_pred, labels):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"results/confusion_matrix_partition_{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
# Get all unique class labels from the truths
class_labels = np.unique(Ytest_decoded)

plot_confusion_matrix(Ytest_decoded, y_pred_decoded, labels=class_labels)
# Out:
# Saved confusion matrix for partition 200 to results/confusion_matrix_partition_200.png
