# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer
import sys

# %%
partition = 300

# %%
# !{sys.executable} -m pip install pytorch-tabnet --upgrade
# Out:
# Requirement already satisfied: pytorch-tabnet in /opt/conda/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.5.0)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.14.0)
# Requirement already satisfied: torch>=1.3 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (2.3.1)
# Requirement already satisfied: tqdm>=4.36 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3->pytorch-tabnet) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
trainpath = f'../../../../data/top30groups/anonLoc/train1/train{partition}.csv'
testpath = f'../../../../data/top30groups/anonLoc/test1/test{partition}.csv'

traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
torch.cuda.empty_cache()

# %%
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

def split_data(dftrain, dftest):
    Xtrain = dftrain.drop(columns=['gname']).values.astype(float)
    Ytrain = dftrain['gname'].values
    Xtest = dftest.drop(columns=['gname']).values.astype(float)
    Ytest = dftest['gname'].values

    le = LabelEncoder()
    Ytrain = le.fit_transform(Ytrain)
    Ytest = le.transform(Ytest)

    #y_pred_decoded = model.label_encoder.inverse_transform(y_pred)
    y_true_decoded = le.inverse_transform(Ytest)

    return Xtrain, Ytrain, Xtest, Ytest, y_true_decoded, le

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
from pytorch_tabnet.tab_model import TabNetClassifier

class TabNetClassifierWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, n_d=8, n_a=8, n_steps=3, gamma=1.3, lambda_sparse=1e-3, optimizer_params=None):
        self.n_d = n_d
        self.n_a = n_a
        self.n_steps = n_steps
        self.gamma = gamma
        self.lambda_sparse = lambda_sparse
        self.optimizer_params = optimizer_params or {'lr': 0.01}
        self.model = None

    def fit(self, X, y):
        self.model = TabNetClassifier(
            n_d=self.n_d,
            n_a=self.n_a,
            n_steps=self.n_steps,
            gamma=self.gamma,
            lambda_sparse=self.lambda_sparse,
            optimizer_params=self.optimizer_params,
            seed=42,
            verbose=0
        )

        self.model.fit(
            X, y,
            eval_set=[(X, y)],
            max_epochs=500,
            patience=120,
            batch_size=1024,
            virtual_batch_size=128,
            eval_metric=['accuracy']
        )

        self.classes_ = np.unique(y)  
        return self

    def predict(self, X):
        return self.model.predict(X)

    def score(self, X, y):
        preds = self.predict(X)
        return (preds == y).mean()

# %%
#from pytorch_tabnet.sklearn import TabNetClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor

def find_best_tabnet(Xtrain, Ytrain, n_iter=20):
    print("Starting TabNet grid search")
    print("CUDA available:", torch.cuda.is_available())

    param_dist = {
        'n_d': [8, 16, 24],
        'n_a': [8, 16, 24],
        'n_steps': [3, 4, 5],
        'gamma': [1.0, 1.3, 1.5],
        'lambda_sparse': [1e-4, 1e-3, 1e-2],
        'optimizer_params': [{'lr': 0.01}]
    }

    random_search = RandomizedSearchCV(
        estimator=TabNetClassifierWrapper(),
        param_distributions=param_dist,
        n_iter=n_iter,
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
        scoring='accuracy',
        verbose=1,
        n_jobs=-1,
        random_state=42
    )

    random_search.fit(Xtrain, Ytrain)
    print("Best parameters:", random_search.best_params_)
    print("Best accuracy:", random_search.best_score_)

    return random_search.best_params_

# %%
from pytorch_tabnet.callbacks import Callback
import time

class EpochTimer(Callback):
    def __init__(self):
        self.epoch_times = []

    def on_epoch_begin(self, epoch_idx, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch_idx, logs=None):
        duration = time.time() - self.start_time
        self.epoch_times.append(duration)
        print(f"⏱️ Epoch {epoch_idx + 1} took {duration:.2f} seconds")

# %%
Xtrain, Ytrain, Xtest, Ytest, Ytest_decoded, le = split_data(traindata, testdata)
best_tabnet_params = find_best_tabnet(Xtrain, Ytrain)

from sklearn.model_selection import train_test_split

# Split 80% train, 20% validation
X_tr, X_val, y_tr, y_val = train_test_split(
    Xtrain, Ytrain,
    test_size=0.2,
    random_state=42,
    stratify=Ytrain
)

# Re-initialize TabNet with best params
final_model = TabNetClassifier(
    **{k: v for k, v in best_tabnet_params.items()},
    verbose=1,
    seed=42
)

epoch_timer = EpochTimer()

# Retrain on full training data
final_model.fit(
    X_tr, y_tr,
    eval_set=[(X_val, y_val)],
    max_epochs=1000,
    patience=200,
    batch_size=1024,
    virtual_batch_size=128,
    callbacks=[epoch_timer]
)
# Out:
# Starting TabNet grid search
# CUDA available: True
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.71667
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.7873
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 460 and best_val_0_accuracy = 0.71806
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 464 and best_val_0_accuracy = 0.73036
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.7621
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.71468
#
# Early stopping occurred at epoch 354 with best_epoch = 234 and best_val_0_accuracy = 0.66825
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.7627
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.77262
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 461 and best_val_0_accuracy = 0.78135
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.74306
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Early stopping occurred at epoch 480 with best_epoch = 360 and best_val_0_accuracy = 0.64901
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Early stopping occurred at epoch 489 with best_epoch = 369 and best_val_0_accuracy = 0.68472
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Early stopping occurred at epoch 496 with best_epoch = 376 and best_val_0_accuracy = 0.69167
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.67302
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.70615
# Stop training because you reached max_epochs = 500 with best_epoch = 481 and best_val_0_accuracy = 0.68631
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.66151
# Stop training because you reached max_epochs = 500 with best_epoch = 423 and best_val_0_accuracy = 0.68552
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.72619
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 440 and best_val_0_accuracy = 0.69246
# Stop training because you reached max_epochs = 500 with best_epoch = 492 and best_val_0_accuracy = 0.71746
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.68393
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.65536
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.70595
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.69821
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.71151
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.72579
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.71409
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.70833
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.72639
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 422 and best_val_0_accuracy = 0.70218
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.75496
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.7496
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 470 and best_val_0_accuracy = 0.70278
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.70992
# Stop training because you reached max_epochs = 500 with best_epoch = 450 and best_val_0_accuracy = 0.71528
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 488 and best_val_0_accuracy = 0.66746
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.6756
# Stop training because you reached max_epochs = 500 with best_epoch = 485 and best_val_0_accuracy = 0.68591
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 483 and best_val_0_accuracy = 0.68016
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 469 and best_val_0_accuracy = 0.66448
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 483 and best_val_0_accuracy = 0.68492
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.65833
# Stop training because you reached max_epochs = 500 with best_epoch = 463 and best_val_0_accuracy = 0.70933
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 488 and best_val_0_accuracy = 0.68333
# Stop training because you reached max_epochs = 500 with best_epoch = 475 and best_val_0_accuracy = 0.69782
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.71567
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.72321
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 475 and best_val_0_accuracy = 0.66429
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 462 and best_val_0_accuracy = 0.69147
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.69087
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 473 and best_val_0_accuracy = 0.69385
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.67718
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.69187
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.61825
# Stop training because you reached max_epochs = 500 with best_epoch = 448 and best_val_0_accuracy = 0.64325
# Stop training because you reached max_epochs = 500 with best_epoch = 445 and best_val_0_accuracy = 0.63552
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Early stopping occurred at epoch 460 with best_epoch = 340 and best_val_0_accuracy = 0.64385
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 472 and best_val_0_accuracy = 0.62758
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 472 and best_val_0_accuracy = 0.63492
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 427 and best_val_0_accuracy = 0.62044
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 447 and best_val_0_accuracy = 0.67401
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 481 and best_val_0_accuracy = 0.63373
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.6131
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 420 and best_val_0_accuracy = 0.62421
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.6369
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 397 and best_val_0_accuracy = 0.70278
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.66052
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.69464
# Stop training because you reached max_epochs = 500 with best_epoch = 484 and best_val_0_accuracy = 0.71488
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.68631
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 472 and best_val_0_accuracy = 0.70734
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 441 and best_val_0_accuracy = 0.60575
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.61528
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 455 and best_val_0_accuracy = 0.77083
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 454 and best_val_0_accuracy = 0.74246
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.70913
# Stop training because you reached max_epochs = 500 with best_epoch = 479 and best_val_0_accuracy = 0.73571
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 452 and best_val_0_accuracy = 0.71091
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.72242
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.7381
# Stop training because you reached max_epochs = 500 with best_epoch = 477 and best_val_0_accuracy = 0.77778
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.77579
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.74048
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.71885
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 413 and best_val_0_accuracy = 0.71131
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 477 and best_val_0_accuracy = 0.63214
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 475 and best_val_0_accuracy = 0.64405
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.72083
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.73155
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 480 and best_val_0_accuracy = 0.69683
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 476 and best_val_0_accuracy = 0.6629
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.63512
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 492 and best_val_0_accuracy = 0.66528
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.65833
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.65476
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.65714
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 458 and best_val_0_accuracy = 0.65159
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 471 and best_val_0_accuracy = 0.66905
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.6773
# Best parameters: {'optimizer_params': {'lr': 0.01}, 'n_steps': 4, 'n_d': 16, 'n_a': 24, 'lambda_sparse': 0.01, 'gamma': 1.5}
# Best accuracy: 0.6473015873015873
# epoch 0  | loss: 4.34605 | val_0_accuracy: 0.02937 |  0:00:00s
# ⏱️ Epoch 1 took 0.13 seconds
# epoch 1  | loss: 3.81362 | val_0_accuracy: 0.03095 |  0:00:00s
# ⏱️ Epoch 2 took 0.12 seconds
# epoch 2  | loss: 3.56941 | val_0_accuracy: 0.03889 |  0:00:00s
# ⏱️ Epoch 3 took 0.12 seconds
# epoch 3  | loss: 3.4712  | val_0_accuracy: 0.02143 |  0:00:00s
# ⏱️ Epoch 4 took 0.12 seconds
# epoch 4  | loss: 3.38567 | val_0_accuracy: 0.0373  |  0:00:00s
# ⏱️ Epoch 5 took 0.12 seconds
# epoch 5  | loss: 3.31091 | val_0_accuracy: 0.04206 |  0:00:00s
# ⏱️ Epoch 6 took 0.12 seconds
# epoch 6  | loss: 3.24573 | val_0_accuracy: 0.05873 |  0:00:00s
# ⏱️ Epoch 7 took 0.13 seconds
# epoch 7  | loss: 3.15736 | val_0_accuracy: 0.06587 |  0:00:00s
# ⏱️ Epoch 8 took 0.12 seconds
# epoch 8  | loss: 3.06792 | val_0_accuracy: 0.07778 |  0:00:01s
# ⏱️ Epoch 9 took 0.12 seconds
# epoch 9  | loss: 3.01805 | val_0_accuracy: 0.05079 |  0:00:01s
# ⏱️ Epoch 10 took 0.12 seconds
# epoch 10 | loss: 2.92194 | val_0_accuracy: 0.05    |  0:00:01s
# ⏱️ Epoch 11 took 0.12 seconds
# epoch 11 | loss: 2.8656  | val_0_accuracy: 0.04127 |  0:00:01s
# ⏱️ Epoch 12 took 0.12 seconds
# epoch 12 | loss: 2.80189 | val_0_accuracy: 0.04683 |  0:00:01s
# ⏱️ Epoch 13 took 0.12 seconds
# epoch 13 | loss: 2.74654 | val_0_accuracy: 0.04921 |  0:00:01s
# ⏱️ Epoch 14 took 0.12 seconds
# epoch 14 | loss: 2.69233 | val_0_accuracy: 0.05397 |  0:00:01s
# ⏱️ Epoch 15 took 0.12 seconds
# epoch 15 | loss: 2.63369 | val_0_accuracy: 0.06111 |  0:00:01s
# ⏱️ Epoch 16 took 0.12 seconds
# epoch 16 | loss: 2.58201 | val_0_accuracy: 0.06111 |  0:00:02s
# ⏱️ Epoch 17 took 0.12 seconds
# epoch 17 | loss: 2.5348  | val_0_accuracy: 0.05238 |  0:00:02s
# ⏱️ Epoch 18 took 0.12 seconds
# epoch 18 | loss: 2.46693 | val_0_accuracy: 0.05238 |  0:00:02s
# ⏱️ Epoch 19 took 0.12 seconds
# epoch 19 | loss: 2.44045 | val_0_accuracy: 0.06111 |  0:00:02s
# ⏱️ Epoch 20 took 0.11 seconds
# epoch 20 | loss: 2.40134 | val_0_accuracy: 0.05159 |  0:00:02s
# ⏱️ Epoch 21 took 0.11 seconds
# epoch 21 | loss: 2.38966 | val_0_accuracy: 0.06032 |  0:00:02s
# ⏱️ Epoch 22 took 0.11 seconds
# epoch 22 | loss: 2.34577 | val_0_accuracy: 0.05476 |  0:00:02s
# ⏱️ Epoch 23 took 0.12 seconds
# epoch 23 | loss: 2.28217 | val_0_accuracy: 0.04365 |  0:00:02s
# ⏱️ Epoch 24 took 0.11 seconds
# epoch 24 | loss: 2.29864 | val_0_accuracy: 0.04683 |  0:00:02s
# ⏱️ Epoch 25 took 0.11 seconds
# epoch 25 | loss: 2.29543 | val_0_accuracy: 0.05079 |  0:00:03s
# ⏱️ Epoch 26 took 0.12 seconds
# epoch 26 | loss: 2.30108 | val_0_accuracy: 0.05556 |  0:00:03s
# ⏱️ Epoch 27 took 0.13 seconds
# epoch 27 | loss: 2.27715 | val_0_accuracy: 0.05794 |  0:00:03s
# ⏱️ Epoch 28 took 0.12 seconds
# epoch 28 | loss: 2.26186 | val_0_accuracy: 0.0746  |  0:00:03s
# ⏱️ Epoch 29 took 0.13 seconds
# epoch 29 | loss: 2.23214 | val_0_accuracy: 0.07857 |  0:00:03s
# ⏱️ Epoch 30 took 0.14 seconds
# epoch 30 | loss: 2.20791 | val_0_accuracy: 0.06667 |  0:00:03s
# ⏱️ Epoch 31 took 0.13 seconds
# epoch 31 | loss: 2.20383 | val_0_accuracy: 0.07302 |  0:00:03s
# ⏱️ Epoch 32 took 0.13 seconds
# epoch 32 | loss: 2.16725 | val_0_accuracy: 0.0881  |  0:00:04s
# ⏱️ Epoch 33 took 0.14 seconds
# epoch 33 | loss: 2.15753 | val_0_accuracy: 0.08016 |  0:00:04s
# ⏱️ Epoch 34 took 0.13 seconds
# epoch 34 | loss: 2.15616 | val_0_accuracy: 0.08333 |  0:00:04s
# ⏱️ Epoch 35 took 0.12 seconds
# epoch 35 | loss: 2.1413  | val_0_accuracy: 0.08333 |  0:00:04s
# ⏱️ Epoch 36 took 0.13 seconds
# epoch 36 | loss: 2.09459 | val_0_accuracy: 0.08968 |  0:00:04s
# ⏱️ Epoch 37 took 0.13 seconds
# epoch 37 | loss: 2.12903 | val_0_accuracy: 0.09603 |  0:00:04s
# ⏱️ Epoch 38 took 0.13 seconds
# epoch 38 | loss: 2.12201 | val_0_accuracy: 0.09365 |  0:00:04s
# ⏱️ Epoch 39 took 0.13 seconds
# epoch 39 | loss: 2.13091 | val_0_accuracy: 0.08254 |  0:00:04s
# ⏱️ Epoch 40 took 0.13 seconds
# epoch 40 | loss: 2.07491 | val_0_accuracy: 0.1127  |  0:00:05s
# ⏱️ Epoch 41 took 0.12 seconds
# epoch 41 | loss: 2.12141 | val_0_accuracy: 0.13413 |  0:00:05s
# ⏱️ Epoch 42 took 0.12 seconds
# epoch 42 | loss: 2.08668 | val_0_accuracy: 0.12778 |  0:00:05s
# ⏱️ Epoch 43 took 0.12 seconds
# epoch 43 | loss: 2.11038 | val_0_accuracy: 0.15    |  0:00:05s
# ⏱️ Epoch 44 took 0.12 seconds
# epoch 44 | loss: 2.09611 | val_0_accuracy: 0.13413 |  0:00:05s
# ⏱️ Epoch 45 took 0.11 seconds
# epoch 45 | loss: 2.0921  | val_0_accuracy: 0.12857 |  0:00:05s
# ⏱️ Epoch 46 took 0.11 seconds
# epoch 46 | loss: 2.07106 | val_0_accuracy: 0.11349 |  0:00:05s
# ⏱️ Epoch 47 took 0.11 seconds
# epoch 47 | loss: 2.05664 | val_0_accuracy: 0.16349 |  0:00:05s
# ⏱️ Epoch 48 took 0.11 seconds
# epoch 48 | loss: 2.03184 | val_0_accuracy: 0.21667 |  0:00:05s
# ⏱️ Epoch 49 took 0.11 seconds
# epoch 49 | loss: 2.04128 | val_0_accuracy: 0.17619 |  0:00:06s
# ⏱️ Epoch 50 took 0.11 seconds
# epoch 50 | loss: 2.08266 | val_0_accuracy: 0.20159 |  0:00:06s
# ⏱️ Epoch 51 took 0.11 seconds
# epoch 51 | loss: 2.03799 | val_0_accuracy: 0.27222 |  0:00:06s
# ⏱️ Epoch 52 took 0.11 seconds
# epoch 52 | loss: 2.03363 | val_0_accuracy: 0.21111 |  0:00:06s
# ⏱️ Epoch 53 took 0.12 seconds
# epoch 53 | loss: 1.98879 | val_0_accuracy: 0.21667 |  0:00:06s
# ⏱️ Epoch 54 took 0.12 seconds
# epoch 54 | loss: 1.9735  | val_0_accuracy: 0.22063 |  0:00:06s
# ⏱️ Epoch 55 took 0.12 seconds
# epoch 55 | loss: 1.9806  | val_0_accuracy: 0.25079 |  0:00:06s
# ⏱️ Epoch 56 took 0.12 seconds
# epoch 56 | loss: 1.98598 | val_0_accuracy: 0.25794 |  0:00:06s
# ⏱️ Epoch 57 took 0.12 seconds
# epoch 57 | loss: 1.93833 | val_0_accuracy: 0.20873 |  0:00:07s
# ⏱️ Epoch 58 took 0.12 seconds
# epoch 58 | loss: 2.01182 | val_0_accuracy: 0.30794 |  0:00:07s
# ⏱️ Epoch 59 took 0.14 seconds
# epoch 59 | loss: 1.93308 | val_0_accuracy: 0.26587 |  0:00:07s
# ⏱️ Epoch 60 took 0.14 seconds
# epoch 60 | loss: 1.94438 | val_0_accuracy: 0.2619  |  0:00:07s
# ⏱️ Epoch 61 took 0.13 seconds
# epoch 61 | loss: 1.94774 | val_0_accuracy: 0.30873 |  0:00:07s
# ⏱️ Epoch 62 took 0.12 seconds
# epoch 62 | loss: 1.96569 | val_0_accuracy: 0.31587 |  0:00:07s
# ⏱️ Epoch 63 took 0.13 seconds
# epoch 63 | loss: 1.92589 | val_0_accuracy: 0.28095 |  0:00:07s
# ⏱️ Epoch 64 took 0.13 seconds
# epoch 64 | loss: 1.93008 | val_0_accuracy: 0.36508 |  0:00:07s
# ⏱️ Epoch 65 took 0.13 seconds
# epoch 65 | loss: 1.89046 | val_0_accuracy: 0.26429 |  0:00:08s
# ⏱️ Epoch 66 took 0.12 seconds
# epoch 66 | loss: 1.93784 | val_0_accuracy: 0.33175 |  0:00:08s
# ⏱️ Epoch 67 took 0.13 seconds
# epoch 67 | loss: 1.87062 | val_0_accuracy: 0.36746 |  0:00:08s
# ⏱️ Epoch 68 took 0.13 seconds
# epoch 68 | loss: 1.87041 | val_0_accuracy: 0.37778 |  0:00:08s
# ⏱️ Epoch 69 took 0.12 seconds
# epoch 69 | loss: 1.84589 | val_0_accuracy: 0.43651 |  0:00:08s
# ⏱️ Epoch 70 took 0.13 seconds
# epoch 70 | loss: 1.84279 | val_0_accuracy: 0.39762 |  0:00:08s
# ⏱️ Epoch 71 took 0.12 seconds
# epoch 71 | loss: 1.83025 | val_0_accuracy: 0.43175 |  0:00:08s
# ⏱️ Epoch 72 took 0.12 seconds
# epoch 72 | loss: 1.84215 | val_0_accuracy: 0.46825 |  0:00:08s
# ⏱️ Epoch 73 took 0.12 seconds
# epoch 73 | loss: 1.88178 | val_0_accuracy: 0.38492 |  0:00:09s
# ⏱️ Epoch 74 took 0.11 seconds
# epoch 74 | loss: 1.83813 | val_0_accuracy: 0.41746 |  0:00:09s
# ⏱️ Epoch 75 took 0.11 seconds
# epoch 75 | loss: 1.85031 | val_0_accuracy: 0.40397 |  0:00:09s
# ⏱️ Epoch 76 took 0.11 seconds
# epoch 76 | loss: 1.8969  | val_0_accuracy: 0.38095 |  0:00:09s
# ⏱️ Epoch 77 took 0.12 seconds
# epoch 77 | loss: 1.84103 | val_0_accuracy: 0.36905 |  0:00:09s
# ⏱️ Epoch 78 took 0.12 seconds
# epoch 78 | loss: 1.87621 | val_0_accuracy: 0.37143 |  0:00:09s
# ⏱️ Epoch 79 took 0.12 seconds
# epoch 79 | loss: 1.86692 | val_0_accuracy: 0.30476 |  0:00:09s
# ⏱️ Epoch 80 took 0.12 seconds
# epoch 80 | loss: 1.84031 | val_0_accuracy: 0.43968 |  0:00:09s
# ⏱️ Epoch 81 took 0.13 seconds
# epoch 81 | loss: 1.82532 | val_0_accuracy: 0.48254 |  0:00:10s
# ⏱️ Epoch 82 took 0.13 seconds
# epoch 82 | loss: 1.85295 | val_0_accuracy: 0.4381  |  0:00:10s
# ⏱️ Epoch 83 took 0.12 seconds
# epoch 83 | loss: 1.8378  | val_0_accuracy: 0.46825 |  0:00:10s
# ⏱️ Epoch 84 took 0.12 seconds
# epoch 84 | loss: 1.80835 | val_0_accuracy: 0.42302 |  0:00:10s
# ⏱️ Epoch 85 took 0.12 seconds
# epoch 85 | loss: 1.81046 | val_0_accuracy: 0.47063 |  0:00:10s
# ⏱️ Epoch 86 took 0.12 seconds
# epoch 86 | loss: 1.80639 | val_0_accuracy: 0.42619 |  0:00:10s
# ⏱️ Epoch 87 took 0.12 seconds
# epoch 87 | loss: 1.85002 | val_0_accuracy: 0.48413 |  0:00:10s
# ⏱️ Epoch 88 took 0.12 seconds
# epoch 88 | loss: 1.91117 | val_0_accuracy: 0.39683 |  0:00:11s
# ⏱️ Epoch 89 took 0.28 seconds
# epoch 89 | loss: 1.87352 | val_0_accuracy: 0.45476 |  0:00:11s
# ⏱️ Epoch 90 took 0.15 seconds
# epoch 90 | loss: 1.80253 | val_0_accuracy: 0.47222 |  0:00:11s
# ⏱️ Epoch 91 took 0.12 seconds
# epoch 91 | loss: 1.86073 | val_0_accuracy: 0.44762 |  0:00:11s
# ⏱️ Epoch 92 took 0.12 seconds
# epoch 92 | loss: 1.8636  | val_0_accuracy: 0.41825 |  0:00:11s
# ⏱️ Epoch 93 took 0.12 seconds
# epoch 93 | loss: 1.87036 | val_0_accuracy: 0.46905 |  0:00:11s
# ⏱️ Epoch 94 took 0.12 seconds
# epoch 94 | loss: 1.8088  | val_0_accuracy: 0.4873  |  0:00:11s
# ⏱️ Epoch 95 took 0.13 seconds
# epoch 95 | loss: 1.80551 | val_0_accuracy: 0.45    |  0:00:11s
# ⏱️ Epoch 96 took 0.12 seconds
# epoch 96 | loss: 1.7895  | val_0_accuracy: 0.41111 |  0:00:12s
# ⏱️ Epoch 97 took 0.11 seconds
# epoch 97 | loss: 1.74064 | val_0_accuracy: 0.46746 |  0:00:12s
# ⏱️ Epoch 98 took 0.11 seconds
# epoch 98 | loss: 1.77217 | val_0_accuracy: 0.45714 |  0:00:12s
# ⏱️ Epoch 99 took 0.11 seconds
# epoch 99 | loss: 1.81612 | val_0_accuracy: 0.40873 |  0:00:12s
# ⏱️ Epoch 100 took 0.11 seconds
# epoch 100| loss: 1.77116 | val_0_accuracy: 0.41667 |  0:00:12s
# ⏱️ Epoch 101 took 0.12 seconds
# epoch 101| loss: 1.80018 | val_0_accuracy: 0.43175 |  0:00:12s
# ⏱️ Epoch 102 took 0.11 seconds
# epoch 102| loss: 1.77983 | val_0_accuracy: 0.4246  |  0:00:12s
# ⏱️ Epoch 103 took 0.12 seconds
# epoch 103| loss: 1.76515 | val_0_accuracy: 0.46825 |  0:00:12s
# ⏱️ Epoch 104 took 0.12 seconds
# epoch 104| loss: 1.75166 | val_0_accuracy: 0.41429 |  0:00:12s
# ⏱️ Epoch 105 took 0.12 seconds
# epoch 105| loss: 1.79305 | val_0_accuracy: 0.44683 |  0:00:13s
# ⏱️ Epoch 106 took 0.12 seconds
# epoch 106| loss: 1.74783 | val_0_accuracy: 0.48571 |  0:00:13s
# ⏱️ Epoch 107 took 0.12 seconds
# epoch 107| loss: 1.72022 | val_0_accuracy: 0.49683 |  0:00:13s
# ⏱️ Epoch 108 took 0.12 seconds
# epoch 108| loss: 1.7395  | val_0_accuracy: 0.51984 |  0:00:13s
# ⏱️ Epoch 109 took 0.12 seconds
# epoch 109| loss: 1.75045 | val_0_accuracy: 0.49762 |  0:00:13s
# ⏱️ Epoch 110 took 0.12 seconds
# epoch 110| loss: 1.75873 | val_0_accuracy: 0.51429 |  0:00:13s
# ⏱️ Epoch 111 took 0.12 seconds
# epoch 111| loss: 1.74137 | val_0_accuracy: 0.44127 |  0:00:13s
# ⏱️ Epoch 112 took 0.12 seconds
# epoch 112| loss: 1.72609 | val_0_accuracy: 0.51111 |  0:00:13s
# ⏱️ Epoch 113 took 0.12 seconds
# epoch 113| loss: 1.73271 | val_0_accuracy: 0.51032 |  0:00:14s
# ⏱️ Epoch 114 took 0.12 seconds
# epoch 114| loss: 1.73916 | val_0_accuracy: 0.41905 |  0:00:14s
# ⏱️ Epoch 115 took 0.12 seconds
# epoch 115| loss: 1.72851 | val_0_accuracy: 0.51667 |  0:00:14s
# ⏱️ Epoch 116 took 0.12 seconds
# epoch 116| loss: 1.76809 | val_0_accuracy: 0.43413 |  0:00:14s
# ⏱️ Epoch 117 took 0.12 seconds
# epoch 117| loss: 1.71997 | val_0_accuracy: 0.52302 |  0:00:14s
# ⏱️ Epoch 118 took 0.13 seconds
# epoch 118| loss: 1.71929 | val_0_accuracy: 0.52381 |  0:00:14s
# ⏱️ Epoch 119 took 0.13 seconds
# epoch 119| loss: 1.73917 | val_0_accuracy: 0.5127  |  0:00:14s
# ⏱️ Epoch 120 took 0.12 seconds
# epoch 120| loss: 1.72536 | val_0_accuracy: 0.44206 |  0:00:14s
# ⏱️ Epoch 121 took 0.12 seconds
# epoch 121| loss: 1.71551 | val_0_accuracy: 0.47698 |  0:00:15s
# ⏱️ Epoch 122 took 0.12 seconds
# epoch 122| loss: 1.7206  | val_0_accuracy: 0.46349 |  0:00:15s
# ⏱️ Epoch 123 took 0.12 seconds
# epoch 123| loss: 1.77525 | val_0_accuracy: 0.47937 |  0:00:15s
# ⏱️ Epoch 124 took 0.12 seconds
# epoch 124| loss: 1.71283 | val_0_accuracy: 0.4619  |  0:00:15s
# ⏱️ Epoch 125 took 0.11 seconds
# epoch 125| loss: 1.7001  | val_0_accuracy: 0.48095 |  0:00:15s
# ⏱️ Epoch 126 took 0.11 seconds
# epoch 126| loss: 1.70663 | val_0_accuracy: 0.44048 |  0:00:15s
# ⏱️ Epoch 127 took 0.11 seconds
# epoch 127| loss: 1.72485 | val_0_accuracy: 0.49286 |  0:00:15s
# ⏱️ Epoch 128 took 0.11 seconds
# epoch 128| loss: 1.75322 | val_0_accuracy: 0.42619 |  0:00:15s
# ⏱️ Epoch 129 took 0.12 seconds
# epoch 129| loss: 1.73523 | val_0_accuracy: 0.4881  |  0:00:15s
# ⏱️ Epoch 130 took 0.11 seconds
# epoch 130| loss: 1.79475 | val_0_accuracy: 0.48254 |  0:00:16s
# ⏱️ Epoch 131 took 0.11 seconds
# epoch 131| loss: 1.79844 | val_0_accuracy: 0.5     |  0:00:16s
# ⏱️ Epoch 132 took 0.11 seconds
# epoch 132| loss: 1.76011 | val_0_accuracy: 0.52302 |  0:00:16s
# ⏱️ Epoch 133 took 0.12 seconds
# epoch 133| loss: 1.76886 | val_0_accuracy: 0.45635 |  0:00:16s
# ⏱️ Epoch 134 took 0.12 seconds
# epoch 134| loss: 1.70931 | val_0_accuracy: 0.45952 |  0:00:16s
# ⏱️ Epoch 135 took 0.13 seconds
# epoch 135| loss: 1.71455 | val_0_accuracy: 0.45873 |  0:00:16s
# ⏱️ Epoch 136 took 0.12 seconds
# epoch 136| loss: 1.7504  | val_0_accuracy: 0.51032 |  0:00:16s
# ⏱️ Epoch 137 took 0.12 seconds
# epoch 137| loss: 1.77587 | val_0_accuracy: 0.45397 |  0:00:16s
# ⏱️ Epoch 138 took 0.12 seconds
# epoch 138| loss: 1.76858 | val_0_accuracy: 0.41667 |  0:00:17s
# ⏱️ Epoch 139 took 0.12 seconds
# epoch 139| loss: 1.75623 | val_0_accuracy: 0.52381 |  0:00:17s
# ⏱️ Epoch 140 took 0.12 seconds
# epoch 140| loss: 1.68685 | val_0_accuracy: 0.4381  |  0:00:17s
# ⏱️ Epoch 141 took 0.12 seconds
# epoch 141| loss: 1.7519  | val_0_accuracy: 0.51349 |  0:00:17s
# ⏱️ Epoch 142 took 0.13 seconds
# epoch 142| loss: 1.76897 | val_0_accuracy: 0.5246  |  0:00:17s
# ⏱️ Epoch 143 took 0.13 seconds
# epoch 143| loss: 1.73486 | val_0_accuracy: 0.45635 |  0:00:17s
# ⏱️ Epoch 144 took 0.12 seconds
# epoch 144| loss: 1.74226 | val_0_accuracy: 0.50397 |  0:00:17s
# ⏱️ Epoch 145 took 0.12 seconds
# epoch 145| loss: 1.74167 | val_0_accuracy: 0.50794 |  0:00:17s
# ⏱️ Epoch 146 took 0.13 seconds
# epoch 146| loss: 1.68669 | val_0_accuracy: 0.49286 |  0:00:18s
# ⏱️ Epoch 147 took 0.12 seconds
# epoch 147| loss: 1.6991  | val_0_accuracy: 0.53413 |  0:00:18s
# ⏱️ Epoch 148 took 0.12 seconds
# epoch 148| loss: 1.69043 | val_0_accuracy: 0.51905 |  0:00:18s
# ⏱️ Epoch 149 took 0.13 seconds
# epoch 149| loss: 1.69512 | val_0_accuracy: 0.50476 |  0:00:18s
# ⏱️ Epoch 150 took 0.12 seconds
# epoch 150| loss: 1.7631  | val_0_accuracy: 0.5381  |  0:00:18s
# ⏱️ Epoch 151 took 0.13 seconds
# epoch 151| loss: 1.71664 | val_0_accuracy: 0.43095 |  0:00:18s
# ⏱️ Epoch 152 took 0.11 seconds
# epoch 152| loss: 1.76365 | val_0_accuracy: 0.50079 |  0:00:18s
# ⏱️ Epoch 153 took 0.11 seconds
# epoch 153| loss: 1.68997 | val_0_accuracy: 0.49206 |  0:00:18s
# ⏱️ Epoch 154 took 0.11 seconds
# epoch 154| loss: 1.75012 | val_0_accuracy: 0.54206 |  0:00:18s
# ⏱️ Epoch 155 took 0.12 seconds
# epoch 155| loss: 1.67525 | val_0_accuracy: 0.53016 |  0:00:19s
# ⏱️ Epoch 156 took 0.11 seconds
# epoch 156| loss: 1.69707 | val_0_accuracy: 0.48254 |  0:00:19s
# ⏱️ Epoch 157 took 0.11 seconds
# epoch 157| loss: 1.6885  | val_0_accuracy: 0.53254 |  0:00:19s
# ⏱️ Epoch 158 took 0.11 seconds
# epoch 158| loss: 1.72778 | val_0_accuracy: 0.50317 |  0:00:19s
# ⏱️ Epoch 159 took 0.11 seconds
# epoch 159| loss: 1.72    | val_0_accuracy: 0.45238 |  0:00:19s
# ⏱️ Epoch 160 took 0.12 seconds
# epoch 160| loss: 1.72898 | val_0_accuracy: 0.49921 |  0:00:19s
# ⏱️ Epoch 161 took 0.12 seconds
# epoch 161| loss: 1.76256 | val_0_accuracy: 0.51746 |  0:00:19s
# ⏱️ Epoch 162 took 0.12 seconds
# epoch 162| loss: 1.70321 | val_0_accuracy: 0.50714 |  0:00:19s
# ⏱️ Epoch 163 took 0.13 seconds
# epoch 163| loss: 1.76464 | val_0_accuracy: 0.48333 |  0:00:20s
# ⏱️ Epoch 164 took 0.12 seconds
# epoch 164| loss: 1.75875 | val_0_accuracy: 0.53254 |  0:00:20s
# ⏱️ Epoch 165 took 0.12 seconds
# epoch 165| loss: 1.71882 | val_0_accuracy: 0.48889 |  0:00:20s
# ⏱️ Epoch 166 took 0.12 seconds
# epoch 166| loss: 1.72475 | val_0_accuracy: 0.37619 |  0:00:20s
# ⏱️ Epoch 167 took 0.12 seconds
# epoch 167| loss: 1.78806 | val_0_accuracy: 0.53333 |  0:00:20s
# ⏱️ Epoch 168 took 0.12 seconds
# epoch 168| loss: 1.68505 | val_0_accuracy: 0.49127 |  0:00:20s
# ⏱️ Epoch 169 took 0.12 seconds
# epoch 169| loss: 1.73528 | val_0_accuracy: 0.42381 |  0:00:20s
# ⏱️ Epoch 170 took 0.12 seconds
# epoch 170| loss: 1.74981 | val_0_accuracy: 0.53571 |  0:00:20s
# ⏱️ Epoch 171 took 0.12 seconds
# epoch 171| loss: 1.75596 | val_0_accuracy: 0.42381 |  0:00:20s
# ⏱️ Epoch 172 took 0.12 seconds
# epoch 172| loss: 1.72145 | val_0_accuracy: 0.42302 |  0:00:21s
# ⏱️ Epoch 173 took 0.12 seconds
# epoch 173| loss: 1.72042 | val_0_accuracy: 0.5254  |  0:00:21s
# ⏱️ Epoch 174 took 0.12 seconds
# epoch 174| loss: 1.70298 | val_0_accuracy: 0.52143 |  0:00:21s
# ⏱️ Epoch 175 took 0.12 seconds
# epoch 175| loss: 1.69031 | val_0_accuracy: 0.52381 |  0:00:21s
# ⏱️ Epoch 176 took 0.12 seconds
# epoch 176| loss: 1.66632 | val_0_accuracy: 0.49603 |  0:00:21s
# ⏱️ Epoch 177 took 0.12 seconds
# epoch 177| loss: 1.67246 | val_0_accuracy: 0.48254 |  0:00:21s
# ⏱️ Epoch 178 took 0.12 seconds
# epoch 178| loss: 1.64044 | val_0_accuracy: 0.52381 |  0:00:21s
# ⏱️ Epoch 179 took 0.12 seconds
# epoch 179| loss: 1.6437  | val_0_accuracy: 0.5119  |  0:00:21s
# ⏱️ Epoch 180 took 0.13 seconds
# epoch 180| loss: 1.62085 | val_0_accuracy: 0.55397 |  0:00:22s
# ⏱️ Epoch 181 took 0.12 seconds
# epoch 181| loss: 1.64541 | val_0_accuracy: 0.50476 |  0:00:22s
# ⏱️ Epoch 182 took 0.11 seconds
# epoch 182| loss: 1.66211 | val_0_accuracy: 0.51349 |  0:00:22s
# ⏱️ Epoch 183 took 0.11 seconds
# epoch 183| loss: 1.66489 | val_0_accuracy: 0.49444 |  0:00:22s
# ⏱️ Epoch 184 took 0.11 seconds
# epoch 184| loss: 1.6786  | val_0_accuracy: 0.4627  |  0:00:22s
# ⏱️ Epoch 185 took 0.11 seconds
# epoch 185| loss: 1.64906 | val_0_accuracy: 0.54762 |  0:00:22s
# ⏱️ Epoch 186 took 0.12 seconds
# epoch 186| loss: 1.62789 | val_0_accuracy: 0.49048 |  0:00:22s
# ⏱️ Epoch 187 took 0.12 seconds
# epoch 187| loss: 1.66553 | val_0_accuracy: 0.50079 |  0:00:22s
# ⏱️ Epoch 188 took 0.12 seconds
# epoch 188| loss: 1.62278 | val_0_accuracy: 0.50794 |  0:00:22s
# ⏱️ Epoch 189 took 0.12 seconds
# epoch 189| loss: 1.65434 | val_0_accuracy: 0.43175 |  0:00:23s
# ⏱️ Epoch 190 took 0.12 seconds
# epoch 190| loss: 1.7147  | val_0_accuracy: 0.52778 |  0:00:23s
# ⏱️ Epoch 191 took 0.12 seconds
# epoch 191| loss: 1.66638 | val_0_accuracy: 0.53254 |  0:00:23s
# ⏱️ Epoch 192 took 0.12 seconds
# epoch 192| loss: 1.72024 | val_0_accuracy: 0.52619 |  0:00:23s
# ⏱️ Epoch 193 took 0.12 seconds
# epoch 193| loss: 1.6851  | val_0_accuracy: 0.49206 |  0:00:23s
# ⏱️ Epoch 194 took 0.12 seconds
# epoch 194| loss: 1.66546 | val_0_accuracy: 0.54048 |  0:00:23s
# ⏱️ Epoch 195 took 0.12 seconds
# epoch 195| loss: 1.68993 | val_0_accuracy: 0.49365 |  0:00:23s
# ⏱️ Epoch 196 took 0.12 seconds
# epoch 196| loss: 1.6494  | val_0_accuracy: 0.5373  |  0:00:23s
# ⏱️ Epoch 197 took 0.12 seconds
# epoch 197| loss: 1.66518 | val_0_accuracy: 0.5119  |  0:00:24s
# ⏱️ Epoch 198 took 0.12 seconds
# epoch 198| loss: 1.69437 | val_0_accuracy: 0.47222 |  0:00:24s
# ⏱️ Epoch 199 took 0.12 seconds
# epoch 199| loss: 1.69816 | val_0_accuracy: 0.49127 |  0:00:24s
# ⏱️ Epoch 200 took 0.12 seconds
# epoch 200| loss: 1.68367 | val_0_accuracy: 0.55635 |  0:00:24s
# ⏱️ Epoch 201 took 0.13 seconds
# epoch 201| loss: 1.67243 | val_0_accuracy: 0.47143 |  0:00:24s
# ⏱️ Epoch 202 took 0.13 seconds
# epoch 202| loss: 1.62503 | val_0_accuracy: 0.49841 |  0:00:24s
# ⏱️ Epoch 203 took 0.12 seconds
# epoch 203| loss: 1.66497 | val_0_accuracy: 0.50159 |  0:00:24s
# ⏱️ Epoch 204 took 0.12 seconds
# epoch 204| loss: 1.62479 | val_0_accuracy: 0.52302 |  0:00:24s
# ⏱️ Epoch 205 took 0.13 seconds
# epoch 205| loss: 1.59828 | val_0_accuracy: 0.51746 |  0:00:25s
# ⏱️ Epoch 206 took 0.13 seconds
# epoch 206| loss: 1.64097 | val_0_accuracy: 0.45556 |  0:00:25s
# ⏱️ Epoch 207 took 0.12 seconds
# epoch 207| loss: 1.64162 | val_0_accuracy: 0.44683 |  0:00:25s
# ⏱️ Epoch 208 took 0.12 seconds
# epoch 208| loss: 1.64396 | val_0_accuracy: 0.51905 |  0:00:25s
# ⏱️ Epoch 209 took 0.12 seconds
# epoch 209| loss: 1.64557 | val_0_accuracy: 0.53254 |  0:00:25s
# ⏱️ Epoch 210 took 0.12 seconds
# epoch 210| loss: 1.63215 | val_0_accuracy: 0.49286 |  0:00:25s
# ⏱️ Epoch 211 took 0.11 seconds
# epoch 211| loss: 1.65098 | val_0_accuracy: 0.54048 |  0:00:25s
# ⏱️ Epoch 212 took 0.11 seconds
# epoch 212| loss: 1.61976 | val_0_accuracy: 0.52698 |  0:00:25s
# ⏱️ Epoch 213 took 0.11 seconds
# epoch 213| loss: 1.60875 | val_0_accuracy: 0.53333 |  0:00:25s
# ⏱️ Epoch 214 took 0.12 seconds
# epoch 214| loss: 1.6413  | val_0_accuracy: 0.52619 |  0:00:26s
# ⏱️ Epoch 215 took 0.12 seconds
# epoch 215| loss: 1.66488 | val_0_accuracy: 0.55397 |  0:00:26s
# ⏱️ Epoch 216 took 0.12 seconds
# epoch 216| loss: 1.64008 | val_0_accuracy: 0.55317 |  0:00:26s
# ⏱️ Epoch 217 took 0.12 seconds
# epoch 217| loss: 1.56791 | val_0_accuracy: 0.48492 |  0:00:26s
# ⏱️ Epoch 218 took 0.12 seconds
# epoch 218| loss: 1.58558 | val_0_accuracy: 0.53175 |  0:00:26s
# ⏱️ Epoch 219 took 0.12 seconds
# epoch 219| loss: 1.60169 | val_0_accuracy: 0.51746 |  0:00:26s
# ⏱️ Epoch 220 took 0.12 seconds
# ...
# epoch 831| loss: 1.18719 | val_0_accuracy: 0.65317 |  0:01:41s
# ⏱️ Epoch 832 took 0.12 seconds
# epoch 832| loss: 1.29368 | val_0_accuracy: 0.62381 |  0:01:42s
# ⏱️ Epoch 833 took 0.12 seconds
# epoch 833| loss: 1.23962 | val_0_accuracy: 0.60476 |  0:01:42s
# ⏱️ Epoch 834 took 0.12 seconds
# epoch 834| loss: 1.30728 | val_0_accuracy: 0.56667 |  0:01:42s
# ⏱️ Epoch 835 took 0.12 seconds
# epoch 835| loss: 1.25737 | val_0_accuracy: 0.62302 |  0:01:42s
# ⏱️ Epoch 836 took 0.12 seconds
# epoch 836| loss: 1.2436  | val_0_accuracy: 0.64921 |  0:01:42s
# ⏱️ Epoch 837 took 0.12 seconds
# epoch 837| loss: 1.23123 | val_0_accuracy: 0.5881  |  0:01:42s
# ⏱️ Epoch 838 took 0.11 seconds
# epoch 838| loss: 1.19634 | val_0_accuracy: 0.56508 |  0:01:42s
# ⏱️ Epoch 839 took 0.11 seconds
# epoch 839| loss: 1.19513 | val_0_accuracy: 0.61746 |  0:01:42s
# ⏱️ Epoch 840 took 0.11 seconds
# epoch 840| loss: 1.23272 | val_0_accuracy: 0.59286 |  0:01:42s
# ⏱️ Epoch 841 took 0.12 seconds
# epoch 841| loss: 1.21644 | val_0_accuracy: 0.60238 |  0:01:43s
# ⏱️ Epoch 842 took 0.11 seconds
# epoch 842| loss: 1.19773 | val_0_accuracy: 0.64762 |  0:01:43s
# ⏱️ Epoch 843 took 0.11 seconds
# epoch 843| loss: 1.1926  | val_0_accuracy: 0.64524 |  0:01:43s
# ⏱️ Epoch 844 took 0.11 seconds
# epoch 844| loss: 1.22992 | val_0_accuracy: 0.60397 |  0:01:43s
# ⏱️ Epoch 845 took 0.11 seconds
# epoch 845| loss: 1.28301 | val_0_accuracy: 0.63889 |  0:01:43s
# ⏱️ Epoch 846 took 0.11 seconds
# epoch 846| loss: 1.23269 | val_0_accuracy: 0.65238 |  0:01:43s
# ⏱️ Epoch 847 took 0.12 seconds
# epoch 847| loss: 1.19114 | val_0_accuracy: 0.66508 |  0:01:43s
# ⏱️ Epoch 848 took 0.12 seconds
# epoch 848| loss: 1.23594 | val_0_accuracy: 0.63889 |  0:01:43s
# ⏱️ Epoch 849 took 0.12 seconds
# epoch 849| loss: 1.27989 | val_0_accuracy: 0.57063 |  0:01:43s
# ⏱️ Epoch 850 took 0.12 seconds
# epoch 850| loss: 1.19369 | val_0_accuracy: 0.61032 |  0:01:44s
# ⏱️ Epoch 851 took 0.14 seconds
# epoch 851| loss: 1.2687  | val_0_accuracy: 0.62857 |  0:01:44s
# ⏱️ Epoch 852 took 0.12 seconds
# epoch 852| loss: 1.24495 | val_0_accuracy: 0.61508 |  0:01:44s
# ⏱️ Epoch 853 took 0.12 seconds
# epoch 853| loss: 1.21871 | val_0_accuracy: 0.61111 |  0:01:44s
# ⏱️ Epoch 854 took 0.12 seconds
# epoch 854| loss: 1.17257 | val_0_accuracy: 0.65397 |  0:01:44s
# ⏱️ Epoch 855 took 0.12 seconds
# epoch 855| loss: 1.20196 | val_0_accuracy: 0.65476 |  0:01:44s
# ⏱️ Epoch 856 took 0.12 seconds
# epoch 856| loss: 1.21123 | val_0_accuracy: 0.66587 |  0:01:44s
# ⏱️ Epoch 857 took 0.12 seconds
# epoch 857| loss: 1.26403 | val_0_accuracy: 0.60873 |  0:01:44s
# ⏱️ Epoch 858 took 0.12 seconds
# epoch 858| loss: 1.28452 | val_0_accuracy: 0.55873 |  0:01:45s
# ⏱️ Epoch 859 took 0.12 seconds
# epoch 859| loss: 1.21119 | val_0_accuracy: 0.64048 |  0:01:45s
# ⏱️ Epoch 860 took 0.12 seconds
# epoch 860| loss: 1.25381 | val_0_accuracy: 0.6119  |  0:01:45s
# ⏱️ Epoch 861 took 0.13 seconds
# epoch 861| loss: 1.19082 | val_0_accuracy: 0.56111 |  0:01:45s
# ⏱️ Epoch 862 took 0.12 seconds
# epoch 862| loss: 1.23902 | val_0_accuracy: 0.58413 |  0:01:45s
# ⏱️ Epoch 863 took 0.12 seconds
# epoch 863| loss: 1.23938 | val_0_accuracy: 0.54048 |  0:01:45s
# ⏱️ Epoch 864 took 0.12 seconds
# epoch 864| loss: 1.2722  | val_0_accuracy: 0.58968 |  0:01:45s
# ⏱️ Epoch 865 took 0.12 seconds
# epoch 865| loss: 1.23228 | val_0_accuracy: 0.6254  |  0:01:45s
# ⏱️ Epoch 866 took 0.12 seconds
# epoch 866| loss: 1.25427 | val_0_accuracy: 0.61746 |  0:01:46s
# ⏱️ Epoch 867 took 0.12 seconds
# epoch 867| loss: 1.18592 | val_0_accuracy: 0.63254 |  0:01:46s
# ⏱️ Epoch 868 took 0.11 seconds
# epoch 868| loss: 1.21704 | val_0_accuracy: 0.63016 |  0:01:46s
# ⏱️ Epoch 869 took 0.11 seconds
# epoch 869| loss: 1.17102 | val_0_accuracy: 0.64683 |  0:01:46s
# ⏱️ Epoch 870 took 0.11 seconds
# epoch 870| loss: 1.21925 | val_0_accuracy: 0.64206 |  0:01:46s
# ⏱️ Epoch 871 took 0.12 seconds
# epoch 871| loss: 1.20587 | val_0_accuracy: 0.61349 |  0:01:46s
# ⏱️ Epoch 872 took 0.12 seconds
# epoch 872| loss: 1.21331 | val_0_accuracy: 0.64524 |  0:01:46s
# ⏱️ Epoch 873 took 0.12 seconds
# epoch 873| loss: 1.19199 | val_0_accuracy: 0.63413 |  0:01:46s
# ⏱️ Epoch 874 took 0.12 seconds
# epoch 874| loss: 1.20931 | val_0_accuracy: 0.61429 |  0:01:46s
# ⏱️ Epoch 875 took 0.12 seconds
# epoch 875| loss: 1.20788 | val_0_accuracy: 0.57143 |  0:01:47s
# ⏱️ Epoch 876 took 0.13 seconds
# epoch 876| loss: 1.24338 | val_0_accuracy: 0.50714 |  0:01:47s
# ⏱️ Epoch 877 took 0.15 seconds
# epoch 877| loss: 1.29659 | val_0_accuracy: 0.63333 |  0:01:47s
# ⏱️ Epoch 878 took 0.13 seconds
# epoch 878| loss: 1.17083 | val_0_accuracy: 0.6254  |  0:01:47s
# ⏱️ Epoch 879 took 0.12 seconds
# epoch 879| loss: 1.2408  | val_0_accuracy: 0.62381 |  0:01:47s
# ⏱️ Epoch 880 took 0.12 seconds
# epoch 880| loss: 1.21631 | val_0_accuracy: 0.64206 |  0:01:47s
# ⏱️ Epoch 881 took 0.14 seconds
# epoch 881| loss: 1.17563 | val_0_accuracy: 0.6246  |  0:01:47s
# ⏱️ Epoch 882 took 0.13 seconds
# epoch 882| loss: 1.29592 | val_0_accuracy: 0.52619 |  0:01:48s
# ⏱️ Epoch 883 took 0.12 seconds
# epoch 883| loss: 1.22491 | val_0_accuracy: 0.60714 |  0:01:48s
# ⏱️ Epoch 884 took 0.12 seconds
# epoch 884| loss: 1.16268 | val_0_accuracy: 0.6373  |  0:01:48s
# ⏱️ Epoch 885 took 0.12 seconds
# epoch 885| loss: 1.18597 | val_0_accuracy: 0.61111 |  0:01:48s
# ⏱️ Epoch 886 took 0.12 seconds
# epoch 886| loss: 1.24893 | val_0_accuracy: 0.65    |  0:01:48s
# ⏱️ Epoch 887 took 0.12 seconds
# epoch 887| loss: 1.22563 | val_0_accuracy: 0.65476 |  0:01:48s
# ⏱️ Epoch 888 took 0.12 seconds
# epoch 888| loss: 1.19088 | val_0_accuracy: 0.63889 |  0:01:48s
# ⏱️ Epoch 889 took 0.12 seconds
# epoch 889| loss: 1.2122  | val_0_accuracy: 0.62937 |  0:01:48s
# ⏱️ Epoch 890 took 0.13 seconds
# epoch 890| loss: 1.22255 | val_0_accuracy: 0.6127  |  0:01:48s
# ⏱️ Epoch 891 took 0.13 seconds
# epoch 891| loss: 1.20904 | val_0_accuracy: 0.64444 |  0:01:49s
# ⏱️ Epoch 892 took 0.12 seconds
# epoch 892| loss: 1.18759 | val_0_accuracy: 0.64683 |  0:01:49s
# ⏱️ Epoch 893 took 0.11 seconds
# epoch 893| loss: 1.20536 | val_0_accuracy: 0.64524 |  0:01:49s
# ⏱️ Epoch 894 took 0.11 seconds
# epoch 894| loss: 1.19916 | val_0_accuracy: 0.55159 |  0:01:49s
# ⏱️ Epoch 895 took 0.11 seconds
# epoch 895| loss: 1.27806 | val_0_accuracy: 0.54127 |  0:01:49s
# ⏱️ Epoch 896 took 0.11 seconds
# epoch 896| loss: 1.24793 | val_0_accuracy: 0.64524 |  0:01:49s
# ⏱️ Epoch 897 took 0.11 seconds
# epoch 897| loss: 1.21703 | val_0_accuracy: 0.6381  |  0:01:49s
# ⏱️ Epoch 898 took 0.11 seconds
# epoch 898| loss: 1.20627 | val_0_accuracy: 0.60873 |  0:01:49s
# ⏱️ Epoch 899 took 0.11 seconds
# epoch 899| loss: 1.39023 | val_0_accuracy: 0.59444 |  0:01:50s
# ⏱️ Epoch 900 took 0.11 seconds
# epoch 900| loss: 1.31173 | val_0_accuracy: 0.63651 |  0:01:50s
# ⏱️ Epoch 901 took 0.14 seconds
# epoch 901| loss: 1.27048 | val_0_accuracy: 0.64365 |  0:01:50s
# ⏱️ Epoch 902 took 0.12 seconds
# epoch 902| loss: 1.24836 | val_0_accuracy: 0.58175 |  0:01:50s
# ⏱️ Epoch 903 took 0.12 seconds
# epoch 903| loss: 1.24634 | val_0_accuracy: 0.58333 |  0:01:50s
# ⏱️ Epoch 904 took 0.12 seconds
# epoch 904| loss: 1.22847 | val_0_accuracy: 0.63175 |  0:01:50s
# ⏱️ Epoch 905 took 0.12 seconds
# epoch 905| loss: 1.25697 | val_0_accuracy: 0.55159 |  0:01:50s
# ⏱️ Epoch 906 took 0.11 seconds
# epoch 906| loss: 1.18139 | val_0_accuracy: 0.60079 |  0:01:50s
# ⏱️ Epoch 907 took 0.12 seconds
# epoch 907| loss: 1.22848 | val_0_accuracy: 0.61508 |  0:01:50s
# ⏱️ Epoch 908 took 0.12 seconds
# epoch 908| loss: 1.21361 | val_0_accuracy: 0.64683 |  0:01:51s
# ⏱️ Epoch 909 took 0.11 seconds
# epoch 909| loss: 1.16402 | val_0_accuracy: 0.64048 |  0:01:51s
# ⏱️ Epoch 910 took 0.11 seconds
# epoch 910| loss: 1.18572 | val_0_accuracy: 0.60476 |  0:01:51s
# ⏱️ Epoch 911 took 0.13 seconds
# epoch 911| loss: 1.18195 | val_0_accuracy: 0.59127 |  0:01:51s
# ⏱️ Epoch 912 took 0.12 seconds
# epoch 912| loss: 1.25451 | val_0_accuracy: 0.64127 |  0:01:51s
# ⏱️ Epoch 913 took 0.12 seconds
# epoch 913| loss: 1.24258 | val_0_accuracy: 0.57857 |  0:01:51s
# ⏱️ Epoch 914 took 0.12 seconds
# epoch 914| loss: 1.22815 | val_0_accuracy: 0.56111 |  0:01:51s
# ⏱️ Epoch 915 took 0.12 seconds
# epoch 915| loss: 1.31032 | val_0_accuracy: 0.57143 |  0:01:51s
# ⏱️ Epoch 916 took 0.12 seconds
# epoch 916| loss: 1.35146 | val_0_accuracy: 0.60873 |  0:01:52s
# ⏱️ Epoch 917 took 0.12 seconds
# epoch 917| loss: 1.26942 | val_0_accuracy: 0.58254 |  0:01:52s
# ⏱️ Epoch 918 took 0.12 seconds
# epoch 918| loss: 1.25361 | val_0_accuracy: 0.63254 |  0:01:52s
# ⏱️ Epoch 919 took 0.12 seconds
# epoch 919| loss: 1.23329 | val_0_accuracy: 0.60159 |  0:01:52s
# ⏱️ Epoch 920 took 0.12 seconds
# epoch 920| loss: 1.25261 | val_0_accuracy: 0.59444 |  0:01:52s
# ⏱️ Epoch 921 took 0.14 seconds
# epoch 921| loss: 1.43592 | val_0_accuracy: 0.55079 |  0:01:52s
# ⏱️ Epoch 922 took 0.12 seconds
# epoch 922| loss: 1.29293 | val_0_accuracy: 0.58175 |  0:01:52s
# ⏱️ Epoch 923 took 0.11 seconds
# epoch 923| loss: 1.3314  | val_0_accuracy: 0.57381 |  0:01:52s
# ⏱️ Epoch 924 took 0.11 seconds
# epoch 924| loss: 1.35646 | val_0_accuracy: 0.61825 |  0:01:52s
# ⏱️ Epoch 925 took 0.11 seconds
# epoch 925| loss: 1.30434 | val_0_accuracy: 0.45873 |  0:01:53s
# ⏱️ Epoch 926 took 0.11 seconds
# epoch 926| loss: 1.28163 | val_0_accuracy: 0.58095 |  0:01:53s
# ⏱️ Epoch 927 took 0.11 seconds
# epoch 927| loss: 1.18562 | val_0_accuracy: 0.62381 |  0:01:53s
# ⏱️ Epoch 928 took 0.12 seconds
# epoch 928| loss: 1.30326 | val_0_accuracy: 0.61349 |  0:01:53s
# ⏱️ Epoch 929 took 0.12 seconds
# epoch 929| loss: 1.21395 | val_0_accuracy: 0.60635 |  0:01:53s
# ⏱️ Epoch 930 took 0.12 seconds
# epoch 930| loss: 1.31985 | val_0_accuracy: 0.49286 |  0:01:53s
# ⏱️ Epoch 931 took 0.13 seconds
# epoch 931| loss: 1.21276 | val_0_accuracy: 0.63175 |  0:01:53s
# ⏱️ Epoch 932 took 0.13 seconds
# epoch 932| loss: 1.21542 | val_0_accuracy: 0.63175 |  0:01:53s
# ⏱️ Epoch 933 took 0.12 seconds
# epoch 933| loss: 1.28687 | val_0_accuracy: 0.63889 |  0:01:54s
# ⏱️ Epoch 934 took 0.12 seconds
# epoch 934| loss: 1.21227 | val_0_accuracy: 0.55238 |  0:01:54s
# ⏱️ Epoch 935 took 0.12 seconds
# epoch 935| loss: 1.1656  | val_0_accuracy: 0.60873 |  0:01:54s
# ⏱️ Epoch 936 took 0.12 seconds
# epoch 936| loss: 1.23574 | val_0_accuracy: 0.62698 |  0:01:54s
# ⏱️ Epoch 937 took 0.12 seconds
# epoch 937| loss: 1.22349 | val_0_accuracy: 0.61746 |  0:01:54s
# ⏱️ Epoch 938 took 0.24 seconds
# epoch 938| loss: 1.18919 | val_0_accuracy: 0.58889 |  0:01:54s
# ⏱️ Epoch 939 took 0.12 seconds
# epoch 939| loss: 1.1903  | val_0_accuracy: 0.58968 |  0:01:54s
# ⏱️ Epoch 940 took 0.12 seconds
# epoch 940| loss: 1.24597 | val_0_accuracy: 0.56508 |  0:01:55s
# ⏱️ Epoch 941 took 0.12 seconds
# epoch 941| loss: 1.26475 | val_0_accuracy: 0.63254 |  0:01:55s
# ⏱️ Epoch 942 took 0.12 seconds
# epoch 942| loss: 1.18775 | val_0_accuracy: 0.62222 |  0:01:55s
# ⏱️ Epoch 943 took 0.12 seconds
# epoch 943| loss: 1.1956  | val_0_accuracy: 0.58095 |  0:01:55s
# ⏱️ Epoch 944 took 0.12 seconds
# epoch 944| loss: 1.14511 | val_0_accuracy: 0.61587 |  0:01:55s
# ⏱️ Epoch 945 took 0.12 seconds
# epoch 945| loss: 1.18249 | val_0_accuracy: 0.62619 |  0:01:55s
# ⏱️ Epoch 946 took 0.12 seconds
# epoch 946| loss: 1.1693  | val_0_accuracy: 0.59603 |  0:01:55s
# ⏱️ Epoch 947 took 0.11 seconds
# epoch 947| loss: 1.13252 | val_0_accuracy: 0.61587 |  0:01:55s
# ⏱️ Epoch 948 took 0.12 seconds
# epoch 948| loss: 1.1548  | val_0_accuracy: 0.59524 |  0:01:55s
# ⏱️ Epoch 949 took 0.11 seconds
# epoch 949| loss: 1.14657 | val_0_accuracy: 0.55238 |  0:01:56s
# ⏱️ Epoch 950 took 0.12 seconds
# epoch 950| loss: 1.24017 | val_0_accuracy: 0.59603 |  0:01:56s
# ⏱️ Epoch 951 took 0.11 seconds
# epoch 951| loss: 1.2066  | val_0_accuracy: 0.60952 |  0:01:56s
# ⏱️ Epoch 952 took 0.12 seconds
# epoch 952| loss: 1.16266 | val_0_accuracy: 0.62143 |  0:01:56s
# ⏱️ Epoch 953 took 0.12 seconds
# epoch 953| loss: 1.14073 | val_0_accuracy: 0.60556 |  0:01:56s
# ⏱️ Epoch 954 took 0.13 seconds
# epoch 954| loss: 1.1382  | val_0_accuracy: 0.63889 |  0:01:56s
# ⏱️ Epoch 955 took 0.12 seconds
# epoch 955| loss: 1.23277 | val_0_accuracy: 0.63254 |  0:01:56s
# ⏱️ Epoch 956 took 0.13 seconds
# epoch 956| loss: 1.17176 | val_0_accuracy: 0.6     |  0:01:56s
# ⏱️ Epoch 957 took 0.12 seconds
# epoch 957| loss: 1.21103 | val_0_accuracy: 0.46905 |  0:01:57s
# ⏱️ Epoch 958 took 0.13 seconds
# epoch 958| loss: 1.27785 | val_0_accuracy: 0.58413 |  0:01:57s
# ⏱️ Epoch 959 took 0.13 seconds
# epoch 959| loss: 1.20682 | val_0_accuracy: 0.62857 |  0:01:57s
# ⏱️ Epoch 960 took 0.13 seconds
# epoch 960| loss: 1.18196 | val_0_accuracy: 0.61984 |  0:01:57s
# ⏱️ Epoch 961 took 0.12 seconds
# epoch 961| loss: 1.17331 | val_0_accuracy: 0.58016 |  0:01:57s
# ⏱️ Epoch 962 took 0.12 seconds
# epoch 962| loss: 1.18869 | val_0_accuracy: 0.61429 |  0:01:57s
# ⏱️ Epoch 963 took 0.12 seconds
# epoch 963| loss: 1.21507 | val_0_accuracy: 0.64603 |  0:01:57s
# ⏱️ Epoch 964 took 0.13 seconds
# epoch 964| loss: 1.21399 | val_0_accuracy: 0.64524 |  0:01:57s
# ⏱️ Epoch 965 took 0.13 seconds
# epoch 965| loss: 1.19789 | val_0_accuracy: 0.61032 |  0:01:58s
# ⏱️ Epoch 966 took 0.12 seconds
# epoch 966| loss: 1.19172 | val_0_accuracy: 0.59762 |  0:01:58s
# ⏱️ Epoch 967 took 0.12 seconds
# epoch 967| loss: 1.19023 | val_0_accuracy: 0.57857 |  0:01:58s
# ⏱️ Epoch 968 took 0.12 seconds
# epoch 968| loss: 1.17523 | val_0_accuracy: 0.62857 |  0:01:58s
# ⏱️ Epoch 969 took 0.13 seconds
# epoch 969| loss: 1.17304 | val_0_accuracy: 0.63016 |  0:01:58s
# ⏱️ Epoch 970 took 0.13 seconds
# epoch 970| loss: 1.17776 | val_0_accuracy: 0.63889 |  0:01:58s
# ⏱️ Epoch 971 took 0.13 seconds
# epoch 971| loss: 1.13896 | val_0_accuracy: 0.6381  |  0:01:58s
# ⏱️ Epoch 972 took 0.13 seconds
# epoch 972| loss: 1.23072 | val_0_accuracy: 0.61746 |  0:01:58s
# ⏱️ Epoch 973 took 0.14 seconds
# epoch 973| loss: 1.24386 | val_0_accuracy: 0.58333 |  0:01:59s
# ⏱️ Epoch 974 took 0.13 seconds
# epoch 974| loss: 1.21857 | val_0_accuracy: 0.65238 |  0:01:59s
# ⏱️ Epoch 975 took 0.13 seconds
# epoch 975| loss: 1.20263 | val_0_accuracy: 0.62857 |  0:01:59s
# ⏱️ Epoch 976 took 0.12 seconds
# epoch 976| loss: 1.18168 | val_0_accuracy: 0.60714 |  0:01:59s
# ⏱️ Epoch 977 took 0.11 seconds
# epoch 977| loss: 1.17406 | val_0_accuracy: 0.64365 |  0:01:59s
# ⏱️ Epoch 978 took 0.12 seconds
# epoch 978| loss: 1.17494 | val_0_accuracy: 0.58254 |  0:01:59s
# ⏱️ Epoch 979 took 0.12 seconds
# epoch 979| loss: 1.17224 | val_0_accuracy: 0.60556 |  0:01:59s
# ⏱️ Epoch 980 took 0.12 seconds
# epoch 980| loss: 1.14669 | val_0_accuracy: 0.61429 |  0:01:59s
# ⏱️ Epoch 981 took 0.13 seconds
# epoch 981| loss: 1.18687 | val_0_accuracy: 0.62143 |  0:02:00s
# ⏱️ Epoch 982 took 0.12 seconds
# epoch 982| loss: 1.18016 | val_0_accuracy: 0.61349 |  0:02:00s
# ⏱️ Epoch 983 took 0.12 seconds
# epoch 983| loss: 1.2054  | val_0_accuracy: 0.62143 |  0:02:00s
# ⏱️ Epoch 984 took 0.13 seconds
# epoch 984| loss: 1.22905 | val_0_accuracy: 0.65873 |  0:02:00s
# ⏱️ Epoch 985 took 0.13 seconds
# epoch 985| loss: 1.21888 | val_0_accuracy: 0.59921 |  0:02:00s
# ⏱️ Epoch 986 took 0.13 seconds
# epoch 986| loss: 1.19606 | val_0_accuracy: 0.6373  |  0:02:00s
# ⏱️ Epoch 987 took 0.13 seconds
# epoch 987| loss: 1.17599 | val_0_accuracy: 0.64365 |  0:02:00s
# ⏱️ Epoch 988 took 0.13 seconds
# epoch 988| loss: 1.22787 | val_0_accuracy: 0.54365 |  0:02:00s
# ⏱️ Epoch 989 took 0.12 seconds
# epoch 989| loss: 1.25514 | val_0_accuracy: 0.59286 |  0:02:01s
# ⏱️ Epoch 990 took 0.12 seconds
# epoch 990| loss: 1.17296 | val_0_accuracy: 0.62302 |  0:02:01s
# ⏱️ Epoch 991 took 0.12 seconds
# epoch 991| loss: 1.16589 | val_0_accuracy: 0.61905 |  0:02:01s
# ⏱️ Epoch 992 took 0.13 seconds
# epoch 992| loss: 1.22047 | val_0_accuracy: 0.63413 |  0:02:01s
# ⏱️ Epoch 993 took 0.13 seconds
# epoch 993| loss: 1.20141 | val_0_accuracy: 0.60317 |  0:02:01s
# ⏱️ Epoch 994 took 0.12 seconds
# epoch 994| loss: 1.12675 | val_0_accuracy: 0.64444 |  0:02:01s
# ⏱️ Epoch 995 took 0.12 seconds
# epoch 995| loss: 1.11869 | val_0_accuracy: 0.6119  |  0:02:01s
# ⏱️ Epoch 996 took 0.13 seconds
# epoch 996| loss: 1.19477 | val_0_accuracy: 0.65317 |  0:02:01s
# ⏱️ Epoch 997 took 0.13 seconds
# epoch 997| loss: 1.21452 | val_0_accuracy: 0.57222 |  0:02:02s
# ⏱️ Epoch 998 took 0.12 seconds
# epoch 998| loss: 1.14999 | val_0_accuracy: 0.57857 |  0:02:02s
# ⏱️ Epoch 999 took 0.12 seconds
# epoch 999| loss: 1.20018 | val_0_accuracy: 0.65635 |  0:02:02s
# ⏱️ Epoch 1000 took 0.12 seconds
# Stop training because you reached max_epochs = 1000 with best_epoch = 856 and best_val_0_accuracy = 0.66587

# %%
_, _, _, _, _, le = split_data(traindata, testdata)

# %%
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

file_path = os.path.join("results", f"gtd{partition}.txt")

# Predict class indices for test set
y_pred = final_model.predict(Xtest)
y_proba = final_model.predict_proba(Xtest)
y_pred_decoded = le.inverse_transform(y_pred)
y_true_decoded = le.inverse_transform(Ytest)

# Make sure the directory exists
os.makedirs("results", exist_ok=True)

# Compute accuracy from decoded labels
acc = accuracy_score(y_true_decoded, y_pred_decoded)

# Write metrics to file
with open(file_path, "w") as file:
    file.write(f"Accuracy: {acc:.4f}\n")
    file.write(f"Precision weighted: {precision_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Recall weighted: {recall_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"F1 Score weighted: {f1_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Precision micro: {precision_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Recall micro: {recall_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"F1 Score micro: {f1_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Precision macro: {precision_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"Recall macro: {recall_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"F1 Score macro: {f1_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"roc auc weighted: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='weighted'):.4f}\n")
    file.write(f"roc auc macro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='macro'):.4f}\n")
    file.write(f"roc auc micro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='micro'):.4f}\n")

with open(f"results/epoch_time_gtd{partition}.txt", "w") as f:
    f.write('\n'.join(str(x) for x in epoch_timer.epoch_times))

# %%
print(classification_report(Ytest_decoded, y_pred_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.23      0.34      0.28        90
#         African National Congress (South Africa)       0.43      0.62      0.51        90
#                                 Al-Qaida in Iraq       0.46      0.51      0.48        90
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.12      0.12      0.12        90
#                                       Al-Shabaab       0.17      0.21      0.19        90
#              Basque Fatherland and Freedom (ETA)       0.49      0.39      0.43        90
#                                       Boko Haram       0.22      0.16      0.18        90
#   Communist Party of India - Maoist (CPI-Maoist)       0.54      0.50      0.52        90
#        Corsican National Liberation Front (FLNC)       0.48      0.81      0.60        90
#                        Donetsk People's Republic       0.62      0.44      0.52        90
# Farabundo Marti National Liberation Front (FMLN)       0.48      0.56      0.52        90
#                                Fulani extremists       0.69      0.83      0.76        90
#                  Houthi extremists (Ansar Allah)       0.39      0.52      0.44        90
#                      Irish Republican Army (IRA)       0.61      0.56      0.58        90
#      Islamic State of Iraq and the Levant (ISIL)       0.28      0.33      0.30        90
#                   Kurdistan Workers' Party (PKK)       0.30      0.27      0.28        90
#          Liberation Tigers of Tamil Eelam (LTTE)       0.54      0.57      0.55        90
#          Manuel Rodriguez Patriotic Front (FPMR)       0.69      0.66      0.67        90
#                                          Maoists       0.43      0.40      0.42        90
#                                Muslim extremists       0.34      0.24      0.28        90
#       National Liberation Army of Colombia (ELN)       0.71      0.57      0.63        90
#                          New People's Army (NPA)       0.68      0.48      0.56        90
#                Nicaraguan Democratic Force (FDN)       0.49      0.60      0.54        90
#                                     Palestinians       0.63      0.34      0.45        90
#    Revolutionary Armed Forces of Colombia (FARC)       0.36      0.30      0.33        90
#                                Shining Path (SL)       0.19      0.11      0.14        90
#                                  Sikh Extremists       0.45      0.60      0.51        90
#                                          Taliban       0.42      0.37      0.39        90
#                  Tehrik-i-Taliban Pakistan (TTP)       0.78      0.43      0.56        90
#        Tupac Amaru Revolutionary Movement (MRTA)       0.73      0.79      0.76        90
#
#                                         accuracy                           0.45      2700
#                                        macro avg       0.47      0.45      0.45      2700
#                                     weighted avg       0.47      0.45      0.45      2700

# %%
def plot_confusion_matrix(y_true, y_pred, labels):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"results/confusion_matrix_partition_{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
# Get all unique class labels from the truths
class_labels = np.unique(Ytest_decoded)

plot_confusion_matrix(Ytest_decoded, y_pred_decoded, labels=class_labels)
# Out:
# Saved confusion matrix for partition 300 to results/confusion_matrix_partition_300.png
