# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer
import sys

# %%
partition = 100

# %%
# !{sys.executable} -m pip install pytorch-tabnet --upgrade
# Out:
# Requirement already satisfied: pytorch-tabnet in /opt/conda/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.5.0)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (1.14.0)
# Requirement already satisfied: torch>=1.3 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (2.3.1)
# Requirement already satisfied: tqdm>=4.36 in /opt/conda/lib/python3.11/site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.3->pytorch-tabnet) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3->pytorch-tabnet) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
trainpath = f'../../../../data/top30groups/noGeographic/train1/train{partition}.csv'
testpath = f'../../../../data/top30groups/noGeographic/test1/test{partition}.csv'

traindata = pd.read_csv(trainpath, encoding='ISO-8859-1')
testdata = pd.read_csv(testpath, encoding='ISO-8859-1')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
torch.cuda.empty_cache()

# %%
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

def split_data(dftrain, dftest):
    Xtrain = dftrain.drop(columns=['gname']).values.astype(float)
    Ytrain = dftrain['gname'].values
    Xtest = dftest.drop(columns=['gname']).values.astype(float)
    Ytest = dftest['gname'].values

    le = LabelEncoder()
    Ytrain = le.fit_transform(Ytrain)
    Ytest = le.transform(Ytest)

    #y_pred_decoded = model.label_encoder.inverse_transform(y_pred)
    y_true_decoded = le.inverse_transform(Ytest)

    return Xtrain, Ytrain, Xtest, Ytest, y_true_decoded, le

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
from pytorch_tabnet.tab_model import TabNetClassifier

class TabNetClassifierWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, n_d=8, n_a=8, n_steps=3, gamma=1.3, lambda_sparse=1e-3, optimizer_params=None):
        self.n_d = n_d
        self.n_a = n_a
        self.n_steps = n_steps
        self.gamma = gamma
        self.lambda_sparse = lambda_sparse
        self.optimizer_params = optimizer_params or {'lr': 0.01}
        self.model = None

    def fit(self, X, y):
        self.model = TabNetClassifier(
            n_d=self.n_d,
            n_a=self.n_a,
            n_steps=self.n_steps,
            gamma=self.gamma,
            lambda_sparse=self.lambda_sparse,
            optimizer_params=self.optimizer_params,
            seed=42,
            verbose=0
        )

        self.model.fit(
            X, y,
            eval_set=[(X, y)],
            max_epochs=500,
            patience=120,
            batch_size=1024,
            virtual_batch_size=128,
            eval_metric=['accuracy']
        )

        self.classes_ = np.unique(y)  
        return self

    def predict(self, X):
        return self.model.predict(X)

    def score(self, X, y):
        preds = self.predict(X)
        return (preds == y).mean()

# %%
#from pytorch_tabnet.sklearn import TabNetClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor

def find_best_tabnet(Xtrain, Ytrain, n_iter=20):
    print("Starting TabNet grid search")
    print("CUDA available:", torch.cuda.is_available())

    param_dist = {
        'n_d': [8, 16, 24],
        'n_a': [8, 16, 24],
        'n_steps': [3, 4, 5],
        'gamma': [1.0, 1.3, 1.5],
        'lambda_sparse': [1e-4, 1e-3, 1e-2],
        'optimizer_params': [{'lr': 0.01}]
    }

    random_search = RandomizedSearchCV(
        estimator=TabNetClassifierWrapper(),
        param_distributions=param_dist,
        n_iter=n_iter,
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
        scoring='accuracy',
        verbose=1,
        n_jobs=-1,
        random_state=42
    )

    random_search.fit(Xtrain, Ytrain)
    print("Best parameters:", random_search.best_params_)
    print("Best accuracy:", random_search.best_score_)

    return random_search.best_params_

# %%
from pytorch_tabnet.callbacks import Callback
import time

class EpochTimer(Callback):
    def __init__(self):
        self.epoch_times = []

    def on_epoch_begin(self, epoch_idx, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch_idx, logs=None):
        duration = time.time() - self.start_time
        self.epoch_times.append(duration)
        print(f"⏱️ Epoch {epoch_idx + 1} took {duration:.2f} seconds")

# %%
Xtrain, Ytrain, Xtest, Ytest, Ytest_decoded, le = split_data(traindata, testdata)
best_tabnet_params = find_best_tabnet(Xtrain, Ytrain)

from sklearn.model_selection import train_test_split

# Split 80% train, 20% validation
X_tr, X_val, y_tr, y_val = train_test_split(
    Xtrain, Ytrain,
    test_size=0.2,
    random_state=42,
    stratify=Ytrain
)

# Re-initialize TabNet with best params
final_model = TabNetClassifier(
    **{k: v for k, v in best_tabnet_params.items()},
    verbose=1,
    seed=42
)

epoch_timer = EpochTimer()

# Retrain on full training data
final_model.fit(
    X_tr, y_tr,
    eval_set=[(X_val, y_val)],
    max_epochs=1000,
    patience=200,
    batch_size=1024,
    virtual_batch_size=128,
    callbacks=[epoch_timer]
)
# Out:
# Starting TabNet grid search
# CUDA available: True
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Stop training because you reached max_epochs = 500 with best_epoch = 466 and best_val_0_accuracy = 0.69226
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 473 and best_val_0_accuracy = 0.76071
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.74048
# Stop training because you reached max_epochs = 500 with best_epoch = 466 and best_val_0_accuracy = 0.76071
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.73274
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.71845
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.76667
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 458 and best_val_0_accuracy = 0.77083
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.73214
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 453 and best_val_0_accuracy = 0.77024
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.75417
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 434 and best_val_0_accuracy = 0.65476
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.69405
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.65476
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.65655
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.68393
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.70655
# Stop training because you reached max_epochs = 500 with best_epoch = 467 and best_val_0_accuracy = 0.69881
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.63929
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.74702
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.67798
# Stop training because you reached max_epochs = 500 with best_epoch = 485 and best_val_0_accuracy = 0.65119
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.7
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.65595
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.62619
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 463 and best_val_0_accuracy = 0.67917
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.71131
# Stop training because you reached max_epochs = 500 with best_epoch = 481 and best_val_0_accuracy = 0.675
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.72798
# Stop training because you reached max_epochs = 500 with best_epoch = 450 and best_val_0_accuracy = 0.68452
# Stop training because you reached max_epochs = 500 with best_epoch = 494 and best_val_0_accuracy = 0.68155
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 471 and best_val_0_accuracy = 0.71607
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 485 and best_val_0_accuracy = 0.73929
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.72321
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.71548
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 489 and best_val_0_accuracy = 0.72321
# Stop training because you reached max_epochs = 500 with best_epoch = 457 and best_val_0_accuracy = 0.70238
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.64405
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 473 and best_val_0_accuracy = 0.68155
# Stop training because you reached max_epochs = 500 with best_epoch = 484 and best_val_0_accuracy = 0.63274
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 477 and best_val_0_accuracy = 0.65298
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.63333
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.70774
# Stop training because you reached max_epochs = 500 with best_epoch = 480 and best_val_0_accuracy = 0.65238
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.64762
# Stop training because you reached max_epochs = 500 with best_epoch = 485 and best_val_0_accuracy = 0.6875
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.67619
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.74821
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.71548
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.62738
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 497 and best_val_0_accuracy = 0.66429
# Stop training because you reached max_epochs = 500 with best_epoch = 456 and best_val_0_accuracy = 0.65357
# Stop training because you reached max_epochs = 500 with best_epoch = 460 and best_val_0_accuracy = 0.67381
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 489 and best_val_0_accuracy = 0.68214
# Stop training because you reached max_epochs = 500 with best_epoch = 495 and best_val_0_accuracy = 0.66369
# Stop training because you reached max_epochs = 500 with best_epoch = 474 and best_val_0_accuracy = 0.59107
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.55833
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 491 and best_val_0_accuracy = 0.55595
# Stop training because you reached max_epochs = 500 with best_epoch = 481 and best_val_0_accuracy = 0.58988
# Stop training because you reached max_epochs = 500 with best_epoch = 489 and best_val_0_accuracy = 0.60476
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 459 and best_val_0_accuracy = 0.57143
# Stop training because you reached max_epochs = 500 with best_epoch = 469 and best_val_0_accuracy = 0.61726
# Stop training because you reached max_epochs = 500 with best_epoch = 461 and best_val_0_accuracy = 0.59226
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 480 and best_val_0_accuracy = 0.58929
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 449 and best_val_0_accuracy = 0.64405
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 483 and best_val_0_accuracy = 0.60595
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 492 and best_val_0_accuracy = 0.57381
# Stop training because you reached max_epochs = 500 with best_epoch = 489 and best_val_0_accuracy = 0.68333
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 479 and best_val_0_accuracy = 0.58155
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 421 and best_val_0_accuracy = 0.64345
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 486 and best_val_0_accuracy = 0.68988
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.6625
# Stop training because you reached max_epochs = 500 with best_epoch = 461 and best_val_0_accuracy = 0.70595
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 437 and best_val_0_accuracy = 0.625
# Stop training because you reached max_epochs = 500 with best_epoch = 431 and best_val_0_accuracy = 0.55179
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 485 and best_val_0_accuracy = 0.7631
# Stop training because you reached max_epochs = 500 with best_epoch = 455 and best_val_0_accuracy = 0.72262
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.71905
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.71548
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.71429
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.72262
# Stop training because you reached max_epochs = 500 with best_epoch = 493 and best_val_0_accuracy = 0.67381
# Stop training because you reached max_epochs = 500 with best_epoch = 488 and best_val_0_accuracy = 0.70536
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 469 and best_val_0_accuracy = 0.67917
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 470 and best_val_0_accuracy = 0.57798
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.62976
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 488 and best_val_0_accuracy = 0.73155
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.74464
# Stop training because you reached max_epochs = 500 with best_epoch = 496 and best_val_0_accuracy = 0.67083
# Stop training because you reached max_epochs = 500 with best_epoch = 499 and best_val_0_accuracy = 0.68988
# Stop training because you reached max_epochs = 500 with best_epoch = 471 and best_val_0_accuracy = 0.7369
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 492 and best_val_0_accuracy = 0.7119
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 463 and best_val_0_accuracy = 0.56964
# Stop training because you reached max_epochs = 500 with best_epoch = 482 and best_val_0_accuracy = 0.57857
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.57679
# Stop training because you reached max_epochs = 500 with best_epoch = 492 and best_val_0_accuracy = 0.58036
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 487 and best_val_0_accuracy = 0.58631
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 490 and best_val_0_accuracy = 0.54821
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 498 and best_val_0_accuracy = 0.5994
# Stop training because you reached max_epochs = 500 with best_epoch = 488 and best_val_0_accuracy = 0.57798
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /opt/conda/lib/python3.11/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Stop training because you reached max_epochs = 500 with best_epoch = 429 and best_val_0_accuracy = 0.70762
# Best parameters: {'optimizer_params': {'lr': 0.01}, 'n_steps': 5, 'n_d': 24, 'n_a': 8, 'lambda_sparse': 0.0001, 'gamma': 1.5}
# Best accuracy: 0.5785714285714286
# epoch 0  | loss: 5.11685 | val_0_accuracy: 0.03571 |  0:00:00s
# ⏱️ Epoch 1 took 0.05 seconds
# epoch 1  | loss: 4.84634 | val_0_accuracy: 0.05476 |  0:00:00s
# ⏱️ Epoch 2 took 0.05 seconds
# epoch 2  | loss: 4.65009 | val_0_accuracy: 0.03571 |  0:00:00s
# ⏱️ Epoch 3 took 0.04 seconds
# epoch 3  | loss: 4.5208  | val_0_accuracy: 0.03333 |  0:00:00s
# ⏱️ Epoch 4 took 0.04 seconds
# epoch 4  | loss: 4.34744 | val_0_accuracy: 0.04048 |  0:00:00s
# ⏱️ Epoch 5 took 0.04 seconds
# epoch 5  | loss: 4.18681 | val_0_accuracy: 0.04048 |  0:00:00s
# ⏱️ Epoch 6 took 0.04 seconds
# epoch 6  | loss: 4.06679 | val_0_accuracy: 0.0381  |  0:00:00s
# ⏱️ Epoch 7 took 0.04 seconds
# epoch 7  | loss: 4.00464 | val_0_accuracy: 0.02619 |  0:00:00s
# ⏱️ Epoch 8 took 0.04 seconds
# epoch 8  | loss: 3.87283 | val_0_accuracy: 0.03095 |  0:00:00s
# ⏱️ Epoch 9 took 0.04 seconds
# epoch 9  | loss: 3.86908 | val_0_accuracy: 0.04286 |  0:00:00s
# ⏱️ Epoch 10 took 0.04 seconds
# epoch 10 | loss: 3.88116 | val_0_accuracy: 0.04286 |  0:00:00s
# ⏱️ Epoch 11 took 0.04 seconds
# epoch 11 | loss: 3.77473 | val_0_accuracy: 0.0381  |  0:00:00s
# ⏱️ Epoch 12 took 0.04 seconds
# epoch 12 | loss: 3.72932 | val_0_accuracy: 0.05714 |  0:00:00s
# ⏱️ Epoch 13 took 0.05 seconds
# epoch 13 | loss: 3.6379  | val_0_accuracy: 0.05714 |  0:00:00s
# ⏱️ Epoch 14 took 0.04 seconds
# epoch 14 | loss: 3.60912 | val_0_accuracy: 0.06667 |  0:00:00s
# ⏱️ Epoch 15 took 0.05 seconds
# epoch 15 | loss: 3.60953 | val_0_accuracy: 0.0619  |  0:00:00s
# ⏱️ Epoch 16 took 0.04 seconds
# epoch 16 | loss: 3.51192 | val_0_accuracy: 0.05476 |  0:00:00s
# ⏱️ Epoch 17 took 0.04 seconds
# epoch 17 | loss: 3.50632 | val_0_accuracy: 0.0381  |  0:00:00s
# ⏱️ Epoch 18 took 0.04 seconds
# epoch 18 | loss: 3.46797 | val_0_accuracy: 0.05238 |  0:00:00s
# ⏱️ Epoch 19 took 0.04 seconds
# epoch 19 | loss: 3.42422 | val_0_accuracy: 0.06429 |  0:00:00s
# ⏱️ Epoch 20 took 0.04 seconds
# epoch 20 | loss: 3.41987 | val_0_accuracy: 0.06667 |  0:00:00s
# ⏱️ Epoch 21 took 0.04 seconds
# epoch 21 | loss: 3.39409 | val_0_accuracy: 0.0619  |  0:00:00s
# ⏱️ Epoch 22 took 0.04 seconds
# ⏱️ Epoch 185 took 0.04 seconds
# epoch 185| loss: 1.84542 | val_0_accuracy: 0.17143 |  0:00:08s
# ⏱️ Epoch 186 took 0.04 seconds
# epoch 186| loss: 1.85796 | val_0_accuracy: 0.15    |  0:00:08s
# ⏱️ Epoch 187 took 0.04 seconds
# epoch 187| loss: 1.80772 | val_0_accuracy: 0.12857 |  0:00:08s
# ⏱️ Epoch 188 took 0.04 seconds
# epoch 188| loss: 1.85004 | val_0_accuracy: 0.14048 |  0:00:08s
# ⏱️ Epoch 189 took 0.04 seconds
# epoch 189| loss: 1.93524 | val_0_accuracy: 0.12857 |  0:00:08s
# ⏱️ Epoch 190 took 0.04 seconds
# epoch 190| loss: 1.85219 | val_0_accuracy: 0.11429 |  0:00:08s
# ⏱️ Epoch 191 took 0.04 seconds
# epoch 191| loss: 1.87409 | val_0_accuracy: 0.12381 |  0:00:08s
# ⏱️ Epoch 192 took 0.04 seconds
# epoch 192| loss: 1.9058  | val_0_accuracy: 0.15    |  0:00:08s
# ⏱️ Epoch 193 took 0.04 seconds
# epoch 193| loss: 1.75533 | val_0_accuracy: 0.1619  |  0:00:08s
# ⏱️ Epoch 194 took 0.04 seconds
# epoch 194| loss: 1.79343 | val_0_accuracy: 0.1881  |  0:00:08s
# ⏱️ Epoch 195 took 0.05 seconds
# epoch 195| loss: 1.7495  | val_0_accuracy: 0.19762 |  0:00:08s
# ⏱️ Epoch 196 took 0.05 seconds
# epoch 196| loss: 1.81922 | val_0_accuracy: 0.21667 |  0:00:08s
# ⏱️ Epoch 197 took 0.05 seconds
# epoch 197| loss: 1.84542 | val_0_accuracy: 0.17619 |  0:00:08s
# ⏱️ Epoch 198 took 0.04 seconds
# epoch 198| loss: 1.81522 | val_0_accuracy: 0.15952 |  0:00:08s
# ⏱️ Epoch 199 took 0.04 seconds
# epoch 199| loss: 1.7225  | val_0_accuracy: 0.15952 |  0:00:08s
# ⏱️ Epoch 200 took 0.04 seconds
# epoch 200| loss: 1.73147 | val_0_accuracy: 0.15    |  0:00:08s
# ⏱️ Epoch 201 took 0.04 seconds
# epoch 201| loss: 1.82715 | val_0_accuracy: 0.14286 |  0:00:08s
# ⏱️ Epoch 202 took 0.04 seconds
# epoch 202| loss: 1.82429 | val_0_accuracy: 0.18095 |  0:00:08s
# ⏱️ Epoch 203 took 0.04 seconds
# epoch 203| loss: 1.71777 | val_0_accuracy: 0.1881  |  0:00:08s
# ⏱️ Epoch 204 took 0.04 seconds
# epoch 204| loss: 1.79664 | val_0_accuracy: 0.19286 |  0:00:08s
# ⏱️ Epoch 205 took 0.04 seconds
# epoch 205| loss: 1.71199 | val_0_accuracy: 0.2119  |  0:00:08s
# ⏱️ Epoch 206 took 0.05 seconds
# epoch 206| loss: 1.72326 | val_0_accuracy: 0.22381 |  0:00:08s
# ⏱️ Epoch 207 took 0.05 seconds
# epoch 207| loss: 1.70272 | val_0_accuracy: 0.25    |  0:00:08s
# epoch 843| loss: 1.06467 | val_0_accuracy: 0.52619 |  0:00:36s
# ⏱️ Epoch 844 took 0.04 seconds
# epoch 844| loss: 1.07762 | val_0_accuracy: 0.52619 |  0:00:36s
# ⏱️ Epoch 845 took 0.04 seconds
# epoch 845| loss: 1.05207 | val_0_accuracy: 0.53333 |  0:00:36s
# ⏱️ Epoch 846 took 0.04 seconds
# epoch 846| loss: 1.18221 | val_0_accuracy: 0.54762 |  0:00:36s
# ⏱️ Epoch 847 took 0.04 seconds
# epoch 847| loss: 1.14306 | val_0_accuracy: 0.60238 |  0:00:36s
# ⏱️ Epoch 848 took 0.05 seconds
# epoch 848| loss: 1.08945 | val_0_accuracy: 0.62143 |  0:00:36s
# ⏱️ Epoch 849 took 0.04 seconds
# epoch 849| loss: 0.99285 | val_0_accuracy: 0.62619 |  0:00:36s
# ⏱️ Epoch 850 took 0.04 seconds
# epoch 850| loss: 0.98089 | val_0_accuracy: 0.6119  |  0:00:36s
# ⏱️ Epoch 851 took 0.04 seconds
# epoch 851| loss: 1.10198 | val_0_accuracy: 0.57381 |  0:00:36s
# ⏱️ Epoch 852 took 0.04 seconds
# epoch 852| loss: 1.02804 | val_0_accuracy: 0.57857 |  0:00:36s
# ⏱️ Epoch 853 took 0.04 seconds
# epoch 853| loss: 0.97007 | val_0_accuracy: 0.59286 |  0:00:36s
# ⏱️ Epoch 854 took 0.04 seconds
# epoch 854| loss: 0.98843 | val_0_accuracy: 0.60476 |  0:00:36s
# ⏱️ Epoch 855 took 0.04 seconds
# epoch 855| loss: 1.0539  | val_0_accuracy: 0.61429 |  0:00:36s
# ⏱️ Epoch 856 took 0.04 seconds
# epoch 856| loss: 1.01022 | val_0_accuracy: 0.6119  |  0:00:36s
# ⏱️ Epoch 857 took 0.04 seconds
# epoch 857| loss: 1.06166 | val_0_accuracy: 0.6119  |  0:00:36s
# ⏱️ Epoch 858 took 0.04 seconds
# epoch 858| loss: 1.01638 | val_0_accuracy: 0.62857 |  0:00:36s
# ⏱️ Epoch 859 took 0.05 seconds
# epoch 859| loss: 0.94762 | val_0_accuracy: 0.63571 |  0:00:36s
# ⏱️ Epoch 860 took 0.05 seconds
# epoch 860| loss: 1.13921 | val_0_accuracy: 0.62619 |  0:00:36s
# ⏱️ Epoch 861 took 0.04 seconds
# epoch 861| loss: 1.01595 | val_0_accuracy: 0.62857 |  0:00:36s
# ⏱️ Epoch 862 took 0.04 seconds
# epoch 862| loss: 0.97849 | val_0_accuracy: 0.62619 |  0:00:36s
# ⏱️ Epoch 863 took 0.04 seconds
# epoch 863| loss: 1.06615 | val_0_accuracy: 0.62381 |  0:00:36s
# ⏱️ Epoch 864 took 0.04 seconds
# epoch 864| loss: 1.07432 | val_0_accuracy: 0.58333 |  0:00:36s
# ⏱️ Epoch 865 took 0.04 seconds
# epoch 865| loss: 1.04853 | val_0_accuracy: 0.55476 |  0:00:37s
# ⏱️ Epoch 866 took 0.04 seconds
# ⏱️ Epoch 890 took 0.04 seconds
# epoch 890| loss: 1.00313 | val_0_accuracy: 0.61667 |  0:00:38s
# ⏱️ Epoch 891 took 0.04 seconds
# epoch 891| loss: 0.93076 | val_0_accuracy: 0.59286 |  0:00:38s
# ⏱️ Epoch 892 took 0.04 seconds
# epoch 892| loss: 1.09624 | val_0_accuracy: 0.6     |  0:00:38s
# ⏱️ Epoch 893 took 0.04 seconds
# epoch 893| loss: 0.98397 | val_0_accuracy: 0.58333 |  0:00:38s
# ⏱️ Epoch 894 took 0.04 seconds
# epoch 894| loss: 0.98135 | val_0_accuracy: 0.6119  |  0:00:38s
# ⏱️ Epoch 895 took 0.04 seconds
# epoch 895| loss: 1.13954 | val_0_accuracy: 0.60714 |  0:00:38s
# ⏱️ Epoch 896 took 0.04 seconds
# epoch 896| loss: 1.03455 | val_0_accuracy: 0.62381 |  0:00:38s
# ⏱️ Epoch 897 took 0.04 seconds
# epoch 897| loss: 0.99697 | val_0_accuracy: 0.62143 |  0:00:38s
# ⏱️ Epoch 898 took 0.04 seconds
# epoch 898| loss: 0.97847 | val_0_accuracy: 0.60476 |  0:00:38s
# ⏱️ Epoch 899 took 0.04 seconds
# epoch 899| loss: 0.97075 | val_0_accuracy: 0.60238 |  0:00:38s
# ⏱️ Epoch 900 took 0.04 seconds
# epoch 900| loss: 1.05498 | val_0_accuracy: 0.60476 |  0:00:38s
# ⏱️ Epoch 901 took 0.04 seconds
# epoch 901| loss: 0.93788 | val_0_accuracy: 0.59762 |  0:00:38s
# ⏱️ Epoch 902 took 0.04 seconds
# epoch 902| loss: 1.05355 | val_0_accuracy: 0.58571 |  0:00:38s
# ⏱️ Epoch 903 took 0.04 seconds
# epoch 903| loss: 0.99271 | val_0_accuracy: 0.54048 |  0:00:38s
# ⏱️ Epoch 904 took 0.04 seconds
# epoch 904| loss: 0.96407 | val_0_accuracy: 0.54048 |  0:00:38s
# ⏱️ Epoch 905 took 0.04 seconds
# epoch 905| loss: 1.03768 | val_0_accuracy: 0.52619 |  0:00:38s
# ⏱️ Epoch 906 took 0.04 seconds
# epoch 906| loss: 0.97834 | val_0_accuracy: 0.54762 |  0:00:38s
# ⏱️ Epoch 907 took 0.04 seconds
# epoch 907| loss: 1.04487 | val_0_accuracy: 0.57619 |  0:00:38s
# ⏱️ Epoch 908 took 0.04 seconds
# epoch 908| loss: 1.01852 | val_0_accuracy: 0.6119  |  0:00:38s
# ⏱️ Epoch 909 took 0.04 seconds
# epoch 909| loss: 1.0702  | val_0_accuracy: 0.58571 |  0:00:38s
# ⏱️ Epoch 910 took 0.04 seconds
# epoch 910| loss: 1.04682 | val_0_accuracy: 0.54762 |  0:00:38s
# ⏱️ Epoch 911 took 0.04 seconds
# epoch 911| loss: 1.07027 | val_0_accuracy: 0.54048 |  0:00:38s
# ⏱️ Epoch 912 took 0.04 seconds
# epoch 912| loss: 0.98513 | val_0_accuracy: 0.51905 |  0:00:39s
# ⏱️ Epoch 913 took 0.04 seconds
# epoch 913| loss: 0.96093 | val_0_accuracy: 0.51429 |  0:00:39s
# ⏱️ Epoch 914 took 0.04 seconds
# epoch 914| loss: 1.04112 | val_0_accuracy: 0.55    |  0:00:39s
# ⏱️ Epoch 915 took 0.04 seconds
# epoch 915| loss: 0.95405 | val_0_accuracy: 0.56429 |  0:00:39s
# ⏱️ Epoch 916 took 0.04 seconds
# epoch 916| loss: 1.00728 | val_0_accuracy: 0.5881  |  0:00:39s
# ⏱️ Epoch 917 took 0.04 seconds
# epoch 917| loss: 1.17064 | val_0_accuracy: 0.56905 |  0:00:39s
# ⏱️ Epoch 918 took 0.04 seconds
# epoch 918| loss: 1.02131 | val_0_accuracy: 0.56667 |  0:00:39s
# ⏱️ Epoch 919 took 0.04 seconds
# epoch 919| loss: 1.0884  | val_0_accuracy: 0.57381 |  0:00:39s
# ⏱️ Epoch 920 took 0.04 seconds
# epoch 920| loss: 1.06582 | val_0_accuracy: 0.56667 |  0:00:39s
# ⏱️ Epoch 921 took 0.04 seconds
# epoch 921| loss: 1.09244 | val_0_accuracy: 0.56905 |  0:00:39s
# ⏱️ Epoch 922 took 0.04 seconds
# epoch 922| loss: 1.21615 | val_0_accuracy: 0.58333 |  0:00:39s
# ⏱️ Epoch 923 took 0.04 seconds
# epoch 923| loss: 1.03161 | val_0_accuracy: 0.60476 |  0:00:39s
# ⏱️ Epoch 924 took 0.04 seconds
# epoch 924| loss: 0.97868 | val_0_accuracy: 0.59524 |  0:00:39s
# ⏱️ Epoch 925 took 0.04 seconds
# epoch 925| loss: 1.00507 | val_0_accuracy: 0.59524 |  0:00:39s
# ⏱️ Epoch 926 took 0.04 seconds
# epoch 926| loss: 1.0321  | val_0_accuracy: 0.57143 |  0:00:39s
# ⏱️ Epoch 927 took 0.04 seconds
# epoch 927| loss: 0.99221 | val_0_accuracy: 0.55    |  0:00:39s
# ⏱️ Epoch 928 took 0.04 seconds
# epoch 928| loss: 1.00114 | val_0_accuracy: 0.54524 |  0:00:39s
# ⏱️ Epoch 929 took 0.04 seconds
# epoch 929| loss: 1.08343 | val_0_accuracy: 0.53333 |  0:00:39s
# ⏱️ Epoch 930 took 0.04 seconds
# epoch 930| loss: 1.12967 | val_0_accuracy: 0.53333 |  0:00:39s
# ⏱️ Epoch 931 took 0.05 seconds
# epoch 931| loss: 1.07567 | val_0_accuracy: 0.5619  |  0:00:39s
# ⏱️ Epoch 932 took 0.05 seconds
# epoch 932| loss: 0.95322 | val_0_accuracy: 0.61905 |  0:00:39s
# ⏱️ Epoch 933 took 0.05 seconds
# epoch 933| loss: 0.95659 | val_0_accuracy: 0.62619 |  0:00:39s
# ⏱️ Epoch 934 took 0.04 seconds
# epoch 934| loss: 0.9737  | val_0_accuracy: 0.6     |  0:00:39s
# ⏱️ Epoch 935 took 0.04 seconds
# epoch 935| loss: 0.94008 | val_0_accuracy: 0.59048 |  0:00:39s
# ⏱️ Epoch 936 took 0.04 seconds
# epoch 936| loss: 1.03826 | val_0_accuracy: 0.59762 |  0:00:40s
# ⏱️ Epoch 937 took 0.04 seconds
# epoch 937| loss: 1.00241 | val_0_accuracy: 0.6119  |  0:00:40s
# ⏱️ Epoch 938 took 0.05 seconds
# epoch 938| loss: 1.00956 | val_0_accuracy: 0.6119  |  0:00:40s
# ⏱️ Epoch 939 took 0.05 seconds
# epoch 939| loss: 0.9959  | val_0_accuracy: 0.61429 |  0:00:40s
# ⏱️ Epoch 940 took 0.05 seconds
# epoch 940| loss: 1.05572 | val_0_accuracy: 0.58095 |  0:00:40s
# ⏱️ Epoch 941 took 0.05 seconds
# epoch 941| loss: 1.05592 | val_0_accuracy: 0.52857 |  0:00:40s
# ⏱️ Epoch 942 took 0.04 seconds
# epoch 942| loss: 1.05066 | val_0_accuracy: 0.50476 |  0:00:40s
# ⏱️ Epoch 943 took 0.04 seconds
# epoch 943| loss: 1.19824 | val_0_accuracy: 0.5119  |  0:00:40s
# ⏱️ Epoch 944 took 0.04 seconds
# epoch 944| loss: 1.04973 | val_0_accuracy: 0.52381 |  0:00:40s
# ⏱️ Epoch 945 took 0.04 seconds
# epoch 945| loss: 1.10029 | val_0_accuracy: 0.54762 |  0:00:40s
# ⏱️ Epoch 946 took 0.04 seconds
# epoch 946| loss: 0.93341 | val_0_accuracy: 0.58333 |  0:00:40s
# ⏱️ Epoch 947 took 0.04 seconds
# epoch 947| loss: 0.98931 | val_0_accuracy: 0.60952 |  0:00:40s
# ⏱️ Epoch 948 took 0.04 seconds
# epoch 948| loss: 1.09349 | val_0_accuracy: 0.59524 |  0:00:40s
# ⏱️ Epoch 949 took 0.04 seconds
# epoch 949| loss: 1.02951 | val_0_accuracy: 0.59048 |  0:00:40s
# ⏱️ Epoch 950 took 0.04 seconds
# epoch 950| loss: 0.96884 | val_0_accuracy: 0.5881  |  0:00:40s
# ⏱️ Epoch 951 took 0.04 seconds
# epoch 951| loss: 0.97231 | val_0_accuracy: 0.59762 |  0:00:40s
# ⏱️ Epoch 952 took 0.04 seconds
# epoch 952| loss: 0.99077 | val_0_accuracy: 0.6     |  0:00:40s
# ⏱️ Epoch 953 took 0.04 seconds
# epoch 953| loss: 0.96262 | val_0_accuracy: 0.60238 |  0:00:40s
# ⏱️ Epoch 954 took 0.04 seconds
# epoch 954| loss: 1.13749 | val_0_accuracy: 0.59048 |  0:00:40s
# ⏱️ Epoch 955 took 0.04 seconds
# epoch 955| loss: 1.09832 | val_0_accuracy: 0.57619 |  0:00:40s
# ⏱️ Epoch 956 took 0.04 seconds
# epoch 956| loss: 1.00191 | val_0_accuracy: 0.59286 |  0:00:40s
# ⏱️ Epoch 957 took 0.04 seconds
# epoch 957| loss: 0.99056 | val_0_accuracy: 0.60238 |  0:00:40s
# ⏱️ Epoch 958 took 0.04 seconds
# epoch 958| loss: 0.8961  | val_0_accuracy: 0.61667 |  0:00:40s
# ⏱️ Epoch 959 took 0.04 seconds
# epoch 959| loss: 1.0041  | val_0_accuracy: 0.60714 |  0:00:41s
# ⏱️ Epoch 960 took 0.04 seconds
# epoch 960| loss: 0.99204 | val_0_accuracy: 0.59048 |  0:00:41s
# ⏱️ Epoch 961 took 0.04 seconds
# epoch 961| loss: 1.04785 | val_0_accuracy: 0.57857 |  0:00:41s
# ⏱️ Epoch 962 took 0.04 seconds
# epoch 962| loss: 0.91089 | val_0_accuracy: 0.60238 |  0:00:41s
# ⏱️ Epoch 963 took 0.04 seconds
# epoch 963| loss: 0.93783 | val_0_accuracy: 0.61429 |  0:00:41s
# ⏱️ Epoch 964 took 0.04 seconds
# epoch 964| loss: 0.91538 | val_0_accuracy: 0.6     |  0:00:41s
# ⏱️ Epoch 965 took 0.04 seconds
# epoch 965| loss: 1.03664 | val_0_accuracy: 0.56667 |  0:00:41s
# ⏱️ Epoch 966 took 0.04 seconds
# epoch 966| loss: 1.06828 | val_0_accuracy: 0.55238 |  0:00:41s
# ⏱️ Epoch 967 took 0.04 seconds
# epoch 967| loss: 1.02452 | val_0_accuracy: 0.56667 |  0:00:41s
# ⏱️ Epoch 968 took 0.04 seconds
# epoch 968| loss: 0.92117 | val_0_accuracy: 0.55    |  0:00:41s
# ⏱️ Epoch 969 took 0.04 seconds
# epoch 969| loss: 1.02381 | val_0_accuracy: 0.58095 |  0:00:41s
# ⏱️ Epoch 970 took 0.04 seconds
# epoch 970| loss: 0.91695 | val_0_accuracy: 0.59286 |  0:00:41s
# ⏱️ Epoch 971 took 0.04 seconds
# epoch 971| loss: 1.07454 | val_0_accuracy: 0.57857 |  0:00:41s
# ⏱️ Epoch 972 took 0.04 seconds
# epoch 972| loss: 0.91182 | val_0_accuracy: 0.55952 |  0:00:41s
# ⏱️ Epoch 973 took 0.04 seconds
# epoch 973| loss: 0.93765 | val_0_accuracy: 0.55476 |  0:00:41s
# ⏱️ Epoch 974 took 0.04 seconds
# epoch 974| loss: 0.96761 | val_0_accuracy: 0.5619  |  0:00:41s
# ⏱️ Epoch 975 took 0.04 seconds
# epoch 975| loss: 1.00225 | val_0_accuracy: 0.57619 |  0:00:41s
# ⏱️ Epoch 976 took 0.04 seconds
# epoch 976| loss: 0.91686 | val_0_accuracy: 0.58095 |  0:00:41s
# ⏱️ Epoch 977 took 0.04 seconds
# epoch 977| loss: 1.05069 | val_0_accuracy: 0.58095 |  0:00:41s
# ⏱️ Epoch 978 took 0.04 seconds
# epoch 978| loss: 1.00848 | val_0_accuracy: 0.56429 |  0:00:41s
# ⏱️ Epoch 979 took 0.04 seconds
# epoch 979| loss: 1.00554 | val_0_accuracy: 0.56667 |  0:00:41s
# ⏱️ Epoch 980 took 0.04 seconds
# epoch 980| loss: 1.00323 | val_0_accuracy: 0.59524 |  0:00:41s
# ⏱️ Epoch 981 took 0.04 seconds
# epoch 981| loss: 1.00576 | val_0_accuracy: 0.59762 |  0:00:41s
# ⏱️ Epoch 982 took 0.04 seconds
# epoch 982| loss: 0.935   | val_0_accuracy: 0.60238 |  0:00:41s
# ⏱️ Epoch 983 took 0.04 seconds
# epoch 983| loss: 0.94778 | val_0_accuracy: 0.61429 |  0:00:42s
# ⏱️ Epoch 984 took 0.04 seconds
# epoch 984| loss: 0.91422 | val_0_accuracy: 0.59048 |  0:00:42s
# ⏱️ Epoch 985 took 0.04 seconds
# epoch 985| loss: 0.94067 | val_0_accuracy: 0.60476 |  0:00:42s
# ⏱️ Epoch 986 took 0.05 seconds
# epoch 986| loss: 0.93109 | val_0_accuracy: 0.61667 |  0:00:42s
# ⏱️ Epoch 987 took 0.05 seconds
# epoch 987| loss: 0.99557 | val_0_accuracy: 0.60952 |  0:00:42s
# ⏱️ Epoch 988 took 0.05 seconds
# epoch 988| loss: 0.90666 | val_0_accuracy: 0.6     |  0:00:42s
# ⏱️ Epoch 989 took 0.04 seconds
# epoch 989| loss: 0.99465 | val_0_accuracy: 0.6119  |  0:00:42s
# ⏱️ Epoch 990 took 0.04 seconds
# epoch 990| loss: 1.03259 | val_0_accuracy: 0.61667 |  0:00:42s
# ⏱️ Epoch 991 took 0.04 seconds
# epoch 991| loss: 0.95359 | val_0_accuracy: 0.62143 |  0:00:42s
# ⏱️ Epoch 992 took 0.04 seconds
# epoch 992| loss: 1.01058 | val_0_accuracy: 0.60952 |  0:00:42s
# ⏱️ Epoch 993 took 0.04 seconds
# epoch 993| loss: 1.08749 | val_0_accuracy: 0.61905 |  0:00:42s
# ⏱️ Epoch 994 took 0.05 seconds
# epoch 994| loss: 1.06021 | val_0_accuracy: 0.63333 |  0:00:42s
# ⏱️ Epoch 995 took 0.05 seconds
# epoch 995| loss: 1.00945 | val_0_accuracy: 0.63333 |  0:00:42s
# ⏱️ Epoch 996 took 0.04 seconds
# epoch 996| loss: 0.98351 | val_0_accuracy: 0.61667 |  0:00:42s
# ⏱️ Epoch 997 took 0.04 seconds
# epoch 997| loss: 0.99499 | val_0_accuracy: 0.59762 |  0:00:42s
# ⏱️ Epoch 998 took 0.04 seconds
# epoch 998| loss: 1.09543 | val_0_accuracy: 0.57857 |  0:00:42s
# ⏱️ Epoch 999 took 0.04 seconds
# epoch 999| loss: 0.97272 | val_0_accuracy: 0.58571 |  0:00:42s
# ⏱️ Epoch 1000 took 0.04 seconds
# Stop training because you reached max_epochs = 1000 with best_epoch = 880 and best_val_0_accuracy = 0.6381

# %%
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

file_path = os.path.join("results", f"gtd{partition}.txt")

# Predict class indices for test set
y_pred = final_model.predict(Xtest)
y_proba = final_model.predict_proba(Xtest)
y_pred_decoded = le.inverse_transform(y_pred)
y_true_decoded = le.inverse_transform(Ytest)

# Make sure the directory exists
os.makedirs("results", exist_ok=True)

# Compute accuracy from decoded labels
acc = accuracy_score(y_true_decoded, y_pred_decoded)

# Write metrics to file
with open(file_path, "w") as file:
    file.write(f"Accuracy: {acc:.4f}\n")
    file.write(f"Precision weighted: {precision_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Recall weighted: {recall_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"F1 Score weighted: {f1_score(y_true_decoded, y_pred_decoded, average='weighted'):.4f}\n")
    file.write(f"Precision micro: {precision_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Recall micro: {recall_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"F1 Score micro: {f1_score(y_true_decoded, y_pred_decoded, average='micro'):.4f}\n")
    file.write(f"Precision macro: {precision_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"Recall macro: {recall_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"F1 Score macro: {f1_score(y_true_decoded, y_pred_decoded, average='macro'):.4f}\n")
    file.write(f"roc auc weighted: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='weighted'):.4f}\n")
    file.write(f"roc auc macro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='macro'):.4f}\n")
    file.write(f"roc auc micro: {roc_auc_score(y_true_decoded, y_proba, multi_class='ovr', average='micro'):.4f}\n")

with open(f"results/epoch_time_gtd{partition}.txt", "w") as f:
    f.write('\n'.join(str(x) for x in epoch_timer.epoch_times))

# %%
print(classification_report(Ytest_decoded, y_pred_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.27      0.47      0.34        30
#         African National Congress (South Africa)       0.75      0.80      0.77        30
#                                 Al-Qaida in Iraq       0.32      0.40      0.35        30
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.43      0.40      0.41        30
#                                       Al-Shabaab       0.37      0.43      0.40        30
#              Basque Fatherland and Freedom (ETA)       0.76      0.73      0.75        30
#                                       Boko Haram       0.46      0.37      0.41        30
#   Communist Party of India - Maoist (CPI-Maoist)       0.64      0.77      0.70        30
#        Corsican National Liberation Front (FLNC)       0.77      0.80      0.79        30
#                        Donetsk People's Republic       0.50      0.57      0.53        30
# Farabundo Marti National Liberation Front (FMLN)       0.50      0.67      0.57        30
#                                Fulani extremists       0.56      0.63      0.59        30
#                  Houthi extremists (Ansar Allah)       0.50      0.53      0.52        30
#                      Irish Republican Army (IRA)       0.85      0.73      0.79        30
#      Islamic State of Iraq and the Levant (ISIL)       0.46      0.37      0.41        30
#                   Kurdistan Workers' Party (PKK)       0.44      0.40      0.42        30
#          Liberation Tigers of Tamil Eelam (LTTE)       0.59      0.67      0.62        30
#          Manuel Rodriguez Patriotic Front (FPMR)       0.67      0.73      0.70        30
#                                          Maoists       0.59      0.57      0.58        30
#                                Muslim extremists       0.48      0.37      0.42        30
#       National Liberation Army of Colombia (ELN)       0.78      0.60      0.68        30
#                          New People's Army (NPA)       0.55      0.60      0.57        30
#                Nicaraguan Democratic Force (FDN)       0.79      0.63      0.70        30
#                                     Palestinians       0.59      0.43      0.50        30
#    Revolutionary Armed Forces of Colombia (FARC)       0.40      0.33      0.36        30
#                                Shining Path (SL)       0.45      0.43      0.44        30
#                                  Sikh Extremists       0.78      0.60      0.68        30
#                                          Taliban       0.32      0.20      0.24        30
#                  Tehrik-i-Taliban Pakistan (TTP)       0.65      0.57      0.61        30
#        Tupac Amaru Revolutionary Movement (MRTA)       0.69      0.80      0.74        30
#
#                                         accuracy                           0.55       900
#                                        macro avg       0.56      0.55      0.55       900
#                                     weighted avg       0.56      0.55      0.55       900

# %%
def plot_confusion_matrix(y_true, y_pred, labels):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"results/confusion_matrix_partition_{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
# Get all unique class labels from the truths
class_labels = np.unique(Ytest_decoded)

plot_confusion_matrix(Ytest_decoded, y_pred_decoded, labels=class_labels)
# Out:
# Saved confusion matrix for partition 100 to results/confusion_matrix_partition_100.png
