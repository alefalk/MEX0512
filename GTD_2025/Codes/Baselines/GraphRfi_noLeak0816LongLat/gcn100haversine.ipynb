# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
combined_geo = combined_geo.drop(columns=geodata)

# %%
import ast

def to_tuple_if_needed(val):
    if isinstance(val, str):
        return ast.literal_eval(val)
    return val  # already a tuple

combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid
param_grid = {
    'lr': [0.001, 0.01],
    'n_tree': [50, 80, 120],
    'tree_depth': [9, 10, 12],
    'tree_feature_rate': [0.1, 0.3,0.5],
    'feat_dropout': [0.1],
    'embed_dim': [32, 64]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 20)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# tensor(1142)
# tensor(459)
# tensor(470)
# tensor(2328)
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4505 | NRF Loss: 3.4012 | Joint: 6.8517 | Val Acc: 0.0733
# Epoch 050 | GCN Loss: 3.0194 | NRF Loss: 3.3795 | Joint: 6.3989 | Val Acc: 0.4183
# Epoch 100 | GCN Loss: 2.5819 | NRF Loss: 3.2794 | Joint: 5.8614 | Val Acc: 0.3233
# Epoch 150 | GCN Loss: 2.2368 | NRF Loss: 3.1270 | Joint: 5.3638 | Val Acc: 0.3117
# Epoch 200 | GCN Loss: 1.9817 | NRF Loss: 2.9693 | Joint: 4.9510 | Val Acc: 0.3833
# Epoch 250 | GCN Loss: 1.7836 | NRF Loss: 2.8202 | Joint: 4.6038 | Val Acc: 0.4300
# Epoch 300 | GCN Loss: 1.6243 | NRF Loss: 2.6798 | Joint: 4.3041 | Val Acc: 0.4983
# Epoch 350 | GCN Loss: 1.4942 | NRF Loss: 2.5487 | Joint: 4.0429 | Val Acc: 0.5567
# Epoch 400 | GCN Loss: 1.3860 | NRF Loss: 2.4257 | Joint: 3.8117 | Val Acc: 0.5800
# Epoch 450 | GCN Loss: 1.2941 | NRF Loss: 2.3181 | Joint: 3.6122 | Val Acc: 0.6133
# Epoch 500 | GCN Loss: 1.2150 | NRF Loss: 2.2215 | Joint: 3.4365 | Val Acc: 0.6533
# Epoch 550 | GCN Loss: 1.1469 | NRF Loss: 2.1426 | Joint: 3.2896 | Val Acc: 0.7017
# Epoch 600 | GCN Loss: 1.0882 | NRF Loss: 2.0637 | Joint: 3.1519 | Val Acc: 0.7267
# Epoch 650 | GCN Loss: 1.0373 | NRF Loss: 1.9954 | Joint: 3.0327 | Val Acc: 0.7283
# Epoch 700 | GCN Loss: 0.9931 | NRF Loss: 1.9301 | Joint: 2.9231 | Val Acc: 0.7400
# Epoch 750 | GCN Loss: 0.9544 | NRF Loss: 1.8659 | Joint: 2.8202 | Val Acc: 0.7283
# Epoch 800 | GCN Loss: 0.9203 | NRF Loss: 1.8142 | Joint: 2.7344 | Val Acc: 0.7233
# Epoch 850 | GCN Loss: 0.8899 | NRF Loss: 1.7688 | Joint: 2.6587 | Val Acc: 0.7200
# Epoch 900 | GCN Loss: 0.8628 | NRF Loss: 1.7209 | Joint: 2.5837 | Val Acc: 0.7133
# Epoch 950 | GCN Loss: 0.8384 | NRF Loss: 1.6759 | Joint: 2.5143 | Val Acc: 0.7083
# Epoch 1000 | GCN Loss: 0.8164 | NRF Loss: 1.6412 | Joint: 2.4576 | Val Acc: 0.7100
# Epoch 1050 | GCN Loss: 0.7962 | NRF Loss: 1.6085 | Joint: 2.4047 | Val Acc: 0.7133
# Epoch 1100 | GCN Loss: 0.7777 | NRF Loss: 1.5710 | Joint: 2.3487 | Val Acc: 0.7083
# Early stopping at epoch 1101
# Best validation acc: 0.7417 @ epoch 701
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 12, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4303 | NRF Loss: 3.4012 | Joint: 6.8315 | Val Acc: 0.1767
# Epoch 050 | GCN Loss: 1.2963 | NRF Loss: 2.4204 | Joint: 3.7167 | Val Acc: 0.6233
# Epoch 100 | GCN Loss: 0.8511 | NRF Loss: 1.5908 | Joint: 2.4418 | Val Acc: 0.6867
# Epoch 150 | GCN Loss: 0.6954 | NRF Loss: 1.1820 | Joint: 1.8774 | Val Acc: 0.7233
# Epoch 200 | GCN Loss: 0.6093 | NRF Loss: 0.9742 | Joint: 1.5835 | Val Acc: 0.7683
# Epoch 250 | GCN Loss: 0.5529 | NRF Loss: 0.8652 | Joint: 1.4182 | Val Acc: 0.8067
# Epoch 300 | GCN Loss: 0.5127 | NRF Loss: 0.7974 | Joint: 1.3102 | Val Acc: 0.8117
# Epoch 350 | GCN Loss: 0.4835 | NRF Loss: 0.7465 | Joint: 1.2300 | Val Acc: 0.8167
# Epoch 400 | GCN Loss: 0.4617 | NRF Loss: 0.7084 | Joint: 1.1702 | Val Acc: 0.8233
# Epoch 450 | GCN Loss: 0.4452 | NRF Loss: 0.6870 | Joint: 1.1322 | Val Acc: 0.8150
# Epoch 500 | GCN Loss: 0.4313 | NRF Loss: 0.6608 | Joint: 1.0921 | Val Acc: 0.8200
# Epoch 550 | GCN Loss: 0.4204 | NRF Loss: 0.6419 | Joint: 1.0624 | Val Acc: 0.8217
# Epoch 600 | GCN Loss: 0.4105 | NRF Loss: 0.6288 | Joint: 1.0393 | Val Acc: 0.8167
# Epoch 650 | GCN Loss: 0.4020 | NRF Loss: 0.6134 | Joint: 1.0154 | Val Acc: 0.8250
# Epoch 700 | GCN Loss: 0.3947 | NRF Loss: 0.6033 | Joint: 0.9980 | Val Acc: 0.8217
# Epoch 750 | GCN Loss: 0.3880 | NRF Loss: 0.5916 | Joint: 0.9796 | Val Acc: 0.8233
# Epoch 800 | GCN Loss: 0.3812 | NRF Loss: 0.5817 | Joint: 0.9630 | Val Acc: 0.8333
# Epoch 850 | GCN Loss: 0.3747 | NRF Loss: 0.5722 | Joint: 0.9469 | Val Acc: 0.8250
# Epoch 900 | GCN Loss: 0.3689 | NRF Loss: 0.5642 | Joint: 0.9332 | Val Acc: 0.8217
# Epoch 950 | GCN Loss: 0.3634 | NRF Loss: 0.5543 | Joint: 0.9177 | Val Acc: 0.8317
# Epoch 1000 | GCN Loss: 0.3585 | NRF Loss: 0.5505 | Joint: 0.9090 | Val Acc: 0.8217
# Epoch 1050 | GCN Loss: 0.3540 | NRF Loss: 0.5459 | Joint: 0.8999 | Val Acc: 0.8150
# Epoch 1100 | GCN Loss: 0.3492 | NRF Loss: 0.5424 | Joint: 0.8915 | Val Acc: 0.8383
# Epoch 1150 | GCN Loss: 0.3454 | NRF Loss: 0.5341 | Joint: 0.8795 | Val Acc: 0.8267
# Epoch 1200 | GCN Loss: 0.3425 | NRF Loss: 0.5306 | Joint: 0.8730 | Val Acc: 0.8433
# Epoch 1250 | GCN Loss: 0.3375 | NRF Loss: 0.5248 | Joint: 0.8624 | Val Acc: 0.8450
# Epoch 1300 | GCN Loss: 0.3341 | NRF Loss: 0.5216 | Joint: 0.8556 | Val Acc: 0.8417
# Epoch 1350 | GCN Loss: 0.3308 | NRF Loss: 0.5173 | Joint: 0.8481 | Val Acc: 0.8433
# Epoch 1400 | GCN Loss: 0.3282 | NRF Loss: 0.5174 | Joint: 0.8456 | Val Acc: 0.8383
# Epoch 1450 | GCN Loss: 0.3247 | NRF Loss: 0.5119 | Joint: 0.8366 | Val Acc: 0.8417
# Epoch 1500 | GCN Loss: 0.3220 | NRF Loss: 0.5103 | Joint: 0.8323 | Val Acc: 0.8267
# Epoch 1550 | GCN Loss: 0.3194 | NRF Loss: 0.5034 | Joint: 0.8228 | Val Acc: 0.8433
# Epoch 1600 | GCN Loss: 0.3170 | NRF Loss: 0.4955 | Joint: 0.8125 | Val Acc: 0.8483
# Early stopping at epoch 1624
# Best validation acc: 0.8567 @ epoch 1224
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4432 | NRF Loss: 3.4012 | Joint: 6.8444 | Val Acc: 0.1500
# Epoch 050 | GCN Loss: 1.5595 | NRF Loss: 2.4074 | Joint: 3.9670 | Val Acc: 0.6350
# Epoch 100 | GCN Loss: 1.0295 | NRF Loss: 1.5772 | Joint: 2.6067 | Val Acc: 0.7417
# Epoch 150 | GCN Loss: 0.8236 | NRF Loss: 1.1610 | Joint: 1.9846 | Val Acc: 0.7617
# Epoch 200 | GCN Loss: 0.7144 | NRF Loss: 0.9610 | Joint: 1.6755 | Val Acc: 0.7950
# Epoch 250 | GCN Loss: 0.6425 | NRF Loss: 0.8556 | Joint: 1.4981 | Val Acc: 0.8117
# Epoch 300 | GCN Loss: 0.5919 | NRF Loss: 0.7836 | Joint: 1.3755 | Val Acc: 0.8117
# Epoch 350 | GCN Loss: 0.5544 | NRF Loss: 0.7328 | Joint: 1.2872 | Val Acc: 0.8217
# Epoch 400 | GCN Loss: 0.5251 | NRF Loss: 0.6967 | Joint: 1.2218 | Val Acc: 0.8183
# Epoch 450 | GCN Loss: 0.5026 | NRF Loss: 0.6677 | Joint: 1.1703 | Val Acc: 0.8267
# Epoch 500 | GCN Loss: 0.4843 | NRF Loss: 0.6402 | Joint: 1.1245 | Val Acc: 0.8400
# Epoch 550 | GCN Loss: 0.4697 | NRF Loss: 0.6215 | Joint: 1.0911 | Val Acc: 0.8383
# Epoch 600 | GCN Loss: 0.4576 | NRF Loss: 0.6059 | Joint: 1.0634 | Val Acc: 0.8300
# Epoch 650 | GCN Loss: 0.4477 | NRF Loss: 0.5901 | Joint: 1.0378 | Val Acc: 0.8383
# Epoch 700 | GCN Loss: 0.4387 | NRF Loss: 0.5766 | Joint: 1.0153 | Val Acc: 0.8367
# Epoch 750 | GCN Loss: 0.4310 | NRF Loss: 0.5631 | Joint: 0.9941 | Val Acc: 0.8350
# Epoch 800 | GCN Loss: 0.4242 | NRF Loss: 0.5547 | Joint: 0.9789 | Val Acc: 0.8467
# Epoch 850 | GCN Loss: 0.4183 | NRF Loss: 0.5424 | Joint: 0.9607 | Val Acc: 0.8417
# Epoch 900 | GCN Loss: 0.4128 | NRF Loss: 0.5327 | Joint: 0.9455 | Val Acc: 0.8617
# Epoch 950 | GCN Loss: 0.4078 | NRF Loss: 0.5279 | Joint: 0.9357 | Val Acc: 0.8450
# Epoch 1000 | GCN Loss: 0.4030 | NRF Loss: 0.5189 | Joint: 0.9219 | Val Acc: 0.8433
# Epoch 1050 | GCN Loss: 0.3989 | NRF Loss: 0.5102 | Joint: 0.9090 | Val Acc: 0.8483
# Epoch 1100 | GCN Loss: 0.3949 | NRF Loss: 0.5042 | Joint: 0.8990 | Val Acc: 0.8550
# Epoch 1150 | GCN Loss: 0.3914 | NRF Loss: 0.4968 | Joint: 0.8882 | Val Acc: 0.8467
# Epoch 1200 | GCN Loss: 0.3880 | NRF Loss: 0.4895 | Joint: 0.8775 | Val Acc: 0.8583
# Epoch 1250 | GCN Loss: 0.3849 | NRF Loss: 0.4801 | Joint: 0.8651 | Val Acc: 0.8500
# Early stopping at epoch 1299
# Best validation acc: 0.8667 @ epoch 899
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 120, 'tree_depth': 9, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4267 | NRF Loss: 3.4012 | Joint: 6.8279 | Val Acc: 0.0333
# Epoch 050 | GCN Loss: 3.0243 | NRF Loss: 3.3666 | Joint: 6.3909 | Val Acc: 0.2567
# Epoch 100 | GCN Loss: 2.5829 | NRF Loss: 3.2160 | Joint: 5.7989 | Val Acc: 0.2433
# Epoch 150 | GCN Loss: 2.2268 | NRF Loss: 3.0228 | Joint: 5.2496 | Val Acc: 0.3400
# Epoch 200 | GCN Loss: 1.9715 | NRF Loss: 2.8402 | Joint: 4.8117 | Val Acc: 0.4400
# Epoch 250 | GCN Loss: 1.7774 | NRF Loss: 2.6826 | Joint: 4.4600 | Val Acc: 0.5083
# Epoch 300 | GCN Loss: 1.6228 | NRF Loss: 2.5475 | Joint: 4.1703 | Val Acc: 0.5683
# Epoch 350 | GCN Loss: 1.4957 | NRF Loss: 2.4289 | Joint: 3.9246 | Val Acc: 0.5867
# Epoch 400 | GCN Loss: 1.3899 | NRF Loss: 2.3252 | Joint: 3.7151 | Val Acc: 0.5817
# Epoch 450 | GCN Loss: 1.2999 | NRF Loss: 2.2309 | Joint: 3.5308 | Val Acc: 0.6033
# Epoch 500 | GCN Loss: 1.2224 | NRF Loss: 2.1473 | Joint: 3.3697 | Val Acc: 0.6167
# Epoch 550 | GCN Loss: 1.1557 | NRF Loss: 2.0696 | Joint: 3.2252 | Val Acc: 0.6250
# Epoch 600 | GCN Loss: 1.0981 | NRF Loss: 1.9974 | Joint: 3.0955 | Val Acc: 0.6400
# Epoch 650 | GCN Loss: 1.0482 | NRF Loss: 1.9328 | Joint: 2.9809 | Val Acc: 0.6533
# Epoch 700 | GCN Loss: 1.0047 | NRF Loss: 1.8740 | Joint: 2.8787 | Val Acc: 0.6617
# Epoch 750 | GCN Loss: 0.9666 | NRF Loss: 1.8193 | Joint: 2.7860 | Val Acc: 0.6733
# Epoch 800 | GCN Loss: 0.9328 | NRF Loss: 1.7689 | Joint: 2.7018 | Val Acc: 0.6833
# Epoch 850 | GCN Loss: 0.9027 | NRF Loss: 1.7232 | Joint: 2.6259 | Val Acc: 0.6817
# Epoch 900 | GCN Loss: 0.8756 | NRF Loss: 1.6772 | Joint: 2.5528 | Val Acc: 0.6850
# Epoch 950 | GCN Loss: 0.8511 | NRF Loss: 1.6350 | Joint: 2.4861 | Val Acc: 0.6983
# Epoch 1000 | GCN Loss: 0.8290 | NRF Loss: 1.5999 | Joint: 2.4289 | Val Acc: 0.7067
# Epoch 1050 | GCN Loss: 0.8088 | NRF Loss: 1.5616 | Joint: 2.3704 | Val Acc: 0.7083
# Epoch 1100 | GCN Loss: 0.7903 | NRF Loss: 1.5285 | Joint: 2.3188 | Val Acc: 0.7133
# Epoch 1150 | GCN Loss: 0.7731 | NRF Loss: 1.4968 | Joint: 2.2699 | Val Acc: 0.7150
# Epoch 1200 | GCN Loss: 0.7572 | NRF Loss: 1.4640 | Joint: 2.2212 | Val Acc: 0.7200
# Epoch 1250 | GCN Loss: 0.7423 | NRF Loss: 1.4402 | Joint: 2.1824 | Val Acc: 0.7167
# Epoch 1300 | GCN Loss: 0.7284 | NRF Loss: 1.4129 | Joint: 2.1414 | Val Acc: 0.7167
# Epoch 1350 | GCN Loss: 0.7154 | NRF Loss: 1.3851 | Joint: 2.1006 | Val Acc: 0.7200
# Epoch 1400 | GCN Loss: 0.7032 | NRF Loss: 1.3649 | Joint: 2.0681 | Val Acc: 0.7317
# Epoch 1450 | GCN Loss: 0.6916 | NRF Loss: 1.3408 | Joint: 2.0324 | Val Acc: 0.7317
# Epoch 1500 | GCN Loss: 0.6806 | NRF Loss: 1.3213 | Joint: 2.0019 | Val Acc: 0.7350
# Epoch 1550 | GCN Loss: 0.6702 | NRF Loss: 1.3002 | Joint: 1.9704 | Val Acc: 0.7383
# Epoch 1600 | GCN Loss: 0.6603 | NRF Loss: 1.2805 | Joint: 1.9407 | Val Acc: 0.7417
# Epoch 1650 | GCN Loss: 0.6508 | NRF Loss: 1.2636 | Joint: 1.9145 | Val Acc: 0.7417
# Epoch 1700 | GCN Loss: 0.6418 | NRF Loss: 1.2484 | Joint: 1.8902 | Val Acc: 0.7367
# Epoch 1750 | GCN Loss: 0.6330 | NRF Loss: 1.2306 | Joint: 1.8636 | Val Acc: 0.7383
# Epoch 1800 | GCN Loss: 0.6246 | NRF Loss: 1.2165 | Joint: 1.8411 | Val Acc: 0.7433
# Epoch 1850 | GCN Loss: 0.6165 | NRF Loss: 1.2020 | Joint: 1.8184 | Val Acc: 0.7433
# Epoch 1900 | GCN Loss: 0.6087 | NRF Loss: 1.1843 | Joint: 1.7930 | Val Acc: 0.7517
# Epoch 1950 | GCN Loss: 0.6012 | NRF Loss: 1.1705 | Joint: 1.7717 | Val Acc: 0.7550
# Epoch 2000 | GCN Loss: 0.5940 | NRF Loss: 1.1583 | Joint: 1.7523 | Val Acc: 0.7567
# Epoch 2050 | GCN Loss: 0.5869 | NRF Loss: 1.1454 | Joint: 1.7324 | Val Acc: 0.7550
# Epoch 2100 | GCN Loss: 0.5801 | NRF Loss: 1.1307 | Joint: 1.7108 | Val Acc: 0.7533
# Epoch 2150 | GCN Loss: 0.5734 | NRF Loss: 1.1218 | Joint: 1.6952 | Val Acc: 0.7633
# Epoch 2200 | GCN Loss: 0.5670 | NRF Loss: 1.1115 | Joint: 1.6784 | Val Acc: 0.7683
# Epoch 2250 | GCN Loss: 0.5608 | NRF Loss: 1.1026 | Joint: 1.6634 | Val Acc: 0.7800
# Epoch 2300 | GCN Loss: 0.5548 | NRF Loss: 1.0920 | Joint: 1.6468 | Val Acc: 0.7733
# Epoch 2350 | GCN Loss: 0.5490 | NRF Loss: 1.0813 | Joint: 1.6304 | Val Acc: 0.7700
# Epoch 2400 | GCN Loss: 0.5430 | NRF Loss: 1.0738 | Joint: 1.6168 | Val Acc: 0.7700
# Epoch 2450 | GCN Loss: 0.5372 | NRF Loss: 1.0631 | Joint: 1.6003 | Val Acc: 0.7733
# Epoch 2500 | GCN Loss: 0.5318 | NRF Loss: 1.0543 | Joint: 1.5861 | Val Acc: 0.7717
# Epoch 2550 | GCN Loss: 0.5265 | NRF Loss: 1.0466 | Joint: 1.5732 | Val Acc: 0.7700
# Epoch 2600 | GCN Loss: 0.5213 | NRF Loss: 1.0402 | Joint: 1.5615 | Val Acc: 0.7767
# Epoch 2650 | GCN Loss: 0.5163 | NRF Loss: 1.0340 | Joint: 1.5503 | Val Acc: 0.7750
# Epoch 2700 | GCN Loss: 0.5113 | NRF Loss: 1.0250 | Joint: 1.5363 | Val Acc: 0.7733
# Epoch 2750 | GCN Loss: 0.5066 | NRF Loss: 1.0169 | Joint: 1.5235 | Val Acc: 0.7750
# Epoch 2800 | GCN Loss: 0.5020 | NRF Loss: 1.0108 | Joint: 1.5127 | Val Acc: 0.7850
# Epoch 2850 | GCN Loss: 0.4975 | NRF Loss: 1.0053 | Joint: 1.5028 | Val Acc: 0.7883
# Epoch 2900 | GCN Loss: 0.4931 | NRF Loss: 0.9991 | Joint: 1.4923 | Val Acc: 0.7733
# Epoch 2950 | GCN Loss: 0.4888 | NRF Loss: 0.9921 | Joint: 1.4809 | Val Acc: 0.7750
# Best validation acc: 0.7917 @ epoch 2840
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3967 | NRF Loss: 3.4012 | Joint: 6.7979 | Val Acc: 0.1817
# Epoch 050 | GCN Loss: 1.2811 | NRF Loss: 2.4715 | Joint: 3.7527 | Val Acc: 0.5683
# Epoch 100 | GCN Loss: 0.8391 | NRF Loss: 1.6796 | Joint: 2.5187 | Val Acc: 0.7050
# Epoch 150 | GCN Loss: 0.6950 | NRF Loss: 1.2839 | Joint: 1.9789 | Val Acc: 0.7317
# Epoch 200 | GCN Loss: 0.6113 | NRF Loss: 1.0892 | Joint: 1.7005 | Val Acc: 0.7383
# Epoch 250 | GCN Loss: 0.5536 | NRF Loss: 0.9750 | Joint: 1.5286 | Val Acc: 0.7583
# Epoch 300 | GCN Loss: 0.5138 | NRF Loss: 0.9030 | Joint: 1.4168 | Val Acc: 0.7733
# Epoch 350 | GCN Loss: 0.4856 | NRF Loss: 0.8559 | Joint: 1.3415 | Val Acc: 0.7800
# Epoch 400 | GCN Loss: 0.4643 | NRF Loss: 0.8189 | Joint: 1.2832 | Val Acc: 0.7983
# Epoch 450 | GCN Loss: 0.4468 | NRF Loss: 0.7900 | Joint: 1.2368 | Val Acc: 0.8050
# Epoch 500 | GCN Loss: 0.4325 | NRF Loss: 0.7647 | Joint: 1.1972 | Val Acc: 0.7967
# Epoch 550 | GCN Loss: 0.4218 | NRF Loss: 0.7462 | Joint: 1.1680 | Val Acc: 0.8083
# Epoch 600 | GCN Loss: 0.4114 | NRF Loss: 0.7311 | Joint: 1.1425 | Val Acc: 0.8133
# Epoch 650 | GCN Loss: 0.4031 | NRF Loss: 0.7113 | Joint: 1.1144 | Val Acc: 0.8067
# Epoch 700 | GCN Loss: 0.3960 | NRF Loss: 0.7023 | Joint: 1.0983 | Val Acc: 0.8217
# Epoch 750 | GCN Loss: 0.3899 | NRF Loss: 0.6909 | Joint: 1.0808 | Val Acc: 0.8317
# Epoch 800 | GCN Loss: 0.3844 | NRF Loss: 0.6816 | Joint: 1.0660 | Val Acc: 0.8250
# Epoch 850 | GCN Loss: 0.3778 | NRF Loss: 0.6722 | Joint: 1.0501 | Val Acc: 0.8433
# Epoch 900 | GCN Loss: 0.3727 | NRF Loss: 0.6645 | Joint: 1.0372 | Val Acc: 0.8367
# Epoch 950 | GCN Loss: 0.3678 | NRF Loss: 0.6577 | Joint: 1.0255 | Val Acc: 0.8433
# Epoch 1000 | GCN Loss: 0.3634 | NRF Loss: 0.6468 | Joint: 1.0102 | Val Acc: 0.8283
# Epoch 1050 | GCN Loss: 0.3589 | NRF Loss: 0.6386 | Joint: 0.9974 | Val Acc: 0.8300
# Epoch 1100 | GCN Loss: 0.3550 | NRF Loss: 0.6336 | Joint: 0.9886 | Val Acc: 0.8450
# Epoch 1150 | GCN Loss: 0.3514 | NRF Loss: 0.6246 | Joint: 0.9760 | Val Acc: 0.8400
# Epoch 1200 | GCN Loss: 0.3477 | NRF Loss: 0.6177 | Joint: 0.9655 | Val Acc: 0.8333
# Epoch 1250 | GCN Loss: 0.3444 | NRF Loss: 0.6134 | Joint: 0.9578 | Val Acc: 0.8450
# Epoch 1300 | GCN Loss: 0.3414 | NRF Loss: 0.6091 | Joint: 0.9505 | Val Acc: 0.8450
# Epoch 1350 | GCN Loss: 0.3386 | NRF Loss: 0.6000 | Joint: 0.9387 | Val Acc: 0.8417
# Epoch 1400 | GCN Loss: 0.3359 | NRF Loss: 0.5972 | Joint: 0.9331 | Val Acc: 0.8483
# Epoch 1450 | GCN Loss: 0.3336 | NRF Loss: 0.5923 | Joint: 0.9259 | Val Acc: 0.8517
# Epoch 1500 | GCN Loss: 0.3302 | NRF Loss: 0.5889 | Joint: 0.9191 | Val Acc: 0.8433
# Epoch 1550 | GCN Loss: 0.3276 | NRF Loss: 0.5854 | Joint: 0.9130 | Val Acc: 0.8417
# Epoch 1600 | GCN Loss: 0.3249 | NRF Loss: 0.5833 | Joint: 0.9083 | Val Acc: 0.8450
# Epoch 1650 | GCN Loss: 0.3222 | NRF Loss: 0.5746 | Joint: 0.8969 | Val Acc: 0.8467
# Epoch 1700 | GCN Loss: 0.3200 | NRF Loss: 0.5716 | Joint: 0.8916 | Val Acc: 0.8483
# Epoch 1750 | GCN Loss: 0.3184 | NRF Loss: 0.5672 | Joint: 0.8856 | Val Acc: 0.8500
# Epoch 1800 | GCN Loss: 0.3156 | NRF Loss: 0.5607 | Joint: 0.8762 | Val Acc: 0.8517
# Epoch 1850 | GCN Loss: 0.3133 | NRF Loss: 0.5552 | Joint: 0.8685 | Val Acc: 0.8450
# Epoch 1900 | GCN Loss: 0.3112 | NRF Loss: 0.5520 | Joint: 0.8632 | Val Acc: 0.8533
# Epoch 1950 | GCN Loss: 0.3090 | NRF Loss: 0.5470 | Joint: 0.8561 | Val Acc: 0.8517
# Epoch 2000 | GCN Loss: 0.3069 | NRF Loss: 0.5453 | Joint: 0.8522 | Val Acc: 0.8500
# Epoch 2050 | GCN Loss: 0.3050 | NRF Loss: 0.5430 | Joint: 0.8480 | Val Acc: 0.8533
# Epoch 2100 | GCN Loss: 0.3035 | NRF Loss: 0.5413 | Joint: 0.8447 | Val Acc: 0.8517
# Epoch 2150 | GCN Loss: 0.3017 | NRF Loss: 0.5353 | Joint: 0.8369 | Val Acc: 0.8533
# Epoch 2200 | GCN Loss: 0.3001 | NRF Loss: 0.5358 | Joint: 0.8359 | Val Acc: 0.8600
# Epoch 2250 | GCN Loss: 0.2983 | NRF Loss: 0.5312 | Joint: 0.8294 | Val Acc: 0.8500
# Epoch 2300 | GCN Loss: 0.2967 | NRF Loss: 0.5286 | Joint: 0.8253 | Val Acc: 0.8550
# Epoch 2350 | GCN Loss: 0.2952 | NRF Loss: 0.5237 | Joint: 0.8189 | Val Acc: 0.8567
# Epoch 2400 | GCN Loss: 0.2948 | NRF Loss: 0.5261 | Joint: 0.8209 | Val Acc: 0.8483
# Epoch 2450 | GCN Loss: 0.2924 | NRF Loss: 0.5212 | Joint: 0.8135 | Val Acc: 0.8517
# Epoch 2500 | GCN Loss: 0.2912 | NRF Loss: 0.5175 | Joint: 0.8087 | Val Acc: 0.8583
# Epoch 2550 | GCN Loss: 0.2897 | NRF Loss: 0.5128 | Joint: 0.8025 | Val Acc: 0.8600
# Epoch 2600 | GCN Loss: 0.2885 | NRF Loss: 0.5124 | Joint: 0.8008 | Val Acc: 0.8567
# Epoch 2650 | GCN Loss: 0.2874 | NRF Loss: 0.5138 | Joint: 0.8013 | Val Acc: 0.8550
# Early stopping at epoch 2668
# Best validation acc: 0.8667 @ epoch 2268
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4147 | NRF Loss: 3.4012 | Joint: 6.8159 | Val Acc: 0.1017
# Epoch 050 | GCN Loss: 1.2696 | NRF Loss: 2.5855 | Joint: 3.8551 | Val Acc: 0.5900
# Epoch 100 | GCN Loss: 0.8580 | NRF Loss: 1.7254 | Joint: 2.5833 | Val Acc: 0.7133
# Epoch 150 | GCN Loss: 0.7068 | NRF Loss: 1.2999 | Joint: 2.0067 | Val Acc: 0.7250
# Epoch 200 | GCN Loss: 0.6201 | NRF Loss: 1.0950 | Joint: 1.7151 | Val Acc: 0.7667
# Epoch 250 | GCN Loss: 0.5609 | NRF Loss: 0.9843 | Joint: 1.5452 | Val Acc: 0.7983
# Epoch 300 | GCN Loss: 0.5194 | NRF Loss: 0.9169 | Joint: 1.4363 | Val Acc: 0.8083
# Epoch 350 | GCN Loss: 0.4889 | NRF Loss: 0.8742 | Joint: 1.3631 | Val Acc: 0.8183
# Epoch 400 | GCN Loss: 0.4659 | NRF Loss: 0.8417 | Joint: 1.3076 | Val Acc: 0.8167
# Epoch 450 | GCN Loss: 0.4482 | NRF Loss: 0.8176 | Joint: 1.2657 | Val Acc: 0.8200
# Epoch 500 | GCN Loss: 0.4338 | NRF Loss: 0.7976 | Joint: 1.2314 | Val Acc: 0.8217
# Epoch 550 | GCN Loss: 0.4219 | NRF Loss: 0.7850 | Joint: 1.2069 | Val Acc: 0.8233
# Epoch 600 | GCN Loss: 0.4112 | NRF Loss: 0.7717 | Joint: 1.1829 | Val Acc: 0.8300
# Epoch 650 | GCN Loss: 0.4023 | NRF Loss: 0.7656 | Joint: 1.1679 | Val Acc: 0.8283
# Epoch 700 | GCN Loss: 0.3946 | NRF Loss: 0.7491 | Joint: 1.1437 | Val Acc: 0.8233
# Epoch 750 | GCN Loss: 0.3873 | NRF Loss: 0.7459 | Joint: 1.1332 | Val Acc: 0.8250
# Epoch 800 | GCN Loss: 0.3807 | NRF Loss: 0.7339 | Joint: 1.1146 | Val Acc: 0.8250
# Epoch 850 | GCN Loss: 0.3751 | NRF Loss: 0.7312 | Joint: 1.1063 | Val Acc: 0.8200
# Epoch 900 | GCN Loss: 0.3699 | NRF Loss: 0.7285 | Joint: 1.0984 | Val Acc: 0.8200
# Epoch 950 | GCN Loss: 0.3654 | NRF Loss: 0.7219 | Joint: 1.0874 | Val Acc: 0.8183
# Early stopping at epoch 982
# Best validation acc: 0.8333 @ epoch 582
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 120, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3979 | NRF Loss: 3.4012 | Joint: 6.7991 | Val Acc: 0.2450
# Epoch 050 | GCN Loss: 1.2920 | NRF Loss: 2.4203 | Joint: 3.7123 | Val Acc: 0.6183
# Epoch 100 | GCN Loss: 0.8507 | NRF Loss: 1.6389 | Joint: 2.4896 | Val Acc: 0.7150
# Epoch 150 | GCN Loss: 0.6931 | NRF Loss: 1.2399 | Joint: 1.9330 | Val Acc: 0.7500
# Epoch 200 | GCN Loss: 0.6055 | NRF Loss: 1.0425 | Joint: 1.6480 | Val Acc: 0.7517
# Epoch 250 | GCN Loss: 0.5485 | NRF Loss: 0.9302 | Joint: 1.4787 | Val Acc: 0.7517
# Epoch 300 | GCN Loss: 0.5091 | NRF Loss: 0.8602 | Joint: 1.3692 | Val Acc: 0.7500
# Epoch 350 | GCN Loss: 0.4805 | NRF Loss: 0.8111 | Joint: 1.2916 | Val Acc: 0.7583
# Epoch 400 | GCN Loss: 0.4581 | NRF Loss: 0.7735 | Joint: 1.2316 | Val Acc: 0.7800
# Epoch 450 | GCN Loss: 0.4410 | NRF Loss: 0.7437 | Joint: 1.1846 | Val Acc: 0.8000
# Epoch 500 | GCN Loss: 0.4273 | NRF Loss: 0.7233 | Joint: 1.1505 | Val Acc: 0.8067
# Epoch 550 | GCN Loss: 0.4160 | NRF Loss: 0.7059 | Joint: 1.1219 | Val Acc: 0.8117
# Epoch 600 | GCN Loss: 0.4065 | NRF Loss: 0.6891 | Joint: 1.0956 | Val Acc: 0.8117
# Epoch 650 | GCN Loss: 0.3980 | NRF Loss: 0.6737 | Joint: 1.0717 | Val Acc: 0.8150
# Epoch 700 | GCN Loss: 0.3909 | NRF Loss: 0.6580 | Joint: 1.0489 | Val Acc: 0.8150
# Epoch 750 | GCN Loss: 0.3846 | NRF Loss: 0.6419 | Joint: 1.0266 | Val Acc: 0.8250
# Epoch 800 | GCN Loss: 0.3786 | NRF Loss: 0.6331 | Joint: 1.0117 | Val Acc: 0.8283
# Epoch 850 | GCN Loss: 0.3734 | NRF Loss: 0.6231 | Joint: 0.9966 | Val Acc: 0.8483
# Epoch 900 | GCN Loss: 0.3685 | NRF Loss: 0.6129 | Joint: 0.9814 | Val Acc: 0.8333
# Epoch 950 | GCN Loss: 0.3638 | NRF Loss: 0.6061 | Joint: 0.9699 | Val Acc: 0.8400
# Epoch 1000 | GCN Loss: 0.3595 | NRF Loss: 0.5978 | Joint: 0.9573 | Val Acc: 0.8467
# Epoch 1050 | GCN Loss: 0.3553 | NRF Loss: 0.5907 | Joint: 0.9460 | Val Acc: 0.8267
# Epoch 1100 | GCN Loss: 0.3509 | NRF Loss: 0.5827 | Joint: 0.9335 | Val Acc: 0.8517
# Epoch 1150 | GCN Loss: 0.3473 | NRF Loss: 0.5771 | Joint: 0.9244 | Val Acc: 0.8483
# Epoch 1200 | GCN Loss: 0.3434 | NRF Loss: 0.5685 | Joint: 0.9119 | Val Acc: 0.8450
# Epoch 1250 | GCN Loss: 0.3400 | NRF Loss: 0.5651 | Joint: 0.9051 | Val Acc: 0.8533
# Epoch 1300 | GCN Loss: 0.3371 | NRF Loss: 0.5554 | Joint: 0.8926 | Val Acc: 0.8583
# Epoch 1350 | GCN Loss: 0.3340 | NRF Loss: 0.5465 | Joint: 0.8805 | Val Acc: 0.8500
# Epoch 1400 | GCN Loss: 0.3312 | NRF Loss: 0.5411 | Joint: 0.8723 | Val Acc: 0.8600
# Epoch 1450 | GCN Loss: 0.3287 | NRF Loss: 0.5326 | Joint: 0.8614 | Val Acc: 0.8533
# Epoch 1500 | GCN Loss: 0.3261 | NRF Loss: 0.5289 | Joint: 0.8550 | Val Acc: 0.8550
# Epoch 1550 | GCN Loss: 0.3240 | NRF Loss: 0.5212 | Joint: 0.8452 | Val Acc: 0.8567
# Epoch 1600 | GCN Loss: 0.3215 | NRF Loss: 0.5163 | Joint: 0.8377 | Val Acc: 0.8550
# Epoch 1650 | GCN Loss: 0.3195 | NRF Loss: 0.5121 | Joint: 0.8317 | Val Acc: 0.8583
# Epoch 1700 | GCN Loss: 0.3179 | NRF Loss: 0.5098 | Joint: 0.8277 | Val Acc: 0.8567
# Epoch 1750 | GCN Loss: 0.3151 | NRF Loss: 0.5006 | Joint: 0.8157 | Val Acc: 0.8583
# Epoch 1800 | GCN Loss: 0.3131 | NRF Loss: 0.4982 | Joint: 0.8112 | Val Acc: 0.8550
# Epoch 1850 | GCN Loss: 0.3113 | NRF Loss: 0.4965 | Joint: 0.8077 | Val Acc: 0.8600
# Epoch 1900 | GCN Loss: 0.3095 | NRF Loss: 0.4933 | Joint: 0.8028 | Val Acc: 0.8567
# Epoch 1950 | GCN Loss: 0.3079 | NRF Loss: 0.4899 | Joint: 0.7978 | Val Acc: 0.8567
# Epoch 2000 | GCN Loss: 0.3063 | NRF Loss: 0.4843 | Joint: 0.7906 | Val Acc: 0.8483
# Early stopping at epoch 2038
# Best validation acc: 0.8667 @ epoch 1638
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4085 | NRF Loss: 3.4012 | Joint: 6.8097 | Val Acc: 0.2783
# Epoch 050 | GCN Loss: 1.5392 | NRF Loss: 2.4122 | Joint: 3.9514 | Val Acc: 0.6533
# Epoch 100 | GCN Loss: 1.0315 | NRF Loss: 1.5968 | Joint: 2.6282 | Val Acc: 0.7200
# Epoch 150 | GCN Loss: 0.8299 | NRF Loss: 1.1824 | Joint: 2.0122 | Val Acc: 0.7700
# Epoch 200 | GCN Loss: 0.7217 | NRF Loss: 0.9844 | Joint: 1.7060 | Val Acc: 0.7833
# Epoch 250 | GCN Loss: 0.6477 | NRF Loss: 0.8711 | Joint: 1.5188 | Val Acc: 0.7933
# Epoch 300 | GCN Loss: 0.5896 | NRF Loss: 0.7987 | Joint: 1.3883 | Val Acc: 0.7917
# Epoch 350 | GCN Loss: 0.5485 | NRF Loss: 0.7506 | Joint: 1.2991 | Val Acc: 0.8033
# Epoch 400 | GCN Loss: 0.5188 | NRF Loss: 0.7109 | Joint: 1.2297 | Val Acc: 0.8183
# Epoch 450 | GCN Loss: 0.4962 | NRF Loss: 0.6829 | Joint: 1.1791 | Val Acc: 0.8133
# Epoch 500 | GCN Loss: 0.4784 | NRF Loss: 0.6608 | Joint: 1.1392 | Val Acc: 0.8167
# Epoch 550 | GCN Loss: 0.4634 | NRF Loss: 0.6455 | Joint: 1.1089 | Val Acc: 0.8333
# Epoch 600 | GCN Loss: 0.4514 | NRF Loss: 0.6317 | Joint: 1.0830 | Val Acc: 0.8350
# Epoch 650 | GCN Loss: 0.4409 | NRF Loss: 0.6155 | Joint: 1.0564 | Val Acc: 0.8167
# Epoch 700 | GCN Loss: 0.4317 | NRF Loss: 0.6031 | Joint: 1.0348 | Val Acc: 0.8300
# Epoch 750 | GCN Loss: 0.4238 | NRF Loss: 0.5889 | Joint: 1.0128 | Val Acc: 0.8233
# Epoch 800 | GCN Loss: 0.4170 | NRF Loss: 0.5834 | Joint: 1.0004 | Val Acc: 0.8300
# Epoch 850 | GCN Loss: 0.4107 | NRF Loss: 0.5756 | Joint: 0.9863 | Val Acc: 0.8133
# Epoch 900 | GCN Loss: 0.4051 | NRF Loss: 0.5645 | Joint: 0.9696 | Val Acc: 0.8383
# Epoch 950 | GCN Loss: 0.3995 | NRF Loss: 0.5579 | Joint: 0.9574 | Val Acc: 0.8367
# Epoch 1000 | GCN Loss: 0.3945 | NRF Loss: 0.5452 | Joint: 0.9397 | Val Acc: 0.8383
# Epoch 1050 | GCN Loss: 0.3899 | NRF Loss: 0.5415 | Joint: 0.9314 | Val Acc: 0.8500
# Epoch 1100 | GCN Loss: 0.3858 | NRF Loss: 0.5372 | Joint: 0.9230 | Val Acc: 0.8467
# Epoch 1150 | GCN Loss: 0.3818 | NRF Loss: 0.5275 | Joint: 0.9093 | Val Acc: 0.8550
# Epoch 1200 | GCN Loss: 0.3783 | NRF Loss: 0.5218 | Joint: 0.9001 | Val Acc: 0.8550
# Epoch 1250 | GCN Loss: 0.3747 | NRF Loss: 0.5165 | Joint: 0.8912 | Val Acc: 0.8533
# Epoch 1300 | GCN Loss: 0.3716 | NRF Loss: 0.5101 | Joint: 0.8818 | Val Acc: 0.8650
# Epoch 1350 | GCN Loss: 0.3685 | NRF Loss: 0.5028 | Joint: 0.8713 | Val Acc: 0.8533
# Epoch 1400 | GCN Loss: 0.3657 | NRF Loss: 0.4979 | Joint: 0.8636 | Val Acc: 0.8617
# Epoch 1450 | GCN Loss: 0.3635 | NRF Loss: 0.4923 | Joint: 0.8558 | Val Acc: 0.8650
# Epoch 1500 | GCN Loss: 0.3602 | NRF Loss: 0.4896 | Joint: 0.8498 | Val Acc: 0.8667
# Epoch 1550 | GCN Loss: 0.3579 | NRF Loss: 0.4870 | Joint: 0.8449 | Val Acc: 0.8667
# Epoch 1600 | GCN Loss: 0.3555 | NRF Loss: 0.4805 | Joint: 0.8359 | Val Acc: 0.8667
# Epoch 1650 | GCN Loss: 0.3533 | NRF Loss: 0.4756 | Joint: 0.8290 | Val Acc: 0.8750
# Epoch 1700 | GCN Loss: 0.3513 | NRF Loss: 0.4693 | Joint: 0.8206 | Val Acc: 0.8767
# Epoch 1750 | GCN Loss: 0.3493 | NRF Loss: 0.4661 | Joint: 0.8154 | Val Acc: 0.8750
# Epoch 1800 | GCN Loss: 0.3474 | NRF Loss: 0.4601 | Joint: 0.8074 | Val Acc: 0.8767
# Epoch 1850 | GCN Loss: 0.3457 | NRF Loss: 0.4542 | Joint: 0.7999 | Val Acc: 0.8750
# Epoch 1900 | GCN Loss: 0.3438 | NRF Loss: 0.4523 | Joint: 0.7961 | Val Acc: 0.8767
# Epoch 1950 | GCN Loss: 0.3420 | NRF Loss: 0.4512 | Joint: 0.7932 | Val Acc: 0.8783
# Epoch 2000 | GCN Loss: 0.3403 | NRF Loss: 0.4457 | Joint: 0.7860 | Val Acc: 0.8700
# Epoch 2050 | GCN Loss: 0.3381 | NRF Loss: 0.4455 | Joint: 0.7837 | Val Acc: 0.8833
# Epoch 2100 | GCN Loss: 0.3366 | NRF Loss: 0.4370 | Joint: 0.7736 | Val Acc: 0.8733
# Early stopping at epoch 2129
# Best validation acc: 0.8833 @ epoch 1729
# Evaluating on test set using semi-transductive/inductive logic...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4010 | NRF Loss: 3.4012 | Joint: 6.8022 | Val Acc: 0.0467
# Epoch 050 | GCN Loss: 2.9902 | NRF Loss: 3.3762 | Joint: 6.3664 | Val Acc: 0.3233
# Epoch 100 | GCN Loss: 2.5692 | NRF Loss: 3.2719 | Joint: 5.8411 | Val Acc: 0.2050
# Epoch 150 | GCN Loss: 2.2425 | NRF Loss: 3.1294 | Joint: 5.3718 | Val Acc: 0.2467
# Epoch 200 | GCN Loss: 1.9976 | NRF Loss: 2.9864 | Joint: 4.9840 | Val Acc: 0.3250
# Epoch 250 | GCN Loss: 1.8003 | NRF Loss: 2.8446 | Joint: 4.6449 | Val Acc: 0.3983
# Epoch 300 | GCN Loss: 1.6366 | NRF Loss: 2.7077 | Joint: 4.3442 | Val Acc: 0.4467
# Epoch 350 | GCN Loss: 1.4996 | NRF Loss: 2.5829 | Joint: 4.0825 | Val Acc: 0.5800
# Epoch 400 | GCN Loss: 1.3846 | NRF Loss: 2.4696 | Joint: 3.8542 | Val Acc: 0.6133
# Epoch 450 | GCN Loss: 1.2872 | NRF Loss: 2.3638 | Joint: 3.6511 | Val Acc: 0.6417
# Epoch 500 | GCN Loss: 1.2045 | NRF Loss: 2.2710 | Joint: 3.4756 | Val Acc: 0.6250
# Epoch 550 | GCN Loss: 1.1346 | NRF Loss: 2.1846 | Joint: 3.3192 | Val Acc: 0.6367
# Epoch 600 | GCN Loss: 1.0755 | NRF Loss: 2.1108 | Joint: 3.1864 | Val Acc: 0.6333
# Epoch 650 | GCN Loss: 1.0252 | NRF Loss: 2.0431 | Joint: 3.0682 | Val Acc: 0.6417
# Epoch 700 | GCN Loss: 0.9820 | NRF Loss: 1.9773 | Joint: 2.9593 | Val Acc: 0.6400
# Epoch 750 | GCN Loss: 0.9446 | NRF Loss: 1.9238 | Joint: 2.8684 | Val Acc: 0.6450
# Epoch 800 | GCN Loss: 0.9118 | NRF Loss: 1.8719 | Joint: 2.7837 | Val Acc: 0.6500
# Epoch 850 | GCN Loss: 0.8829 | NRF Loss: 1.8241 | Joint: 2.7070 | Val Acc: 0.6600
# Epoch 900 | GCN Loss: 0.8572 | NRF Loss: 1.7838 | Joint: 2.6410 | Val Acc: 0.6633
# Epoch 950 | GCN Loss: 0.8340 | NRF Loss: 1.7389 | Joint: 2.5729 | Val Acc: 0.6717
# Epoch 1000 | GCN Loss: 0.8131 | NRF Loss: 1.7019 | Joint: 2.5150 | Val Acc: 0.6833
# Epoch 1050 | GCN Loss: 0.7939 | NRF Loss: 1.6669 | Joint: 2.4608 | Val Acc: 0.6917
# Epoch 1100 | GCN Loss: 0.7762 | NRF Loss: 1.6325 | Joint: 2.4087 | Val Acc: 0.6883
# Epoch 1150 | GCN Loss: 0.7598 | NRF Loss: 1.6019 | Joint: 2.3617 | Val Acc: 0.6917
# Epoch 1200 | GCN Loss: 0.7445 | NRF Loss: 1.5727 | Joint: 2.3172 | Val Acc: 0.6900
# Epoch 1250 | GCN Loss: 0.7302 | NRF Loss: 1.5427 | Joint: 2.2729 | Val Acc: 0.6967
# Epoch 1300 | GCN Loss: 0.7167 | NRF Loss: 1.5178 | Joint: 2.2345 | Val Acc: 0.6983
# Epoch 1350 | GCN Loss: 0.7039 | NRF Loss: 1.4911 | Joint: 2.1950 | Val Acc: 0.6950
# Epoch 1400 | GCN Loss: 0.6918 | NRF Loss: 1.4728 | Joint: 2.1645 | Val Acc: 0.7017
# Epoch 1450 | GCN Loss: 0.6802 | NRF Loss: 1.4500 | Joint: 2.1303 | Val Acc: 0.7000
# Epoch 1500 | GCN Loss: 0.6692 | NRF Loss: 1.4276 | Joint: 2.0968 | Val Acc: 0.6967
# Epoch 1550 | GCN Loss: 0.6585 | NRF Loss: 1.4084 | Joint: 2.0669 | Val Acc: 0.7017
# Epoch 1600 | GCN Loss: 0.6482 | NRF Loss: 1.3893 | Joint: 2.0375 | Val Acc: 0.7050
# Epoch 1650 | GCN Loss: 0.6380 | NRF Loss: 1.3745 | Joint: 2.0126 | Val Acc: 0.7133
# Epoch 1700 | GCN Loss: 0.6283 | NRF Loss: 1.3625 | Joint: 1.9908 | Val Acc: 0.7133
# Epoch 1750 | GCN Loss: 0.6190 | NRF Loss: 1.3453 | Joint: 1.9643 | Val Acc: 0.7167
# Epoch 1800 | GCN Loss: 0.6100 | NRF Loss: 1.3309 | Joint: 1.9409 | Val Acc: 0.7200
# Epoch 1850 | GCN Loss: 0.6014 | NRF Loss: 1.3145 | Joint: 1.9159 | Val Acc: 0.7167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 41
#      32 args = {
#      33     **dict(zip(param_names, combo)),
#      34     'partition': f"gtd{partition}",
#    (...)
#      37     'final_evaluation': True
#      38 }
#      40 print(f"Running config: {args}")
# ---> 41 acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
#      42     combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask,
#      43     args, row_to_node_index, index_to_label, verbose=True)
#      45 if acc > best_score:
#      46     best_score = acc
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0816LongLat/haversine_build_graph_and_train.py:280, in train_joint(df, full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_df, val_df, test_df, train_mask, val_mask, test_mask, args, row_to_node_index, index_to_label, verbose)
#     277 # NRF only sees TRAIN rows
#     278 input_features_train = torch.cat([non_geo_features[row_train_mask],
#     279                                   emb_per_row[row_train_mask]], dim=1)
# --> 280 out_forest_train = neural_forest(input_features_train)
#     282 # Losses
#     283 loss1 = F.cross_entropy(pred_nodes[train_mask], y_gcn[train_mask])   # node-level CE
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0816LongLat/ndf.py:241, in NeuralDecisionForest.forward(self, x)
#     239 out = self.feature_layer(x)
#     240 out = out.view(x.size()[0], -1)
# --> 241 out = self.forest(out)
#     242 return out
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0816LongLat/ndf.py:224, in Forest.forward(self, x)
#     222 probs = []
#     223 for tree in self.trees:
# --> 224     mu = tree(x)
#     225     p=tree.cal_prob(mu,tree.get_pi())
#     226     probs.append(p.unsqueeze(2))
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_noLeak0816LongLat/ndf.py:180, in Tree.forward(self, x)
#     178 end_idx = 2
#     179 for n_layer in range(0, self.depth):
# --> 180     _mu = _mu.view(batch_size,-1,1).repeat(1,1,2)
#     181     _decision = decision[:, begin_idx:end_idx, :]  # -> [batch_size,2**n_layer,2]
#     182     _mu = _mu*_decision # -> [batch_size,2**n_layer,2]
#
# KeyboardInterrupt:

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 80, 'tree_depth': 12, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.8866667151451111, 'epoch': 634, 'y_pred': ['Tehrik-i-Taliban Pakistan (TTP)', 'Palestinians', 'Palestinians', 'Palestinians', "New People's Army (NPA)", 'Taliban', 'National Liberation Army of Colombia (ELN)', 'Revolutionary Armed Forces of Colombia (FARC)', "New People's Army (NPA)", 'African National Congress (South Africa)', 'Palestinians', 'Nicaraguan Democratic Force (FDN)', 'Corsican National Liberation Front (FLNC)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Houthi extremists (Ansar Allah)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Boko Haram', 'Boko Haram', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Taliban', 'Shining Path (SL)', 'Sikh Extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Nicaraguan Democratic Force (FDN)', 'Boko Haram', 'Nicaraguan Democratic Force (FDN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'National Liberation Army of Colombia (ELN)', 'Abu Sayyaf Group (ASG)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Taliban', 'Irish Republican Army (IRA)', 'Abu Sayyaf Group (ASG)', "Donetsk People's Republic", 'Corsican National Liberation Front (FLNC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Boko Haram', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Irish Republican Army (IRA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Maoists', 'Irish Republican Army (IRA)', 'Taliban', 'Shining Path (SL)', "Kurdistan Workers' Party (PKK)", 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Islamic State of Iraq and the Levant (ISIL)', 'Maoists', 'Al-Qaida in Iraq', 'Houthi extremists (Ansar Allah)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Muslim extremists', 'Palestinians', 'Farabundo Marti National Liberation Front (FMLN)', "New People's Army (NPA)", 'Houthi extremists (Ansar Allah)', 'Irish Republican Army (IRA)', "New People's Army (NPA)", 'Maoists', 'Farabundo Marti National Liberation Front (FMLN)', 'Shining Path (SL)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Sikh Extremists', 'Basque Fatherland and Freedom (ETA)', 'Taliban', 'Irish Republican Army (IRA)', 'Farabundo Marti National Liberation Front (FMLN)', 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Al-Shabaab', "New People's Army (NPA)", 'Corsican National Liberation Front (FLNC)', 'Abu Sayyaf Group (ASG)', 'Muslim extremists', 'Taliban', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'Maoists', 'Basque Fatherland and Freedom (ETA)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Boko Haram', "Donetsk People's Republic", "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Corsican National Liberation Front (FLNC)', 'Irish Republican Army (IRA)' ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
