# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch

# %%
#partition = 100

# %%
#df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
"""from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])"""
# Out:
# "from sklearn.preprocessing import StandardScaler\n\n# Columns to exclude from scaling\nexclude_cols = ['gname']\n\n# Columns to scale\nscale_cols = [col for col in df.columns if col not in exclude_cols]\n\n# Scale only selected columns\nscaler = StandardScaler()\ndf[scale_cols] = scaler.fit_transform(df[scale_cols])"

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
y_preds, y_trues, logs = [], [], []


import itertools, random, os

param_grid = {
    'lr': [0.001],
    'n_tree': [40, 80, 100],
    'tree_depth': [8, 9, 10, 11, 12],
    'tree_feature_rate': [0.1, 0.3, 0.5],
    'feat_dropout': [0.0, 0.1, 0.2],
    'embed_dim': [16, 32, 64]
}

# Random sample from grid
keys = list(param_grid.keys())
all_combos = list(itertools.product(*param_grid.values()))
sample_size = min(50, len(all_combos))


partitions = [100, 200, 300, 478]
best_scores = []
best_runs = []
best_paramsets = []

for partition in partitions:

    sampled_combos = random.sample(all_combos, sample_size)
    sampled_dicts = [dict(zip(keys, combo)) for combo in sampled_combos]

    df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")
    label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}


    from sklearn.preprocessing import StandardScaler

    # Columns to exclude from scaling
    exclude_cols = ['gname']

    # Columns to scale
    scale_cols = [col for col in df.columns if col not in exclude_cols]

    # Scale only selected columns
    scaler = StandardScaler()
    df[scale_cols] = scaler.fit_transform(df[scale_cols])

    feature_cols = [c for c in df.columns if c != "gname"]
    non_geo_features = torch.tensor(
        df[feature_cols].astype(float).fillna(0).values,
        dtype=torch.float32
    )

    X, y_nrf, train_mask, val_mask, test_mask, index_to_label = build_nrf_data(df, label_index, feature_cols)

    # -------- Stage 1: Find best params (1500 epochs) --------
    best_score_stage1 = -1
    best_params = None

    for combo in sampled_dicts:
        args = {
            **combo,
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1500,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, _, *_ = train_joint(non_geo_features, y_nrf, train_mask, val_mask, test_mask, args, index_to_label)

        if acc > best_score_stage1:
            best_score_stage1 = acc
            best_params = combo

    # -------- Stage 2: Full run (3000 epochs) --------
    final_args = {
        **best_params,
        'partition': f"gtd{partition}",
        'n_class': len(label_index),
        'epochs': 3000,
        'final_evaluation': True
    }

    print(f"[Stage 2] Final run for partition {partition} with params: {final_args}")
    acc, epoch, precision, recall, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
        non_geo_features, y_nrf, train_mask, val_mask, test_mask, final_args, index_to_label
    )

    best_scores.append(acc)
    best_paramsets.append(best_params)
    best_runs.append({
        "args": final_args,
        "acc": acc,
        "epoch": epoch,
        "y_pred": y_pred_decoded,
        "y_true": y_true_decoded,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "micro": (p_micro, r_micro, f1_micro),
        "macro": (p_macro, r_macro, f1_macro),
        "auroc": (auc_w, auc_mi, auc_ma),
        "epoch_logs": epoch_logs
    })
# Out:
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.
# Epoch 350 | NDF Loss: 2.5050 | Val Acc: 0.3633
# Epoch 400 | NDF Loss: 2.4088 | Val Acc: 0.3667
# Epoch 450 | NDF Loss: 2.3189 | Val Acc: 0.3800
# Epoch 500 | NDF Loss: 2.2343 | Val Acc: 0.3817
# Epoch 550 | NDF Loss: 2.1546 | Val Acc: 0.3867
# Epoch 600 | NDF Loss: 2.0794 | Val Acc: 0.3867
# Epoch 650 | NDF Loss: 2.0090 | Val Acc: 0.3883
# Epoch 700 | NDF Loss: 1.9429 | Val Acc: 0.3900
# Epoch 750 | NDF Loss: 1.8807 | Val Acc: 0.3900
# Early stopping at epoch 766
# Best validation acc: 0.3950 @ epoch 666
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 16, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.4012 | Val Acc: 0.0733
# Epoch 050 | NDF Loss: 3.3082 | Val Acc: 0.1950
# Epoch 100 | NDF Loss: 3.1717 | Val Acc: 0.2467
# Epoch 150 | NDF Loss: 3.0480 | Val Acc: 0.2983
# Epoch 200 | NDF Loss: 2.9378 | Val Acc: 0.3183
# Epoch 250 | NDF Loss: 2.8370 | Val Acc: 0.3317
# Epoch 300 | NDF Loss: 2.7439 | Val Acc: 0.3333
# Epoch 350 | NDF Loss: 2.6566 | Val Acc: 0.3467
# Epoch 400 | NDF Loss: 2.5744 | Val Acc: 0.3533
# Epoch 450 | NDF Loss: 2.4965 | Val Acc: 0.3650
# Epoch 500 | NDF Loss: 2.4229 | Val Acc: 0.3800
# Epoch 550 | NDF Loss: 2.3528 | Val Acc: 0.3883
# Epoch 600 | NDF Loss: 2.2862 | Val Acc: 0.3917
# Epoch 650 | NDF Loss: 2.2234 | Val Acc: 0.3950
# Epoch 700 | NDF Loss: 2.1641 | Val Acc: 0.4000
# Epoch 750 | NDF Loss: 2.1079 | Val Acc: 0.4017
# Early stopping at epoch 787
# Best validation acc: 0.4017 @ epoch 687
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 16, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.4010 | Val Acc: 0.1217
# Epoch 050 | NDF Loss: 3.2200 | Val Acc: 0.2433
# Epoch 100 | NDF Loss: 3.0795 | Val Acc: 0.3000
# Epoch 150 | NDF Loss: 2.9682 | Val Acc: 0.3217
# Epoch 200 | NDF Loss: 2.8693 | Val Acc: 0.3600
# Epoch 250 | NDF Loss: 2.7782 | Val Acc: 0.3800
# Epoch 300 | NDF Loss: 2.6931 | Val Acc: 0.3817
# Epoch 350 | NDF Loss: 2.6126 | Val Acc: 0.3983
# Epoch 400 | NDF Loss: 2.5369 | Val Acc: 0.3983
# Epoch 450 | NDF Loss: 2.4652 | Val Acc: 0.3967
# Epoch 500 | NDF Loss: 2.3968 | Val Acc: 0.3983
# Early stopping at epoch 502
# Best validation acc: 0.4000 @ epoch 402
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.4012 | Val Acc: 0.
# Epoch 500 | NDF Loss: 2.4646 | Val Acc: 0.4592
# Epoch 550 | NDF Loss: 2.4034 | Val Acc: 0.4692
# Epoch 600 | NDF Loss: 2.3451 | Val Acc: 0.4733
# Epoch 650 | NDF Loss: 2.2898 | Val Acc: 0.4767
# Epoch 700 | NDF Loss: 2.2371 | Val Acc: 0.4817
# Epoch 750 | NDF Loss: 2.1870 | Val Acc: 0.4875
# Epoch 800 | NDF Loss: 2.1393 | Val Acc: 0.4867
# Epoch 850 | NDF Loss: 2.0940 | Val Acc: 0.4900
# Early stopping at epoch 878
# Best validation acc: 0.4900 @ epoch 778
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 12, 'tree_feature_rate': 0.5, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd200', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.4012 | Val Acc: 0.1958
# Epoch 050 | NDF Loss: 3.1538 | Val Acc: 0.3108
# Epoch 100 | NDF Loss: 3.0062 | Val Acc: 0.3733
# Epoch 150 | NDF Loss: 2.8873 | Val Acc: 0.4058
# Epoch 200 | NDF Loss: 2.7808 | Val Acc: 0.4242
# Epoch 250 | NDF Loss: 2.6818 | Val Acc: 0.4417
# Epoch 300 | NDF Loss: 2.5892 | Val Acc: 0.4483
# Epoch 350 | NDF Loss: 2.5019 | Val Acc: 0.4567
# Epoch 400 | NDF Loss: 2.4197 | Val Acc: 0.4633
# Epoch 450 | NDF Loss: 2.3420 | Val Acc: 0.4692
# Epoch 500 | NDF Loss: 2.2685 | Val Acc: 0.4725
# Epoch 550 | NDF Loss: 2.1996 | Val Acc: 0.4775
# Epoch 600 | NDF Loss: 2.1342 | Val Acc: 0.4783
# Epoch 650 | NDF Loss: 2.0723 | Val Acc: 0.4842
# Epoch 700 | NDF Loss: 2.0137 | Val Acc: 0.4867
# Epoch 750 | NDF Loss: 1.9583 | Val Acc: 0.4933
# Epoch 800 | NDF Loss: 1.9060 | Val Acc: 0.4950
# Epoch 850 | NDF Loss: 1.8565 | Val Acc: 0.4942
# Epoch 900 | NDF Loss: 1.8091 | Val Acc: 0.4967
# Epoch 950 | NDF Loss: 1.7640 | Val Acc: 0.4958
# Early stopping at epoch 972
# Best validation acc: 0.4967 @ epoch 872
# [Stage 2] Final run for partition 200 with params: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 64, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | NDF Loss: 3.4012 | Val Acc: 0.1158
# Epoch 050 | NDF Loss: 3.3006 | Val Acc: 0.1975
# Epoch 100 | NDF Loss: 3.1570 | Val Acc: 0.2583
# Epoch 150 | NDF Loss: 3.0299 | Val Acc: 0.3308
# Epoch 200 | NDF Loss: 2.9175 | Val Acc: 0.3658
# Epoch 250 | NDF Loss: 2.8148 | Val Acc: 0.3933
# Epoch 300 | NDF Loss: 2.7189 | Val Acc: 0.4108
# Epoch 350 | NDF Loss: 2.6288 | Val Acc: 0.4308
# Epoch 400 | NDF Loss: 2.5435 | Val Acc: 0.4450
# Epoch 450 | NDF Loss: 2.4630 | Val Acc: 0.4450
# Epoch 500 | NDF Loss: 2.3869 | Val Acc: 0.4533
# Epoch 550 | NDF Loss: 2.3150 | Val Acc: 0.4583
# Epoch 600 | NDF Loss: 2.2470 | Val Acc: 0.4617
# Epoch 400 | NDF Loss: 2.5062 | Val Acc: 0.4544
# Epoch 450 | NDF Loss: 2.4224 | Val Acc: 0.4722
# Epoch 500 | NDF Loss: 2.3434 | Val Acc: 0.4822
# Epoch 550 | NDF Loss: 2.2691 | Val Acc: 0.4900
# Epoch 600 | NDF Loss: 2.1992 | Val Acc: 0.4933
# Epoch 650 | NDF Loss: 2.1334 | Val Acc: 0.4967
# Epoch 700 | NDF Loss: 2.0716 | Val Acc: 0.5061
# Epoch 750 | NDF Loss: 2.0138 | Val Acc: 0.5106
# Epoch 800 | NDF Loss: 1.9595 | Val Acc: 0.5183
# Epoch 850 | NDF Loss: 1.9080 | Val Acc: 0.5233
# Epoch 900 | NDF Loss: 1.8595 | Val Acc: 0.5256
# Epoch 950 | NDF Loss: 1.8137 | Val Acc: 0.5272
# Epoch 1000 | NDF Loss: 1.7704 | Val Acc: 0.5272
# Epoch 1050 | NDF Loss: 1.7298 | Val Acc: 0.5267
# Early stopping at epoch 1092
# Best validation acc: 0.5289 @ epoch 992
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | NDF Loss: 3.4013 | Val Acc: 0.1967
# Epoch 050 | NDF Loss: 3.1916 | Val Acc: 0.3056
# Epoch 100 | NDF Loss: 3.0718 | Val Acc: 0.3728
# Epoch 150 | NDF Loss: 2.9722 | Val Acc: 0.4128
# Epoch 200 | NDF Loss: 2.8816 | Val Acc: 0.4428
# Epoch 250 | NDF Loss: 2.7971 | Val Acc: 0.4650
# Epoch 300 | NDF Loss: 2.7177 | Val Acc: 0.4778
# Epoch 350 | NDF Loss: 2.6424 | Val Acc: 0.4889
# Epoch 400 | NDF Loss: 2.5709 | Val Acc: 0.5028
# Epoch 450 | NDF Loss: 2.5031 | Val Acc: 0.5117
# Epoch 500 | NDF Loss: 2.4387 | Val Acc: 0.5189
# Epoch 550 | NDF Loss: 2.3780 | Val Acc: 0.5294
# Epoch 600 | NDF Loss: 2.3206 | Val Acc: 0.5317
# Epoch 650 | NDF Loss: 2.2659 | Val Acc: 0.5356
# Epoch 700 | NDF Loss: 2.2140 | Val Acc: 0.5372
# Epoch 750 | NDF Loss: 2.1647 | Val Acc: 0.5372
# Epoch 800 | NDF Loss: 2.1176 | Val Acc: 0.5394
# Epoch 850 | NDF Loss: 2.0728 | Val Acc: 0.5367
# Epoch 900 | NDF Loss: 2.0302 | Val Acc: 0.5389
# Epoch 950 | NDF Loss: 1.9899 | Val Acc: 0.5400
# Epoch 1000 | NDF Loss: 1.9512 | Val Acc: 0.5383
# Early stopping at epoch 1006
# Best validation acc: 0.5411 @ epoch 906
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 12, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 69
#      60 args = {
#      61     **combo,
#      62     'partition': f"gtd{partition}",
#    (...)
#      65     'final_evaluation': False
#      66 }
#      68 print(f"Running config: {args}")
# ---> 69 acc, _, *_ = train_joint(non_geo_features, y_nrf, train_mask, val_mask, test_mask, args, index_to_label)
#      71 if acc > best_score_stage1:
#      72     best_score_stage1 = acc
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/DNDF_anonLocGRFi/haversine_build_graph_and_train.py:116, in train_joint(non_geo_features, y_nrf, train_mask, val_mask, test_mask, args, index_to_label, verbose)
#     114 ndf.train()
#     115 optimizer.zero_grad()
# --> 116 out = ndf(X)                                # probs (N, C)
#     117 loss = ndf.loss(out[tr], y[tr])             # NLLLoss(log(probs)) inside
#     118 loss.backward()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/DNDF_anonLocGRFi/ndf.py:233, in NeuralDecisionForest.forward(self, x)
#     231 out = self.feature_layer(x)
#     232 out = out.view(x.size()[0], -1)
# --> 233 out = self.forest(out)
#     234 return out
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/DNDF_anonLocGRFi/ndf.py:216, in Forest.forward(self, x)
#     214 probs = []
#     215 for tree in self.trees:
# --> 216     mu = tree(x)
#     217     p=tree.cal_prob(mu,tree.get_pi())
#     218     probs.append(p.unsqueeze(2))
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/DNDF_anonLocGRFi/ndf.py:163, in Tree.forward(self, x)
#     161 decision = torch.unsqueeze(decision,dim=2)
#     162 decision_comp = 1-decision
# --> 163 decision = torch.cat((decision,decision_comp),dim=2) # -> [batch_size,n_leaf,2]
#     165 # compute route probability
#     166 # note: we do not use decision[:,0]
#     167 batch_size = x.size()[0]
#
# RuntimeError: NVML_SUCCESS == r INTERNAL ASSERT FAILED at "../c10/cuda/CUDACachingAllocator.cpp":844, please report a bug to PyTorch.

# %%
#gtd100
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
#Best validation acc: 0.4300 @ epoch 686


#gtd200
#Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 9, 'tree_feature_rate': 0.5, 'feat_dropout': 0.2, 'embed_dim': 64, 'partition': 'gtd300', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
#Best validation acc: 0.5411 @ epoch 906

# %%
# Save best results
for i, p in enumerate(partitions):
    args = best_runs[i]["args"]
    os.makedirs(f"Results{p}", exist_ok=True)

    results_path = f"Results{p}/Results_{p}_prediction"
    with open(results_path, "w") as f:
        f.write(f"Best acc: {best_runs[i]['acc']:.4f} at epoch {best_runs[i]['epoch']} for {p} prediction\n")
        f.write(f"Config: {args}\n")
        f.write(f"Weighted Precision: {best_runs[i]['precision']:.4f}, Recall: {best_runs[i]['recall']:.4f}, F1: {best_runs[i]['f1']:.4f}\n")
        f.write(f"Macro Precision: {best_runs[i]['macro'][0]:.4f}, Recall: {best_runs[i]['macro'][1]:.4f}, F1: {best_runs[i]['macro'][2]:.4f}\n")
        f.write(f"Micro Precision: {best_runs[i]['micro'][0]:.4f}, Recall: {best_runs[i]['micro'][1]:.4f}, F1: {best_runs[i]['micro'][2]:.4f}\n")
        f.write(f"AUROC Weighted: {best_runs[i]['auroc'][0]:.4f}, Micro: {best_runs[i]['auroc'][1]:.4f}, Macro: {best_runs[i]['auroc'][2]:.4f}\n")

    log_path = f"Results{p}/epoch_logs_{p}_prediction"
    with open(log_path, "w") as f:
        f.write('\n'.join(f"{x:.4f}" for x in best_runs[i]['epoch_logs']))

    y_preds.append(best_runs[i]['y_pred'])
    y_trues.append(best_runs[i]['y_true'])

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""

# %%
best_acc

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
