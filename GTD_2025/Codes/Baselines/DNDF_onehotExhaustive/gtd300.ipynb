# %%
partition = 300

# %%
import sys
from train import main
from itertools import product  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import re

def load_tested_configs(log_path):
    tested = set()
    with open(log_path, 'r') as f:
        for line in f:
            if line.startswith("Running:"):
                match = re.findall(r"[-\w.]+=\S+", line)
                if match:
                    # Normalize values to correct types
                    config = tuple([
                        int(re.search(r"=(\d+)", match[0]).group(1)),       # n_tree
                        int(re.search(r"=(\d+)", match[1]).group(1)),       # t_depth
                        int(re.search(r"=(\d+)", match[2]).group(1)),       # hd
                        int(re.search(r"=(\d+)", match[3]).group(1)),       # batch_size
                        float(re.search(r"=(\d+\.?\d*)", match[4]).group(1)), # feature_rate
                        float(re.search(r"=(\d+\.?\d*)", match[5]).group(1)), # dropout
                        float(re.search(r"=(\d+\.?\d*)", match[6]).group(1)), # lr
                    ])
                    tested.add(config)
    return tested

# %%
import random
from itertools import product
import sys
#{'n_tree': 20, 'tree_depth': 10, 'batch_size': 256, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'lr': 0.01}

log_path = "logs300.txt"  # path to your saved printout
tested_configs = load_tested_configs(log_path)

n_tree_values = [5, 10, 20, 50, 100]
tree_depth_values = [13, 14]
hidden_dim = [1024, 768]
batch_size_values = [256, 512]
tree_feature_rates = [0.1, 0.2, 0.3, 0.4]
feat_dropouts = [0.0, 0.1]
lrs = [0.01]

n_iter = 50
best_score = 0
best_config = {}


param_space = list(product(
    n_tree_values,
    tree_depth_values,
    hidden_dim,
    batch_size_values,
    tree_feature_rates,
    feat_dropouts,
    lrs
))

available_configs = [cfg for cfg in param_space if cfg not in tested_configs]
sampled_configs = random.sample(available_configs, min(n_iter, len(available_configs)))

best_acc = 0

sampled_configs = random.sample(param_space, min(n_iter, len(param_space)))
i = 1
for n_tree, t_depth, hd, batch_size, feature_rate, dropout, lr in sampled_configs:
    print(f"\nRunning: n_tree={n_tree}, t_depth={t_depth}, hd={hd}, batch_size={batch_size}, feature_rate={feature_rate}, dropout={dropout}, lr={lr}")
    sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', str(n_tree),
        '-tree_depth', str(t_depth),
        '-batch_size', str(batch_size),
        '-hidden_dim', str(hd),
        '-tree_feature_rate', str(feature_rate),
        '-feat_dropout', str(dropout),
        '-lr', str(lr),
        '-epochs', '400',
        '-verbose', '0',
        '-jointly_training',
        '-searching', '1'
    ]

    print(f"{i} / 100")
    acc = main()
    #print(acc)
    i =i + 1

    if acc > best_acc:
        best_acc = acc
        best_config = {
            'n_tree': n_tree,
            'tree_depth': t_depth,
            'batch_size': batch_size,
            'hidden_dim': hd,
            'tree_feature_rate': feature_rate,
            'feat_dropout': dropout,
            'lr': lr
        }

print("\nBest hyperparameter configuration:")
print(best_acc)
print(f"Best accuracy: {best_acc}")
# Out:
# Running: n_tree=5, t_depth=13, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 1 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  75%|███████▌  | 301/400 [01:40<00:33,  3.00it/s]
# Early stopping at epoch 302
#
# Best Accuracy: 0.593651
#
# Running: n_tree=20, t_depth=13, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 2 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  38%|███▊      | 151/400 [02:19<03:50,  1.08it/s]
# Early stopping at epoch 152
#
# Best Accuracy: 0.593651
#
# Running: n_tree=5, t_depth=13, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 3 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  47%|████▋     | 187/400 [00:59<01:07,  3.17it/s]
# Early stopping at epoch 188
#
# Best Accuracy: 0.593651
#
# Running: n_tree=20, t_depth=14, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 4 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [01:57<04:43,  1.00s/it]
# Early stopping at epoch 118
# Best Accuracy: 0.588889
#
# Running: n_tree=50, t_depth=13, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 5 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  42%|████▏     | 167/400 [03:55<05:28,  1.41s/it]
# Early stopping at epoch 168
#
# Best Accuracy: 0.584127
#
# Running: n_tree=10, t_depth=13, hd=768, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 6 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  54%|█████▍    | 217/400 [02:00<01:41,  1.80it/s]
# Early stopping at epoch 218
#
# Best Accuracy: 0.594444
#
# Running: n_tree=5, t_depth=13, hd=768, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 7 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  34%|███▍      | 136/400 [00:54<01:45,  2.49it/s]
# Early stopping at epoch 137
#
# Best Accuracy: 0.575397
#
# Running: n_tree=10, t_depth=13, hd=768, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 8 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  56%|█████▋    | 226/400 [01:29<01:09,  2.52it/s]
# Early stopping at epoch 227
#
# Best Accuracy: 0.606349
#
# Running: n_tree=100, t_depth=14, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 9 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  66%|██████▋   | 265/400 [24:21<12:24,  5.51s/it]
# Early stopping at epoch 266
# Best Accuracy: 0.588095
#
# Running: n_tree=50, t_depth=14, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 10 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  45%|████▌     | 180/400 [08:50<10:48,  2.95s/it]
# Early stopping at epoch 181
# Best Accuracy: 0.571429
#
# Running: n_tree=5, t_depth=14, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 11 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  34%|███▎      | 134/400 [00:39<01:18,  3.40it/s]
# Early stopping at epoch 135
#
# Best Accuracy: 0.598413
#
# Running: n_tree=5, t_depth=14, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 12 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  54%|█████▍    | 216/400 [01:09<00:58,  3.13it/s]
# Early stopping at epoch 217
#
# Best Accuracy: 0.596032
#
# Running: n_tree=50, t_depth=14, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 13 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  32%|███▎      | 130/400 [05:36<11:39,  2.59s/it]
# Early stopping at epoch 131
# Best Accuracy: 0.581746
#
# Running: n_tree=100, t_depth=14, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 14 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  34%|███▍      | 136/400 [09:52<19:11,  4.36s/it]
# Early stopping at epoch 137
# Best Accuracy: 0.587302
#
# Running: n_tree=50, t_depth=13, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 15 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  40%|████      | 161/400 [03:59<05:54,  1.49s/it]
# Early stopping at epoch 162
# Best Accuracy: 0.584127
#
# Running: n_tree=50, t_depth=14, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 16 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  77%|███████▋  | 309/400 [12:02<03:32,  2.34s/it]
# Early stopping at epoch 310
# Best Accuracy: 0.580952
#
# Running: n_tree=50, t_depth=13, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 17 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [02:43<06:55,  1.45s/it]
# Early stopping at epoch 114
# Best Accuracy: 0.581746
#
# Running: n_tree=100, t_depth=13, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 18 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  50%|█████     | 200/400 [09:55<09:55,  2.98s/it]
# Early stopping at epoch 201
# Best Accuracy: 0.581746
#
# Running: n_tree=10, t_depth=14, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 19 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  57%|█████▋    | 228/400 [02:30<01:53,  1.52it/s]
# Early stopping at epoch 229
#
# Best Accuracy: 0.589683
#
# Running: n_tree=20, t_depth=13, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 20 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  36%|███▌      | 143/400 [01:28<02:39,  1.61it/s]
# Early stopping at epoch 144
#
# Best Accuracy: 0.581746
#
# Running: n_tree=50, t_depth=14, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 21 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  46%|████▋     | 186/400 [08:11<09:25,  2.64s/it]
# Early stopping at epoch 187
#
# Best Accuracy: 0.590476
#
# Running: n_tree=10, t_depth=13, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 22 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  56%|█████▋    | 225/400 [01:56<01:30,  1.93it/s]
# Early stopping at epoch 226
#
# Best Accuracy: 0.583333
#
# Running: n_tree=100, t_depth=14, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 23 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  30%|███       | 121/400 [12:12<28:10,  6.06s/it]
# Early stopping at epoch 122
# Best Accuracy: 0.571429
#
# Running: n_tree=10, t_depth=13, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 24 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  26%|██▋       | 105/400 [00:37<01:46,  2.78it/s]
# Early stopping at epoch 106
#
# Best Accuracy: 0.581746
#
# Running: n_tree=20, t_depth=13, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 25 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  32%|███▏      | 127/400 [01:49<03:55,  1.16it/s]
# Early stopping at epoch 128
#
# Best Accuracy: 0.576984
#
# Running: n_tree=100, t_depth=13, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 26 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  34%|███▍      | 136/400 [06:03<11:46,  2.67s/it]
# Early stopping at epoch 137
#
# Best Accuracy: 0.588095
# Running: n_tree=10, t_depth=14, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 27 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  73%|███████▎  | 293/400 [03:03<01:07,  1.60it/s]
# Early stopping at epoch 294
#
# Best Accuracy: 0.608730
#
# Running: n_tree=20, t_depth=14, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 28 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  64%|██████▍   | 255/400 [05:14<02:58,  1.23s/it]
# Early stopping at epoch 256
# Best Accuracy: 0.585714
#
# Running: n_tree=5, t_depth=14, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 29 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  42%|████▎     | 170/400 [00:50<01:08,  3.35it/s]
# Early stopping at epoch 171
#
# Best Accuracy: 0.573016
#
# Running: n_tree=5, t_depth=14, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 30 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  31%|███       | 124/400 [00:38<01:24,  3.25it/s]
# Early stopping at epoch 125
#
# Best Accuracy: 0.586508
#
# Running: n_tree=10, t_depth=14, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 31 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  37%|███▋      | 148/400 [01:20<02:16,  1.84it/s]
# Early stopping at epoch 149
#
# Best Accuracy: 0.594444
#
# Running: n_tree=50, t_depth=14, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 32 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  41%|████      | 163/400 [06:21<09:14,  2.34s/it]
# Early stopping at epoch 164
# Best Accuracy: 0.587302
#
# Running: n_tree=5, t_depth=14, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 33 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  82%|████████▎ | 330/400 [02:04<00:26,  2.64it/s]
# Early stopping at epoch 331
#
# Best Accuracy: 0.599206
#
# Running: n_tree=5, t_depth=14, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 34 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  41%|████      | 163/400 [00:52<01:16,  3.12it/s]
# Early stopping at epoch 164
#
# Best Accuracy: 0.573810
#
# Running: n_tree=10, t_depth=14, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 35 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  35%|███▌      | 141/400 [01:15<02:19,  1.86it/s]
# Early stopping at epoch 142
#
# Best Accuracy: 0.591270
#
# Running: n_tree=10, t_depth=14, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 36 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  35%|███▌      | 141/400 [01:28<02:43,  1.59it/s]
# Early stopping at epoch 142
#
# Best Accuracy: 0.589683
#
# Running: n_tree=50, t_depth=14, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 37 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  42%|████▏     | 167/400 [07:46<10:50,  2.79s/it]
# Early stopping at epoch 168
# Best Accuracy: 0.590476
#
# Running: n_tree=10, t_depth=13, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 38 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  41%|████▏     | 165/400 [01:27<02:05,  1.88it/s]
# Early stopping at epoch 166
#
# Best Accuracy: 0.590476
#
# Running: n_tree=20, t_depth=14, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 39 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  56%|█████▌    | 224/400 [03:27<02:42,  1.08it/s]
# Early stopping at epoch 225
#
# Best Accuracy: 0.596825
#
# Running: n_tree=100, t_depth=13, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 40 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  39%|███▉      | 157/400 [07:22<11:25,  2.82s/it]
# Early stopping at epoch 158
# Best Accuracy: 0.573016
#
# Running: n_tree=10, t_depth=13, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 41 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  57%|█████▋    | 228/400 [01:59<01:29,  1.91it/s]
# Early stopping at epoch 229
#
# Best Accuracy: 0.608730
#
# Running: n_tree=100, t_depth=13, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 42 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  57%|█████▋    | 227/400 [10:00<07:37,  2.65s/it]
# Early stopping at epoch 228
#
# Best Accuracy: 0.584127
#
# Running: n_tree=5, t_depth=14, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 43 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  47%|████▋     | 189/400 [01:02<01:09,  3.05it/s]
# Early stopping at epoch 190
#
# Best Accuracy: 0.592857
#
# Running: n_tree=10, t_depth=14, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 44 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  79%|███████▉  | 317/400 [02:51<00:44,  1.85it/s]
# Early stopping at epoch 318
#
# Best Accuracy: 0.582540
#
# Running: n_tree=10, t_depth=13, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 45 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  38%|███▊      | 151/400 [01:00<01:39,  2.50it/s]
# Early stopping at epoch 152
#
# Best Accuracy: 0.600000
#
# Running: n_tree=100, t_depth=14, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 46 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  33%|███▎      | 131/400 [10:23<21:19,  4.76s/it]
# Early stopping at epoch 132
# Best Accuracy: 0.580952
#
# Running: n_tree=100, t_depth=13, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 47 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  62%|██████▏   | 246/400 [14:08<08:51,  3.45s/it]
# Early stopping at epoch 247
# Best Accuracy: 0.586508
#
# Running: n_tree=20, t_depth=13, hd=768, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 48 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  42%|████▏     | 169/400 [02:24<03:17,  1.17it/s]
# Early stopping at epoch 170
#
# Best Accuracy: 0.595238
#
# Running: n_tree=10, t_depth=14, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 49 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  42%|████▏     | 167/400 [01:48<02:31,  1.54it/s]
# Early stopping at epoch 168
#
# Best Accuracy: 0.594444
#
# Running: n_tree=100, t_depth=14, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 50 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  31%|███▏      | 125/400 [09:14<20:20,  4.44s/it]
# Early stopping at epoch 126
# Best Accuracy: 0.580952
#
# Best hyperparameter configuration:
# 0.6087301587301587
# Best accuracy: 0.6087301587301587

# %%
""" 07-07

========== Final Test Evaluation ==========
Model Parameters:
  Dataset: gtd300
  Hidden Dim: 1024
  n_tree: 20, tree_depth: 10, tree_feature_rate: 0.4
  Batch size: 256, Dropout: 0.1, LR: 0.01

Best Accuracy: 0.5870
Weighted Precision: 0.7085, Recall: 0.5870, F1 Score: 0.6189, ROCAUC: 0.9274
Macro Precision: 0.7085, Recall: 0.5870, F1 Score: 0.6189, ROCAUC: 0.9274
Micro Precision: 0.5870, Recall: 0.5870, F1 Score: 0.5870, ROCAUC: 0.9301
"""

#Running: n_tree=10, t_depth=12, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# Out:
# ' 07-07\n\n========== Final Test Evaluation ==========\nModel Parameters:\n  Dataset: gtd300\n  Hidden Dim: 1024\n  n_tree: 20, tree_depth: 10, tree_feature_rate: 0.4\n  Batch size: 256, Dropout: 0.1, LR: 0.01\n\nBest Accuracy: 0.5870\nWeighted Precision: 0.7085, Recall: 0.5870, F1 Score: 0.6189, ROCAUC: 0.9274\nMacro Precision: 0.7085, Recall: 0.5870, F1 Score: 0.6189, ROCAUC: 0.9274\nMicro Precision: 0.5870, Recall: 0.5870, F1 Score: 0.5870, ROCAUC: 0.9301\n'

# %%
"""sys.argv = [
    'train.py',
    '-dataset', f'gtd{partition}',
    '-n_class', '30',
    '-gpuid', '0',
    '-n_tree', str(best_config['n_tree']),
    '-tree_depth', str(best_config['tree_depth']),
    '-batch_size', str(best_config['batch_size']),
    '-epochs', '1000',
    '-verbose', '1',
    '-jointly_training'
]"""

sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', '20',
        '-tree_depth', '10',
        '-batch_size', '256',
        '-epochs', '1500',
        '-hidden_dim', '1024',
        '-verbose', '0',
        '-tree_feature_rate', '0.4',
        '-feat_dropout', '0.1',
        '-lr', '0.01',
        '-jointly_training'
    ]

best_model, preds, targets, labels, epoch_logs = main()
# Out:
# Use gtd300 dataset
# Patience: 500
# Training Epochs:   3%|▎         | 50/1500 [00:43<20:43,  1.17it/s]
# [Epoch 50] Train Loss: 0.2116, Eval Loss: 1.6392, Eval Accuracy: 0.5730
# Training Epochs:   7%|▋         | 100/1500 [01:27<20:04,  1.16it/s]
# [Epoch 100] Train Loss: 0.1538, Eval Loss: 1.6437, Eval Accuracy: 0.5659
# Training Epochs:  10%|█         | 150/1500 [02:10<19:16,  1.17it/s]
# [Epoch 150] Train Loss: 0.1267, Eval Loss: 1.7839, Eval Accuracy: 0.5667
# Training Epochs:  13%|█▎        | 200/1500 [02:53<18:49,  1.15it/s]
# [Epoch 200] Train Loss: 0.1140, Eval Loss: 1.8174, Eval Accuracy: 0.5762
# Training Epochs:  17%|█▋        | 250/1500 [03:37<18:16,  1.14it/s]
# [Epoch 250] Train Loss: 0.1017, Eval Loss: 1.7366, Eval Accuracy: 0.5675
# Training Epochs:  20%|██        | 300/1500 [04:20<16:59,  1.18it/s]
# [Epoch 300] Train Loss: 0.0915, Eval Loss: 1.8065, Eval Accuracy: 0.5690
# Training Epochs:  23%|██▎       | 350/1500 [05:03<16:34,  1.16it/s]
# [Epoch 350] Train Loss: 0.0865, Eval Loss: 1.8067, Eval Accuracy: 0.5730
# Training Epochs:  27%|██▋       | 400/1500 [05:49<15:54,  1.15it/s]
# [Epoch 400] Train Loss: 0.0772, Eval Loss: 1.9057, Eval Accuracy: 0.5619
# Training Epochs:  30%|███       | 450/1500 [06:32<16:30,  1.06it/s]
# [Epoch 450] Train Loss: 0.0708, Eval Loss: 2.0088, Eval Accuracy: 0.5754
# Training Epochs:  33%|███▎      | 500/1500 [07:15<14:13,  1.17it/s]
# [Epoch 500] Train Loss: 0.0684, Eval Loss: 1.8883, Eval Accuracy: 0.5810
# Training Epochs:  37%|███▋      | 550/1500 [07:57<13:25,  1.18it/s]
# [Epoch 550] Train Loss: 0.0650, Eval Loss: 1.8803, Eval Accuracy: 0.5817
# Training Epochs:  40%|████      | 600/1500 [08:40<12:36,  1.19it/s]
# [Epoch 600] Train Loss: 0.0631, Eval Loss: 1.9920, Eval Accuracy: 0.5619
# Training Epochs:  43%|████▎     | 650/1500 [09:22<11:49,  1.20it/s]
# [Epoch 650] Train Loss: 0.0605, Eval Loss: 2.0303, Eval Accuracy: 0.5603
# Training Epochs:  47%|████▋     | 700/1500 [10:04<11:06,  1.20it/s]
# [Epoch 700] Train Loss: 0.0613, Eval Loss: 1.9449, Eval Accuracy: 0.5651
# Training Epochs:  50%|█████     | 750/1500 [10:47<10:33,  1.18it/s]
# [Epoch 750] Train Loss: 0.0589, Eval Loss: 2.0700, Eval Accuracy: 0.5762
# Training Epochs:  53%|█████▎    | 800/1500 [11:29<09:52,  1.18it/s]
# [Epoch 800] Train Loss: 0.0582, Eval Loss: 2.1273, Eval Accuracy: 0.5754
# Training Epochs:  57%|█████▋    | 850/1500 [12:13<09:36,  1.13it/s]
# [Epoch 850] Train Loss: 0.0556, Eval Loss: 2.0998, Eval Accuracy: 0.5770
# Training Epochs:  60%|██████    | 900/1500 [12:55<08:35,  1.16it/s]
# [Epoch 900] Train Loss: 0.0529, Eval Loss: 2.1165, Eval Accuracy: 0.5643
# Training Epochs:  63%|██████▎   | 950/1500 [13:38<07:48,  1.17it/s]
# [Epoch 950] Train Loss: 0.0525, Eval Loss: 2.0004, Eval Accuracy: 0.5651
# Training Epochs:  67%|██████▋   | 1000/1500 [14:20<06:55,  1.20it/s]
# [Epoch 1000] Train Loss: 0.0527, Eval Loss: 2.2107, Eval Accuracy: 0.5690
# Training Epochs:  69%|██████▉   | 1035/1500 [14:51<06:40,  1.16it/s]
# Early stopping at epoch 1036
# Evaluating on test set with best model...

# %%
from sklearn.metrics import classification_report

print(classification_report(targets, preds))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.45      0.72      0.55        90
#         African National Congress (South Africa)       0.67      0.67      0.67        90
#                                 Al-Qaida in Iraq       0.66      0.87      0.75        90
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.56      0.70      0.62        90
#                                       Al-Shabaab       0.90      0.63      0.75        90
#              Basque Fatherland and Freedom (ETA)       0.97      0.69      0.81        90
#                                       Boko Haram       0.81      0.43      0.57        90
#   Communist Party of India - Maoist (CPI-Maoist)       0.57      0.42      0.48        90
#        Corsican National Liberation Front (FLNC)       0.97      0.83      0.90        90
#                        Donetsk People's Republic       0.96      0.76      0.84        90
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.62      0.77        90
#                                Fulani extremists       0.59      0.56      0.57        90
#                  Houthi extremists (Ansar Allah)       0.79      0.50      0.61        90
#                      Irish Republican Army (IRA)       0.91      0.76      0.82        90
#      Islamic State of Iraq and the Levant (ISIL)       0.60      0.37      0.46        90
#                   Kurdistan Workers' Party (PKK)       0.38      0.23      0.29        90
#          Liberation Tigers of Tamil Eelam (LTTE)       0.78      0.71      0.74        90
#          Manuel Rodriguez Patriotic Front (FPMR)       1.00      0.81      0.90        90
#                                          Maoists       0.31      0.29      0.30        90
#                                Muslim extremists       0.79      0.51      0.62        90
#       National Liberation Army of Colombia (ELN)       0.41      0.44      0.43        90
#                          New People's Army (NPA)       0.13      0.58      0.21        90
#                Nicaraguan Democratic Force (FDN)       0.57      0.64      0.60        90
#                                     Palestinians       1.00      0.59      0.74        90
#    Revolutionary Armed Forces of Colombia (FARC)       0.21      0.51      0.30        90
#                                Shining Path (SL)       0.84      0.42      0.56        90
#                                  Sikh Extremists       0.95      0.64      0.77        90
#                                          Taliban       0.73      0.24      0.37        90
#                  Tehrik-i-Taliban Pakistan (TTP)       0.92      0.64      0.76        90
#        Tupac Amaru Revolutionary Movement (MRTA)       0.81      0.81      0.81        90
#
#                                         accuracy                           0.59      2700
#                                        macro avg       0.71      0.59      0.62      2700
#                                     weighted avg       0.71      0.59      0.62      2700

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition):
    cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition gtd{partition})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    save_path = f"results/confusion_matrix_partition_gtd{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition gtd{partition} to {save_path}")

# %%
plot_confusion_matrix(targets, preds, labels, partition)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_confusion_matrix(targets, preds, labels, partition)
#
# Cell In[6], line 2, in plot_confusion_matrix(y_true, y_pred, labels, partition)
#       1 def plot_confusion_matrix(y_true, y_pred, labels, partition):
# ----> 2     cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
#       3     cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
#       5     plt.figure(figsize=(18, 16))
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     340         return np.zeros((n_labels, n_labels), dtype=int)
#     341     elif len(np.intersect1d(y_true, labels)) == 0:
# --> 342         raise ValueError("At least one label specified must be in y_true")
#     344 if sample_weight is None:
#     345     sample_weight = np.ones(y_true.shape[0], dtype=np.int64)
#
# ValueError: At least one label specified must be in y_true
