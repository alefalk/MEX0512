# %%
partition = 100

# %%
import sys
from train import main
from itertools import product  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import random
from itertools import product
import sys

n_tree_values = [5, 10, 20, 50, 100]
tree_depth_values = [6, 7, 8, 9, 10, 11]
hidden_dim = [1024, 768]
batch_size_values = [256, 512]
tree_feature_rates = [0.1, 0.2, 0.3, 0.4]
feat_dropouts = [0.0, 0.1, 0.2]
lrs = [0.01, 0.001]

n_iter = 100
best_score = 0
best_config = {}

param_space = list(product(
    n_tree_values,
    tree_depth_values,
    hidden_dim,
    batch_size_values,
    tree_feature_rates,
    feat_dropouts,
    lrs
))

best_acc = 0

sampled_configs = random.sample(param_space, min(n_iter, len(param_space)))
i = 1
for n_tree, t_depth, hd, batch_size, feature_rate, dropout, lr in sampled_configs:
    print(f"\nRunning: n_tree={n_tree}, t_depth={t_depth}, hd={hd}, batch_size={batch_size}, feature_rate={feature_rate}, dropout={dropout}, lr={lr}")
    sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', str(n_tree),
        '-tree_depth', str(t_depth),
        '-batch_size', str(batch_size),
        '-hidden_dim', str(hd),
        '-tree_feature_rate', str(feature_rate),
        '-feat_dropout', str(dropout),
        '-lr', str(lr),
        '-epochs', '400',
        '-verbose', '0',
        '-jointly_training',
        '-searching', '1'
    ]

    print(f"{i} / 100")
    acc = main()
    #print(acc)
    i =i + 1

    if acc > best_acc:
        best_acc = acc
        best_config = {
            'n_tree': n_tree,
            'tree_depth': t_depth,
            'batch_size': batch_size,
            'hidden_dim': hd,
            'tree_feature_rate': feature_rate,
            'feat_dropout': dropout,
            'lr': lr
        }

print("\nBest hyperparameter configuration:")
print(best_acc)
print(f"Best accuracy: {best_score}")
# Out:
# Running: n_tree=50, t_depth=6, hd=768, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 1 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:24<00:59,  4.73it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.516667
#
# Running: n_tree=100, t_depth=11, hd=768, batch_size=256, feature_rate=0.4, dropout=0.2, lr=0.01
# 2 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [01:56<05:06,  1.06s/it]
# Early stopping at epoch 111
# Best Accuracy: 0.500000
#
# Running: n_tree=20, t_depth=7, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 3 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:20<00:52,  5.49it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.521429
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 4 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:06<00:16, 17.11it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.490476
#
# Running: n_tree=10, t_depth=7, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 5 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:08<00:21, 13.60it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.504762
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 6 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:58<02:33,  1.89it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.497619
#
# Running: n_tree=20, t_depth=8, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.0, lr=0.01
# 7 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:21<00:54,  5.21it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.514286
#
# Running: n_tree=20, t_depth=11, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 8 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 108/400 [00:25<01:09,  4.23it/s]
# Early stopping at epoch 109
#
# Best Accuracy: 0.500000
#
# Running: n_tree=10, t_depth=7, hd=768, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 9 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:12<00:31,  9.20it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.530952
#
# Running: n_tree=10, t_depth=8, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 10 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 118/400 [00:14<00:33,  8.35it/s]
# Early stopping at epoch 119
#
# Best Accuracy: 0.504762
#
# Running: n_tree=5, t_depth=10, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 11 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  32%|███▏      | 126/400 [00:11<00:24, 11.39it/s]
# Early stopping at epoch 127
#
# Best Accuracy: 0.533333
#
# Running: n_tree=10, t_depth=10, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 12 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███       | 124/400 [00:10<00:24, 11.30it/s]
# Early stopping at epoch 125
#
# Best Accuracy: 0.528571
#
# Running: n_tree=100, t_depth=10, hd=768, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 13 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 118/400 [01:07<02:40,  1.76it/s]
# Early stopping at epoch 119
#
# Best Accuracy: 0.504762
#
# Running: n_tree=100, t_depth=11, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 14 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [01:59<05:03,  1.06s/it]
# Early stopping at epoch 114
# Best Accuracy: 0.504762
#
# Running: n_tree=50, t_depth=6, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.2, lr=0.01
# 15 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 122/400 [00:26<01:01,  4.55it/s]
# Early stopping at epoch 123
#
# Best Accuracy: 0.507143
#
# Running: n_tree=100, t_depth=7, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 16 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [01:21<03:36,  1.34it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.514286
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 17 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:23<01:01,  4.72it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.490476
#
# Running: n_tree=50, t_depth=7, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 18 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 112/400 [00:43<01:51,  2.58it/s]
# Early stopping at epoch 113
#
# Best Accuracy: 0.507143
#
# Running: n_tree=20, t_depth=7, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 19 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 121/400 [00:13<00:31,  9.00it/s]
# Early stopping at epoch 122
#
# Best Accuracy: 0.516667
#
# Running: n_tree=10, t_depth=10, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 20 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:10<00:25, 11.29it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.523810
#
# Running: n_tree=50, t_depth=8, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 21 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███▏      | 125/400 [00:52<01:54,  2.39it/s]
# Early stopping at epoch 126
#
# Best Accuracy: 0.502381
#
# Running: n_tree=5, t_depth=11, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 22 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:07<00:18, 15.12it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.533333
#
# Running: n_tree=20, t_depth=11, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 23 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:17<00:43,  6.59it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.511905
#
# Running: n_tree=5, t_depth=8, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 24 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [00:08<00:22, 12.97it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.514286
#
# Running: n_tree=5, t_depth=10, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 25 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 122/400 [00:11<00:25, 11.04it/s]
# Early stopping at epoch 123
#
# Best Accuracy: 0.495238
#
# Running: n_tree=5, t_depth=7, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 26 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  33%|███▎      | 132/400 [00:07<00:14, 18.33it/s]
# Early stopping at epoch 133
#
# Best Accuracy: 0.504762
#
# Running: n_tree=50, t_depth=6, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 27 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:24<01:00,  4.71it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.507143
#
# Running: n_tree=10, t_depth=9, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 28 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:14<00:37,  7.75it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.526190
#
# Running: n_tree=5, t_depth=7, hd=768, batch_size=512, feature_rate=0.3, dropout=0.2, lr=0.01
# 29 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:06<00:15, 18.53it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.504762
#
# Running: n_tree=10, t_depth=7, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 30 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 112/400 [00:08<00:21, 13.58it/s]
# Early stopping at epoch 113
#
# Best Accuracy: 0.530952
#
# Running: n_tree=10, t_depth=6, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 31 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:12<00:29,  9.47it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.500000
#
# Running: n_tree=100, t_depth=7, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 32 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [00:49<02:05,  2.28it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.502381
#
# Running: n_tree=100, t_depth=11, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 33 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 107/400 [01:53<05:09,  1.06s/it]
# Early stopping at epoch 108
# Best Accuracy: 0.516667
#
# Running: n_tree=50, t_depth=8, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.2, lr=0.01
# 34 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:29<01:13,  3.88it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.502381
#
# Running: n_tree=100, t_depth=8, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 35 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:55<02:16,  2.08it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.504762
#
# Running: n_tree=10, t_depth=8, hd=768, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 36 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███       | 124/400 [00:14<00:32,  8.43it/s]
# Early stopping at epoch 125
#
# Best Accuracy: 0.500000
#
# Running: n_tree=20, t_depth=8, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.2, lr=0.01
# 37 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  42%|████▏     | 169/400 [00:20<00:28,  8.22it/s]
# Early stopping at epoch 170
#
# Best Accuracy: 0.504762
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 38 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  36%|███▌      | 143/400 [00:12<00:21, 11.69it/s]
# Early stopping at epoch 144
#
# Best Accuracy: 0.523810
#
# Running: n_tree=50, t_depth=7, hd=768, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 39 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  36%|███▌      | 142/400 [00:54<01:39,  2.61it/s]
# Early stopping at epoch 143
#
# Best Accuracy: 0.526190
#
# Running: n_tree=20, t_depth=8, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 40 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:14<00:34,  8.22it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.509524
#
# Running: n_tree=5, t_depth=7, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 41 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:06<00:15, 18.23it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.502381
#
# Running: n_tree=20, t_depth=7, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 42 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:19<00:52,  5.57it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.516667
#
# Running: n_tree=20, t_depth=6, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.2, lr=0.01
# 43 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 107/400 [00:17<00:48,  6.07it/s]
# Early stopping at epoch 108
#
# Best Accuracy: 0.488095
#
# Running: n_tree=10, t_depth=8, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 44 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:08<00:22, 13.13it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.511905
#
# Running: n_tree=5, t_depth=7, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 45 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 119/400 [00:06<00:14, 19.62it/s]
# Early stopping at epoch 120
#
# Best Accuracy: 0.533333
#
# Running: n_tree=10, t_depth=6, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 46 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 112/400 [00:11<00:28, 10.00it/s]
# Early stopping at epoch 113
#
# Best Accuracy: 0.526190
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 47 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 112/400 [00:23<00:59,  4.85it/s]
# Early stopping at epoch 113
#
# Best Accuracy: 0.511905
#
# Running: n_tree=10, t_depth=11, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 48 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:15<00:39,  7.17it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.526190
#
# Running: n_tree=5, t_depth=6, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 49 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 107/400 [00:07<00:20, 14.07it/s]
# Early stopping at epoch 108
#
# Best Accuracy: 0.514286
#
# Running: n_tree=5, t_depth=11, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 50 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 121/400 [00:07<00:17, 16.37it/s]
# Early stopping at epoch 122
#
# Best Accuracy: 0.507143
#
# Running: n_tree=20, t_depth=10, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 51 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 120/400 [00:16<00:37,  7.37it/s]
# Early stopping at epoch 121
#
# Best Accuracy: 0.511905
#
# Running: n_tree=50, t_depth=10, hd=768, batch_size=512, feature_rate=0.4, dropout=0.2, lr=0.01
# 52 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:33<01:26,  3.35it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.502381
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=256, feature_rate=0.1, dropout=0.0, lr=0.01
# 53 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:23<01:03,  4.56it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.514286
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 54 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [01:06<02:49,  1.70it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.495238
#
# Running: n_tree=100, t_depth=11, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 55 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███       | 124/400 [02:11<04:51,  1.06s/it]
# Early stopping at epoch 125
#
# Best Accuracy: 0.497619
#
# Running: n_tree=10, t_depth=11, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 56 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:16<00:39,  7.14it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.521429
#
# Running: n_tree=5, t_depth=8, hd=768, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 57 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:06<00:15, 18.71it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.500000
#
# Running: n_tree=10, t_depth=6, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 58 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:11<00:30,  9.65it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.516667
#
# Running: n_tree=5, t_depth=10, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 59 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:09<00:24, 11.65it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.500000
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 60 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:58<02:35,  1.87it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.492857
#
# Running: n_tree=20, t_depth=9, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 61 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 118/400 [00:15<00:36,  7.80it/s]
# Early stopping at epoch 119
#
# Best Accuracy: 0.507143
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.2, lr=0.01
# 62 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:06<00:15, 17.87it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.495238
#
# Running: n_tree=20, t_depth=6, hd=768, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 63 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 109/400 [00:17<00:47,  6.08it/s]
# Early stopping at epoch 110
#
# Best Accuracy: 0.528571
#
# Running: n_tree=50, t_depth=10, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 64 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:34<01:25,  3.35it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.516667
#
# Running: n_tree=50, t_depth=8, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 65 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:27<01:12,  3.99it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.497619
#
# Running: n_tree=20, t_depth=6, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 66 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:11<00:29,  9.74it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.526190
#
# Running: n_tree=100, t_depth=6, hd=768, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 67 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [01:14<03:08,  1.52it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.500000
#
# Running: n_tree=10, t_depth=9, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 68 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:13<00:35,  8.11it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.504762
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 69 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:14<00:35,  7.97it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.523810
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=256, feature_rate=0.4, dropout=0.2, lr=0.01
# 70 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:58<02:33,  1.89it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.511905
#
# Running: n_tree=20, t_depth=7, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 71 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [00:19<00:50,  5.67it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.519048
#
# Running: n_tree=10, t_depth=8, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 72 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███       | 124/400 [00:09<00:20, 13.35it/s]
# Early stopping at epoch 125
#
# Best Accuracy: 0.511905
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 73 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:08<00:23, 12.51it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.507143
#
# Running: n_tree=20, t_depth=10, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 74 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:24<01:02,  4.61it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.504762
#
# Running: n_tree=5, t_depth=9, hd=768, batch_size=256, feature_rate=0.3, dropout=0.1, lr=0.01
# 75 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 120/400 [00:09<00:22, 12.46it/s]
# Early stopping at epoch 121
#
# Best Accuracy: 0.509524
#
# Running: n_tree=5, t_depth=10, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 76 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 116/400 [00:06<00:16, 17.01it/s]
# Early stopping at epoch 117
#
# Best Accuracy: 0.533333
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.2, lr=0.01
# 77 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [01:47<04:40,  1.03it/s]
# Early stopping at epoch 112
# Best Accuracy: 0.514286
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 78 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  27%|██▋       | 108/400 [01:45<04:44,  1.03it/s]
# Early stopping at epoch 109
# Best Accuracy: 0.504762
#
# Running: n_tree=20, t_depth=10, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 79 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:24<01:02,  4.60it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.519048
#
# Running: n_tree=50, t_depth=10, hd=768, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 80 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  31%|███       | 123/400 [00:36<01:21,  3.38it/s]
# Early stopping at epoch 124
#
# Best Accuracy: 0.516667
#
# Running: n_tree=20, t_depth=8, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 81 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 118/400 [00:14<00:33,  8.33it/s]
# Early stopping at epoch 119
#
# Best Accuracy: 0.514286
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 82 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 114/400 [00:23<00:58,  4.87it/s]
# Early stopping at epoch 115
#
# Best Accuracy: 0.523810
#
# Running: n_tree=100, t_depth=7, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 83 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:48<02:05,  2.30it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.504762
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 84 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:24<01:03,  4.54it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.490476
#
# Running: n_tree=20, t_depth=11, hd=768, batch_size=512, feature_rate=0.4, dropout=0.2, lr=0.01
# 85 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:16<00:43,  6.65it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.502381
#
# Running: n_tree=5, t_depth=10, hd=768, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 86 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:09<00:24, 11.88it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.507143
#
# Running: n_tree=5, t_depth=7, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 87 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 112/400 [00:08<00:21, 13.42it/s]
# Early stopping at epoch 113
#
# Best Accuracy: 0.500000
#
# Running: n_tree=10, t_depth=9, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 88 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 115/400 [00:09<00:23, 12.24it/s]
# Early stopping at epoch 116
#
# Best Accuracy: 0.523810
#
# Running: n_tree=10, t_depth=6, hd=768, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 89 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:10<00:28, 10.10it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.502381
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 90 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  32%|███▏      | 126/400 [00:39<01:25,  3.20it/s]
# Early stopping at epoch 127
#
# Best Accuracy: 0.500000
#
# Running: n_tree=20, t_depth=11, hd=768, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 91 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [00:16<00:42,  6.76it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.502381
#
# Running: n_tree=100, t_depth=7, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 92 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 113/400 [00:49<02:05,  2.29it/s]
# Early stopping at epoch 114
#
# Best Accuracy: 0.516667
#
# Running: n_tree=5, t_depth=11, hd=768, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 93 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:10<00:25, 11.13it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.504762
#
# Running: n_tree=10, t_depth=11, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 94 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 121/400 [00:11<00:25, 10.91it/s]
# Early stopping at epoch 122
#
# Best Accuracy: 0.523810
#
# Running: n_tree=100, t_depth=7, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 95 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  29%|██▉       | 117/400 [00:50<02:01,  2.32it/s]
# Early stopping at epoch 118
#
# Best Accuracy: 0.504762
#
# Running: n_tree=100, t_depth=7, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 96 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|███       | 121/400 [00:51<01:59,  2.33it/s]
# Early stopping at epoch 122
# Best Accuracy: 0.502381
#
# Running: n_tree=20, t_depth=7, hd=768, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 97 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  32%|███▏      | 126/400 [00:22<00:48,  5.66it/s]
# Early stopping at epoch 127
#
# Best Accuracy: 0.504762
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.2, lr=0.01
# 98 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 111/400 [01:45<04:35,  1.05it/s]
# Early stopping at epoch 112
#
# Best Accuracy: 0.521429
#
# Running: n_tree=10, t_depth=7, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 99 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  28%|██▊       | 110/400 [00:08<00:21, 13.63it/s]
# Early stopping at epoch 111
#
# Best Accuracy: 0.516667
#
# Running: n_tree=50, t_depth=8, hd=768, batch_size=512, feature_rate=0.2, dropout=0.2, lr=0.01
# 100 / 100
# Use gtd100 dataset
# Patience: 100
# Training Epochs:  30%|██▉       | 119/400 [00:29<01:10,  3.97it/s]
# Early stopping at epoch 120
#
# Best Accuracy: 0.497619
#
# Best hyperparameter configuration:
# {'n_tree': 50, 'tree_depth': 8, 'batch_size': 512, 'hidden_dim': 768, 'tree_feature_rate': 0.2, 'feat_dropout': 0.2, 'lr': 0.01}
# Best accuracy: 0

# %%
#Running: n_tree=5, t_depth=10, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01

# %%
"""sys.argv = [
    'train.py',
    '-dataset', f'gtd{partition}',
    '-n_class', '30',
    '-gpuid', '0',
    '-n_tree', str(best_config['n_tree']),
    '-tree_depth', str(best_config['tree_depth']),
    '-batch_size', str(best_config['batch_size']),
    '-epochs', '1000',
    '-verbose', '1',
    '-jointly_training'
]"""

sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', '5',
        '-tree_depth', '10',
        '-batch_size', '512',
        '-hidden_dim', '1024',
        '-epochs', '1500',
        '-verbose', '0',
        '-tree_feature_rate', '0.3',
        '-feat_dropout', '0.0',
        '-lr', '0.01',
        '-jointly_training',
        '-searching', '0'
    ]

best_model, preds, targets, labels, epoch_logs = main()
# Out:
# Use gtd100 dataset
# Patience: 500
# Training Epochs:   4%|▎         | 53/1500 [00:03<01:21, 17.71it/s]
# [Epoch 50] Train Loss: 0.6074, Eval Loss: 1.9004, Eval Accuracy: 0.4738
# Training Epochs:   7%|▋         | 103/1500 [00:06<01:17, 18.09it/s]
# [Epoch 100] Train Loss: 0.2828, Eval Loss: 1.8558, Eval Accuracy: 0.4548
# Training Epochs:  10%|█         | 153/1500 [00:09<01:14, 18.01it/s]
# [Epoch 150] Train Loss: 0.2331, Eval Loss: 1.8659, Eval Accuracy: 0.4571
# Training Epochs:  14%|█▎        | 203/1500 [00:12<01:11, 18.07it/s]
# [Epoch 200] Train Loss: 0.1872, Eval Loss: 1.8986, Eval Accuracy: 0.4762
# Training Epochs:  17%|█▋        | 253/1500 [00:14<01:10, 17.64it/s]
# [Epoch 250] Train Loss: 0.1530, Eval Loss: 1.9513, Eval Accuracy: 0.4738
# Training Epochs:  20%|██        | 303/1500 [00:17<01:12, 16.57it/s]
# [Epoch 300] Train Loss: 0.1381, Eval Loss: 1.9528, Eval Accuracy: 0.4905
# Training Epochs:  24%|██▎       | 353/1500 [00:20<01:02, 18.22it/s]
# [Epoch 350] Train Loss: 0.1274, Eval Loss: 1.9426, Eval Accuracy: 0.4857
# Training Epochs:  27%|██▋       | 403/1500 [00:23<01:01, 17.95it/s]
# [Epoch 400] Train Loss: 0.1278, Eval Loss: 1.9467, Eval Accuracy: 0.4810
# Training Epochs:  30%|███       | 453/1500 [00:26<00:56, 18.43it/s]
# [Epoch 450] Train Loss: 0.1214, Eval Loss: 1.9685, Eval Accuracy: 0.4833
# Training Epochs:  34%|███▎      | 503/1500 [00:28<00:54, 18.21it/s]
# [Epoch 500] Train Loss: 0.1224, Eval Loss: 1.9692, Eval Accuracy: 0.4857
# Training Epochs:  34%|███▍      | 514/1500 [00:29<00:56, 17.31it/s]
# Early stopping at epoch 515
# Evaluating on test set with best model...

# %%
from sklearn.metrics import classification_report

print(classification_report(targets, preds))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.59      0.63      0.61        30
#         African National Congress (South Africa)       0.42      0.83      0.56        30
#                                 Al-Qaida in Iraq       0.78      0.70      0.74        30
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.35      0.57      0.44        30
#                                       Al-Shabaab       0.74      0.57      0.64        30
#              Basque Fatherland and Freedom (ETA)       1.00      0.53      0.70        30
#                                       Boko Haram       0.72      0.43      0.54        30
#   Communist Party of India - Maoist (CPI-Maoist)       0.33      0.20      0.25        30
#        Corsican National Liberation Front (FLNC)       1.00      0.77      0.87        30
#                        Donetsk People's Republic       0.81      0.73      0.77        30
# Farabundo Marti National Liberation Front (FMLN)       0.82      0.30      0.44        30
#                                Fulani extremists       0.58      0.50      0.54        30
#                  Houthi extremists (Ansar Allah)       0.68      0.50      0.58        30
#                      Irish Republican Army (IRA)       0.95      0.63      0.76        30
#      Islamic State of Iraq and the Levant (ISIL)       0.41      0.30      0.35        30
#                   Kurdistan Workers' Party (PKK)       0.08      0.20      0.11        30
#          Liberation Tigers of Tamil Eelam (LTTE)       0.59      0.33      0.43        30
#          Manuel Rodriguez Patriotic Front (FPMR)       1.00      0.87      0.93        30
#                                          Maoists       0.29      0.23      0.26        30
#                                Muslim extremists       0.25      0.23      0.24        30
#       National Liberation Army of Colombia (ELN)       0.54      0.50      0.52        30
#                          New People's Army (NPA)       0.05      0.03      0.04        30
#                Nicaraguan Democratic Force (FDN)       0.21      0.20      0.21        30
#                                     Palestinians       0.88      0.77      0.82        30
#    Revolutionary Armed Forces of Colombia (FARC)       0.15      0.63      0.24        30
#                                Shining Path (SL)       0.39      0.23      0.29        30
#                                  Sikh Extremists       0.57      0.53      0.55        30
#                                          Taliban       0.44      0.13      0.21        30
#                  Tehrik-i-Taliban Pakistan (TTP)       0.33      0.40      0.36        30
#        Tupac Amaru Revolutionary Movement (MRTA)       0.94      0.50      0.65        30
#
#                                         accuracy                           0.47       900
#                                        macro avg       0.56      0.47      0.49       900
#                                     weighted avg       0.56      0.47      0.49       900

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition):
    cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition gtd{partition})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    save_path = f"results/confusion_matrix_partition_gtd{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition gtd{partition} to {save_path}")

# %%
plot_confusion_matrix(targets, preds, labels, partition)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_confusion_matrix(targets, preds, labels, partition)
#
# Cell In[7], line 2, in plot_confusion_matrix(y_true, y_pred, labels, partition)
#       1 def plot_confusion_matrix(y_true, y_pred, labels, partition):
# ----> 2     cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
#       3     cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
#       5     plt.figure(figsize=(18, 16))
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     340         return np.zeros((n_labels, n_labels), dtype=int)
#     341     elif len(np.intersect1d(y_true, labels)) == 0:
# --> 342         raise ValueError("At least one label specified must be in y_true")
#     344 if sample_weight is None:
#     345     sample_weight = np.ones(y_true.shape[0], dtype=np.int64)
#
# ValueError: At least one label specified must be in y_true
