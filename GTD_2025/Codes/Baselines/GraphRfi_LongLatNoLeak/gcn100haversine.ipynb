# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/LongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
geodata = ['longitude', 'latitude']
combined_geo = df.copy()
combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
param_grid = {
    'lr': [0.001],
    'n_tree': [40, 80, 100],
    'tree_depth': [10],
    'tree_feature_rate': [0.2,0.5],
    'feat_dropout': [0.1],
    'embed_dim': [32, 64]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    full_coords, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
        combined_geo, label_index, continuous_col=col)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask,
            args, row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# tensor(1142)
# tensor(459)
# tensor(470)
# tensor(2328)
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.2, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4251 | NRF Loss: 3.4012 | Joint: 6.8263 | Val Acc: 0.2183
# Epoch 050 | GCN Loss: 3.1394 | NRF Loss: 3.1478 | Joint: 6.2873 | Val Acc: 0.3917
# Epoch 100 | GCN Loss: 2.8170 | NRF Loss: 2.8934 | Joint: 5.7104 | Val Acc: 0.6633
# Epoch 150 | GCN Loss: 2.5109 | NRF Loss: 2.7223 | Joint: 5.2332 | Val Acc: 0.7317
# Epoch 200 | GCN Loss: 2.2686 | NRF Loss: 2.5847 | Joint: 4.8533 | Val Acc: 0.7617
# Epoch 250 | GCN Loss: 2.0811 | NRF Loss: 2.4628 | Joint: 4.5439 | Val Acc: 0.7800
# Epoch 300 | GCN Loss: 1.9299 | NRF Loss: 2.3527 | Joint: 4.2826 | Val Acc: 0.8100
# Epoch 350 | GCN Loss: 1.8016 | NRF Loss: 2.2520 | Joint: 4.0536 | Val Acc: 0.8083
# Epoch 400 | GCN Loss: 1.6885 | NRF Loss: 2.1583 | Joint: 3.8468 | Val Acc: 0.8183
# Epoch 450 | GCN Loss: 1.5881 | NRF Loss: 2.0698 | Joint: 3.6579 | Val Acc: 0.8200
# Epoch 500 | GCN Loss: 1.4987 | NRF Loss: 1.9867 | Joint: 3.4854 | Val Acc: 0.8183
# Epoch 550 | GCN Loss: 1.4192 | NRF Loss: 1.9098 | Joint: 3.3290 | Val Acc: 0.8200
# Epoch 600 | GCN Loss: 1.3487 | NRF Loss: 1.8364 | Joint: 3.1851 | Val Acc: 0.8217
# Epoch 650 | GCN Loss: 1.2859 | NRF Loss: 1.7677 | Joint: 3.0536 | Val Acc: 0.8233
# Epoch 700 | GCN Loss: 1.2300 | NRF Loss: 1.7031 | Joint: 2.9331 | Val Acc: 0.8200
# Epoch 750 | GCN Loss: 1.1799 | NRF Loss: 1.6420 | Joint: 2.8219 | Val Acc: 0.8183
# Epoch 800 | GCN Loss: 1.1348 | NRF Loss: 1.5821 | Joint: 2.7168 | Val Acc: 0.7983
# Epoch 850 | GCN Loss: 1.0941 | NRF Loss: 1.5271 | Joint: 2.6212 | Val Acc: 0.7950
# Epoch 900 | GCN Loss: 1.0574 | NRF Loss: 1.4759 | Joint: 2.5333 | Val Acc: 0.8033
# Epoch 950 | GCN Loss: 1.0240 | NRF Loss: 1.4266 | Joint: 2.4505 | Val Acc: 0.8000
# Epoch 1000 | GCN Loss: 0.9935 | NRF Loss: 1.3812 | Joint: 2.3747 | Val Acc: 0.8017
# Epoch 1050 | GCN Loss: 0.9659 | NRF Loss: 1.3374 | Joint: 2.3033 | Val Acc: 0.8000
# Early stopping at epoch 1089
# Best validation acc: 0.8383 @ epoch 789
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.2, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4081 | NRF Loss: 3.4012 | Joint: 6.8093 | Val Acc: 0.1767
# Epoch 050 | GCN Loss: 2.9885 | NRF Loss: 3.1408 | Joint: 6.1293 | Val Acc: 0.3700
# Epoch 100 | GCN Loss: 2.5300 | NRF Loss: 2.8915 | Joint: 5.4215 | Val Acc: 0.6633
# Epoch 150 | GCN Loss: 2.1860 | NRF Loss: 2.7271 | Joint: 4.9131 | Val Acc: 0.7400
# Epoch 200 | GCN Loss: 1.9452 | NRF Loss: 2.5957 | Joint: 4.5409 | Val Acc: 0.7767
# Epoch 250 | GCN Loss: 1.7602 | NRF Loss: 2.4811 | Joint: 4.2413 | Val Acc: 0.7700
# Epoch 300 | GCN Loss: 1.6101 | NRF Loss: 2.3775 | Joint: 3.9876 | Val Acc: 0.7717
# Epoch 350 | GCN Loss: 1.4852 | NRF Loss: 2.2827 | Joint: 3.7679 | Val Acc: 0.7783
# Epoch 400 | GCN Loss: 1.3794 | NRF Loss: 2.1944 | Joint: 3.5738 | Val Acc: 0.7950
# Epoch 450 | GCN Loss: 1.2891 | NRF Loss: 2.1112 | Joint: 3.4003 | Val Acc: 0.8117
# Epoch 500 | GCN Loss: 1.2117 | NRF Loss: 2.0320 | Joint: 3.2437 | Val Acc: 0.8200
# Epoch 550 | GCN Loss: 1.1451 | NRF Loss: 1.9567 | Joint: 3.1018 | Val Acc: 0.8233
# Epoch 600 | GCN Loss: 1.0877 | NRF Loss: 1.8852 | Joint: 2.9729 | Val Acc: 0.8250
# Epoch 650 | GCN Loss: 1.0379 | NRF Loss: 1.8179 | Joint: 2.8558 | Val Acc: 0.8250
# Epoch 700 | GCN Loss: 0.9945 | NRF Loss: 1.7553 | Joint: 2.7499 | Val Acc: 0.8283
# Epoch 750 | GCN Loss: 0.9565 | NRF Loss: 1.6955 | Joint: 2.6520 | Val Acc: 0.8267
# Epoch 800 | GCN Loss: 0.9229 | NRF Loss: 1.6382 | Joint: 2.5611 | Val Acc: 0.8267
# Epoch 850 | GCN Loss: 0.8929 | NRF Loss: 1.5844 | Joint: 2.4773 | Val Acc: 0.8217
# Epoch 900 | GCN Loss: 0.8661 | NRF Loss: 1.5329 | Joint: 2.3990 | Val Acc: 0.8217
# Epoch 950 | GCN Loss: 0.8420 | NRF Loss: 1.4844 | Joint: 2.3264 | Val Acc: 0.8267
# Early stopping at epoch 989
# Best validation acc: 0.8333 @ epoch 689
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3926 | NRF Loss: 3.4011 | Joint: 6.7938 | Val Acc: 0.2533
# Epoch 050 | GCN Loss: 3.0928 | NRF Loss: 3.0389 | Joint: 6.1317 | Val Acc: 0.5583
# Epoch 100 | GCN Loss: 2.7784 | NRF Loss: 2.8350 | Joint: 5.6135 | Val Acc: 0.7533
# Epoch 150 | GCN Loss: 2.4865 | NRF Loss: 2.6914 | Joint: 5.1778 | Val Acc: 0.7883
# Epoch 200 | GCN Loss: 2.2478 | NRF Loss: 2.5660 | Joint: 4.8138 | Val Acc: 0.8283
# Epoch 250 | GCN Loss: 2.0571 | NRF Loss: 2.4507 | Joint: 4.5078 | Val Acc: 0.8350
# Epoch 300 | GCN Loss: 1.9006 | NRF Loss: 2.3448 | Joint: 4.2454 | Val Acc: 0.8333
# Epoch 350 | GCN Loss: 1.7667 | NRF Loss: 2.2455 | Joint: 4.0121 | Val Acc: 0.8367
# Epoch 400 | GCN Loss: 1.6496 | NRF Loss: 2.1528 | Joint: 3.8024 | Val Acc: 0.8433
# Epoch 450 | GCN Loss: 1.5466 | NRF Loss: 2.0641 | Joint: 3.6107 | Val Acc: 0.8517
# Epoch 500 | GCN Loss: 1.4554 | NRF Loss: 1.9811 | Joint: 3.4365 | Val Acc: 0.8517
# Epoch 550 | GCN Loss: 1.3750 | NRF Loss: 1.9023 | Joint: 3.2774 | Val Acc: 0.8650
# Epoch 600 | GCN Loss: 1.3040 | NRF Loss: 1.8277 | Joint: 3.1317 | Val Acc: 0.8600
# Epoch 650 | GCN Loss: 1.2411 | NRF Loss: 1.7564 | Joint: 2.9976 | Val Acc: 0.8600
# Epoch 700 | GCN Loss: 1.1853 | NRF Loss: 1.6886 | Joint: 2.8739 | Val Acc: 0.8617
# Epoch 750 | GCN Loss: 1.1357 | NRF Loss: 1.6253 | Joint: 2.7610 | Val Acc: 0.8650
# Epoch 800 | GCN Loss: 1.0915 | NRF Loss: 1.5653 | Joint: 2.6567 | Val Acc: 0.8683
# Epoch 850 | GCN Loss: 1.0521 | NRF Loss: 1.5089 | Joint: 2.5610 | Val Acc: 0.8667
# Epoch 900 | GCN Loss: 1.0169 | NRF Loss: 1.4538 | Joint: 2.4707 | Val Acc: 0.8667
# Epoch 950 | GCN Loss: 0.9853 | NRF Loss: 1.4010 | Joint: 2.3863 | Val Acc: 0.8700
# Epoch 1000 | GCN Loss: 0.9568 | NRF Loss: 1.3515 | Joint: 2.3082 | Val Acc: 0.8650
# Epoch 1050 | GCN Loss: 0.9311 | NRF Loss: 1.3043 | Joint: 2.2354 | Val Acc: 0.8650
# Early stopping at epoch 1057
# Best validation acc: 0.8733 @ epoch 757
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4176 | NRF Loss: 3.4012 | Joint: 6.8189 | Val Acc: 0.2883
# Epoch 050 | GCN Loss: 2.9924 | NRF Loss: 3.0453 | Joint: 6.0376 | Val Acc: 0.5467
# Epoch 100 | GCN Loss: 2.5524 | NRF Loss: 2.8420 | Joint: 5.3944 | Val Acc: 0.7350
# Epoch 150 | GCN Loss: 2.2196 | NRF Loss: 2.7025 | Joint: 4.9221 | Val Acc: 0.7867
# Epoch 200 | GCN Loss: 1.9790 | NRF Loss: 2.5827 | Joint: 4.5617 | Val Acc: 0.7967
# Epoch 250 | GCN Loss: 1.7894 | NRF Loss: 2.4745 | Joint: 4.2639 | Val Acc: 0.8183
# Epoch 300 | GCN Loss: 1.6319 | NRF Loss: 2.3736 | Joint: 4.0054 | Val Acc: 0.8133
# Epoch 350 | GCN Loss: 1.4981 | NRF Loss: 2.2785 | Joint: 3.7766 | Val Acc: 0.8183
# Epoch 400 | GCN Loss: 1.3844 | NRF Loss: 2.1886 | Joint: 3.5730 | Val Acc: 0.8350
# Epoch 450 | GCN Loss: 1.2874 | NRF Loss: 2.1037 | Joint: 3.3911 | Val Acc: 0.8533
# Epoch 500 | GCN Loss: 1.2049 | NRF Loss: 2.0220 | Joint: 3.2269 | Val Acc: 0.8517
# Epoch 550 | GCN Loss: 1.1349 | NRF Loss: 1.9456 | Joint: 3.0805 | Val Acc: 0.8450
# Epoch 600 | GCN Loss: 1.0752 | NRF Loss: 1.8730 | Joint: 2.9482 | Val Acc: 0.8417
# Epoch 650 | GCN Loss: 1.0241 | NRF Loss: 1.8042 | Joint: 2.8284 | Val Acc: 0.8483
# Epoch 700 | GCN Loss: 0.9804 | NRF Loss: 1.7388 | Joint: 2.7192 | Val Acc: 0.8433
# Epoch 750 | GCN Loss: 0.9427 | NRF Loss: 1.6772 | Joint: 2.6199 | Val Acc: 0.8550
# Early stopping at epoch 796
# Best validation acc: 0.8633 @ epoch 496
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.2, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3939 | NRF Loss: 3.4012 | Joint: 6.7952 | Val Acc: 0.1667
# Epoch 050 | GCN Loss: 3.1303 | NRF Loss: 3.1607 | Joint: 6.2910 | Val Acc: 0.3950
# Epoch 100 | GCN Loss: 2.8161 | NRF Loss: 2.9059 | Joint: 5.7220 | Val Acc: 0.6333
# Epoch 150 | GCN Loss: 2.5096 | NRF Loss: 2.7337 | Joint: 5.2433 | Val Acc: 0.7283
# Epoch 200 | GCN Loss: 2.2621 | NRF Loss: 2.5920 | Joint: 4.8541 | Val Acc: 0.7650
# Epoch 250 | GCN Loss: 2.0653 | NRF Loss: 2.4680 | Joint: 4.5333 | Val Acc: 0.8050
# Epoch 300 | GCN Loss: 1.9040 | NRF Loss: 2.3559 | Joint: 4.2599 | Val Acc: 0.8150
# Epoch 350 | GCN Loss: 1.7689 | NRF Loss: 2.2534 | Joint: 4.0224 | Val Acc: 0.8167
# Epoch 400 | GCN Loss: 1.6545 | NRF Loss: 2.1594 | Joint: 3.8139 | Val Acc: 0.8200
# Epoch 450 | GCN Loss: 1.5562 | NRF Loss: 2.0724 | Joint: 3.6286 | Val Acc: 0.8333
# Epoch 500 | GCN Loss: 1.4705 | NRF Loss: 1.9908 | Joint: 3.4614 | Val Acc: 0.8267
# Epoch 550 | GCN Loss: 1.3949 | NRF Loss: 1.9128 | Joint: 3.3077 | Val Acc: 0.8217
# Epoch 600 | GCN Loss: 1.3273 | NRF Loss: 1.8389 | Joint: 3.1662 | Val Acc: 0.8250
# Epoch 650 | GCN Loss: 1.2663 | NRF Loss: 1.7689 | Joint: 3.0353 | Val Acc: 0.8283
# Epoch 700 | GCN Loss: 1.2114 | NRF Loss: 1.7024 | Joint: 2.9138 | Val Acc: 0.8267
# Early stopping at epoch 750
# Best validation acc: 0.8333 @ epoch 450
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.2, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4279 | NRF Loss: 3.4012 | Joint: 6.8291 | Val Acc: 0.2667
# Epoch 050 | GCN Loss: 2.9977 | NRF Loss: 3.1455 | Joint: 6.1432 | Val Acc: 0.3617
# Epoch 100 | GCN Loss: 2.5504 | NRF Loss: 2.8962 | Joint: 5.4466 | Val Acc: 0.6467
# Epoch 150 | GCN Loss: 2.2140 | NRF Loss: 2.7320 | Joint: 4.9460 | Val Acc: 0.7333
# Epoch 200 | GCN Loss: 1.9762 | NRF Loss: 2.5980 | Joint: 4.5742 | Val Acc: 0.7683
# Epoch 250 | GCN Loss: 1.7873 | NRF Loss: 2.4816 | Joint: 4.2688 | Val Acc: 0.7767
# Epoch 300 | GCN Loss: 1.6265 | NRF Loss: 2.3769 | Joint: 4.0034 | Val Acc: 0.7867
# Epoch 350 | GCN Loss: 1.4914 | NRF Loss: 2.2807 | Joint: 3.7720 | Val Acc: 0.7917
# Epoch 400 | GCN Loss: 1.3784 | NRF Loss: 2.1903 | Joint: 3.5687 | Val Acc: 0.7917
# Epoch 450 | GCN Loss: 1.2833 | NRF Loss: 2.1059 | Joint: 3.3892 | Val Acc: 0.8067
# Epoch 500 | GCN Loss: 1.2028 | NRF Loss: 2.0269 | Joint: 3.2297 | Val Acc: 0.8133
# Epoch 550 | GCN Loss: 1.1345 | NRF Loss: 1.9512 | Joint: 3.0856 | Val Acc: 0.8250
# Epoch 600 | GCN Loss: 1.0764 | NRF Loss: 1.8801 | Joint: 2.9566 | Val Acc: 0.8250
# Epoch 650 | GCN Loss: 1.0270 | NRF Loss: 1.8126 | Joint: 2.8396 | Val Acc: 0.8317
# Epoch 700 | GCN Loss: 0.9845 | NRF Loss: 1.7485 | Joint: 2.7330 | Val Acc: 0.8283
# Epoch 750 | GCN Loss: 0.9478 | NRF Loss: 1.6869 | Joint: 2.6346 | Val Acc: 0.8267
# Epoch 800 | GCN Loss: 0.9157 | NRF Loss: 1.6288 | Joint: 2.5445 | Val Acc: 0.8333
# Epoch 850 | GCN Loss: 0.8876 | NRF Loss: 1.5753 | Joint: 2.4629 | Val Acc: 0.8367
# Epoch 900 | GCN Loss: 0.8626 | NRF Loss: 1.5242 | Joint: 2.3868 | Val Acc: 0.8250
# Epoch 950 | GCN Loss: 0.8401 | NRF Loss: 1.4758 | Joint: 2.3159 | Val Acc: 0.8300
# Epoch 1000 | GCN Loss: 0.8198 | NRF Loss: 1.4296 | Joint: 2.2494 | Val Acc: 0.8350
# Epoch 1050 | GCN Loss: 0.8012 | NRF Loss: 1.3860 | Joint: 2.1872 | Val Acc: 0.8317
# Epoch 1100 | GCN Loss: 0.7841 | NRF Loss: 1.3454 | Joint: 2.1295 | Val Acc: 0.8333
# Epoch 1150 | GCN Loss: 0.7683 | NRF Loss: 1.3064 | Joint: 2.0747 | Val Acc: 0.8400
# Epoch 1200 | GCN Loss: 0.7536 | NRF Loss: 1.2696 | Joint: 2.0232 | Val Acc: 0.8400
# Epoch 1250 | GCN Loss: 0.7399 | NRF Loss: 1.2350 | Joint: 1.9749 | Val Acc: 0.8433
# Epoch 1300 | GCN Loss: 0.7269 | NRF Loss: 1.2026 | Joint: 1.9296 | Val Acc: 0.8467
# Epoch 1350 | GCN Loss: 0.7147 | NRF Loss: 1.1713 | Joint: 1.8860 | Val Acc: 0.8483
# Epoch 1400 | GCN Loss: 0.7031 | NRF Loss: 1.1420 | Joint: 1.8451 | Val Acc: 0.8467
# Epoch 1450 | GCN Loss: 0.6919 | NRF Loss: 1.1144 | Joint: 1.8063 | Val Acc: 0.8517
# Epoch 1500 | GCN Loss: 0.6809 | NRF Loss: 1.0879 | Joint: 1.7689 | Val Acc: 0.8500
# Epoch 1550 | GCN Loss: 0.6703 | NRF Loss: 1.0631 | Joint: 1.7334 | Val Acc: 0.8500
# Epoch 1600 | GCN Loss: 0.6600 | NRF Loss: 1.0398 | Joint: 1.6998 | Val Acc: 0.8533
# Epoch 1650 | GCN Loss: 0.6499 | NRF Loss: 1.0177 | Joint: 1.6676 | Val Acc: 0.8517
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 39
#      30 args = {
#      31     **dict(zip(param_names, combo)),
#      32     'partition': f"gtd{partition}",
#    (...)
#      35     'final_evaluation': True
#      36 }
#      38 print(f"Running config: {args}")
# ---> 39 acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
#      40     combined_geo, full_coords, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask,
#      41     args, row_to_node_index, index_to_label, verbose=True)
#      43 if acc > best_score:
#      44     best_score = acc
#
# File ~/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_LongLatNoLeak/haversine_build_graph_and_train.py:255, in train_joint(df, full_coords, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, args, row_to_node_index, index_to_label, verbose)
#     252 #loss2 = neural_forest.loss(out_forest_train, y_nrf[row_train_mask])  # row-level NRF loss on train rows
#     253 loss  = loss1 + loss2
# --> 255 loss.backward()
#     256 optimizer.step()
#     258 # ---- Validation ----
#
# File /opt/conda/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
print(best_run)

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.2, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.8850000500679016, 'epoch': 1715, 'y_pred': ['National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Islamic State of Iraq and the Levant (ISIL)', 'Abu Sayyaf Group (ASG)', 'Basque Fatherland and Freedom (ETA)', 'National Liberation Army of Colombia (ELN)', "New People's Army (NPA)", 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Shining Path (SL)', "Donetsk People's Republic", 'Corsican National Liberation Front (FLNC)', "Donetsk People's Republic", 'Shining Path (SL)', 'Boko Haram', 'Sikh Extremists', 'Taliban', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Irish Republican Army (IRA)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Palestinians', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', 'National Liberation Army of Colombia (ELN)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Taliban', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Corsican National Liberation Front (FLNC)', 'Farabundo Marti National Liberation Front (FMLN)', 'Taliban', 'Nicaraguan Democratic Force (FDN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Abu Sayyaf Group (ASG)', 'Corsican National Liberation Front (FLNC)', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Communist Party of India - Maoist (CPI-Maoist)', 'Fulani extremists', 'Maoists', 'Farabundo Marti National Liberation Front (FMLN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Taliban', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Revolutionary Armed Forces of Colombia (FARC)', "Kurdistan Workers' Party (PKK)", 'Nicaraguan Democratic Force (FDN)', 'Palestinians', "New People's Army (NPA)", 'Nicaraguan Democratic Force (FDN)', 'Shining Path (SL)', 'Al-Qaida in Iraq', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'Sikh Extremists', 'Al-Shabaab', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Nicaraguan Democratic Force (FDN)', 'Irish Republican Army (IRA)', 'Nicaraguan Democratic Force (FDN)', 'Maoists', 'Islamic State of Iraq and the Levant (ISIL)', "Donetsk People's Republic", "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in Iraq', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Farabundo Marti National Liberation Front (FMLN)', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Communist Party of India - Maoist (CPI-Maoist)', "New People's Army (NPA)", 'Boko Haram', 'Farabundo Marti National Liberation Front (FMLN)', "Kurdistan Workers' Party (PKK)", 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Fulani extremists', "New People's Army (NPA)", 'Houthi extremists (Ansar Allah)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Nicaraguan Democratic Force (FDN)', 'Sikh Extremists', 'Farabundo Marti National Liberation Front (FMLN)', 'Boko Haram', 'Boko Haram', 'National Liberation Army of Colombia (ELN)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Farabundo Marti National Liberation Front (FMLN)', 'Boko Haram', 'Boko Haram', 'Houthi extremists (Ansar Allah)', "Kurdistan Workers' Party (PKK)", 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Nicaraguan Democratic Force (FDN)', 'Nicaraguan Democratic Force (FDN)', 'Abu Sayyaf Group (ASG)', "New People's Army (NPA)", 'Al-Qaida in Iraq', 'Houthi extremists (Ansar Allah)', 'Sikh Extremists', 'Sikh Extremists', 'Irish R ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""
# Out:
# '\nBest acc: 0.9205 at epoch 750 for weaptype1 prediction\nWeighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191\nMacro Precision: 0.9176, Recall: 0.9107, F1: 0.9105\nMicro Precision: 0.9205, Recall: 0.9205, F1: 0.9205\nAUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963\n\n'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.98      0.93      0.95        43
#         African National Congress (South Africa)       0.98      1.00      0.99        58
#                                 Al-Qaida in Iraq       1.00      0.79      0.88        87
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.98      0.92      0.95        50
#                                       Al-Shabaab       1.00      1.00      1.00        58
#              Basque Fatherland and Freedom (ETA)       0.98      0.90      0.94        60
#                                       Boko Haram       0.93      0.95      0.94        41
#   Communist Party of India - Maoist (CPI-Maoist)       1.00      0.92      0.96        24
#        Corsican National Liberation Front (FLNC)       0.97      0.96      0.97        78
#                        Donetsk People's Republic       1.00      1.00      1.00        59
# Farabundo Marti National Liberation Front (FMLN)       1.00      0.85      0.92        55
#                                Fulani extremists       0.93      0.89      0.91        28
#                  Houthi extremists (Ansar Allah)       0.95      0.96      0.96        57
#                      Irish Republican Army (IRA)       0.95      1.00      0.97        71
#      Islamic State of Iraq and the Levant (ISIL)       0.65      0.93      0.76        40
#                   Kurdistan Workers' Party (PKK)       0.93      0.87      0.90        30
#          Liberation Tigers of Tamil Eelam (LTTE)       0.98      0.96      0.97        45
#          Manuel Rodriguez Patriotic Front (FPMR)       0.99      1.00      0.99        77
#                                          Maoists       0.92      0.96      0.94        25
#                                Muslim extremists       0.76      0.97      0.85        30
#       National Liberation Army of Colombia (ELN)       0.94      0.90      0.92        51
#                          New People's Army (NPA)       0.81      0.94      0.87        18
#                Nicaraguan Democratic Force (FDN)       0.67      0.94      0.78        17
#                                     Palestinians       0.98      0.97      0.98        65
#    Revolutionary Armed Forces of Colombia (FARC)       0.85      0.88      0.86        32
#                                Shining Path (SL)       0.79      0.98      0.87        46
#                                  Sikh Extremists       0.97      0.98      0.97        57
#                                          Taliban       0.59      0.73      0.65        22
#                  Tehrik-i-Taliban Pakistan (TTP)       0.90      0.83      0.87        54
#        Tupac Amaru Revolutionary Movement (MRTA)       0.99      0.86      0.92        96
#
#                                         accuracy                           0.93      1474
#                                        macro avg       0.91      0.93      0.92      1474
#                                     weighted avg       0.94      0.93      0.93      1474

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
# Out:
# Saved confusion matrix for partition 100 to Results100/cm_100_weaptype1.png
