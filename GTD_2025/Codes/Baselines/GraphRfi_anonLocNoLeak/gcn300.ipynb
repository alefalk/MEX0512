# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 300

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid

param_grid = {
    'lr': [0.001, 0.01],
    'n_tree': [50, 80, 100],
    'tree_depth': [8, 10, 11],
    'tree_feature_rate': [0.1, 0.3],
    'feat_dropout': [0.1, 0.0, 0.2],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 20)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 5157
# tensor(3285)
# tensor(1216)
# tensor(1206)
# tensor(7076)
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4012 | NRF Loss: 3.4012 | Joint: 6.8024 | Val Acc: 0.0800
# Epoch 050 | GCN Loss: 3.1283 | NRF Loss: 3.3299 | Joint: 6.4582 | Val Acc: 0.1983
# Epoch 100 | GCN Loss: 2.5159 | NRF Loss: 3.1572 | Joint: 5.6731 | Val Acc: 0.2633
# Epoch 150 | GCN Loss: 1.7183 | NRF Loss: 2.9752 | Joint: 4.6935 | Val Acc: 0.3233
# Epoch 200 | GCN Loss: 0.9751 | NRF Loss: 2.7992 | Joint: 3.7744 | Val Acc: 0.3322
# Epoch 250 | GCN Loss: 0.5030 | NRF Loss: 2.6312 | Joint: 3.1342 | Val Acc: 0.3456
# Epoch 300 | GCN Loss: 0.2742 | NRF Loss: 2.4871 | Joint: 2.7613 | Val Acc: 0.3400
# Epoch 350 | GCN Loss: 0.1673 | NRF Loss: 2.3625 | Joint: 2.5298 | Val Acc: 0.3322
# Epoch 400 | GCN Loss: 0.1128 | NRF Loss: 2.2519 | Joint: 2.3647 | Val Acc: 0.3333
# Epoch 450 | GCN Loss: 0.0816 | NRF Loss: 2.1524 | Joint: 2.2341 | Val Acc: 0.3333
# Epoch 500 | GCN Loss: 0.0621 | NRF Loss: 2.0619 | Joint: 2.1240 | Val Acc: 0.3289
# Early stopping at epoch 531
# Best validation acc: 0.3467 @ epoch 231
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4018 | NRF Loss: 3.4012 | Joint: 6.8030 | Val Acc: 0.1467
# Epoch 050 | GCN Loss: 3.1354 | NRF Loss: 3.2460 | Joint: 6.3814 | Val Acc: 0.2239
# Epoch 100 | GCN Loss: 2.5220 | NRF Loss: 3.0590 | Joint: 5.5810 | Val Acc: 0.3572
# Epoch 150 | GCN Loss: 1.7273 | NRF Loss: 2.8833 | Joint: 4.6107 | Val Acc: 0.4156
# Epoch 200 | GCN Loss: 0.9903 | NRF Loss: 2.7120 | Joint: 3.7023 | Val Acc: 0.4111
# Epoch 250 | GCN Loss: 0.5192 | NRF Loss: 2.5593 | Joint: 3.0785 | Val Acc: 0.4022
# Epoch 300 | GCN Loss: 0.2854 | NRF Loss: 2.4272 | Joint: 2.7126 | Val Acc: 0.3972
# Epoch 350 | GCN Loss: 0.1746 | NRF Loss: 2.3114 | Joint: 2.4860 | Val Acc: 0.3844
# Epoch 400 | GCN Loss: 0.1177 | NRF Loss: 2.2060 | Joint: 2.3238 | Val Acc: 0.3800
# Epoch 450 | GCN Loss: 0.0852 | NRF Loss: 2.1086 | Joint: 2.1939 | Val Acc: 0.3778
# Early stopping at epoch 472
# Best validation acc: 0.4233 @ epoch 172
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4017 | NRF Loss: 3.4012 | Joint: 6.8029 | Val Acc: 0.0494
# Epoch 050 | GCN Loss: 3.1385 | NRF Loss: 3.3343 | Joint: 6.4728 | Val Acc: 0.2022
# Epoch 100 | GCN Loss: 2.5226 | NRF Loss: 3.1710 | Joint: 5.6935 | Val Acc: 0.2622
# Epoch 150 | GCN Loss: 1.7073 | NRF Loss: 2.9921 | Joint: 4.6994 | Val Acc: 0.3317
# Epoch 200 | GCN Loss: 0.9484 | NRF Loss: 2.8099 | Joint: 3.7583 | Val Acc: 0.3478
# Epoch 250 | GCN Loss: 0.4819 | NRF Loss: 2.6389 | Joint: 3.1208 | Val Acc: 0.3378
# Epoch 300 | GCN Loss: 0.2633 | NRF Loss: 2.4915 | Joint: 2.7548 | Val Acc: 0.3239
# Epoch 350 | GCN Loss: 0.1617 | NRF Loss: 2.3662 | Joint: 2.5280 | Val Acc: 0.3183
# Epoch 400 | GCN Loss: 0.1095 | NRF Loss: 2.2564 | Joint: 2.3659 | Val Acc: 0.3261
# Epoch 450 | GCN Loss: 0.0797 | NRF Loss: 2.1572 | Joint: 2.2369 | Val Acc: 0.3289
# Early stopping at epoch 487
# Best validation acc: 0.3500 @ epoch 187
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4021 | NRF Loss: 3.4012 | Joint: 6.8034 | Val Acc: 0.2000
# Epoch 050 | GCN Loss: 0.0354 | NRF Loss: 2.4176 | Joint: 2.4530 | Val Acc: 0.3472
# Epoch 100 | GCN Loss: 0.0075 | NRF Loss: 1.5126 | Joint: 1.5201 | Val Acc: 0.3322
# Epoch 150 | GCN Loss: 0.0050 | NRF Loss: 1.0134 | Joint: 1.0184 | Val Acc: 0.3233
# Epoch 200 | GCN Loss: 0.0036 | NRF Loss: 0.7613 | Joint: 0.7649 | Val Acc: 0.3156
# Epoch 250 | GCN Loss: 0.0027 | NRF Loss: 0.6197 | Joint: 0.6224 | Val Acc: 0.3111
# Epoch 300 | GCN Loss: 0.0022 | NRF Loss: 0.5280 | Joint: 0.5302 | Val Acc: 0.3161
# Early stopping at epoch 334
# Best validation acc: 0.3633 @ epoch 34
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4003 | NRF Loss: 3.4012 | Joint: 6.8015 | Val Acc: 0.1017
# Epoch 050 | GCN Loss: 3.1160 | NRF Loss: 3.3320 | Joint: 6.4480 | Val Acc: 0.1906
# Epoch 100 | GCN Loss: 2.4938 | NRF Loss: 3.1649 | Joint: 5.6586 | Val Acc: 0.2628
# Epoch 150 | GCN Loss: 1.6998 | NRF Loss: 2.9804 | Joint: 4.6802 | Val Acc: 0.3339
# Epoch 200 | GCN Loss: 0.9684 | NRF Loss: 2.7999 | Joint: 3.7683 | Val Acc: 0.3611
# Epoch 250 | GCN Loss: 0.5031 | NRF Loss: 2.6311 | Joint: 3.1342 | Val Acc: 0.3433
# Epoch 300 | GCN Loss: 0.2749 | NRF Loss: 2.4857 | Joint: 2.7606 | Val Acc: 0.3400
# Epoch 350 | GCN Loss: 0.1677 | NRF Loss: 2.3629 | Joint: 2.5306 | Val Acc: 0.3394
# Epoch 400 | GCN Loss: 0.1128 | NRF Loss: 2.2565 | Joint: 2.3693 | Val Acc: 0.3333
# Epoch 450 | GCN Loss: 0.0816 | NRF Loss: 2.1616 | Joint: 2.2432 | Val Acc: 0.3317
# Early stopping at epoch 491
# Best validation acc: 0.3661 @ epoch 191
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.2033
# Epoch 050 | GCN Loss: 0.0368 | NRF Loss: 2.4416 | Joint: 2.4784 | Val Acc: 0.3628
# Epoch 100 | GCN Loss: 0.0080 | NRF Loss: 1.5626 | Joint: 1.5706 | Val Acc: 0.3350
# Epoch 150 | GCN Loss: 0.0054 | NRF Loss: 1.0669 | Joint: 1.0724 | Val Acc: 0.3256
# Epoch 200 | GCN Loss: 0.0039 | NRF Loss: 0.8138 | Joint: 0.8177 | Val Acc: 0.3206
# Epoch 250 | GCN Loss: 0.0030 | NRF Loss: 0.6684 | Joint: 0.6714 | Val Acc: 0.3144
# Epoch 300 | GCN Loss: 0.0024 | NRF Loss: 0.5783 | Joint: 0.5807 | Val Acc: 0.3078
# Epoch 350 | GCN Loss: 0.0020 | NRF Loss: 0.5136 | Joint: 0.5156 | Val Acc: 0.3122
# Early stopping at epoch 355
# Best validation acc: 0.3644 @ epoch 55
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4015 | NRF Loss: 3.4012 | Joint: 6.8026 | Val Acc: 0.2039
# Epoch 050 | GCN Loss: 0.0389 | NRF Loss: 2.4309 | Joint: 2.4698 | Val Acc: 0.3550
# Epoch 100 | GCN Loss: 0.0087 | NRF Loss: 1.5617 | Joint: 1.5704 | Val Acc: 0.3439
# Epoch 150 | GCN Loss: 0.0057 | NRF Loss: 1.0765 | Joint: 1.0823 | Val Acc: 0.3233
# Epoch 200 | GCN Loss: 0.0041 | NRF Loss: 0.8231 | Joint: 0.8272 | Val Acc: 0.3150
# Epoch 250 | GCN Loss: 0.0032 | NRF Loss: 0.6761 | Joint: 0.6793 | Val Acc: 0.3111
# Epoch 300 | GCN Loss: 0.0026 | NRF Loss: 0.5828 | Joint: 0.5854 | Val Acc: 0.3078
# Early stopping at epoch 335
# Best validation acc: 0.3633 @ epoch 35
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4011 | Joint: 6.8024 | Val Acc: 0.2061
# Epoch 050 | GCN Loss: 0.0441 | NRF Loss: 2.4330 | Joint: 2.4771 | Val Acc: 0.3911
# Epoch 100 | GCN Loss: 0.0073 | NRF Loss: 1.6387 | Joint: 1.6460 | Val Acc: 0.3683
# Epoch 150 | GCN Loss: 0.0046 | NRF Loss: 1.1745 | Joint: 1.1791 | Val Acc: 0.3544
# Epoch 200 | GCN Loss: 0.0032 | NRF Loss: 0.9324 | Joint: 0.9356 | Val Acc: 0.3483
# Epoch 250 | GCN Loss: 0.0024 | NRF Loss: 0.7974 | Joint: 0.7998 | Val Acc: 0.3517
# Epoch 300 | GCN Loss: 0.0019 | NRF Loss: 0.7136 | Joint: 0.7154 | Val Acc: 0.3583
# Early stopping at epoch 334
# Best validation acc: 0.4067 @ epoch 34
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.1700
# Epoch 050 | GCN Loss: 3.1280 | NRF Loss: 3.2469 | Joint: 6.3749 | Val Acc: 0.2306
# Epoch 100 | GCN Loss: 2.5120 | NRF Loss: 3.0699 | Joint: 5.5819 | Val Acc: 0.3489
# Epoch 150 | GCN Loss: 1.7115 | NRF Loss: 2.9009 | Joint: 4.6124 | Val Acc: 0.4033
# Epoch 200 | GCN Loss: 0.9645 | NRF Loss: 2.7291 | Joint: 3.6936 | Val Acc: 0.4072
# Epoch 250 | GCN Loss: 0.4927 | NRF Loss: 2.5793 | Joint: 3.0721 | Val Acc: 0.3878
# Epoch 300 | GCN Loss: 0.2676 | NRF Loss: 2.4485 | Joint: 2.7161 | Val Acc: 0.3839
# Epoch 350 | GCN Loss: 0.1637 | NRF Loss: 2.3338 | Joint: 2.4975 | Val Acc: 0.3711
# Epoch 400 | GCN Loss: 0.1108 | NRF Loss: 2.2298 | Joint: 2.3405 | Val Acc: 0.3589
# Epoch 450 | GCN Loss: 0.0805 | NRF Loss: 2.1359 | Joint: 2.2163 | Val Acc: 0.3522
# Early stopping at epoch 485
# Best validation acc: 0.4217 @ epoch 185
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4012 | NRF Loss: 3.4012 | Joint: 6.8024 | Val Acc: 0.1733
# Epoch 050 | GCN Loss: 0.0371 | NRF Loss: 2.4774 | Joint: 2.5145 | Val Acc: 0.3694
# Epoch 100 | GCN Loss: 0.0079 | NRF Loss: 1.6536 | Joint: 1.6614 | Val Acc: 0.3467
# Epoch 150 | GCN Loss: 0.0053 | NRF Loss: 1.1687 | Joint: 1.1740 | Val Acc: 0.3322
# Epoch 200 | GCN Loss: 0.0038 | NRF Loss: 0.9091 | Joint: 0.9129 | Val Acc: 0.3300
# Epoch 250 | GCN Loss: 0.0029 | NRF Loss: 0.7604 | Joint: 0.7633 | Val Acc: 0.3256
# Epoch 300 | GCN Loss: 0.0024 | NRF Loss: 0.6636 | Joint: 0.6660 | Val Acc: 0.3244
# Early stopping at epoch 337
# Best validation acc: 0.3783 @ epoch 37
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4011 | NRF Loss: 3.4012 | Joint: 6.8023 | Val Acc: 0.1928
# Epoch 050 | GCN Loss: 0.0344 | NRF Loss: 2.4298 | Joint: 2.4642 | Val Acc: 0.3639
# Epoch 100 | GCN Loss: 0.0072 | NRF Loss: 1.5455 | Joint: 1.5527 | Val Acc: 0.3483
# Epoch 150 | GCN Loss: 0.0045 | NRF Loss: 1.0525 | Joint: 1.0570 | Val Acc: 0.3489
# Epoch 200 | GCN Loss: 0.0031 | NRF Loss: 0.8099 | Joint: 0.8130 | Val Acc: 0.3411
# Epoch 250 | GCN Loss: 0.0023 | NRF Loss: 0.6784 | Joint: 0.6807 | Val Acc: 0.3411
# Epoch 300 | GCN Loss: 0.0018 | NRF Loss: 0.5987 | Joint: 0.6005 | Val Acc: 0.3411
# Early stopping at epoch 337
# Best validation acc: 0.3939 @ epoch 37
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4023 | NRF Loss: 3.4012 | Joint: 6.8035 | Val Acc: 0.1978
# Epoch 050 | GCN Loss: 0.0356 | NRF Loss: 2.4320 | Joint: 2.4676 | Val Acc: 0.3622
# Epoch 100 | GCN Loss: 0.0079 | NRF Loss: 1.5336 | Joint: 1.5415 | Val Acc: 0.3411
# Epoch 150 | GCN Loss: 0.0054 | NRF Loss: 1.0323 | Joint: 1.0376 | Val Acc: 0.3289
# Epoch 200 | GCN Loss: 0.0039 | NRF Loss: 0.7813 | Joint: 0.7852 | Val Acc: 0.3172
# Epoch 250 | GCN Loss: 0.0030 | NRF Loss: 0.6391 | Joint: 0.6421 | Val Acc: 0.3178
# Epoch 300 | GCN Loss: 0.0024 | NRF Loss: 0.5476 | Joint: 0.5500 | Val Acc: 0.3189
# Early stopping at epoch 341
# Best validation acc: 0.3711 @ epoch 41
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4010 | NRF Loss: 3.4012 | Joint: 6.8022 | Val Acc: 0.1800
# Epoch 050 | GCN Loss: 3.1283 | NRF Loss: 3.2507 | Joint: 6.3789 | Val Acc: 0.2300
# Epoch 100 | GCN Loss: 2.5105 | NRF Loss: 3.0650 | Joint: 5.5755 | Val Acc: 0.3583
# Epoch 150 | GCN Loss: 1.7002 | NRF Loss: 2.8900 | Joint: 4.5901 | Val Acc: 0.3994
# Epoch 200 | GCN Loss: 0.9492 | NRF Loss: 2.7158 | Joint: 3.6650 | Val Acc: 0.4117
# Epoch 250 | GCN Loss: 0.4822 | NRF Loss: 2.5648 | Joint: 3.0469 | Val Acc: 0.4106
# Epoch 300 | GCN Loss: 0.2607 | NRF Loss: 2.4347 | Joint: 2.6953 | Val Acc: 0.4056
# Epoch 350 | GCN Loss: 0.1589 | NRF Loss: 2.3184 | Joint: 2.4772 | Val Acc: 0.4022
# Epoch 400 | GCN Loss: 0.1072 | NRF Loss: 2.2128 | Joint: 2.3200 | Val Acc: 0.3928
# Epoch 450 | GCN Loss: 0.0777 | NRF Loss: 2.1151 | Joint: 2.1928 | Val Acc: 0.3828
# Epoch 500 | GCN Loss: 0.0593 | NRF Loss: 2.0246 | Joint: 2.0839 | Val Acc: 0.3761
# Early stopping at epoch 521
# Best validation acc: 0.4217 @ epoch 221
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.2017
# Epoch 050 | GCN Loss: 0.0364 | NRF Loss: 2.3854 | Joint: 2.4217 | Val Acc: 0.4056
# Epoch 100 | GCN Loss: 0.0073 | NRF Loss: 1.5148 | Joint: 1.5221 | Val Acc: 0.3839
# Epoch 150 | GCN Loss: 0.0049 | NRF Loss: 1.0163 | Joint: 1.0211 | Val Acc: 0.3644
# Epoch 200 | GCN Loss: 0.0035 | NRF Loss: 0.7654 | Joint: 0.7689 | Val Acc: 0.3717
# Epoch 250 | GCN Loss: 0.0027 | NRF Loss: 0.6248 | Joint: 0.6275 | Val Acc: 0.3606
# Epoch 300 | GCN Loss: 0.0021 | NRF Loss: 0.5378 | Joint: 0.5399 | Val Acc: 0.3617
# Early stopping at epoch 333
# Best validation acc: 0.4344 @ epoch 33
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4015 | NRF Loss: 3.4012 | Joint: 6.8027 | Val Acc: 0.1739
# Epoch 050 | GCN Loss: 3.1200 | NRF Loss: 3.2507 | Joint: 6.3707 | Val Acc: 0.2239
# Epoch 100 | GCN Loss: 2.5013 | NRF Loss: 3.0653 | Joint: 5.5666 | Val Acc: 0.3283
# Epoch 150 | GCN Loss: 1.7047 | NRF Loss: 2.8936 | Joint: 4.5984 | Val Acc: 0.3633
# Epoch 200 | GCN Loss: 0.9629 | NRF Loss: 2.7223 | Joint: 3.6852 | Val Acc: 0.3811
# Epoch 250 | GCN Loss: 0.4941 | NRF Loss: 2.5717 | Joint: 3.0658 | Val Acc: 0.3750
# Epoch 300 | GCN Loss: 0.2692 | NRF Loss: 2.4419 | Joint: 2.7111 | Val Acc: 0.3694
# Epoch 350 | GCN Loss: 0.1642 | NRF Loss: 2.3273 | Joint: 2.4915 | Val Acc: 0.3589
# Epoch 400 | GCN Loss: 0.1106 | NRF Loss: 2.2233 | Joint: 2.3339 | Val Acc: 0.3544
# Epoch 450 | GCN Loss: 0.0801 | NRF Loss: 2.1276 | Joint: 2.2076 | Val Acc: 0.3450
# Early stopping at epoch 473
# Best validation acc: 0.3900 @ epoch 173
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4008 | NRF Loss: 3.4012 | Joint: 6.8020 | Val Acc: 0.1656
# Epoch 050 | GCN Loss: 3.1117 | NRF Loss: 3.2528 | Joint: 6.3645 | Val Acc: 0.2206
# Epoch 100 | GCN Loss: 2.4872 | NRF Loss: 3.0697 | Joint: 5.5569 | Val Acc: 0.3500
# Epoch 150 | GCN Loss: 1.6924 | NRF Loss: 2.8955 | Joint: 4.5879 | Val Acc: 0.4106
# Epoch 200 | GCN Loss: 0.9629 | NRF Loss: 2.7216 | Joint: 3.6845 | Val Acc: 0.4339
# Epoch 250 | GCN Loss: 0.5016 | NRF Loss: 2.5653 | Joint: 3.0669 | Val Acc: 0.4294
# Epoch 300 | GCN Loss: 0.2751 | NRF Loss: 2.4316 | Joint: 2.7067 | Val Acc: 0.4211
# Epoch 350 | GCN Loss: 0.1679 | NRF Loss: 2.3146 | Joint: 2.4825 | Val Acc: 0.4117
# Epoch 400 | GCN Loss: 0.1129 | NRF Loss: 2.2091 | Joint: 2.3220 | Val Acc: 0.4067
# Epoch 450 | GCN Loss: 0.0815 | NRF Loss: 2.1132 | Joint: 2.1947 | Val Acc: 0.4011
# Early stopping at epoch 491
# Best validation acc: 0.4350 @ epoch 191
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4008 | NRF Loss: 3.4012 | Joint: 6.8019 | Val Acc: 0.2039
# Epoch 050 | GCN Loss: 0.0399 | NRF Loss: 2.3794 | Joint: 2.4193 | Val Acc: 0.4167
# Epoch 100 | GCN Loss: 0.0080 | NRF Loss: 1.5147 | Joint: 1.5227 | Val Acc: 0.4022
# Epoch 150 | GCN Loss: 0.0052 | NRF Loss: 1.0179 | Joint: 1.0231 | Val Acc: 0.3817
# Epoch 200 | GCN Loss: 0.0037 | NRF Loss: 0.7717 | Joint: 0.7755 | Val Acc: 0.3822
# Epoch 250 | GCN Loss: 0.0028 | NRF Loss: 0.6344 | Joint: 0.6373 | Val Acc: 0.3689
# Epoch 300 | GCN Loss: 0.0023 | NRF Loss: 0.5511 | Joint: 0.5533 | Val Acc: 0.3556
# Epoch 350 | GCN Loss: 0.0019 | NRF Loss: 0.4929 | Joint: 0.4948 | Val Acc: 0.3550
# Early stopping at epoch 354
# Best validation acc: 0.4228 @ epoch 54
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4014 | NRF Loss: 3.4012 | Joint: 6.8026 | Val Acc: 0.1939
# Epoch 050 | GCN Loss: 0.0324 | NRF Loss: 2.4202 | Joint: 2.4526 | Val Acc: 0.3956
# Epoch 100 | GCN Loss: 0.0076 | NRF Loss: 1.5295 | Joint: 1.5371 | Val Acc: 0.3494
# Epoch 150 | GCN Loss: 0.0052 | NRF Loss: 1.0317 | Joint: 1.0370 | Val Acc: 0.3489
# Epoch 200 | GCN Loss: 0.0038 | NRF Loss: 0.7809 | Joint: 0.7847 | Val Acc: 0.3494
# Epoch 250 | GCN Loss: 0.0029 | NRF Loss: 0.6404 | Joint: 0.6433 | Val Acc: 0.3378
# Epoch 300 | GCN Loss: 0.0023 | NRF Loss: 0.5515 | Joint: 0.5538 | Val Acc: 0.3372
# Epoch 350 | GCN Loss: 0.0020 | NRF Loss: 0.4896 | Joint: 0.4915 | Val Acc: 0.3356
# Early stopping at epoch 351
# Best validation acc: 0.3967 @ epoch 51
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4016 | NRF Loss: 3.4012 | Joint: 6.8028 | Val Acc: 0.1017
# Epoch 050 | GCN Loss: 3.1319 | NRF Loss: 3.3299 | Joint: 6.4618 | Val Acc: 0.1950
# Epoch 100 | GCN Loss: 2.5130 | NRF Loss: 3.1565 | Joint: 5.6695 | Val Acc: 0.2606
# Epoch 150 | GCN Loss: 1.7166 | NRF Loss: 2.9727 | Joint: 4.6893 | Val Acc: 0.3383
# Epoch 200 | GCN Loss: 0.9783 | NRF Loss: 2.7872 | Joint: 3.7654 | Val Acc: 0.3483
# Epoch 250 | GCN Loss: 0.5083 | NRF Loss: 2.6145 | Joint: 3.1228 | Val Acc: 0.3422
# Epoch 300 | GCN Loss: 0.2789 | NRF Loss: 2.4651 | Joint: 2.7440 | Val Acc: 0.3356
# Epoch 350 | GCN Loss: 0.1710 | NRF Loss: 2.3359 | Joint: 2.5069 | Val Acc: 0.3400
# Epoch 400 | GCN Loss: 0.1154 | NRF Loss: 2.2225 | Joint: 2.3379 | Val Acc: 0.3500
# Epoch 450 | GCN Loss: 0.0836 | NRF Loss: 2.1218 | Joint: 2.2054 | Val Acc: 0.3472
# Early stopping at epoch 489
# Best validation acc: 0.3522 @ epoch 189
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4015 | NRF Loss: 3.4012 | Joint: 6.8027 | Val Acc: 0.2039
# Epoch 050 | GCN Loss: 3.1354 | NRF Loss: 3.2500 | Joint: 6.3854 | Val Acc: 0.2261
# Epoch 100 | GCN Loss: 2.5206 | NRF Loss: 3.0736 | Joint: 5.5941 | Val Acc: 0.3461
# Epoch 150 | GCN Loss: 1.7086 | NRF Loss: 2.8983 | Joint: 4.6069 | Val Acc: 0.4133
# Epoch 200 | GCN Loss: 0.9536 | NRF Loss: 2.7236 | Joint: 3.6772 | Val Acc: 0.4233
# Epoch 250 | GCN Loss: 0.4893 | NRF Loss: 2.5721 | Joint: 3.0615 | Val Acc: 0.4144
# Epoch 300 | GCN Loss: 0.2690 | NRF Loss: 2.4439 | Joint: 2.7128 | Val Acc: 0.4017
# Epoch 350 | GCN Loss: 0.1655 | NRF Loss: 2.3315 | Joint: 2.4970 | Val Acc: 0.3850
# Epoch 400 | GCN Loss: 0.1119 | NRF Loss: 2.2295 | Joint: 2.3414 | Val Acc: 0.3739
# Epoch 450 | GCN Loss: 0.0811 | NRF Loss: 2.1345 | Joint: 2.2156 | Val Acc: 0.3733
# Early stopping at epoch 483
# Best validation acc: 0.4278 @ epoch 183
# Evaluating on test set using full graph...
# 0.398333340883255

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd300', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.398333340883255, 'epoch': 191, 'y_pred': ['Corsican National Liberation Front (FLNC)', 'Boko Haram', 'Basque Fatherland and Freedom (ETA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'African National Congress (South Africa)', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Shabaab', 'Al-Qaida in Iraq', 'Nicaraguan Democratic Force (FDN)', 'Basque Fatherland and Freedom (ETA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Houthi extremists (Ansar Allah)', 'Maoists', 'Islamic State of Iraq and the Levant (ISIL)', 'African National Congress (South Africa)', 'Houthi extremists (Ansar Allah)', 'Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in Iraq', 'Islamic State of Iraq and the Levant (ISIL)', "Donetsk People's Republic", 'Muslim extremists', 'Muslim extremists', 'Al-Shabaab', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in Iraq', 'Al-Shabaab', 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Al-Qaida in Iraq', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Irish Republican Army (IRA)', 'Nicaraguan Democratic Force (FDN)', 'Corsican National Liberation Front (FLNC)', 'Abu Sayyaf Group (ASG)', 'Fulani extremists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Corsican National Liberation Front (FLNC)', 'Corsican National Liberation Front (FLNC)', 'Islamic State of Iraq and the Levant (ISIL)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Corsican National Liberation Front (FLNC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Muslim extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Fulani extremists', 'Corsican National Liberation Front (FLNC)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Irish Republican Army (IRA)', 'Al-Qaida in Iraq', 'Tehrik-i-Taliban Pakistan (TTP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Nicaraguan Democratic Force (FDN)', 'Fulani extremists', 'Irish Republican Army (IRA)', 'Corsican National Liberation Front (FLNC)', 'Basque Fatherland and Freedom (ETA)', 'Al-Shabaab', 'Basque Fatherland and Freedom (ETA)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in Iraq', 'Tehrik-i-Taliban Pakistan (TTP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Houthi extremists (Ansar Allah)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Abu Sayyaf Group (ASG)', 'Palestinians', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'National Liberation Army of Colombia (ELN)', 'Irish Republican Army (IRA)', 'Maoists', 'Abu Sayyaf Group (ASG)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'African National Congress (South Africa)', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Muslim extremists', 'Al-Qaida in the Arabian Peninsula (AQAP)', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Shabaab', 'Palestinians', 'Corsican National Liberation Front (FLNC)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Palestinians', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Farabundo Marti National Liberation Front (FMLN)', 'Fulani extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Abu Sayyaf Group (ASG)', 'Liber ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
