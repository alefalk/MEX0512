# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 200

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid

param_grid = {
    'lr': [0.001, 0.01],
    'n_tree': [50, 80, 100],
    'tree_depth': [8, 10, 11],
    'tree_feature_rate': [0.1, 0.3],
    'feat_dropout': [0.1, 0.0, 0.2],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 20)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 3614
# tensor(2293)
# tensor(838)
# tensor(842)
# tensor(4646)
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4011 | NRF Loss: 3.4012 | Joint: 6.8023 | Val Acc: 0.0683
# Epoch 050 | GCN Loss: 3.1375 | NRF Loss: 3.3302 | Joint: 6.4678 | Val Acc: 0.1958
# Epoch 100 | GCN Loss: 2.5062 | NRF Loss: 3.1759 | Joint: 5.6822 | Val Acc: 0.2525
# Epoch 150 | GCN Loss: 1.6812 | NRF Loss: 3.0057 | Joint: 4.6869 | Val Acc: 0.3117
# Epoch 200 | GCN Loss: 0.9264 | NRF Loss: 2.8270 | Joint: 3.7534 | Val Acc: 0.3417
# Epoch 250 | GCN Loss: 0.4686 | NRF Loss: 2.6596 | Joint: 3.1282 | Val Acc: 0.3375
# Epoch 300 | GCN Loss: 0.2553 | NRF Loss: 2.5166 | Joint: 2.7720 | Val Acc: 0.3292
# Epoch 350 | GCN Loss: 0.1564 | NRF Loss: 2.3938 | Joint: 2.5502 | Val Acc: 0.3200
# Epoch 400 | GCN Loss: 0.1052 | NRF Loss: 2.2850 | Joint: 2.3902 | Val Acc: 0.3117
# Epoch 450 | GCN Loss: 0.0760 | NRF Loss: 2.1867 | Joint: 2.2627 | Val Acc: 0.3092
# Epoch 500 | GCN Loss: 0.0578 | NRF Loss: 2.0970 | Joint: 2.1548 | Val Acc: 0.3083
# Early stopping at epoch 501
# Best validation acc: 0.3425 @ epoch 201
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4019 | NRF Loss: 3.4012 | Joint: 6.8031 | Val Acc: 0.2000
# Epoch 050 | GCN Loss: 0.0495 | NRF Loss: 2.4283 | Joint: 2.4777 | Val Acc: 0.3517
# Epoch 100 | GCN Loss: 0.0084 | NRF Loss: 1.6025 | Joint: 1.6109 | Val Acc: 0.3242
# Epoch 150 | GCN Loss: 0.0055 | NRF Loss: 1.1096 | Joint: 1.1150 | Val Acc: 0.3167
# Epoch 200 | GCN Loss: 0.0040 | NRF Loss: 0.8479 | Joint: 0.8518 | Val Acc: 0.3183
# Epoch 250 | GCN Loss: 0.0030 | NRF Loss: 0.7012 | Joint: 0.7043 | Val Acc: 0.3067
# Epoch 300 | GCN Loss: 0.0024 | NRF Loss: 0.6076 | Joint: 0.6100 | Val Acc: 0.3108
# Early stopping at epoch 337
# Best validation acc: 0.3792 @ epoch 37
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4020 | NRF Loss: 3.4012 | Joint: 6.8032 | Val Acc: 0.1883
# Epoch 050 | GCN Loss: 0.0351 | NRF Loss: 2.4527 | Joint: 2.4878 | Val Acc: 0.3417
# Epoch 100 | GCN Loss: 0.0072 | NRF Loss: 1.6059 | Joint: 1.6130 | Val Acc: 0.3250
# Epoch 150 | GCN Loss: 0.0049 | NRF Loss: 1.1162 | Joint: 1.1212 | Val Acc: 0.3192
# Epoch 200 | GCN Loss: 0.0036 | NRF Loss: 0.8636 | Joint: 0.8672 | Val Acc: 0.2975
# Epoch 250 | GCN Loss: 0.0028 | NRF Loss: 0.7208 | Joint: 0.7236 | Val Acc: 0.2925
# Epoch 300 | GCN Loss: 0.0022 | NRF Loss: 0.6299 | Joint: 0.6322 | Val Acc: 0.2950
# Early stopping at epoch 342
# Best validation acc: 0.3608 @ epoch 42
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.3999 | NRF Loss: 3.4012 | Joint: 6.8011 | Val Acc: 0.1050
# Epoch 050 | GCN Loss: 3.1293 | NRF Loss: 3.3318 | Joint: 6.4611 | Val Acc: 0.1758
# Epoch 100 | GCN Loss: 2.5147 | NRF Loss: 3.1663 | Joint: 5.6810 | Val Acc: 0.2592
# Epoch 150 | GCN Loss: 1.7254 | NRF Loss: 2.9870 | Joint: 4.7124 | Val Acc: 0.3325
# Epoch 200 | GCN Loss: 0.9943 | NRF Loss: 2.8059 | Joint: 3.8002 | Val Acc: 0.3650
# Epoch 250 | GCN Loss: 0.5251 | NRF Loss: 2.6275 | Joint: 3.1525 | Val Acc: 0.3567
# Epoch 300 | GCN Loss: 0.2920 | NRF Loss: 2.4712 | Joint: 2.7632 | Val Acc: 0.3525
# Epoch 350 | GCN Loss: 0.1801 | NRF Loss: 2.3372 | Joint: 2.5173 | Val Acc: 0.3492
# Epoch 400 | GCN Loss: 0.1214 | NRF Loss: 2.2202 | Joint: 2.3416 | Val Acc: 0.3325
# Epoch 450 | GCN Loss: 0.0874 | NRF Loss: 2.1154 | Joint: 2.2028 | Val Acc: 0.3292
# Early stopping at epoch 491
# Best validation acc: 0.3708 @ epoch 191
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4001 | NRF Loss: 3.4012 | Joint: 6.8013 | Val Acc: 0.1742
# Epoch 050 | GCN Loss: 3.1291 | NRF Loss: 3.2475 | Joint: 6.3766 | Val Acc: 0.2175
# Epoch 100 | GCN Loss: 2.5067 | NRF Loss: 3.0604 | Joint: 5.5671 | Val Acc: 0.3433
# Epoch 150 | GCN Loss: 1.6993 | NRF Loss: 2.8888 | Joint: 4.5881 | Val Acc: 0.3883
# Epoch 200 | GCN Loss: 0.9580 | NRF Loss: 2.7153 | Joint: 3.6734 | Val Acc: 0.3917
# Epoch 250 | GCN Loss: 0.4973 | NRF Loss: 2.5605 | Joint: 3.0578 | Val Acc: 0.3792
# Epoch 300 | GCN Loss: 0.2735 | NRF Loss: 2.4245 | Joint: 2.6979 | Val Acc: 0.3500
# Epoch 350 | GCN Loss: 0.1668 | NRF Loss: 2.3038 | Joint: 2.4706 | Val Acc: 0.3425
# Epoch 400 | GCN Loss: 0.1120 | NRF Loss: 2.1945 | Joint: 2.3065 | Val Acc: 0.3417
# Epoch 450 | GCN Loss: 0.0809 | NRF Loss: 2.0939 | Joint: 2.1748 | Val Acc: 0.3350
# Early stopping at epoch 487
# Best validation acc: 0.3967 @ epoch 187
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4020 | NRF Loss: 3.4012 | Joint: 6.8033 | Val Acc: 0.0358
# Epoch 050 | GCN Loss: 3.1448 | NRF Loss: 3.3332 | Joint: 6.4780 | Val Acc: 0.1867
# Epoch 100 | GCN Loss: 2.5221 | NRF Loss: 3.1813 | Joint: 5.7034 | Val Acc: 0.2550
# Epoch 150 | GCN Loss: 1.6956 | NRF Loss: 3.0193 | Joint: 4.7148 | Val Acc: 0.3283
# Epoch 200 | GCN Loss: 0.9335 | NRF Loss: 2.8504 | Joint: 3.7839 | Val Acc: 0.3575
# Epoch 250 | GCN Loss: 0.4731 | NRF Loss: 2.6837 | Joint: 3.1567 | Val Acc: 0.3458
# Epoch 300 | GCN Loss: 0.2597 | NRF Loss: 2.5356 | Joint: 2.7952 | Val Acc: 0.3358
# Epoch 350 | GCN Loss: 0.1600 | NRF Loss: 2.4092 | Joint: 2.5693 | Val Acc: 0.3258
# Epoch 400 | GCN Loss: 0.1083 | NRF Loss: 2.3002 | Joint: 2.4086 | Val Acc: 0.3283
# Epoch 450 | GCN Loss: 0.0787 | NRF Loss: 2.2023 | Joint: 2.2809 | Val Acc: 0.3258
# Early stopping at epoch 498
# Best validation acc: 0.3600 @ epoch 198
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.0442
# Epoch 050 | GCN Loss: 3.1441 | NRF Loss: 3.3316 | Joint: 6.4757 | Val Acc: 0.2025
# Epoch 100 | GCN Loss: 2.5291 | NRF Loss: 3.1775 | Joint: 5.7065 | Val Acc: 0.2550
# Epoch 150 | GCN Loss: 1.7175 | NRF Loss: 3.0095 | Joint: 4.7270 | Val Acc: 0.3125
# Epoch 200 | GCN Loss: 0.9577 | NRF Loss: 2.8300 | Joint: 3.7878 | Val Acc: 0.3183
# Epoch 250 | GCN Loss: 0.4872 | NRF Loss: 2.6591 | Joint: 3.1463 | Val Acc: 0.3117
# Epoch 300 | GCN Loss: 0.2664 | NRF Loss: 2.5149 | Joint: 2.7813 | Val Acc: 0.2992
# Epoch 350 | GCN Loss: 0.1635 | NRF Loss: 2.3921 | Joint: 2.5556 | Val Acc: 0.2975
# Epoch 400 | GCN Loss: 0.1100 | NRF Loss: 2.2842 | Joint: 2.3942 | Val Acc: 0.2917
# Epoch 450 | GCN Loss: 0.0793 | NRF Loss: 2.1875 | Joint: 2.2669 | Val Acc: 0.2958
# Early stopping at epoch 482
# Best validation acc: 0.3275 @ epoch 182
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4023 | NRF Loss: 3.4012 | Joint: 6.8035 | Val Acc: 0.1583
# Epoch 050 | GCN Loss: 0.0348 | NRF Loss: 2.4445 | Joint: 2.4793 | Val Acc: 0.3292
# Epoch 100 | GCN Loss: 0.0075 | NRF Loss: 1.6164 | Joint: 1.6239 | Val Acc: 0.3250
# Epoch 150 | GCN Loss: 0.0053 | NRF Loss: 1.1315 | Joint: 1.1368 | Val Acc: 0.3200
# Epoch 200 | GCN Loss: 0.0039 | NRF Loss: 0.8738 | Joint: 0.8777 | Val Acc: 0.3142
# Epoch 250 | GCN Loss: 0.0030 | NRF Loss: 0.7297 | Joint: 0.7327 | Val Acc: 0.3075
# Epoch 300 | GCN Loss: 0.0025 | NRF Loss: 0.6332 | Joint: 0.6357 | Val Acc: 0.3150
# Early stopping at epoch 331
# Best validation acc: 0.3508 @ epoch 31
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4004 | NRF Loss: 3.4012 | Joint: 6.8016 | Val Acc: 0.0725
# Epoch 050 | GCN Loss: 3.1396 | NRF Loss: 3.3273 | Joint: 6.4669 | Val Acc: 0.1958
# Epoch 100 | GCN Loss: 2.5254 | NRF Loss: 3.1515 | Joint: 5.6769 | Val Acc: 0.2600
# Epoch 150 | GCN Loss: 1.7213 | NRF Loss: 2.9602 | Joint: 4.6815 | Val Acc: 0.3258
# Epoch 200 | GCN Loss: 0.9721 | NRF Loss: 2.7712 | Joint: 3.7433 | Val Acc: 0.3367
# Epoch 250 | GCN Loss: 0.4982 | NRF Loss: 2.5964 | Joint: 3.0946 | Val Acc: 0.3333
# Epoch 300 | GCN Loss: 0.2713 | NRF Loss: 2.4434 | Joint: 2.7147 | Val Acc: 0.3292
# Epoch 350 | GCN Loss: 0.1656 | NRF Loss: 2.3083 | Joint: 2.4738 | Val Acc: 0.3300
# Epoch 400 | GCN Loss: 0.1114 | NRF Loss: 2.1902 | Joint: 2.3016 | Val Acc: 0.3267
# Epoch 450 | GCN Loss: 0.0806 | NRF Loss: 2.0831 | Joint: 2.1637 | Val Acc: 0.3325
# Epoch 500 | GCN Loss: 0.0614 | NRF Loss: 1.9874 | Joint: 2.0489 | Val Acc: 0.3233
# Early stopping at epoch 538
# Best validation acc: 0.3392 @ epoch 238
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4015 | NRF Loss: 3.4012 | Joint: 6.8028 | Val Acc: 0.1100
# Epoch 050 | GCN Loss: 3.1426 | NRF Loss: 3.2585 | Joint: 6.4011 | Val Acc: 0.2258
# Epoch 100 | GCN Loss: 2.5250 | NRF Loss: 3.0948 | Joint: 5.6198 | Val Acc: 0.3300
# Epoch 150 | GCN Loss: 1.7104 | NRF Loss: 2.9331 | Joint: 4.6435 | Val Acc: 0.3542
# Epoch 200 | GCN Loss: 0.9558 | NRF Loss: 2.7673 | Joint: 3.7230 | Val Acc: 0.3517
# Epoch 250 | GCN Loss: 0.4904 | NRF Loss: 2.6200 | Joint: 3.1104 | Val Acc: 0.3508
# Epoch 300 | GCN Loss: 0.2686 | NRF Loss: 2.4955 | Joint: 2.7641 | Val Acc: 0.3375
# Epoch 350 | GCN Loss: 0.1643 | NRF Loss: 2.3862 | Joint: 2.5505 | Val Acc: 0.3300
# Epoch 400 | GCN Loss: 0.1107 | NRF Loss: 2.2864 | Joint: 2.3972 | Val Acc: 0.3233
# Epoch 450 | GCN Loss: 0.0802 | NRF Loss: 2.1950 | Joint: 2.2752 | Val Acc: 0.3208
# Epoch 500 | GCN Loss: 0.0612 | NRF Loss: 2.1100 | Joint: 2.1712 | Val Acc: 0.3250
# Early stopping at epoch 518
# Best validation acc: 0.3583 @ epoch 218
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4019 | NRF Loss: 3.4012 | Joint: 6.8031 | Val Acc: 0.1950
# Epoch 050 | GCN Loss: 0.0413 | NRF Loss: 2.3738 | Joint: 2.4151 | Val Acc: 0.3958
# Epoch 100 | GCN Loss: 0.0077 | NRF Loss: 1.4997 | Joint: 1.5074 | Val Acc: 0.3708
# Epoch 150 | GCN Loss: 0.0052 | NRF Loss: 1.0036 | Joint: 1.0088 | Val Acc: 0.3608
# Epoch 200 | GCN Loss: 0.0037 | NRF Loss: 0.7530 | Joint: 0.7567 | Val Acc: 0.3525
# Epoch 250 | GCN Loss: 0.0028 | NRF Loss: 0.6150 | Joint: 0.6179 | Val Acc: 0.3458
# Epoch 300 | GCN Loss: 0.0023 | NRF Loss: 0.5299 | Joint: 0.5322 | Val Acc: 0.3442
# Early stopping at epoch 341
# Best validation acc: 0.4100 @ epoch 41
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4012 | NRF Loss: 3.4012 | Joint: 6.8024 | Val Acc: 0.2008
# Epoch 050 | GCN Loss: 0.0436 | NRF Loss: 2.3735 | Joint: 2.4171 | Val Acc: 0.3767
# Epoch 100 | GCN Loss: 0.0075 | NRF Loss: 1.5091 | Joint: 1.5166 | Val Acc: 0.3367
# Epoch 150 | GCN Loss: 0.0047 | NRF Loss: 0.9975 | Joint: 1.0023 | Val Acc: 0.3200
# Epoch 200 | GCN Loss: 0.0033 | NRF Loss: 0.7481 | Joint: 0.7514 | Val Acc: 0.3150
# Epoch 250 | GCN Loss: 0.0024 | NRF Loss: 0.6148 | Joint: 0.6172 | Val Acc: 0.3175
# Epoch 300 | GCN Loss: 0.0019 | NRF Loss: 0.5371 | Joint: 0.5390 | Val Acc: 0.3100
# Early stopping at epoch 332
# Best validation acc: 0.3933 @ epoch 32
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4031 | NRF Loss: 3.4012 | Joint: 6.8043 | Val Acc: 0.2017
# Epoch 050 | GCN Loss: 0.0395 | NRF Loss: 2.3557 | Joint: 2.3951 | Val Acc: 0.3917
# Epoch 100 | GCN Loss: 0.0073 | NRF Loss: 1.4570 | Joint: 1.4644 | Val Acc: 0.3442
# Epoch 150 | GCN Loss: 0.0049 | NRF Loss: 0.9337 | Joint: 0.9386 | Val Acc: 0.3425
# Epoch 200 | GCN Loss: 0.0035 | NRF Loss: 0.6874 | Joint: 0.6909 | Val Acc: 0.3358
# Epoch 250 | GCN Loss: 0.0027 | NRF Loss: 0.5547 | Joint: 0.5573 | Val Acc: 0.3333
# Epoch 300 | GCN Loss: 0.0021 | NRF Loss: 0.4742 | Joint: 0.4763 | Val Acc: 0.3233
# Early stopping at epoch 347
# Best validation acc: 0.3942 @ epoch 47
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4006 | NRF Loss: 3.4012 | Joint: 6.8018 | Val Acc: 0.1892
# Epoch 050 | GCN Loss: 0.0426 | NRF Loss: 2.4402 | Joint: 2.4828 | Val Acc: 0.3383
# Epoch 100 | GCN Loss: 0.0073 | NRF Loss: 1.5873 | Joint: 1.5946 | Val Acc: 0.3042
# Epoch 150 | GCN Loss: 0.0046 | NRF Loss: 1.1017 | Joint: 1.1063 | Val Acc: 0.3067
# Epoch 200 | GCN Loss: 0.0031 | NRF Loss: 0.8603 | Joint: 0.8634 | Val Acc: 0.2992
# Epoch 250 | GCN Loss: 0.0023 | NRF Loss: 0.7311 | Joint: 0.7334 | Val Acc: 0.2950
# Epoch 300 | GCN Loss: 0.0018 | NRF Loss: 0.6515 | Joint: 0.6533 | Val Acc: 0.2975
# Early stopping at epoch 329
# Best validation acc: 0.3650 @ epoch 29
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.1992
# Epoch 050 | GCN Loss: 0.0358 | NRF Loss: 2.3847 | Joint: 2.4205 | Val Acc: 0.3692
# Epoch 100 | GCN Loss: 0.0072 | NRF Loss: 1.5081 | Joint: 1.5153 | Val Acc: 0.3250
# Epoch 150 | GCN Loss: 0.0049 | NRF Loss: 0.9978 | Joint: 1.0027 | Val Acc: 0.3208
# Epoch 200 | GCN Loss: 0.0035 | NRF Loss: 0.7428 | Joint: 0.7463 | Val Acc: 0.3217
# Epoch 250 | GCN Loss: 0.0027 | NRF Loss: 0.5998 | Joint: 0.6025 | Val Acc: 0.3250
# Epoch 300 | GCN Loss: 0.0022 | NRF Loss: 0.5106 | Joint: 0.5128 | Val Acc: 0.3292
# Early stopping at epoch 337
# Best validation acc: 0.3917 @ epoch 37
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4012 | NRF Loss: 3.4012 | Joint: 6.8024 | Val Acc: 0.1967
# Epoch 050 | GCN Loss: 0.0332 | NRF Loss: 2.3992 | Joint: 2.4324 | Val Acc: 0.3425
# Epoch 100 | GCN Loss: 0.0067 | NRF Loss: 1.4972 | Joint: 1.5039 | Val Acc: 0.3242
# Epoch 150 | GCN Loss: 0.0043 | NRF Loss: 0.9958 | Joint: 1.0001 | Val Acc: 0.3183
# Epoch 200 | GCN Loss: 0.0030 | NRF Loss: 0.7529 | Joint: 0.7558 | Val Acc: 0.3108
# Epoch 250 | GCN Loss: 0.0022 | NRF Loss: 0.6232 | Joint: 0.6254 | Val Acc: 0.3100
# Epoch 300 | GCN Loss: 0.0017 | NRF Loss: 0.5487 | Joint: 0.5505 | Val Acc: 0.3117
# Early stopping at epoch 335
# Best validation acc: 0.3658 @ epoch 35
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4008 | NRF Loss: 3.4012 | Joint: 6.8019 | Val Acc: 0.1992
# Epoch 050 | GCN Loss: 0.0381 | NRF Loss: 2.3708 | Joint: 2.4089 | Val Acc: 0.3875
# Epoch 100 | GCN Loss: 0.0077 | NRF Loss: 1.4710 | Joint: 1.4787 | Val Acc: 0.3258
# Epoch 150 | GCN Loss: 0.0052 | NRF Loss: 0.9577 | Joint: 0.9629 | Val Acc: 0.3300
# Epoch 200 | GCN Loss: 0.0037 | NRF Loss: 0.7079 | Joint: 0.7117 | Val Acc: 0.3225
# Epoch 250 | GCN Loss: 0.0029 | NRF Loss: 0.5705 | Joint: 0.5734 | Val Acc: 0.3342
# Epoch 300 | GCN Loss: 0.0023 | NRF Loss: 0.4848 | Joint: 0.4871 | Val Acc: 0.3333
# Early stopping at epoch 332
# Best validation acc: 0.4008 @ epoch 32
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4005 | NRF Loss: 3.4012 | Joint: 6.8017 | Val Acc: 0.0625
# Epoch 050 | GCN Loss: 3.1329 | NRF Loss: 3.3312 | Joint: 6.4641 | Val Acc: 0.1958
# Epoch 100 | GCN Loss: 2.5100 | NRF Loss: 3.1637 | Joint: 5.6737 | Val Acc: 0.2542
# Epoch 150 | GCN Loss: 1.7001 | NRF Loss: 2.9842 | Joint: 4.6843 | Val Acc: 0.3208
# Epoch 200 | GCN Loss: 0.9545 | NRF Loss: 2.8034 | Joint: 3.7579 | Val Acc: 0.3625
# Epoch 250 | GCN Loss: 0.4930 | NRF Loss: 2.6271 | Joint: 3.1201 | Val Acc: 0.3525
# Epoch 300 | GCN Loss: 0.2731 | NRF Loss: 2.4755 | Joint: 2.7486 | Val Acc: 0.3333
# Epoch 350 | GCN Loss: 0.1691 | NRF Loss: 2.3450 | Joint: 2.5141 | Val Acc: 0.3300
# Epoch 400 | GCN Loss: 0.1143 | NRF Loss: 2.2310 | Joint: 2.3453 | Val Acc: 0.3200
# Epoch 450 | GCN Loss: 0.0825 | NRF Loss: 2.1277 | Joint: 2.2102 | Val Acc: 0.3250
# Epoch 500 | GCN Loss: 0.0626 | NRF Loss: 2.0343 | Joint: 2.0968 | Val Acc: 0.3192
# Early stopping at epoch 516
# Best validation acc: 0.3742 @ epoch 216
# Evaluating on test set using full graph...
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 11, 'tree_feature_rate': 0.3, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4017 | NRF Loss: 3.4012 | Joint: 6.8029 | Val Acc: 0.2017
# Epoch 050 | GCN Loss: 0.0433 | NRF Loss: 2.3575 | Joint: 2.4007 | Val Acc: 0.4033
# Epoch 100 | GCN Loss: 0.0074 | NRF Loss: 1.4843 | Joint: 1.4917 | Val Acc: 0.3642
# Epoch 150 | GCN Loss: 0.0047 | NRF Loss: 0.9750 | Joint: 0.9797 | Val Acc: 0.3558
# Epoch 200 | GCN Loss: 0.0033 | NRF Loss: 0.7305 | Joint: 0.7338 | Val Acc: 0.3517
# Epoch 250 | GCN Loss: 0.0024 | NRF Loss: 0.5996 | Joint: 0.6020 | Val Acc: 0.3517
# Epoch 300 | GCN Loss: 0.0019 | NRF Loss: 0.5228 | Joint: 0.5246 | Val Acc: 0.3542
# Early stopping at epoch 350
# Best validation acc: 0.4033 @ epoch 50
# Evaluating on test set using full graph...
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4015 | NRF Loss: 3.4012 | Joint: 6.8027 | Val Acc: 0.1058
# Epoch 050 | GCN Loss: 3.1428 | NRF Loss: 3.2450 | Joint: 6.3878 | Val Acc: 0.2200
# Epoch 100 | GCN Loss: 2.5218 | NRF Loss: 3.0655 | Joint: 5.5873 | Val Acc: 0.3275
# Epoch 150 | GCN Loss: 1.7155 | NRF Loss: 2.8956 | Joint: 4.6110 | Val Acc: 0.3633
# Epoch 200 | GCN Loss: 0.9695 | NRF Loss: 2.7236 | Joint: 3.6931 | Val Acc: 0.3775
# Epoch 250 | GCN Loss: 0.5022 | NRF Loss: 2.5679 | Joint: 3.0701 | Val Acc: 0.3533
# Epoch 300 | GCN Loss: 0.2761 | NRF Loss: 2.4320 | Joint: 2.7081 | Val Acc: 0.3408
# Epoch 350 | GCN Loss: 0.1686 | NRF Loss: 2.3116 | Joint: 2.4802 | Val Acc: 0.3558
# Epoch 400 | GCN Loss: 0.1130 | NRF Loss: 2.2016 | Joint: 2.3145 | Val Acc: 0.3417
# Epoch 450 | GCN Loss: 0.0814 | NRF Loss: 2.1006 | Joint: 2.1820 | Val Acc: 0.3400
# Early stopping at epoch 498
# Best validation acc: 0.3792 @ epoch 198
# Evaluating on test set using full graph...
# 0.3658333420753479

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.001, 'n_tree': 50, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd200', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.3658333420753479, 'epoch': 198, 'y_pred': ['Fulani extremists', 'Al-Shabaab', 'Sikh Extremists', 'Palestinians', 'Islamic State of Iraq and the Levant (ISIL)', 'Palestinians', 'Muslim extremists', 'Boko Haram', 'Al-Shabaab', "Kurdistan Workers' Party (PKK)", 'Sikh Extremists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Nicaraguan Democratic Force (FDN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Houthi extremists (Ansar Allah)', 'African National Congress (South Africa)', "Donetsk People's Republic", 'Tupac Amaru Revolutionary Movement (MRTA)', 'Boko Haram', 'Manuel Rodriguez Patriotic Front (FPMR)', "New People's Army (NPA)", 'Shining Path (SL)', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", 'Boko Haram', 'African National Congress (South Africa)', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Sikh Extremists', 'Maoists', "Kurdistan Workers' Party (PKK)", 'Nicaraguan Democratic Force (FDN)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Sikh Extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Shabaab', 'Corsican National Liberation Front (FLNC)', 'Nicaraguan Democratic Force (FDN)', "Donetsk People's Republic", 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Palestinians', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Maoists', 'Al-Shabaab', 'Islamic State of Iraq and the Levant (ISIL)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Manuel Rodriguez Patriotic Front (FPMR)', "New People's Army (NPA)", 'Taliban', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Boko Haram', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Muslim extremists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Nicaraguan Democratic Force (FDN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Corsican National Liberation Front (FLNC)', 'Tehrik-i-Taliban Pakistan (TTP)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Abu Sayyaf Group (ASG)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Irish Republican Army (IRA)', 'Maoists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Shabaab', "New People's Army (NPA)", 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Boko Haram', 'Corsican National Liberation Front (FLNC)', 'Sikh Extremists', 'Taliban', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Al-Qaida in Iraq', 'Corsican National Liberation Front (FLNC)', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Irish Republican Army (IRA)', 'Islamic State of Iraq and the Levant (ISIL)', "New People's Army (NPA)", 'Palestinians', 'African National Congress (South Africa)', 'Boko Haram', 'Sikh Extremists', 'Basque Fatherland and Freedom (ETA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in Iraq', 'Fulani extremists', 'Sikh Extremists', 'Palestinians', 'Maoists', "New People's Army (NPA)", 'Al-Qaida in Iraq', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Maoists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Abu Sayyaf Group (ASG)', 'Al-Shabaab', 'Al-Qaida in Iraq', 'Taliban', 'Tehrik-i-Taliban Pakistan (TTP)', 'Irish Republican Army (IRA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Fulani extremists', 'Nicaraguan Democratic Force (FDN)', 'Maoists', 'Sikh Extremists', 'Sikh Extremists', "Donetsk People's Republic", 'Corsican National Liberation Front (FLNC)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Fulani extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Islamic State of Iraq and the Levant (ISIL)', "New People's Army (NPA)", 'National Liberation Army of Colombia (ELN)', 'Manuel Rodri ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
