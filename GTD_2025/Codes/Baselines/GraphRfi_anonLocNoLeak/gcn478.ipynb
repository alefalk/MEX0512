# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 478

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
import random
# Hyperparameter grid

param_grid = {
    'lr': [0.001, 0.01],
    'n_tree': [50, 80, 100],
    'tree_depth': [8, 10, 11],
    'tree_feature_rate': [0.1, 0.3],
    'feat_dropout': [0.1, 0.0, 0.2],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())
sampled_combos = random.sample(grid_combos, 10)

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in sampled_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 1500,
            'final_evaluation': False
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 7819
# tensor(4925)
# tensor(1868)
# tensor(1884)
# tensor(11369)
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.1840
# Epoch 050 | GCN Loss: 0.0372 | NRF Loss: 2.4106 | Joint: 2.4478 | Val Acc: 0.3792
# Epoch 100 | GCN Loss: 0.0078 | NRF Loss: 1.6106 | Joint: 1.6184 | Val Acc: 0.3635
# Early stopping at epoch 135
# Best validation acc: 0.3941 @ epoch 35
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4008 | NRF Loss: 3.4012 | Joint: 6.8020 | Val Acc: 0.1993
# Epoch 050 | GCN Loss: 0.0473 | NRF Loss: 2.4294 | Joint: 2.4767 | Val Acc: 0.3771
# Epoch 100 | GCN Loss: 0.0077 | NRF Loss: 1.5620 | Joint: 1.5697 | Val Acc: 0.3517
# Early stopping at epoch 145
# Best validation acc: 0.3795 @ epoch 45
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4005 | NRF Loss: 3.4012 | Joint: 6.8017 | Val Acc: 0.1844
# Epoch 050 | GCN Loss: 0.0433 | NRF Loss: 2.4974 | Joint: 2.5407 | Val Acc: 0.3823
# Epoch 100 | GCN Loss: 0.0087 | NRF Loss: 1.7053 | Joint: 1.7140 | Val Acc: 0.3365
# Epoch 150 | GCN Loss: 0.0059 | NRF Loss: 1.2475 | Joint: 1.2534 | Val Acc: 0.3309
# Early stopping at epoch 156
# Best validation acc: 0.3826 @ epoch 56
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4009 | NRF Loss: 3.4012 | Joint: 6.8021 | Val Acc: 0.0660
# Epoch 050 | GCN Loss: 3.1049 | NRF Loss: 3.3355 | Joint: 6.4403 | Val Acc: 0.1799
# Epoch 100 | GCN Loss: 2.4801 | NRF Loss: 3.1895 | Joint: 5.6696 | Val Acc: 0.2344
# Epoch 150 | GCN Loss: 1.6754 | NRF Loss: 3.0216 | Joint: 4.6971 | Val Acc: 0.3177
# Epoch 200 | GCN Loss: 0.9382 | NRF Loss: 2.8479 | Joint: 3.7861 | Val Acc: 0.3583
# Epoch 250 | GCN Loss: 0.4827 | NRF Loss: 2.6860 | Joint: 3.1688 | Val Acc: 0.3653
# Epoch 300 | GCN Loss: 0.2659 | NRF Loss: 2.5507 | Joint: 2.8166 | Val Acc: 0.3698
# Epoch 350 | GCN Loss: 0.1640 | NRF Loss: 2.4374 | Joint: 2.6014 | Val Acc: 0.3715
# Epoch 400 | GCN Loss: 0.1112 | NRF Loss: 2.3372 | Joint: 2.4484 | Val Acc: 0.3674
# Early stopping at epoch 420
# Best validation acc: 0.3740 @ epoch 320
# Running config: {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4014 | NRF Loss: 3.4012 | Joint: 6.8026 | Val Acc: 0.0872
# Epoch 050 | GCN Loss: 3.1179 | NRF Loss: 3.3339 | Joint: 6.4518 | Val Acc: 0.1910
# Epoch 100 | GCN Loss: 2.5002 | NRF Loss: 3.1660 | Joint: 5.6662 | Val Acc: 0.2556
# Epoch 150 | GCN Loss: 1.6923 | NRF Loss: 2.9824 | Joint: 4.6747 | Val Acc: 0.3208
# Epoch 200 | GCN Loss: 0.9449 | NRF Loss: 2.8067 | Joint: 3.7516 | Val Acc: 0.3271
# Epoch 250 | GCN Loss: 0.4847 | NRF Loss: 2.6460 | Joint: 3.1307 | Val Acc: 0.3399
# Epoch 300 | GCN Loss: 0.2670 | NRF Loss: 2.5094 | Joint: 2.7763 | Val Acc: 0.3500
# Epoch 350 | GCN Loss: 0.1644 | NRF Loss: 2.3935 | Joint: 2.5579 | Val Acc: 0.3486
# Early stopping at epoch 395
# Best validation acc: 0.3503 @ epoch 295
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 8, 'tree_feature_rate': 0.3, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4013 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.0594
# Epoch 050 | GCN Loss: 3.1135 | NRF Loss: 3.2636 | Joint: 6.3771 | Val Acc: 0.2108
# Epoch 100 | GCN Loss: 2.4946 | NRF Loss: 3.1008 | Joint: 5.5954 | Val Acc: 0.3417
# Epoch 150 | GCN Loss: 1.6893 | NRF Loss: 2.9343 | Joint: 4.6237 | Val Acc: 0.3819
# Epoch 200 | GCN Loss: 0.9466 | NRF Loss: 2.7751 | Joint: 3.7216 | Val Acc: 0.3663
# Epoch 250 | GCN Loss: 0.4892 | NRF Loss: 2.6418 | Joint: 3.1310 | Val Acc: 0.3625
# Early stopping at epoch 259
# Best validation acc: 0.3861 @ epoch 159
# Running config: {'lr': 0.001, 'n_tree': 50, 'tree_depth': 11, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4011 | NRF Loss: 3.4012 | Joint: 6.8023 | Val Acc: 0.0788
# Epoch 050 | GCN Loss: 3.0987 | NRF Loss: 3.3306 | Joint: 6.4293 | Val Acc: 0.1792
# Epoch 100 | GCN Loss: 2.4732 | NRF Loss: 3.1620 | Joint: 5.6352 | Val Acc: 0.2549
# Epoch 150 | GCN Loss: 1.6743 | NRF Loss: 2.9792 | Joint: 4.6535 | Val Acc: 0.3399
# Epoch 200 | GCN Loss: 0.9419 | NRF Loss: 2.7935 | Joint: 3.7354 | Val Acc: 0.3455
# Epoch 250 | GCN Loss: 0.4921 | NRF Loss: 2.6235 | Joint: 3.1156 | Val Acc: 0.3455
# Early stopping at epoch 272
# Best validation acc: 0.3486 @ epoch 172
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4018 | NRF Loss: 3.4012 | Joint: 6.8030 | Val Acc: 0.1851
# Epoch 050 | GCN Loss: 0.0436 | NRF Loss: 2.4193 | Joint: 2.4629 | Val Acc: 0.3854
# Epoch 100 | GCN Loss: 0.0081 | NRF Loss: 1.6101 | Joint: 1.6181 | Val Acc: 0.3681
# Early stopping at epoch 135
# Best validation acc: 0.4149 @ epoch 35
# Running config: {'lr': 0.01, 'n_tree': 100, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4014 | NRF Loss: 3.4012 | Joint: 6.8026 | Val Acc: 0.1903
# Epoch 050 | GCN Loss: 0.0352 | NRF Loss: 2.4918 | Joint: 2.5269 | Val Acc: 0.3448
# Epoch 100 | GCN Loss: 0.0076 | NRF Loss: 1.6989 | Joint: 1.7065 | Val Acc: 0.3278
# Early stopping at epoch 134
# Best validation acc: 0.3740 @ epoch 34
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 10, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}
# Epoch 000 | GCN Loss: 3.4005 | NRF Loss: 3.4012 | Joint: 6.8017 | Val Acc: 0.1882
# Epoch 050 | GCN Loss: 0.0443 | NRF Loss: 2.4426 | Joint: 2.4869 | Val Acc: 0.3656
# Epoch 100 | GCN Loss: 0.0081 | NRF Loss: 1.6027 | Joint: 1.6108 | Val Acc: 0.3247
# Early stopping at epoch 134
# Best validation acc: 0.3681 @ epoch 34
# 0.4149305522441864

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.3, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd478', 'n_class': 30, 'epochs': 1500, 'final_evaluation': False}, 'acc': 0.4149305522441864, 'epoch': 35, 'y_pred': ['Tupac Amaru Revolutionary Movement (MRTA)', 'Manuel Rodriguez Patriotic Front (FPMR)', "Donetsk People's Republic", 'African National Congress (South Africa)', 'African National Congress (South Africa)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Irish Republican Army (IRA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'Irish Republican Army (IRA)', "Donetsk People's Republic", 'Al-Qaida in Iraq', "New People's Army (NPA)", 'Tehrik-i-Taliban Pakistan (TTP)', 'Sikh Extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'African National Congress (South Africa)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'African National Congress (South Africa)', 'Al-Shabaab', 'National Liberation Army of Colombia (ELN)', 'Farabundo Marti National Liberation Front (FMLN)', 'Shining Path (SL)', 'Revolutionary Armed Forces of Colombia (FARC)', 'African National Congress (South Africa)', 'Communist Party of India - Maoist (CPI-Maoist)', 'National Liberation Army of Colombia (ELN)', 'Basque Fatherland and Freedom (ETA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', 'Nicaraguan Democratic Force (FDN)', 'National Liberation Army of Colombia (ELN)', 'Al-Shabaab', 'Al-Qaida in Iraq', 'Shining Path (SL)', 'National Liberation Army of Colombia (ELN)', 'Shining Path (SL)', "Donetsk People's Republic", "Donetsk People's Republic", "Donetsk People's Republic", 'Houthi extremists (Ansar Allah)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Palestinians', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', "Donetsk People's Republic", 'Nicaraguan Democratic Force (FDN)', 'African National Congress (South Africa)', 'Tupac Amaru Revolutionary Movement (MRTA)', "Donetsk People's Republic", 'Al-Qaida in Iraq', 'Revolutionary Armed Forces of Colombia (FARC)', 'Basque Fatherland and Freedom (ETA)', 'African National Congress (South Africa)', 'Palestinians', 'Taliban', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Islamic State of Iraq and the Levant (ISIL)', 'Corsican National Liberation Front (FLNC)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Abu Sayyaf Group (ASG)', 'Al-Qaida in Iraq', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Shabaab', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Islamic State of Iraq and the Levant (ISIL)', 'Abu Sayyaf Group (ASG)', 'National Liberation Army of Colombia (ELN)', 'African National Congress (South Africa)', 'Nicaraguan Democratic Force (FDN)', 'Fulani extremists', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Palestinians', 'Tehrik-i-Taliban Pakistan (TTP)', 'Abu Sayyaf Group (ASG)', 'Boko Haram', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Maoists', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Nicaraguan Democratic Force (FDN)', 'Taliban', 'Sikh Extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Houthi extremists (Ansar Allah)', 'Basque Fatherland and Freedom (ETA)', 'Fulani extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Abu Sayyaf Group (ASG)', 'Maoists', "Donetsk People's Republic", 'Boko Haram', 'Tehrik-i-Taliban Pakistan (TTP)', 'Fulani extremists', 'Nicaraguan Democratic Force (FDN)', 'Shining Path (SL)', 'Palestinians', 'National Liberation Army of Colombia (ELN)', 'Houthi extremists (Ansar Allah)', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', "Kurdistan Workers' Party (PKK)", 'African National Congress (South Africa)', 'Tehrik-i-Tali ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
