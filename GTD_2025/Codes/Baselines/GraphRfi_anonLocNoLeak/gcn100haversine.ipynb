# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/anonLoc/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid

param_grid = {
    'lr': [0.01],
    'n_tree': [80],
    'tree_depth': [8],
    'tree_feature_rate': [0.1],
    'feat_dropout': [0.2],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 1943
# tensor(1220)
# tensor(463)
# tensor(466)
# tensor(2249)
# Running config: {'lr': 0.01, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4024 | NRF Loss: 3.4012 | Joint: 6.8036 | Val Acc: 0.1850
# Epoch 050 | GCN Loss: 0.0465 | NRF Loss: 2.4546 | Joint: 2.5010 | Val Acc: 0.3100
# Epoch 100 | GCN Loss: 0.0079 | NRF Loss: 1.5473 | Joint: 1.5553 | Val Acc: 0.3067
# Epoch 150 | GCN Loss: 0.0054 | NRF Loss: 1.0291 | Joint: 1.0346 | Val Acc: 0.3033
# Epoch 200 | GCN Loss: 0.0040 | NRF Loss: 0.7654 | Joint: 0.7693 | Val Acc: 0.2983
# Epoch 250 | GCN Loss: 0.0031 | NRF Loss: 0.6195 | Joint: 0.6226 | Val Acc: 0.2933
# Epoch 300 | GCN Loss: 0.0025 | NRF Loss: 0.5281 | Joint: 0.5306 | Val Acc: 0.2750
# Epoch 350 | GCN Loss: 0.0020 | NRF Loss: 0.4655 | Joint: 0.4675 | Val Acc: 0.2700
# Epoch 400 | GCN Loss: 0.0017 | NRF Loss: 0.4187 | Joint: 0.4204 | Val Acc: 0.2700
# Epoch 450 | GCN Loss: 0.0015 | NRF Loss: 0.3829 | Joint: 0.3844 | Val Acc: 0.2683
# Epoch 500 | GCN Loss: 0.0013 | NRF Loss: 0.3525 | Joint: 0.3538 | Val Acc: 0.2650
# Early stopping at epoch 546
# Best validation acc: 0.3200 @ epoch 46
# Evaluating on test set using full graph...
# 0.24666666984558105

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 80, 'tree_depth': 8, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.24666666984558105, 'epoch': 46, 'y_pred': ['Tehrik-i-Taliban Pakistan (TTP)', "Kurdistan Workers' Party (PKK)", 'Shining Path (SL)', 'Fulani extremists', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'African National Congress (South Africa)', 'Houthi extremists (Ansar Allah)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Sikh Extremists', 'Boko Haram', 'Maoists', 'Boko Haram', 'Al-Shabaab', 'Irish Republican Army (IRA)', 'Irish Republican Army (IRA)', 'Boko Haram', 'Shining Path (SL)', 'Irish Republican Army (IRA)', 'Maoists', 'Irish Republican Army (IRA)', 'Maoists', 'Maoists', 'Irish Republican Army (IRA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Corsican National Liberation Front (FLNC)', "New People's Army (NPA)", 'Nicaraguan Democratic Force (FDN)', 'Houthi extremists (Ansar Allah)', 'Farabundo Marti National Liberation Front (FMLN)', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in Iraq', 'African National Congress (South Africa)', 'Houthi extremists (Ansar Allah)', 'Boko Haram', 'Nicaraguan Democratic Force (FDN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Maoists', 'Shining Path (SL)', 'Corsican National Liberation Front (FLNC)', 'Islamic State of Iraq and the Levant (ISIL)', "Kurdistan Workers' Party (PKK)", 'Sikh Extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Shining Path (SL)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Houthi extremists (Ansar Allah)', 'Manuel Rodriguez Patriotic Front (FPMR)', "New People's Army (NPA)", 'Nicaraguan Democratic Force (FDN)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Fulani extremists', 'Muslim extremists', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Fulani extremists', 'Taliban', 'Irish Republican Army (IRA)', 'National Liberation Army of Colombia (ELN)', "Donetsk People's Republic", 'Maoists', 'Irish Republican Army (IRA)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Nicaraguan Democratic Force (FDN)', 'Manuel Rodriguez Patriotic Front (FPMR)', 'Maoists', 'Basque Fatherland and Freedom (ETA)', 'Basque Fatherland and Freedom (ETA)', 'Shining Path (SL)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Tehrik-i-Taliban Pakistan (TTP)', 'Abu Sayyaf Group (ASG)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Boko Haram', 'Taliban', 'Fulani extremists', 'Basque Fatherland and Freedom (ETA)', 'Shining Path (SL)', 'Shining Path (SL)', 'Irish Republican Army (IRA)', 'Maoists', 'Maoists', "Donetsk People's Republic", 'Irish Republican Army (IRA)', 'Basque Fatherland and Freedom (ETA)', 'Maoists', 'Maoists', 'Sikh Extremists', 'Tehrik-i-Taliban Pakistan (TTP)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in Iraq', 'Fulani extremists', 'Revolutionary Armed Forces of Colombia (FARC)', "New People's Army (NPA)", "Donetsk People's Republic", 'Taliban', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Islamic State of Iraq and the Levant (ISIL)', 'African National Congress (South Africa)', 'Houthi extremists (Ansar Allah)', 'Shining Path (SL)', 'Taliban', 'Al-Qaida in Iraq', 'Boko Haram', 'Fulani extremists', 'Houthi extremists (Ansar Allah)', 'Fulani extremists', 'Irish Republican Army (IRA)', "Donetsk People's Republic", 'Irish Republican Army (IRA)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Muslim extremists', "New People's Army (NPA)", 'Maoists', 'Maoists', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in Iraq', 'Manuel Rodriguez Patriotic Front (FPMR)', "Donetsk People's Republic", 'Shining Path (SL)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Al-Qaida in Iraq', 'Maoists', 'Shining Path (SL)', 'Houthi extremists (Ansar Allah)', "New People's Army (NPA)", "Do ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
