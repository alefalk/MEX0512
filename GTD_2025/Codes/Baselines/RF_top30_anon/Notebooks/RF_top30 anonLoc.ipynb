# %%
import sys
import os

sys.path.append(os.path.abspath("../Classifiers"))

from RF import *

# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,  f1_score, precision_score, recall_score

# %%
feature_type = "anonLoc"

# %%
if not os.path.isdir("Results"):
    os.mkdir("Results")
if not os.path.isdir(f"Results/{feature_type}"):
    os.mkdir(f"Results/{feature_type}")

# %% [markdown]
# ### Paths to top30 from GTD data

# %%
trains = ['train100', 'train200', 'train300', 'train478']
tests = ['test100', 'test200', 'test300', 'test478', ]
traindir = f'../../../../data/top30groups/{feature_type}/train1'
testdir = f'../../../../data/top30groups/{feature_type}/test1'

trainpaths = []
testpaths = []
for i, partition in enumerate(trains):
    trainpaths.append(f'{traindir}/{partition}.csv')
    testpaths.append(f'{testdir}/{tests[i]}.csv')

# %%
df = pd.read_csv(trainpaths[0])

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1', 'nkill', 'property',
#        'ishostkid', 'encodedlonglat', 'gname'],
#       dtype='object')

# %%
df["encodedlonglat"].nunique()
# Out:
# 1304

# %% [markdown]
# ### Training models and computing accuracy

# %%
models = []
accuracies = []
predictions = []
truths = []
probas = []
n = [100, 200, 300, 478]
train_times = []
for i, path in enumerate(trainpaths):
    print(f'Computing for partition {i+1}, balanced classes with {n[i]} entries for each class')
    dftrain = pd.read_csv(trainpaths[i])
    dftest = pd.read_csv(testpaths[i])
    print("unique train locs: ", dftrain["encodedlonglat"].nunique())
    print("unique test locs: ", dftest["encodedlonglat"].nunique())
    
    # run classifier on data
    rfc, accuracy, y_pred_rfc, labels, proba, train_time = main(trainpaths[i], testpaths[i])

    #  saving models, accuracies, predictions, and truths in case we need it for statistics later
    models.append(rfc)
    accuracies.append(accuracy)
    predictions.append(y_pred_rfc)
    truths.append(labels)
    probas.append(proba)
    train_times.append(train_time)
    print("---------------------------------------------------")
# Out:
# Computing for partition 1, balanced classes with 100 entries for each class
# unique train locs:  1304
# unique test locs:  667
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 53.00%
# ---------------------------------------------------
# Computing for partition 2, balanced classes with 200 entries for each class
# unique train locs:  2361
# unique test locs:  1183
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 57.17%
# ---------------------------------------------------
# Computing for partition 3, balanced classes with 300 entries for each class
# unique train locs:  3283
# unique test locs:  1633
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 50.56%
# ---------------------------------------------------
# Computing for partition 4, balanced classes with 478 entries for each class
# unique train locs:  4765
# unique test locs:  2411
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 55.02%
# ---------------------------------------------------

# %%
for i in range(len(truths)):
    print(f'Classification report size {n[i]}')
    print(classification_report(predictions[i], truths[i]))
    print('--------------------------------------')
# Out:
# Classification report size 100
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.33      0.36      0.34        28
#         African National Congress (South Africa)       0.80      0.52      0.63        46
#                                 Al-Qaida in Iraq       0.53      0.47      0.50        34
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.37      0.37      0.37        30
#                                       Al-Shabaab       0.47      0.47      0.47        30
#              Basque Fatherland and Freedom (ETA)       0.53      0.64      0.58        25
#                                       Boko Haram       0.30      0.32      0.31        28
#   Communist Party of India - Maoist (CPI-Maoist)       0.57      0.47      0.52        36
#        Corsican National Liberation Front (FLNC)       0.83      0.60      0.69        42
#                        Donetsk People's Republic       0.63      0.54      0.58        35
# Farabundo Marti National Liberation Front (FMLN)       0.73      0.54      0.62        41
#                                Fulani extremists       0.73      0.47      0.57        47
#                  Houthi extremists (Ansar Allah)       0.53      0.67      0.59        24
#                      Irish Republican Army (IRA)       0.63      0.73      0.68        26
#      Islamic State of Iraq and the Levant (ISIL)       0.33      0.45      0.38        22
#                   Kurdistan Workers' Party (PKK)       0.23      0.41      0.30        17
#          Liberation Tigers of Tamil Eelam (LTTE)       0.50      0.56      0.53        27
#          Manuel Rodriguez Patriotic Front (FPMR)       0.83      0.64      0.72        39
#                                          Maoists       0.33      0.43      0.38        23
#                                Muslim extremists       0.17      0.45      0.24        11
#       National Liberation Army of Colombia (ELN)       0.67      0.61      0.63        33
#                          New People's Army (NPA)       0.63      0.54      0.58        35
#                Nicaraguan Democratic Force (FDN)       0.67      0.57      0.62        35
#                                     Palestinians       0.60      0.67      0.63        27
#    Revolutionary Armed Forces of Colombia (FARC)       0.47      0.54      0.50        26
#                                Shining Path (SL)       0.40      0.57      0.47        21
#                                  Sikh Extremists       0.57      0.50      0.53        34
#                                          Taliban       0.27      0.36      0.31        22
#                  Tehrik-i-Taliban Pakistan (TTP)       0.47      0.52      0.49        27
#        Tupac Amaru Revolutionary Movement (MRTA)       0.77      0.79      0.78        29
#
#                                         accuracy                           0.53       900
#                                        macro avg       0.53      0.53      0.52       900
#                                     weighted avg       0.57      0.53      0.54       900
#
# --------------------------------------
# Classification report size 200
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.45      0.45      0.45        60
#         African National Congress (South Africa)       0.80      0.49      0.61        97
#                                 Al-Qaida in Iraq       0.67      0.48      0.56        84
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.28      0.33      0.31        51
#                                       Al-Shabaab       0.47      0.39      0.43        71
#              Basque Fatherland and Freedom (ETA)       0.50      0.60      0.55        50
#                                       Boko Haram       0.32      0.45      0.37        42
#   Communist Party of India - Maoist (CPI-Maoist)       0.65      0.61      0.63        64
#        Corsican National Liberation Front (FLNC)       0.88      0.50      0.64       105
#                        Donetsk People's Republic       0.70      0.59      0.64        71
# Farabundo Marti National Liberation Front (FMLN)       0.73      0.62      0.67        71
#                                Fulani extremists       0.82      0.57      0.67        86
#                  Houthi extremists (Ansar Allah)       0.47      0.52      0.49        54
#                      Irish Republican Army (IRA)       0.77      0.74      0.75        62
#      Islamic State of Iraq and the Levant (ISIL)       0.32      0.46      0.38        41
#                   Kurdistan Workers' Party (PKK)       0.23      0.33      0.27        42
#          Liberation Tigers of Tamil Eelam (LTTE)       0.62      0.62      0.62        60
#          Manuel Rodriguez Patriotic Front (FPMR)       0.82      0.84      0.83        58
#                                          Maoists       0.55      0.54      0.55        61
#                                Muslim extremists       0.33      0.48      0.39        42
#       National Liberation Army of Colombia (ELN)       0.55      0.75      0.63        44
#                          New People's Army (NPA)       0.43      0.54      0.48        48
#                Nicaraguan Democratic Force (FDN)       0.85      0.60      0.70        85
#                                     Palestinians       0.68      0.82      0.75        50
#    Revolutionary Armed Forces of Colombia (FARC)       0.50      0.61      0.55        49
#                                Shining Path (SL)       0.43      0.59      0.50        44
#                                  Sikh Extremists       0.72      0.68      0.70        63
#                                          Taliban       0.20      0.44      0.28        27
#                  Tehrik-i-Taliban Pakistan (TTP)       0.67      0.65      0.66        62
#        Tupac Amaru Revolutionary Movement (MRTA)       0.75      0.80      0.78        56
#
#                                         accuracy                           0.57      1800
#                                        macro avg       0.57      0.57      0.56      1800
#                                     weighted avg       0.62      0.57      0.58      1800
#
# --------------------------------------
# Classification report size 300
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.34      0.46      0.39        68
#         African National Congress (South Africa)       0.84      0.32      0.46       237
#                                 Al-Qaida in Iraq       0.71      0.51      0.60       125
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.27      0.29      0.28        82
#                                       Al-Shabaab       0.34      0.35      0.35        89
#              Basque Fatherland and Freedom (ETA)       0.56      0.59      0.57        85
#                                       Boko Haram       0.23      0.44      0.30        48
#   Communist Party of India - Maoist (CPI-Maoist)       0.71      0.59      0.64       109
#        Corsican National Liberation Front (FLNC)       0.87      0.44      0.58       178
#                        Donetsk People's Republic       0.59      0.48      0.53       111
# Farabundo Marti National Liberation Front (FMLN)       0.49      0.44      0.46       100
#                                Fulani extremists       0.82      0.57      0.68       129
#                  Houthi extremists (Ansar Allah)       0.48      0.46      0.47        93
#                      Irish Republican Army (IRA)       0.74      0.63      0.68       107
#      Islamic State of Iraq and the Levant (ISIL)       0.31      0.38      0.34        74
#                   Kurdistan Workers' Party (PKK)       0.13      0.29      0.18        41
#          Liberation Tigers of Tamil Eelam (LTTE)       0.46      0.64      0.53        64
#          Manuel Rodriguez Patriotic Front (FPMR)       0.63      0.69      0.66        83
#                                          Maoists       0.44      0.51      0.48        78
#                                Muslim extremists       0.14      0.72      0.24        18
#       National Liberation Army of Colombia (ELN)       0.47      0.65      0.54        65
#                          New People's Army (NPA)       0.48      0.62      0.54        69
#                Nicaraguan Democratic Force (FDN)       0.71      0.37      0.49       171
#                                     Palestinians       0.62      0.66      0.64        85
#    Revolutionary Armed Forces of Colombia (FARC)       0.43      0.68      0.53        57
#                                Shining Path (SL)       0.24      0.51      0.33        43
#                                  Sikh Extremists       0.64      0.60      0.62        97
#                                          Taliban       0.20      0.67      0.31        27
#                  Tehrik-i-Taliban Pakistan (TTP)       0.43      0.57      0.49        68
#        Tupac Amaru Revolutionary Movement (MRTA)       0.81      0.74      0.77        99
#
#                                         accuracy                           0.51      2700
#                                        macro avg       0.51      0.53      0.49      2700
#                                     weighted avg       0.59      0.51      0.52      2700
#
# --------------------------------------
# Classification report size 478
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.42      0.61      0.50       100
#         African National Congress (South Africa)       0.69      0.43      0.53       234
#                                 Al-Qaida in Iraq       0.65      0.54      0.59       171
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.31      0.37      0.34       123
#                                       Al-Shabaab       0.33      0.36      0.34       135
#              Basque Fatherland and Freedom (ETA)       0.63      0.55      0.59       165
#                                       Boko Haram       0.27      0.42      0.33        92
#   Communist Party of India - Maoist (CPI-Maoist)       0.53      0.45      0.49       171
#        Corsican National Liberation Front (FLNC)       0.89      0.47      0.62       272
#                        Donetsk People's Republic       0.76      0.54      0.63       202
# Farabundo Marti National Liberation Front (FMLN)       0.62      0.59      0.61       152
#                                Fulani extremists       0.85      0.61      0.72       200
#                  Houthi extremists (Ansar Allah)       0.51      0.48      0.49       153
#                      Irish Republican Army (IRA)       0.81      0.62      0.70       189
#      Islamic State of Iraq and the Levant (ISIL)       0.24      0.42      0.30        80
#                   Kurdistan Workers' Party (PKK)       0.17      0.55      0.26        44
#          Liberation Tigers of Tamil Eelam (LTTE)       0.51      0.55      0.53       134
#          Manuel Rodriguez Patriotic Front (FPMR)       0.81      0.67      0.74       174
#                                          Maoists       0.49      0.45      0.47       156
#                                Muslim extremists       0.24      0.50      0.32        68
#       National Liberation Army of Colombia (ELN)       0.45      0.61      0.52       107
#                          New People's Army (NPA)       0.61      0.68      0.64       129
#                Nicaraguan Democratic Force (FDN)       0.81      0.50      0.62       233
#                                     Palestinians       0.60      0.80      0.68       108
#    Revolutionary Armed Forces of Colombia (FARC)       0.56      0.70      0.62       116
#                                Shining Path (SL)       0.38      0.64      0.48        86
#                                  Sikh Extremists       0.65      0.65      0.65       144
#                                          Taliban       0.33      0.47      0.39       100
#                  Tehrik-i-Taliban Pakistan (TTP)       0.50      0.69      0.58       104
#        Tupac Amaru Revolutionary Movement (MRTA)       0.88      0.71      0.79       178
#
#                                         accuracy                           0.55      4320
#                                        macro avg       0.55      0.55      0.53      4320
#                                     weighted avg       0.61      0.55      0.57      4320
#
# --------------------------------------

# %%
from sklearn.metrics import roc_auc_score

with open(f"Results/{feature_type}/rf_top30_{feature_type}.txt", "w") as f:
    for i in range(len(trainpaths)):
        f.write(f"Partition {i+1} - {n[i]} samples per class, with longitude and latitude data\n")
        f.write(f"Accuracy: {accuracies[i]*100:.2f}%\n")
        f.write(f"Precision Score weighted: {precision_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"recall Score weighted: {recall_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"f1 Score weighted: {f1_score(truths[i], predictions[i], average='weighted')}\n")
        f.write(f"Precision Score micro: {precision_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"recall Score micro: {recall_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"f1 Score micro: {f1_score(truths[i], predictions[i], average='micro')}\n")
        f.write(f"Precision Score macro: {precision_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"recall Score macro: {recall_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"f1 Score macro: {f1_score(truths[i], predictions[i], average='macro')}\n")
        f.write(f"roc auc weighted: {roc_auc_score(truths[i], probas[i],multi_class='ovr', average='weighted'):.4f}\n")
        f.write(f"roc auc macro: {roc_auc_score(truths[i], probas[i], multi_class='ovr', average='macro'):.4f}\n")
        f.write(f"roc auc micro: {roc_auc_score(truths[i], probas[i], multi_class='ovr', average='micro'):.4f}\n")
        f.write("---------------------------------------------------\n")

for partition in n:
    with open(f"Results/{feature_type}/traintimes_gtd{partition}.txt", "w") as f:
        f.write(str(train_times[i]))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition_id):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition {partition_id})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results/{feature_type}/confusion_matrix_partition_{partition_id}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition_id} to {save_path}")

# %%
for i in range(len(truths)):
    y_true = truths[i]
    y_pred = predictions[i]

    # Get all unique class labels from the truths
    class_labels = np.unique(np.concatenate(truths))

    plot_confusion_matrix(y_true, y_pred, labels=class_labels, partition_id=i + 1)

# Combined
all_true = np.concatenate(truths)
all_pred = np.concatenate(predictions)
all_labels = np.unique(all_true)

plot_confusion_matrix(all_true, all_pred, labels=all_labels, partition_id="All")
# Out:
# Saved confusion matrix for partition 1 to Results/anonLoc/confusion_matrix_partition_1.png
# Saved confusion matrix for partition 2 to Results/anonLoc/confusion_matrix_partition_2.png
# Saved confusion matrix for partition 3 to Results/anonLoc/confusion_matrix_partition_3.png
# Saved confusion matrix for partition 4 to Results/anonLoc/confusion_matrix_partition_4.png
# Saved confusion matrix for partition All to Results/anonLoc/confusion_matrix_partition_All.png

# %%
top_k = 20

for i, rfc in enumerate(models):
    importances = rfc.feature_importances_

    feature_names = rfc.feature_names_in_

    indices = np.argsort(importances)[::-1][:top_k]
    top_features = [feature_names[j] for j in indices]
    top_importances = importances[indices]

    plt.figure(figsize=(8, 4))
    plt.barh(top_features[::-1], top_importances[::-1])
    plt.xlabel("Importance")
    plt.title(f"Top {top_k} Feature Importances - Partition {i+1}, classes with {n[i]} entries")
    plt.tight_layout()
    plt.show()
