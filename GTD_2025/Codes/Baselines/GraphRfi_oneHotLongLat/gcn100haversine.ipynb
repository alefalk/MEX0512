# %% [markdown]
# # Import and Read data

# %%
import sys
sys.path.append('.')  # Add current directory to path
from haversine_build_graph_and_train import *
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
partition = 100

# %%
df = pd.read_csv(f"../../../data/top30groups/OneHotLongLatCombined/combined/combined{partition}.csv")

# %%
from sklearn.preprocessing import StandardScaler

# Columns to exclude from scaling
exclude_cols = ['gname']

# Columns to scale
scale_cols = [col for col in df.columns if col not in exclude_cols]

# Scale only selected columns
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
import os 
if not os.path.isdir(f"Results{partition}"):
    os.mkdir(f"Results{partition}")

# %% [markdown]
# # Create longlat feature

# %%
#geodata = ['longitude', 'latitude']
#combined_geo = df.copy()
#combined_geo['longlat'] = list(zip(df['longitude'], df['latitude']))
#combined_geo = combined_geo.drop(columns=geodata)

# %%
#import ast

#def to_tuple_if_needed(val):
#    if isinstance(val, str):
#        return ast.literal_eval(val)
#    return val  # already a tuple

#combined_geo['longlat'] = combined_geo['longlat'].apply(to_tuple_if_needed)

# %% [markdown]
# # Weapon type prediction

# %%
torch.cuda.empty_cache()

# %%
#label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}

#full_coords, data, edge_index_full, y_gcn, y_nrf, non_geo_features, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(
#        combined_geo, label_index, continuous_col='weaptype1')

# %%
df.columns
# Out:
# Index(['extended', 'vicinity', 'multiple', 'success', 'suicide', 'attacktype1',
#        'targtype1', 'target1', 'individual', 'weaptype1',
#        ...
#        'longlat_(126.036107, 8.866664)', 'longlat_(126.055367, 7.823071)',
#        'longlat_(126.187778, 8.941944)', 'longlat_(126.23167, 9.02111)',
#        'longlat_(126.255202, 8.280488)', 'longlat_(126.300309, 8.892579)',
#        'longlat_(126.30035, 8.801867)', 'longlat_(126.314871, 8.217759)',
#        'longlat_(151.179691, -33.934491)', 'gname'],
#       dtype='object', length=1804)

# %%
label_index = {g: i for i, g in enumerate(sorted(df['gname'].unique()))}
continuous_cols = ['weaptype1']
y_preds, y_trues, logs = [], [], []
from itertools import product
import os
# Hyperparameter grid
#Running: n_tree=10, t_depth=12, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
param_grid = {
    'lr': [0.01],
    'n_tree': [10],
    'tree_depth': [12],
    'tree_feature_rate': [0.4],
    'feat_dropout': [0.0],
    'embed_dim': [32]
    }

# Convert to list of dicts (cartesian product)
grid_combos = list(product(*param_grid.values()))
param_names = list(param_grid.keys())

for col in continuous_cols:
    print(f"\nTraining model for {col} prediction...")

    data,edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df, train_mask, val_mask, test_mask, row_to_node_index, index_to_label = build_graph_data(df, label_index)

    best_run = None
    best_score = -1

    for combo in grid_combos:
        args = {
            **dict(zip(param_names, combo)),
            'partition': f"gtd{partition}",
            'n_class': len(label_index),
            'epochs': 3000,
            'final_evaluation': True
        }

        print(f"Running config: {args}")
        acc, epoch, p, r, f1, y_pred_decoded, y_true_decoded, p_micro, r_micro, f1_micro, p_macro, r_macro, f1_macro, auc_w, auc_mi, auc_ma, epoch_logs = train_joint(
            df, data, edge_index_full, y_gcn, y_nrf, train_df, val_df, test_df,
                train_mask, val_mask, test_mask, args,
                row_to_node_index, index_to_label, verbose=True)

        if acc > best_score:
            best_score = acc
            best_run = {
                "args": args,
                "acc": acc,
                "epoch": epoch,
                "y_pred": y_pred_decoded,
                "y_true": y_true_decoded,
                "precision": p,
                "recall": r,
                "f1": f1,
                "micro": (p_micro, r_micro, f1_micro),
                "macro": (p_macro, r_macro, f1_macro),
                "auroc": (auc_w, auc_mi, auc_ma),
                "epoch_logs": epoch_logs
            }


    # Save best results
    if best_run:
        args = best_run["args"]
        os.makedirs(f"Results{partition}", exist_ok=True)

        results_path = f"Results{partition}/Results_{col}_prediction"
        with open(results_path, "w") as f:
            f.write(f"Best acc: {best_run['acc']:.4f} at epoch {best_run['epoch']} for {col} prediction\n")
            f.write(f"Config: {args}\n")
            f.write(f"Weighted Precision: {best_run['precision']:.4f}, Recall: {best_run['recall']:.4f}, F1: {best_run['f1']:.4f}\n")
            f.write(f"Macro Precision: {best_run['macro'][0]:.4f}, Recall: {best_run['macro'][1]:.4f}, F1: {best_run['macro'][2]:.4f}\n")
            f.write(f"Micro Precision: {best_run['micro'][0]:.4f}, Recall: {best_run['micro'][1]:.4f}, F1: {best_run['micro'][2]:.4f}\n")
            f.write(f"AUROC Weighted: {best_run['auroc'][0]:.4f}, Micro: {best_run['auroc'][1]:.4f}, Macro: {best_run['auroc'][2]:.4f}\n")

        log_path = f"Results{partition}/epoch_logs_{col}_prediction"
        with open(log_path, "w") as f:
            f.write('\n'.join(f"{x:.4f}" for x in best_run['epoch_logs']))

        y_preds.append(best_run['y_pred'])
        y_trues.append(best_run['y_true'])

print(best_score)
# Out:
# Training model for weaptype1 prediction...
# 1943
# /home/jovyan/MEX0512/GTD_2025/Codes/Baselines/GraphRfi_oneHotLongLat/haversine_build_graph_and_train.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['pair'] = list(zip(df['target1'], df['weaptype1']))
# tensor(1220)
# tensor(463)
# tensor(466)
# tensor(2249)
# Running config: {'lr': 0.01, 'n_tree': 10, 'tree_depth': 12, 'tree_feature_rate': 0.4, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
# Epoch 000 | GCN Loss: 3.4012 | NRF Loss: 3.4012 | Joint: 6.8025 | Val Acc: 0.4383
# Epoch 050 | GCN Loss: 0.0452 | NRF Loss: 2.0002 | Joint: 2.0453 | Val Acc: 0.4317
# Epoch 100 | GCN Loss: 0.0069 | NRF Loss: 1.2053 | Joint: 1.2122 | Val Acc: 0.4183
# Epoch 150 | GCN Loss: 0.0044 | NRF Loss: 0.7087 | Joint: 0.7131 | Val Acc: 0.4150
# Epoch 200 | GCN Loss: 0.0031 | NRF Loss: 0.4427 | Joint: 0.4458 | Val Acc: 0.4250
# Epoch 250 | GCN Loss: 0.0023 | NRF Loss: 0.3014 | Joint: 0.3038 | Val Acc: 0.4217
# Epoch 300 | GCN Loss: 0.0018 | NRF Loss: 0.2199 | Joint: 0.2218 | Val Acc: 0.4233
# Early stopping at epoch 304
# Best validation acc: 0.4583 @ epoch 4
# Evaluating on test set using full graph...
# 0.4333333373069763

# %%
#test 0.9355495572090149
#Running config: {'lr': 0.001, 'n_tree': 40, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 64, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}
#Early stopping at epoch 779
#Best validation acc: 0.9331 @ epoch 679
#{'args': {'lr': 0.001, 'n_tree': 100, 'tree_depth': 10, 'tree_feature_rate': 0.5, 'feat_dropout': 0.1, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.9355495572090149,

# %%
print(best_run)
# Out:
# {'args': {'lr': 0.01, 'n_tree': 10, 'tree_depth': 12, 'tree_feature_rate': 0.4, 'feat_dropout': 0.0, 'embed_dim': 32, 'partition': 'gtd100', 'n_class': 30, 'epochs': 3000, 'final_evaluation': True}, 'acc': 0.4333333373069763, 'epoch': 4, 'y_pred': ['Farabundo Marti National Liberation Front (FMLN)', 'Al-Qaida in Iraq', 'Corsican National Liberation Front (FLNC)', 'Al-Shabaab', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Muslim extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'National Liberation Army of Colombia (ELN)', 'Revolutionary Armed Forces of Colombia (FARC)', "Donetsk People's Republic", 'Muslim extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Irish Republican Army (IRA)', 'Corsican National Liberation Front (FLNC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'National Liberation Army of Colombia (ELN)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Al-Shabaab', 'Abu Sayyaf Group (ASG)', 'Corsican National Liberation Front (FLNC)', 'Palestinians', 'Revolutionary Armed Forces of Colombia (FARC)', 'Abu Sayyaf Group (ASG)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in Iraq', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Al-Shabaab', 'Palestinians', 'Muslim extremists', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Shining Path (SL)', 'Shining Path (SL)', 'Taliban', 'Revolutionary Armed Forces of Colombia (FARC)', 'Al-Qaida in Iraq', 'Communist Party of India - Maoist (CPI-Maoist)', 'National Liberation Army of Colombia (ELN)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'African National Congress (South Africa)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Liberation Tigers of Tamil Eelam (LTTE)', 'Boko Haram', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in the Arabian Peninsula (AQAP)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Fulani extremists', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Al-Qaida in Iraq', 'Al-Shabaab', 'Revolutionary Armed Forces of Colombia (FARC)', 'Boko Haram', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Basque Fatherland and Freedom (ETA)', "Kurdistan Workers' Party (PKK)", 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Sikh Extremists', 'Communist Party of India - Maoist (CPI-Maoist)', 'Communist Party of India - Maoist (CPI-Maoist)', 'Revolutionary Armed Forces of Colombia (FARC)', 'Muslim extremists', 'Islamic State of Iraq and the Levant (ISIL)', 'Revolutionary Armed Forces of Colomb ...

# %%
"""
default_args = {
    'partition': f"gtd{partition}",
    'embed_dim': 16,
    'lr': 0.001,
    'epochs': 1000,
    'feat_dropout': 0,
    'n_tree': 80,
    'tree_depth': 10,
    'tree_feature_rate': 0.5,
    'n_class': len(label_index),
    'final_evaluation': True
}
0.9287652969360352

"""
# Out:
# '\ndefault_args = {\n    \'partition\': f"gtd{partition}",\n    \'embed_dim\': 16,\n    \'lr\': 0.001,\n    \'epochs\': 1000,\n    \'feat_dropout\': 0,\n    \'n_tree\': 80,\n    \'tree_depth\': 10,\n    \'tree_feature_rate\': 0.5,\n    \'n_class\': len(label_index),\n    \'final_evaluation\': True\n}\n0.9287652969360352\n\n'

# %%
best_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_acc
#
# NameError: name 'best_acc' is not defined

# %%
"""
Best acc: 0.9205 at epoch 750 for weaptype1 prediction
Weighted Precision: 0.9242, Recall: 0.9205, F1: 0.9191
Macro Precision: 0.9176, Recall: 0.9107, F1: 0.9105
Micro Precision: 0.9205, Recall: 0.9205, F1: 0.9205
AUROC Weighted: 0.9967, Micro: 0.9970, Macro: 0.9963

"""

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred_decoded, y_true_decoded))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, continuous_col):
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    # Save the figure
    save_path = f"Results{partition}/cm_{partition}_{continuous_col}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition {partition} to {save_path}")

# %%
for i in range(len(continuous_cols)):
    plot_confusion_matrix(y_preds[i], y_trues[i], sorted(df['gname'].unique()), continuous_cols[i])
