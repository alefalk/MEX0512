# %%
partition = 300

# %%
import sys
from train import main
from itertools import product  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import random
from itertools import product
import sys
#{'n_tree': 20, 'tree_depth': 10, 'batch_size': 256, 'tree_feature_rate': 0.1, 'feat_dropout': 0.2, 'lr': 0.01}

n_tree_values = [5, 10, 20, 50, 100]
tree_depth_values = [9, 10, 11]
hidden_dim = [1024, 768]
batch_size_values = [256, 512]
tree_feature_rates = [0.1, 0.2, 0.3, 0.4]
feat_dropouts = [0.0, 0.1, 0.2, 0.3]
lrs = [0.01]

n_iter = 50
best_score = 0
best_config = {}

param_space = list(product(
    n_tree_values,
    tree_depth_values,
    hidden_dim,
    batch_size_values,
    tree_feature_rates,
    feat_dropouts,
    lrs
))

best_acc = 0

sampled_configs = random.sample(param_space, min(n_iter, len(param_space)))
i = 1
for n_tree, t_depth, hd, batch_size, feature_rate, dropout, lr in sampled_configs:
    print(f"\nRunning: n_tree={n_tree}, t_depth={t_depth}, hd={hd}, batch_size={batch_size}, feature_rate={feature_rate}, dropout={dropout}, lr={lr}")
    sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', str(n_tree),
        '-tree_depth', str(t_depth),
        '-batch_size', str(batch_size),
        '-hidden_dim', str(hd),
        '-tree_feature_rate', str(feature_rate),
        '-feat_dropout', str(dropout),
        '-lr', str(lr),
        '-epochs', '400',
        '-verbose', '0',
        '-jointly_training',
        '-searching', '1'
    ]

    print(f"{i} / 100")
    acc = main()
    #print(acc)
    i =i + 1

    if acc > best_acc:
        best_acc = acc
        best_config = {
            'n_tree': n_tree,
            'tree_depth': t_depth,
            'batch_size': batch_size,
            'hidden_dim': hd,
            'tree_feature_rate': feature_rate,
            'feat_dropout': dropout,
            'lr': lr
        }

print("\nBest hyperparameter configuration:")
print(best_config)
print(f"Best accuracy: {best_acc}")
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Running: n_tree=20, t_depth=11, hd=768, batch_size=256, feature_rate=0.0, dropout=0.0, lr=0.01
# 1 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [01:02<03:06,  1.61it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=100, t_depth=11, hd=768, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 2 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  78%|███████▊  | 314/400 [15:42<04:18,  3.00s/it]
# Early stopping at epoch 315
#
# Best Accuracy: 0.905556
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.0, dropout=0.0, lr=0.01
# 3 / 100
# Use gtd300 dataset
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [01:14<03:42,  1.35it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 4 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  72%|███████▏  | 287/400 [02:39<01:02,  1.80it/s]
# Early stopping at epoch 288
#
# Best Accuracy: 0.896032
#
# Running: n_tree=100, t_depth=11, hd=768, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 5 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [19:32<00:00,  2.93s/it]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Best Accuracy: 0.911905
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=512, feature_rate=0.0, dropout=0.0, lr=0.01
# 6 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [00:29<01:29,  3.34it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=10, t_depth=9, hd=768, batch_size=256, feature_rate=0.3, dropout=0.3, lr=0.01
# 7 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  68%|██████▊   | 271/400 [01:29<00:42,  3.04it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 272
#
# Best Accuracy: 0.886508
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=512, feature_rate=0.0, dropout=0.1, lr=0.01
# 8 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [02:28<07:25,  1.48s/it]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=10, t_depth=10, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 9 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  80%|████████  | 321/400 [01:04<00:15,  5.00it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 322
#
# Best Accuracy: 0.886508
#
# Running: n_tree=5, t_depth=11, hd=1024, batch_size=256, feature_rate=0.0, dropout=0.3, lr=0.01
# 10 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [00:20<01:02,  4.78it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=5, t_depth=9, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 11 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [00:44<00:00,  8.96it/s]
# Best Accuracy: 0.880159
#
# Running: n_tree=5, t_depth=11, hd=768, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 12 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  92%|█████████▏| 367/400 [00:46<00:04,  7.85it/s]
# Early stopping at epoch 368
#
# Best Accuracy: 0.890476
#
# Running: n_tree=50, t_depth=10, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 13 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  56%|█████▌    | 223/400 [05:40<04:30,  1.53s/it]
# Early stopping at epoch 224
#
# Best Accuracy: 0.898413
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 14 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  90%|████████▉ | 359/400 [05:11<00:35,  1.15it/s]
# Early stopping at epoch 360
#
# Best Accuracy: 0.903175
#
# Running: n_tree=100, t_depth=9, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.3, lr=0.01
# 15 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  81%|████████▏ | 325/400 [07:46<01:47,  1.43s/it]
# Early stopping at epoch 326
#
# Best Accuracy: 0.906349
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.4, dropout=0.3, lr=0.01
# 16 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  83%|████████▎ | 331/400 [04:24<00:55,  1.25it/s]
# Early stopping at epoch 332
#
# Best Accuracy: 0.919048
#
# Running: n_tree=10, t_depth=9, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.3, lr=0.01
# 17 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  54%|█████▍    | 217/400 [01:07<00:56,  3.21it/s]
# Early stopping at epoch 218
#
# Best Accuracy: 0.886508
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 18 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [00:42<00:00,  9.45it/s]
# Best Accuracy: 0.849206
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.3, lr=0.01
# 19 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  77%|███████▋  | 307/400 [00:32<00:09,  9.45it/s]
# Early stopping at epoch 308
#
# Best Accuracy: 0.865079
#
# Running: n_tree=20, t_depth=9, hd=768, batch_size=512, feature_rate=0.4, dropout=0.2, lr=0.01
# 20 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  66%|██████▋   | 265/400 [01:18<00:40,  3.37it/s]
# Early stopping at epoch 266
#
# Best Accuracy: 0.896032
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 21 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [00:42<00:00,  9.33it/s]
# Best Accuracy: 0.863492
#
# Running: n_tree=50, t_depth=10, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 22 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [04:47<00:00,  1.39it/s]
# Best Accuracy: 0.909524
#
# Running: n_tree=100, t_depth=11, hd=768, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 23 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [10:05<00:00,  1.51s/it]
# Best Accuracy: 0.922222
#
# Running: n_tree=100, t_depth=9, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 24 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  95%|█████████▌| 381/400 [08:07<00:24,  1.28s/it]
# Early stopping at epoch 382
#
# Best Accuracy: 0.913492
#
# Running: n_tree=100, t_depth=10, hd=768, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 25 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  70%|███████   | 280/400 [12:46<05:28,  2.74s/it]
# Early stopping at epoch 281
#
# Best Accuracy: 0.905556
#
# Running: n_tree=5, t_depth=11, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 26 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  76%|███████▋  | 306/400 [01:02<00:19,  4.90it/s]
# Early stopping at epoch 307
#
# Best Accuracy: 0.854762
#
# Running: n_tree=10, t_depth=9, hd=768, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 27 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  51%|█████     | 204/400 [01:03<01:01,  3.20it/s]
# Early stopping at epoch 205
#
# Best Accuracy: 0.882540
#
# Running: n_tree=5, t_depth=9, hd=768, batch_size=512, feature_rate=0.1, dropout=0.3, lr=0.01
# 28 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  48%|████▊     | 191/400 [00:20<00:22,  9.40it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 192
#
# Best Accuracy: 0.861905
#
# Running: n_tree=5, t_depth=10, hd=1024, batch_size=512, feature_rate=0.0, dropout=0.2, lr=0.01
# 29 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [00:11<00:33,  8.94it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 30 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  73%|███████▎  | 293/400 [00:52<00:19,  5.55it/s]
# Early stopping at epoch 294
#
# Best Accuracy: 0.872222
#
# Running: n_tree=50, t_depth=9, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.3, lr=0.01
# 31 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  81%|████████  | 324/400 [03:38<00:51,  1.49it/s]
# Early stopping at epoch 325
#
# Best Accuracy: 0.908730
#
# Running: n_tree=10, t_depth=10, hd=768, batch_size=512, feature_rate=0.4, dropout=0.3, lr=0.01
# 32 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  79%|███████▉  | 315/400 [00:58<00:15,  5.37it/s]
# Early stopping at epoch 316
#
# Best Accuracy: 0.900794
#
# Running: n_tree=100, t_depth=10, hd=768, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 33 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  90%|████████▉ | 359/400 [16:05<01:50,  2.69s/it]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 360
#
# Best Accuracy: 0.907937
#
# Running: n_tree=100, t_depth=10, hd=768, batch_size=512, feature_rate=0.0, dropout=0.0, lr=0.01
# 34 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [02:14<06:44,  1.35s/it]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.0, dropout=0.0, lr=0.01
# 35 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [04:22<13:07,  2.62s/it]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.2, lr=0.01
# 36 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  91%|█████████ | 364/400 [15:44<01:33,  2.60s/it]
# Early stopping at epoch 365
#
# Best Accuracy: 0.911111
#
# Running: n_tree=100, t_depth=11, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.2, lr=0.01
# 37 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  91%|█████████ | 364/400 [08:43<00:51,  1.44s/it]
# Early stopping at epoch 365
#
# Best Accuracy: 0.919048
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 38 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  84%|████████▍ | 335/400 [16:39<03:13,  2.98s/it]
# Early stopping at epoch 336
#
# Best Accuracy: 0.900000
#
# Running: n_tree=100, t_depth=9, hd=768, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 39 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [09:53<00:00,  1.48s/it]
# Best Accuracy: 0.909524
#
# Running: n_tree=5, t_depth=11, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.3, lr=0.01
# 40 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  47%|████▋     | 189/400 [00:36<00:40,  5.17it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 190
#
# Best Accuracy: 0.857143
#
# Running: n_tree=20, t_depth=11, hd=768, batch_size=512, feature_rate=0.0, dropout=0.1, lr=0.01
# 41 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [00:30<01:32,  3.23it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.0, dropout=0.1, lr=0.01
# 42 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [00:50<02:32,  1.97it/s]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=20, t_depth=11, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 43 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  72%|███████▏  | 289/400 [02:55<01:07,  1.65it/s]
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Early stopping at epoch 290
#
# Best Accuracy: 0.890476
#
# Running: n_tree=100, t_depth=9, hd=1024, batch_size=512, feature_rate=0.0, dropout=0.0, lr=0.01
# 44 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [01:59<05:59,  1.20s/it]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=100, t_depth=9, hd=768, batch_size=256, feature_rate=0.3, dropout=0.2, lr=0.01
# 45 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [17:18<00:00,  2.60s/it]
# Best Accuracy: 0.902381
#
# Running: n_tree=10, t_depth=11, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 46 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  56%|█████▌    | 224/400 [00:45<00:35,  4.97it/s]
# Early stopping at epoch 225
#
# Best Accuracy: 0.896032
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 47 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  78%|███████▊  | 312/400 [14:55<04:12,  2.87s/it]
# Early stopping at epoch 313
# Best Accuracy: 0.901587
#
# Running: n_tree=50, t_depth=10, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 48 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs:  77%|███████▋  | 308/400 [07:30<02:14,  1.46s/it]
# Early stopping at epoch 309
#
# Best Accuracy: 0.901587
#
# Running: n_tree=100, t_depth=11, hd=1024, batch_size=256, feature_rate=0.0, dropout=0.1, lr=0.01
# 49 / 100
# Use gtd300 dataset
# /opt/conda/lib/python3.11/site-packages/torch/nn/init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Patience: 100
# Training Epochs:  25%|██▌       | 100/400 [04:57<14:51,  2.97s/it]
# Early stopping at epoch 101
#
# Best Accuracy: 0.033333
#
# Running: n_tree=50, t_depth=11, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 50 / 100
# Use gtd300 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [10:17<00:00,  1.54s/it]
# Best Accuracy: 0.908730
#
# Best hyperparameter configuration:
# {'n_tree': 100, 'tree_depth': 11, 'batch_size': 512, 'hidden_dim': 768, 'tree_feature_rate': 0.1, 'feat_dropout': 0.1, 'lr': 0.01}
# Best accuracy: 0.9222222222222223

# %%
"""sys.argv = [
    'train.py',
    '-dataset', f'gtd{partition}',
    '-n_class', '30',
    '-gpuid', '0',
    '-n_tree', str(best_config['n_tree']),
    '-tree_depth', str(best_config['tree_depth']),
    '-batch_size', str(best_config['batch_size']),
    '-epochs', '1000',
    '-verbose', '1',
    '-jointly_training'
]"""

sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', '20',
        '-tree_depth', '10',
        '-batch_size', '256',
        '-epochs', '1500',
        '-verbose', '0',
        '-tree_feature_rate', str(best_config['tree_feature_rate']),
        '-feat_dropout', str(best_config['feat_dropout']),
        '-lr', str(best_config['lr']),
        '-jointly_training'
    ]

best_model, preds, targets, labels, epoch_logs = main()
# Out:
# Use gtd300 dataset
# Patience: 300
# Training Epochs:   3%|▎         | 50/1500 [00:30<14:17,  1.69it/s]
# [Epoch 50] Train Loss: 0.4668, Eval Loss: 0.5008, Eval Accuracy: 0.8778
# Training Epochs:   7%|▋         | 100/1500 [01:00<13:47,  1.69it/s]
# [Epoch 100] Train Loss: 0.4149, Eval Loss: 0.4614, Eval Accuracy: 0.8881
# Training Epochs:  10%|█         | 150/1500 [01:30<13:18,  1.69it/s]
# [Epoch 150] Train Loss: 0.4006, Eval Loss: 0.4491, Eval Accuracy: 0.8968
# Training Epochs:  13%|█▎        | 200/1500 [02:00<12:58,  1.67it/s]
# [Epoch 200] Train Loss: 0.3857, Eval Loss: 0.4412, Eval Accuracy: 0.8944
# Training Epochs:  17%|█▋        | 250/1500 [02:30<12:32,  1.66it/s]
# [Epoch 250] Train Loss: 0.3786, Eval Loss: 0.4309, Eval Accuracy: 0.9024
# Training Epochs:  20%|██        | 300/1500 [03:00<11:53,  1.68it/s]
# [Epoch 300] Train Loss: 0.3721, Eval Loss: 0.4308, Eval Accuracy: 0.9024
# Training Epochs:  23%|██▎       | 350/1500 [03:30<11:21,  1.69it/s]
# [Epoch 350] Train Loss: 0.3663, Eval Loss: 0.4268, Eval Accuracy: 0.8976
# Training Epochs:  27%|██▋       | 400/1500 [03:59<10:55,  1.68it/s]
# [Epoch 400] Train Loss: 0.3607, Eval Loss: 0.4242, Eval Accuracy: 0.8937
# Training Epochs:  30%|███       | 450/1500 [04:29<10:21,  1.69it/s]
# [Epoch 450] Train Loss: 0.3610, Eval Loss: 0.4175, Eval Accuracy: 0.9016
# Training Epochs:  33%|███▎      | 500/1500 [04:59<10:01,  1.66it/s]
# [Epoch 500] Train Loss: 0.3573, Eval Loss: 0.4235, Eval Accuracy: 0.9048
# Training Epochs:  37%|███▋      | 550/1500 [05:29<09:22,  1.69it/s]
# [Epoch 550] Train Loss: 0.3567, Eval Loss: 0.4171, Eval Accuracy: 0.8992
# Training Epochs:  40%|████      | 600/1500 [05:58<08:53,  1.69it/s]
# [Epoch 600] Train Loss: 0.3549, Eval Loss: 0.4211, Eval Accuracy: 0.9000
# Training Epochs:  43%|████▎     | 650/1500 [06:28<08:24,  1.69it/s]
# [Epoch 650] Train Loss: 0.3565, Eval Loss: 0.4248, Eval Accuracy: 0.9000
# Training Epochs:  47%|████▋     | 700/1500 [06:58<07:54,  1.69it/s]
# [Epoch 700] Train Loss: 0.3592, Eval Loss: 0.4295, Eval Accuracy: 0.8992
# Training Epochs:  50%|█████     | 750/1500 [07:28<07:27,  1.68it/s]
# [Epoch 750] Train Loss: 0.3540, Eval Loss: 0.4197, Eval Accuracy: 0.8960
# Training Epochs:  53%|█████▎    | 800/1500 [07:57<06:48,  1.71it/s]
# [Epoch 800] Train Loss: 0.3503, Eval Loss: 0.4272, Eval Accuracy: 0.8937
# Training Epochs:  54%|█████▍    | 809/1500 [08:03<06:53,  1.67it/s]
# Early stopping at epoch 810
# Evaluating on test set with best model...

# %%
from sklearn.metrics import classification_report

print(classification_report(targets, preds))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.95      0.97      0.96        90
#         African National Congress (South Africa)       0.99      1.00      0.99        90
#                                 Al-Qaida in Iraq       0.80      0.91      0.85        90
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.84      0.84      0.84        90
#                                       Al-Shabaab       1.00      0.99      0.99        90
#              Basque Fatherland and Freedom (ETA)       1.00      1.00      1.00        90
#                                       Boko Haram       0.94      0.89      0.91        90
#   Communist Party of India - Maoist (CPI-Maoist)       0.91      0.90      0.91        90
#        Corsican National Liberation Front (FLNC)       0.99      1.00      0.99        90
#                        Donetsk People's Republic       1.00      1.00      1.00        90
# Farabundo Marti National Liberation Front (FMLN)       0.73      0.98      0.83        90
#                                Fulani extremists       0.89      0.96      0.92        90
#                  Houthi extremists (Ansar Allah)       0.84      0.86      0.85        90
#                      Irish Republican Army (IRA)       1.00      1.00      1.00        90
#      Islamic State of Iraq and the Levant (ISIL)       0.82      0.73      0.78        90
#                   Kurdistan Workers' Party (PKK)       0.96      0.94      0.95        90
#          Liberation Tigers of Tamil Eelam (LTTE)       0.96      1.00      0.98        90
#          Manuel Rodriguez Patriotic Front (FPMR)       1.00      0.99      0.99        90
#                                          Maoists       0.89      0.91      0.90        90
#                                Muslim extremists       0.96      0.76      0.84        90
#       National Liberation Army of Colombia (ELN)       0.91      0.79      0.85        90
#                          New People's Army (NPA)       0.95      0.97      0.96        90
#                Nicaraguan Democratic Force (FDN)       0.97      0.64      0.77        90
#                                     Palestinians       0.99      0.97      0.98        90
#    Revolutionary Armed Forces of Colombia (FARC)       0.81      0.91      0.86        90
#                                Shining Path (SL)       0.87      0.89      0.88        90
#                                  Sikh Extremists       0.89      0.93      0.91        90
#                                          Taliban       0.77      0.88      0.82        90
#                  Tehrik-i-Taliban Pakistan (TTP)       0.84      0.73      0.78        90
#        Tupac Amaru Revolutionary Movement (MRTA)       0.89      0.88      0.88        90
#
#                                         accuracy                           0.91      2700
#                                        macro avg       0.91      0.91      0.91      2700
#                                     weighted avg       0.91      0.91      0.91      2700

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition):
    cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition gtd{partition})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    save_path = f"results/confusion_matrix_partition_gtd{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition gtd{partition} to {save_path}")

# %%
plot_confusion_matrix(targets, preds, labels, partition)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_confusion_matrix(targets, preds, labels, partition)
#
# Cell In[9], line 2, in plot_confusion_matrix(y_true, y_pred, labels, partition)
#       1 def plot_confusion_matrix(y_true, y_pred, labels, partition):
# ----> 2     cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
#       3     cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
#       5     plt.figure(figsize=(18, 16))
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     340         return np.zeros((n_labels, n_labels), dtype=int)
#     341     elif len(np.intersect1d(y_true, labels)) == 0:
# --> 342         raise ValueError("At least one label specified must be in y_true")
#     344 if sample_weight is None:
#     345     sample_weight = np.ones(y_true.shape[0], dtype=np.int64)
#
# ValueError: At least one label specified must be in y_true
