# %%
partition = 200

# %%
import sys
from train import main
from itertools import product  
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import random
from itertools import product
import sys

n_tree_values = [5, 10, 20, 50, 100]
tree_depth_values = [6, 7, 8, 9, 10, 11, 12]
hidden_dim = [1024, 768]
batch_size_values = [256, 512]
tree_feature_rates = [0.1, 0.2, 0.3, 0.4]
feat_dropouts = [0.0, 0.1]
lrs = [0.01]

n_iter = 50
best_score = 0
best_config = {}

param_space = list(product(
    n_tree_values,
    tree_depth_values,
    hidden_dim,
    batch_size_values,
    tree_feature_rates,
    feat_dropouts,
    lrs
))

best_acc = 0

sampled_configs = random.sample(param_space, min(n_iter, len(param_space)))
i = 1
for n_tree, t_depth, hd, batch_size, feature_rate, dropout, lr in sampled_configs:
    print(f"\nRunning: n_tree={n_tree}, t_depth={t_depth}, hd={hd}, batch_size={batch_size}, feature_rate={feature_rate}, dropout={dropout}, lr={lr}")
    sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', str(n_tree),
        '-tree_depth', str(t_depth),
        '-batch_size', str(batch_size),
        '-hidden_dim', str(hd),
        '-tree_feature_rate', str(feature_rate),
        '-feat_dropout', str(dropout),
        '-lr', str(lr),
        '-epochs', '400',
        '-verbose', '0',
        '-jointly_training',
        '-searching', '1'
    ]

    print(f"{i} / 100")
    acc = main()
    #print(acc)
    i =i + 1

    if acc > best_acc:
        best_acc = acc
        best_config = {
            'n_tree': n_tree,
            'tree_depth': t_depth,
            'batch_size': batch_size,
            'hidden_dim': hd,
            'tree_feature_rate': feature_rate,
            'feat_dropout': dropout,
            'lr': lr
        }

print("\nBest hyperparameter configuration:")
print(best_config)
print(f"Best accuracy: {best_score}")
# Out:
# Running: n_tree=20, t_depth=12, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 1 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [03:13<00:00,  2.07it/s]
# Best Accuracy: 0.535714
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 2 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  68%|██████▊   | 271/400 [01:55<00:54,  2.35it/s]
# Early stopping at epoch 272
#
# Best Accuracy: 0.522619
#
# Running: n_tree=100, t_depth=7, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 3 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  88%|████████▊ | 350/400 [04:40<00:40,  1.25it/s]
# Early stopping at epoch 351
#
# Best Accuracy: 0.483333
#
# Running: n_tree=10, t_depth=7, hd=768, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 4 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  64%|██████▎   | 254/400 [00:47<00:27,  5.40it/s]
# Early stopping at epoch 255
#
# Best Accuracy: 0.497619
#
# Running: n_tree=5, t_depth=11, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 5 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  60%|██████    | 242/400 [00:34<00:22,  6.96it/s]
# Early stopping at epoch 243
#
# Best Accuracy: 0.480952
#
# Running: n_tree=10, t_depth=6, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 6 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  65%|██████▌   | 260/400 [00:25<00:13, 10.31it/s]
# Early stopping at epoch 261
#
# Best Accuracy: 0.432143
#
# Running: n_tree=20, t_depth=8, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01
# 7 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  76%|███████▋  | 305/400 [01:51<00:34,  2.73it/s]
# Early stopping at epoch 306
#
# Best Accuracy: 0.519048
#
# Running: n_tree=10, t_depth=7, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 8 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  70%|██████▉   | 278/400 [00:52<00:22,  5.35it/s]
# Early stopping at epoch 279
#
# Best Accuracy: 0.447619
#
# Running: n_tree=100, t_depth=8, hd=1024, batch_size=256, feature_rate=0.2, dropout=0.0, lr=0.01
# 9 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  80%|███████▉  | 319/400 [09:20<02:22,  1.76s/it]
# Early stopping at epoch 320
#
# Best Accuracy: 0.507143
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 10 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  66%|██████▌   | 262/400 [01:01<00:32,  4.24it/s]
# Early stopping at epoch 263
#
# Best Accuracy: 0.494048
#
# Running: n_tree=50, t_depth=8, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 11 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  54%|█████▍    | 217/400 [03:09<02:39,  1.14it/s]
# Early stopping at epoch 218
#
# Best Accuracy: 0.490476
#
# Running: n_tree=10, t_depth=12, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 12 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  68%|██████▊   | 273/400 [00:41<00:19,  6.51it/s]
# Early stopping at epoch 274
#
# Best Accuracy: 0.503571
#
# Running: n_tree=10, t_depth=10, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 13 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  81%|████████▏ | 325/400 [00:41<00:09,  7.74it/s]
# Early stopping at epoch 326
#
# Best Accuracy: 0.500000
#
# Running: n_tree=50, t_depth=7, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 14 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  92%|█████████▏| 366/400 [02:29<00:13,  2.44it/s]
# Early stopping at epoch 367
#
# Best Accuracy: 0.491667
#
# Running: n_tree=100, t_depth=7, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 15 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  88%|████████▊ | 351/400 [09:06<01:16,  1.56s/it]
# Early stopping at epoch 352
#
# Best Accuracy: 0.489286
#
# Running: n_tree=5, t_depth=7, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 16 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  36%|███▋      | 146/400 [00:16<00:29,  8.75it/s]
# Early stopping at epoch 147
#
# Best Accuracy: 0.434524
#
# Running: n_tree=50, t_depth=7, hd=1024, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 17 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  86%|████████▋ | 346/400 [04:30<00:42,  1.28it/s]
# Early stopping at epoch 347
#
# Best Accuracy: 0.494048
#
# Running: n_tree=5, t_depth=8, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 18 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  62%|██████▏   | 249/400 [00:28<00:17,  8.81it/s]
# Early stopping at epoch 250
#
# Best Accuracy: 0.448810
#
# Running: n_tree=5, t_depth=12, hd=768, batch_size=256, feature_rate=0.1, dropout=0.0, lr=0.01
# 19 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  51%|█████▏    | 205/400 [00:30<00:28,  6.75it/s]
# Early stopping at epoch 206
#
# Best Accuracy: 0.514286
#
# Running: n_tree=50, t_depth=6, hd=768, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 20 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  84%|████████▍ | 338/400 [02:01<00:22,  2.79it/s]
# Early stopping at epoch 339
#
# Best Accuracy: 0.492857
#
# Running: n_tree=20, t_depth=11, hd=768, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 21 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [03:00<00:00,  2.22it/s]
# Best Accuracy: 0.521429
#
# Running: n_tree=10, t_depth=9, hd=768, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 22 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  67%|██████▋   | 267/400 [00:32<00:16,  8.15it/s]
# Early stopping at epoch 268
#
# Best Accuracy: 0.470238
#
# Running: n_tree=10, t_depth=7, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 23 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  80%|████████  | 321/400 [00:32<00:08,  9.84it/s]
# Early stopping at epoch 322
#
# Best Accuracy: 0.485714
#
# Running: n_tree=20, t_depth=9, hd=768, batch_size=256, feature_rate=0.3, dropout=0.0, lr=0.01
# 24 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [02:37<00:00,  2.55it/s]
# Best Accuracy: 0.502381
#
# Running: n_tree=10, t_depth=8, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 25 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  41%|████▏     | 165/400 [00:33<00:47,  4.94it/s]
# Early stopping at epoch 166
#
# Best Accuracy: 0.478571
#
# Running: n_tree=50, t_depth=8, hd=768, batch_size=512, feature_rate=0.1, dropout=0.0, lr=0.01
# 26 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [02:55<00:00,  2.28it/s]
# Best Accuracy: 0.513095
#
# Running: n_tree=100, t_depth=9, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 27 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  78%|███████▊  | 314/400 [04:54<01:20,  1.07it/s]
# Early stopping at epoch 315
#
# Best Accuracy: 0.498810
#
# Running: n_tree=100, t_depth=9, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 28 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  80%|███████▉  | 318/400 [05:01<01:17,  1.06it/s]
# Early stopping at epoch 319
#
# Best Accuracy: 0.490476
#
# Running: n_tree=5, t_depth=6, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 29 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  75%|███████▌  | 301/400 [00:17<00:05, 17.50it/s]
# Early stopping at epoch 302
#
# Best Accuracy: 0.438095
#
# Running: n_tree=100, t_depth=6, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 30 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  60%|█████▉    | 239/400 [02:44<01:50,  1.45it/s]
# Early stopping at epoch 240
#
# Best Accuracy: 0.488095
#
# Running: n_tree=20, t_depth=10, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 31 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  52%|█████▏    | 206/400 [01:25<01:20,  2.42it/s]
# Early stopping at epoch 207
#
# Best Accuracy: 0.490476
#
# Running: n_tree=50, t_depth=9, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 32 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  90%|█████████ | 361/400 [05:26<00:35,  1.11it/s]
# Early stopping at epoch 362
#
# Best Accuracy: 0.491667
#
# Running: n_tree=20, t_depth=9, hd=1024, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 33 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  64%|██████▍   | 256/400 [01:37<00:54,  2.62it/s]
# Early stopping at epoch 257
#
# Best Accuracy: 0.498810
#
# Running: n_tree=100, t_depth=9, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 34 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  78%|███████▊  | 311/400 [04:42<01:20,  1.10it/s]
# Early stopping at epoch 312
#
# Best Accuracy: 0.496429
#
# Running: n_tree=20, t_depth=10, hd=768, batch_size=256, feature_rate=0.2, dropout=0.1, lr=0.01
# 35 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [02:44<00:00,  2.44it/s]
# Best Accuracy: 0.510714
#
# Running: n_tree=5, t_depth=6, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 36 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  47%|████▋     | 189/400 [00:18<00:21, 10.03it/s]
# Early stopping at epoch 190
#
# Best Accuracy: 0.483333
#
# Running: n_tree=50, t_depth=8, hd=768, batch_size=256, feature_rate=0.4, dropout=0.0, lr=0.01
# 37 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  91%|█████████▏| 365/400 [05:01<00:28,  1.21it/s]
# Early stopping at epoch 366
#
# Best Accuracy: 0.498810
#
# Running: n_tree=20, t_depth=12, hd=1024, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 38 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  58%|█████▊    | 234/400 [01:02<00:44,  3.73it/s]
# Early stopping at epoch 235
#
# Best Accuracy: 0.517857
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 39 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  53%|█████▎    | 213/400 [01:58<01:44,  1.80it/s]
# Early stopping at epoch 214
#
# Best Accuracy: 0.504762
#
# Running: n_tree=20, t_depth=7, hd=768, batch_size=512, feature_rate=0.3, dropout=0.0, lr=0.01
# 40 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  84%|████████▍ | 336/400 [00:57<00:11,  5.81it/s]
# Early stopping at epoch 337
#
# Best Accuracy: 0.504762
#
# Running: n_tree=20, t_depth=6, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.1, lr=0.01
# 41 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  67%|██████▋   | 267/400 [00:41<00:20,  6.49it/s]
# Early stopping at epoch 268
#
# Best Accuracy: 0.467857
#
# Running: n_tree=50, t_depth=11, hd=768, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 42 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [03:25<00:00,  1.94it/s]
# Best Accuracy: 0.516667
#
# Running: n_tree=50, t_depth=6, hd=1024, batch_size=512, feature_rate=0.4, dropout=0.0, lr=0.01
# 43 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [02:16<00:00,  2.92it/s]
# Best Accuracy: 0.496429
#
# Running: n_tree=100, t_depth=10, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.1, lr=0.01
# 44 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  56%|█████▌    | 222/400 [03:35<02:52,  1.03it/s]
# Early stopping at epoch 223
#
# Best Accuracy: 0.504762
#
# Running: n_tree=5, t_depth=8, hd=1024, batch_size=512, feature_rate=0.2, dropout=0.0, lr=0.01
# 45 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  80%|████████  | 321/400 [00:19<00:04, 16.37it/s]
# Early stopping at epoch 322
#
# Best Accuracy: 0.450000
#
# Running: n_tree=20, t_depth=6, hd=768, batch_size=512, feature_rate=0.3, dropout=0.1, lr=0.01
# 46 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  50%|█████     | 200/400 [00:29<00:29,  6.69it/s]
# Early stopping at epoch 201
#
# Best Accuracy: 0.460714
#
# Running: n_tree=50, t_depth=12, hd=1024, batch_size=512, feature_rate=0.1, dropout=0.1, lr=0.01
# 47 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  72%|███████▏  | 287/400 [02:39<01:02,  1.80it/s]
# Early stopping at epoch 288
#
# Best Accuracy: 0.514286
#
# Running: n_tree=5, t_depth=9, hd=768, batch_size=256, feature_rate=0.4, dropout=0.1, lr=0.01
# 48 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs:  38%|███▊      | 150/400 [00:17<00:28,  8.78it/s]
# Early stopping at epoch 151
#
# Best Accuracy: 0.451190
#
# Running: n_tree=5, t_depth=10, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.0, lr=0.01
# 49 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [00:47<00:00,  8.46it/s]
# Best Accuracy: 0.514286
#
# Running: n_tree=5, t_depth=9, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.0, lr=0.01
# 50 / 100
# Use gtd200 dataset
# Patience: 100
# Training Epochs: 100%|██████████| 400/400 [00:44<00:00,  8.97it/s]
# Best Accuracy: 0.495238
#
# Best hyperparameter configuration:
# {'n_tree': 5, 'tree_depth': 9, 'batch_size': 256, 'hidden_dim': 1024, 'tree_feature_rate': 0.1, 'feat_dropout': 0.0, 'lr': 0.01}
# Best accuracy: 0

# %%
#Running: n_tree=20, t_depth=12, hd=1024, batch_size=256, feature_rate=0.1, dropout=0.1, lr=0.01

# %%
"""sys.argv = [
    'train.py',
    '-dataset', f'gtd{partition}',
    '-n_class', '30',
    '-gpuid', '0',
    '-n_tree', str(best_config['n_tree']),
    '-tree_depth', str(best_config['tree_depth']),
    '-batch_size', str(best_config['batch_size']),
    '-epochs', '1000',
    '-verbose', '1',
    '-jointly_training'
]"""


sys.argv = [
        'train.py',
        '-dataset', f'gtd{partition}',
        '-n_class', '30',
        '-gpuid', '0',
        '-n_tree', '20',
        '-tree_depth', '12',
        '-batch_size', '256',
        '-hidden_dim', '1024',
        '-epochs', '1500',
        '-verbose', '0',
        '-tree_feature_rate', '0.1',
        '-feat_dropout', '0.1',
        '-lr', '0.01',
        '-jointly_training',
        '-searching', '0'
    ]

best_model, preds, targets, labels, epoch_logs = main()
# Out:
# Use gtd200 dataset
# Patience: 300
# Training Epochs:   3%|▎         | 50/1500 [00:25<11:34,  2.09it/s]
# [Epoch 50] Train Loss: 1.3257, Eval Loss: 1.8016, Eval Accuracy: 0.4952
# Training Epochs:   7%|▋         | 100/1500 [00:49<11:24,  2.05it/s]
# [Epoch 100] Train Loss: 1.1768, Eval Loss: 1.8062, Eval Accuracy: 0.5143
# Training Epochs:  10%|█         | 150/1500 [01:13<10:41,  2.10it/s]
# [Epoch 150] Train Loss: 1.1249, Eval Loss: 1.8550, Eval Accuracy: 0.5155
# Training Epochs:  13%|█▎        | 200/1500 [01:37<10:11,  2.13it/s]
# [Epoch 200] Train Loss: 1.1126, Eval Loss: 1.8909, Eval Accuracy: 0.5202
# Training Epochs:  17%|█▋        | 250/1500 [02:01<10:11,  2.04it/s]
# [Epoch 250] Train Loss: 1.1230, Eval Loss: 1.9383, Eval Accuracy: 0.5286
# Training Epochs:  20%|██        | 300/1500 [02:24<09:29,  2.11it/s]
# [Epoch 300] Train Loss: 1.1068, Eval Loss: 1.9683, Eval Accuracy: 0.5250
# Training Epochs:  23%|██▎       | 350/1500 [02:48<09:05,  2.11it/s]
# [Epoch 350] Train Loss: 1.1218, Eval Loss: 2.0042, Eval Accuracy: 0.5310
# Training Epochs:  27%|██▋       | 400/1500 [03:12<08:39,  2.12it/s]
# [Epoch 400] Train Loss: 1.1465, Eval Loss: 2.0088, Eval Accuracy: 0.5083
# Training Epochs:  30%|███       | 450/1500 [03:36<08:17,  2.11it/s]
# [Epoch 450] Train Loss: 1.1535, Eval Loss: 2.0601, Eval Accuracy: 0.5000
# Training Epochs:  33%|███▎      | 500/1500 [03:59<07:54,  2.11it/s]
# [Epoch 500] Train Loss: 1.1437, Eval Loss: 2.0549, Eval Accuracy: 0.5167
# Training Epochs:  34%|███▎      | 503/1500 [04:01<07:59,  2.08it/s]
# Early stopping at epoch 504
# Evaluating on test set with best model...

# %%
from sklearn.metrics import classification_report

print(classification_report(targets, preds))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       0.00      0.00      0.00        60
#         African National Congress (South Africa)       0.00      0.00      0.00        60
#                                 Al-Qaida in Iraq       0.00      0.00      0.00        60
#         Al-Qaida in the Arabian Peninsula (AQAP)       0.00      0.00      0.00        60
#                                       Al-Shabaab       0.00      0.00      0.00        60
#              Basque Fatherland and Freedom (ETA)       0.00      0.00      0.00        60
#                                       Boko Haram       0.00      0.00      0.00        60
#   Communist Party of India - Maoist (CPI-Maoist)       0.00      0.00      0.00        60
#        Corsican National Liberation Front (FLNC)       0.00      0.00      0.00        60
#                        Donetsk People's Republic       0.00      0.00      0.00        60
# Farabundo Marti National Liberation Front (FMLN)       0.00      0.00      0.00        60
#                                Fulani extremists       0.00      0.00      0.00        60
#                  Houthi extremists (Ansar Allah)       0.00      0.00      0.00        60
#                      Irish Republican Army (IRA)       0.00      0.00      0.00        60
#      Islamic State of Iraq and the Levant (ISIL)       0.00      0.00      0.00        60
#                   Kurdistan Workers' Party (PKK)       0.00      0.00      0.00        60
#          Liberation Tigers of Tamil Eelam (LTTE)       0.00      0.00      0.00        60
#          Manuel Rodriguez Patriotic Front (FPMR)       0.00      0.00      0.00        60
#                                          Maoists       0.00      0.00      0.00        60
#                                Muslim extremists       0.00      0.00      0.00        60
#       National Liberation Army of Colombia (ELN)       0.03      1.00      0.06        60
#                          New People's Army (NPA)       0.00      0.00      0.00        60
#                Nicaraguan Democratic Force (FDN)       0.00      0.00      0.00        60
#                                     Palestinians       0.00      0.00      0.00        60
#    Revolutionary Armed Forces of Colombia (FARC)       0.00      0.00      0.00        60
#                                Shining Path (SL)       0.00      0.00      0.00        60
#                                  Sikh Extremists       0.00      0.00      0.00        60
#                                          Taliban       0.00      0.00      0.00        60
#                  Tehrik-i-Taliban Pakistan (TTP)       0.00      0.00      0.00        60
#        Tupac Amaru Revolutionary Movement (MRTA)       0.00      0.00      0.00        60
#
#                                         accuracy                           0.03      1800
#                                        macro avg       0.00      0.03      0.00      1800
#                                     weighted avg       0.00      0.03      0.00      1800
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def plot_confusion_matrix(y_true, y_pred, labels, partition):
    cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_normalized,
                annot=True,
                fmt=".2f",
                xticklabels=labels,
                yticklabels=labels,
                cmap="viridis",
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8})

    plt.title(f"Normalized Confusion Matrix (Partition gtd{partition})", fontsize=18)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()

    save_path = f"results/confusion_matrix_partition_gtd{partition}.png"
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Saved confusion matrix for partition gtd{partition} to {save_path}")

# %%
plot_confusion_matrix(targets, preds, labels, partition)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_confusion_matrix(targets, preds, labels, partition)
#
# Cell In[6], line 2, in plot_confusion_matrix(y_true, y_pred, labels, partition)
#       1 def plot_confusion_matrix(y_true, y_pred, labels, partition):
# ----> 2     cm = confusion_matrix(y_true, y_pred, labels=range(len(labels)))
#       3     cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
#       5     plt.figure(figsize=(18, 16))
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     340         return np.zeros((n_labels, n_labels), dtype=int)
#     341     elif len(np.intersect1d(y_true, labels)) == 0:
# --> 342         raise ValueError("At least one label specified must be in y_true")
#     344 if sample_weight is None:
#     345     sample_weight = np.ones(y_true.shape[0], dtype=np.int64)
#
# ValueError: At least one label specified must be in y_true
